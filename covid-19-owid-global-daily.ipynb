# %%
import pandas as pd

# %%
df = pd.read_csv("covid-19-data/public/data/owid-covid-data.csv")
df.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1      AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# 0              NaN                597.029                 9.59
# 1              NaN                597.029                 9.59
# 2              NaN                597.029                 9.59
# 3              NaN                597.029                 9.59
# 4              NaN                597.029                 9.59
#
#    female_smokers  male_smokers  handwashing_facilities  \
# 0             NaN           NaN                  37.746
# 1             NaN           NaN                  37.746
# 2             NaN           NaN                  37.746
# 3             NaN           NaN                  37.746
# 4             NaN           NaN                  37.746
#
#    hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                         0.5            64.83                    0.511
# 1                         0.5            64.83                    0.511
# 2                         0.5            64.83                    0.511
# 3                         0.5            64.83                    0.511
# 4                         0.5            64.83                    0.511
#
#    excess_mortality
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
#
# [5 rows x 60 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107897 entries, 0 to 107896
# Data columns (total 60 columns):
#  #   Column                                 Non-Null Count   Dtype
# ---  ------                                 --------------   -----
#  0   iso_code                               107897 non-null  object
#  1   continent                              102895 non-null  object
#  2   location                               107897 non-null  object
#  3   date                                   107897 non-null  object
#  4   total_cases                            103418 non-null  float64
#  5   new_cases                              103415 non-null  float64
#  6   new_cases_smoothed                     102405 non-null  float64
#  7   total_deaths                           93026 non-null   float64
#  8   new_deaths                             93181 non-null   float64
#  9   new_deaths_smoothed                    102405 non-null  float64
#  10  total_cases_per_million                102870 non-null  float64
#  11  new_cases_per_million                  102867 non-null  float64
#  12  new_cases_smoothed_per_million         101862 non-null  float64
#  13  total_deaths_per_million               92491 non-null   float64
#  14  new_deaths_per_million                 92646 non-null   float64
#  15  new_deaths_smoothed_per_million        101862 non-null  float64
#  16  reproduction_rate                      87037 non-null   float64
#  17  icu_patients                           11164 non-null   float64
#  18  icu_patients_per_million               11164 non-null   float64
#  19  hosp_patients                          13506 non-null   float64
#  20  hosp_patients_per_million              13506 non-null   float64
#  21  weekly_icu_admissions                  993 non-null     float64
#  22  weekly_icu_admissions_per_million      993 non-null     float64
#  23  weekly_hosp_admissions                 1897 non-null    float64
#  24  weekly_hosp_admissions_per_million     1897 non-null    float64
#  25  new_tests                              47637 non-null   float64
#  26  total_tests                            47382 non-null   float64
#  27  total_tests_per_thousand               47382 non-null   float64
#  28  new_tests_per_thousand                 47637 non-null   float64
#  29  new_tests_smoothed                     55979 non-null   float64
#  30  new_tests_smoothed_per_thousand        55979 non-null   float64
#  31  positive_rate                          52317 non-null   float64
#  32  tests_per_case                         51685 non-null   float64
#  33  tests_units                            57758 non-null   object
#  34  total_vaccinations                     20884 non-null   float64
#  35  people_vaccinated                      19995 non-null   float64
#  36  people_fully_vaccinated                17025 non-null   float64
#  37  new_vaccinations                       17390 non-null   float64
#  38  new_vaccinations_smoothed              36482 non-null   float64
#  39  total_vaccinations_per_hundred         20884 non-null   float64
#  40  people_vaccinated_per_hundred          19995 non-null   float64
#  41  people_fully_vaccinated_per_hundred    17025 non-null   float64
#  42  new_vaccinations_smoothed_per_million  36482 non-null   float64
#  43  stringency_index                       89606 non-null   float64
#  44  population                             107184 non-null  float64
#  45  population_density                     100109 non-null  float64
#  46  median_age                             96048 non-null   float64
#  47  aged_65_older                          94974 non-null   float64
#  48  aged_70_older                          95519 non-null   float64
#  49  gdp_per_capita                         96462 non-null   float64
#  50  extreme_poverty                        64930 non-null   float64
#  51  cardiovasc_death_rate                  96392 non-null   float64
#  52  diabetes_prevalence                    99041 non-null   float64
#  53  female_smokers                         75329 non-null   float64
#  54  male_smokers                           74229 non-null   float64
#  55  handwashing_facilities                 48413 non-null   float64
#  56  hospital_beds_per_thousand             87725 non-null   float64
#  57  life_expectancy                        102397 non-null  float64
#  58  human_development_index                96497 non-null   float64
#  59  excess_mortality                       3814 non-null    float64
# dtypes: float64(55), object(5)
# memory usage: 49.4+ MB

# %%
df.describe()
# Out:
#         total_cases      new_cases  new_cases_smoothed  total_deaths  \
# count  1.034180e+05  103415.000000       102405.000000  9.302600e+04
# mean   1.205230e+06    6194.990988         6195.409741  3.177895e+04
# std    8.166690e+06   38229.718914        37802.058244  1.897018e+05
# min    1.000000e+00  -74347.000000        -6223.000000  1.000000e+00
# 25%    1.518000e+03       2.000000            8.000000  6.000000e+01
# 50%    1.591000e+04      79.000000           98.000000  4.690000e+02
# 75%    1.681740e+05     854.000000          902.857000  4.446000e+03
# max    2.022909e+08  905993.000000       826368.143000  4.286932e+06
#
#          new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  93181.000000        102405.000000            102870.000000
# mean     145.738906           131.730075             14906.079959
# std      796.315400           741.545016             26576.873437
# min    -1918.000000          -232.143000                 0.001000
# 25%        0.000000             0.000000               291.491000
# 50%        2.000000             1.429000              2159.745500
# 75%       18.000000            15.000000             16178.225250
# max    18000.000000         14726.429000            192014.496000
#
#        new_cases_per_million  new_cases_smoothed_per_million  \
# count          102867.000000                   101862.000000
# mean               77.863603                       77.941722
# std               201.859356                      159.114147
# min             -3162.163000                     -276.825000
# 25%                 0.242000                        1.402000
# 50%                 9.174000                       12.290000
# 75%                73.184000                       81.160500
# max             18293.675000                     4083.500000
#
#        total_deaths_per_million  ...  extreme_poverty  cardiovasc_death_rate  \
# count              92491.000000  ...     64930.000000           96392.000000
# mean                 322.888491  ...        13.441597             258.803167
# std                  569.556810  ...        19.972997             119.151811
# min                    0.001000  ...         0.100000              79.370000
# 25%                    8.901000  ...         0.600000             168.711000
# 50%                   59.160000  ...         2.200000             242.648000
# 75%                  363.928500  ...        21.200000             329.942000
# max                 5970.943000  ...        77.600000             724.417000
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# count         99041.000000    75329.000000  74229.000000
# mean              7.958585       10.583254     32.717840
# std               4.189775       10.484892     13.491991
# min               0.990000        0.100000      7.700000
# 25%               5.310000        1.900000     21.600000
# 50%               7.110000        6.300000     31.400000
# 75%              10.080000       19.300000     41.100000
# max              30.530000       44.000000     78.100000
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# count            48413.000000                87725.000000    102397.000000
# mean                50.791857                    3.026116        73.243479
# std                 31.756591                    2.456131         7.553995
# min                  1.188000                    0.100000        53.280000
# 25%                 19.351000                    1.300000        67.920000
# 50%                 49.839000                    2.400000        74.620000
# 75%                 83.241000                    3.861000        78.740000
# max                100.000000                   13.800000        86.750000
#
#        human_development_index  excess_mortality
# count             96497.000000       3814.000000
# mean                  0.726999         18.228529
# std                   0.150299         35.577132
# min                   0.394000        -95.590000
# 25%                   0.602000          0.535000
# 50%                   0.744000          7.515000
# 75%                   0.848000         24.022500
# max                   0.957000        410.620000
#
# [8 rows x 55 columns]

# %%
df.continent.unique()
# Out:
# array(['Asia', nan, 'Europe', 'Africa', 'North America', 'South America',
#        'Oceania'], dtype=object)

# %%
df.loc[df.continent.isna()].location.unique()
# Out:
# array(['Africa', 'Asia', 'Europe', 'European Union', 'International',
#        'North America', 'Oceania', 'South America', 'World'], dtype=object)

# %%
df.loc[df.location=="International"]
# Out:
#        iso_code continent       location        date  total_cases  new_cases  \
# 45681  OWID_INT       NaN  International  2020-02-07         61.0       61.0
# 45682  OWID_INT       NaN  International  2020-02-08         61.0        0.0
# 45683  OWID_INT       NaN  International  2020-02-09         64.0        3.0
# 45684  OWID_INT       NaN  International  2020-02-10        135.0       71.0
# 45685  OWID_INT       NaN  International  2020-02-11        135.0        0.0
# ...         ...       ...            ...         ...          ...        ...
# 46224  OWID_INT       NaN  International  2021-08-03        721.0        0.0
# 46225  OWID_INT       NaN  International  2021-08-04        721.0        0.0
# 46226  OWID_INT       NaN  International  2021-08-05        721.0        0.0
# 46227  OWID_INT       NaN  International  2021-08-06        721.0        0.0
# 46228  OWID_INT       NaN  International  2021-08-07        721.0        0.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 45681                 NaN           NaN         NaN                  NaN  ...
# 45682                 NaN           NaN         NaN                  NaN  ...
# 45683                 NaN           NaN         NaN                  NaN  ...
# 45684                 NaN           NaN         NaN                  NaN  ...
# 45685                 NaN           NaN         NaN                  NaN  ...
# ...                   ...           ...         ...                  ...  ...
# 46224                 0.0          15.0         0.0                  0.0  ...
# 46225                 0.0          15.0         0.0                  0.0  ...
# 46226                 0.0          15.0         0.0                  0.0  ...
# 46227                 0.0          15.0         0.0                  0.0  ...
# 46228                 0.0          15.0         0.0                  0.0  ...
#
#        extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# 45681              NaN                    NaN                  NaN
# 45682              NaN                    NaN                  NaN
# 45683              NaN                    NaN                  NaN
# 45684              NaN                    NaN                  NaN
# 45685              NaN                    NaN                  NaN
# ...                ...                    ...                  ...
# 46224              NaN                    NaN                  NaN
# 46225              NaN                    NaN                  NaN
# 46226              NaN                    NaN                  NaN
# 46227              NaN                    NaN                  NaN
# 46228              NaN                    NaN                  NaN
#
#        female_smokers  male_smokers  handwashing_facilities  \
# 45681             NaN           NaN                     NaN
# 45682             NaN           NaN                     NaN
# 45683             NaN           NaN                     NaN
# 45684             NaN           NaN                     NaN
# 45685             NaN           NaN                     NaN
# ...               ...           ...                     ...
# 46224             NaN           NaN                     NaN
# 46225             NaN           NaN                     NaN
# 46226             NaN           NaN                     NaN
# 46227             NaN           NaN                     NaN
# 46228             NaN           NaN                     NaN
#
#        hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 45681                         NaN              NaN                      NaN
# 45682                         NaN              NaN                      NaN
# 45683                         NaN              NaN                      NaN
# 45684                         NaN              NaN                      NaN
# 45685                         NaN              NaN                      NaN
# ...                           ...              ...                      ...
# 46224                         NaN              NaN                      NaN
# 46225                         NaN              NaN                      NaN
# 46226                         NaN              NaN                      NaN
# 46227                         NaN              NaN                      NaN
# 46228                         NaN              NaN                      NaN
#
#        excess_mortality
# 45681               NaN
# 45682               NaN
# 45683               NaN
# 45684               NaN
# 45685               NaN
# ...                 ...
# 46224               NaN
# 46225               NaN
# 46226               NaN
# 46227               NaN
# 46228               NaN
#
# [548 rows x 60 columns]

# %%
df.location.unique()
# Out:
# array(['Afghanistan', 'Africa', 'Albania', 'Algeria', 'Andorra', 'Angola',
#        'Anguilla', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        'Asia', 'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain',
#        'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin',
#        'Bermuda', 'Bhutan', 'Bolivia', 'Bonaire Sint Eustatius and Saba',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Brunei', 'Bulgaria', 'Burkina Faso',
#        'Burundi', 'Cambodia', 'Cameroon', 'Canada', 'Cape Verde',
#        'Cayman Islands', 'Central African Republic', 'Chad', 'Chile',
#        'China', 'Colombia', 'Comoros', 'Congo', 'Cook Islands',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Curacao',
#        'Cyprus', 'Czechia', 'Democratic Republic of Congo', 'Denmark',
#        'Djibouti', 'Dominica', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Estonia',
#        'Eswatini', 'Ethiopia', 'Europe', 'European Union',
#        'Faeroe Islands', 'Falkland Islands', 'Fiji', 'Finland', 'France',
#        'French Polynesia', 'Gabon', 'Gambia', 'Georgia', 'Germany',
#        'Ghana', 'Gibraltar', 'Greece', 'Greenland', 'Grenada',
#        'Guatemala', 'Guernsey', 'Guinea', 'Guinea-Bissau', 'Guyana',
#        'Haiti', 'Honduras', 'Hong Kong', 'Hungary', 'Iceland', 'India',
#        'Indonesia', 'International', 'Iran', 'Iraq', 'Ireland',
#        'Isle of Man', 'Israel', 'Italy', 'Jamaica', 'Japan', 'Jersey',
#        'Jordan', 'Kazakhstan', 'Kenya', 'Kiribati', 'Kosovo', 'Kuwait',
#        'Kyrgyzstan', 'Laos', 'Latvia', 'Lebanon', 'Lesotho', 'Liberia',
#        'Libya', 'Liechtenstein', 'Lithuania', 'Luxembourg', 'Macao',
#        'Madagascar', 'Malawi', 'Malaysia', 'Maldives', 'Mali', 'Malta',
#        'Marshall Islands', 'Mauritania', 'Mauritius', 'Mexico',
#        'Micronesia (country)', 'Moldova', 'Monaco', 'Mongolia',
#        'Montenegro', 'Montserrat', 'Morocco', 'Mozambique', 'Myanmar',
#        'Namibia', 'Nauru', 'Nepal', 'Netherlands', 'New Caledonia',
#        'New Zealand', 'Nicaragua', 'Niger', 'Nigeria', 'Niue',
#        'North America', 'North Macedonia', 'Northern Cyprus', 'Norway',
#        'Oceania', 'Oman', 'Pakistan', 'Palestine', 'Panama',
#        'Papua New Guinea', 'Paraguay', 'Peru', 'Philippines', 'Pitcairn',
#        'Poland', 'Portugal', 'Qatar', 'Romania', 'Russia', 'Rwanda',
#        'Saint Helena', 'Saint Kitts and Nevis', 'Saint Lucia',
#        'Saint Vincent and the Grenadines', 'Samoa', 'San Marino',
#        'Sao Tome and Principe', 'Saudi Arabia', 'Senegal', 'Serbia',
#        'Seychelles', 'Sierra Leone', 'Singapore',
#        'Sint Maarten (Dutch part)', 'Slovakia', 'Slovenia',
#        'Solomon Islands', 'Somalia', 'South Africa', 'South America',
#        'South Korea', 'South Sudan', 'Spain', 'Sri Lanka', 'Sudan',
#        'Suriname', 'Sweden', 'Switzerland', 'Syria', 'Taiwan',
#        'Tajikistan', 'Tanzania', 'Thailand', 'Timor', 'Togo', 'Tonga',
#        'Trinidad and Tobago', 'Tunisia', 'Turkey', 'Turkmenistan',
#        'Turks and Caicos Islands', 'Tuvalu', 'Uganda', 'Ukraine',
#        'United Arab Emirates', 'United Kingdom', 'United States',
#        'Uruguay', 'Uzbekistan', 'Vanuatu', 'Vatican', 'Venezuela',
#        'Vietnam', 'Wallis and Futuna', 'World', 'Yemen', 'Zambia',
#        'Zimbabwe'], dtype=object)

# %%
df["date"] = pd.to_datetime(df["date"])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107897 entries, 0 to 107896
# Data columns (total 60 columns):
#  #   Column                                 Non-Null Count   Dtype
# ---  ------                                 --------------   -----
#  0   iso_code                               107897 non-null  object
#  1   continent                              102895 non-null  object
#  2   location                               107897 non-null  object
#  3   date                                   107897 non-null  datetime64[ns]
#  4   total_cases                            103418 non-null  float64
#  5   new_cases                              103415 non-null  float64
#  6   new_cases_smoothed                     102405 non-null  float64
#  7   total_deaths                           93026 non-null   float64
#  8   new_deaths                             93181 non-null   float64
#  9   new_deaths_smoothed                    102405 non-null  float64
#  10  total_cases_per_million                102870 non-null  float64
#  11  new_cases_per_million                  102867 non-null  float64
#  12  new_cases_smoothed_per_million         101862 non-null  float64
#  13  total_deaths_per_million               92491 non-null   float64
#  14  new_deaths_per_million                 92646 non-null   float64
#  15  new_deaths_smoothed_per_million        101862 non-null  float64
#  16  reproduction_rate                      87037 non-null   float64
#  17  icu_patients                           11164 non-null   float64
#  18  icu_patients_per_million               11164 non-null   float64
#  19  hosp_patients                          13506 non-null   float64
#  20  hosp_patients_per_million              13506 non-null   float64
#  21  weekly_icu_admissions                  993 non-null     float64
#  22  weekly_icu_admissions_per_million      993 non-null     float64
#  23  weekly_hosp_admissions                 1897 non-null    float64
#  24  weekly_hosp_admissions_per_million     1897 non-null    float64
#  25  new_tests                              47637 non-null   float64
#  26  total_tests                            47382 non-null   float64
#  27  total_tests_per_thousand               47382 non-null   float64
#  28  new_tests_per_thousand                 47637 non-null   float64
#  29  new_tests_smoothed                     55979 non-null   float64
#  30  new_tests_smoothed_per_thousand        55979 non-null   float64
#  31  positive_rate                          52317 non-null   float64
#  32  tests_per_case                         51685 non-null   float64
#  33  tests_units                            57758 non-null   object
#  34  total_vaccinations                     20884 non-null   float64
#  35  people_vaccinated                      19995 non-null   float64
#  36  people_fully_vaccinated                17025 non-null   float64
#  37  new_vaccinations                       17390 non-null   float64
#  38  new_vaccinations_smoothed              36482 non-null   float64
#  39  total_vaccinations_per_hundred         20884 non-null   float64
#  40  people_vaccinated_per_hundred          19995 non-null   float64
#  41  people_fully_vaccinated_per_hundred    17025 non-null   float64
#  42  new_vaccinations_smoothed_per_million  36482 non-null   float64
#  43  stringency_index                       89606 non-null   float64
#  44  population                             107184 non-null  float64
#  45  population_density                     100109 non-null  float64
#  46  median_age                             96048 non-null   float64
#  47  aged_65_older                          94974 non-null   float64
#  48  aged_70_older                          95519 non-null   float64
#  49  gdp_per_capita                         96462 non-null   float64
#  50  extreme_poverty                        64930 non-null   float64
#  51  cardiovasc_death_rate                  96392 non-null   float64
#  52  diabetes_prevalence                    99041 non-null   float64
#  53  female_smokers                         75329 non-null   float64
#  54  male_smokers                           74229 non-null   float64
#  55  handwashing_facilities                 48413 non-null   float64
#  56  hospital_beds_per_thousand             87725 non-null   float64
#  57  life_expectancy                        102397 non-null  float64
#  58  human_development_index                96497 non-null   float64
#  59  excess_mortality                       3814 non-null    float64
# dtypes: datetime64[ns](1), float64(55), object(4)
# memory usage: 49.4+ MB

# %% [markdown]
# ## 最新日付チェック

# %%
import datetime
#latest_date_str = (df.date.max()-datetime.timedelta(days=1)).strftime("%Y-%m-%d")
latest_date_str = df.date.max().strftime("%Y-%m-%d")
latest_date_str
# Out:
# '2021-08-07'

# %% [markdown]
# ## 全世界のデータのみ

# %%
world_df = df.copy().loc[df.location=="World"]
world_df.tail()
# Out:
#         iso_code continent location       date  total_cases  new_cases  \
# 106393  OWID_WRL       NaN    World 2021-08-03  199565838.0   640774.0
# 106394  OWID_WRL       NaN    World 2021-08-04  200236965.0   671127.0
# 106395  OWID_WRL       NaN    World 2021-08-05  200924905.0   687940.0
# 106396  OWID_WRL       NaN    World 2021-08-06  201746214.0   821309.0
# 106397  OWID_WRL       NaN    World 2021-08-07  202290946.0   544732.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 106393          604504.857     4246202.0     10319.0             9289.429
# 106394          607336.143     4256785.0     10583.0             9339.429
# 106395          613623.571     4267764.0     10979.0             9359.429
# 106396          625725.571     4278354.0     10590.0             9513.714
# 106397          630876.286     4286932.0      8578.0             9474.429
#
#         ...  extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# 106393  ...             10.0                 233.07                 8.51
# 106394  ...             10.0                 233.07                 8.51
# 106395  ...             10.0                 233.07                 8.51
# 106396  ...             10.0                 233.07                 8.51
# 106397  ...             10.0                 233.07                 8.51
#
#         female_smokers  male_smokers  handwashing_facilities  \
# 106393           6.434        34.635                   60.13
# 106394           6.434        34.635                   60.13
# 106395           6.434        34.635                   60.13
# 106396           6.434        34.635                   60.13
# 106397           6.434        34.635                   60.13
#
#         hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 106393                       2.705            72.58                    0.737
# 106394                       2.705            72.58                    0.737
# 106395                       2.705            72.58                    0.737
# 106396                       2.705            72.58                    0.737
# 106397                       2.705            72.58                    0.737
#
#         excess_mortality
# 106393               NaN
# 106394               NaN
# 106395               NaN
# 106396               NaN
# 106397               NaN
#
# [5 rows x 60 columns]

# %% [markdown]
# ### 主要国の定義

# %%
countries = pd.DataFrame([
    ("Japan",""),
    ("United States",""),
    ("India",""),
    ("Indonesia",""),
    ("Spain",""),
    ("Brazil",""),
    ("France",""),
    ("United Kingdom",""),
    ("Russia",""),
    ("Turkey",""),
#    ("South Africa",""),
    ("Iran",""),
#    ("Ecuador",""),
],columns=["country","text_disp_date"])
countries
# Out:
#            country text_disp_date
# 0            Japan
# 1    United States
# 2            India
# 3        Indonesia
# 4            Spain
# 5           Brazil
# 6           France
# 7   United Kingdom
# 8           Russia
# 9           Turkey
# 10            Iran

# %%
# 東Asia 主要国
e_asia_c = pd.DataFrame([
    ("Japan",""),
    ("China",""),
    ("Taiwan",""),
    ("South Korea",""),
    ("Indonesia",""),
    ("Philippines","20210618"),
    ("Vietnam",""),
    ("Myanmar","20210718"),
    ("Thailand",""),
],columns=["country","text_disp_date"])
e_asia_c
# Out:
#        country text_disp_date
# 0        Japan
# 1        China
# 2       Taiwan
# 3  South Korea
# 4    Indonesia
# 5  Philippines       20210618
# 6      Vietnam
# 7      Myanmar       20210718
# 8     Thailand

# %%
c_trans = pd.merge(countries, df, left_on="country", right_on="location",how="inner")
c_trans.head()
# Out:
#   country text_disp_date iso_code continent location       date  total_cases  \
# 0   Japan                     JPN      Asia    Japan 2020-01-22          2.0
# 1   Japan                     JPN      Asia    Japan 2020-01-23          2.0
# 2   Japan                     JPN      Asia    Japan 2020-01-24          2.0
# 3   Japan                     JPN      Asia    Japan 2020-01-25          2.0
# 4   Japan                     JPN      Asia    Japan 2020-01-26          4.0
#
#    new_cases  new_cases_smoothed  total_deaths  ...  extreme_poverty  \
# 0        NaN                 NaN           NaN  ...              NaN
# 1        0.0                 NaN           NaN  ...              NaN
# 2        0.0                 NaN           NaN  ...              NaN
# 3        0.0                 NaN           NaN  ...              NaN
# 4        2.0                 NaN           NaN  ...              NaN
#
#    cardiovasc_death_rate  diabetes_prevalence  female_smokers  male_smokers  \
# 0                  79.37                 5.72            11.2          33.7
# 1                  79.37                 5.72            11.2          33.7
# 2                  79.37                 5.72            11.2          33.7
# 3                  79.37                 5.72            11.2          33.7
# 4                  79.37                 5.72            11.2          33.7
#
#    handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 0                     NaN                       13.05            84.63
# 1                     NaN                       13.05            84.63
# 2                     NaN                       13.05            84.63
# 3                     NaN                       13.05            84.63
# 4                     NaN                       13.05            84.63
#
#    human_development_index  excess_mortality
# 0                    0.919               NaN
# 1                    0.919               NaN
# 2                    0.919               NaN
# 3                    0.919               NaN
# 4                    0.919               NaN
#
# [5 rows x 62 columns]

# %%
c_trans.location.unique()
# Out:
# array(['Japan', 'United States', 'India', 'Indonesia', 'Spain', 'Brazil',
#        'France', 'United Kingdom', 'Russia', 'Turkey', 'Iran'],
#       dtype=object)

# %%
c_trans.loc[c_trans.date==latest_date_str][["country","date","total_deaths","total_deaths_per_million"]].sort_values("total_deaths_per_million",ascending=False)
# Out:
#              country       date  total_deaths  total_deaths_per_million
# 3290          Brazil 2021-08-07      562752.0                  2647.505
# 4407  United Kingdom 2021-08-07      130585.0                  1923.592
# 1127   United States 2021-08-07      616718.0                  1863.181
# 2761           Spain 2021-08-07       82006.0                  1753.960
# 3852          France 2021-08-07      112379.0                  1663.291
# 6013            Iran 2021-08-07       93473.0                  1112.867
# 4962          Russia 2021-08-07      161343.0                  1105.585
# 5477          Turkey 2021-08-07       52088.0                   617.602
# 2207       Indonesia 2021-08-07      105598.0                   386.065
# 1683           India 2021-08-07      427862.0                   310.044
# 563            Japan 2021-08-07       15287.0                   120.868

# %%
e_a_trans = pd.merge(e_asia_c, df, left_on="country", right_on="location",how="inner")
e_a_trans
# Out:
#        country text_disp_date iso_code continent  location       date  \
# 0        Japan                     JPN      Asia     Japan 2020-01-22
# 1        Japan                     JPN      Asia     Japan 2020-01-23
# 2        Japan                     JPN      Asia     Japan 2020-01-24
# 3        Japan                     JPN      Asia     Japan 2020-01-25
# 4        Japan                     JPN      Asia     Japan 2020-01-26
# ...        ...            ...      ...       ...       ...        ...
# 4982  Thailand                     THA      Asia  Thailand 2021-08-03
# 4983  Thailand                     THA      Asia  Thailand 2021-08-04
# 4984  Thailand                     THA      Asia  Thailand 2021-08-05
# 4985  Thailand                     THA      Asia  Thailand 2021-08-06
# 4986  Thailand                     THA      Asia  Thailand 2021-08-07
#
#       total_cases  new_cases  new_cases_smoothed  total_deaths  ...  \
# 0             2.0        NaN                 NaN           NaN  ...
# 1             2.0        0.0                 NaN           NaN  ...
# 2             2.0        0.0                 NaN           NaN  ...
# 3             2.0        0.0                 NaN           NaN  ...
# 4             4.0        2.0                 NaN           NaN  ...
# ...           ...        ...                 ...           ...  ...
# 4982     652185.0    18901.0           17908.143        5315.0  ...
# 4983     672385.0    20200.0           18432.000        5503.0  ...
# 4984     693305.0    20920.0           18896.429        5663.0  ...
# 4985     714684.0    21379.0           19472.714        5854.0  ...
# 4986     736522.0    21838.0           19890.714        6066.0  ...
#
#       extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# 0                 NaN                 79.370                 5.72
# 1                 NaN                 79.370                 5.72
# 2                 NaN                 79.370                 5.72
# 3                 NaN                 79.370                 5.72
# 4                 NaN                 79.370                 5.72
# ...               ...                    ...                  ...
# 4982              0.1                109.861                 7.04
# 4983              0.1                109.861                 7.04
# 4984              0.1                109.861                 7.04
# 4985              0.1                109.861                 7.04
# 4986              0.1                109.861                 7.04
#
#       female_smokers  male_smokers  handwashing_facilities  \
# 0               11.2          33.7                     NaN
# 1               11.2          33.7                     NaN
# 2               11.2          33.7                     NaN
# 3               11.2          33.7                     NaN
# 4               11.2          33.7                     NaN
# ...              ...           ...                     ...
# 4982             1.9          38.8                   90.67
# 4983             1.9          38.8                   90.67
# 4984             1.9          38.8                   90.67
# 4985             1.9          38.8                   90.67
# 4986             1.9          38.8                   90.67
#
#       hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                          13.05            84.63                    0.919
# 1                          13.05            84.63                    0.919
# 2                          13.05            84.63                    0.919
# 3                          13.05            84.63                    0.919
# 4                          13.05            84.63                    0.919
# ...                          ...              ...                      ...
# 4982                        2.10            77.15                    0.777
# 4983                        2.10            77.15                    0.777
# 4984                        2.10            77.15                    0.777
# 4985                        2.10            77.15                    0.777
# 4986                        2.10            77.15                    0.777
#
#       excess_mortality
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# ...                ...
# 4982               NaN
# 4983               NaN
# 4984               NaN
# 4985               NaN
# 4986               NaN
#
# [4987 rows x 62 columns]

# %%
e_a_trans.location.unique()
# Out:
# array(['Japan', 'China', 'Taiwan', 'South Korea', 'Indonesia',
#        'Philippines', 'Vietnam', 'Myanmar', 'Thailand'], dtype=object)

# %% [markdown]
# ## 今日の新規感染者数

# %%
#c_df_latest = df.loc[(df.date==pd.to_datetime(latest_date_str)-datetime.timedelta(days=1)) & (df.iso_code.str.len()==3)]
c_df_latest = df.loc[(df.date==pd.to_datetime(latest_date_str)) & (df.iso_code.str.len()==3)]

c_df_latest
# Out:
#        iso_code      continent     location       date  total_cases  \
# 530         AFG           Asia  Afghanistan 2021-08-07     149810.0
# 1602        ALB         Europe      Albania 2021-08-07     133730.0
# 2132        DZA         Africa      Algeria 2021-08-07     180356.0
# 2656        AND         Europe      Andorra 2021-08-07      14836.0
# 3162        AGO         Africa       Angola 2021-08-07      43592.0
# ...         ...            ...          ...        ...          ...
# 105137      VEN  South America    Venezuela 2021-08-07     312115.0
# 105700      VNM           Asia      Vietnam 2021-08-07     205656.0
# 106882      YEM           Asia        Yemen 2021-08-07       7131.0
# 107390      ZMB         Africa       Zambia 2021-08-07     199662.0
# 107896      ZWE         Africa     Zimbabwe 2021-08-07     115890.0
#
#         new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 530           0.0             469.571        6879.0         0.0
# 1602        139.0              92.714        2459.0         1.0
# 2132       1140.0            1280.571        4520.0        33.0
# 2656          0.0              22.571         128.0         0.0
# 3162        105.0             116.429        1044.0         2.0
# ...           ...                 ...           ...         ...
# 105137     1155.0             907.000        3694.0        12.0
# 105700    12275.0            7942.286        3250.0       234.0
# 106882        0.0              10.000        1384.0         0.0
# 107390      527.0             549.429        3474.0        15.0
# 107896      445.0            1004.286        3826.0        21.0
#
#         new_deaths_smoothed  ...  extreme_poverty  cardiovasc_death_rate  \
# 530                  28.857  ...              NaN                597.029
# 1602                  0.286  ...              1.1                304.195
# 2132                 38.000  ...              0.5                278.364
# 2656                  0.000  ...              NaN                109.135
# 3162                  4.714  ...              NaN                276.045
# ...                     ...  ...              ...                    ...
# 105137               14.714  ...              NaN                204.850
# 105700              277.714  ...              2.0                245.465
# 106882                1.286  ...             18.8                495.003
# 107390               12.143  ...             57.5                234.499
# 107896               42.000  ...             21.4                307.846
#
#         diabetes_prevalence  female_smokers  male_smokers  \
# 530                    9.59             NaN           NaN
# 1602                  10.08             7.1          51.2
# 2132                   6.73             0.7          30.4
# 2656                   7.97            29.0          37.8
# 3162                   3.94             NaN           NaN
# ...                     ...             ...           ...
# 105137                 6.47             NaN           NaN
# 105700                 6.00             1.0          45.9
# 106882                 5.35             7.6          29.2
# 107390                 3.94             3.1          24.7
# 107896                 1.82             1.6          30.7
#
#         handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 530                     37.746                        0.50            64.83
# 1602                       NaN                        2.89            78.57
# 2132                    83.741                        1.90            76.88
# 2656                       NaN                         NaN            83.73
# 3162                    26.664                         NaN            61.15
# ...                        ...                         ...              ...
# 105137                     NaN                        0.80            72.06
# 105700                  85.847                        2.60            75.40
# 106882                  49.542                        0.70            66.12
# 107390                  13.938                        2.00            63.89
# 107896                  36.791                        1.70            61.49
#
#         human_development_index  excess_mortality
# 530                       0.511               NaN
# 1602                      0.795               NaN
# 2132                      0.748               NaN
# 2656                      0.868               NaN
# 3162                      0.581               NaN
# ...                         ...               ...
# 105137                    0.711               NaN
# 105700                    0.704               NaN
# 106882                    0.470               NaN
# 107390                    0.584               NaN
# 107896                    0.571               NaN
#
# [192 rows x 60 columns]

# %%
c_df_latest.sum()
# Out:
# iso_code                                 AFGALBDZAANDAGOATGARGARMAUSAUTAZEBHSBHRBGDBRBB...
# continent                                AsiaEuropeAfricaEuropeAfricaNorth AmericaSouth...
# location                                 AfghanistanAlbaniaAlgeriaAndorraAngolaAntigua ...
# total_cases                                                                    202180154.0
# new_cases                                                                         544358.0
# new_cases_smoothed                                                              630667.714
# total_deaths                                                                     4284646.0
# new_deaths                                                                          8577.0
# new_deaths_smoothed                                                               9474.144
# total_cases_per_million                                                        7605056.593
# new_cases_per_million                                                            17875.331
# new_cases_smoothed_per_million                                                   21639.203
# total_deaths_per_million                                                        133494.712
# new_deaths_per_million                                                             197.038
# new_deaths_smoothed_per_million                                                     241.21
# reproduction_rate                                                                      0.0
# icu_patients                                                                           0.0
# icu_patients_per_million                                                               0.0
# hosp_patients                                                                          0.0
# hosp_patients_per_million                                                              0.0
# weekly_icu_admissions                                                                  0.0
# weekly_icu_admissions_per_million                                                      0.0
# weekly_hosp_admissions                                                                 0.0
# weekly_hosp_admissions_per_million                                                     0.0
# new_tests                                                                              0.0
# total_tests                                                                            0.0
# total_tests_per_thousand                                                               0.0
# new_tests_per_thousand                                                                 0.0
# new_tests_smoothed                                                                     0.0
# new_tests_smoothed_per_thousand                                                        0.0
# positive_rate                                                                          0.0
# tests_per_case                                                                         0.0
# tests_units                                                                              0
# total_vaccinations                                                            3578548982.0
# people_vaccinated                                                             1188242836.0
# people_fully_vaccinated                                                        622803891.0
# new_vaccinations                                                                28418594.0
# new_vaccinations_smoothed                                                       32372053.0
# total_vaccinations_per_hundred                                                     4347.66
# people_vaccinated_per_hundred                                                      2428.39
# people_fully_vaccinated_per_hundred                                                1792.18
# new_vaccinations_smoothed_per_million                                             301213.0
# stringency_index                                                                       0.0
# population                                                                    7754692151.0
# population_density                                                               64107.006
# median_age                                                                          5561.4
# aged_65_older                                                                     1567.406
# aged_70_older                                                                      996.387
# gdp_per_capita                                                                 3368457.295
# extreme_poverty                                                                     1731.0
# cardiovasc_death_rate                                                            48966.937
# diabetes_prevalence                                                                1514.99
# female_smokers                                                                      1517.2
# male_smokers                                                                        4633.3
# handwashing_facilities                                                            4715.599
# hospital_beds_per_thousand                                                         500.078
# life_expectancy                                                                   13994.45
# human_development_index                                                            134.272
# excess_mortality                                                                       0.0
# dtype: object

# %% [markdown]
# ## 可視化

# %%
import matplotlib.pyplot as plt
#%matplotlib notebook
# %matplotlib inline

# %%
min_date = pd.to_datetime("2021-05-01")

# %%
world_df["case_rolling7ave"] = world_df.new_cases.rolling(7).mean()
world_df[["new_cases_smoothed","case_rolling7ave"]]
# Out:
#         new_cases_smoothed  case_rolling7ave
# 105834                 NaN               NaN
# 105835                 NaN               NaN
# 105836                 NaN               NaN
# 105837                 NaN               NaN
# 105838                 NaN               NaN
# ...                    ...               ...
# 106393          604504.857     604504.857143
# 106394          607336.143     607336.142857
# 106395          613623.571     613623.571429
# 106396          625725.571     625725.571429
# 106397          630876.286     630876.285714
#
# [564 rows x 2 columns]

# %%
fig=plt.figure(figsize=(20,12))
plt.subplot(2,2,1) # (rows, columns, panel number)
plt.title("Daily new confirmed COVID-19 cases in the world")
plt.bar(world_df.date,world_df.new_cases,label="New cases")
plt.plot_date(world_df["date"],world_df["new_cases_smoothed"],label="rolling 7-day average", fmt="-", color="orange")
#plt.xticks(rotation=70)
plt.ylabel("people")
plt.grid(axis="y")
plt.legend()

plt.subplot(2,2,2) # (rows, columns, panel number)
plt.title("Daily new confirmed COVID-19 cases in the world(Recent)")
chart_data = world_df[world_df.date >= min_date]
plt.bar(chart_data["date"],chart_data["new_cases"],label="New cases")
plt.plot_date(chart_data["date"],chart_data["new_cases_smoothed"],label="rolling 7-day average", fmt="-", color="orange")
#plt.xticks(rotation=70)
plt.grid(axis="y")
plt.legend()

plt.subplot(2,2,3) # (rows, columns, panel number)
plt.title("Daily new deaths in the world")
plt.bar(world_df.date,world_df.new_deaths,label="New deaths")
plt.plot_date(world_df["date"],world_df["new_deaths_smoothed"],label="rolling 7-day average", fmt="-", color="orange")
#plt.xticks(rotation=70)
plt.ylabel("people")
plt.grid(axis="y")
plt.legend()

plt.subplot(2,2,4) # (rows, columns, panel number)
plt.title("Daily new deaths in the world(Recent)")
chart_data = world_df[world_df.date >= min_date]
plt.bar(chart_data["date"],chart_data["new_deaths"],label="New deaths")
plt.plot_date(chart_data["date"],chart_data["new_deaths_smoothed"],label="rolling 7-day average", fmt="-", color="orange")
#plt.xticks(rotation=70)
plt.grid(axis="y")
plt.legend()

fig.text(0,1,"Latest: {}".format(latest_date_str),ha="left",va="top")
fig.text(0,0
         ,"*Data Source : COVID-19 Dataset by Our World in Data",
        ha="left",va="bottom")

fig.tight_layout()

# %%
fig.savefig("out/covid-owid-global-daily.png")

# %% [markdown]
# ### 国別

# %% [markdown]
# #### 人口100万人当たりの新規感染者数（直近）

# %%
"""
#min_date = pd.to_datetime("2021-05-01")
# 主要国 新規感染者
chart_data = c_trans[c_trans.date >= min_date]
dates = chart_data["date"].unique()
print(len(dates))
print(dates.max())
for i,cr in countries.iterrows():
    c = cr["country"]
    dates = chart_data.loc[chart_data["location"]==c]["date"]
    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else latest_date_str
    print(len(chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"]))
    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"],label=c, fmt="-")
    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_cases_smoothed_per_million"],c
            ,fontsize=8,va="center")
"""
# Out:
# '\n#min_date = pd.to_datetime("2021-05-01")\n# 主要国 新規感染者\nchart_data = c_trans[c_trans.date >= min_date]\ndates = chart_data["date"].unique()\nprint(len(dates))\nprint(dates.max())\nfor i,cr in countries.iterrows():\n    c = cr["country"]\n    dates = chart_data.loc[chart_data["location"]==c]["date"]\n    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else latest_date_str\n    print(len(chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"]))\n    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"],label=c, fmt="-")\n    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_cases_smoothed_per_million"],c\n            ,fontsize=8,va="center")\n'

# %%
"""
fig=plt.figure(figsize=(14,10))
min_date = pd.to_datetime("2021-03-01")
# 主要国 新規感染者
plt.subplot(2,2,1) # (rows, columns, panel number)
plt.title("Daily new confirmed COVID-19 cases\n per million population in major countries\n(rolling 7day ave.)")
plt.grid()
plt.xticks(rotation=70)
chart_data = c_trans[c_trans.date >= min_date]
dates = chart_data["date"].unique()
for i,cr in countries.iterrows():
    c = cr["country"]
    dates = chart_data.loc[chart_data["location"]==c]["date"]
    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else dates.max()
    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"],label=c, fmt="-")
    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_cases_smoothed_per_million"],c
            ,fontsize=8,va="center")
plt.legend(bbox_to_anchor=(0, 1),loc='upper left', fontsize=9)
"""
# Out:
# '\nfig=plt.figure(figsize=(14,10))\nmin_date = pd.to_datetime("2021-03-01")\n# 主要国 新規感染者\nplt.subplot(2,2,1) # (rows, columns, panel number)\nplt.title("Daily new confirmed COVID-19 cases\n per million population in major countries\n(rolling 7day ave.)")\nplt.grid()\nplt.xticks(rotation=70)\nchart_data = c_trans[c_trans.date >= min_date]\ndates = chart_data["date"].unique()\nfor i,cr in countries.iterrows():\n    c = cr["country"]\n    dates = chart_data.loc[chart_data["location"]==c]["date"]\n    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else dates.max()\n    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"],label=c, fmt="-")\n    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_cases_smoothed_per_million"],c\n            ,fontsize=8,va="center")\nplt.legend(bbox_to_anchor=(0, 1),loc=\'upper left\', fontsize=9)\n'

# %%
fig=plt.figure(figsize=(20,14))
# 主要国 新規感染者
plt.subplot(2,2,1) # (rows, columns, panel number)
plt.title("Daily new confirmed COVID-19 cases\n per million population in major countries\n(rolling 7day ave.)")
plt.grid()
plt.xticks(rotation=45)
chart_data = c_trans[c_trans.date >= min_date]
for i,cr in countries.iterrows():
    c = cr["country"]
    dates = chart_data.loc[chart_data["location"]==c]["date"]
    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else dates.max()
    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"],label=c, fmt="-")
    text_y = chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_cases_smoothed_per_million"]
#    print(text_y)
    print(c,text_disp_date,text_y)
#    plt.text(text_disp_date,text_y,c,fontsize=10,va="center")
    plt.text(text_disp_date,text_y,c,va="center")
plt.legend(bbox_to_anchor=(0, 1),loc='upper left')

# 主要国 死者
plt.subplot(2,2,2) # (rows, columns, panel number)
plt.title("Daily new deaths in major countries(rolling 7day ave.)")
plt.grid()
plt.xticks(rotation=45)
chart_data = c_trans[c_trans.date >= min_date]
for i,cr in countries.iterrows():
    c = cr["country"]
    dates = chart_data.loc[chart_data["location"]==c]["date"]
    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else dates.max()
    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_deaths_smoothed"],label=c, fmt="-")
    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_deaths_smoothed"],c
            ,va="center")
plt.legend(bbox_to_anchor=(0, 1),loc='upper left')

plt.subplot(2,2,3) # (rows, columns, panel number)
plt.grid()
plt.xticks(rotation=45)
plt.title("Daily new confirmed COVID-19 cases\n per million population in Eastern Asia\n(rolling 7day ave.)")
chart_data = e_a_trans[e_a_trans.date >= min_date]
for i,cr in e_asia_c.iterrows():
    c = cr["country"]
    dates = chart_data.loc[chart_data["location"]==c]["date"]
    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else dates.max()
    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"],label=c, fmt="-")
    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_cases_smoothed_per_million"],c
             ,va="center")
plt.legend(bbox_to_anchor=(0, 1),loc='upper left')

plt.subplot(2,2,4) # (rows, columns, panel number)
plt.grid()
plt.xticks(rotation=45)
plt.title("Daily new deaths in Eastern Asia(rolling 7day ave.)")
chart_data = e_a_trans[e_a_trans.date >= min_date]
for i,cr in e_asia_c.iterrows():
    c = cr["country"]
    dates = chart_data.loc[chart_data["location"]==c]["date"]
    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else dates.max()
    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_deaths_smoothed"],label=c, fmt="-")
    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_deaths_smoothed"],c
             ,va="center")
plt.legend(bbox_to_anchor=(0, 1),loc='upper left')

fig.text(0,0.98,"Latest: {}".format(latest_date_str),ha="left",va="top")
fig.text(0,0
         ,"*Data Source : COVID-19 Dataset by Our World in Data",
        ha="left",va="bottom")
fig.tight_layout()
"""
"""
# Out:
# Japan 2021-08-07 00:00:00 563    102.413
# Name: new_cases_smoothed_per_million, dtype: float64
# United States 2021-08-07 00:00:00 1127    328.558
# Name: new_cases_smoothed_per_million, dtype: float64
# India 2021-08-07 00:00:00 1683    28.844
# Name: new_cases_smoothed_per_million, dtype: float64
# Indonesia 2021-08-07 00:00:00 2207    120.103
# Name: new_cases_smoothed_per_million, dtype: float64
# Spain 2021-08-07 00:00:00 2761    431.088
# Name: new_cases_smoothed_per_million, dtype: float64
# Brazil 2021-08-07 00:00:00 3290    157.216
# Name: new_cases_smoothed_per_million, dtype: float64
# France 2021-08-07 00:00:00 3852    339.497
# Name: new_cases_smoothed_per_million, dtype: float64
# United Kingdom 2021-08-07 00:00:00 4407    394.468
# Name: new_cases_smoothed_per_million, dtype: float64
# Russia 2021-08-07 00:00:00 4962    151.85
# Name: new_cases_smoothed_per_million, dtype: float64
# Turkey 2021-08-07 00:00:00 5477    285.914
# Name: new_cases_smoothed_per_million, dtype: float64
# Iran 2021-08-07 00:00:00 6013    421.978
# Name: new_cases_smoothed_per_million, dtype: float64
# '\n'

# %%
fig.savefig("out/covid-owid-countries-daily.png")

# %% [markdown]
# ### 新規感染者数

# %%
fig = plt.figure(figsize=(12,14))

plt.subplot(2,2,1) # (rows, columns, panel number)
plt.title("New confirmed COVID-19 cases worst 50")
plt.yticks(fontsize=9)
plt.xlabel("people")
chart_data = c_df_latest.sort_values("new_cases",ascending=False).head(50).sort_values("new_cases",ascending=True)
plt.barh(chart_data["location"],chart_data["new_cases"],label="new cases a day")
plt.grid(axis="x")
mean = int(c_df_latest.new_cases.mean())
plt.plot([mean,mean],[0,50], 'k--', lw=0.5)
plt.text(mean,50,"Mean:{}".format(mean),ha="center",fontsize=9)
plt.legend()

plt.subplot(2,2,2) # (rows, columns, panel number)
plt.title("New confirmed COVID-19 cases per million worst 50")
plt.yticks(fontsize=9)
plt.xlabel("people")
chart_data = c_df_latest.sort_values("new_cases_per_million",ascending=False).head(50).sort_values("new_cases_per_million",ascending=True)
plt.barh(chart_data["location"],chart_data["new_cases_per_million"],label="new cases a day per million")
plt.grid(axis="x")
mean = int(chart_data.new_cases_per_million.mean())
plt.plot([mean,mean],[0,50], 'k--', lw=0.5)
plt.text(mean,50,"Mean:{}".format(mean),ha="center",fontsize=9)
plt.legend()

fig.text(0,0.98,"Latest: {}".format(latest_date_str),fontsize=9,ha="left",va="top")
fig.text(0,0
         ,"*Data Source : COVID-19 Dataset by Our World in Data",
        fontsize=8,ha="left",va="bottom")

plt.subplot(2,2,3) # (rows, columns, panel number)
plt.title("New deaths worst 50")
plt.yticks(fontsize=9)
plt.xlabel("people")
chart_data = c_df_latest.sort_values("new_deaths",ascending=False).head(50).sort_values("new_deaths",ascending=True)
plt.barh(chart_data["location"],chart_data["new_deaths"],label="new deaths a day")
plt.grid(axis="x")
mean = int(c_df_latest.new_deaths.mean())
plt.plot([mean,mean],[0,50], 'k--', lw=0.5)
plt.text(mean,50,"Mean:{}".format(mean),ha="center",fontsize=9)
plt.legend()

plt.subplot(2,2,4) # (rows, columns, panel number)
plt.title("Total deaths per capita worst 50")
plt.yticks(fontsize=9)
plt.xlabel("%")
chart_data = c_df_latest.copy()
chart_data["total_deaths_per_capita"] = chart_data.total_deaths / chart_data.population * 100
chart_data = chart_data.sort_values("total_deaths_per_capita",ascending=False).head(50).sort_values("total_deaths_per_capita",ascending=True)
plt.barh(chart_data["location"],chart_data["total_deaths_per_capita"],label="total deaths per capita")
plt.grid(axis="x")
mean = round(chart_data.total_deaths_per_capita.mean(),2)
plt.plot([mean,mean],[0,50], 'k--', lw=0.5)
plt.text(mean,50,"Mean:{}".format(mean),ha="center",fontsize=9)
plt.legend()


fig.tight_layout()

# %%
fig.savefig("out/covid-owid-global-latest-top.png")

# %%
a_df = df.loc[df.location=="Japan"]
c_df = df.loc[(df.date==pd.to_datetime("2021-07-27")) & (df.iso_code.str.len()==3)]

# %%
a_df.tail(10)
# Out:
#       iso_code continent location       date  total_cases  new_cases  \
# 50176      JPN      Asia    Japan 2021-07-29     904126.0    10684.0
# 50177      JPN      Asia    Japan 2021-07-30     914718.0    10592.0
# 50178      JPN      Asia    Japan 2021-07-31     927058.0    12340.0
# 50179      JPN      Asia    Japan 2021-08-01     937348.0    10290.0
# 50180      JPN      Asia    Japan 2021-08-02     945746.0     8398.0
# 50181      JPN      Asia    Japan 2021-08-03     957791.0    12045.0
# 50182      JPN      Asia    Japan 2021-08-04     971905.0    14114.0
# 50183      JPN      Asia    Japan 2021-08-05     987206.0    15301.0
# 50184      JPN      Asia    Japan 2021-08-06    1002693.0    15487.0
# 50185      JPN      Asia    Japan 2021-08-07    1017728.0    15035.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 50176            6517.571       15188.0        14.0               19.429  ...
# 50177            7447.571       15197.0         9.0               19.714  ...
# 50178            8676.143       15206.0         9.0               19.714  ...
# 50179            9426.857       15211.0         5.0               19.857  ...
# 50180            9955.286       15222.0        11.0               19.714  ...
# 50181           10574.857       15232.0        10.0               19.429  ...
# 50182           11209.000       15246.0        14.0               10.286  ...
# 50183           11868.571       15254.0         8.0                9.429  ...
# 50184           12567.857       15272.0        18.0               10.714  ...
# 50185           12952.857       15287.0        15.0               11.571  ...
#
#        extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# 50176              NaN                  79.37                 5.72
# 50177              NaN                  79.37                 5.72
# 50178              NaN                  79.37                 5.72
# 50179              NaN                  79.37                 5.72
# 50180              NaN                  79.37                 5.72
# 50181              NaN                  79.37                 5.72
# 50182              NaN                  79.37                 5.72
# 50183              NaN                  79.37                 5.72
# 50184              NaN                  79.37                 5.72
# 50185              NaN                  79.37                 5.72
#
#        female_smokers  male_smokers  handwashing_facilities  \
# 50176            11.2          33.7                     NaN
# 50177            11.2          33.7                     NaN
# 50178            11.2          33.7                     NaN
# 50179            11.2          33.7                     NaN
# 50180            11.2          33.7                     NaN
# 50181            11.2          33.7                     NaN
# 50182            11.2          33.7                     NaN
# 50183            11.2          33.7                     NaN
# 50184            11.2          33.7                     NaN
# 50185            11.2          33.7                     NaN
#
#        hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 50176                       13.05            84.63                    0.919
# 50177                       13.05            84.63                    0.919
# 50178                       13.05            84.63                    0.919
# 50179                       13.05            84.63                    0.919
# 50180                       13.05            84.63                    0.919
# 50181                       13.05            84.63                    0.919
# 50182                       13.05            84.63                    0.919
# 50183                       13.05            84.63                    0.919
# 50184                       13.05            84.63                    0.919
# 50185                       13.05            84.63                    0.919
#
#        excess_mortality
# 50176               NaN
# 50177               NaN
# 50178               NaN
# 50179               NaN
# 50180               NaN
# 50181               NaN
# 50182               NaN
# 50183               NaN
# 50184               NaN
# 50185               NaN
#
# [10 rows x 60 columns]

# %%
c_df.sort_values("new_deaths",ascending=False).head(50)
# Out:
#        iso_code      continent        location       date  total_cases  \
# 45669       IDN           Asia       Indonesia 2021-07-27    3239936.0
# 14216       BRA  South America          Brazil 2021-07-27   19749073.0
# 80646       RUS         Europe          Russia 2021-07-27    6094379.0
# 45145       IND           Asia           India 2021-07-27   31484605.0
# 63338       MEX  North America          Mexico 2021-07-27    2771846.0
# 102799      USA  North America   United States 2021-07-27   34603919.0
# 46753       IRN           Asia            Iran 2021-07-27    3758197.0
# 67330       MMR           Asia         Myanmar 2021-07-27     279119.0
# 89727       ZAF         Africa    South Africa 2021-07-27    2391223.0
# 21336       COL  South America        Colombia 2021-07-27    4747775.0
# 8825        BGD           Asia      Bangladesh 2021-07-27    1194752.0
# 4426        ARG  South America       Argentina 2021-07-27    4875927.0
# 59881       MYS           Asia        Malaysia 2021-07-27    1044071.0
# 99334       TUN         Africa         Tunisia 2021-07-27     575002.0
# 102235      GBR         Europe  United Kingdom 2021-07-27    5771732.0
# 97169       THA           Asia        Thailand 2021-07-27     526828.0
# 107885      ZWE         Africa        Zimbabwe 2021-07-27     101711.0
# 77365       PER  South America            Peru 2021-07-27    2106371.0
# 24448       CUB  North America            Cuba 2021-07-27     349055.0
# 77921       PHL           Asia     Philippines 2021-07-27    1562420.0
# 47284       IRQ           Asia            Iraq 2021-07-27    1577013.0
# 12669       BOL  South America         Bolivia 2021-07-27     470024.0
# 40231       GTM  North America       Guatemala 2021-07-27     355223.0
# 42975       HND  North America        Honduras 2021-07-27     291687.0
# 76780       PRY  South America        Paraguay 2021-07-27     450494.0
# 91869       ESP         Europe           Spain 2021-07-27    4368453.0
# 99849       TUR           Asia          Turkey 2021-07-27    5638178.0
# 92428       LKA           Asia       Sri Lanka 2021-07-27     299892.0
# 74717       PAK           Asia        Pakistan 2021-07-27    1015827.0
# 22889       CRI  North America      Costa Rica 2021-07-27     402044.0
# 101123      UKR         Europe         Ukraine 2021-07-27    2327777.0
# 519         AFG           Asia     Afghanistan 2021-07-27     145008.0
# 67842       NAM         Africa         Namibia 2021-07-27     117293.0
# 66831       MOZ         Africa      Mozambique 2021-07-27     113426.0
# 35453       FRA         Europe          France 2021-07-27    6088930.0
# 20252       CHL  South America           Chile 2021-07-27    1611090.0
# 59320       MWI         Africa          Malawi 2021-07-27      49752.0
# 66327       MAR         Africa         Morocco 2021-07-27     588448.0
# 2121        DZA         Africa         Algeria 2021-07-27     165204.0
# 49095       ITA         Europe           Italy 2021-07-27    4325046.0
# 56557       LBY         Africa           Libya 2021-07-27     240309.0
# 107379      ZMB         Africa          Zambia 2021-07-27     192956.0
# 68514       NPL           Asia           Nepal 2021-07-27     685673.0
# 16892       KHM           Asia        Cambodia 2021-07-27      74386.0
# 37747       DEU         Europe         Germany 2021-07-27    3766501.0
# 74187       OMN           Asia            Oman 2021-07-27     295017.0
# 37185       GEO           Asia         Georgia 2021-07-27     407689.0
# 105126      VEN  South America       Venezuela 2021-07-27     301979.0
# 53504       KGZ           Asia      Kyrgyzstan 2021-07-27     159089.0
# 85106       SEN         Africa         Senegal 2021-07-27      58523.0
#
#         new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 45669     45203.0           41411.143       86835.0      2069.0
# 14216     41411.0           47090.857      551835.0      1333.0
# 80646     22486.0           23207.714      152836.0       767.0
# 45145     43654.0           38324.000      422022.0       640.0
# 63338     17408.0           13364.143      239079.0       484.0
# 102799    70740.0           61306.429      611416.0       439.0
# 46753     34951.0           26007.000       89479.0       357.0
# 67330      4964.0            5507.000        7845.0       338.0
# 89727      7733.0           11427.286       70338.0       320.0
# 21336     11426.0           11289.286      119482.0       300.0
# 8825      14925.0            9409.000       19779.0       258.0
# 4426      16757.0           13101.143      104352.0       247.0
# 59881     16117.0           14881.714        8408.0       207.0
# 99334      1608.0            2870.143       18968.0       164.0
# 102235    23401.0           32728.143      129591.0       131.0
# 97169     14150.0           14336.143        4264.0       118.0
# 107885     1767.0            1899.429        3280.0       107.0
# 77365      1366.0            1479.714      196058.0        85.0
# 24448      7903.0            7800.857        2492.0        75.0
# 77921      7024.0            6359.571       27318.0        71.0
# 47284     12185.0            9499.429       18418.0        71.0
# 12669      1601.0             985.571       17716.0        65.0
# 40231      2639.0            2494.429       10176.0        64.0
# 42975      1240.0            1285.857        7713.0        63.0
# 76780       592.0             603.857       14759.0        58.0
# 91869     26399.0           25616.714       81323.0        55.0
# 99849     19761.0           13144.571       51048.0        51.0
# 92428      1711.0            1702.714        4195.0        48.0
# 74717      4119.0            2768.000       23133.0        46.0
# 22889      3436.0            1129.857        4987.0        46.0
# 101123     1227.0            1127.286       55420.0        39.0
# 519         723.0             370.571        6515.0        38.0
# 67842       329.0             550.714        2871.0        37.0
# 66831      1703.0            1631.000        1341.0        34.0
# 35453     27128.0           19513.000      111883.0        32.0
# 20252       745.0            1318.857       35151.0        32.0
# 59320       743.0             724.000        1540.0        27.0
# 66327      6971.0            3718.857        9638.0        27.0
# 2121       1544.0            1345.714        4112.0        25.0
# 49095      4516.0            4566.143      127995.0        24.0
# 56557      3348.0            1944.000        3422.0        24.0
# 107379      640.0             764.857        3316.0        21.0
# 68514      2726.0            2102.857        9758.0        20.0
# 16892       685.0             798.571        1324.0        19.0
# 37747      2060.0            1665.000       91592.0        19.0
# 74187       491.0             853.571        3788.0        17.0
# 37185      3666.0            2392.000        5731.0        17.0
# 105126     1060.0            1159.000        3524.0        15.0
# 53504       969.0            1068.857        2275.0        14.0
# 85106       642.0             707.143        1300.0        14.0
#
#         new_deaths_smoothed  ...  extreme_poverty  cardiovasc_death_rate  \
# 45669              1519.286  ...              5.7                342.864
# 14216              1093.571  ...              3.4                177.961
# 80646               768.429  ...              0.1                431.297
# 45145               506.000  ...             21.2                282.280
# 63338               324.143  ...              2.5                152.783
# 102799              293.429  ...              1.2                151.089
# 46753               265.000  ...              0.2                270.308
# 67330               325.429  ...              6.4                202.104
# 89727               380.286  ...             18.9                200.380
# 21336               335.857  ...              4.5                124.240
# 8825                207.714  ...             14.8                298.003
# 4426                281.571  ...              0.6                191.032
# 59881               166.714  ...              0.1                260.942
# 99334               163.857  ...              2.0                318.991
# 102235               68.857  ...              0.2                122.137
# 97169               108.857  ...              0.1                109.861
# 107885               76.143  ...             21.4                307.846
# 77365               103.714  ...              3.5                 85.755
# 24448                67.571  ...              NaN                190.968
# 77921                67.714  ...              NaN                370.437
# 47284                66.714  ...              2.5                218.612
# 12669                34.429  ...              7.1                204.299
# 40231                35.571  ...              8.7                155.898
# 42975                29.429  ...             16.0                240.208
# 76780                52.143  ...              1.7                199.128
# 91869                25.000  ...              1.0                 99.403
# 99849                56.857  ...              0.2                171.285
# 92428                46.429  ...              0.7                197.093
# 74717                35.000  ...              4.0                423.031
# 22889                10.286  ...              1.3                137.973
# 101123               28.429  ...              0.1                539.849
# 519                  35.571  ...              NaN                597.029
# 67842                44.857  ...             13.4                243.811
# 66831                26.143  ...             62.9                329.942
# 35453                24.000  ...              NaN                 86.060
# 20252                83.143  ...              1.3                127.993
# 59320                25.286  ...             71.4                227.349
# 66327                21.714  ...              1.0                419.146
# 2121                 19.000  ...              0.5                278.364
# 49095                15.857  ...              2.0                113.151
# 56557                16.143  ...              NaN                341.862
# 107379               25.429  ...             57.5                234.499
# 68514                21.571  ...             15.0                260.797
# 16892                25.000  ...              NaN                270.892
# 37747                24.143  ...              NaN                156.139
# 74187                41.429  ...              NaN                266.342
# 37185                19.857  ...              4.2                496.218
# 105126               18.857  ...              NaN                204.850
# 53504                11.286  ...              1.4                436.362
# 85106                 9.143  ...             38.0                241.219
#
#         diabetes_prevalence  female_smokers  male_smokers  \
# 45669                  6.32             2.8          76.1
# 14216                  8.11            10.1          17.9
# 80646                  6.18            23.4          58.3
# 45145                 10.39             1.9          20.6
# 63338                 13.06             6.9          21.4
# 102799                10.79            19.1          24.6
# 46753                  9.59             0.8          21.1
# 67330                  4.61             6.3          35.2
# 89727                  5.52             8.1          33.2
# 21336                  7.44             4.7          13.5
# 8825                   8.38             1.0          44.7
# 4426                   5.50            16.2          27.7
# 59881                 16.74             1.0          42.4
# 99334                  8.52             1.1          65.8
# 102235                 4.28            20.0          24.7
# 97169                  7.04             1.9          38.8
# 107885                 1.82             1.6          30.7
# 77365                  5.95             4.8           NaN
# 24448                  8.27            17.1          53.3
# 77921                  7.07             7.8          40.8
# 47284                  8.83             NaN           NaN
# 12669                  6.89             NaN           NaN
# 40231                 10.18             NaN           NaN
# 42975                  7.21             2.0           NaN
# 76780                  8.27             5.0          21.6
# 91869                  7.17            27.4          31.4
# 99849                 12.13            14.1          41.1
# 92428                 10.68             0.3          27.0
# 74717                  8.35             2.8          36.7
# 22889                  8.78             6.4          17.4
# 101123                 7.11            13.5          47.4
# 519                    9.59             NaN           NaN
# 67842                  3.94             9.7          34.2
# 66831                  3.30             5.1          29.1
# 35453                  4.77            30.1          35.6
# 20252                  8.46            34.2          41.5
# 59320                  3.94             4.4          24.7
# 66327                  7.14             0.8          47.1
# 2121                   6.73             0.7          30.4
# 49095                  4.78            19.8          27.8
# 56557                 10.43             NaN           NaN
# 107379                 3.94             3.1          24.7
# 68514                  7.26             9.5          37.8
# 16892                  4.00             2.0          33.7
# 37747                  8.31            28.2          33.1
# 74187                 12.61             0.5          15.6
# 37185                  7.11             5.3          55.5
# 105126                 6.47             NaN           NaN
# 53504                  7.11             3.6          50.5
# 85106                  2.42             0.4          16.6
#
#         handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 45669                   64.204                        1.04            71.72
# 14216                      NaN                        2.20            75.88
# 80646                      NaN                        8.05            72.58
# 45145                   59.550                        0.53            69.66
# 63338                   87.847                        1.38            75.05
# 102799                     NaN                        2.77            78.86
# 46753                      NaN                        1.50            76.68
# 67330                   79.287                        0.90            67.13
# 89727                   43.993                        2.32            64.13
# 21336                   65.386                        1.71            77.29
# 8825                    34.808                        0.80            72.59
# 4426                       NaN                        5.00            76.67
# 59881                      NaN                        1.90            76.16
# 99334                   78.687                        2.30            76.70
# 102235                     NaN                        2.54            81.32
# 97169                   90.670                        2.10            77.15
# 107885                  36.791                        1.70            61.49
# 77365                      NaN                        1.60            76.74
# 24448                   85.198                        5.20            78.80
# 77921                   78.463                        1.00            71.23
# 47284                   94.576                        1.40            70.60
# 12669                   25.383                        1.10            71.51
# 40231                   76.665                        0.60            74.30
# 42975                   84.169                        0.70            75.27
# 76780                   79.602                        1.30            74.25
# 91869                      NaN                        2.97            83.56
# 99849                      NaN                        2.81            77.69
# 92428                      NaN                        3.60            76.98
# 74717                   59.607                        0.60            67.27
# 22889                   83.841                        1.13            80.28
# 101123                     NaN                        8.80            72.06
# 519                     37.746                        0.50            64.83
# 67842                   44.600                         NaN            63.71
# 66831                   12.227                        0.70            60.85
# 35453                      NaN                        5.98            82.66
# 20252                      NaN                        2.11            80.18
# 59320                    8.704                        1.30            64.26
# 66327                      NaN                        1.10            76.68
# 2121                    83.741                        1.90            76.88
# 49095                      NaN                        3.18            83.51
# 56557                      NaN                        3.70            72.91
# 107379                  13.938                        2.00            63.89
# 68514                   47.782                        0.30            70.78
# 16892                   66.229                        0.80            69.82
# 37747                      NaN                        8.00            81.33
# 74187                   97.400                        1.60            77.86
# 37185                      NaN                        2.60            73.77
# 105126                     NaN                        0.80            72.06
# 53504                   89.220                        4.50            71.45
# 85106                   20.859                         NaN            67.94
#
#         human_development_index  excess_mortality
# 45669                     0.718               NaN
# 14216                     0.765               NaN
# 80646                     0.824               NaN
# 45145                     0.645               NaN
# 63338                     0.779               NaN
# 102799                    0.926               NaN
# 46753                     0.783               NaN
# 67330                     0.583               NaN
# 89727                     0.709               NaN
# 21336                     0.767               NaN
# 8825                      0.632               NaN
# 4426                      0.845               NaN
# 59881                     0.810               NaN
# 99334                     0.740               NaN
# 102235                    0.932               NaN
# 97169                     0.777               NaN
# 107885                    0.571               NaN
# 77365                     0.777               NaN
# 24448                     0.783               NaN
# 77921                     0.718               NaN
# 47284                     0.674               NaN
# 12669                     0.718               NaN
# 40231                     0.663               NaN
# 42975                     0.634               NaN
# 76780                     0.728               NaN
# 91869                     0.904               NaN
# 99849                     0.820               NaN
# 92428                     0.782               NaN
# 74717                     0.557               NaN
# 22889                     0.810               NaN
# 101123                    0.779               NaN
# 519                       0.511               NaN
# 67842                     0.646               NaN
# 66831                     0.456               NaN
# 35453                     0.901               NaN
# 20252                     0.851               NaN
# 59320                     0.483               NaN
# 66327                     0.686               NaN
# 2121                      0.748               NaN
# 49095                     0.892               NaN
# 56557                     0.724               NaN
# 107379                    0.584               NaN
# 68514                     0.602               NaN
# 16892                     0.594               NaN
# 37747                     0.947               NaN
# 74187                     0.813               NaN
# 37185                     0.812               NaN
# 105126                    0.711               NaN
# 53504                     0.697               NaN
# 85106                     0.512               NaN
#
# [50 rows x 60 columns]

# %%
c_df.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'new_tests', 'total_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'new_vaccinations',
#        'new_vaccinations_smoothed', 'total_vaccinations_per_hundred',
#        'people_vaccinated_per_hundred', 'people_fully_vaccinated_per_hundred',
#        'new_vaccinations_smoothed_per_million', 'stringency_index',
#        'population', 'population_density', 'median_age', 'aged_65_older',
#        'aged_70_older', 'gdp_per_capita', 'extreme_poverty',
#        'cardiovasc_death_rate', 'diabetes_prevalence', 'female_smokers',
#        'male_smokers', 'handwashing_facilities', 'hospital_beds_per_thousand',
#        'life_expectancy', 'human_development_index', 'excess_mortality'],
#       dtype='object')
