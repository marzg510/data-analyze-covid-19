# %%
import pandas as pd

# %%
df = pd.read_csv("covid-19-data/public/data/owid-covid-data.csv")
df.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1      AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 0           NaN                  37.746                         0.5
# 1           NaN                  37.746                         0.5
# 2           NaN                  37.746                         0.5
# 3           NaN                  37.746                         0.5
# 4           NaN                  37.746                         0.5
#
#    life_expectancy  human_development_index  population  \
# 0            64.83                    0.511  41128772.0
# 1            64.83                    0.511  41128772.0
# 2            64.83                    0.511  41128772.0
# 3            64.83                    0.511  41128772.0
# 4            64.83                    0.511  41128772.0
#
#    excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                   NaN                          NaN
# 1                                   NaN                          NaN
# 2                                   NaN                          NaN
# 3                                   NaN                          NaN
# 4                                   NaN                          NaN
#
#    excess_mortality  excess_mortality_cumulative_per_million
# 0               NaN                                      NaN
# 1               NaN                                      NaN
# 2               NaN                                      NaN
# 3               NaN                                      NaN
# 4               NaN                                      NaN
#
# [5 rows x 67 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 235693 entries, 0 to 235692
# Data columns (total 67 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   iso_code                                    235693 non-null  object
#  1   continent                                   222396 non-null  object
#  2   location                                    235693 non-null  object
#  3   date                                        235693 non-null  object
#  4   total_cases                                 222465 non-null  float64
#  5   new_cases                                   222212 non-null  float64
#  6   new_cases_smoothed                          221013 non-null  float64
#  7   total_deaths                                203169 non-null  float64
#  8   new_deaths                                  203101 non-null  float64
#  9   new_deaths_smoothed                         201921 non-null  float64
#  10  total_cases_per_million                     221450 non-null  float64
#  11  new_cases_per_million                       221197 non-null  float64
#  12  new_cases_smoothed_per_million              220003 non-null  float64
#  13  total_deaths_per_million                    202167 non-null  float64
#  14  new_deaths_per_million                      202099 non-null  float64
#  15  new_deaths_smoothed_per_million             200924 non-null  float64
#  16  reproduction_rate                           171567 non-null  float64
#  17  icu_patients                                32042 non-null   float64
#  18  icu_patients_per_million                    32042 non-null   float64
#  19  hosp_patients                               35866 non-null   float64
#  20  hosp_patients_per_million                   35866 non-null   float64
#  21  weekly_icu_admissions                       8038 non-null    float64
#  22  weekly_icu_admissions_per_million           8038 non-null    float64
#  23  weekly_hosp_admissions                      19006 non-null   float64
#  24  weekly_hosp_admissions_per_million          19006 non-null   float64
#  25  total_tests                                 79387 non-null   float64
#  26  new_tests                                   75403 non-null   float64
#  27  total_tests_per_thousand                    79387 non-null   float64
#  28  new_tests_per_thousand                      75403 non-null   float64
#  29  new_tests_smoothed                          103965 non-null  float64
#  30  new_tests_smoothed_per_thousand             103965 non-null  float64
#  31  positive_rate                               95927 non-null   float64
#  32  tests_per_case                              94348 non-null   float64
#  33  tests_units                                 106788 non-null  object
#  34  total_vaccinations                          67258 non-null   float64
#  35  people_vaccinated                           64380 non-null   float64
#  36  people_fully_vaccinated                     61690 non-null   float64
#  37  total_boosters                              36732 non-null   float64
#  38  new_vaccinations                            55783 non-null   float64
#  39  new_vaccinations_smoothed                   138057 non-null  float64
#  40  total_vaccinations_per_hundred              67258 non-null   float64
#  41  people_vaccinated_per_hundred               64380 non-null   float64
#  42  people_fully_vaccinated_per_hundred         61690 non-null   float64
#  43  total_boosters_per_hundred                  36732 non-null   float64
#  44  new_vaccinations_smoothed_per_million       138057 non-null  float64
#  45  new_people_vaccinated_smoothed              137558 non-null  float64
#  46  new_people_vaccinated_smoothed_per_hundred  137558 non-null  float64
#  47  stringency_index                            174808 non-null  float64
#  48  population_density                          205835 non-null  float64
#  49  median_age                                  190411 non-null  float64
#  50  aged_65_older                               188402 non-null  float64
#  51  aged_70_older                               189415 non-null  float64
#  52  gdp_per_capita                              189896 non-null  float64
#  53  extreme_poverty                             123706 non-null  float64
#  54  cardiovasc_death_rate                       189884 non-null  float64
#  55  diabetes_prevalence                         199709 non-null  float64
#  56  female_smokers                              143849 non-null  float64
#  57  male_smokers                                141880 non-null  float64
#  58  handwashing_facilities                      93524 non-null   float64
#  59  hospital_beds_per_thousand                  169093 non-null  float64
#  60  life_expectancy                             216631 non-null  float64
#  61  human_development_index                     185345 non-null  float64
#  62  population                                  234678 non-null  float64
#  63  excess_mortality_cumulative_absolute        7766 non-null    float64
#  64  excess_mortality_cumulative                 7766 non-null    float64
#  65  excess_mortality                            7817 non-null    float64
#  66  excess_mortality_cumulative_per_million     7766 non-null    float64
# dtypes: float64(62), object(5)
# memory usage: 120.5+ MB

# %%
df.describe()
# Out:
#         total_cases     new_cases  new_cases_smoothed  total_deaths  \
# count  2.224650e+05  2.222120e+05        2.210130e+05  2.031690e+05
# mean   4.622690e+06  1.222833e+04        1.226604e+04  7.530209e+04
# std    2.880476e+07  8.441630e+04        8.247975e+04  3.864255e+05
# min    1.000000e+00  0.000000e+00        0.000000e+00  1.000000e+00
# 25%    4.697000e+03  0.000000e+00        5.714000e+00  1.150000e+02
# 50%    5.224700e+04  5.000000e+01        9.028600e+01  1.224000e+03
# 75%    5.457610e+05  9.290000e+02        1.101571e+03  1.004700e+04
# max    6.368819e+08  4.081968e+06        3.436036e+06  6.617493e+06
#
#           new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  203101.000000        201921.000000            221450.000000
# mean      135.352716           135.985095             62861.089680
# std       720.535485           706.155831            110405.537058
# min         0.000000             0.000000                 0.001000
# 25%         0.000000             0.000000              1134.165750
# 50%         1.000000             1.429000             10808.103500
# 75%        13.000000            15.143000             75054.506750
# max     17733.000000         14859.000000            676654.312000
#
#        new_cases_per_million  new_cases_smoothed_per_million  \
# count          221197.000000                   220003.000000
# mean              186.836709                      187.186097
# std              1154.301879                      684.907084
# min                 0.000000                        0.000000
# 25%                 0.000000                        1.238000
# 50%                 6.792000                       18.422000
# 75%                93.883000                      132.490500
# max            228872.025000                    36421.827000
#
#        total_deaths_per_million  ...   male_smokers  handwashing_facilities  \
# count             202167.000000  ...  141880.000000            93524.000000
# mean                 702.163104  ...      32.812371               50.908588
# std                  985.914737  ...      13.535799               31.877377
# min                    0.000000  ...       7.700000                1.188000
# 25%                   30.513000  ...      21.600000               20.859000
# 50%                  220.040000  ...      33.100000               49.839000
# 75%                 1041.496500  ...      41.300000               83.241000
# max                 6381.692000  ...      78.100000              100.000000
#
#        hospital_beds_per_thousand  life_expectancy  human_development_index  \
# count               169093.000000    216631.000000            185345.000000
# mean                     3.088512        73.615348                 0.724732
# std                      2.551818         7.446923                 0.149604
# min                      0.100000        53.280000                 0.394000
# 25%                      1.300000        69.500000                 0.602000
# 50%                      2.500000        75.050000                 0.742000
# 75%                      4.200000        79.070000                 0.845000
# max                     13.800000        86.750000                 0.957000
#
#          population  excess_mortality_cumulative_absolute  \
# count  2.346780e+05                          7.766000e+03
# mean   1.412703e+08                          4.796967e+04
# std    6.935931e+08                          1.325850e+05
# min    4.700000e+01                         -3.772610e+04
# 25%    8.960070e+05                          3.460000e+01
# 50%    6.948395e+06                          6.009500e+03
# 75%    3.369661e+07                          3.471957e+04
# max    7.975105e+09                          1.224011e+06
#
#        excess_mortality_cumulative  excess_mortality  \
# count                  7766.000000       7817.000000
# mean                      9.963914         14.325741
# std                      13.541548         26.390612
# min                     -28.450000        -95.920000
# 25%                       0.560000         -0.120000
# 50%                       7.385000          7.270000
# 75%                      15.607500         19.770000
# max                      76.550000        376.580000
#
#        excess_mortality_cumulative_per_million
# count                              7766.000000
# mean                               1352.302239
# std                                1735.666231
# min                               -1884.678982
# 25%                                  27.051515
# 50%                                 807.128549
# 75%                                2109.735183
# max                                9771.680201
#
# [8 rows x 62 columns]

# %%
df.continent.unique()
# Out:
# array(['Asia', nan, 'Europe', 'Africa', 'North America', 'South America',
#        'Oceania'], dtype=object)

# %%
df.loc[df.continent.isna()].location.unique()
# Out:
# array(['Africa', 'Asia', 'Europe', 'European Union', 'High income',
#        'International', 'Low income', 'Lower middle income',
#        'North America', 'Oceania', 'South America', 'Upper middle income',
#        'World'], dtype=object)

# %%
df.loc[df.location=="International"]
# Out:
#        iso_code continent       location        date  total_cases  new_cases  \
# 98033  OWID_INT       NaN  International  2020-02-07         61.0       61.0
# 98034  OWID_INT       NaN  International  2020-02-08         61.0        0.0
# 98035  OWID_INT       NaN  International  2020-02-09         64.0        3.0
# 98036  OWID_INT       NaN  International  2020-02-10        135.0       71.0
# 98037  OWID_INT       NaN  International  2020-02-11        135.0        0.0
# ...         ...       ...            ...         ...          ...        ...
# 99043  OWID_INT       NaN  International  2022-11-13        721.0        0.0
# 99044  OWID_INT       NaN  International  2022-11-14        721.0        0.0
# 99045  OWID_INT       NaN  International  2022-11-15        721.0        0.0
# 99046  OWID_INT       NaN  International  2022-11-16        721.0        0.0
# 99047  OWID_INT       NaN  International  2022-11-17        721.0        0.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 98033                 NaN           NaN         NaN                  NaN  ...
# 98034                 NaN           NaN         NaN                  NaN  ...
# 98035                 NaN           NaN         NaN                  NaN  ...
# 98036                 NaN           NaN         NaN                  NaN  ...
# 98037                 NaN           NaN         NaN                  NaN  ...
# ...                   ...           ...         ...                  ...  ...
# 99043                 0.0          15.0         0.0                  0.0  ...
# 99044                 0.0          15.0         0.0                  0.0  ...
# 99045                 0.0          15.0         0.0                  0.0  ...
# 99046                 0.0          15.0         0.0                  0.0  ...
# 99047                 0.0          15.0         0.0                  0.0  ...
#
#        male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 98033           NaN                     NaN                         NaN
# 98034           NaN                     NaN                         NaN
# 98035           NaN                     NaN                         NaN
# 98036           NaN                     NaN                         NaN
# 98037           NaN                     NaN                         NaN
# ...             ...                     ...                         ...
# 99043           NaN                     NaN                         NaN
# 99044           NaN                     NaN                         NaN
# 99045           NaN                     NaN                         NaN
# 99046           NaN                     NaN                         NaN
# 99047           NaN                     NaN                         NaN
#
#        life_expectancy  human_development_index  population  \
# 98033              NaN                      NaN         NaN
# 98034              NaN                      NaN         NaN
# 98035              NaN                      NaN         NaN
# 98036              NaN                      NaN         NaN
# 98037              NaN                      NaN         NaN
# ...                ...                      ...         ...
# 99043              NaN                      NaN         NaN
# 99044              NaN                      NaN         NaN
# 99045              NaN                      NaN         NaN
# 99046              NaN                      NaN         NaN
# 99047              NaN                      NaN         NaN
#
#        excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 98033                                   NaN                          NaN
# 98034                                   NaN                          NaN
# 98035                                   NaN                          NaN
# 98036                                   NaN                          NaN
# 98037                                   NaN                          NaN
# ...                                     ...                          ...
# 99043                                   NaN                          NaN
# 99044                                   NaN                          NaN
# 99045                                   NaN                          NaN
# 99046                                   NaN                          NaN
# 99047                                   NaN                          NaN
#
#        excess_mortality  excess_mortality_cumulative_per_million
# 98033               NaN                                      NaN
# 98034               NaN                                      NaN
# 98035               NaN                                      NaN
# 98036               NaN                                      NaN
# 98037               NaN                                      NaN
# ...                 ...                                      ...
# 99043               NaN                                      NaN
# 99044               NaN                                      NaN
# 99045               NaN                                      NaN
# 99046               NaN                                      NaN
# 99047               NaN                                      NaN
#
# [1015 rows x 67 columns]

# %%
df.location.unique()
# Out:
# array(['Afghanistan', 'Africa', 'Albania', 'Algeria', 'Andorra', 'Angola',
#        'Anguilla', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        'Asia', 'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain',
#        'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin',
#        'Bermuda', 'Bhutan', 'Bolivia', 'Bonaire Sint Eustatius and Saba',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Brunei', 'Bulgaria', 'Burkina Faso',
#        'Burundi', 'Cambodia', 'Cameroon', 'Canada', 'Cape Verde',
#        'Cayman Islands', 'Central African Republic', 'Chad', 'Chile',
#        'China', 'Colombia', 'Comoros', 'Congo', 'Cook Islands',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Curacao',
#        'Cyprus', 'Czechia', 'Democratic Republic of Congo', 'Denmark',
#        'Djibouti', 'Dominica', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'England', 'Equatorial Guinea', 'Eritrea',
#        'Estonia', 'Eswatini', 'Ethiopia', 'Europe', 'European Union',
#        'Faeroe Islands', 'Falkland Islands', 'Fiji', 'Finland', 'France',
#        'French Polynesia', 'Gabon', 'Gambia', 'Georgia', 'Germany',
#        'Ghana', 'Gibraltar', 'Greece', 'Greenland', 'Grenada', 'Guam',
#        'Guatemala', 'Guernsey', 'Guinea', 'Guinea-Bissau', 'Guyana',
#        'Haiti', 'High income', 'Honduras', 'Hong Kong', 'Hungary',
#        'Iceland', 'India', 'Indonesia', 'International', 'Iran', 'Iraq',
#        'Ireland', 'Isle of Man', 'Israel', 'Italy', 'Jamaica', 'Japan',
#        'Jersey', 'Jordan', 'Kazakhstan', 'Kenya', 'Kiribati', 'Kosovo',
#        'Kuwait', 'Kyrgyzstan', 'Laos', 'Latvia', 'Lebanon', 'Lesotho',
#        'Liberia', 'Libya', 'Liechtenstein', 'Lithuania', 'Low income',
#        'Lower middle income', 'Luxembourg', 'Macao', 'Madagascar',
#        'Malawi', 'Malaysia', 'Maldives', 'Mali', 'Malta',
#        'Marshall Islands', 'Mauritania', 'Mauritius', 'Mexico',
#        'Micronesia (country)', 'Moldova', 'Monaco', 'Mongolia',
#        'Montenegro', 'Montserrat', 'Morocco', 'Mozambique', 'Myanmar',
#        'Namibia', 'Nauru', 'Nepal', 'Netherlands', 'New Caledonia',
#        'New Zealand', 'Nicaragua', 'Niger', 'Nigeria', 'Niue',
#        'North America', 'North Korea', 'North Macedonia',
#        'Northern Cyprus', 'Northern Ireland', 'Northern Mariana Islands',
#        'Norway', 'Oceania', 'Oman', 'Pakistan', 'Palau', 'Palestine',
#        'Panama', 'Papua New Guinea', 'Paraguay', 'Peru', 'Philippines',
#        'Pitcairn', 'Poland', 'Portugal', 'Puerto Rico', 'Qatar',
#        'Romania', 'Russia', 'Rwanda', 'Saint Helena',
#        'Saint Kitts and Nevis', 'Saint Lucia',
#        'Saint Pierre and Miquelon', 'Saint Vincent and the Grenadines',
#        'Samoa', 'San Marino', 'Sao Tome and Principe', 'Saudi Arabia',
#        'Scotland', 'Senegal', 'Serbia', 'Seychelles', 'Sierra Leone',
#        'Singapore', 'Sint Maarten (Dutch part)', 'Slovakia', 'Slovenia',
#        'Solomon Islands', 'Somalia', 'South Africa', 'South America',
#        'South Korea', 'South Sudan', 'Spain', 'Sri Lanka', 'Sudan',
#        'Suriname', 'Sweden', 'Switzerland', 'Syria', 'Taiwan',
#        'Tajikistan', 'Tanzania', 'Thailand', 'Timor', 'Togo', 'Tokelau',
#        'Tonga', 'Trinidad and Tobago', 'Tunisia', 'Turkey',
#        'Turkmenistan', 'Turks and Caicos Islands', 'Tuvalu', 'Uganda',
#        'Ukraine', 'United Arab Emirates', 'United Kingdom',
#        'United States', 'United States Virgin Islands',
#        'Upper middle income', 'Uruguay', 'Uzbekistan', 'Vanuatu',
#        'Vatican', 'Venezuela', 'Vietnam', 'Wales', 'Wallis and Futuna',
#        'Western Sahara', 'World', 'Yemen', 'Zambia', 'Zimbabwe'],
#       dtype=object)

# %%
df["date"] = pd.to_datetime(df["date"])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 235693 entries, 0 to 235692
# Data columns (total 67 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   iso_code                                    235693 non-null  object
#  1   continent                                   222396 non-null  object
#  2   location                                    235693 non-null  object
#  3   date                                        235693 non-null  datetime64[ns]
#  4   total_cases                                 222465 non-null  float64
#  5   new_cases                                   222212 non-null  float64
#  6   new_cases_smoothed                          221013 non-null  float64
#  7   total_deaths                                203169 non-null  float64
#  8   new_deaths                                  203101 non-null  float64
#  9   new_deaths_smoothed                         201921 non-null  float64
#  10  total_cases_per_million                     221450 non-null  float64
#  11  new_cases_per_million                       221197 non-null  float64
#  12  new_cases_smoothed_per_million              220003 non-null  float64
#  13  total_deaths_per_million                    202167 non-null  float64
#  14  new_deaths_per_million                      202099 non-null  float64
#  15  new_deaths_smoothed_per_million             200924 non-null  float64
#  16  reproduction_rate                           171567 non-null  float64
#  17  icu_patients                                32042 non-null   float64
#  18  icu_patients_per_million                    32042 non-null   float64
#  19  hosp_patients                               35866 non-null   float64
#  20  hosp_patients_per_million                   35866 non-null   float64
#  21  weekly_icu_admissions                       8038 non-null    float64
#  22  weekly_icu_admissions_per_million           8038 non-null    float64
#  23  weekly_hosp_admissions                      19006 non-null   float64
#  24  weekly_hosp_admissions_per_million          19006 non-null   float64
#  25  total_tests                                 79387 non-null   float64
#  26  new_tests                                   75403 non-null   float64
#  27  total_tests_per_thousand                    79387 non-null   float64
#  28  new_tests_per_thousand                      75403 non-null   float64
#  29  new_tests_smoothed                          103965 non-null  float64
#  30  new_tests_smoothed_per_thousand             103965 non-null  float64
#  31  positive_rate                               95927 non-null   float64
#  32  tests_per_case                              94348 non-null   float64
#  33  tests_units                                 106788 non-null  object
#  34  total_vaccinations                          67258 non-null   float64
#  35  people_vaccinated                           64380 non-null   float64
#  36  people_fully_vaccinated                     61690 non-null   float64
#  37  total_boosters                              36732 non-null   float64
#  38  new_vaccinations                            55783 non-null   float64
#  39  new_vaccinations_smoothed                   138057 non-null  float64
#  40  total_vaccinations_per_hundred              67258 non-null   float64
#  41  people_vaccinated_per_hundred               64380 non-null   float64
#  42  people_fully_vaccinated_per_hundred         61690 non-null   float64
#  43  total_boosters_per_hundred                  36732 non-null   float64
#  44  new_vaccinations_smoothed_per_million       138057 non-null  float64
#  45  new_people_vaccinated_smoothed              137558 non-null  float64
#  46  new_people_vaccinated_smoothed_per_hundred  137558 non-null  float64
#  47  stringency_index                            174808 non-null  float64
#  48  population_density                          205835 non-null  float64
#  49  median_age                                  190411 non-null  float64
#  50  aged_65_older                               188402 non-null  float64
#  51  aged_70_older                               189415 non-null  float64
#  52  gdp_per_capita                              189896 non-null  float64
#  53  extreme_poverty                             123706 non-null  float64
#  54  cardiovasc_death_rate                       189884 non-null  float64
#  55  diabetes_prevalence                         199709 non-null  float64
#  56  female_smokers                              143849 non-null  float64
#  57  male_smokers                                141880 non-null  float64
#  58  handwashing_facilities                      93524 non-null   float64
#  59  hospital_beds_per_thousand                  169093 non-null  float64
#  60  life_expectancy                             216631 non-null  float64
#  61  human_development_index                     185345 non-null  float64
#  62  population                                  234678 non-null  float64
#  63  excess_mortality_cumulative_absolute        7766 non-null    float64
#  64  excess_mortality_cumulative                 7766 non-null    float64
#  65  excess_mortality                            7817 non-null    float64
#  66  excess_mortality_cumulative_per_million     7766 non-null    float64
# dtypes: datetime64[ns](1), float64(62), object(4)
# memory usage: 120.5+ MB

# %% [markdown]
# ## 最新日付チェック

# %%
import datetime
#latest_date_str = (df.date.max()-datetime.timedelta(days=1)).strftime("%Y-%m-%d")
latest_date_str = df.date.max().strftime("%Y-%m-%d")
latest_date_str
# Out:
# '2022-11-17'

# %% [markdown]
# ## 全世界のデータのみ

# %%
world_df = df.copy().loc[df.location=="World"]
world_df.tail()
# Out:
#         iso_code continent location       date  total_cases  new_cases  \
# 232788  OWID_WRL       NaN    World 2022-11-13  635077633.0   182856.0
# 232789  OWID_WRL       NaN    World 2022-11-14  635440951.0   364619.0
# 232790  OWID_WRL       NaN    World 2022-11-15  635933936.0   492985.0
# 232791  OWID_WRL       NaN    World 2022-11-16  636412927.0   478991.0
# 232792  OWID_WRL       NaN    World 2022-11-17  636881914.0   469555.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 232788          364384.286     6610421.0       437.0             1266.571
# 232789          369645.000     6611702.0      1281.0             1288.571
# 232790          377682.143     6612692.0      1415.0             1321.714
# 232791          385511.286     6614908.0      2216.0             1345.429
# 232792          387594.571     6617493.0      2587.0             1428.571
#
#         ...  male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 232788  ...        34.635                   60.13                       2.705
# 232789  ...        34.635                   60.13                       2.705
# 232790  ...        34.635                   60.13                       2.705
# 232791  ...        34.635                   60.13                       2.705
# 232792  ...        34.635                   60.13                       2.705
#
#         life_expectancy  human_development_index    population  \
# 232788            72.58                    0.737  7.975105e+09
# 232789            72.58                    0.737  7.975105e+09
# 232790            72.58                    0.737  7.975105e+09
# 232791            72.58                    0.737  7.975105e+09
# 232792            72.58                    0.737  7.975105e+09
#
#         excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 232788                                   NaN                          NaN
# 232789                                   NaN                          NaN
# 232790                                   NaN                          NaN
# 232791                                   NaN                          NaN
# 232792                                   NaN                          NaN
#
#         excess_mortality  excess_mortality_cumulative_per_million
# 232788               NaN                                      NaN
# 232789               NaN                                      NaN
# 232790               NaN                                      NaN
# 232791               NaN                                      NaN
# 232792               NaN                                      NaN
#
# [5 rows x 67 columns]

# %% [markdown]
# ### 主要国の定義

# %%
countries = pd.DataFrame([
    ("Japan",""),
    ("United States",""),
    ("Germany",""),
#    ("India",""),
#    ("Indonesia",""),
#    ("Spain",""),
    ("Brazil",""),
    ("France",""),
    ("United Kingdom",""),
    ("Russia",""),
    ("Turkey",""),
#    ("South Africa",""),
#    ("Iran",""),
    ("Poland",""),
#    ("Ecuador",""),
],columns=["country","text_disp_date"])
countries
# Out:
#           country text_disp_date
# 0           Japan
# 1   United States
# 2         Germany
# 3          Brazil
# 4          France
# 5  United Kingdom
# 6          Russia
# 7          Turkey
# 8          Poland

# %%
# 東Asia 主要国
e_asia_c = pd.DataFrame([
    ("Japan",""),
    ("China",""),
    ("Taiwan",""),
    ("South Korea",""),
    ("Indonesia",""),
    ("Philippines",""),
    ("Vietnam",""),
    ("Myanmar",""),
    ("Thailand",""),
],columns=["country","text_disp_date"])
e_asia_c
# Out:
#        country text_disp_date
# 0        Japan
# 1        China
# 2       Taiwan
# 3  South Korea
# 4    Indonesia
# 5  Philippines
# 6      Vietnam
# 7      Myanmar
# 8     Thailand

# %%
c_trans = pd.merge(countries, df, left_on="country", right_on="location",how="inner")
c_trans.head()
# Out:
#   country text_disp_date iso_code continent location       date  total_cases  \
# 0   Japan                     JPN      Asia    Japan 2020-01-22          2.0
# 1   Japan                     JPN      Asia    Japan 2020-01-23          2.0
# 2   Japan                     JPN      Asia    Japan 2020-01-24          2.0
# 3   Japan                     JPN      Asia    Japan 2020-01-25          2.0
# 4   Japan                     JPN      Asia    Japan 2020-01-26          4.0
#
#    new_cases  new_cases_smoothed  total_deaths  ...  male_smokers  \
# 0        NaN                 NaN           NaN  ...          33.7
# 1        0.0                 NaN           NaN  ...          33.7
# 2        0.0                 NaN           NaN  ...          33.7
# 3        0.0                 NaN           NaN  ...          33.7
# 4        2.0                 NaN           NaN  ...          33.7
#
#    handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 0                     NaN                       13.05            84.63
# 1                     NaN                       13.05            84.63
# 2                     NaN                       13.05            84.63
# 3                     NaN                       13.05            84.63
# 4                     NaN                       13.05            84.63
#
#    human_development_index   population  excess_mortality_cumulative_absolute  \
# 0                    0.919  123951696.0                                   NaN
# 1                    0.919  123951696.0                                   NaN
# 2                    0.919  123951696.0                                   NaN
# 3                    0.919  123951696.0                                   NaN
# 4                    0.919  123951696.0                                   NaN
#
#    excess_mortality_cumulative  excess_mortality  \
# 0                          NaN               NaN
# 1                          NaN               NaN
# 2                          NaN               NaN
# 3                          NaN               NaN
# 4                          NaN               NaN
#
#    excess_mortality_cumulative_per_million
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
# [5 rows x 69 columns]

# %%
c_trans.location.unique()
# Out:
# array(['Japan', 'United States', 'Germany', 'Brazil', 'France',
#        'United Kingdom', 'Russia', 'Turkey', 'Poland'], dtype=object)

# %%
c_trans.loc[c_trans.date==latest_date_str][["country","date","total_deaths","total_deaths_per_million"]].sort_values("total_deaths_per_million",ascending=False)
# Out:
#              country       date  total_deaths  total_deaths_per_million
# 4083          Brazil 2022-11-17      688835.0                  3199.219
# 2061   United States 2022-11-17     1076492.0                  3182.159
# 6135  United Kingdom 2022-11-17      211346.0                  3130.637
# 9128          Poland 2022-11-17      118252.0                  2966.896
# 7157          Russia 2022-11-17      383381.0                  2649.245
# 5112          France 2022-11-17      158158.0                  2332.267
# 3087         Germany 2022-11-17      156410.0                  1876.098
# 8139          Turkey 2022-11-17      101203.0                  1185.863
# 1030           Japan 2022-11-17       47974.0                   387.038

# %%
e_a_trans = pd.merge(e_asia_c, df, left_on="country", right_on="location",how="inner")
e_a_trans
# Out:
#        country text_disp_date iso_code continent  location       date  \
# 0        Japan                     JPN      Asia     Japan 2020-01-22
# 1        Japan                     JPN      Asia     Japan 2020-01-23
# 2        Japan                     JPN      Asia     Japan 2020-01-24
# 3        Japan                     JPN      Asia     Japan 2020-01-25
# 4        Japan                     JPN      Asia     Japan 2020-01-26
# ...        ...            ...      ...       ...       ...        ...
# 9184  Thailand                     THA      Asia  Thailand 2022-11-13
# 9185  Thailand                     THA      Asia  Thailand 2022-11-14
# 9186  Thailand                     THA      Asia  Thailand 2022-11-15
# 9187  Thailand                     THA      Asia  Thailand 2022-11-16
# 9188  Thailand                     THA      Asia  Thailand 2022-11-17
#
#       total_cases  new_cases  new_cases_smoothed  total_deaths  ...  \
# 0             2.0        NaN                 NaN           NaN  ...
# 1             2.0        0.0                 NaN           NaN  ...
# 2             2.0        0.0                 NaN           NaN  ...
# 3             2.0        0.0                 NaN           NaN  ...
# 4             4.0        2.0                 NaN           NaN  ...
# ...           ...        ...                 ...           ...  ...
# 9184    4698373.0     3166.0             452.286       33037.0  ...
# 9185    4698373.0        NaN                 NaN       33037.0  ...
# 9186    4698373.0        NaN                 NaN       33037.0  ...
# 9187    4698373.0        NaN                 NaN       33037.0  ...
# 9188    4698373.0        NaN                 NaN       33037.0  ...
#
#       male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 0             33.7                     NaN                       13.05
# 1             33.7                     NaN                       13.05
# 2             33.7                     NaN                       13.05
# 3             33.7                     NaN                       13.05
# 4             33.7                     NaN                       13.05
# ...            ...                     ...                         ...
# 9184          38.8                   90.67                        2.10
# 9185          38.8                   90.67                        2.10
# 9186          38.8                   90.67                        2.10
# 9187          38.8                   90.67                        2.10
# 9188          38.8                   90.67                        2.10
#
#       life_expectancy  human_development_index   population  \
# 0               84.63                    0.919  123951696.0
# 1               84.63                    0.919  123951696.0
# 2               84.63                    0.919  123951696.0
# 3               84.63                    0.919  123951696.0
# 4               84.63                    0.919  123951696.0
# ...               ...                      ...          ...
# 9184            77.15                    0.777   71697024.0
# 9185            77.15                    0.777   71697024.0
# 9186            77.15                    0.777   71697024.0
# 9187            77.15                    0.777   71697024.0
# 9188            77.15                    0.777   71697024.0
#
#       excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                      NaN                          NaN
# 1                                      NaN                          NaN
# 2                                      NaN                          NaN
# 3                                      NaN                          NaN
# 4                                      NaN                          NaN
# ...                                    ...                          ...
# 9184                                   NaN                          NaN
# 9185                                   NaN                          NaN
# 9186                                   NaN                          NaN
# 9187                                   NaN                          NaN
# 9188                                   NaN                          NaN
#
#       excess_mortality  excess_mortality_cumulative_per_million
# 0                  NaN                                      NaN
# 1                  NaN                                      NaN
# 2                  NaN                                      NaN
# 3                  NaN                                      NaN
# 4                  NaN                                      NaN
# ...                ...                                      ...
# 9184               NaN                                      NaN
# 9185               NaN                                      NaN
# 9186               NaN                                      NaN
# 9187               NaN                                      NaN
# 9188               NaN                                      NaN
#
# [9189 rows x 69 columns]

# %%
e_a_trans.location.unique()
# Out:
# array(['Japan', 'China', 'Taiwan', 'South Korea', 'Indonesia',
#        'Philippines', 'Vietnam', 'Myanmar', 'Thailand'], dtype=object)

# %% [markdown]
# ## 今日の新規感染者数

# %%
#c_df_latest = df.loc[(df.date==pd.to_datetime(latest_date_str)-datetime.timedelta(days=1)) & (df.iso_code.str.len()==3)]
c_df_latest = df.loc[(df.date==pd.to_datetime(latest_date_str)) & (df.iso_code.str.len()==3)]

c_df_latest
# Out:
#        iso_code continent           location       date  total_cases  \
# 997         AFG      Asia        Afghanistan 2022-11-17     204982.0
# 3003        ALB    Europe            Albania 2022-11-17     333233.0
# 4000        DZA    Africa            Algeria 2022-11-17     270996.0
# 4991        AND    Europe            Andorra 2022-11-17      46824.0
# 5964        AGO    Africa             Angola 2022-11-17     103131.0
# ...         ...       ...                ...        ...          ...
# 230032      VNM      Asia            Vietnam 2022-11-17   11510484.0
# 231760      WLF   Oceania  Wallis and Futuna 2022-11-17       3415.0
# 233744      YEM      Asia              Yemen 2022-11-17      11945.0
# 234719      ZMB    Africa             Zambia 2022-11-17     333685.0
# 235692      ZWE    Africa           Zimbabwe 2022-11-17     257893.0
#
#         new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 997         162.0              99.286        7830.0         0.0
# 3003         18.0              18.571        3594.0         0.0
# 4000         15.0              11.286        6881.0         0.0
# 4991          NaN                 NaN         156.0         0.0
# 5964          0.0               0.000        1917.0         0.0
# ...           ...                 ...           ...         ...
# 230032      509.0             420.571       43167.0         0.0
# 231760        0.0               0.000           7.0         0.0
# 233744        0.0               0.000        2159.0         0.0
# 234719        0.0               0.000        4017.0         0.0
# 235692        0.0               0.000        5606.0         0.0
#
#         new_deaths_smoothed  ...  male_smokers  handwashing_facilities  \
# 997                   0.143  ...           NaN                  37.746
# 3003                  0.143  ...          51.2                     NaN
# 4000                  0.000  ...          30.4                  83.741
# 4991                  0.143  ...          37.8                     NaN
# 5964                  0.000  ...           NaN                  26.664
# ...                     ...  ...           ...                     ...
# 230032                0.143  ...          45.9                  85.847
# 231760                0.000  ...           NaN                     NaN
# 233744                0.000  ...          29.2                  49.542
# 234719                0.000  ...          24.7                  13.938
# 235692                0.000  ...          30.7                  36.791
#
#         hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 997                           0.50            64.83                    0.511
# 3003                          2.89            78.57                    0.795
# 4000                          1.90            76.88                    0.748
# 4991                           NaN            83.73                    0.868
# 5964                           NaN            61.15                    0.581
# ...                            ...              ...                      ...
# 230032                        2.60            75.40                    0.704
# 231760                         NaN            79.94                      NaN
# 233744                        0.70            66.12                    0.470
# 234719                        2.00            63.89                    0.584
# 235692                        1.70            61.49                    0.571
#
#         population  excess_mortality_cumulative_absolute  \
# 997     41128772.0                                   NaN
# 3003     2842318.0                                   NaN
# 4000    44903228.0                                   NaN
# 4991       79843.0                                   NaN
# 5964    35588996.0                                   NaN
# ...            ...                                   ...
# 230032  98186856.0                                   NaN
# 231760     11596.0                                   NaN
# 233744  33696612.0                                   NaN
# 234719  20017670.0                                   NaN
# 235692  16320539.0                                   NaN
#
#         excess_mortality_cumulative  excess_mortality  \
# 997                             NaN               NaN
# 3003                            NaN               NaN
# 4000                            NaN               NaN
# 4991                            NaN               NaN
# 5964                            NaN               NaN
# ...                             ...               ...
# 230032                          NaN               NaN
# 231760                          NaN               NaN
# 233744                          NaN               NaN
# 234719                          NaN               NaN
# 235692                          NaN               NaN
#
#         excess_mortality_cumulative_per_million
# 997                                         NaN
# 3003                                        NaN
# 4000                                        NaN
# 4991                                        NaN
# 5964                                        NaN
# ...                                         ...
# 230032                                      NaN
# 231760                                      NaN
# 233744                                      NaN
# 234719                                      NaN
# 235692                                      NaN
#
# [217 rows x 67 columns]

# %%
c_df_latest.sum()
# Out:
# /tmp/ipykernel_28957/3714355302.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   c_df_latest.sum()
# iso_code                                   AFGALBDZAANDAGOAIAATGARGARMABWAUSAUTAZEBHSBHRB...
# continent                                  AsiaEuropeAfricaEuropeAfricaNorth AmericaNorth...
# location                                   AfghanistanAlbaniaAlgeriaAndorraAngolaAnguilla...
# total_cases                                                                      636608998.0
# new_cases                                                                           469555.0
#                                                                  ...
# population                                                                      7962743041.0
# excess_mortality_cumulative_absolute                                                     0.0
# excess_mortality_cumulative                                                              0.0
# excess_mortality                                                                         0.0
# excess_mortality_cumulative_per_million                                                  0.0
# Length: 66, dtype: object

# %% [markdown]
# ## 可視化

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook
#%matplotlib inline

# %%
min_date = pd.to_datetime(datetime.datetime.now()).round("D")- datetime.timedelta(days=90)

# %%
world_df["case_rolling7ave"] = world_df.new_cases.rolling(7).mean()
world_df[["new_cases_smoothed","case_rolling7ave"]]
# Out:
#         new_cases_smoothed  case_rolling7ave
# 231762                 NaN               NaN
# 231763                 NaN               NaN
# 231764                 NaN               NaN
# 231765                 NaN               NaN
# 231766                 NaN               NaN
# ...                    ...               ...
# 232788          364384.286     364384.285714
# 232789          369645.000     369645.000000
# 232790          377682.143     377682.142857
# 232791          385511.286     385511.285714
# 232792          387594.571     387594.571429
#
# [1031 rows x 2 columns]

# %%
fig=plt.figure(figsize=(20,12))
plt.subplot(2,2,1) # (rows, columns, panel number)
plt.title("Daily new confirmed COVID-19 cases in the world")
plt.bar(world_df.date,world_df.new_cases,label="New cases")
plt.plot_date(world_df["date"],world_df["new_cases_smoothed"],label="7daysMA", fmt="-", color="orange")
#plt.xticks(rotation=70)
plt.ylabel("people")
plt.grid(axis="y")
plt.legend()

plt.subplot(2,2,2) # (rows, columns, panel number)
plt.title("Daily new confirmed COVID-19 cases in the world(Recent)")
chart_data = world_df[world_df.date >= min_date]
plt.bar(chart_data["date"],chart_data["new_cases"],label="New cases")
plt.plot_date(chart_data["date"],chart_data["new_cases_smoothed"],label="7days MA", fmt="-", color="orange")
#plt.xticks(rotation=70)
plt.grid(axis="y")
plt.legend()

plt.subplot(2,2,3) # (rows, columns, panel number)
plt.title("Daily new deaths in the world")
plt.bar(world_df.date,world_df.new_deaths,label="New deaths")
plt.plot_date(world_df["date"],world_df["new_deaths_smoothed"],label="7days MA", fmt="-", color="orange")
#plt.xticks(rotation=70)
plt.ylabel("people")
plt.grid(axis="y")
plt.legend()

plt.subplot(2,2,4) # (rows, columns, panel number)
plt.title("Daily new deaths in the world(Recent)")
chart_data = world_df[world_df.date >= min_date]
plt.bar(chart_data["date"],chart_data["new_deaths"],label="New deaths")
plt.plot_date(chart_data["date"],chart_data["new_deaths_smoothed"],label="7days MA", fmt="-", color="orange")
#plt.xticks(rotation=70)
plt.grid(axis="y")
plt.legend()

fig.text(0,1,"Latest: {}".format(latest_date_str),ha="left",va="top")
fig.text(0,0
         ,"*Data Source : COVID-19 Dataset by Our World in Data",
        ha="left",va="bottom")

plt.tight_layout()
# Out:
# <div id='ed7d137d-5ad8-4738-a139-6f134c1d689a'></div>

# %%
fig.savefig("out/covid-owid-global-daily.png")

# %% [markdown]
# ### 国別

# %% [markdown]
# #### 人口100万人当たりの新規感染者数（直近）

# %%
"""
#min_date = pd.to_datetime("2021-05-01")
# 主要国 新規感染者
chart_data = c_trans[c_trans.date >= min_date]
dates = chart_data["date"].unique()
print(len(dates))
print(dates.max())
for i,cr in countries.iterrows():
    c = cr["country"]
    dates = chart_data.loc[chart_data["location"]==c]["date"]
    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else latest_date_str
    print(len(chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"]))
    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"],label=c, fmt="-")
    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_cases_smoothed_per_million"],c
            ,fontsize=8,va="center")
"""
# Out:
# '\n#min_date = pd.to_datetime("2021-05-01")\n# 主要国 新規感染者\nchart_data = c_trans[c_trans.date >= min_date]\ndates = chart_data["date"].unique()\nprint(len(dates))\nprint(dates.max())\nfor i,cr in countries.iterrows():\n    c = cr["country"]\n    dates = chart_data.loc[chart_data["location"]==c]["date"]\n    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else latest_date_str\n    print(len(chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"]))\n    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"],label=c, fmt="-")\n    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_cases_smoothed_per_million"],c\n            ,fontsize=8,va="center")\n'

# %%
"""
fig=plt.figure(figsize=(14,10))
min_date = pd.to_datetime("2021-03-01")
# 主要国 新規感染者
plt.subplot(2,2,1) # (rows, columns, panel number)
plt.title("Daily new confirmed COVID-19 cases\n per million population in major countries\n(rolling 7day ave.)")
plt.grid()
plt.xticks(rotation=70)
chart_data = c_trans[c_trans.date >= min_date]
dates = chart_data["date"].unique()
for i,cr in countries.iterrows():
    c = cr["country"]
    dates = chart_data.loc[chart_data["location"]==c]["date"]
    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else dates.max()
    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"],label=c, fmt="-")
    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_cases_smoothed_per_million"],c
            ,fontsize=8,va="center")
plt.legend(bbox_to_anchor=(0, 1),loc='upper left', fontsize=9)
"""
# Out:
# '\nfig=plt.figure(figsize=(14,10))\nmin_date = pd.to_datetime("2021-03-01")\n# 主要国 新規感染者\nplt.subplot(2,2,1) # (rows, columns, panel number)\nplt.title("Daily new confirmed COVID-19 cases\n per million population in major countries\n(rolling 7day ave.)")\nplt.grid()\nplt.xticks(rotation=70)\nchart_data = c_trans[c_trans.date >= min_date]\ndates = chart_data["date"].unique()\nfor i,cr in countries.iterrows():\n    c = cr["country"]\n    dates = chart_data.loc[chart_data["location"]==c]["date"]\n    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else dates.max()\n    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"],label=c, fmt="-")\n    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_cases_smoothed_per_million"],c\n            ,fontsize=8,va="center")\nplt.legend(bbox_to_anchor=(0, 1),loc=\'upper left\', fontsize=9)\n'

# %%
fig=plt.figure(figsize=(20,14))
# 主要国 新規感染者
plt.subplot(2,2,1) # (rows, columns, panel number)
plt.title("Daily new confirmed COVID-19 cases\n per million population in major countries(7daysMA)")
plt.grid()
plt.xticks(rotation=45)
chart_data = c_trans[c_trans.date >= min_date]
for i,cr in countries.iterrows():
    c = cr["country"]
    dates = chart_data.loc[chart_data["location"]==c]["date"]
    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else dates.max()
    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"],label=c, fmt="-")
    text_y = chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_cases_smoothed_per_million"]
#    print(text_y)
    print(c,text_disp_date,text_y)
#    plt.text(text_disp_date,text_y,c,fontsize=10,va="center")
    plt.text(text_disp_date,text_y,c,va="center")
plt.legend(bbox_to_anchor=(0, 1),loc='upper left')

# 主要国 死者
plt.subplot(2,2,2) # (rows, columns, panel number)
plt.title("Daily new deaths in major countries(7daysMA)")
plt.grid()
plt.xticks(rotation=45)
chart_data = c_trans[c_trans.date >= min_date]
for i,cr in countries.iterrows():
    c = cr["country"]
    dates = chart_data.loc[chart_data["location"]==c]["date"]
    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else dates.max()
    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_deaths_smoothed"],label=c, fmt="-")
    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_deaths_smoothed"],c
            ,va="center")
plt.legend(bbox_to_anchor=(0, 1),loc='upper left')

plt.subplot(2,2,3) # (rows, columns, panel number)
plt.grid()
plt.xticks(rotation=45)
plt.title("Daily new confirmed COVID-19 cases\n per million population in Eastern Asia(7daysMA)")
chart_data = e_a_trans[e_a_trans.date >= min_date]
for i,cr in e_asia_c.iterrows():
    c = cr["country"]
    dates = chart_data.loc[chart_data["location"]==c]["date"]
    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else dates.max()
    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"],label=c, fmt="-")
    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_cases_smoothed_per_million"],c
             ,va="center")
plt.legend(bbox_to_anchor=(0, 1),loc='upper left')

plt.subplot(2,2,4) # (rows, columns, panel number)
plt.grid()
plt.xticks(rotation=45)
plt.title("Daily new deaths in Eastern Asia(7daysMA)")
chart_data = e_a_trans[e_a_trans.date >= min_date]
for i,cr in e_asia_c.iterrows():
    c = cr["country"]
    dates = chart_data.loc[chart_data["location"]==c]["date"]
    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else dates.max()
    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_deaths_smoothed"],label=c, fmt="-")
    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_deaths_smoothed"],c
             ,va="center")
plt.legend(bbox_to_anchor=(0, 1),loc='upper left')

fig.text(0,0.98,"Latest: {}".format(latest_date_str),ha="left",va="top")
fig.text(0,0
         ,"*Data Source : COVID-19 Dataset by Our World in Data",
        ha="left",va="bottom")
fig.tight_layout()
"""
"""
# Out:
# <div id='06f8ba8c-b652-499c-a05a-b07b7b9d9598'></div>
# Japan 2022-11-17 00:00:00 1030    644.447
# Name: new_cases_smoothed_per_million, dtype: float64
# United States 2022-11-17 00:00:00 2061    110.605
# Name: new_cases_smoothed_per_million, dtype: float64
# Germany 2022-11-17 00:00:00 3087    299.958
# Name: new_cases_smoothed_per_million, dtype: float64
# Brazil 2022-11-17 00:00:00 4083    54.052
# Name: new_cases_smoothed_per_million, dtype: float64
# France 2022-11-17 00:00:00 5112    384.046
# Name: new_cases_smoothed_per_million, dtype: float64
# United Kingdom 2022-11-17 00:00:00 6135    49.604
# Name: new_cases_smoothed_per_million, dtype: float64
# Russia 2022-11-17 00:00:00 7157    35.673
# Name: new_cases_smoothed_per_million, dtype: float64
# Turkey 2022-11-17 00:00:00 8139    0.0
# Name: new_cases_smoothed_per_million, dtype: float64
# Poland 2022-11-17 00:00:00 9128    8.398
# Name: new_cases_smoothed_per_million, dtype: float64
# '\n'

# %%
fig.savefig("out/covid-owid-countries-daily.png")
# Out:
# posx and posy should be finite values
# posx and posy should be finite values

# %% [markdown]
# ### 新規感染者数

# %%
fig = plt.figure(figsize=(12,14))

plt.subplot(2,2,1) # (rows, columns, panel number)
plt.title("New confirmed COVID-19 cases worst 50")
plt.yticks(fontsize=9)
plt.xlabel("people")
chart_data = c_df_latest.sort_values("new_cases",ascending=False).head(50).sort_values("new_cases",ascending=True)
plt.barh(chart_data["location"],chart_data["new_cases"],label="new cases a day")
plt.grid(axis="x")
mean = int(c_df_latest.new_cases.mean())
plt.plot([mean,mean],[0,50], 'k--', lw=0.5)
plt.text(mean,50,"Mean:{}".format(mean),ha="center",fontsize=9)
plt.legend()

plt.subplot(2,2,2) # (rows, columns, panel number)
plt.title("New confirmed COVID-19 cases per million worst 50")
plt.yticks(fontsize=9)
plt.xlabel("people")
chart_data = c_df_latest.sort_values("new_cases_per_million",ascending=False).head(50).sort_values("new_cases_per_million",ascending=True)
plt.barh(chart_data["location"],chart_data["new_cases_per_million"],label="new cases a day per million")
plt.grid(axis="x")
mean = int(chart_data.new_cases_per_million.mean())
plt.plot([mean,mean],[0,50], 'k--', lw=0.5)
plt.text(mean,50,"Mean:{}".format(mean),ha="center",fontsize=9)
plt.legend()

fig.text(0,0.98,"Latest: {}".format(latest_date_str),fontsize=9,ha="left",va="top")
fig.text(0,0
         ,"*Data Source : COVID-19 Dataset by Our World in Data",
        fontsize=8,ha="left",va="bottom")

plt.subplot(2,2,3) # (rows, columns, panel number)
plt.title("New deaths worst 50")
plt.yticks(fontsize=9)
plt.xlabel("people")
chart_data = c_df_latest.sort_values("new_deaths",ascending=False).head(50).sort_values("new_deaths",ascending=True)
plt.barh(chart_data["location"],chart_data["new_deaths"],label="new deaths a day")
plt.grid(axis="x")
mean = int(c_df_latest.new_deaths.mean())
plt.plot([mean,mean],[0,50], 'k--', lw=0.5)
plt.text(mean,50,"Mean:{}".format(mean),ha="center",fontsize=9)
plt.legend()

plt.subplot(2,2,4) # (rows, columns, panel number)
plt.title("Total deaths per capita worst 50")
plt.yticks(fontsize=9)
plt.xlabel("%")
chart_data = c_df_latest.copy()
chart_data["total_deaths_per_capita"] = chart_data.total_deaths / chart_data.population * 100
chart_data = chart_data.sort_values("total_deaths_per_capita",ascending=False).head(50).sort_values("total_deaths_per_capita",ascending=True)
plt.barh(chart_data["location"],chart_data["total_deaths_per_capita"],label="total deaths per capita")
plt.grid(axis="x")
mean = round(chart_data.total_deaths_per_capita.mean(),2)
plt.plot([mean,mean],[0,50], 'k--', lw=0.5)
plt.text(mean,50,"Mean:{}".format(mean),ha="center",fontsize=9)
plt.legend()


fig.tight_layout()
# Out:
# <div id='53ea5126-e396-4df6-8bb3-3063291745c2'></div>

# %%
fig.savefig("out/covid-owid-global-latest-top.png")

# %%
a_df = df.loc[df.location=="Japan"]
c_df = df.loc[(df.date==pd.to_datetime("2021-07-27")) & (df.iso_code.str.len()==3)]

# %%
a_df.tail(10)
# Out:
#        iso_code continent location       date  total_cases  new_cases  \
# 107042      JPN      Asia    Japan 2022-11-08   22815395.0    81401.0
# 107043      JPN      Asia    Japan 2022-11-09   22902805.0    87410.0
# 107044      JPN      Asia    Japan 2022-11-10   22981382.0    78577.0
# 107045      JPN      Asia    Japan 2022-11-11   23055475.0    74093.0
# 107046      JPN      Asia    Japan 2022-11-12   23134961.0    79486.0
# 107047      JPN      Asia    Japan 2022-11-13   23203855.0    68894.0
# 107048      JPN      Asia    Japan 2022-11-14   23241410.0    37555.0
# 107049      JPN      Asia    Japan 2022-11-15   23341236.0    99826.0
# 107050      JPN      Asia    Japan 2022-11-16   23448938.0   107702.0
# 107051      JPN      Asia    Japan 2022-11-17   23540544.0    91606.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 107042           60789.000       47245.0        70.0               61.143
# 107043           63219.571       47342.0        97.0               65.000
# 107044           64805.857       47442.0       100.0               69.429
# 107045           70524.286       47523.0        81.0               72.571
# 107046           71283.714       47618.0        95.0               75.857
# 107047           71640.429       47685.0        67.0               78.857
# 107048           72488.000       47733.0        48.0               79.714
# 107049           75120.143       47723.0         NaN                  NaN
# 107050           78019.000       47834.0       111.0               71.714
# 107051           79880.286       47974.0       140.0               77.429
#
#         ...  male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 107042  ...          33.7                     NaN                       13.05
# 107043  ...          33.7                     NaN                       13.05
# 107044  ...          33.7                     NaN                       13.05
# 107045  ...          33.7                     NaN                       13.05
# 107046  ...          33.7                     NaN                       13.05
# 107047  ...          33.7                     NaN                       13.05
# 107048  ...          33.7                     NaN                       13.05
# 107049  ...          33.7                     NaN                       13.05
# 107050  ...          33.7                     NaN                       13.05
# 107051  ...          33.7                     NaN                       13.05
#
#         life_expectancy  human_development_index   population  \
# 107042            84.63                    0.919  123951696.0
# 107043            84.63                    0.919  123951696.0
# 107044            84.63                    0.919  123951696.0
# 107045            84.63                    0.919  123951696.0
# 107046            84.63                    0.919  123951696.0
# 107047            84.63                    0.919  123951696.0
# 107048            84.63                    0.919  123951696.0
# 107049            84.63                    0.919  123951696.0
# 107050            84.63                    0.919  123951696.0
# 107051            84.63                    0.919  123951696.0
#
#         excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 107042                                   NaN                          NaN
# 107043                                   NaN                          NaN
# 107044                                   NaN                          NaN
# 107045                                   NaN                          NaN
# 107046                                   NaN                          NaN
# 107047                                   NaN                          NaN
# 107048                                   NaN                          NaN
# 107049                                   NaN                          NaN
# 107050                                   NaN                          NaN
# 107051                                   NaN                          NaN
#
#         excess_mortality  excess_mortality_cumulative_per_million
# 107042               NaN                                      NaN
# 107043               NaN                                      NaN
# 107044               NaN                                      NaN
# 107045               NaN                                      NaN
# 107046               NaN                                      NaN
# 107047               NaN                                      NaN
# 107048               NaN                                      NaN
# 107049               NaN                                      NaN
# 107050               NaN                                      NaN
# 107051               NaN                                      NaN
#
# [10 rows x 67 columns]

# %%
c_df.sort_values("new_deaths",ascending=False).head(50)
# Out:
#        iso_code      continent        location       date  total_cases  \
# 97554       IDN           Asia       Indonesia 2021-07-27    3239936.0
# 29274       BRA  South America          Brazil 2021-07-27   19758310.0
# 174339      RUS         Europe          Russia 2021-07-27    6094379.0
# 96563       IND           Asia           India 2021-07-27   31484605.0
# 135352      MEX  North America          Mexico 2021-07-27    2771846.0
# 222013      USA  North America   United States 2021-07-27   34723396.0
# 99572       IRN           Asia            Iran 2021-07-27    3758197.0
# 143882      MMR           Asia         Myanmar 2021-07-27     279119.0
# 194929      ZAF         Africa    South Africa 2021-07-27    2391223.0
# 44118       COL  South America        Colombia 2021-07-27    4747775.0
# 17489       BGD           Asia      Bangladesh 2021-07-27    1194752.0
# 8483        ARG  South America       Argentina 2021-07-27    4875927.0
# 128480      MYS           Asia        Malaysia 2021-07-27    1044071.0
# 213902      TUN         Africa         Tunisia 2021-07-27     575002.0
# 208906      THA           Asia        Thailand 2021-07-27     526828.0
# 235214      ZWE         Africa        Zimbabwe 2021-07-27     101711.0
# 167043      PER  South America            Peru 2021-07-27    2106371.0
# 220982      GBR         Europe  United Kingdom 2021-07-27    5745526.0
# 50521       CUB  North America            Cuba 2021-07-27     349055.0
# 168066      PHL           Asia     Philippines 2021-07-27    1562420.0
# 100570      IRQ           Asia            Iraq 2021-07-27    1577013.0
# 25367       BOL  South America         Bolivia 2021-07-27     470024.0
# 86076       GTM  North America       Guatemala 2021-07-27     355223.0
# 92526       HND  North America        Honduras 2021-07-27     291687.0
# 166056      PRY  South America        Paraguay 2021-07-27     450494.0
# 198938      ESP         Europe           Spain 2021-07-27    4368453.0
# 214884      TUR           Asia          Turkey 2021-07-27    5638178.0
# 199964      LKA           Asia       Sri Lanka 2021-07-27     299892.0
# 161672      PAK           Asia        Pakistan 2021-07-27    1015827.0
# 47561       CRI  North America      Costa Rica 2021-07-27     402044.0
# 218935      UKR         Europe         Ukraine 2021-07-27    2327777.0
# 79330       DEU         Europe         Germany 2021-07-27    3758401.0
# 519         AFG           Asia     Afghanistan 2021-07-27     145008.0
# 144861      NAM         Africa         Namibia 2021-07-27     117293.0
# 142916      MOZ         Africa      Mozambique 2021-07-27     113426.0
# 42100       CHL  South America           Chile 2021-07-27    1611090.0
# 74373       FRA         Europe          France 2021-07-27    6068988.0
# 127451      MWI         Africa          Malawi 2021-07-27      49752.0
# 141945      MAR         Africa         Morocco 2021-07-27     588448.0
# 3522        DZA         Africa         Algeria 2021-07-27     165204.0
# 104560      ITA         Europe           Italy 2021-07-27    4325046.0
# 119491      LBY         Africa           Libya 2021-07-27     240309.0
# 234241      ZMB         Africa          Zambia 2021-07-27     192956.0
# 146478      NPL           Asia           Nepal 2021-07-27     685673.0
# 35179       KHM           Asia        Cambodia 2021-07-27      74386.0
# 160675      OMN           Asia            Oman 2021-07-27     295017.0
# 78304       GEO           Asia         Georgia 2021-07-27     407689.0
# 228524      VEN  South America       Venezuela 2021-07-27     301979.0
# 113641      KGZ           Asia      Kyrgyzstan 2021-07-27     159089.0
# 175318      RWA         Africa          Rwanda 2021-07-27      66987.0
#
#         new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 97554     45203.0           41411.143       86835.0      2069.0
# 29274     43591.0           47082.000      552128.0      1289.0
# 174339    22486.0           23207.714      152836.0       767.0
# 96563     43654.0           38324.000      422022.0       640.0
# 135352    17408.0           13364.143      239079.0       484.0
# 222013    65071.0           60958.857      607825.0       458.0
# 99572     34951.0           26007.000       89479.0       357.0
# 143882     4964.0            5507.000        7845.0       338.0
# 194929     7733.0           11427.286       70338.0       320.0
# 44118     11426.0           11289.286      119482.0       300.0
# 17489     14925.0            9409.000       19779.0       258.0
# 8483      16757.0           13101.143      104352.0       247.0
# 128480    16117.0           14881.714        8408.0       207.0
# 213902     1608.0            2870.143       18968.0       164.0
# 208906    14150.0           14336.143        4264.0       118.0
# 235214     1767.0            1899.429        3280.0       107.0
# 167043     1366.0            1479.714      196058.0        85.0
# 220982    23228.0           32274.857      156155.0        77.0
# 50521      7903.0            7800.857        2492.0        75.0
# 168066     7024.0            6359.571       27318.0        71.0
# 100570    12185.0            9499.429       18418.0        71.0
# 25367      1601.0             985.571       17716.0        65.0
# 86076      2639.0            2494.429       10176.0        64.0
# 92526      1240.0            1285.857        7713.0        63.0
# 166056      592.0             603.857       14759.0        58.0
# 198938    26399.0           25616.714       81323.0        55.0
# 214884    19761.0           13144.571       51048.0        51.0
# 199964     1711.0            1702.714        4195.0        48.0
# 161672     4119.0            2768.000       23133.0        46.0
# 47561      3436.0            1129.857        4987.0        46.0
# 218935     1227.0            1127.286       55420.0        39.0
# 79330      1545.0            1713.000       91565.0        38.0
# 519         723.0             370.571        6515.0        38.0
# 144861      329.0             550.714        2871.0        37.0
# 142916     1703.0            1631.000        1341.0        34.0
# 42100       745.0            1318.857       35151.0        32.0
# 74373     27024.0           19467.143      111727.0        28.0
# 127451      743.0             724.000        1540.0        27.0
# 141945     6971.0            3718.857        9638.0        27.0
# 3522       1544.0            1345.714        4112.0        25.0
# 104560     4516.0            4566.143      127995.0        24.0
# 119491     3348.0            1944.000        3422.0        24.0
# 234241      640.0             764.857        3316.0        21.0
# 146478     2726.0            2102.857        9758.0        20.0
# 35179       685.0             798.571        1324.0        19.0
# 160675      491.0             853.571        3788.0        17.0
# 78304      3666.0            2392.000        5731.0        17.0
# 228524     1060.0            1159.000        3524.0        15.0
# 113641      969.0            1068.857        2275.0        14.0
# 175318      969.0            1120.857         771.0        14.0
#
#         new_deaths_smoothed  ...  male_smokers  handwashing_facilities  \
# 97554              1519.286  ...          76.1                  64.204
# 29274              1085.143  ...          17.9                     NaN
# 174339              768.429  ...          58.3                     NaN
# 96563               506.000  ...          20.6                  59.550
# 135352              324.143  ...          21.4                  87.847
# 222013              307.000  ...          24.6                     NaN
# 99572               265.000  ...          21.1                     NaN
# 143882              325.429  ...          35.2                  79.287
# 194929              380.286  ...          33.2                  43.993
# 44118               335.857  ...          13.5                  65.386
# 17489               207.714  ...          44.7                  34.808
# 8483                281.571  ...          27.7                     NaN
# 128480              166.714  ...          42.4                     NaN
# 213902              163.857  ...          65.8                  78.687
# 208906              108.857  ...          38.8                  90.670
# 235214               76.143  ...          30.7                  36.791
# 167043              103.714  ...           NaN                     NaN
# 220982               75.286  ...          24.7                     NaN
# 50521                67.571  ...          53.3                  85.198
# 168066               67.714  ...          40.8                  78.463
# 100570               66.714  ...           NaN                  94.576
# 25367                34.429  ...           NaN                  25.383
# 86076                35.571  ...           NaN                  76.665
# 92526                29.429  ...           NaN                  84.169
# 166056               52.143  ...          21.6                  79.602
# 198938               25.000  ...          31.4                     NaN
# 214884               56.857  ...          41.1                     NaN
# 199964               46.429  ...          27.0                     NaN
# 161672               35.000  ...          36.7                  59.607
# 47561                10.286  ...          17.4                  83.841
# 218935               28.429  ...          47.4                     NaN
# 79330                24.000  ...          33.1                     NaN
# 519                  35.571  ...           NaN                  37.746
# 144861               44.857  ...          34.2                  44.600
# 142916               26.143  ...          29.1                  12.227
# 42100                83.143  ...          41.5                     NaN
# 74373                24.429  ...          35.6                     NaN
# 127451               25.286  ...          24.7                   8.704
# 141945               21.714  ...          47.1                     NaN
# 3522                 19.000  ...          30.4                  83.741
# 104560               15.857  ...          27.8                     NaN
# 119491               16.143  ...           NaN                     NaN
# 234241               25.429  ...          24.7                  13.938
# 146478               21.571  ...          37.8                  47.782
# 35179                25.000  ...          33.7                  66.229
# 160675               41.429  ...          15.6                  97.400
# 78304                19.857  ...          55.5                     NaN
# 228524               18.857  ...           NaN                     NaN
# 113641               11.286  ...          50.5                  89.220
# 175318               13.429  ...          21.0                   4.617
#
#         hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 97554                         1.04            71.72                    0.718
# 29274                         2.20            75.88                    0.765
# 174339                        8.05            72.58                    0.824
# 96563                         0.53            69.66                    0.645
# 135352                        1.38            75.05                    0.779
# 222013                        2.77            78.86                    0.926
# 99572                         1.50            76.68                    0.783
# 143882                        0.90            67.13                    0.583
# 194929                        2.32            64.13                    0.709
# 44118                         1.71            77.29                    0.767
# 17489                         0.80            72.59                    0.632
# 8483                          5.00            76.67                    0.845
# 128480                        1.90            76.16                    0.810
# 213902                        2.30            76.70                    0.740
# 208906                        2.10            77.15                    0.777
# 235214                        1.70            61.49                    0.571
# 167043                        1.60            76.74                    0.777
# 220982                        2.54            81.32                    0.932
# 50521                         5.20            78.80                    0.783
# 168066                        1.00            71.23                    0.718
# 100570                        1.40            70.60                    0.674
# 25367                         1.10            71.51                    0.718
# 86076                         0.60            74.30                    0.663
# 92526                         0.70            75.27                    0.634
# 166056                        1.30            74.25                    0.728
# 198938                        2.97            83.56                    0.904
# 214884                        2.81            77.69                    0.820
# 199964                        3.60            76.98                    0.782
# 161672                        0.60            67.27                    0.557
# 47561                         1.13            80.28                    0.810
# 218935                        8.80            72.06                    0.779
# 79330                         8.00            81.33                    0.947
# 519                           0.50            64.83                    0.511
# 144861                         NaN            63.71                    0.646
# 142916                        0.70            60.85                    0.456
# 42100                         2.11            80.18                    0.851
# 74373                         5.98            82.66                    0.901
# 127451                        1.30            64.26                    0.483
# 141945                        1.10            76.68                    0.686
# 3522                          1.90            76.88                    0.748
# 104560                        3.18            83.51                    0.892
# 119491                        3.70            72.91                    0.724
# 234241                        2.00            63.89                    0.584
# 146478                        0.30            70.78                    0.602
# 35179                         0.80            69.82                    0.594
# 160675                        1.60            77.86                    0.813
# 78304                         2.60            73.77                    0.812
# 228524                        0.80            72.06                    0.711
# 113641                        4.50            71.45                    0.697
# 175318                         NaN            69.02                    0.543
#
#           population  excess_mortality_cumulative_absolute  \
# 97554   2.755013e+08                                   NaN
# 29274   2.153135e+08                                   NaN
# 174339  1.447133e+08                                   NaN
# 96563   1.417173e+09                                   NaN
# 135352  1.275041e+08                                   NaN
# 222013  3.382899e+08                                   NaN
# 99572   8.855057e+07                                   NaN
# 143882  5.417931e+07                                   NaN
# 194929  5.989388e+07                                   NaN
# 44118   5.187403e+07                                   NaN
# 17489   1.711864e+08                                   NaN
# 8483    4.551032e+07                                   NaN
# 128480  3.393822e+07                                   NaN
# 213902  1.235612e+07                                   NaN
# 208906  7.169702e+07                                   NaN
# 235214  1.632054e+07                                   NaN
# 167043  3.404959e+07                                   NaN
# 220982  6.750894e+07                                   NaN
# 50521   1.121220e+07                                   NaN
# 168066  1.155590e+08                                   NaN
# 100570  4.449612e+07                                   NaN
# 25367   1.222411e+07                                   NaN
# 86076   1.784391e+07                                   NaN
# 92526   1.043286e+07                                   NaN
# 166056  6.780745e+06                                   NaN
# 198938  4.755863e+07                                   NaN
# 214884  8.534125e+07                                   NaN
# 199964  2.183215e+07                                   NaN
# 161672  2.358249e+08                                   NaN
# 47561   5.180836e+06                                   NaN
# 218935  3.970174e+07                                   NaN
# 79330   8.336984e+07                                   NaN
# 519     4.112877e+07                                   NaN
# 144861  2.567024e+06                                   NaN
# 142916  3.296952e+07                                   NaN
# 42100   1.960374e+07                                   NaN
# 74373   6.781300e+07                                   NaN
# 127451  2.040532e+07                                   NaN
# 141945  3.745798e+07                                   NaN
# 3522    4.490323e+07                                   NaN
# 104560  5.903747e+07                                   NaN
# 119491  6.812344e+06                                   NaN
# 234241  2.001767e+07                                   NaN
# 146478  3.054759e+07                                   NaN
# 35179   1.676785e+07                                   NaN
# 160675  4.576300e+06                                   NaN
# 78304   3.744385e+06                                   NaN
# 228524  2.830170e+07                                   NaN
# 113641  6.630621e+06                                   NaN
# 175318  1.377670e+07                                   NaN
#
#         excess_mortality_cumulative  excess_mortality  \
# 97554                           NaN               NaN
# 29274                           NaN               NaN
# 174339                          NaN               NaN
# 96563                           NaN               NaN
# 135352                          NaN               NaN
# 222013                          NaN               NaN
# 99572                           NaN               NaN
# 143882                          NaN               NaN
# 194929                          NaN               NaN
# 44118                           NaN               NaN
# 17489                           NaN               NaN
# 8483                            NaN               NaN
# 128480                          NaN               NaN
# 213902                          NaN               NaN
# 208906                          NaN               NaN
# 235214                          NaN               NaN
# 167043                          NaN               NaN
# 220982                          NaN               NaN
# 50521                           NaN               NaN
# 168066                          NaN               NaN
# 100570                          NaN               NaN
# 25367                           NaN               NaN
# 86076                           NaN               NaN
# 92526                           NaN               NaN
# 166056                          NaN               NaN
# 198938                          NaN               NaN
# 214884                          NaN               NaN
# 199964                          NaN               NaN
# 161672                          NaN               NaN
# 47561                           NaN               NaN
# 218935                          NaN               NaN
# 79330                           NaN               NaN
# 519                             NaN               NaN
# 144861                          NaN               NaN
# 142916                          NaN               NaN
# 42100                           NaN               NaN
# 74373                           NaN               NaN
# 127451                          NaN               NaN
# 141945                          NaN               NaN
# 3522                            NaN               NaN
# 104560                          NaN               NaN
# 119491                          NaN               NaN
# 234241                          NaN               NaN
# 146478                          NaN               NaN
# 35179                           NaN               NaN
# 160675                          NaN               NaN
# 78304                           NaN               NaN
# 228524                          NaN               NaN
# 113641                          NaN               NaN
# 175318                          NaN               NaN
#
#         excess_mortality_cumulative_per_million
# 97554                                       NaN
# 29274                                       NaN
# 174339                                      NaN
# 96563                                       NaN
# 135352                                      NaN
# 222013                                      NaN
# 99572                                       NaN
# 143882                                      NaN
# 194929                                      NaN
# 44118                                       NaN
# 17489                                       NaN
# 8483                                        NaN
# 128480                                      NaN
# 213902                                      NaN
# 208906                                      NaN
# 235214                                      NaN
# 167043                                      NaN
# 220982                                      NaN
# 50521                                       NaN
# 168066                                      NaN
# 100570                                      NaN
# 25367                                       NaN
# 86076                                       NaN
# 92526                                       NaN
# 166056                                      NaN
# 198938                                      NaN
# 214884                                      NaN
# 199964                                      NaN
# 161672                                      NaN
# 47561                                       NaN
# 218935                                      NaN
# 79330                                       NaN
# 519                                         NaN
# 144861                                      NaN
# 142916                                      NaN
# 42100                                       NaN
# 74373                                       NaN
# 127451                                      NaN
# 141945                                      NaN
# 3522                                        NaN
# 104560                                      NaN
# 119491                                      NaN
# 234241                                      NaN
# 146478                                      NaN
# 35179                                       NaN
# 160675                                      NaN
# 78304                                       NaN
# 228524                                      NaN
# 113641                                      NaN
# 175318                                      NaN
#
# [50 rows x 67 columns]

# %%
c_df.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'total_tests', 'new_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'total_boosters',
#        'new_vaccinations', 'new_vaccinations_smoothed',
#        'total_vaccinations_per_hundred', 'people_vaccinated_per_hundred',
#        'people_fully_vaccinated_per_hundred', 'total_boosters_per_hundred',
#        'new_vaccinations_smoothed_per_million',
#        'new_people_vaccinated_smoothed',
#        'new_people_vaccinated_smoothed_per_hundred', 'stringency_index',
#        'population_density', 'median_age', 'aged_65_older', 'aged_70_older',
#        'gdp_per_capita', 'extreme_poverty', 'cardiovasc_death_rate',
#        'diabetes_prevalence', 'female_smokers', 'male_smokers',
#        'handwashing_facilities', 'hospital_beds_per_thousand',
#        'life_expectancy', 'human_development_index', 'population',
#        'excess_mortality_cumulative_absolute', 'excess_mortality_cumulative',
#        'excess_mortality', 'excess_mortality_cumulative_per_million'],
#       dtype='object')
