# %%
import pandas as pd

# %%
df = pd.read_csv("covid-19-data/public/data/owid-covid-data.csv")
df.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1      AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# 0              NaN                597.029                 9.59
# 1              NaN                597.029                 9.59
# 2              NaN                597.029                 9.59
# 3              NaN                597.029                 9.59
# 4              NaN                597.029                 9.59
#
#    female_smokers  male_smokers  handwashing_facilities  \
# 0             NaN           NaN                  37.746
# 1             NaN           NaN                  37.746
# 2             NaN           NaN                  37.746
# 3             NaN           NaN                  37.746
# 4             NaN           NaN                  37.746
#
#    hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                         0.5            64.83                    0.511
# 1                         0.5            64.83                    0.511
# 2                         0.5            64.83                    0.511
# 3                         0.5            64.83                    0.511
# 4                         0.5            64.83                    0.511
#
#    excess_mortality
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
#
# [5 rows x 60 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106352 entries, 0 to 106351
# Data columns (total 60 columns):
#  #   Column                                 Non-Null Count   Dtype
# ---  ------                                 --------------   -----
#  0   iso_code                               106352 non-null  object
#  1   continent                              101413 non-null  object
#  2   location                               106352 non-null  object
#  3   date                                   106352 non-null  object
#  4   total_cases                            102011 non-null  float64
#  5   new_cases                              102008 non-null  float64
#  6   new_cases_smoothed                     100998 non-null  float64
#  7   total_deaths                           91669 non-null   float64
#  8   new_deaths                             91824 non-null   float64
#  9   new_deaths_smoothed                    100998 non-null  float64
#  10  total_cases_per_million                101470 non-null  float64
#  11  new_cases_per_million                  101467 non-null  float64
#  12  new_cases_smoothed_per_million         100462 non-null  float64
#  13  total_deaths_per_million               91141 non-null   float64
#  14  new_deaths_per_million                 91296 non-null   float64
#  15  new_deaths_smoothed_per_million        100462 non-null  float64
#  16  reproduction_rate                      85742 non-null   float64
#  17  icu_patients                           11017 non-null   float64
#  18  icu_patients_per_million               11017 non-null   float64
#  19  hosp_patients                          13305 non-null   float64
#  20  hosp_patients_per_million              13305 non-null   float64
#  21  weekly_icu_admissions                  979 non-null     float64
#  22  weekly_icu_admissions_per_million      979 non-null     float64
#  23  weekly_hosp_admissions                 1881 non-null    float64
#  24  weekly_hosp_admissions_per_million     1881 non-null    float64
#  25  new_tests                              47261 non-null   float64
#  26  total_tests                            46987 non-null   float64
#  27  total_tests_per_thousand               46987 non-null   float64
#  28  new_tests_per_thousand                 47261 non-null   float64
#  29  new_tests_smoothed                     55353 non-null   float64
#  30  new_tests_smoothed_per_thousand        55353 non-null   float64
#  31  positive_rate                          51713 non-null   float64
#  32  tests_per_case                         51081 non-null   float64
#  33  tests_units                            57119 non-null   object
#  34  total_vaccinations                     19958 non-null   float64
#  35  people_vaccinated                      19080 non-null   float64
#  36  people_fully_vaccinated                16151 non-null   float64
#  37  new_vaccinations                       16609 non-null   float64
#  38  new_vaccinations_smoothed              34965 non-null   float64
#  39  total_vaccinations_per_hundred         19958 non-null   float64
#  40  people_vaccinated_per_hundred          19080 non-null   float64
#  41  people_fully_vaccinated_per_hundred    16151 non-null   float64
#  42  new_vaccinations_smoothed_per_million  34965 non-null   float64
#  43  stringency_index                       88392 non-null   float64
#  44  population                             105646 non-null  float64
#  45  population_density                     98695 non-null   float64
#  46  median_age                             94721 non-null   float64
#  47  aged_65_older                          93661 non-null   float64
#  48  aged_70_older                          94199 non-null   float64
#  49  gdp_per_capita                         95127 non-null   float64
#  50  extreme_poverty                        64055 non-null   float64
#  51  cardiovasc_death_rate                  95070 non-null   float64
#  52  diabetes_prevalence                    97657 non-null   float64
#  53  female_smokers                         74315 non-null   float64
#  54  male_smokers                           73229 non-null   float64
#  55  handwashing_facilities                 47748 non-null   float64
#  56  hospital_beds_per_thousand             86543 non-null   float64
#  57  life_expectancy                        100935 non-null  float64
#  58  human_development_index                95182 non-null   float64
#  59  excess_mortality                       3673 non-null    float64
# dtypes: float64(55), object(5)
# memory usage: 48.7+ MB

# %%
df.describe()
# Out:
#         total_cases      new_cases  new_cases_smoothed  total_deaths  \
# count  1.020110e+05  102008.000000       100998.000000  9.166900e+04
# mean   1.178241e+06    6144.430515         6149.662706  3.120269e+04
# std    7.998911e+06   37996.519559        37617.405697  1.862623e+05
# min    1.000000e+00  -74347.000000        -6223.000000  1.000000e+00
# 25%    1.479000e+03       2.000000            7.857000  5.900000e+01
# 50%    1.540800e+04      77.000000           96.143000  4.520000e+02
# 75%    1.639840e+05     845.000000          893.143000  4.340000e+03
# max    1.978254e+08  905993.000000       826368.143000  4.216780e+06
#
#          new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  91824.000000        100998.000000            101470.000000
# mean     145.583682           131.503092             14563.692310
# std      796.030249           740.766850             26119.765832
# min    -1918.000000          -232.143000                 0.001000
# 25%        0.000000             0.000000               284.216000
# 50%        2.000000             1.429000              2085.834000
# 75%       18.000000            14.714000             15638.243250
# max    18056.000000         14735.286000            189969.585000
#
#        new_cases_per_million  new_cases_smoothed_per_million  \
# count          101467.000000                   100462.000000
# mean               77.373955                       77.485826
# std               201.468146                      158.960475
# min             -3162.163000                     -276.825000
# 25%                 0.239000                        1.376000
# 50%                 9.053000                       11.957000
# 75%                72.196000                       80.325000
# max             18293.675000                     4083.500000
#
#        total_deaths_per_million  ...  extreme_poverty  cardiovasc_death_rate  \
# count              91141.000000  ...     64055.000000           95070.000000
# mean                 316.492005  ...        13.434887             258.740017
# std                  561.451667  ...        19.970489             119.127249
# min                    0.001000  ...         0.100000              79.370000
# 25%                    8.835000  ...         0.600000             168.711000
# 50%                   58.104000  ...         2.200000             242.648000
# 75%                  354.097000  ...        21.200000             329.942000
# max                 5955.172000  ...        77.600000             724.417000
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# count         97657.000000    74315.000000  73229.000000
# mean              7.954432       10.583190     32.714780
# std               4.184425       10.484428     13.489926
# min               0.990000        0.100000      7.700000
# 25%               5.310000        1.900000     21.600000
# 50%               7.110000        6.300000     31.400000
# 75%              10.080000       19.300000     41.100000
# max              30.530000       44.000000     78.100000
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# count            47748.000000                86543.000000    100935.000000
# mean                50.799113                    3.026599        73.242105
# std                 31.757021                    2.456525         7.554971
# min                  1.188000                    0.100000        53.280000
# 25%                 19.351000                    1.300000        67.920000
# 50%                 49.839000                    2.400000        74.620000
# 75%                 83.241000                    3.861000        78.740000
# max                100.000000                   13.800000        86.750000
#
#        human_development_index  excess_mortality
# count             95182.000000       3673.000000
# mean                  0.727068         18.127661
# std                   0.150307         35.586647
# min                   0.394000        -95.590000
# 25%                   0.602000          0.430000
# 50%                   0.744000          7.440000
# 75%                   0.848000         23.940000
# max                   0.957000        410.120000
#
# [8 rows x 55 columns]

# %%
df.continent.unique()
# Out:
# array(['Asia', nan, 'Europe', 'Africa', 'North America', 'South America',
#        'Oceania'], dtype=object)

# %%
df.loc[df.continent.isna()].location.unique()
# Out:
# array(['Africa', 'Asia', 'Europe', 'European Union', 'International',
#        'North America', 'Oceania', 'South America', 'World'], dtype=object)

# %%
df.loc[df.location=="International"]
# Out:
#        iso_code continent       location        date  total_cases  new_cases  \
# 45024  OWID_INT       NaN  International  2020-02-07         61.0       61.0
# 45025  OWID_INT       NaN  International  2020-02-08         61.0        0.0
# 45026  OWID_INT       NaN  International  2020-02-09         64.0        3.0
# 45027  OWID_INT       NaN  International  2020-02-10        135.0       71.0
# 45028  OWID_INT       NaN  International  2020-02-11        135.0        0.0
# ...         ...       ...            ...         ...          ...        ...
# 45560  OWID_INT       NaN  International  2021-07-27        721.0        0.0
# 45561  OWID_INT       NaN  International  2021-07-28        721.0        0.0
# 45562  OWID_INT       NaN  International  2021-07-29        721.0        0.0
# 45563  OWID_INT       NaN  International  2021-07-30        721.0        0.0
# 45564  OWID_INT       NaN  International  2021-07-31        721.0        0.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 45024                 NaN           NaN         NaN                  NaN  ...
# 45025                 NaN           NaN         NaN                  NaN  ...
# 45026                 NaN           NaN         NaN                  NaN  ...
# 45027                 NaN           NaN         NaN                  NaN  ...
# 45028                 NaN           NaN         NaN                  NaN  ...
# ...                   ...           ...         ...                  ...  ...
# 45560                 0.0          15.0         0.0                  0.0  ...
# 45561                 0.0          15.0         0.0                  0.0  ...
# 45562                 0.0          15.0         0.0                  0.0  ...
# 45563                 0.0          15.0         0.0                  0.0  ...
# 45564                 0.0          15.0         0.0                  0.0  ...
#
#        extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# 45024              NaN                    NaN                  NaN
# 45025              NaN                    NaN                  NaN
# 45026              NaN                    NaN                  NaN
# 45027              NaN                    NaN                  NaN
# 45028              NaN                    NaN                  NaN
# ...                ...                    ...                  ...
# 45560              NaN                    NaN                  NaN
# 45561              NaN                    NaN                  NaN
# 45562              NaN                    NaN                  NaN
# 45563              NaN                    NaN                  NaN
# 45564              NaN                    NaN                  NaN
#
#        female_smokers  male_smokers  handwashing_facilities  \
# 45024             NaN           NaN                     NaN
# 45025             NaN           NaN                     NaN
# 45026             NaN           NaN                     NaN
# 45027             NaN           NaN                     NaN
# 45028             NaN           NaN                     NaN
# ...               ...           ...                     ...
# 45560             NaN           NaN                     NaN
# 45561             NaN           NaN                     NaN
# 45562             NaN           NaN                     NaN
# 45563             NaN           NaN                     NaN
# 45564             NaN           NaN                     NaN
#
#        hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 45024                         NaN              NaN                      NaN
# 45025                         NaN              NaN                      NaN
# 45026                         NaN              NaN                      NaN
# 45027                         NaN              NaN                      NaN
# 45028                         NaN              NaN                      NaN
# ...                           ...              ...                      ...
# 45560                         NaN              NaN                      NaN
# 45561                         NaN              NaN                      NaN
# 45562                         NaN              NaN                      NaN
# 45563                         NaN              NaN                      NaN
# 45564                         NaN              NaN                      NaN
#
#        excess_mortality
# 45024               NaN
# 45025               NaN
# 45026               NaN
# 45027               NaN
# 45028               NaN
# ...                 ...
# 45560               NaN
# 45561               NaN
# 45562               NaN
# 45563               NaN
# 45564               NaN
#
# [541 rows x 60 columns]

# %%
df.location.unique()
# Out:
# array(['Afghanistan', 'Africa', 'Albania', 'Algeria', 'Andorra', 'Angola',
#        'Anguilla', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        'Asia', 'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain',
#        'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin',
#        'Bermuda', 'Bhutan', 'Bolivia', 'Bonaire Sint Eustatius and Saba',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Brunei', 'Bulgaria', 'Burkina Faso',
#        'Burundi', 'Cambodia', 'Cameroon', 'Canada', 'Cape Verde',
#        'Cayman Islands', 'Central African Republic', 'Chad', 'Chile',
#        'China', 'Colombia', 'Comoros', 'Congo', 'Cook Islands',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Curacao',
#        'Cyprus', 'Czechia', 'Democratic Republic of Congo', 'Denmark',
#        'Djibouti', 'Dominica', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Estonia',
#        'Eswatini', 'Ethiopia', 'Europe', 'European Union',
#        'Faeroe Islands', 'Falkland Islands', 'Fiji', 'Finland', 'France',
#        'French Polynesia', 'Gabon', 'Gambia', 'Georgia', 'Germany',
#        'Ghana', 'Gibraltar', 'Greece', 'Greenland', 'Grenada',
#        'Guatemala', 'Guernsey', 'Guinea', 'Guinea-Bissau', 'Guyana',
#        'Haiti', 'Honduras', 'Hong Kong', 'Hungary', 'Iceland', 'India',
#        'Indonesia', 'International', 'Iran', 'Iraq', 'Ireland',
#        'Isle of Man', 'Israel', 'Italy', 'Jamaica', 'Japan', 'Jersey',
#        'Jordan', 'Kazakhstan', 'Kenya', 'Kiribati', 'Kosovo', 'Kuwait',
#        'Kyrgyzstan', 'Laos', 'Latvia', 'Lebanon', 'Lesotho', 'Liberia',
#        'Libya', 'Liechtenstein', 'Lithuania', 'Luxembourg', 'Macao',
#        'Madagascar', 'Malawi', 'Malaysia', 'Maldives', 'Mali', 'Malta',
#        'Marshall Islands', 'Mauritania', 'Mauritius', 'Mexico',
#        'Micronesia (country)', 'Moldova', 'Monaco', 'Mongolia',
#        'Montenegro', 'Montserrat', 'Morocco', 'Mozambique', 'Myanmar',
#        'Namibia', 'Nauru', 'Nepal', 'Netherlands', 'New Caledonia',
#        'New Zealand', 'Nicaragua', 'Niger', 'Nigeria', 'Niue',
#        'North America', 'North Macedonia', 'Northern Cyprus', 'Norway',
#        'Oceania', 'Oman', 'Pakistan', 'Palestine', 'Panama',
#        'Papua New Guinea', 'Paraguay', 'Peru', 'Philippines', 'Pitcairn',
#        'Poland', 'Portugal', 'Qatar', 'Romania', 'Russia', 'Rwanda',
#        'Saint Helena', 'Saint Kitts and Nevis', 'Saint Lucia',
#        'Saint Vincent and the Grenadines', 'Samoa', 'San Marino',
#        'Sao Tome and Principe', 'Saudi Arabia', 'Senegal', 'Serbia',
#        'Seychelles', 'Sierra Leone', 'Singapore',
#        'Sint Maarten (Dutch part)', 'Slovakia', 'Slovenia',
#        'Solomon Islands', 'Somalia', 'South Africa', 'South America',
#        'South Korea', 'South Sudan', 'Spain', 'Sri Lanka', 'Sudan',
#        'Suriname', 'Sweden', 'Switzerland', 'Syria', 'Taiwan',
#        'Tajikistan', 'Tanzania', 'Thailand', 'Timor', 'Togo', 'Tonga',
#        'Trinidad and Tobago', 'Tunisia', 'Turkey', 'Turkmenistan',
#        'Turks and Caicos Islands', 'Tuvalu', 'Uganda', 'Ukraine',
#        'United Arab Emirates', 'United Kingdom', 'United States',
#        'Uruguay', 'Uzbekistan', 'Vanuatu', 'Vatican', 'Venezuela',
#        'Vietnam', 'Wallis and Futuna', 'World', 'Yemen', 'Zambia',
#        'Zimbabwe'], dtype=object)

# %%
df["date"] = pd.to_datetime(df["date"])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106352 entries, 0 to 106351
# Data columns (total 60 columns):
#  #   Column                                 Non-Null Count   Dtype
# ---  ------                                 --------------   -----
#  0   iso_code                               106352 non-null  object
#  1   continent                              101413 non-null  object
#  2   location                               106352 non-null  object
#  3   date                                   106352 non-null  datetime64[ns]
#  4   total_cases                            102011 non-null  float64
#  5   new_cases                              102008 non-null  float64
#  6   new_cases_smoothed                     100998 non-null  float64
#  7   total_deaths                           91669 non-null   float64
#  8   new_deaths                             91824 non-null   float64
#  9   new_deaths_smoothed                    100998 non-null  float64
#  10  total_cases_per_million                101470 non-null  float64
#  11  new_cases_per_million                  101467 non-null  float64
#  12  new_cases_smoothed_per_million         100462 non-null  float64
#  13  total_deaths_per_million               91141 non-null   float64
#  14  new_deaths_per_million                 91296 non-null   float64
#  15  new_deaths_smoothed_per_million        100462 non-null  float64
#  16  reproduction_rate                      85742 non-null   float64
#  17  icu_patients                           11017 non-null   float64
#  18  icu_patients_per_million               11017 non-null   float64
#  19  hosp_patients                          13305 non-null   float64
#  20  hosp_patients_per_million              13305 non-null   float64
#  21  weekly_icu_admissions                  979 non-null     float64
#  22  weekly_icu_admissions_per_million      979 non-null     float64
#  23  weekly_hosp_admissions                 1881 non-null    float64
#  24  weekly_hosp_admissions_per_million     1881 non-null    float64
#  25  new_tests                              47261 non-null   float64
#  26  total_tests                            46987 non-null   float64
#  27  total_tests_per_thousand               46987 non-null   float64
#  28  new_tests_per_thousand                 47261 non-null   float64
#  29  new_tests_smoothed                     55353 non-null   float64
#  30  new_tests_smoothed_per_thousand        55353 non-null   float64
#  31  positive_rate                          51713 non-null   float64
#  32  tests_per_case                         51081 non-null   float64
#  33  tests_units                            57119 non-null   object
#  34  total_vaccinations                     19958 non-null   float64
#  35  people_vaccinated                      19080 non-null   float64
#  36  people_fully_vaccinated                16151 non-null   float64
#  37  new_vaccinations                       16609 non-null   float64
#  38  new_vaccinations_smoothed              34965 non-null   float64
#  39  total_vaccinations_per_hundred         19958 non-null   float64
#  40  people_vaccinated_per_hundred          19080 non-null   float64
#  41  people_fully_vaccinated_per_hundred    16151 non-null   float64
#  42  new_vaccinations_smoothed_per_million  34965 non-null   float64
#  43  stringency_index                       88392 non-null   float64
#  44  population                             105646 non-null  float64
#  45  population_density                     98695 non-null   float64
#  46  median_age                             94721 non-null   float64
#  47  aged_65_older                          93661 non-null   float64
#  48  aged_70_older                          94199 non-null   float64
#  49  gdp_per_capita                         95127 non-null   float64
#  50  extreme_poverty                        64055 non-null   float64
#  51  cardiovasc_death_rate                  95070 non-null   float64
#  52  diabetes_prevalence                    97657 non-null   float64
#  53  female_smokers                         74315 non-null   float64
#  54  male_smokers                           73229 non-null   float64
#  55  handwashing_facilities                 47748 non-null   float64
#  56  hospital_beds_per_thousand             86543 non-null   float64
#  57  life_expectancy                        100935 non-null  float64
#  58  human_development_index                95182 non-null   float64
#  59  excess_mortality                       3673 non-null    float64
# dtypes: datetime64[ns](1), float64(55), object(4)
# memory usage: 48.7+ MB

# %% [markdown]
# ## 最新日付チェック

# %%
import datetime
#latest_date_str = (df.date.max()-datetime.timedelta(days=1)).strftime("%Y-%m-%d")
latest_date_str = df.date.max().strftime("%Y-%m-%d")
latest_date_str
# Out:
# '2021-07-31'

# %% [markdown]
# ## 全世界のデータのみ

# %%
world_df = df.copy().loc[df.location=="World"]
world_df.tail()
# Out:
#         iso_code continent location       date  total_cases  new_cases  \
# 104869  OWID_WRL       NaN    World 2021-07-27  195334304.0   613517.0
# 104870  OWID_WRL       NaN    World 2021-07-28  195968310.0   634006.0
# 104871  OWID_WRL       NaN    World 2021-07-29  196626531.0   658221.0
# 104872  OWID_WRL       NaN    World 2021-07-30  197366135.0   739604.0
# 104873  OWID_WRL       NaN    World 2021-07-31  197825365.0   459230.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 104869          554161.143     4177716.0      9976.0             8489.571
# 104870          564769.571     4187379.0      9663.0             8617.571
# 104871          578040.714     4198939.0     11560.0             9001.143
# 104872          585279.714     4208547.0      9608.0             9268.571
# 104873          583187.000     4216780.0      8233.0             9128.714
#
#         ...  extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# 104869  ...             10.0                 233.07                 8.51
# 104870  ...             10.0                 233.07                 8.51
# 104871  ...             10.0                 233.07                 8.51
# 104872  ...             10.0                 233.07                 8.51
# 104873  ...             10.0                 233.07                 8.51
#
#         female_smokers  male_smokers  handwashing_facilities  \
# 104869           6.434        34.635                   60.13
# 104870           6.434        34.635                   60.13
# 104871           6.434        34.635                   60.13
# 104872           6.434        34.635                   60.13
# 104873           6.434        34.635                   60.13
#
#         hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 104869                       2.705            72.58                    0.737
# 104870                       2.705            72.58                    0.737
# 104871                       2.705            72.58                    0.737
# 104872                       2.705            72.58                    0.737
# 104873                       2.705            72.58                    0.737
#
#         excess_mortality
# 104869               NaN
# 104870               NaN
# 104871               NaN
# 104872               NaN
# 104873               NaN
#
# [5 rows x 60 columns]

# %% [markdown]
# ### 主要国の定義

# %%
countries = pd.DataFrame([
    ("Japan",""),
    ("United States",""),
    ("India",""),
    ("Spain",""),
    ("Brazil",""),
#    ("Israel",""),
    ("United Kingdom",""),
#    ("France","20210425"),
    ("Russia",""),
    ("Colombia",""),
    ("South Africa",""),
    ("Iran",""),
#    ("Ecuador",""),
],columns=["country","text_disp_date"])
countries
# Out:
#           country text_disp_date
# 0           Japan
# 1   United States
# 2           India
# 3           Spain
# 4          Brazil
# 5  United Kingdom
# 6          Russia
# 7        Colombia
# 8    South Africa
# 9            Iran

# %%
# 東Asia 主要国
e_asia_c = pd.DataFrame([
    ("Japan",""),
    ("China",""),
    ("Taiwan",""),
    ("South Korea",""),
    ("Indonesia",""),
    ("Philippines","20210618"),
    ("Vietnam",""),
    ("Myanmar",""),
],columns=["country","text_disp_date"])
e_asia_c
# Out:
#        country text_disp_date
# 0        Japan
# 1        China
# 2       Taiwan
# 3  South Korea
# 4    Indonesia
# 5  Philippines       20210618
# 6      Vietnam
# 7      Myanmar

# %%
c_trans = pd.merge(countries, df, left_on="country", right_on="location",how="inner")
c_trans.head()
# Out:
#   country text_disp_date iso_code continent location       date  total_cases  \
# 0   Japan                     JPN      Asia    Japan 2020-01-22          2.0
# 1   Japan                     JPN      Asia    Japan 2020-01-23          2.0
# 2   Japan                     JPN      Asia    Japan 2020-01-24          2.0
# 3   Japan                     JPN      Asia    Japan 2020-01-25          2.0
# 4   Japan                     JPN      Asia    Japan 2020-01-26          4.0
#
#    new_cases  new_cases_smoothed  total_deaths  ...  extreme_poverty  \
# 0        NaN                 NaN           NaN  ...              NaN
# 1        0.0                 NaN           NaN  ...              NaN
# 2        0.0                 NaN           NaN  ...              NaN
# 3        0.0                 NaN           NaN  ...              NaN
# 4        2.0                 NaN           NaN  ...              NaN
#
#    cardiovasc_death_rate  diabetes_prevalence  female_smokers  male_smokers  \
# 0                  79.37                 5.72            11.2          33.7
# 1                  79.37                 5.72            11.2          33.7
# 2                  79.37                 5.72            11.2          33.7
# 3                  79.37                 5.72            11.2          33.7
# 4                  79.37                 5.72            11.2          33.7
#
#    handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 0                     NaN                       13.05            84.63
# 1                     NaN                       13.05            84.63
# 2                     NaN                       13.05            84.63
# 3                     NaN                       13.05            84.63
# 4                     NaN                       13.05            84.63
#
#    human_development_index  excess_mortality
# 0                    0.919               NaN
# 1                    0.919               NaN
# 2                    0.919               NaN
# 3                    0.919               NaN
# 4                    0.919               NaN
#
# [5 rows x 62 columns]

# %%
c_trans.location.unique()
# Out:
# array(['Japan', 'United States', 'India', 'Spain', 'Brazil',
#        'United Kingdom', 'Russia', 'Colombia', 'South Africa', 'Iran'],
#       dtype=object)

# %%
c_trans.loc[c_trans.date==latest_date_str][["country","date","total_deaths","total_deaths_per_million"]].sort_values("total_deaths_per_million",ascending=False)
# Out:
#              country       date  total_deaths  total_deaths_per_million
# 2731          Brazil 2021-07-31      556370.0                  2617.480
# 4340        Colombia 2021-07-31      120723.0                  2372.566
# 3279  United Kingdom 2021-07-31      129949.0                  1914.224
# 1113   United States 2021-07-31      613157.0                  1852.423
# 2209           Spain 2021-07-31       81486.0                  1742.838
# 4881    South Africa 2021-07-31       72013.0                  1214.207
# 5410            Iran 2021-07-31       90630.0                  1079.019
# 3827          Russia 2021-07-31      155952.0                  1068.644
# 1662           India 2021-07-31      423810.0                   307.108
# 556            Japan 2021-07-31       15206.0                   120.228

# %%
e_a_trans = pd.merge(e_asia_c, df, left_on="country", right_on="location",how="inner")
e_a_trans
# Out:
#       country text_disp_date iso_code continent location       date  \
# 0       Japan                     JPN      Asia    Japan 2020-01-22
# 1       Japan                     JPN      Asia    Japan 2020-01-23
# 2       Japan                     JPN      Asia    Japan 2020-01-24
# 3       Japan                     JPN      Asia    Japan 2020-01-25
# 4       Japan                     JPN      Asia    Japan 2020-01-26
# ...       ...            ...      ...       ...      ...        ...
# 4344  Myanmar                     MMR      Asia  Myanmar 2021-07-27
# 4345  Myanmar                     MMR      Asia  Myanmar 2021-07-28
# 4346  Myanmar                     MMR      Asia  Myanmar 2021-07-29
# 4347  Myanmar                     MMR      Asia  Myanmar 2021-07-30
# 4348  Myanmar                     MMR      Asia  Myanmar 2021-07-31
#
#       total_cases  new_cases  new_cases_smoothed  total_deaths  ...  \
# 0             2.0        NaN                 NaN           NaN  ...
# 1             2.0        0.0                 NaN           NaN  ...
# 2             2.0        0.0                 NaN           NaN  ...
# 3             2.0        0.0                 NaN           NaN  ...
# 4             4.0        2.0                 NaN           NaN  ...
# ...           ...        ...                 ...           ...  ...
# 4344     279119.0     4964.0            5507.000        7845.0  ...
# 4345     284099.0     4980.0            5348.000        8210.0  ...
# 4346     289333.0     5234.0            5138.429        8552.0  ...
# 4347     294460.0     5127.0            5084.286        8942.0  ...
# 4348     299185.0     4725.0            4951.143        9334.0  ...
#
#       extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# 0                 NaN                 79.370                 5.72
# 1                 NaN                 79.370                 5.72
# 2                 NaN                 79.370                 5.72
# 3                 NaN                 79.370                 5.72
# 4                 NaN                 79.370                 5.72
# ...               ...                    ...                  ...
# 4344              6.4                202.104                 4.61
# 4345              6.4                202.104                 4.61
# 4346              6.4                202.104                 4.61
# 4347              6.4                202.104                 4.61
# 4348              6.4                202.104                 4.61
#
#       female_smokers  male_smokers  handwashing_facilities  \
# 0               11.2          33.7                     NaN
# 1               11.2          33.7                     NaN
# 2               11.2          33.7                     NaN
# 3               11.2          33.7                     NaN
# 4               11.2          33.7                     NaN
# ...              ...           ...                     ...
# 4344             6.3          35.2                  79.287
# 4345             6.3          35.2                  79.287
# 4346             6.3          35.2                  79.287
# 4347             6.3          35.2                  79.287
# 4348             6.3          35.2                  79.287
#
#       hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                          13.05            84.63                    0.919
# 1                          13.05            84.63                    0.919
# 2                          13.05            84.63                    0.919
# 3                          13.05            84.63                    0.919
# 4                          13.05            84.63                    0.919
# ...                          ...              ...                      ...
# 4344                        0.90            67.13                    0.583
# 4345                        0.90            67.13                    0.583
# 4346                        0.90            67.13                    0.583
# 4347                        0.90            67.13                    0.583
# 4348                        0.90            67.13                    0.583
#
#       excess_mortality
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# ...                ...
# 4344               NaN
# 4345               NaN
# 4346               NaN
# 4347               NaN
# 4348               NaN
#
# [4349 rows x 62 columns]

# %%
e_a_trans.location.unique()
# Out:
# array(['Japan', 'China', 'Taiwan', 'South Korea', 'Indonesia',
#        'Philippines', 'Vietnam', 'Myanmar'], dtype=object)

# %% [markdown]
# ## 今日の新規感染者数

# %%
#c_df_latest = df.loc[(df.date==pd.to_datetime(latest_date_str)-datetime.timedelta(days=1)) & (df.iso_code.str.len()==3)]
c_df_latest = df.loc[(df.date==pd.to_datetime(latest_date_str)) & (df.iso_code.str.len()==3)]

c_df_latest
# Out:
#        iso_code      continent     location       date  total_cases  \
# 523         AFG           Asia  Afghanistan 2021-07-31     146523.0
# 1581        ALB         Europe      Albania 2021-07-31     133081.0
# 2104        DZA         Africa      Algeria 2021-07-31     171392.0
# 2621        AND         Europe      Andorra 2021-07-31      14678.0
# 3120        AGO         Africa       Angola 2021-07-31      42777.0
# ...         ...            ...          ...        ...          ...
# 103640      VEN  South America    Venezuela 2021-07-31     305766.0
# 104196      VNM           Asia      Vietnam 2021-07-31     150060.0
# 105351      YEM           Asia        Yemen 2021-07-31       7061.0
# 105852      ZMB         Africa       Zambia 2021-07-31     195816.0
# 106351      ZWE         Africa     Zimbabwe 2021-07-31     108860.0
#
#         new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 523           0.0             440.571        6677.0         0.0
# 1581         45.0              32.571        2457.0         0.0
# 2104       1203.0            1503.429        4254.0        35.0
# 2621          0.0              25.714         128.0         0.0
# 3120        131.0             148.714        1011.0         3.0
# ...           ...                 ...           ...         ...
# 103640     1040.0             994.571        3591.0        15.0
# 104196     8938.0            7878.143        1306.0       145.0
# 105351        3.0               7.571        1375.0         0.0
# 105852      720.0             612.714        3389.0        13.0
# 106351     1370.0            1654.714        3532.0        42.0
#
#         new_deaths_smoothed  ...  extreme_poverty  cardiovasc_death_rate  \
# 523                  45.714  ...              NaN                597.029
# 1581                  0.143  ...              1.1                304.195
# 2104                 30.286  ...              0.5                278.364
# 2621                  0.143  ...              NaN                109.135
# 3120                  4.143  ...              NaN                276.045
# ...                     ...  ...              ...                    ...
# 103640               16.571  ...              NaN                204.850
# 104196              133.714  ...              2.0                245.465
# 105351                0.286  ...             18.8                495.003
# 105852               19.857  ...             57.5                234.499
# 106351               68.857  ...             21.4                307.846
#
#         diabetes_prevalence  female_smokers  male_smokers  \
# 523                    9.59             NaN           NaN
# 1581                  10.08             7.1          51.2
# 2104                   6.73             0.7          30.4
# 2621                   7.97            29.0          37.8
# 3120                   3.94             NaN           NaN
# ...                     ...             ...           ...
# 103640                 6.47             NaN           NaN
# 104196                 6.00             1.0          45.9
# 105351                 5.35             7.6          29.2
# 105852                 3.94             3.1          24.7
# 106351                 1.82             1.6          30.7
#
#         handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 523                     37.746                        0.50            64.83
# 1581                       NaN                        2.89            78.57
# 2104                    83.741                        1.90            76.88
# 2621                       NaN                         NaN            83.73
# 3120                    26.664                         NaN            61.15
# ...                        ...                         ...              ...
# 103640                     NaN                        0.80            72.06
# 104196                  85.847                        2.60            75.40
# 105351                  49.542                        0.70            66.12
# 105852                  13.938                        2.00            63.89
# 106351                  36.791                        1.70            61.49
#
#         human_development_index  excess_mortality
# 523                       0.511               NaN
# 1581                      0.795               NaN
# 2104                      0.748               NaN
# 2621                      0.868               NaN
# 3120                      0.581               NaN
# ...                         ...               ...
# 103640                    0.711               NaN
# 104196                    0.704               NaN
# 105351                    0.470               NaN
# 105852                    0.584               NaN
# 106351                    0.571               NaN
#
# [191 rows x 60 columns]

# %%
c_df_latest.sum()
# Out:
# iso_code                                 AFGALBDZAANDAGOATGARGARMAUSAUTAZEBHSBHRBGDBRBB...
# continent                                AsiaEuropeAfricaEuropeAfricaNorth AmericaSouth...
# location                                 AfghanistanAlbaniaAlgeriaAndorraAngolaAntigua ...
# total_cases                                                                    197716033.0
# new_cases                                                                         459090.0
# new_cases_smoothed                                                              583111.569
# total_deaths                                                                     4214496.0
# new_deaths                                                                          8233.0
# new_deaths_smoothed                                                               9128.714
# total_cases_per_million                                                        7453275.048
# new_cases_per_million                                                            16500.788
# new_cases_smoothed_per_million                                                   20940.797
# total_deaths_per_million                                                        131632.918
# new_deaths_per_million                                                             215.015
# new_deaths_smoothed_per_million                                                    268.038
# reproduction_rate                                                                      0.0
# icu_patients                                                                           0.0
# icu_patients_per_million                                                               0.0
# hosp_patients                                                                          0.0
# hosp_patients_per_million                                                              0.0
# weekly_icu_admissions                                                                  0.0
# weekly_icu_admissions_per_million                                                      0.0
# weekly_hosp_admissions                                                                 0.0
# weekly_hosp_admissions_per_million                                                     0.0
# new_tests                                                                              0.0
# total_tests                                                                            0.0
# total_tests_per_thousand                                                               0.0
# new_tests_per_thousand                                                                 0.0
# new_tests_smoothed                                                                     0.0
# new_tests_smoothed_per_thousand                                                        0.0
# positive_rate                                                                          0.0
# tests_per_case                                                                         0.0
# tests_units                                                                              0
# total_vaccinations                                                                     0.0
# people_vaccinated                                                                      0.0
# people_fully_vaccinated                                                                0.0
# new_vaccinations                                                                       0.0
# new_vaccinations_smoothed                                                              0.0
# total_vaccinations_per_hundred                                                         0.0
# people_vaccinated_per_hundred                                                          0.0
# people_fully_vaccinated_per_hundred                                                    0.0
# new_vaccinations_smoothed_per_million                                                  0.0
# stringency_index                                                                    225.47
# population                                                                    7754528051.0
# population_density                                                               63744.362
# median_age                                                                          5519.7
# aged_65_older                                                                     1551.039
# aged_70_older                                                                      986.319
# gdp_per_capita                                                                 3368457.295
# extreme_poverty                                                                     1731.0
# cardiovasc_death_rate                                                            48966.937
# diabetes_prevalence                                                                1503.37
# female_smokers                                                                      1517.2
# male_smokers                                                                        4633.3
# handwashing_facilities                                                            4715.599
# hospital_beds_per_thousand                                                         500.078
# life_expectancy                                                                   13915.57
# human_development_index                                                            134.272
# excess_mortality                                                                       0.0
# dtype: object

# %% [markdown]
# ## 可視化

# %%
import matplotlib.pyplot as plt
#%matplotlib notebook
# %matplotlib inline

# %%
min_date = pd.to_datetime("2021-05-01")

# %%
world_df["case_rolling7ave"] = world_df.new_cases.rolling(7).mean()
world_df[["new_cases_smoothed","case_rolling7ave"]]
# Out:
#         new_cases_smoothed  case_rolling7ave
# 104317                 NaN               NaN
# 104318                 NaN               NaN
# 104319                 NaN               NaN
# 104320                 NaN               NaN
# 104321                 NaN               NaN
# ...                    ...               ...
# 104869          554161.143     554161.142857
# 104870          564769.571     564769.571429
# 104871          578040.714     578040.714286
# 104872          585279.714     585279.714286
# 104873          583187.000     583187.000000
#
# [557 rows x 2 columns]

# %%
fig=plt.figure(figsize=(20,12))
plt.subplot(2,2,1) # (rows, columns, panel number)
plt.title("Daily new confirmed COVID-19 cases in the world")
plt.bar(world_df.date,world_df.new_cases,label="New cases")
plt.plot_date(world_df["date"],world_df["new_cases_smoothed"],label="rolling 7-day average", fmt="-", color="orange")
#plt.xticks(rotation=70)
plt.ylabel("people")
plt.grid(axis="y")
plt.legend()

plt.subplot(2,2,2) # (rows, columns, panel number)
plt.title("Daily new confirmed COVID-19 cases in the world(Recent)")
chart_data = world_df[world_df.date >= min_date]
plt.bar(chart_data["date"],chart_data["new_cases"],label="New cases")
plt.plot_date(chart_data["date"],chart_data["new_cases_smoothed"],label="rolling 7-day average", fmt="-", color="orange")
#plt.xticks(rotation=70)
plt.grid(axis="y")
plt.legend()

plt.subplot(2,2,3) # (rows, columns, panel number)
plt.title("Daily new deaths in the world")
plt.bar(world_df.date,world_df.new_deaths,label="New deaths")
plt.plot_date(world_df["date"],world_df["new_deaths_smoothed"],label="rolling 7-day average", fmt="-", color="orange")
#plt.xticks(rotation=70)
plt.ylabel("people")
plt.grid(axis="y")
plt.legend()

plt.subplot(2,2,4) # (rows, columns, panel number)
plt.title("Daily new deaths in the world(Recent)")
chart_data = world_df[world_df.date >= min_date]
plt.bar(chart_data["date"],chart_data["new_deaths"],label="New deaths")
plt.plot_date(chart_data["date"],chart_data["new_deaths_smoothed"],label="rolling 7-day average", fmt="-", color="orange")
#plt.xticks(rotation=70)
plt.grid(axis="y")
plt.legend()

fig.text(0,1,"Latest: {}".format(latest_date_str),ha="left",va="top")
fig.text(0,0
         ,"*Data Source : COVID-19 Dataset by Our World in Data",
        ha="left",va="bottom")

fig.tight_layout()

# %%
fig.savefig("out/covid-owid-global-daily.png")

# %% [markdown]
# ### 国別

# %% [markdown]
# #### 人口100万人当たりの新規感染者数（直近）

# %%
"""
#min_date = pd.to_datetime("2021-05-01")
# 主要国 新規感染者
chart_data = c_trans[c_trans.date >= min_date]
dates = chart_data["date"].unique()
print(len(dates))
print(dates.max())
for i,cr in countries.iterrows():
    c = cr["country"]
    dates = chart_data.loc[chart_data["location"]==c]["date"]
    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else latest_date_str
    print(len(chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"]))
    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"],label=c, fmt="-")
    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_cases_smoothed_per_million"],c
            ,fontsize=8,va="center")
"""
# Out:
# '\n#min_date = pd.to_datetime("2021-05-01")\n# 主要国 新規感染者\nchart_data = c_trans[c_trans.date >= min_date]\ndates = chart_data["date"].unique()\nprint(len(dates))\nprint(dates.max())\nfor i,cr in countries.iterrows():\n    c = cr["country"]\n    dates = chart_data.loc[chart_data["location"]==c]["date"]\n    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else latest_date_str\n    print(len(chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"]))\n    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"],label=c, fmt="-")\n    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_cases_smoothed_per_million"],c\n            ,fontsize=8,va="center")\n'

# %%
"""
fig=plt.figure(figsize=(14,10))
min_date = pd.to_datetime("2021-03-01")
# 主要国 新規感染者
plt.subplot(2,2,1) # (rows, columns, panel number)
plt.title("Daily new confirmed COVID-19 cases\n per million population in major countries\n(rolling 7day ave.)")
plt.grid()
plt.xticks(rotation=70)
chart_data = c_trans[c_trans.date >= min_date]
dates = chart_data["date"].unique()
for i,cr in countries.iterrows():
    c = cr["country"]
    dates = chart_data.loc[chart_data["location"]==c]["date"]
    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else dates.max()
    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"],label=c, fmt="-")
    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_cases_smoothed_per_million"],c
            ,fontsize=8,va="center")
plt.legend(bbox_to_anchor=(0, 1),loc='upper left', fontsize=9)
"""
# Out:
# '\nfig=plt.figure(figsize=(14,10))\nmin_date = pd.to_datetime("2021-03-01")\n# 主要国 新規感染者\nplt.subplot(2,2,1) # (rows, columns, panel number)\nplt.title("Daily new confirmed COVID-19 cases\n per million population in major countries\n(rolling 7day ave.)")\nplt.grid()\nplt.xticks(rotation=70)\nchart_data = c_trans[c_trans.date >= min_date]\ndates = chart_data["date"].unique()\nfor i,cr in countries.iterrows():\n    c = cr["country"]\n    dates = chart_data.loc[chart_data["location"]==c]["date"]\n    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else dates.max()\n    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"],label=c, fmt="-")\n    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_cases_smoothed_per_million"],c\n            ,fontsize=8,va="center")\nplt.legend(bbox_to_anchor=(0, 1),loc=\'upper left\', fontsize=9)\n'

# %%
fig=plt.figure(figsize=(20,14))
# 主要国 新規感染者
plt.subplot(2,2,1) # (rows, columns, panel number)
plt.title("Daily new confirmed COVID-19 cases\n per million population in major countries\n(rolling 7day ave.)")
plt.grid()
plt.xticks(rotation=45)
chart_data = c_trans[c_trans.date >= min_date]
for i,cr in countries.iterrows():
    c = cr["country"]
    dates = chart_data.loc[chart_data["location"]==c]["date"]
    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else dates.max()
    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"],label=c, fmt="-")
    text_y = chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_cases_smoothed_per_million"]
#    print(text_y)
    print(c,text_disp_date,text_y)
#    plt.text(text_disp_date,text_y,c,fontsize=10,va="center")
    plt.text(text_disp_date,text_y,c,va="center")
plt.legend(bbox_to_anchor=(0, 1),loc='upper left')

# 主要国 死者
plt.subplot(2,2,2) # (rows, columns, panel number)
plt.title("Daily new deaths in major countries(rolling 7day ave.)")
plt.grid()
plt.xticks(rotation=45)
chart_data = c_trans[c_trans.date >= min_date]
for i,cr in countries.iterrows():
    c = cr["country"]
    dates = chart_data.loc[chart_data["location"]==c]["date"]
    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else dates.max()
    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_deaths_smoothed"],label=c, fmt="-")
    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_deaths_smoothed"],c
            ,va="center")
plt.legend(bbox_to_anchor=(0, 1),loc='upper left')

plt.subplot(2,2,3) # (rows, columns, panel number)
plt.grid()
plt.xticks(rotation=45)
plt.title("Daily new confirmed COVID-19 cases\n per million population in Eastern Asia\n(rolling 7day ave.)")
chart_data = e_a_trans[e_a_trans.date >= min_date]
for i,cr in e_asia_c.iterrows():
    c = cr["country"]
    dates = chart_data.loc[chart_data["location"]==c]["date"]
    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else dates.max()
    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"],label=c, fmt="-")
    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_cases_smoothed_per_million"],c
             ,va="center")
plt.legend(bbox_to_anchor=(0, 1),loc='upper left')

plt.subplot(2,2,4) # (rows, columns, panel number)
plt.grid()
plt.xticks(rotation=45)
plt.title("Daily new deaths in Eastern Asia(rolling 7day ave.)")
chart_data = e_a_trans[e_a_trans.date >= min_date]
for i,cr in e_asia_c.iterrows():
    c = cr["country"]
    dates = chart_data.loc[chart_data["location"]==c]["date"]
    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else dates.max()
    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_deaths_smoothed"],label=c, fmt="-")
    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_deaths_smoothed"],c
             ,va="center")
plt.legend(bbox_to_anchor=(0, 1),loc='upper left')

fig.text(0,0.98,"Latest: {}".format(latest_date_str),ha="left",va="top")
fig.text(0,0
         ,"*Data Source : COVID-19 Dataset by Our World in Data",
        ha="left",va="bottom")
fig.tight_layout()
"""
"""
# Out:
# Japan 2021-07-31 00:00:00 556    68.599
# Name: new_cases_smoothed_per_million, dtype: float64
# United States 2021-07-31 00:00:00 1113    237.461
# Name: new_cases_smoothed_per_million, dtype: float64
# India 2021-07-31 00:00:00 1662    25.061
# Name: new_cases_smoothed_per_million, dtype: float64
# Spain 2021-07-31 00:00:00 2209    509.085
# Name: new_cases_smoothed_per_million, dtype: float64
# Brazil 2021-07-31 00:00:00 2731    166.22
# Name: new_cases_smoothed_per_million, dtype: float64
# United Kingdom 2021-07-31 00:00:00 3279    397.639
# Name: new_cases_smoothed_per_million, dtype: float64
# Russia 2021-07-31 00:00:00 3827    156.187
# Name: new_cases_smoothed_per_million, dtype: float64
# Colombia 2021-07-31 00:00:00 4340    192.38
# Name: new_cases_smoothed_per_million, dtype: float64
# South Africa 2021-07-31 00:00:00 4881    191.128
# Name: new_cases_smoothed_per_million, dtype: float64
# Iran 2021-07-31 00:00:00 5410    351.598
# Name: new_cases_smoothed_per_million, dtype: float64
# '\n'

# %%
fig.savefig("out/covid-owid-countries-daily.png")

# %% [markdown]
# ### 新規感染者数

# %%
fig = plt.figure(figsize=(12,14))

plt.subplot(2,2,1) # (rows, columns, panel number)
plt.title("New confirmed COVID-19 cases worst 50")
plt.yticks(fontsize=9)
plt.xlabel("people")
chart_data = c_df_latest.sort_values("new_cases",ascending=False).head(50).sort_values("new_cases",ascending=True)
plt.barh(chart_data["location"],chart_data["new_cases"],label="new cases a day")
plt.grid(axis="x")
mean = int(c_df_latest.new_cases.mean())
plt.plot([mean,mean],[0,50], 'k--', lw=0.5)
plt.text(mean,50,"Mean:{}".format(mean),ha="center",fontsize=9)
plt.legend()

plt.subplot(2,2,2) # (rows, columns, panel number)
plt.title("New confirmed COVID-19 cases per million worst 50")
plt.yticks(fontsize=9)
plt.xlabel("people")
chart_data = c_df_latest.sort_values("new_cases_per_million",ascending=False).head(50).sort_values("new_cases_per_million",ascending=True)
plt.barh(chart_data["location"],chart_data["new_cases_per_million"],label="new cases a day per million")
plt.grid(axis="x")
mean = int(chart_data.new_cases_per_million.mean())
plt.plot([mean,mean],[0,50], 'k--', lw=0.5)
plt.text(mean,50,"Mean:{}".format(mean),ha="center",fontsize=9)
plt.legend()

fig.text(0,0.98,"Latest: {}".format(latest_date_str),fontsize=9,ha="left",va="top")
fig.text(0,0
         ,"*Data Source : COVID-19 Dataset by Our World in Data",
        fontsize=8,ha="left",va="bottom")

plt.subplot(2,2,3) # (rows, columns, panel number)
plt.title("New deaths worst 50")
plt.yticks(fontsize=9)
plt.xlabel("people")
chart_data = c_df_latest.sort_values("new_deaths",ascending=False).head(50).sort_values("new_deaths",ascending=True)
plt.barh(chart_data["location"],chart_data["new_deaths"],label="new deaths a day")
plt.grid(axis="x")
mean = int(c_df_latest.new_deaths.mean())
plt.plot([mean,mean],[0,50], 'k--', lw=0.5)
plt.text(mean,50,"Mean:{}".format(mean),ha="center",fontsize=9)
plt.legend()

plt.subplot(2,2,4) # (rows, columns, panel number)
plt.title("Total deaths per population worst 50")
plt.yticks(fontsize=9)
plt.xlabel("%")
chart_data = c_df_latest.copy()
chart_data["total_deaths_per_poputaion"] = chart_data.total_deaths / chart_data.population * 100
chart_data = chart_data.sort_values("total_deaths_per_poputaion",ascending=False).head(50).sort_values("total_deaths_per_poputaion",ascending=True)
plt.barh(chart_data["location"],chart_data["total_deaths_per_poputaion"],label="total deaths per population")
plt.grid(axis="x")
mean = round(chart_data.total_deaths_per_poputaion.mean(),2)
plt.plot([mean,mean],[0,50], 'k--', lw=0.5)
plt.text(mean,50,"Mean:{}".format(mean),ha="center",fontsize=9)
plt.legend()


fig.tight_layout()

# %%
fig.savefig("out/covid-owid-global-latest-top.png")

# %%
a_df = df.loc[df.location=="Japan"]
c_df = df.loc[(df.date==pd.to_datetime("2021-07-27")) & (df.iso_code.str.len()==3)]

# %%
a_df.tail(10)
# Out:
#       iso_code continent location       date  total_cases  new_cases  \
# 49459      JPN      Asia    Japan 2021-07-22     858503.0     5366.0
# 49460      JPN      Asia    Japan 2021-07-23     862585.0     4082.0
# 49461      JPN      Asia    Japan 2021-07-24     866325.0     3740.0
# 49462      JPN      Asia    Japan 2021-07-25     871360.0     5035.0
# 49463      JPN      Asia    Japan 2021-07-26     876059.0     4699.0
# 49464      JPN      Asia    Japan 2021-07-27     883767.0     7708.0
# 49465      JPN      Asia    Japan 2021-07-28     893442.0     9675.0
# 49466      JPN      Asia    Japan 2021-07-29     904126.0    10684.0
# 49467      JPN      Asia    Japan 2021-07-30     914718.0    10592.0
# 49468      JPN      Asia    Japan 2021-07-31     927058.0    12340.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 49459            3840.286       15052.0         6.0               12.429  ...
# 49460            3936.571       15059.0         7.0               11.857  ...
# 49461            3910.286       15068.0         9.0               11.143  ...
# 49462            4191.714       15072.0         4.0               11.286  ...
# 49463            4524.714       15084.0        12.0               11.143  ...
# 49464            5077.857       15096.0        12.0               10.000  ...
# 49465            5757.857       15174.0        78.0               18.286  ...
# 49466            6517.571       15188.0        14.0               19.429  ...
# 49467            7447.571       15197.0         9.0               19.714  ...
# 49468            8676.143       15206.0         9.0               19.714  ...
#
#        extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# 49459              NaN                  79.37                 5.72
# 49460              NaN                  79.37                 5.72
# 49461              NaN                  79.37                 5.72
# 49462              NaN                  79.37                 5.72
# 49463              NaN                  79.37                 5.72
# 49464              NaN                  79.37                 5.72
# 49465              NaN                  79.37                 5.72
# 49466              NaN                  79.37                 5.72
# 49467              NaN                  79.37                 5.72
# 49468              NaN                  79.37                 5.72
#
#        female_smokers  male_smokers  handwashing_facilities  \
# 49459            11.2          33.7                     NaN
# 49460            11.2          33.7                     NaN
# 49461            11.2          33.7                     NaN
# 49462            11.2          33.7                     NaN
# 49463            11.2          33.7                     NaN
# 49464            11.2          33.7                     NaN
# 49465            11.2          33.7                     NaN
# 49466            11.2          33.7                     NaN
# 49467            11.2          33.7                     NaN
# 49468            11.2          33.7                     NaN
#
#        hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 49459                       13.05            84.63                    0.919
# 49460                       13.05            84.63                    0.919
# 49461                       13.05            84.63                    0.919
# 49462                       13.05            84.63                    0.919
# 49463                       13.05            84.63                    0.919
# 49464                       13.05            84.63                    0.919
# 49465                       13.05            84.63                    0.919
# 49466                       13.05            84.63                    0.919
# 49467                       13.05            84.63                    0.919
# 49468                       13.05            84.63                    0.919
#
#        excess_mortality
# 49459               NaN
# 49460               NaN
# 49461               NaN
# 49462               NaN
# 49463               NaN
# 49464               NaN
# 49465               NaN
# 49466               NaN
# 49467               NaN
# 49468               NaN
#
# [10 rows x 60 columns]

# %%
c_df.sort_values("new_deaths",ascending=False).head(50)
# Out:
#        iso_code      continent        location       date  total_cases  \
# 45019       IDN           Asia       Indonesia 2021-07-27    3239936.0
# 14020       BRA  South America          Brazil 2021-07-27   19749073.0
# 79498       RUS         Europe          Russia 2021-07-27    6094379.0
# 44502       IND           Asia           India 2021-07-27   31484605.0
# 62433       MEX  North America          Mexico 2021-07-27    2771846.0
# 101344      USA  North America   United States 2021-07-27   34603919.0
# 46089       IRN           Asia            Iran 2021-07-27    3758197.0
# 66362       MMR           Asia         Myanmar 2021-07-27     279119.0
# 88446       ZAF         Africa    South Africa 2021-07-27    2391223.0
# 21035       COL  South America        Colombia 2021-07-27    4747775.0
# 8706        BGD           Asia      Bangladesh 2021-07-27    1194752.0
# 4370        ARG  South America       Argentina 2021-07-27    4875927.0
# 59025       MYS           Asia        Malaysia 2021-07-27    1044071.0
# 97921       TUN         Africa         Tunisia 2021-07-27     575002.0
# 100787      GBR         Europe  United Kingdom 2021-07-27    5771732.0
# 95790       THA           Asia        Thailand 2021-07-27     526828.0
# 106347      ZWE         Africa        Zimbabwe 2021-07-27     101711.0
# 76265       PER  South America            Peru 2021-07-27    2106371.0
# 50620       KAZ           Asia      Kazakhstan 2021-07-27     609646.0
# 24105       CUB  North America            Cuba 2021-07-27     349055.0
# 76814       PHL           Asia     Philippines 2021-07-27    1562420.0
# 46613       IRQ           Asia            Iraq 2021-07-27    1577013.0
# 12494       BOL  South America         Bolivia 2021-07-27     470024.0
# 39658       GTM  North America       Guatemala 2021-07-27     355223.0
# 42360       HND  North America        Honduras 2021-07-27     291687.0
# 75687       PRY  South America        Paraguay 2021-07-27     450494.0
# 90560       ESP         Europe           Spain 2021-07-27    4368453.0
# 98429       TUR           Asia          Turkey 2021-07-27    5638178.0
# 91112       LKA           Asia       Sri Lanka 2021-07-27     299892.0
# 73652       PAK           Asia        Pakistan 2021-07-27    1015827.0
# 22567       CRI  North America      Costa Rica 2021-07-27     402044.0
# 99689       UKR         Europe         Ukraine 2021-07-27    2327777.0
# 519         AFG           Asia     Afghanistan 2021-07-27     145008.0
# 66867       NAM         Africa         Namibia 2021-07-27     117293.0
# 65870       MOZ         Africa      Mozambique 2021-07-27     113426.0
# 19965       CHL  South America           Chile 2021-07-27    1611090.0
# 34953       FRA         Europe          France 2021-07-27    6088930.0
# 65373       MAR         Africa         Morocco 2021-07-27     588448.0
# 58471       MWI         Africa          Malawi 2021-07-27      49752.0
# 2100        DZA         Africa         Algeria 2021-07-27     165204.0
# 48399       ITA         Europe           Italy 2021-07-27    4325046.0
# 55749       LBY         Africa           Libya 2021-07-27     240309.0
# 105848      ZMB         Africa          Zambia 2021-07-27     192956.0
# 67532       NPL           Asia           Nepal 2021-07-27     685673.0
# 37213       DEU         Europe         Germany 2021-07-27    3766501.0
# 16654       KHM           Asia        Cambodia 2021-07-27      74386.0
# 36658       GEO           Asia         Georgia 2021-07-27     407689.0
# 73129       OMN           Asia            Oman 2021-07-27     295017.0
# 103636      VEN  South America       Venezuela 2021-07-27     301979.0
# 83895       SEN         Africa         Senegal 2021-07-27      58523.0
#
#         new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 45019     45203.0           41411.143       86835.0      2069.0
# 14020     41411.0           47090.857      551835.0      1333.0
# 79498     22486.0           23207.714      152836.0       767.0
# 44502     43654.0           38324.000      422022.0       640.0
# 62433     17408.0           13364.143      239079.0       484.0
# 101344    70740.0           61306.429      611414.0       462.0
# 46089     34951.0           26007.000       89479.0       357.0
# 66362      4964.0            5507.000        7845.0       338.0
# 88446      7733.0           11427.286       70338.0       320.0
# 21035     11426.0           11289.286      119482.0       300.0
# 8706      14925.0            9409.000       19779.0       258.0
# 4370      16757.0           13101.143      104352.0       247.0
# 59025     16117.0           14881.714        8408.0       207.0
# 97921      1608.0            2870.143       18968.0       164.0
# 100787    23401.0           32728.143      129591.0       131.0
# 95790     14150.0           14336.143        4264.0       118.0
# 106347     1767.0            1899.429        3280.0       107.0
# 76265      1366.0            1479.714      196058.0        85.0
# 50620      7249.0            6639.000        5619.0        81.0
# 24105      7903.0            7800.857        2492.0        75.0
# 76814      7024.0            6359.571       27318.0        71.0
# 46613     12185.0            9499.429       18418.0        71.0
# 12494      1601.0             985.571       17716.0        65.0
# 39658      2639.0            2494.429       10176.0        64.0
# 42360      1240.0            1285.857        7713.0        63.0
# 75687       592.0             603.857       14759.0        58.0
# 90560     26399.0           25616.714       81323.0        55.0
# 98429     19761.0           13144.571       51048.0        51.0
# 91112      1711.0            1702.714        4195.0        48.0
# 73652      4119.0            2768.000       23133.0        46.0
# 22567      3436.0            1129.857        4987.0        46.0
# 99689      1227.0            1127.286       55420.0        39.0
# 519         723.0             370.571        6515.0        38.0
# 66867       329.0             550.714        2871.0        37.0
# 65870      1703.0            1631.000        1341.0        34.0
# 19965       745.0            1318.857       35151.0        32.0
# 34953     27128.0           19513.000      111883.0        32.0
# 65373      6971.0            3718.857        9638.0        27.0
# 58471       743.0             724.000        1540.0        27.0
# 2100       1544.0            1345.714        4112.0        25.0
# 48399      4516.0            4566.143      127995.0        24.0
# 55749      3348.0            1944.000        3422.0        24.0
# 105848      640.0             764.857        3316.0        21.0
# 67532      2726.0            2102.857        9758.0        20.0
# 37213      2060.0            1665.000       91592.0        19.0
# 16654       685.0             798.571        1324.0        19.0
# 36658      3666.0            2392.000        5731.0        17.0
# 73129       491.0             853.571        3788.0        17.0
# 103636     1060.0            1159.000        3524.0        15.0
# 83895       642.0             707.143        1300.0        14.0
#
#         new_deaths_smoothed  ...  extreme_poverty  cardiovasc_death_rate  \
# 45019              1519.286  ...              5.7                342.864
# 14020              1093.571  ...              3.4                177.961
# 79498               768.429  ...              0.1                431.297
# 44502               506.000  ...             21.2                282.280
# 62433               324.143  ...              2.5                152.783
# 101344              296.714  ...              1.2                151.089
# 46089               265.000  ...              0.2                270.308
# 66362               325.429  ...              6.4                202.104
# 88446               380.286  ...             18.9                200.380
# 21035               335.857  ...              4.5                124.240
# 8706                207.714  ...             14.8                298.003
# 4370                281.571  ...              0.6                191.032
# 59025               166.714  ...              0.1                260.942
# 97921               163.857  ...              2.0                318.991
# 100787               68.857  ...              0.2                122.137
# 95790               108.857  ...              0.1                109.861
# 106347               76.143  ...             21.4                307.846
# 76265               103.714  ...              3.5                 85.755
# 50620                79.571  ...              0.1                466.792
# 24105                67.571  ...              NaN                190.968
# 76814                67.714  ...              NaN                370.437
# 46613                66.714  ...              2.5                218.612
# 12494                34.429  ...              7.1                204.299
# 39658                35.571  ...              8.7                155.898
# 42360                29.429  ...             16.0                240.208
# 75687                52.143  ...              1.7                199.128
# 90560                25.000  ...              1.0                 99.403
# 98429                56.857  ...              0.2                171.285
# 91112                46.429  ...              0.7                197.093
# 73652                35.000  ...              4.0                423.031
# 22567                10.286  ...              1.3                137.973
# 99689                28.429  ...              0.1                539.849
# 519                  35.571  ...              NaN                597.029
# 66867                44.857  ...             13.4                243.811
# 65870                26.143  ...             62.9                329.942
# 19965                83.143  ...              1.3                127.993
# 34953                24.000  ...              NaN                 86.060
# 65373                21.714  ...              1.0                419.146
# 58471                25.286  ...             71.4                227.349
# 2100                 19.000  ...              0.5                278.364
# 48399                15.857  ...              2.0                113.151
# 55749                16.143  ...              NaN                341.862
# 105848               25.429  ...             57.5                234.499
# 67532                21.571  ...             15.0                260.797
# 37213                24.143  ...              NaN                156.139
# 16654                25.000  ...              NaN                270.892
# 36658                19.857  ...              4.2                496.218
# 73129                41.429  ...              NaN                266.342
# 103636               18.857  ...              NaN                204.850
# 83895                 9.143  ...             38.0                241.219
#
#         diabetes_prevalence  female_smokers  male_smokers  \
# 45019                  6.32             2.8          76.1
# 14020                  8.11            10.1          17.9
# 79498                  6.18            23.4          58.3
# 44502                 10.39             1.9          20.6
# 62433                 13.06             6.9          21.4
# 101344                10.79            19.1          24.6
# 46089                  9.59             0.8          21.1
# 66362                  4.61             6.3          35.2
# 88446                  5.52             8.1          33.2
# 21035                  7.44             4.7          13.5
# 8706                   8.38             1.0          44.7
# 4370                   5.50            16.2          27.7
# 59025                 16.74             1.0          42.4
# 97921                  8.52             1.1          65.8
# 100787                 4.28            20.0          24.7
# 95790                  7.04             1.9          38.8
# 106347                 1.82             1.6          30.7
# 76265                  5.95             4.8           NaN
# 50620                  7.11             7.0          43.1
# 24105                  8.27            17.1          53.3
# 76814                  7.07             7.8          40.8
# 46613                  8.83             NaN           NaN
# 12494                  6.89             NaN           NaN
# 39658                 10.18             NaN           NaN
# 42360                  7.21             2.0           NaN
# 75687                  8.27             5.0          21.6
# 90560                  7.17            27.4          31.4
# 98429                 12.13            14.1          41.1
# 91112                 10.68             0.3          27.0
# 73652                  8.35             2.8          36.7
# 22567                  8.78             6.4          17.4
# 99689                  7.11            13.5          47.4
# 519                    9.59             NaN           NaN
# 66867                  3.94             9.7          34.2
# 65870                  3.30             5.1          29.1
# 19965                  8.46            34.2          41.5
# 34953                  4.77            30.1          35.6
# 65373                  7.14             0.8          47.1
# 58471                  3.94             4.4          24.7
# 2100                   6.73             0.7          30.4
# 48399                  4.78            19.8          27.8
# 55749                 10.43             NaN           NaN
# 105848                 3.94             3.1          24.7
# 67532                  7.26             9.5          37.8
# 37213                  8.31            28.2          33.1
# 16654                  4.00             2.0          33.7
# 36658                  7.11             5.3          55.5
# 73129                 12.61             0.5          15.6
# 103636                 6.47             NaN           NaN
# 83895                  2.42             0.4          16.6
#
#         handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 45019                   64.204                        1.04            71.72
# 14020                      NaN                        2.20            75.88
# 79498                      NaN                        8.05            72.58
# 44502                   59.550                        0.53            69.66
# 62433                   87.847                        1.38            75.05
# 101344                     NaN                        2.77            78.86
# 46089                      NaN                        1.50            76.68
# 66362                   79.287                        0.90            67.13
# 88446                   43.993                        2.32            64.13
# 21035                   65.386                        1.71            77.29
# 8706                    34.808                        0.80            72.59
# 4370                       NaN                        5.00            76.67
# 59025                      NaN                        1.90            76.16
# 97921                   78.687                        2.30            76.70
# 100787                     NaN                        2.54            81.32
# 95790                   90.670                        2.10            77.15
# 106347                  36.791                        1.70            61.49
# 76265                      NaN                        1.60            76.74
# 50620                   98.999                        6.70            73.60
# 24105                   85.198                        5.20            78.80
# 76814                   78.463                        1.00            71.23
# 46613                   94.576                        1.40            70.60
# 12494                   25.383                        1.10            71.51
# 39658                   76.665                        0.60            74.30
# 42360                   84.169                        0.70            75.27
# 75687                   79.602                        1.30            74.25
# 90560                      NaN                        2.97            83.56
# 98429                      NaN                        2.81            77.69
# 91112                      NaN                        3.60            76.98
# 73652                   59.607                        0.60            67.27
# 22567                   83.841                        1.13            80.28
# 99689                      NaN                        8.80            72.06
# 519                     37.746                        0.50            64.83
# 66867                   44.600                         NaN            63.71
# 65870                   12.227                        0.70            60.85
# 19965                      NaN                        2.11            80.18
# 34953                      NaN                        5.98            82.66
# 65373                      NaN                        1.10            76.68
# 58471                    8.704                        1.30            64.26
# 2100                    83.741                        1.90            76.88
# 48399                      NaN                        3.18            83.51
# 55749                      NaN                        3.70            72.91
# 105848                  13.938                        2.00            63.89
# 67532                   47.782                        0.30            70.78
# 37213                      NaN                        8.00            81.33
# 16654                   66.229                        0.80            69.82
# 36658                      NaN                        2.60            73.77
# 73129                   97.400                        1.60            77.86
# 103636                     NaN                        0.80            72.06
# 83895                   20.859                         NaN            67.94
#
#         human_development_index  excess_mortality
# 45019                     0.718               NaN
# 14020                     0.765               NaN
# 79498                     0.824               NaN
# 44502                     0.645               NaN
# 62433                     0.779               NaN
# 101344                    0.926               NaN
# 46089                     0.783               NaN
# 66362                     0.583               NaN
# 88446                     0.709               NaN
# 21035                     0.767               NaN
# 8706                      0.632               NaN
# 4370                      0.845               NaN
# 59025                     0.810               NaN
# 97921                     0.740               NaN
# 100787                    0.932               NaN
# 95790                     0.777               NaN
# 106347                    0.571               NaN
# 76265                     0.777               NaN
# 50620                     0.825               NaN
# 24105                     0.783               NaN
# 76814                     0.718               NaN
# 46613                     0.674               NaN
# 12494                     0.718               NaN
# 39658                     0.663               NaN
# 42360                     0.634               NaN
# 75687                     0.728               NaN
# 90560                     0.904               NaN
# 98429                     0.820               NaN
# 91112                     0.782               NaN
# 73652                     0.557               NaN
# 22567                     0.810               NaN
# 99689                     0.779               NaN
# 519                       0.511               NaN
# 66867                     0.646               NaN
# 65870                     0.456               NaN
# 19965                     0.851               NaN
# 34953                     0.901               NaN
# 65373                     0.686               NaN
# 58471                     0.483               NaN
# 2100                      0.748               NaN
# 48399                     0.892               NaN
# 55749                     0.724               NaN
# 105848                    0.584               NaN
# 67532                     0.602               NaN
# 37213                     0.947               NaN
# 16654                     0.594               NaN
# 36658                     0.812               NaN
# 73129                     0.813               NaN
# 103636                    0.711               NaN
# 83895                     0.512               NaN
#
# [50 rows x 60 columns]

# %%
c_df.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'new_tests', 'total_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'new_vaccinations',
#        'new_vaccinations_smoothed', 'total_vaccinations_per_hundred',
#        'people_vaccinated_per_hundred', 'people_fully_vaccinated_per_hundred',
#        'new_vaccinations_smoothed_per_million', 'stringency_index',
#        'population', 'population_density', 'median_age', 'aged_65_older',
#        'aged_70_older', 'gdp_per_capita', 'extreme_poverty',
#        'cardiovasc_death_rate', 'diabetes_prevalence', 'female_smokers',
#        'male_smokers', 'handwashing_facilities', 'hospital_beds_per_thousand',
#        'life_expectancy', 'human_development_index', 'excess_mortality'],
#       dtype='object')
