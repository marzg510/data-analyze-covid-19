# %%
import pandas as pd

# %%
df = pd.read_csv("covid-19-data/public/data/owid-covid-data.csv")
df.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1      AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# 0              NaN                597.029                 9.59
# 1              NaN                597.029                 9.59
# 2              NaN                597.029                 9.59
# 3              NaN                597.029                 9.59
# 4              NaN                597.029                 9.59
#
#    female_smokers  male_smokers  handwashing_facilities  \
# 0             NaN           NaN                  37.746
# 1             NaN           NaN                  37.746
# 2             NaN           NaN                  37.746
# 3             NaN           NaN                  37.746
# 4             NaN           NaN                  37.746
#
#    hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                         0.5            64.83                    0.511
# 1                         0.5            64.83                    0.511
# 2                         0.5            64.83                    0.511
# 3                         0.5            64.83                    0.511
# 4                         0.5            64.83                    0.511
#
#    excess_mortality
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
#
# [5 rows x 60 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98011 entries, 0 to 98010
# Data columns (total 60 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   iso_code                               98011 non-null  object
#  1   continent                              93405 non-null  object
#  2   location                               98011 non-null  object
#  3   date                                   98011 non-null  object
#  4   total_cases                            94574 non-null  float64
#  5   new_cases                              94571 non-null  float64
#  6   new_cases_smoothed                     93561 non-null  float64
#  7   total_deaths                           84491 non-null  float64
#  8   new_deaths                             84647 non-null  float64
#  9   new_deaths_smoothed                    93561 non-null  float64
#  10  total_cases_per_million                94070 non-null  float64
#  11  new_cases_per_million                  94067 non-null  float64
#  12  new_cases_smoothed_per_million         93062 non-null  float64
#  13  total_deaths_per_million               84000 non-null  float64
#  14  new_deaths_per_million                 84156 non-null  float64
#  15  new_deaths_smoothed_per_million        93062 non-null  float64
#  16  reproduction_rate                      78887 non-null  float64
#  17  icu_patients                           9924 non-null   float64
#  18  icu_patients_per_million               9924 non-null   float64
#  19  hosp_patients                          12333 non-null  float64
#  20  hosp_patients_per_million              12333 non-null  float64
#  21  weekly_icu_admissions                  873 non-null    float64
#  22  weekly_icu_admissions_per_million      873 non-null    float64
#  23  weekly_hosp_admissions                 1544 non-null   float64
#  24  weekly_hosp_admissions_per_million     1544 non-null   float64
#  25  new_tests                              44245 non-null  float64
#  26  total_tests                            43918 non-null  float64
#  27  total_tests_per_thousand               43918 non-null  float64
#  28  new_tests_per_thousand                 44245 non-null  float64
#  29  new_tests_smoothed                     51436 non-null  float64
#  30  new_tests_smoothed_per_thousand        51436 non-null  float64
#  31  positive_rate                          48007 non-null  float64
#  32  tests_per_case                         47409 non-null  float64
#  33  tests_units                            53078 non-null  object
#  34  total_vaccinations                     15750 non-null  float64
#  35  people_vaccinated                      14959 non-null  float64
#  36  people_fully_vaccinated                12119 non-null  float64
#  37  new_vaccinations                       13116 non-null  float64
#  38  new_vaccinations_smoothed              27299 non-null  float64
#  39  total_vaccinations_per_hundred         15750 non-null  float64
#  40  people_vaccinated_per_hundred          14959 non-null  float64
#  41  people_fully_vaccinated_per_hundred    12119 non-null  float64
#  42  new_vaccinations_smoothed_per_million  27299 non-null  float64
#  43  stringency_index                       82296 non-null  float64
#  44  population                             97373 non-null  float64
#  45  population_density                     91080 non-null  float64
#  46  median_age                             87652 non-null  float64
#  47  aged_65_older                          86666 non-null  float64
#  48  aged_70_older                          87167 non-null  float64
#  49  gdp_per_capita                         87976 non-null  float64
#  50  extreme_poverty                        59414 non-null  float64
#  51  cardiovasc_death_rate                  88025 non-null  float64
#  52  diabetes_prevalence                    90250 non-null  float64
#  53  female_smokers                         68870 non-null  float64
#  54  male_smokers                           67863 non-null  float64
#  55  handwashing_facilities                 44233 non-null  float64
#  56  hospital_beds_per_thousand             80210 non-null  float64
#  57  life_expectancy                        93065 non-null  float64
#  58  human_development_index                88182 non-null  float64
#  59  excess_mortality                       3463 non-null   float64
# dtypes: float64(55), object(5)
# memory usage: 44.9+ MB

# %%
df.describe()
# Out:
#         total_cases      new_cases  new_cases_smoothed  total_deaths  \
# count  9.457400e+04   94571.000000        93561.000000  8.449100e+04
# mean   1.036817e+06    6043.887619         6072.323556  2.820252e+04
# std    7.115502e+06   37875.486435        37631.948345  1.682030e+05
# min    1.000000e+00  -74347.000000        -6223.000000  1.000000e+00
# 25%    1.218000e+03       2.000000            7.429000  5.300000e+01
# 50%    1.330800e+04      73.000000           91.429000  3.760000e+02
# 75%    1.409945e+05     803.000000          845.857000  3.670000e+03
# max    1.799994e+08  906008.000000       826389.571000  3.900372e+06
#
#          new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  84647.000000         93561.000000             94070.000000
# mean     146.944723           132.119126             12764.325534
# std      803.817198           746.249585             23599.349815
# min    -1918.000000          -232.143000                 0.001000
# 25%        0.000000             0.000000               254.278500
# 50%        2.000000             1.429000              1743.547500
# 75%       18.000000            14.429000             13181.020250
# max    18050.000000         14737.000000            179602.666000
#
#        new_cases_per_million  new_cases_smoothed_per_million  \
# count           94067.000000                    93062.000000
# mean               76.082206                       76.415589
# std               199.609744                      158.882616
# min             -2153.437000                     -276.825000
# 25%                 0.210000                        1.278000
# 50%                 8.317000                       10.968500
# 75%                70.261000                       78.719500
# max             18293.675000                     4083.500000
#
#        total_deaths_per_million  ...  extreme_poverty  cardiovasc_death_rate  \
# count              84000.000000  ...     59414.000000           88025.000000
# mean                 283.491836  ...        13.399349             258.414678
# std                  514.455782  ...        19.957670             119.003548
# min                    0.001000  ...         0.100000              79.370000
# 25%                    7.863000  ...         0.600000             167.295000
# 50%                   50.650000  ...         2.200000             242.648000
# 75%                  308.341000  ...        21.200000             329.635000
# max                 5795.035000  ...        77.600000             724.417000
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# count         90250.000000    68870.000000  67863.000000
# mean              7.920760       10.562487     32.690179
# std               4.138292       10.459974     13.483280
# min               0.990000        0.100000      7.700000
# 25%               5.310000        1.900000     21.600000
# 50%               7.110000        6.300000     31.400000
# 75%              10.080000       19.300000     41.100000
# max              30.530000       44.000000     78.100000
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# count            44233.000000                80210.000000     93065.000000
# mean                50.841094                    3.028085        73.235629
# std                 31.759475                    2.459325         7.559900
# min                  1.188000                    0.100000        53.280000
# 25%                 19.351000                    1.300000        67.920000
# 50%                 49.839000                    2.400000        74.620000
# 75%                 83.241000                    3.861000        78.740000
# max                100.000000                   13.800000        86.750000
#
#        human_development_index  excess_mortality
# count             88182.000000       3463.000000
# mean                  0.727431         18.259939
# std                   0.150375         36.111776
# min                   0.394000        -95.590000
# 25%                   0.602000          0.365000
# 50%                   0.748000          7.340000
# 75%                   0.848000         23.875000
# max                   0.957000        409.690000
#
# [8 rows x 55 columns]

# %%
df.continent.unique()
# Out:
# array(['Asia', nan, 'Europe', 'Africa', 'North America', 'South America',
#        'Oceania'], dtype=object)

# %%
df.loc[df.continent.isna()].location.unique()
# Out:
# array(['Africa', 'Asia', 'Europe', 'European Union', 'International',
#        'North America', 'Oceania', 'South America', 'World'], dtype=object)

# %%
df.loc[df.location=="International"]
# Out:
#        iso_code continent       location        date  total_cases  new_cases  \
# 41524  OWID_INT       NaN  International  2020-02-07         61.0       61.0
# 41525  OWID_INT       NaN  International  2020-02-08         61.0        0.0
# 41526  OWID_INT       NaN  International  2020-02-09         64.0        3.0
# 41527  OWID_INT       NaN  International  2020-02-10        135.0       71.0
# 41528  OWID_INT       NaN  International  2020-02-11        135.0        0.0
# ...         ...       ...            ...         ...          ...        ...
# 42023  OWID_INT       NaN  International  2021-06-20        722.0        0.0
# 42024  OWID_INT       NaN  International  2021-06-21        722.0        0.0
# 42025  OWID_INT       NaN  International  2021-06-22        722.0        0.0
# 42026  OWID_INT       NaN  International  2021-06-23        722.0        0.0
# 42027  OWID_INT       NaN  International  2021-06-24        722.0        0.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 41524                 NaN           NaN         NaN                  NaN  ...
# 41525                 NaN           NaN         NaN                  NaN  ...
# 41526                 NaN           NaN         NaN                  NaN  ...
# 41527                 NaN           NaN         NaN                  NaN  ...
# 41528                 NaN           NaN         NaN                  NaN  ...
# ...                   ...           ...         ...                  ...  ...
# 42023               0.143          15.0         0.0                  0.0  ...
# 42024               0.143          15.0         0.0                  0.0  ...
# 42025               0.143          15.0         0.0                  0.0  ...
# 42026               0.143          15.0         0.0                  0.0  ...
# 42027               0.143          15.0         0.0                  0.0  ...
#
#        extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# 41524              NaN                    NaN                  NaN
# 41525              NaN                    NaN                  NaN
# 41526              NaN                    NaN                  NaN
# 41527              NaN                    NaN                  NaN
# 41528              NaN                    NaN                  NaN
# ...                ...                    ...                  ...
# 42023              NaN                    NaN                  NaN
# 42024              NaN                    NaN                  NaN
# 42025              NaN                    NaN                  NaN
# 42026              NaN                    NaN                  NaN
# 42027              NaN                    NaN                  NaN
#
#        female_smokers  male_smokers  handwashing_facilities  \
# 41524             NaN           NaN                     NaN
# 41525             NaN           NaN                     NaN
# 41526             NaN           NaN                     NaN
# 41527             NaN           NaN                     NaN
# 41528             NaN           NaN                     NaN
# ...               ...           ...                     ...
# 42023             NaN           NaN                     NaN
# 42024             NaN           NaN                     NaN
# 42025             NaN           NaN                     NaN
# 42026             NaN           NaN                     NaN
# 42027             NaN           NaN                     NaN
#
#        hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 41524                         NaN              NaN                      NaN
# 41525                         NaN              NaN                      NaN
# 41526                         NaN              NaN                      NaN
# 41527                         NaN              NaN                      NaN
# 41528                         NaN              NaN                      NaN
# ...                           ...              ...                      ...
# 42023                         NaN              NaN                      NaN
# 42024                         NaN              NaN                      NaN
# 42025                         NaN              NaN                      NaN
# 42026                         NaN              NaN                      NaN
# 42027                         NaN              NaN                      NaN
#
#        excess_mortality
# 41524               NaN
# 41525               NaN
# 41526               NaN
# 41527               NaN
# 41528               NaN
# ...                 ...
# 42023               NaN
# 42024               NaN
# 42025               NaN
# 42026               NaN
# 42027               NaN
#
# [504 rows x 60 columns]

# %%
df.location.unique()
# Out:
# array(['Afghanistan', 'Africa', 'Albania', 'Algeria', 'Andorra', 'Angola',
#        'Anguilla', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        'Asia', 'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain',
#        'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin',
#        'Bermuda', 'Bhutan', 'Bolivia', 'Bonaire Sint Eustatius and Saba',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Brunei', 'Bulgaria', 'Burkina Faso',
#        'Burundi', 'Cambodia', 'Cameroon', 'Canada', 'Cape Verde',
#        'Cayman Islands', 'Central African Republic', 'Chad', 'Chile',
#        'China', 'Colombia', 'Comoros', 'Congo', 'Cook Islands',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Curacao',
#        'Cyprus', 'Czechia', 'Democratic Republic of Congo', 'Denmark',
#        'Djibouti', 'Dominica', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Estonia',
#        'Eswatini', 'Ethiopia', 'Europe', 'European Union',
#        'Faeroe Islands', 'Falkland Islands', 'Fiji', 'Finland', 'France',
#        'French Polynesia', 'Gabon', 'Gambia', 'Georgia', 'Germany',
#        'Ghana', 'Gibraltar', 'Greece', 'Greenland', 'Grenada',
#        'Guatemala', 'Guernsey', 'Guinea', 'Guinea-Bissau', 'Guyana',
#        'Haiti', 'Honduras', 'Hong Kong', 'Hungary', 'Iceland', 'India',
#        'Indonesia', 'International', 'Iran', 'Iraq', 'Ireland',
#        'Isle of Man', 'Israel', 'Italy', 'Jamaica', 'Japan', 'Jersey',
#        'Jordan', 'Kazakhstan', 'Kenya', 'Kiribati', 'Kosovo', 'Kuwait',
#        'Kyrgyzstan', 'Laos', 'Latvia', 'Lebanon', 'Lesotho', 'Liberia',
#        'Libya', 'Liechtenstein', 'Lithuania', 'Luxembourg', 'Macao',
#        'Madagascar', 'Malawi', 'Malaysia', 'Maldives', 'Mali', 'Malta',
#        'Marshall Islands', 'Mauritania', 'Mauritius', 'Mexico',
#        'Micronesia (country)', 'Moldova', 'Monaco', 'Mongolia',
#        'Montenegro', 'Montserrat', 'Morocco', 'Mozambique', 'Myanmar',
#        'Namibia', 'Nauru', 'Nepal', 'Netherlands', 'New Caledonia',
#        'New Zealand', 'Nicaragua', 'Niger', 'Nigeria', 'North America',
#        'North Macedonia', 'Northern Cyprus', 'Norway', 'Oceania', 'Oman',
#        'Pakistan', 'Palestine', 'Panama', 'Papua New Guinea', 'Paraguay',
#        'Peru', 'Philippines', 'Pitcairn', 'Poland', 'Portugal', 'Qatar',
#        'Romania', 'Russia', 'Rwanda', 'Saint Helena',
#        'Saint Kitts and Nevis', 'Saint Lucia',
#        'Saint Vincent and the Grenadines', 'Samoa', 'San Marino',
#        'Sao Tome and Principe', 'Saudi Arabia', 'Senegal', 'Serbia',
#        'Seychelles', 'Sierra Leone', 'Singapore',
#        'Sint Maarten (Dutch part)', 'Slovakia', 'Slovenia',
#        'Solomon Islands', 'Somalia', 'South Africa', 'South America',
#        'South Korea', 'South Sudan', 'Spain', 'Sri Lanka', 'Sudan',
#        'Suriname', 'Sweden', 'Switzerland', 'Syria', 'Taiwan',
#        'Tajikistan', 'Tanzania', 'Thailand', 'Timor', 'Togo', 'Tonga',
#        'Trinidad and Tobago', 'Tunisia', 'Turkey', 'Turkmenistan',
#        'Turks and Caicos Islands', 'Tuvalu', 'Uganda', 'Ukraine',
#        'United Arab Emirates', 'United Kingdom', 'United States',
#        'Uruguay', 'Uzbekistan', 'Vanuatu', 'Vatican', 'Venezuela',
#        'Vietnam', 'Wallis and Futuna', 'World', 'Yemen', 'Zambia',
#        'Zimbabwe'], dtype=object)

# %%
df["date"] = pd.to_datetime(df["date"])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98011 entries, 0 to 98010
# Data columns (total 60 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   iso_code                               98011 non-null  object
#  1   continent                              93405 non-null  object
#  2   location                               98011 non-null  object
#  3   date                                   98011 non-null  datetime64[ns]
#  4   total_cases                            94574 non-null  float64
#  5   new_cases                              94571 non-null  float64
#  6   new_cases_smoothed                     93561 non-null  float64
#  7   total_deaths                           84491 non-null  float64
#  8   new_deaths                             84647 non-null  float64
#  9   new_deaths_smoothed                    93561 non-null  float64
#  10  total_cases_per_million                94070 non-null  float64
#  11  new_cases_per_million                  94067 non-null  float64
#  12  new_cases_smoothed_per_million         93062 non-null  float64
#  13  total_deaths_per_million               84000 non-null  float64
#  14  new_deaths_per_million                 84156 non-null  float64
#  15  new_deaths_smoothed_per_million        93062 non-null  float64
#  16  reproduction_rate                      78887 non-null  float64
#  17  icu_patients                           9924 non-null   float64
#  18  icu_patients_per_million               9924 non-null   float64
#  19  hosp_patients                          12333 non-null  float64
#  20  hosp_patients_per_million              12333 non-null  float64
#  21  weekly_icu_admissions                  873 non-null    float64
#  22  weekly_icu_admissions_per_million      873 non-null    float64
#  23  weekly_hosp_admissions                 1544 non-null   float64
#  24  weekly_hosp_admissions_per_million     1544 non-null   float64
#  25  new_tests                              44245 non-null  float64
#  26  total_tests                            43918 non-null  float64
#  27  total_tests_per_thousand               43918 non-null  float64
#  28  new_tests_per_thousand                 44245 non-null  float64
#  29  new_tests_smoothed                     51436 non-null  float64
#  30  new_tests_smoothed_per_thousand        51436 non-null  float64
#  31  positive_rate                          48007 non-null  float64
#  32  tests_per_case                         47409 non-null  float64
#  33  tests_units                            53078 non-null  object
#  34  total_vaccinations                     15750 non-null  float64
#  35  people_vaccinated                      14959 non-null  float64
#  36  people_fully_vaccinated                12119 non-null  float64
#  37  new_vaccinations                       13116 non-null  float64
#  38  new_vaccinations_smoothed              27299 non-null  float64
#  39  total_vaccinations_per_hundred         15750 non-null  float64
#  40  people_vaccinated_per_hundred          14959 non-null  float64
#  41  people_fully_vaccinated_per_hundred    12119 non-null  float64
#  42  new_vaccinations_smoothed_per_million  27299 non-null  float64
#  43  stringency_index                       82296 non-null  float64
#  44  population                             97373 non-null  float64
#  45  population_density                     91080 non-null  float64
#  46  median_age                             87652 non-null  float64
#  47  aged_65_older                          86666 non-null  float64
#  48  aged_70_older                          87167 non-null  float64
#  49  gdp_per_capita                         87976 non-null  float64
#  50  extreme_poverty                        59414 non-null  float64
#  51  cardiovasc_death_rate                  88025 non-null  float64
#  52  diabetes_prevalence                    90250 non-null  float64
#  53  female_smokers                         68870 non-null  float64
#  54  male_smokers                           67863 non-null  float64
#  55  handwashing_facilities                 44233 non-null  float64
#  56  hospital_beds_per_thousand             80210 non-null  float64
#  57  life_expectancy                        93065 non-null  float64
#  58  human_development_index                88182 non-null  float64
#  59  excess_mortality                       3463 non-null   float64
# dtypes: datetime64[ns](1), float64(55), object(4)
# memory usage: 44.9+ MB

# %%
latest_date_str = df.date.max().strftime("%Y-%m-%d")

# %% [markdown]
# ## 全世界のデータのみ

# %%
world_df = df.copy().loc[df.location=="World"]
world_df.tail()
# Out:
#        iso_code continent location       date  total_cases  new_cases  \
# 96639  OWID_WRL       NaN    World 2021-06-20  178488764.0   300324.0
# 96640  OWID_WRL       NaN    World 2021-06-21  178786159.0   297395.0
# 96641  OWID_WRL       NaN    World 2021-06-22  179158296.0   372137.0
# 96642  OWID_WRL       NaN    World 2021-06-23  179595551.0   437255.0
# 96643  OWID_WRL       NaN    World 2021-06-24  179999388.0   403837.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 96639          360682.714     3866179.0      6556.0             8838.429  ...
# 96640          359093.571     3873255.0      7076.0             8723.429  ...
# 96641          359184.571     3882237.0      8982.0             8498.857  ...
# 96642          364715.429     3891760.0      9523.0             8382.714  ...
# 96643          366334.714     3900372.0      8612.0             8289.571  ...
#
#        extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# 96639             10.0                 233.07                 8.51
# 96640             10.0                 233.07                 8.51
# 96641             10.0                 233.07                 8.51
# 96642             10.0                 233.07                 8.51
# 96643             10.0                 233.07                 8.51
#
#        female_smokers  male_smokers  handwashing_facilities  \
# 96639           6.434        34.635                   60.13
# 96640           6.434        34.635                   60.13
# 96641           6.434        34.635                   60.13
# 96642           6.434        34.635                   60.13
# 96643           6.434        34.635                   60.13
#
#        hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 96639                       2.705            72.58                    0.737
# 96640                       2.705            72.58                    0.737
# 96641                       2.705            72.58                    0.737
# 96642                       2.705            72.58                    0.737
# 96643                       2.705            72.58                    0.737
#
#        excess_mortality
# 96639               NaN
# 96640               NaN
# 96641               NaN
# 96642               NaN
# 96643               NaN
#
# [5 rows x 60 columns]

# %% [markdown]
# ### 主要国の定義

# %%
countries = pd.DataFrame([
    ("Japan",""),
    ("United States",""),
    ("India","20210415"),
    ("Sweden","20210511"),
    ("Brazil",""),
    ("Israel","20210315"),
    ("United Kingdom",""),
    ("France","20210425"),
    ("Russia",""),
],columns=["country","text_disp_date"])
countries
# Out:
#           country text_disp_date
# 0           Japan
# 1   United States
# 2           India       20210415
# 3          Sweden       20210511
# 4          Brazil
# 5          Israel       20210315
# 6  United Kingdom
# 7          France       20210425
# 8          Russia

# %%
# 東Asia 主要国
e_asia_c = pd.DataFrame([
    ("Japan",""),
    ("China",""),
    ("Taiwan",""),
    ("South Korea","20210420"),
    ("Indonesia",""),
    ("Philippines","20210618"),
    ("Vietnam",""),
],columns=["country","text_disp_date"])
e_asia_c
# Out:
#        country text_disp_date
# 0        Japan
# 1        China
# 2       Taiwan
# 3  South Korea       20210420
# 4    Indonesia
# 5  Philippines       20210618
# 6      Vietnam

# %%
c_trans = pd.merge(countries, df, left_on="country", right_on="location",how="inner")
c_trans.head()
# Out:
#   country text_disp_date iso_code continent location       date  total_cases  \
# 0   Japan                     JPN      Asia    Japan 2020-01-22          2.0
# 1   Japan                     JPN      Asia    Japan 2020-01-23          2.0
# 2   Japan                     JPN      Asia    Japan 2020-01-24          2.0
# 3   Japan                     JPN      Asia    Japan 2020-01-25          2.0
# 4   Japan                     JPN      Asia    Japan 2020-01-26          4.0
#
#    new_cases  new_cases_smoothed  total_deaths  ...  extreme_poverty  \
# 0        NaN                 NaN           NaN  ...              NaN
# 1        0.0                 NaN           NaN  ...              NaN
# 2        0.0                 NaN           NaN  ...              NaN
# 3        0.0                 NaN           NaN  ...              NaN
# 4        2.0                 NaN           NaN  ...              NaN
#
#    cardiovasc_death_rate  diabetes_prevalence  female_smokers  male_smokers  \
# 0                  79.37                 5.72            11.2          33.7
# 1                  79.37                 5.72            11.2          33.7
# 2                  79.37                 5.72            11.2          33.7
# 3                  79.37                 5.72            11.2          33.7
# 4                  79.37                 5.72            11.2          33.7
#
#    handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 0                     NaN                       13.05            84.63
# 1                     NaN                       13.05            84.63
# 2                     NaN                       13.05            84.63
# 3                     NaN                       13.05            84.63
# 4                     NaN                       13.05            84.63
#
#    human_development_index  excess_mortality
# 0                    0.919               NaN
# 1                    0.919               NaN
# 2                    0.919               NaN
# 3                    0.919               NaN
# 4                    0.919               NaN
#
# [5 rows x 62 columns]

# %%
c_trans.location.unique()
# Out:
# array(['Japan', 'United States', 'India', 'Sweden', 'Brazil', 'Israel',
#        'United Kingdom', 'France', 'Russia'], dtype=object)

# %%
e_a_trans = pd.merge(e_asia_c, df, left_on="country", right_on="location",how="inner")
e_a_trans
# Out:
#       country text_disp_date iso_code continent location       date  \
# 0       Japan                     JPN      Asia    Japan 2020-01-22
# 1       Japan                     JPN      Asia    Japan 2020-01-23
# 2       Japan                     JPN      Asia    Japan 2020-01-24
# 3       Japan                     JPN      Asia    Japan 2020-01-25
# 4       Japan                     JPN      Asia    Japan 2020-01-26
# ...       ...            ...      ...       ...      ...        ...
# 3593  Vietnam                     VNM      Asia  Vietnam 2021-06-20
# 3594  Vietnam                     VNM      Asia  Vietnam 2021-06-21
# 3595  Vietnam                     VNM      Asia  Vietnam 2021-06-22
# 3596  Vietnam                     VNM      Asia  Vietnam 2021-06-23
# 3597  Vietnam                     VNM      Asia  Vietnam 2021-06-24
#
#       total_cases  new_cases  new_cases_smoothed  total_deaths  ...  \
# 0             2.0        NaN                 NaN           NaN  ...
# 1             2.0        0.0                 NaN           NaN  ...
# 2             2.0        0.0                 NaN           NaN  ...
# 3             2.0        0.0                 NaN           NaN  ...
# 4             4.0        2.0                 NaN           NaN  ...
# ...           ...        ...                 ...           ...  ...
# 3593      13258.0      280.0             375.429          66.0  ...
# 3594      13530.0      272.0             378.429          69.0  ...
# 3595      13782.0      252.0             354.000          69.0  ...
# 3596      13989.0      207.0             313.571          70.0  ...
# 3597      14323.0      334.0             310.429          72.0  ...
#
#       extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# 0                 NaN                 79.370                 5.72
# 1                 NaN                 79.370                 5.72
# 2                 NaN                 79.370                 5.72
# 3                 NaN                 79.370                 5.72
# 4                 NaN                 79.370                 5.72
# ...               ...                    ...                  ...
# 3593              2.0                245.465                 6.00
# 3594              2.0                245.465                 6.00
# 3595              2.0                245.465                 6.00
# 3596              2.0                245.465                 6.00
# 3597              2.0                245.465                 6.00
#
#       female_smokers  male_smokers  handwashing_facilities  \
# 0               11.2          33.7                     NaN
# 1               11.2          33.7                     NaN
# 2               11.2          33.7                     NaN
# 3               11.2          33.7                     NaN
# 4               11.2          33.7                     NaN
# ...              ...           ...                     ...
# 3593             1.0          45.9                  85.847
# 3594             1.0          45.9                  85.847
# 3595             1.0          45.9                  85.847
# 3596             1.0          45.9                  85.847
# 3597             1.0          45.9                  85.847
#
#       hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                          13.05            84.63                    0.919
# 1                          13.05            84.63                    0.919
# 2                          13.05            84.63                    0.919
# 3                          13.05            84.63                    0.919
# 4                          13.05            84.63                    0.919
# ...                          ...              ...                      ...
# 3593                        2.60            75.40                    0.704
# 3594                        2.60            75.40                    0.704
# 3595                        2.60            75.40                    0.704
# 3596                        2.60            75.40                    0.704
# 3597                        2.60            75.40                    0.704
#
#       excess_mortality
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# ...                ...
# 3593               NaN
# 3594               NaN
# 3595               NaN
# 3596               NaN
# 3597               NaN
#
# [3598 rows x 62 columns]

# %%
e_a_trans.location.unique()
# Out:
# array(['Japan', 'China', 'Taiwan', 'South Korea', 'Indonesia',
#        'Philippines', 'Vietnam'], dtype=object)

# %% [markdown]
# ## 可視化

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook
#%matplotlib inline

# %%
world_df["case_rolling7ave"] = world_df.new_cases.rolling(7).mean()
world_df[["new_cases_smoothed","case_rolling7ave"]]
# Out:
#        new_cases_smoothed  case_rolling7ave
# 96124                 NaN               NaN
# 96125                 NaN               NaN
# 96126                 NaN               NaN
# 96127                 NaN               NaN
# 96128                 NaN               NaN
# ...                   ...               ...
# 96639          360682.714     360682.714286
# 96640          359093.571     359093.571429
# 96641          359184.571     359184.571429
# 96642          364715.429     364715.428571
# 96643          366334.714     366334.714286
#
# [520 rows x 2 columns]

# %%
fig=plt.figure(figsize=(12,8))
plt.subplot(2,2,1) # (rows, columns, panel number)
plt.title("Daily new confirmed COVID-19 cases in the world")
plt.bar(world_df.date,world_df.new_cases,label="New cases")
plt.plot_date(world_df["date"],world_df["new_cases_smoothed"],label="rolling 7-day average", fmt="-", color="orange")
plt.xticks(rotation=70)
plt.ylabel("people")
plt.grid(axis="y")
plt.legend()

plt.subplot(2,2,2) # (rows, columns, panel number)
plt.title("Daily new confirmed COVID-19 cases in the world(after 2021 Apr 1st)")
chart_data = world_df[world_df.date >= "2021-04-01"]
plt.bar(chart_data["date"],chart_data["new_cases"],label="New deaths")
plt.plot_date(chart_data["date"],chart_data["new_cases_smoothed"],label="rolling 7-day average", fmt="-", color="orange")
plt.xticks(rotation=70)
plt.grid(axis="y")
plt.legend()

plt.subplot(2,2,3) # (rows, columns, panel number)
plt.title("Daily new deaths in the world")
plt.bar(world_df.date,world_df.new_deaths,label="New cases")
plt.plot_date(world_df["date"],world_df["new_deaths_smoothed"],label="rolling 7-day average", fmt="-", color="orange")
plt.xticks(rotation=70)
plt.ylabel("people")
plt.grid(axis="y")
plt.legend()

plt.subplot(2,2,4) # (rows, columns, panel number)
plt.title("Daily new deaths in the world(after 2021 Apr 1st)")
chart_data = world_df[world_df.date >= "2021-04-01"]
plt.bar(chart_data["date"],chart_data["new_deaths"],label="New deaths")
plt.plot_date(chart_data["date"],chart_data["new_deaths_smoothed"],label="rolling 7-day average", fmt="-", color="orange")
plt.xticks(rotation=70)
plt.grid(axis="y")
plt.legend()

fig.text(0,1,"Latest: {}".format(latest_date_str),fontsize=8,ha="left",va="top")
fig.text(0,0
         ,"*Data Source : COVID-19 Dataset by Our World in Data",
        fontsize=7,ha="left",va="bottom")

fig.tight_layout()
# Out:
# <div id='703d07cc-9cde-484e-a09c-cc77e52d4405'></div>

# %%
fig.savefig("out/covid-owid-global-daily.png")

# %% [markdown]
# ### 国別

# %% [markdown]
# #### 人口100万人当たりの新規感染者数（3月以降）

# %%
min_date = pd.to_datetime("2021-03-01")
# 主要国 新規感染者
chart_data = c_trans[c_trans.date >= min_date]
dates = chart_data["date"].unique()
print(len(dates))
print(dates.max())
for i,cr in countries.iterrows():
    c = cr["country"]
    dates = chart_data.loc[chart_data["location"]==c]["date"]
    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else dates.max()
    print(len(chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"]))
    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"],label=c, fmt="-")
    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_cases_smoothed_per_million"],c
            ,fontsize=8,va="center")
# Out:
# 117
# 2021-06-25T00:00:00.000000000
# 116
# 116
# 116
# 116
# 116
# 117
# 116
# 116
# 116

# %%
fig=plt.figure(figsize=(14,10))
min_date = pd.to_datetime("2021-03-01")
# 主要国 新規感染者
plt.subplot(2,2,1) # (rows, columns, panel number)
plt.title("Daily new confirmed COVID-19 cases\n per million population in major countries\n(rolling 7day ave.)")
plt.grid()
plt.xticks(rotation=70)
chart_data = c_trans[c_trans.date >= min_date]
dates = chart_data["date"].unique()
for i,cr in countries.iterrows():
    c = cr["country"]
    dates = chart_data.loc[chart_data["location"]==c]["date"]
    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else dates.max()
    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"],label=c, fmt="-")
    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_cases_smoothed_per_million"],c
            ,fontsize=8,va="center")
plt.legend(bbox_to_anchor=(0, 1),loc='upper left', fontsize=9)
# Out:
# <div id='48af836f-6d40-4714-a36a-f53fc50c2265'></div>

# %%
fig=plt.figure(figsize=(14,10))
min_date = pd.to_datetime("2021-03-01")
# 主要国 新規感染者
plt.subplot(2,2,1) # (rows, columns, panel number)
plt.title("Daily new confirmed COVID-19 cases\n per million population in major countries\n(rolling 7day ave.)")
plt.grid()
plt.xticks(rotation=45)
chart_data = c_trans[c_trans.date >= min_date]
for i,cr in countries.iterrows():
    c = cr["country"]
    dates = chart_data.loc[chart_data["location"]==c]["date"]
    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else dates.max()
    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"],label=c, fmt="-")
    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_cases_smoothed_per_million"],c
            ,fontsize=8,va="center")
plt.legend(bbox_to_anchor=(0, 1),loc='upper left', fontsize=9)

# 主要国 死者
plt.subplot(2,2,2) # (rows, columns, panel number)
plt.title("Daily new deaths in major countries(rolling 7day ave.)")
plt.grid()
plt.xticks(rotation=45)
chart_data = c_trans[c_trans.date >= min_date]
for i,cr in countries.iterrows():
    c = cr["country"]
    dates = chart_data.loc[chart_data["location"]==c]["date"]
    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else dates.max()
    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_deaths_smoothed"],label=c, fmt="-")
    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_deaths_smoothed"],c
            ,fontsize=8,va="center")
plt.legend(bbox_to_anchor=(0, 1),loc='upper left', fontsize=9)

plt.subplot(2,2,3) # (rows, columns, panel number)
plt.grid()
plt.xticks(rotation=45)
plt.title("Daily new confirmed COVID-19 cases\n per million population in Eastern Asia\n(rolling 7day ave.)")
chart_data = e_a_trans[e_a_trans.date >= min_date]
for i,cr in e_asia_c.iterrows():
    c = cr["country"]
    dates = chart_data.loc[chart_data["location"]==c]["date"]
    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else dates.max()
    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"],label=c, fmt="-")
    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_cases_smoothed_per_million"],c
             ,fontsize=8,va="center")
plt.legend(bbox_to_anchor=(0, 1),loc='upper left', fontsize=9)

plt.subplot(2,2,4) # (rows, columns, panel number)
plt.grid()
plt.xticks(rotation=45)
plt.title("Daily new deaths in Eastern Asia(rolling 7day ave.)")
chart_data = e_a_trans[e_a_trans.date >= min_date]
for i,cr in e_asia_c.iterrows():
    c = cr["country"]
    dates = chart_data.loc[chart_data["location"]==c]["date"]
    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else dates.max()
    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_deaths_smoothed"],label=c, fmt="-")
    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_deaths_smoothed"],c
             ,fontsize=8,va="center")
plt.legend(bbox_to_anchor=(0, 1),loc='upper left', fontsize=9)

fig.text(0,1,"Latest: {}".format(latest_date_str),fontsize=8,ha="left",va="top")
fig.text(0,0
         ,"*Data Source : COVID-19 Dataset by Our World in Data",
        fontsize=7,ha="left",va="bottom")
fig.tight_layout()
# Out:
# <div id='feca7ba4-8521-4ee3-b1b5-802553f877b7'></div>

# %%
fig.savefig("out/covid-owid-countries-daily.png")
