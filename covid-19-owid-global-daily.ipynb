# %%
import pandas as pd

# %%
df = pd.read_csv("covid-19-data/public/data/owid-covid-data.csv")
df.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1      AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# 0              NaN                597.029                 9.59
# 1              NaN                597.029                 9.59
# 2              NaN                597.029                 9.59
# 3              NaN                597.029                 9.59
# 4              NaN                597.029                 9.59
#
#    female_smokers  male_smokers  handwashing_facilities  \
# 0             NaN           NaN                  37.746
# 1             NaN           NaN                  37.746
# 2             NaN           NaN                  37.746
# 3             NaN           NaN                  37.746
# 4             NaN           NaN                  37.746
#
#    hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                         0.5            64.83                    0.511
# 1                         0.5            64.83                    0.511
# 2                         0.5            64.83                    0.511
# 3                         0.5            64.83                    0.511
# 4                         0.5            64.83                    0.511
#
#    excess_mortality
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
#
# [5 rows x 60 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98904 entries, 0 to 98903
# Data columns (total 60 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   iso_code                               98904 non-null  object
#  1   continent                              94262 non-null  object
#  2   location                               98904 non-null  object
#  3   date                                   98904 non-null  object
#  4   total_cases                            95378 non-null  float64
#  5   new_cases                              95375 non-null  float64
#  6   new_cases_smoothed                     94365 non-null  float64
#  7   total_deaths                           85267 non-null  float64
#  8   new_deaths                             85423 non-null  float64
#  9   new_deaths_smoothed                    94365 non-null  float64
#  10  total_cases_per_million                94870 non-null  float64
#  11  new_cases_per_million                  94867 non-null  float64
#  12  new_cases_smoothed_per_million         93862 non-null  float64
#  13  total_deaths_per_million               84772 non-null  float64
#  14  new_deaths_per_million                 84928 non-null  float64
#  15  new_deaths_smoothed_per_million        93862 non-null  float64
#  16  reproduction_rate                      78887 non-null  float64
#  17  icu_patients                           9938 non-null   float64
#  18  icu_patients_per_million               9938 non-null   float64
#  19  hosp_patients                          12348 non-null  float64
#  20  hosp_patients_per_million              12348 non-null  float64
#  21  weekly_icu_admissions                  874 non-null    float64
#  22  weekly_icu_admissions_per_million      874 non-null    float64
#  23  weekly_hosp_admissions                 1546 non-null   float64
#  24  weekly_hosp_admissions_per_million     1546 non-null   float64
#  25  new_tests                              44489 non-null  float64
#  26  total_tests                            44165 non-null  float64
#  27  total_tests_per_thousand               44165 non-null  float64
#  28  new_tests_per_thousand                 44489 non-null  float64
#  29  new_tests_smoothed                     51730 non-null  float64
#  30  new_tests_smoothed_per_thousand        51730 non-null  float64
#  31  positive_rate                          48297 non-null  float64
#  32  tests_per_case                         47699 non-null  float64
#  33  tests_units                            53383 non-null  object
#  34  total_vaccinations                     16219 non-null  float64
#  35  people_vaccinated                      15421 non-null  float64
#  36  people_fully_vaccinated                12555 non-null  float64
#  37  new_vaccinations                       13523 non-null  float64
#  38  new_vaccinations_smoothed              28113 non-null  float64
#  39  total_vaccinations_per_hundred         16219 non-null  float64
#  40  people_vaccinated_per_hundred          15421 non-null  float64
#  41  people_fully_vaccinated_per_hundred    12555 non-null  float64
#  42  new_vaccinations_smoothed_per_million  28113 non-null  float64
#  43  stringency_index                       83044 non-null  float64
#  44  population                             98262 non-null  float64
#  45  population_density                     91907 non-null  float64
#  46  median_age                             88418 non-null  float64
#  47  aged_65_older                          87424 non-null  float64
#  48  aged_70_older                          87929 non-null  float64
#  49  gdp_per_capita                         88764 non-null  float64
#  50  extreme_poverty                        59913 non-null  float64
#  51  cardiovasc_death_rate                  88802 non-null  float64
#  52  diabetes_prevalence                    91058 non-null  float64
#  53  female_smokers                         69464 non-null  float64
#  54  male_smokers                           68449 non-null  float64
#  55  handwashing_facilities                 44613 non-null  float64
#  56  hospital_beds_per_thousand             80900 non-null  float64
#  57  life_expectancy                        93918 non-null  float64
#  58  human_development_index                88948 non-null  float64
#  59  excess_mortality                       3503 non-null   float64
# dtypes: float64(55), object(5)
# memory usage: 45.3+ MB

# %%
df.describe()
# Out:
#         total_cases      new_cases  new_cases_smoothed  total_deaths  \
# count  9.537800e+04   95375.000000        94365.000000  8.526700e+04
# mean   1.052212e+06    6038.256818         6068.421147  2.853229e+04
# std    7.213039e+06   37809.050368        37574.679206  1.702171e+05
# min    1.000000e+00  -74347.000000        -6223.000000  1.000000e+00
# 25%    1.245000e+03       2.000000            7.429000  5.300000e+01
# 50%    1.337400e+04      73.000000           91.714000  3.850000e+02
# 75%    1.425382e+05     804.000000          848.429000  3.738000e+03
# max    1.814258e+08  906017.000000       826388.429000  3.929711e+06
#
#          new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  85423.000000         94365.000000              94870.00000
# mean     146.653957           132.048394              12960.21397
# std      802.334502           745.640153              23885.58002
# min    -1918.000000          -232.143000                  0.00100
# 25%        0.000000             0.000000                258.02400
# 50%        2.000000             1.429000               1775.45550
# 75%       18.000000            14.429000              13471.10050
# max    18050.000000         14737.000000             179667.37900
#
#        new_cases_per_million  new_cases_smoothed_per_million  \
# count           94867.000000                    93862.000000
# mean               76.073508                       76.399165
# std               200.330946                      158.901143
# min             -2153.437000                     -276.825000
# 25%                 0.210000                        1.288000
# 50%                 8.349000                       11.075500
# 75%                70.091500                       78.638500
# max             18293.675000                     4083.500000
#
#        total_deaths_per_million  ...  extreme_poverty  cardiovasc_death_rate  \
# count              84772.000000  ...     59913.000000           88802.000000
# mean                 287.125609  ...        13.404016             258.443682
# std                  519.903965  ...        19.959436             119.009612
# min                    0.001000  ...         0.100000              79.370000
# 25%                    7.950000  ...         0.600000             167.295000
# 50%                   51.058000  ...         2.200000             242.648000
# 75%                  313.133000  ...        21.200000             329.635000
# max                 5820.087000  ...        77.600000             724.417000
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# count         91058.000000    69464.000000  68449.000000
# mean              7.924351       10.562908     32.694905
# std               4.141143       10.459370     13.484337
# min               0.990000        0.100000      7.700000
# 25%               5.310000        1.900000     21.600000
# 50%               7.110000        6.300000     31.400000
# 75%              10.080000       19.300000     41.100000
# max              30.530000       44.000000     78.100000
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# count            44613.000000                80900.000000     93918.000000
# mean                50.836236                    3.027692        73.236505
# std                 31.759194                    2.458843         7.558940
# min                  1.188000                    0.100000        53.280000
# 25%                 19.351000                    1.300000        67.920000
# 50%                 49.839000                    2.400000        74.620000
# 75%                 83.241000                    3.861000        78.740000
# max                100.000000                   13.800000        86.750000
#
#        human_development_index  excess_mortality
# count             88948.000000       3503.000000
# mean                  0.727383         18.243991
# std                   0.150356         36.030922
# min                   0.394000        -95.590000
# 25%                   0.602000          0.405000
# 50%                   0.748000          7.340000
# 75%                   0.848000         23.855000
# max                   0.957000        409.690000
#
# [8 rows x 55 columns]

# %%
df.continent.unique()
# Out:
# array(['Asia', nan, 'Europe', 'Africa', 'North America', 'South America',
#        'Oceania'], dtype=object)

# %%
df.loc[df.continent.isna()].location.unique()
# Out:
# array(['Africa', 'Asia', 'Europe', 'European Union', 'International',
#        'North America', 'Oceania', 'South America', 'World'], dtype=object)

# %%
df.loc[df.location=="International"]
# Out:
#        iso_code continent       location        date  total_cases  new_cases  \
# 41902  OWID_INT       NaN  International  2020-02-07         61.0       61.0
# 41903  OWID_INT       NaN  International  2020-02-08         61.0        0.0
# 41904  OWID_INT       NaN  International  2020-02-09         64.0        3.0
# 41905  OWID_INT       NaN  International  2020-02-10        135.0       71.0
# 41906  OWID_INT       NaN  International  2020-02-11        135.0        0.0
# ...         ...       ...            ...         ...          ...        ...
# 42405  OWID_INT       NaN  International  2021-06-24        727.0        5.0
# 42406  OWID_INT       NaN  International  2021-06-25        727.0        0.0
# 42407  OWID_INT       NaN  International  2021-06-26        727.0        0.0
# 42408  OWID_INT       NaN  International  2021-06-27        727.0        0.0
# 42409  OWID_INT       NaN  International  2021-06-28        722.0       -5.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 41902                 NaN           NaN         NaN                  NaN  ...
# 41903                 NaN           NaN         NaN                  NaN  ...
# 41904                 NaN           NaN         NaN                  NaN  ...
# 41905                 NaN           NaN         NaN                  NaN  ...
# 41906                 NaN           NaN         NaN                  NaN  ...
# ...                   ...           ...         ...                  ...  ...
# 42405               0.857          15.0         0.0                  0.0  ...
# 42406               0.857          15.0         0.0                  0.0  ...
# 42407               0.714          15.0         0.0                  0.0  ...
# 42408               0.714          15.0         0.0                  0.0  ...
# 42409               0.000          15.0         0.0                  0.0  ...
#
#        extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# 41902              NaN                    NaN                  NaN
# 41903              NaN                    NaN                  NaN
# 41904              NaN                    NaN                  NaN
# 41905              NaN                    NaN                  NaN
# 41906              NaN                    NaN                  NaN
# ...                ...                    ...                  ...
# 42405              NaN                    NaN                  NaN
# 42406              NaN                    NaN                  NaN
# 42407              NaN                    NaN                  NaN
# 42408              NaN                    NaN                  NaN
# 42409              NaN                    NaN                  NaN
#
#        female_smokers  male_smokers  handwashing_facilities  \
# 41902             NaN           NaN                     NaN
# 41903             NaN           NaN                     NaN
# 41904             NaN           NaN                     NaN
# 41905             NaN           NaN                     NaN
# 41906             NaN           NaN                     NaN
# ...               ...           ...                     ...
# 42405             NaN           NaN                     NaN
# 42406             NaN           NaN                     NaN
# 42407             NaN           NaN                     NaN
# 42408             NaN           NaN                     NaN
# 42409             NaN           NaN                     NaN
#
#        hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 41902                         NaN              NaN                      NaN
# 41903                         NaN              NaN                      NaN
# 41904                         NaN              NaN                      NaN
# 41905                         NaN              NaN                      NaN
# 41906                         NaN              NaN                      NaN
# ...                           ...              ...                      ...
# 42405                         NaN              NaN                      NaN
# 42406                         NaN              NaN                      NaN
# 42407                         NaN              NaN                      NaN
# 42408                         NaN              NaN                      NaN
# 42409                         NaN              NaN                      NaN
#
#        excess_mortality
# 41902               NaN
# 41903               NaN
# 41904               NaN
# 41905               NaN
# 41906               NaN
# ...                 ...
# 42405               NaN
# 42406               NaN
# 42407               NaN
# 42408               NaN
# 42409               NaN
#
# [508 rows x 60 columns]

# %%
df.location.unique()
# Out:
# array(['Afghanistan', 'Africa', 'Albania', 'Algeria', 'Andorra', 'Angola',
#        'Anguilla', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        'Asia', 'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain',
#        'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin',
#        'Bermuda', 'Bhutan', 'Bolivia', 'Bonaire Sint Eustatius and Saba',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Brunei', 'Bulgaria', 'Burkina Faso',
#        'Burundi', 'Cambodia', 'Cameroon', 'Canada', 'Cape Verde',
#        'Cayman Islands', 'Central African Republic', 'Chad', 'Chile',
#        'China', 'Colombia', 'Comoros', 'Congo', 'Cook Islands',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Curacao',
#        'Cyprus', 'Czechia', 'Democratic Republic of Congo', 'Denmark',
#        'Djibouti', 'Dominica', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Estonia',
#        'Eswatini', 'Ethiopia', 'Europe', 'European Union',
#        'Faeroe Islands', 'Falkland Islands', 'Fiji', 'Finland', 'France',
#        'French Polynesia', 'Gabon', 'Gambia', 'Georgia', 'Germany',
#        'Ghana', 'Gibraltar', 'Greece', 'Greenland', 'Grenada',
#        'Guatemala', 'Guernsey', 'Guinea', 'Guinea-Bissau', 'Guyana',
#        'Haiti', 'Honduras', 'Hong Kong', 'Hungary', 'Iceland', 'India',
#        'Indonesia', 'International', 'Iran', 'Iraq', 'Ireland',
#        'Isle of Man', 'Israel', 'Italy', 'Jamaica', 'Japan', 'Jersey',
#        'Jordan', 'Kazakhstan', 'Kenya', 'Kiribati', 'Kosovo', 'Kuwait',
#        'Kyrgyzstan', 'Laos', 'Latvia', 'Lebanon', 'Lesotho', 'Liberia',
#        'Libya', 'Liechtenstein', 'Lithuania', 'Luxembourg', 'Macao',
#        'Madagascar', 'Malawi', 'Malaysia', 'Maldives', 'Mali', 'Malta',
#        'Marshall Islands', 'Mauritania', 'Mauritius', 'Mexico',
#        'Micronesia (country)', 'Moldova', 'Monaco', 'Mongolia',
#        'Montenegro', 'Montserrat', 'Morocco', 'Mozambique', 'Myanmar',
#        'Namibia', 'Nauru', 'Nepal', 'Netherlands', 'New Caledonia',
#        'New Zealand', 'Nicaragua', 'Niger', 'Nigeria', 'North America',
#        'North Macedonia', 'Northern Cyprus', 'Norway', 'Oceania', 'Oman',
#        'Pakistan', 'Palestine', 'Panama', 'Papua New Guinea', 'Paraguay',
#        'Peru', 'Philippines', 'Pitcairn', 'Poland', 'Portugal', 'Qatar',
#        'Romania', 'Russia', 'Rwanda', 'Saint Helena',
#        'Saint Kitts and Nevis', 'Saint Lucia',
#        'Saint Vincent and the Grenadines', 'Samoa', 'San Marino',
#        'Sao Tome and Principe', 'Saudi Arabia', 'Senegal', 'Serbia',
#        'Seychelles', 'Sierra Leone', 'Singapore',
#        'Sint Maarten (Dutch part)', 'Slovakia', 'Slovenia',
#        'Solomon Islands', 'Somalia', 'South Africa', 'South America',
#        'South Korea', 'South Sudan', 'Spain', 'Sri Lanka', 'Sudan',
#        'Suriname', 'Sweden', 'Switzerland', 'Syria', 'Taiwan',
#        'Tajikistan', 'Tanzania', 'Thailand', 'Timor', 'Togo', 'Tonga',
#        'Trinidad and Tobago', 'Tunisia', 'Turkey', 'Turkmenistan',
#        'Turks and Caicos Islands', 'Tuvalu', 'Uganda', 'Ukraine',
#        'United Arab Emirates', 'United Kingdom', 'United States',
#        'Uruguay', 'Uzbekistan', 'Vanuatu', 'Vatican', 'Venezuela',
#        'Vietnam', 'Wallis and Futuna', 'World', 'Yemen', 'Zambia',
#        'Zimbabwe'], dtype=object)

# %%
df["date"] = pd.to_datetime(df["date"])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98904 entries, 0 to 98903
# Data columns (total 60 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   iso_code                               98904 non-null  object
#  1   continent                              94262 non-null  object
#  2   location                               98904 non-null  object
#  3   date                                   98904 non-null  datetime64[ns]
#  4   total_cases                            95378 non-null  float64
#  5   new_cases                              95375 non-null  float64
#  6   new_cases_smoothed                     94365 non-null  float64
#  7   total_deaths                           85267 non-null  float64
#  8   new_deaths                             85423 non-null  float64
#  9   new_deaths_smoothed                    94365 non-null  float64
#  10  total_cases_per_million                94870 non-null  float64
#  11  new_cases_per_million                  94867 non-null  float64
#  12  new_cases_smoothed_per_million         93862 non-null  float64
#  13  total_deaths_per_million               84772 non-null  float64
#  14  new_deaths_per_million                 84928 non-null  float64
#  15  new_deaths_smoothed_per_million        93862 non-null  float64
#  16  reproduction_rate                      78887 non-null  float64
#  17  icu_patients                           9938 non-null   float64
#  18  icu_patients_per_million               9938 non-null   float64
#  19  hosp_patients                          12348 non-null  float64
#  20  hosp_patients_per_million              12348 non-null  float64
#  21  weekly_icu_admissions                  874 non-null    float64
#  22  weekly_icu_admissions_per_million      874 non-null    float64
#  23  weekly_hosp_admissions                 1546 non-null   float64
#  24  weekly_hosp_admissions_per_million     1546 non-null   float64
#  25  new_tests                              44489 non-null  float64
#  26  total_tests                            44165 non-null  float64
#  27  total_tests_per_thousand               44165 non-null  float64
#  28  new_tests_per_thousand                 44489 non-null  float64
#  29  new_tests_smoothed                     51730 non-null  float64
#  30  new_tests_smoothed_per_thousand        51730 non-null  float64
#  31  positive_rate                          48297 non-null  float64
#  32  tests_per_case                         47699 non-null  float64
#  33  tests_units                            53383 non-null  object
#  34  total_vaccinations                     16219 non-null  float64
#  35  people_vaccinated                      15421 non-null  float64
#  36  people_fully_vaccinated                12555 non-null  float64
#  37  new_vaccinations                       13523 non-null  float64
#  38  new_vaccinations_smoothed              28113 non-null  float64
#  39  total_vaccinations_per_hundred         16219 non-null  float64
#  40  people_vaccinated_per_hundred          15421 non-null  float64
#  41  people_fully_vaccinated_per_hundred    12555 non-null  float64
#  42  new_vaccinations_smoothed_per_million  28113 non-null  float64
#  43  stringency_index                       83044 non-null  float64
#  44  population                             98262 non-null  float64
#  45  population_density                     91907 non-null  float64
#  46  median_age                             88418 non-null  float64
#  47  aged_65_older                          87424 non-null  float64
#  48  aged_70_older                          87929 non-null  float64
#  49  gdp_per_capita                         88764 non-null  float64
#  50  extreme_poverty                        59913 non-null  float64
#  51  cardiovasc_death_rate                  88802 non-null  float64
#  52  diabetes_prevalence                    91058 non-null  float64
#  53  female_smokers                         69464 non-null  float64
#  54  male_smokers                           68449 non-null  float64
#  55  handwashing_facilities                 44613 non-null  float64
#  56  hospital_beds_per_thousand             80900 non-null  float64
#  57  life_expectancy                        93918 non-null  float64
#  58  human_development_index                88948 non-null  float64
#  59  excess_mortality                       3503 non-null   float64
# dtypes: datetime64[ns](1), float64(55), object(4)
# memory usage: 45.3+ MB

# %%
latest_date_str = df.date.max().strftime("%Y-%m-%d")

# %% [markdown]
# ## 全世界のデータのみ

# %%
world_df = df.copy().loc[df.location=="World"]
world_df.tail()
# Out:
#        iso_code continent location       date  total_cases  new_cases  \
# 97520  OWID_WRL       NaN    World 2021-06-24  179999393.0   403842.0
# 97521  OWID_WRL       NaN    World 2021-06-25  180421133.0   421740.0
# 97522  OWID_WRL       NaN    World 2021-06-26  180783952.0   362819.0
# 97523  OWID_WRL       NaN    World 2021-06-27  181093841.0   309889.0
# 97524  OWID_WRL       NaN    World 2021-06-28  181425785.0   331944.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 97520          366325.286     3900440.0      8612.0             8283.571  ...
# 97521          368583.714     3909654.0      9214.0             8284.286  ...
# 97522          370779.714     3917118.0      7464.0             8197.571  ...
# 97523          372146.143     3923065.0      5947.0             8110.143  ...
# 97524          377089.429     3929711.0      6646.0             8048.714  ...
#
#        extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# 97520             10.0                 233.07                 8.51
# 97521             10.0                 233.07                 8.51
# 97522             10.0                 233.07                 8.51
# 97523             10.0                 233.07                 8.51
# 97524             10.0                 233.07                 8.51
#
#        female_smokers  male_smokers  handwashing_facilities  \
# 97520           6.434        34.635                   60.13
# 97521           6.434        34.635                   60.13
# 97522           6.434        34.635                   60.13
# 97523           6.434        34.635                   60.13
# 97524           6.434        34.635                   60.13
#
#        hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 97520                       2.705            72.58                    0.737
# 97521                       2.705            72.58                    0.737
# 97522                       2.705            72.58                    0.737
# 97523                       2.705            72.58                    0.737
# 97524                       2.705            72.58                    0.737
#
#        excess_mortality
# 97520               NaN
# 97521               NaN
# 97522               NaN
# 97523               NaN
# 97524               NaN
#
# [5 rows x 60 columns]

# %% [markdown]
# ### 主要国の定義

# %%
countries = pd.DataFrame([
    ("Japan",""),
    ("United States",""),
    ("India","20210415"),
    ("Sweden","20210511"),
    ("Brazil",""),
    ("Israel","20210315"),
    ("United Kingdom",""),
    ("France","20210425"),
    ("Russia",""),
    ("Colombia",""),
    ("South Africa",""),
],columns=["country","text_disp_date"])
countries
# Out:
#            country text_disp_date
# 0            Japan
# 1    United States
# 2            India       20210415
# 3           Sweden       20210511
# 4           Brazil
# 5           Israel       20210315
# 6   United Kingdom
# 7           France       20210425
# 8           Russia
# 9         Colombia
# 10    South Africa

# %%
# 東Asia 主要国
e_asia_c = pd.DataFrame([
    ("Japan",""),
    ("China",""),
    ("Taiwan",""),
    ("South Korea","20210420"),
    ("Indonesia",""),
    ("Philippines","20210618"),
    ("Vietnam",""),
],columns=["country","text_disp_date"])
e_asia_c
# Out:
#        country text_disp_date
# 0        Japan
# 1        China
# 2       Taiwan
# 3  South Korea       20210420
# 4    Indonesia
# 5  Philippines       20210618
# 6      Vietnam

# %%
c_trans = pd.merge(countries, df, left_on="country", right_on="location",how="inner")
c_trans.head()
# Out:
#   country text_disp_date iso_code continent location       date  total_cases  \
# 0   Japan                     JPN      Asia    Japan 2020-01-22          2.0
# 1   Japan                     JPN      Asia    Japan 2020-01-23          2.0
# 2   Japan                     JPN      Asia    Japan 2020-01-24          2.0
# 3   Japan                     JPN      Asia    Japan 2020-01-25          2.0
# 4   Japan                     JPN      Asia    Japan 2020-01-26          4.0
#
#    new_cases  new_cases_smoothed  total_deaths  ...  extreme_poverty  \
# 0        NaN                 NaN           NaN  ...              NaN
# 1        0.0                 NaN           NaN  ...              NaN
# 2        0.0                 NaN           NaN  ...              NaN
# 3        0.0                 NaN           NaN  ...              NaN
# 4        2.0                 NaN           NaN  ...              NaN
#
#    cardiovasc_death_rate  diabetes_prevalence  female_smokers  male_smokers  \
# 0                  79.37                 5.72            11.2          33.7
# 1                  79.37                 5.72            11.2          33.7
# 2                  79.37                 5.72            11.2          33.7
# 3                  79.37                 5.72            11.2          33.7
# 4                  79.37                 5.72            11.2          33.7
#
#    handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 0                     NaN                       13.05            84.63
# 1                     NaN                       13.05            84.63
# 2                     NaN                       13.05            84.63
# 3                     NaN                       13.05            84.63
# 4                     NaN                       13.05            84.63
#
#    human_development_index  excess_mortality
# 0                    0.919               NaN
# 1                    0.919               NaN
# 2                    0.919               NaN
# 3                    0.919               NaN
# 4                    0.919               NaN
#
# [5 rows x 62 columns]

# %%
c_trans.location.unique()
# Out:
# array(['Japan', 'United States', 'India', 'Sweden', 'Brazil', 'Israel',
#        'United Kingdom', 'France', 'Russia', 'Colombia', 'South Africa'],
#       dtype=object)

# %%
c_trans.loc[c_trans.date==latest_date_str][["country","date","total_deaths","total_deaths_per_million"]].sort_values("total_deaths_per_million",ascending=False)
# Out:
#              country       date  total_deaths  total_deaths_per_million
# 2566          Brazil 2021-06-28      514092.0                  2418.580
# 5093        Colombia 2021-06-28      105326.0                  2069.969
# 3576  United Kingdom 2021-06-28      128367.0                  1890.920
# 1047   United States 2021-06-28      604115.0                  1825.106
# 4098          France 2021-06-28      111174.0                  1645.456
# 2077          Sweden 2021-06-28       14619.0                  1447.530
# 5601    South Africa 2021-06-28       60038.0                  1012.297
# 4613          Russia 2021-06-28      131671.0                   902.261
# 3061          Israel 2021-06-28        6429.0                   742.761
# 1563           India 2021-06-28      397637.0                   288.142
# 523            Japan 2021-06-28       14659.0                   115.903

# %%
e_a_trans = pd.merge(e_asia_c, df, left_on="country", right_on="location",how="inner")
e_a_trans
# Out:
#       country text_disp_date iso_code continent location       date  \
# 0       Japan                     JPN      Asia    Japan 2020-01-22
# 1       Japan                     JPN      Asia    Japan 2020-01-23
# 2       Japan                     JPN      Asia    Japan 2020-01-24
# 3       Japan                     JPN      Asia    Japan 2020-01-25
# 4       Japan                     JPN      Asia    Japan 2020-01-26
# ...       ...            ...      ...       ...      ...        ...
# 3621  Vietnam                     VNM      Asia  Vietnam 2021-06-24
# 3622  Vietnam                     VNM      Asia  Vietnam 2021-06-25
# 3623  Vietnam                     VNM      Asia  Vietnam 2021-06-26
# 3624  Vietnam                     VNM      Asia  Vietnam 2021-06-27
# 3625  Vietnam                     VNM      Asia  Vietnam 2021-06-28
#
#       total_cases  new_cases  new_cases_smoothed  total_deaths  ...  \
# 0             2.0        NaN                 NaN           NaN  ...
# 1             2.0        0.0                 NaN           NaN  ...
# 2             2.0        0.0                 NaN           NaN  ...
# 3             2.0        0.0                 NaN           NaN  ...
# 4             4.0        2.0                 NaN           NaN  ...
# ...           ...        ...                 ...           ...  ...
# 3621      14323.0      334.0             310.429          72.0  ...
# 3622      14537.0      214.0             289.857          74.0  ...
# 3623      15325.0      788.0             335.286          74.0  ...
# 3624      15740.0      415.0             354.571          76.0  ...
# 3625      16136.0      396.0             372.286          78.0  ...
#
#       extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# 0                 NaN                 79.370                 5.72
# 1                 NaN                 79.370                 5.72
# 2                 NaN                 79.370                 5.72
# 3                 NaN                 79.370                 5.72
# 4                 NaN                 79.370                 5.72
# ...               ...                    ...                  ...
# 3621              2.0                245.465                 6.00
# 3622              2.0                245.465                 6.00
# 3623              2.0                245.465                 6.00
# 3624              2.0                245.465                 6.00
# 3625              2.0                245.465                 6.00
#
#       female_smokers  male_smokers  handwashing_facilities  \
# 0               11.2          33.7                     NaN
# 1               11.2          33.7                     NaN
# 2               11.2          33.7                     NaN
# 3               11.2          33.7                     NaN
# 4               11.2          33.7                     NaN
# ...              ...           ...                     ...
# 3621             1.0          45.9                  85.847
# 3622             1.0          45.9                  85.847
# 3623             1.0          45.9                  85.847
# 3624             1.0          45.9                  85.847
# 3625             1.0          45.9                  85.847
#
#       hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                          13.05            84.63                    0.919
# 1                          13.05            84.63                    0.919
# 2                          13.05            84.63                    0.919
# 3                          13.05            84.63                    0.919
# 4                          13.05            84.63                    0.919
# ...                          ...              ...                      ...
# 3621                        2.60            75.40                    0.704
# 3622                        2.60            75.40                    0.704
# 3623                        2.60            75.40                    0.704
# 3624                        2.60            75.40                    0.704
# 3625                        2.60            75.40                    0.704
#
#       excess_mortality
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# ...                ...
# 3621               NaN
# 3622               NaN
# 3623               NaN
# 3624               NaN
# 3625               NaN
#
# [3626 rows x 62 columns]

# %%
e_a_trans.location.unique()
# Out:
# array(['Japan', 'China', 'Taiwan', 'South Korea', 'Indonesia',
#        'Philippines', 'Vietnam'], dtype=object)

# %% [markdown]
# ## 今日の新規感染者数

# %%
c_df_latest= df.loc[(df.date==latest_date_str) & (df.iso_code.str.len()==3)]
c_df_latest
# Out:
#       iso_code      continent     location       date  total_cases  new_cases  \
# 490        AFG           Asia  Afghanistan 2021-06-28     115751.0     4159.0
# 1482       ALB         Europe      Albania 2021-06-28     132513.0        1.0
# 1972       DZA         Africa      Algeria 2021-06-28     138840.0      375.0
# 2456       AND         Europe      Andorra 2021-06-28      13882.0        0.0
# 2922       AGO         Africa       Angola 2021-06-28      38613.0       57.0
# ...        ...            ...          ...        ...          ...        ...
# 96386      VEN  South America    Venezuela 2021-06-28     269635.0        0.0
# 96909      VNM           Asia      Vietnam 2021-06-28      16136.0      396.0
# 97969      YEM           Asia        Yemen 2021-06-28       6909.0        1.0
# 98437      ZMB         Africa       Zambia 2021-06-28     149661.0     1093.0
# 98903      ZWE         Africa     Zimbabwe 2021-06-28      47284.0      842.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 490              1692.714        4730.0       211.0               73.571  ...
# 1482                3.286        2456.0         0.0                0.286  ...
# 1972              363.714        3699.0         6.0                8.286  ...
# 2456                2.571         127.0         0.0                0.000  ...
# 2922              123.571         891.0         2.0                3.286  ...
# ...                   ...           ...         ...                  ...  ...
# 96386            1085.286        3068.0         0.0               13.571  ...
# 96909             372.286          78.0         2.0                1.286  ...
# 97969               2.857        1361.0         1.0                0.857  ...
# 98437            2718.571        2091.0        69.0               57.143  ...
# 98903             727.000        1749.0        13.0                9.143  ...
#
#        extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# 490                NaN                597.029                 9.59
# 1482               1.1                304.195                10.08
# 1972               0.5                278.364                 6.73
# 2456               NaN                109.135                 7.97
# 2922               NaN                276.045                 3.94
# ...                ...                    ...                  ...
# 96386              NaN                204.850                 6.47
# 96909              2.0                245.465                 6.00
# 97969             18.8                495.003                 5.35
# 98437             57.5                234.499                 3.94
# 98903             21.4                307.846                 1.82
#
#        female_smokers  male_smokers  handwashing_facilities  \
# 490               NaN           NaN                  37.746
# 1482              7.1          51.2                     NaN
# 1972              0.7          30.4                  83.741
# 2456             29.0          37.8                     NaN
# 2922              NaN           NaN                  26.664
# ...               ...           ...                     ...
# 96386             NaN           NaN                     NaN
# 96909             1.0          45.9                  85.847
# 97969             7.6          29.2                  49.542
# 98437             3.1          24.7                  13.938
# 98903             1.6          30.7                  36.791
#
#        hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 490                          0.50            64.83                    0.511
# 1482                         2.89            78.57                    0.795
# 1972                         1.90            76.88                    0.748
# 2456                          NaN            83.73                    0.868
# 2922                          NaN            61.15                    0.581
# ...                           ...              ...                      ...
# 96386                        0.80            72.06                    0.711
# 96909                        2.60            75.40                    0.704
# 97969                        0.70            66.12                    0.470
# 98437                        2.00            63.89                    0.584
# 98903                        1.70            61.49                    0.571
#
#        excess_mortality
# 490                 NaN
# 1482                NaN
# 1972                NaN
# 2456                NaN
# 2922                NaN
# ...                 ...
# 96386               NaN
# 96909               NaN
# 97969               NaN
# 98437               NaN
# 98903               NaN
#
# [198 rows x 60 columns]

# %% [markdown]
# ## 可視化

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook
#%matplotlib inline

# %%
world_df["case_rolling7ave"] = world_df.new_cases.rolling(7).mean()
world_df[["new_cases_smoothed","case_rolling7ave"]]
# Out:
#        new_cases_smoothed  case_rolling7ave
# 97001                 NaN               NaN
# 97002                 NaN               NaN
# 97003                 NaN               NaN
# 97004                 NaN               NaN
# 97005                 NaN               NaN
# ...                   ...               ...
# 97520          366325.286     366325.285714
# 97521          368583.714     368583.714286
# 97522          370779.714     370779.714286
# 97523          372146.143     372146.142857
# 97524          377089.429     377089.428571
#
# [524 rows x 2 columns]

# %%
fig=plt.figure(figsize=(12,8))
plt.subplot(2,2,1) # (rows, columns, panel number)
plt.title("Daily new confirmed COVID-19 cases in the world")
plt.bar(world_df.date,world_df.new_cases,label="New cases")
plt.plot_date(world_df["date"],world_df["new_cases_smoothed"],label="rolling 7-day average", fmt="-", color="orange")
plt.xticks(rotation=70)
plt.ylabel("people")
plt.grid(axis="y")
plt.legend()

plt.subplot(2,2,2) # (rows, columns, panel number)
plt.title("Daily new confirmed COVID-19 cases in the world(Recent)")
chart_data = world_df[world_df.date >= "2021-04-01"]
plt.bar(chart_data["date"],chart_data["new_cases"],label="New cases")
plt.plot_date(chart_data["date"],chart_data["new_cases_smoothed"],label="rolling 7-day average", fmt="-", color="orange")
plt.xticks(rotation=70)
plt.grid(axis="y")
plt.legend()

plt.subplot(2,2,3) # (rows, columns, panel number)
plt.title("Daily new deaths in the world")
plt.bar(world_df.date,world_df.new_deaths,label="New deaths")
plt.plot_date(world_df["date"],world_df["new_deaths_smoothed"],label="rolling 7-day average", fmt="-", color="orange")
plt.xticks(rotation=70)
plt.ylabel("people")
plt.grid(axis="y")
plt.legend()

plt.subplot(2,2,4) # (rows, columns, panel number)
plt.title("Daily new deaths in the world(Recent)")
chart_data = world_df[world_df.date >= "2021-04-01"]
plt.bar(chart_data["date"],chart_data["new_deaths"],label="New deaths")
plt.plot_date(chart_data["date"],chart_data["new_deaths_smoothed"],label="rolling 7-day average", fmt="-", color="orange")
plt.xticks(rotation=70)
plt.grid(axis="y")
plt.legend()

fig.text(0,1,"Latest: {}".format(latest_date_str),fontsize=8,ha="left",va="top")
fig.text(0,0
         ,"*Data Source : COVID-19 Dataset by Our World in Data",
        fontsize=7,ha="left",va="bottom")

fig.tight_layout()
# Out:
# <div id='bb37678e-b183-4035-aee4-21b0fdb835e3'></div>

# %%
fig.savefig("out/covid-owid-global-daily.png")

# %% [markdown]
# ### 国別

# %% [markdown]
# #### 人口100万人当たりの新規感染者数（3月以降）

# %%
min_date = pd.to_datetime("2021-03-01")
# 主要国 新規感染者
chart_data = c_trans[c_trans.date >= min_date]
dates = chart_data["date"].unique()
print(len(dates))
print(dates.max())
for i,cr in countries.iterrows():
    c = cr["country"]
    dates = chart_data.loc[chart_data["location"]==c]["date"]
    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else dates.max()
    print(len(chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"]))
    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"],label=c, fmt="-")
    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_cases_smoothed_per_million"],c
            ,fontsize=8,va="center")
# Out:
# 120
# 2021-06-28T00:00:00.000000000
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120

# %%
fig=plt.figure(figsize=(14,10))
min_date = pd.to_datetime("2021-03-01")
# 主要国 新規感染者
plt.subplot(2,2,1) # (rows, columns, panel number)
plt.title("Daily new confirmed COVID-19 cases\n per million population in major countries\n(rolling 7day ave.)")
plt.grid()
plt.xticks(rotation=70)
chart_data = c_trans[c_trans.date >= min_date]
dates = chart_data["date"].unique()
for i,cr in countries.iterrows():
    c = cr["country"]
    dates = chart_data.loc[chart_data["location"]==c]["date"]
    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else dates.max()
    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"],label=c, fmt="-")
    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_cases_smoothed_per_million"],c
            ,fontsize=8,va="center")
plt.legend(bbox_to_anchor=(0, 1),loc='upper left', fontsize=9)
# Out:
# <div id='c26373d4-b22b-43cb-8beb-c0c54f895c80'></div>

# %%
fig=plt.figure(figsize=(14,10))
min_date = pd.to_datetime("2021-03-01")
# 主要国 新規感染者
plt.subplot(2,2,1) # (rows, columns, panel number)
plt.title("Daily new confirmed COVID-19 cases\n per million population in major countries\n(rolling 7day ave.)")
plt.grid()
plt.xticks(rotation=45)
chart_data = c_trans[c_trans.date >= min_date]
for i,cr in countries.iterrows():
    c = cr["country"]
    dates = chart_data.loc[chart_data["location"]==c]["date"]
    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else dates.max()
    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"],label=c, fmt="-")
    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_cases_smoothed_per_million"],c
            ,fontsize=8,va="center")
plt.legend(bbox_to_anchor=(0, 1),loc='upper left', fontsize=9)

# 主要国 死者
plt.subplot(2,2,2) # (rows, columns, panel number)
plt.title("Daily new deaths in major countries(rolling 7day ave.)")
plt.grid()
plt.xticks(rotation=45)
chart_data = c_trans[c_trans.date >= min_date]
for i,cr in countries.iterrows():
    c = cr["country"]
    dates = chart_data.loc[chart_data["location"]==c]["date"]
    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else dates.max()
    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_deaths_smoothed"],label=c, fmt="-")
    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_deaths_smoothed"],c
            ,fontsize=8,va="center")
plt.legend(bbox_to_anchor=(0, 1),loc='upper left', fontsize=9)

plt.subplot(2,2,3) # (rows, columns, panel number)
plt.grid()
plt.xticks(rotation=45)
plt.title("Daily new confirmed COVID-19 cases\n per million population in Eastern Asia\n(rolling 7day ave.)")
chart_data = e_a_trans[e_a_trans.date >= min_date]
for i,cr in e_asia_c.iterrows():
    c = cr["country"]
    dates = chart_data.loc[chart_data["location"]==c]["date"]
    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else dates.max()
    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"],label=c, fmt="-")
    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_cases_smoothed_per_million"],c
             ,fontsize=8,va="center")
plt.legend(bbox_to_anchor=(0, 1),loc='upper left', fontsize=9)

plt.subplot(2,2,4) # (rows, columns, panel number)
plt.grid()
plt.xticks(rotation=45)
plt.title("Daily new deaths in Eastern Asia(rolling 7day ave.)")
chart_data = e_a_trans[e_a_trans.date >= min_date]
for i,cr in e_asia_c.iterrows():
    c = cr["country"]
    dates = chart_data.loc[chart_data["location"]==c]["date"]
    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else dates.max()
    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_deaths_smoothed"],label=c, fmt="-")
    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_deaths_smoothed"],c
             ,fontsize=8,va="center")
plt.legend(bbox_to_anchor=(0, 1),loc='upper left', fontsize=9)

fig.text(0,0.98,"Latest: {}".format(latest_date_str),fontsize=9,ha="left",va="top")
fig.text(0,0
         ,"*Data Source : COVID-19 Dataset by Our World in Data",
        fontsize=8,ha="left",va="bottom")
fig.tight_layout()
# Out:
# <div id='58615a92-aec2-4759-bc3b-1f81da65d53e'></div>

# %%
fig.savefig("out/covid-owid-countries-daily.png")

# %% [markdown]
# ### 新規感染者数

# %%
fig = plt.figure(figsize=(12,8))

plt.subplot(1,2,1) # (rows, columns, panel number)
plt.title("New confirmed COVID-19 cases worst 50")
plt.yticks(fontsize=9)
plt.xlabel("people")
chart_data = c_df_latest.sort_values("new_cases",ascending=False).head(50).sort_values("new_cases",ascending=True)
plt.barh(chart_data["location"],chart_data["new_cases"],label="new cases a day")
plt.grid(axis="x")
mean = int(c_df_latest.new_cases.mean())
plt.plot([mean,mean],[0,50], 'k--', lw=0.5)
plt.text(mean,50,"Mean:{}".format(mean),ha="center",fontsize=9)
plt.legend()

plt.subplot(1,2,2) # (rows, columns, panel number)
plt.title("New confirmed COVID-19 cases per million worst 50")
plt.yticks(fontsize=9)
plt.xlabel("people")
chart_data = c_df_latest.sort_values("new_cases_per_million",ascending=False).head(50).sort_values("new_cases_per_million",ascending=True)
plt.barh(chart_data["location"],chart_data["new_cases_per_million"],label="new cases a day per million")
plt.grid(axis="x")
mean = int(chart_data.new_cases_per_million.mean())
plt.plot([mean,mean],[0,50], 'k--', lw=0.5)
plt.text(mean,50,"Mean:{}".format(mean),ha="center",fontsize=9)
plt.legend()

fig.text(0,0.98,"Latest: {}".format(latest_date_str),fontsize=9,ha="left",va="top")
fig.text(0,0
         ,"*Data Source : COVID-19 Dataset by Our World in Data",
        fontsize=8,ha="left",va="bottom")


fig.tight_layout()
# Out:
# <div id='839d8ba4-cbc1-4b14-9bee-44f778318581'></div>

# %%
fig.savefig("out/covid-owid-global-latest-top.png")
