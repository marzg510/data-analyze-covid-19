# %%
import pandas as pd

# %%
df = pd.read_csv("covid-19-data/public/data/owid-covid-data.csv")
df.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1      AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    female_smokers  male_smokers  handwashing_facilities  \
# 0             NaN           NaN                  37.746
# 1             NaN           NaN                  37.746
# 2             NaN           NaN                  37.746
# 3             NaN           NaN                  37.746
# 4             NaN           NaN                  37.746
#
#    hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                         0.5            64.83                    0.511
# 1                         0.5            64.83                    0.511
# 2                         0.5            64.83                    0.511
# 3                         0.5            64.83                    0.511
# 4                         0.5            64.83                    0.511
#
#    excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                   NaN                          NaN
# 1                                   NaN                          NaN
# 2                                   NaN                          NaN
# 3                                   NaN                          NaN
# 4                                   NaN                          NaN
#
#    excess_mortality  excess_mortality_cumulative_per_million
# 0               NaN                                      NaN
# 1               NaN                                      NaN
# 2               NaN                                      NaN
# 3               NaN                                      NaN
# 4               NaN                                      NaN
#
# [5 rows x 65 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125311 entries, 0 to 125310
# Data columns (total 65 columns):
#  #   Column                                   Non-Null Count   Dtype
# ---  ------                                   --------------   -----
#  0   iso_code                                 125311 non-null  object
#  1   continent                                119634 non-null  object
#  2   location                                 125311 non-null  object
#  3   date                                     125311 non-null  object
#  4   total_cases                              118548 non-null  float64
#  5   new_cases                                118544 non-null  float64
#  6   new_cases_smoothed                       117530 non-null  float64
#  7   total_deaths                             107633 non-null  float64
#  8   new_deaths                               107786 non-null  float64
#  9   new_deaths_smoothed                      117530 non-null  float64
#  10  total_cases_per_million                  117925 non-null  float64
#  11  new_cases_per_million                    117921 non-null  float64
#  12  new_cases_smoothed_per_million           116912 non-null  float64
#  13  total_deaths_per_million                 107023 non-null  float64
#  14  new_deaths_per_million                   107176 non-null  float64
#  15  new_deaths_smoothed_per_million          116912 non-null  float64
#  16  reproduction_rate                        100726 non-null  float64
#  17  icu_patients                             15373 non-null   float64
#  18  icu_patients_per_million                 15373 non-null   float64
#  19  hosp_patients                            17465 non-null   float64
#  20  hosp_patients_per_million                17465 non-null   float64
#  21  weekly_icu_admissions                    1293 non-null    float64
#  22  weekly_icu_admissions_per_million        1293 non-null    float64
#  23  weekly_hosp_admissions                   2258 non-null    float64
#  24  weekly_hosp_admissions_per_million       2258 non-null    float64
#  25  new_tests                                53736 non-null   float64
#  26  total_tests                              53887 non-null   float64
#  27  total_tests_per_thousand                 53887 non-null   float64
#  28  new_tests_per_thousand                   53736 non-null   float64
#  29  new_tests_smoothed                       64878 non-null   float64
#  30  new_tests_smoothed_per_thousand          64878 non-null   float64
#  31  positive_rate                            60954 non-null   float64
#  32  tests_per_case                           60311 non-null   float64
#  33  tests_units                              66845 non-null   object
#  34  total_vaccinations                       29708 non-null   float64
#  35  people_vaccinated                        28383 non-null   float64
#  36  people_fully_vaccinated                  25279 non-null   float64
#  37  total_boosters                           4192 non-null    float64
#  38  new_vaccinations                         24525 non-null   float64
#  39  new_vaccinations_smoothed                53639 non-null   float64
#  40  total_vaccinations_per_hundred           29708 non-null   float64
#  41  people_vaccinated_per_hundred            28383 non-null   float64
#  42  people_fully_vaccinated_per_hundred      25279 non-null   float64
#  43  total_boosters_per_hundred               4192 non-null    float64
#  44  new_vaccinations_smoothed_per_million    53639 non-null   float64
#  45  stringency_index                         104479 non-null  float64
#  46  population                               124432 non-null  float64
#  47  population_density                       115746 non-null  float64
#  48  median_age                               110453 non-null  float64
#  49  aged_65_older                            109229 non-null  float64
#  50  aged_70_older                            109849 non-null  float64
#  51  gdp_per_capita                           111110 non-null  float64
#  52  extreme_poverty                          74356 non-null   float64
#  53  cardiovasc_death_rate                    110714 non-null  float64
#  54  diabetes_prevalence                      114213 non-null  float64
#  55  female_smokers                           86270 non-null   float64
#  56  male_smokers                             85020 non-null   float64
#  57  handwashing_facilities                   55718 non-null   float64
#  58  hospital_beds_per_thousand               100645 non-null  float64
#  59  life_expectancy                          118859 non-null  float64
#  60  human_development_index                  110809 non-null  float64
#  61  excess_mortality_cumulative_absolute     4563 non-null    float64
#  62  excess_mortality_cumulative              4563 non-null    float64
#  63  excess_mortality                         4563 non-null    float64
#  64  excess_mortality_cumulative_per_million  4563 non-null    float64
# dtypes: float64(60), object(5)
# memory usage: 62.1+ MB

# %%
df.describe()
# Out:
#         total_cases      new_cases  new_cases_smoothed  total_deaths  \
# count  1.185480e+05  118544.000000       117530.000000  1.076330e+05
# mean   1.501679e+06    6455.285894         6475.636971  3.768573e+04
# std    1.001869e+07   39202.668094        38800.615144  2.243444e+05
# min    1.000000e+00  -74347.000000        -6223.000000  1.000000e+00
# 25%    2.101000e+03       3.000000            9.571000  7.100000e+01
# 50%    2.237950e+04      94.000000          117.286000  6.270000e+02
# 75%    2.257605e+05     937.000000          989.714000  5.487000e+03
# max    2.424983e+08  905955.000000       826438.429000  4.929776e+06
#
#           new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  107786.000000        117530.000000            117925.000000
# mean      144.047502           131.512691             18652.982691
# std       785.583901           735.845840             31366.083714
# min     -1918.000000          -232.143000                 0.001000
# 25%         0.000000             0.000000               373.463000
# 50%         2.000000             1.714000              2916.981000
# 75%        19.000000            16.000000             23094.092000
# max     18006.000000         14703.143000            223142.251000
#
#        new_cases_per_million  new_cases_smoothed_per_million  \
# count          117921.000000                   116912.000000
# mean               84.721668                       84.696400
# std               196.316967                      165.374755
# min             -3125.829000                     -272.971000
# 25%                 0.292000                        1.585000
# 50%                10.900000                       15.133500
# 75%                82.727000                       92.322250
# max              8620.690000                     3385.473000
#
#        total_deaths_per_million  ...  female_smokers  male_smokers  \
# count              107023.00000  ...    86270.000000  85020.000000
# mean                  386.52434  ...       10.591798     32.743238
# std                   646.02796  ...       10.503878     13.508404
# min                     0.00100  ...        0.100000      7.700000
# 25%                    10.84600  ...        1.900000     21.600000
# 50%                    72.78000  ...        6.300000     31.400000
# 75%                   479.60050  ...       19.300000     41.300000
# max                  5993.66000  ...       44.000000     78.100000
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# count            55718.000000               100645.000000    118859.000000
# mean                50.886463                    3.030776        73.258756
# std                 31.824830                    2.456880         7.534963
# min                  1.188000                    0.100000        53.280000
# 25%                 20.859000                    1.300000        67.920000
# 50%                 49.839000                    2.400000        74.620000
# 75%                 83.241000                    4.000000        78.740000
# max                100.000000                   13.800000        86.750000
#
#        human_development_index  excess_mortality_cumulative_absolute  \
# count            110809.000000                           4563.000000
# mean                  0.726353                          29867.812601
# std                   0.150067                          84621.602001
# min                   0.394000                         -31959.400000
# 25%                   0.602000                           -230.100000
# 50%                   0.744000                           1811.700000
# 75%                   0.848000                          18465.750000
# max                   0.957000                         746026.500000
#
#        excess_mortality_cumulative  excess_mortality  \
# count                  4563.000000       4563.000000
# mean                      8.250493         15.553517
# std                      15.739907         31.104837
# min                     -27.350000        -95.920000
# 25%                      -1.245000         -1.100000
# 50%                       4.790000          6.160000
# 75%                      13.295000         21.745000
# max                     106.830000        373.280000
#
#        excess_mortality_cumulative_per_million
# count                              4563.000000
# mean                                733.690022
# std                                1120.115624
# min                               -1749.128494
# 25%                                 -51.045544
# 50%                                 314.754547
# 75%                                1264.341911
# max                                6124.441930
#
# [8 rows x 60 columns]

# %%
df.continent.unique()
# Out:
# array(['Asia', nan, 'Europe', 'Africa', 'North America', 'South America',
#        'Oceania'], dtype=object)

# %%
df.loc[df.continent.isna()].location.unique()
# Out:
# array(['Africa', 'Asia', 'Europe', 'European Union', 'International',
#        'North America', 'Oceania', 'South America', 'World'], dtype=object)

# %%
df.loc[df.location=="International"]
# Out:
#        iso_code continent       location        date  total_cases  new_cases  \
# 52966  OWID_INT       NaN  International  2020-02-07         61.0       61.0
# 52967  OWID_INT       NaN  International  2020-02-08         61.0        0.0
# 52968  OWID_INT       NaN  International  2020-02-09         64.0        3.0
# 52969  OWID_INT       NaN  International  2020-02-10        135.0       71.0
# 52970  OWID_INT       NaN  International  2020-02-11        135.0        0.0
# ...         ...       ...            ...         ...          ...        ...
# 53584  OWID_INT       NaN  International  2021-10-17        721.0        0.0
# 53585  OWID_INT       NaN  International  2021-10-18        721.0        0.0
# 53586  OWID_INT       NaN  International  2021-10-19        721.0        0.0
# 53587  OWID_INT       NaN  International  2021-10-20        721.0        0.0
# 53588  OWID_INT       NaN  International  2021-10-21        721.0        0.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 52966                 NaN           NaN         NaN                  NaN  ...
# 52967                 NaN           NaN         NaN                  NaN  ...
# 52968                 NaN           NaN         NaN                  NaN  ...
# 52969                 NaN           NaN         NaN                  NaN  ...
# 52970                 NaN           NaN         NaN                  NaN  ...
# ...                   ...           ...         ...                  ...  ...
# 53584                 0.0          15.0         0.0                  0.0  ...
# 53585                 0.0          15.0         0.0                  0.0  ...
# 53586                 0.0          15.0         0.0                  0.0  ...
# 53587                 0.0          15.0         0.0                  0.0  ...
# 53588                 0.0          15.0         0.0                  0.0  ...
#
#        female_smokers  male_smokers  handwashing_facilities  \
# 52966             NaN           NaN                     NaN
# 52967             NaN           NaN                     NaN
# 52968             NaN           NaN                     NaN
# 52969             NaN           NaN                     NaN
# 52970             NaN           NaN                     NaN
# ...               ...           ...                     ...
# 53584             NaN           NaN                     NaN
# 53585             NaN           NaN                     NaN
# 53586             NaN           NaN                     NaN
# 53587             NaN           NaN                     NaN
# 53588             NaN           NaN                     NaN
#
#        hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 52966                         NaN              NaN                      NaN
# 52967                         NaN              NaN                      NaN
# 52968                         NaN              NaN                      NaN
# 52969                         NaN              NaN                      NaN
# 52970                         NaN              NaN                      NaN
# ...                           ...              ...                      ...
# 53584                         NaN              NaN                      NaN
# 53585                         NaN              NaN                      NaN
# 53586                         NaN              NaN                      NaN
# 53587                         NaN              NaN                      NaN
# 53588                         NaN              NaN                      NaN
#
#        excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 52966                                   NaN                          NaN
# 52967                                   NaN                          NaN
# 52968                                   NaN                          NaN
# 52969                                   NaN                          NaN
# 52970                                   NaN                          NaN
# ...                                     ...                          ...
# 53584                                   NaN                          NaN
# 53585                                   NaN                          NaN
# 53586                                   NaN                          NaN
# 53587                                   NaN                          NaN
# 53588                                   NaN                          NaN
#
#        excess_mortality  excess_mortality_cumulative_per_million
# 52966               NaN                                      NaN
# 52967               NaN                                      NaN
# 52968               NaN                                      NaN
# 52969               NaN                                      NaN
# 52970               NaN                                      NaN
# ...                 ...                                      ...
# 53584               NaN                                      NaN
# 53585               NaN                                      NaN
# 53586               NaN                                      NaN
# 53587               NaN                                      NaN
# 53588               NaN                                      NaN
#
# [623 rows x 65 columns]

# %%
df.location.unique()
# Out:
# array(['Afghanistan', 'Africa', 'Albania', 'Algeria', 'Andorra', 'Angola',
#        'Anguilla', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        'Asia', 'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain',
#        'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin',
#        'Bermuda', 'Bhutan', 'Bolivia', 'Bonaire Sint Eustatius and Saba',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Brunei', 'Bulgaria', 'Burkina Faso',
#        'Burundi', 'Cambodia', 'Cameroon', 'Canada', 'Cape Verde',
#        'Cayman Islands', 'Central African Republic', 'Chad', 'Chile',
#        'China', 'Colombia', 'Comoros', 'Congo', 'Cook Islands',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Curacao',
#        'Cyprus', 'Czechia', 'Democratic Republic of Congo', 'Denmark',
#        'Djibouti', 'Dominica', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Estonia',
#        'Eswatini', 'Ethiopia', 'Europe', 'European Union',
#        'Faeroe Islands', 'Falkland Islands', 'Fiji', 'Finland', 'France',
#        'French Polynesia', 'Gabon', 'Gambia', 'Georgia', 'Germany',
#        'Ghana', 'Gibraltar', 'Greece', 'Greenland', 'Grenada',
#        'Guatemala', 'Guernsey', 'Guinea', 'Guinea-Bissau', 'Guyana',
#        'Haiti', 'Honduras', 'Hong Kong', 'Hungary', 'Iceland', 'India',
#        'Indonesia', 'International', 'Iran', 'Iraq', 'Ireland',
#        'Isle of Man', 'Israel', 'Italy', 'Jamaica', 'Japan', 'Jersey',
#        'Jordan', 'Kazakhstan', 'Kenya', 'Kiribati', 'Kosovo', 'Kuwait',
#        'Kyrgyzstan', 'Laos', 'Latvia', 'Lebanon', 'Lesotho', 'Liberia',
#        'Libya', 'Liechtenstein', 'Lithuania', 'Luxembourg', 'Macao',
#        'Madagascar', 'Malawi', 'Malaysia', 'Maldives', 'Mali', 'Malta',
#        'Marshall Islands', 'Mauritania', 'Mauritius', 'Mexico',
#        'Micronesia (country)', 'Moldova', 'Monaco', 'Mongolia',
#        'Montenegro', 'Montserrat', 'Morocco', 'Mozambique', 'Myanmar',
#        'Namibia', 'Nauru', 'Nepal', 'Netherlands', 'New Caledonia',
#        'New Zealand', 'Nicaragua', 'Niger', 'Nigeria', 'Niue',
#        'North America', 'North Macedonia', 'Northern Cyprus', 'Norway',
#        'Oceania', 'Oman', 'Pakistan', 'Palau', 'Palestine', 'Panama',
#        'Papua New Guinea', 'Paraguay', 'Peru', 'Philippines', 'Pitcairn',
#        'Poland', 'Portugal', 'Qatar', 'Romania', 'Russia', 'Rwanda',
#        'Saint Helena', 'Saint Kitts and Nevis', 'Saint Lucia',
#        'Saint Vincent and the Grenadines', 'Samoa', 'San Marino',
#        'Sao Tome and Principe', 'Saudi Arabia', 'Senegal', 'Serbia',
#        'Seychelles', 'Sierra Leone', 'Singapore',
#        'Sint Maarten (Dutch part)', 'Slovakia', 'Slovenia',
#        'Solomon Islands', 'Somalia', 'South Africa', 'South America',
#        'South Korea', 'South Sudan', 'Spain', 'Sri Lanka', 'Sudan',
#        'Suriname', 'Sweden', 'Switzerland', 'Syria', 'Taiwan',
#        'Tajikistan', 'Tanzania', 'Thailand', 'Timor', 'Togo', 'Tokelau',
#        'Tonga', 'Trinidad and Tobago', 'Tunisia', 'Turkey',
#        'Turkmenistan', 'Turks and Caicos Islands', 'Tuvalu', 'Uganda',
#        'Ukraine', 'United Arab Emirates', 'United Kingdom',
#        'United States', 'Uruguay', 'Uzbekistan', 'Vanuatu', 'Vatican',
#        'Venezuela', 'Vietnam', 'Wallis and Futuna', 'World', 'Yemen',
#        'Zambia', 'Zimbabwe'], dtype=object)

# %%
df["date"] = pd.to_datetime(df["date"])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125311 entries, 0 to 125310
# Data columns (total 65 columns):
#  #   Column                                   Non-Null Count   Dtype
# ---  ------                                   --------------   -----
#  0   iso_code                                 125311 non-null  object
#  1   continent                                119634 non-null  object
#  2   location                                 125311 non-null  object
#  3   date                                     125311 non-null  datetime64[ns]
#  4   total_cases                              118548 non-null  float64
#  5   new_cases                                118544 non-null  float64
#  6   new_cases_smoothed                       117530 non-null  float64
#  7   total_deaths                             107633 non-null  float64
#  8   new_deaths                               107786 non-null  float64
#  9   new_deaths_smoothed                      117530 non-null  float64
#  10  total_cases_per_million                  117925 non-null  float64
#  11  new_cases_per_million                    117921 non-null  float64
#  12  new_cases_smoothed_per_million           116912 non-null  float64
#  13  total_deaths_per_million                 107023 non-null  float64
#  14  new_deaths_per_million                   107176 non-null  float64
#  15  new_deaths_smoothed_per_million          116912 non-null  float64
#  16  reproduction_rate                        100726 non-null  float64
#  17  icu_patients                             15373 non-null   float64
#  18  icu_patients_per_million                 15373 non-null   float64
#  19  hosp_patients                            17465 non-null   float64
#  20  hosp_patients_per_million                17465 non-null   float64
#  21  weekly_icu_admissions                    1293 non-null    float64
#  22  weekly_icu_admissions_per_million        1293 non-null    float64
#  23  weekly_hosp_admissions                   2258 non-null    float64
#  24  weekly_hosp_admissions_per_million       2258 non-null    float64
#  25  new_tests                                53736 non-null   float64
#  26  total_tests                              53887 non-null   float64
#  27  total_tests_per_thousand                 53887 non-null   float64
#  28  new_tests_per_thousand                   53736 non-null   float64
#  29  new_tests_smoothed                       64878 non-null   float64
#  30  new_tests_smoothed_per_thousand          64878 non-null   float64
#  31  positive_rate                            60954 non-null   float64
#  32  tests_per_case                           60311 non-null   float64
#  33  tests_units                              66845 non-null   object
#  34  total_vaccinations                       29708 non-null   float64
#  35  people_vaccinated                        28383 non-null   float64
#  36  people_fully_vaccinated                  25279 non-null   float64
#  37  total_boosters                           4192 non-null    float64
#  38  new_vaccinations                         24525 non-null   float64
#  39  new_vaccinations_smoothed                53639 non-null   float64
#  40  total_vaccinations_per_hundred           29708 non-null   float64
#  41  people_vaccinated_per_hundred            28383 non-null   float64
#  42  people_fully_vaccinated_per_hundred      25279 non-null   float64
#  43  total_boosters_per_hundred               4192 non-null    float64
#  44  new_vaccinations_smoothed_per_million    53639 non-null   float64
#  45  stringency_index                         104479 non-null  float64
#  46  population                               124432 non-null  float64
#  47  population_density                       115746 non-null  float64
#  48  median_age                               110453 non-null  float64
#  49  aged_65_older                            109229 non-null  float64
#  50  aged_70_older                            109849 non-null  float64
#  51  gdp_per_capita                           111110 non-null  float64
#  52  extreme_poverty                          74356 non-null   float64
#  53  cardiovasc_death_rate                    110714 non-null  float64
#  54  diabetes_prevalence                      114213 non-null  float64
#  55  female_smokers                           86270 non-null   float64
#  56  male_smokers                             85020 non-null   float64
#  57  handwashing_facilities                   55718 non-null   float64
#  58  hospital_beds_per_thousand               100645 non-null  float64
#  59  life_expectancy                          118859 non-null  float64
#  60  human_development_index                  110809 non-null  float64
#  61  excess_mortality_cumulative_absolute     4563 non-null    float64
#  62  excess_mortality_cumulative              4563 non-null    float64
#  63  excess_mortality                         4563 non-null    float64
#  64  excess_mortality_cumulative_per_million  4563 non-null    float64
# dtypes: datetime64[ns](1), float64(60), object(4)
# memory usage: 62.1+ MB

# %% [markdown]
# ## 最新日付チェック

# %%
import datetime
#latest_date_str = (df.date.max()-datetime.timedelta(days=1)).strftime("%Y-%m-%d")
latest_date_str = df.date.max().strftime("%Y-%m-%d")
latest_date_str
# Out:
# '2021-10-21'

# %% [markdown]
# ## 全世界のデータのみ

# %%
world_df = df.copy().loc[df.location=="World"]
world_df.tail()
# Out:
#         iso_code continent location       date  total_cases  new_cases  \
# 123582  OWID_WRL       NaN    World 2021-10-17  240706344.0   301327.0
# 123583  OWID_WRL       NaN    World 2021-10-18  241132266.0   425922.0
# 123584  OWID_WRL       NaN    World 2021-10-19  241573517.0   441251.0
# 123585  OWID_WRL       NaN    World 2021-10-20  242035641.0   462124.0
# 123586  OWID_WRL       NaN    World 2021-10-21  242498327.0   462686.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 123582          403868.000     4898674.0      4161.0             6695.143
# 123583          408517.571     4905094.0      6420.0             6790.286
# 123584          409760.571     4913600.0      8506.0             6855.000
# 123585          409683.143     4922112.0      8512.0             6830.143
# 123586          412384.714     4929776.0      7664.0             6800.286
#
#         ...  female_smokers  male_smokers  handwashing_facilities  \
# 123582  ...           6.434        34.635                   60.13
# 123583  ...           6.434        34.635                   60.13
# 123584  ...           6.434        34.635                   60.13
# 123585  ...           6.434        34.635                   60.13
# 123586  ...           6.434        34.635                   60.13
#
#         hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 123582                       2.705            72.58                    0.737
# 123583                       2.705            72.58                    0.737
# 123584                       2.705            72.58                    0.737
# 123585                       2.705            72.58                    0.737
# 123586                       2.705            72.58                    0.737
#
#         excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 123582                                   NaN                          NaN
# 123583                                   NaN                          NaN
# 123584                                   NaN                          NaN
# 123585                                   NaN                          NaN
# 123586                                   NaN                          NaN
#
#         excess_mortality  excess_mortality_cumulative_per_million
# 123582               NaN                                      NaN
# 123583               NaN                                      NaN
# 123584               NaN                                      NaN
# 123585               NaN                                      NaN
# 123586               NaN                                      NaN
#
# [5 rows x 65 columns]

# %% [markdown]
# ### 主要国の定義

# %%
countries = pd.DataFrame([
    ("Japan",""),
    ("United States",""),
    ("India",""),
    ("Indonesia",""),
    ("Spain",""),
    ("Brazil",""),
    ("France",""),
    ("United Kingdom",""),
    ("Russia",""),
    ("Turkey",""),
#    ("South Africa",""),
    ("Iran",""),
#    ("Ecuador",""),
],columns=["country","text_disp_date"])
countries
# Out:
#            country text_disp_date
# 0            Japan
# 1    United States
# 2            India
# 3        Indonesia
# 4            Spain
# 5           Brazil
# 6           France
# 7   United Kingdom
# 8           Russia
# 9           Turkey
# 10            Iran

# %%
# 東Asia 主要国
e_asia_c = pd.DataFrame([
    ("Japan",""),
    ("China",""),
    ("Taiwan",""),
    ("South Korea",""),
    ("Indonesia",""),
    ("Philippines",""),
    ("Vietnam",""),
    ("Myanmar",""),
    ("Thailand",""),
],columns=["country","text_disp_date"])
e_asia_c
# Out:
#        country text_disp_date
# 0        Japan
# 1        China
# 2       Taiwan
# 3  South Korea
# 4    Indonesia
# 5  Philippines
# 6      Vietnam
# 7      Myanmar
# 8     Thailand

# %%
c_trans = pd.merge(countries, df, left_on="country", right_on="location",how="inner")
c_trans.head()
# Out:
#   country text_disp_date iso_code continent location       date  total_cases  \
# 0   Japan                     JPN      Asia    Japan 2020-01-22          2.0
# 1   Japan                     JPN      Asia    Japan 2020-01-23          2.0
# 2   Japan                     JPN      Asia    Japan 2020-01-24          2.0
# 3   Japan                     JPN      Asia    Japan 2020-01-25          2.0
# 4   Japan                     JPN      Asia    Japan 2020-01-26          4.0
#
#    new_cases  new_cases_smoothed  total_deaths  ...  female_smokers  \
# 0        NaN                 NaN           NaN  ...            11.2
# 1        0.0                 NaN           NaN  ...            11.2
# 2        0.0                 NaN           NaN  ...            11.2
# 3        0.0                 NaN           NaN  ...            11.2
# 4        2.0                 NaN           NaN  ...            11.2
#
#    male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 0          33.7                     NaN                       13.05
# 1          33.7                     NaN                       13.05
# 2          33.7                     NaN                       13.05
# 3          33.7                     NaN                       13.05
# 4          33.7                     NaN                       13.05
#
#    life_expectancy  human_development_index  \
# 0            84.63                    0.919
# 1            84.63                    0.919
# 2            84.63                    0.919
# 3            84.63                    0.919
# 4            84.63                    0.919
#
#    excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                   NaN                          NaN
# 1                                   NaN                          NaN
# 2                                   NaN                          NaN
# 3                                   NaN                          NaN
# 4                                   NaN                          NaN
#
#    excess_mortality  excess_mortality_cumulative_per_million
# 0               NaN                                      NaN
# 1               NaN                                      NaN
# 2               NaN                                      NaN
# 3               NaN                                      NaN
# 4               NaN                                      NaN
#
# [5 rows x 67 columns]

# %%
c_trans.location.unique()
# Out:
# array(['Japan', 'United States', 'India', 'Indonesia', 'Spain', 'Brazil',
#        'France', 'United Kingdom', 'Russia', 'Turkey', 'Iran'],
#       dtype=object)

# %%
c_trans.loc[c_trans.date==latest_date_str][["country","date","total_deaths","total_deaths_per_million"]].sort_values("total_deaths_per_million",ascending=False)
# Out:
#              country       date  total_deaths  total_deaths_per_million
# 3740          Brazil 2021-10-21      604679.0                  2825.689
# 1277   United States 2021-10-21      733213.0                  2202.403
# 5007  United Kingdom 2021-10-21      139562.0                  2046.150
# 3136           Spain 2021-10-21       87102.0                  1863.335
# 4377          France 2021-10-21      118339.0                  1751.503
# 5637          Russia 2021-10-21      223331.0                  1530.587
# 6838            Iran 2021-10-21      124763.0                  1467.304
# 6227          Turkey 2021-10-21       68472.0                   805.148
# 2507       Indonesia 2021-10-21      143120.0                   517.872
# 1908           India 2021-10-21      453042.0                   325.132
# 638            Japan 2021-10-21       18182.0                   144.243

# %%
e_a_trans = pd.merge(e_asia_c, df, left_on="country", right_on="location",how="inner")
e_a_trans
# Out:
#        country text_disp_date iso_code continent  location       date  \
# 0        Japan                     JPN      Asia     Japan 2020-01-22
# 1        Japan                     JPN      Asia     Japan 2020-01-23
# 2        Japan                     JPN      Asia     Japan 2020-01-24
# 3        Japan                     JPN      Asia     Japan 2020-01-25
# 4        Japan                     JPN      Asia     Japan 2020-01-26
# ...        ...            ...      ...       ...       ...        ...
# 5657  Thailand                     THA      Asia  Thailand 2021-10-17
# 5658  Thailand                     THA      Asia  Thailand 2021-10-18
# 5659  Thailand                     THA      Asia  Thailand 2021-10-19
# 5660  Thailand                     THA      Asia  Thailand 2021-10-20
# 5661  Thailand                     THA      Asia  Thailand 2021-10-21
#
#       total_cases  new_cases  new_cases_smoothed  total_deaths  ...  \
# 0             2.0        NaN                 NaN           NaN  ...
# 1             2.0        0.0                 NaN           NaN  ...
# 2             2.0        0.0                 NaN           NaN  ...
# 3             2.0        0.0                 NaN           NaN  ...
# 4             4.0        2.0                 NaN           NaN  ...
# ...           ...        ...                 ...           ...  ...
# 5657    1783701.0    10863.0           10402.429       18273.0  ...
# 5658    1793812.0    10111.0           10413.286       18336.0  ...
# 5659    1802934.0     9122.0           10367.143       18407.0  ...
# 5660    1811852.0     8918.0           10203.429       18486.0  ...
# 5661    1821579.0     9727.0            9982.143       18559.0  ...
#
#       female_smokers  male_smokers  handwashing_facilities  \
# 0               11.2          33.7                     NaN
# 1               11.2          33.7                     NaN
# 2               11.2          33.7                     NaN
# 3               11.2          33.7                     NaN
# 4               11.2          33.7                     NaN
# ...              ...           ...                     ...
# 5657             1.9          38.8                   90.67
# 5658             1.9          38.8                   90.67
# 5659             1.9          38.8                   90.67
# 5660             1.9          38.8                   90.67
# 5661             1.9          38.8                   90.67
#
#       hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                          13.05            84.63                    0.919
# 1                          13.05            84.63                    0.919
# 2                          13.05            84.63                    0.919
# 3                          13.05            84.63                    0.919
# 4                          13.05            84.63                    0.919
# ...                          ...              ...                      ...
# 5657                        2.10            77.15                    0.777
# 5658                        2.10            77.15                    0.777
# 5659                        2.10            77.15                    0.777
# 5660                        2.10            77.15                    0.777
# 5661                        2.10            77.15                    0.777
#
#       excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                      NaN                          NaN
# 1                                      NaN                          NaN
# 2                                      NaN                          NaN
# 3                                      NaN                          NaN
# 4                                      NaN                          NaN
# ...                                    ...                          ...
# 5657                                   NaN                          NaN
# 5658                                   NaN                          NaN
# 5659                                   NaN                          NaN
# 5660                                   NaN                          NaN
# 5661                                   NaN                          NaN
#
#       excess_mortality  excess_mortality_cumulative_per_million
# 0                  NaN                                      NaN
# 1                  NaN                                      NaN
# 2                  NaN                                      NaN
# 3                  NaN                                      NaN
# 4                  NaN                                      NaN
# ...                ...                                      ...
# 5657               NaN                                      NaN
# 5658               NaN                                      NaN
# 5659               NaN                                      NaN
# 5660               NaN                                      NaN
# 5661               NaN                                      NaN
#
# [5662 rows x 67 columns]

# %%
e_a_trans.location.unique()
# Out:
# array(['Japan', 'China', 'Taiwan', 'South Korea', 'Indonesia',
#        'Philippines', 'Vietnam', 'Myanmar', 'Thailand'], dtype=object)

# %% [markdown]
# ## 今日の新規感染者数

# %%
#c_df_latest = df.loc[(df.date==pd.to_datetime(latest_date_str)-datetime.timedelta(days=1)) & (df.iso_code.str.len()==3)]
c_df_latest = df.loc[(df.date==pd.to_datetime(latest_date_str)) & (df.iso_code.str.len()==3)]

c_df_latest
# Out:
#        iso_code      continent     location       date  total_cases  \
# 605         AFG           Asia  Afghanistan 2021-10-21     155891.0
# 1827        ALB         Europe      Albania 2021-10-21     180029.0
# 2432        DZA         Africa      Algeria 2021-10-21     205599.0
# 3031        AND         Europe      Andorra 2021-10-21      15382.0
# 3612        AGO         Africa       Angola 2021-10-21      63567.0
# ...         ...            ...          ...        ...          ...
# 122099      VEN  South America    Venezuela 2021-10-21     396477.0
# 122737      VNM           Asia      Vietnam 2021-10-21     877537.0
# 124146      YEM           Asia        Yemen 2021-10-21       9635.0
# 124729      ZMB         Africa       Zambia 2021-10-21     209589.0
# 125310      ZWE         Africa     Zimbabwe 2021-10-21     132540.0
#
#         new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 605          32.0              29.857        7249.0         2.0
# 1827        566.0             480.286        2855.0         6.0
# 2432         70.0              84.857        5881.0         3.0
# 3031          0.0               8.000         130.0         0.0
# 3612        227.0             168.857        1685.0         3.0
# ...           ...                 ...           ...         ...
# 122099        0.0            1104.857        4763.0         0.0
# 122737     3636.0            3385.000       21487.0        71.0
# 124146       39.0              24.000        1831.0        10.0
# 124729       18.0              22.571        3658.0         0.0
# 125310      103.0              41.286        4662.0         3.0
#
#         new_deaths_smoothed  ...  female_smokers  male_smokers  \
# 605                   1.571  ...             NaN           NaN
# 1827                  8.286  ...             7.1          51.2
# 2432                  2.429  ...             0.7          30.4
# 3031                  0.000  ...            29.0          37.8
# 3612                  4.571  ...             NaN           NaN
# ...                     ...  ...             ...           ...
# 122099               11.714  ...             NaN           NaN
# 122737               76.714  ...             1.0          45.9
# 124146                5.429  ...             7.6          29.2
# 124729                0.143  ...             3.1          24.7
# 125310                1.000  ...             1.6          30.7
#
#         handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 605                     37.746                        0.50            64.83
# 1827                       NaN                        2.89            78.57
# 2432                    83.741                        1.90            76.88
# 3031                       NaN                         NaN            83.73
# 3612                    26.664                         NaN            61.15
# ...                        ...                         ...              ...
# 122099                     NaN                        0.80            72.06
# 122737                  85.847                        2.60            75.40
# 124146                  49.542                        0.70            66.12
# 124729                  13.938                        2.00            63.89
# 125310                  36.791                        1.70            61.49
#
#         human_development_index  excess_mortality_cumulative_absolute  \
# 605                       0.511                                   NaN
# 1827                      0.795                                   NaN
# 2432                      0.748                                   NaN
# 3031                      0.868                                   NaN
# 3612                      0.581                                   NaN
# ...                         ...                                   ...
# 122099                    0.711                                   NaN
# 122737                    0.704                                   NaN
# 124146                    0.470                                   NaN
# 124729                    0.584                                   NaN
# 125310                    0.571                                   NaN
#
#         excess_mortality_cumulative  excess_mortality  \
# 605                             NaN               NaN
# 1827                            NaN               NaN
# 2432                            NaN               NaN
# 3031                            NaN               NaN
# 3612                            NaN               NaN
# ...                             ...               ...
# 122099                          NaN               NaN
# 122737                          NaN               NaN
# 124146                          NaN               NaN
# 124729                          NaN               NaN
# 125310                          NaN               NaN
#
#         excess_mortality_cumulative_per_million
# 605                                         NaN
# 1827                                        NaN
# 2432                                        NaN
# 3031                                        NaN
# 3612                                        NaN
# ...                                         ...
# 122099                                      NaN
# 122737                                      NaN
# 124146                                      NaN
# 124729                                      NaN
# 125310                                      NaN
#
# [197 rows x 65 columns]

# %%
c_df_latest.sum()
# Out:
# iso_code                                   AFGALBDZAANDAGOATGARGARMABWAUSAUTAZEBHSBHRBGDB...
# continent                                  AsiaEuropeAfricaEuropeAfricaNorth AmericaSouth...
# location                                   AfghanistanAlbaniaAlgeriaAndorraAngolaAntigua ...
# total_cases                                                                      242336151.0
# new_cases                                                                           462668.0
#                                                                  ...
# human_development_index                                                              135.098
# excess_mortality_cumulative_absolute                                                     0.0
# excess_mortality_cumulative                                                              0.0
# excess_mortality                                                                         0.0
# excess_mortality_cumulative_per_million                                                  0.0
# Length: 63, dtype: object

# %% [markdown]
# ## 可視化

# %%
import matplotlib.pyplot as plt
#%matplotlib notebook
# %matplotlib inline

# %%
min_date = pd.to_datetime(datetime.datetime.now()).round("D")- datetime.timedelta(days=90)

# %%
world_df["case_rolling7ave"] = world_df.new_cases.rolling(7).mean()
world_df[["new_cases_smoothed","case_rolling7ave"]]
# Out:
#         new_cases_smoothed  case_rolling7ave
# 122948                 NaN               NaN
# 122949                 NaN               NaN
# 122950                 NaN               NaN
# 122951                 NaN               NaN
# 122952                 NaN               NaN
# ...                    ...               ...
# 123582          403868.000     403868.000000
# 123583          408517.571     408517.571429
# 123584          409760.571     409760.571429
# 123585          409683.143     409683.142857
# 123586          412384.714     412384.714286
#
# [639 rows x 2 columns]

# %%
fig=plt.figure(figsize=(20,12))
plt.subplot(2,2,1) # (rows, columns, panel number)
plt.title("Daily new confirmed COVID-19 cases in the world")
plt.bar(world_df.date,world_df.new_cases,label="New cases")
plt.plot_date(world_df["date"],world_df["new_cases_smoothed"],label="rolling 7-day average", fmt="-", color="orange")
#plt.xticks(rotation=70)
plt.ylabel("people")
plt.grid(axis="y")
plt.legend()

plt.subplot(2,2,2) # (rows, columns, panel number)
plt.title("Daily new confirmed COVID-19 cases in the world(Recent)")
chart_data = world_df[world_df.date >= min_date]
plt.bar(chart_data["date"],chart_data["new_cases"],label="New cases")
plt.plot_date(chart_data["date"],chart_data["new_cases_smoothed"],label="rolling 7-day average", fmt="-", color="orange")
#plt.xticks(rotation=70)
plt.grid(axis="y")
plt.legend()

plt.subplot(2,2,3) # (rows, columns, panel number)
plt.title("Daily new deaths in the world")
plt.bar(world_df.date,world_df.new_deaths,label="New deaths")
plt.plot_date(world_df["date"],world_df["new_deaths_smoothed"],label="rolling 7-day average", fmt="-", color="orange")
#plt.xticks(rotation=70)
plt.ylabel("people")
plt.grid(axis="y")
plt.legend()

plt.subplot(2,2,4) # (rows, columns, panel number)
plt.title("Daily new deaths in the world(Recent)")
chart_data = world_df[world_df.date >= min_date]
plt.bar(chart_data["date"],chart_data["new_deaths"],label="New deaths")
plt.plot_date(chart_data["date"],chart_data["new_deaths_smoothed"],label="rolling 7-day average", fmt="-", color="orange")
#plt.xticks(rotation=70)
plt.grid(axis="y")
plt.legend()

fig.text(0,1,"Latest: {}".format(latest_date_str),ha="left",va="top")
fig.text(0,0
         ,"*Data Source : COVID-19 Dataset by Our World in Data",
        ha="left",va="bottom")

fig.tight_layout()

# %%
fig.savefig("out/covid-owid-global-daily.png")

# %% [markdown]
# ### 国別

# %% [markdown]
# #### 人口100万人当たりの新規感染者数（直近）

# %%
"""
#min_date = pd.to_datetime("2021-05-01")
# 主要国 新規感染者
chart_data = c_trans[c_trans.date >= min_date]
dates = chart_data["date"].unique()
print(len(dates))
print(dates.max())
for i,cr in countries.iterrows():
    c = cr["country"]
    dates = chart_data.loc[chart_data["location"]==c]["date"]
    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else latest_date_str
    print(len(chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"]))
    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"],label=c, fmt="-")
    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_cases_smoothed_per_million"],c
            ,fontsize=8,va="center")
"""
# Out:
# '\n#min_date = pd.to_datetime("2021-05-01")\n# 主要国 新規感染者\nchart_data = c_trans[c_trans.date >= min_date]\ndates = chart_data["date"].unique()\nprint(len(dates))\nprint(dates.max())\nfor i,cr in countries.iterrows():\n    c = cr["country"]\n    dates = chart_data.loc[chart_data["location"]==c]["date"]\n    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else latest_date_str\n    print(len(chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"]))\n    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"],label=c, fmt="-")\n    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_cases_smoothed_per_million"],c\n            ,fontsize=8,va="center")\n'

# %%
"""
fig=plt.figure(figsize=(14,10))
min_date = pd.to_datetime("2021-03-01")
# 主要国 新規感染者
plt.subplot(2,2,1) # (rows, columns, panel number)
plt.title("Daily new confirmed COVID-19 cases\n per million population in major countries\n(rolling 7day ave.)")
plt.grid()
plt.xticks(rotation=70)
chart_data = c_trans[c_trans.date >= min_date]
dates = chart_data["date"].unique()
for i,cr in countries.iterrows():
    c = cr["country"]
    dates = chart_data.loc[chart_data["location"]==c]["date"]
    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else dates.max()
    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"],label=c, fmt="-")
    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_cases_smoothed_per_million"],c
            ,fontsize=8,va="center")
plt.legend(bbox_to_anchor=(0, 1),loc='upper left', fontsize=9)
"""
# Out:
# '\nfig=plt.figure(figsize=(14,10))\nmin_date = pd.to_datetime("2021-03-01")\n# 主要国 新規感染者\nplt.subplot(2,2,1) # (rows, columns, panel number)\nplt.title("Daily new confirmed COVID-19 cases\n per million population in major countries\n(rolling 7day ave.)")\nplt.grid()\nplt.xticks(rotation=70)\nchart_data = c_trans[c_trans.date >= min_date]\ndates = chart_data["date"].unique()\nfor i,cr in countries.iterrows():\n    c = cr["country"]\n    dates = chart_data.loc[chart_data["location"]==c]["date"]\n    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else dates.max()\n    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"],label=c, fmt="-")\n    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_cases_smoothed_per_million"],c\n            ,fontsize=8,va="center")\nplt.legend(bbox_to_anchor=(0, 1),loc=\'upper left\', fontsize=9)\n'

# %%
fig=plt.figure(figsize=(20,14))
# 主要国 新規感染者
plt.subplot(2,2,1) # (rows, columns, panel number)
plt.title("Daily new confirmed COVID-19 cases\n per million population in major countries\n(rolling 7day ave.)")
plt.grid()
plt.xticks(rotation=45)
chart_data = c_trans[c_trans.date >= min_date]
for i,cr in countries.iterrows():
    c = cr["country"]
    dates = chart_data.loc[chart_data["location"]==c]["date"]
    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else dates.max()
    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"],label=c, fmt="-")
    text_y = chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_cases_smoothed_per_million"]
#    print(text_y)
    print(c,text_disp_date,text_y)
#    plt.text(text_disp_date,text_y,c,fontsize=10,va="center")
    plt.text(text_disp_date,text_y,c,va="center")
plt.legend(bbox_to_anchor=(0, 1),loc='upper left')

# 主要国 死者
plt.subplot(2,2,2) # (rows, columns, panel number)
plt.title("Daily new deaths in major countries(rolling 7day ave.)")
plt.grid()
plt.xticks(rotation=45)
chart_data = c_trans[c_trans.date >= min_date]
for i,cr in countries.iterrows():
    c = cr["country"]
    dates = chart_data.loc[chart_data["location"]==c]["date"]
    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else dates.max()
    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_deaths_smoothed"],label=c, fmt="-")
    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_deaths_smoothed"],c
            ,va="center")
plt.legend(bbox_to_anchor=(0, 1),loc='upper left')

plt.subplot(2,2,3) # (rows, columns, panel number)
plt.grid()
plt.xticks(rotation=45)
plt.title("Daily new confirmed COVID-19 cases\n per million population in Eastern Asia\n(rolling 7day ave.)")
chart_data = e_a_trans[e_a_trans.date >= min_date]
for i,cr in e_asia_c.iterrows():
    c = cr["country"]
    dates = chart_data.loc[chart_data["location"]==c]["date"]
    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else dates.max()
    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"],label=c, fmt="-")
    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_cases_smoothed_per_million"],c
             ,va="center")
plt.legend(bbox_to_anchor=(0, 1),loc='upper left')

plt.subplot(2,2,4) # (rows, columns, panel number)
plt.grid()
plt.xticks(rotation=45)
plt.title("Daily new deaths in Eastern Asia(rolling 7day ave.)")
chart_data = e_a_trans[e_a_trans.date >= min_date]
for i,cr in e_asia_c.iterrows():
    c = cr["country"]
    dates = chart_data.loc[chart_data["location"]==c]["date"]
    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else dates.max()
    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_deaths_smoothed"],label=c, fmt="-")
    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_deaths_smoothed"],c
             ,va="center")
plt.legend(bbox_to_anchor=(0, 1),loc='upper left')

fig.text(0,0.98,"Latest: {}".format(latest_date_str),ha="left",va="top")
fig.text(0,0
         ,"*Data Source : COVID-19 Dataset by Our World in Data",
        ha="left",va="bottom")
fig.tight_layout()
"""
"""
# Out:
# Japan 2021-10-21 00:00:00 638    3.171
# Name: new_cases_smoothed_per_million, dtype: float64
# United States 2021-10-21 00:00:00 1277    227.725
# Name: new_cases_smoothed_per_million, dtype: float64
# India 2021-10-21 00:00:00 1908    10.831
# Name: new_cases_smoothed_per_million, dtype: float64
# Indonesia 2021-10-21 00:00:00 2507    2.965
# Name: new_cases_smoothed_per_million, dtype: float64
# Spain 2021-10-21 00:00:00 3136    39.845
# Name: new_cases_smoothed_per_million, dtype: float64
# Brazil 2021-10-21 00:00:00 3740    56.813
# Name: new_cases_smoothed_per_million, dtype: float64
# France 2021-10-21 00:00:00 4377    73.044
# Name: new_cases_smoothed_per_million, dtype: float64
# United Kingdom 2021-10-21 00:00:00 5007    681.117
# Name: new_cases_smoothed_per_million, dtype: float64
# Russia 2021-10-21 00:00:00 5637    227.131
# Name: new_cases_smoothed_per_million, dtype: float64
# Turkey 2021-10-21 00:00:00 6227    338.774
# Name: new_cases_smoothed_per_million, dtype: float64
# Iran 2021-10-21 00:00:00 6838    133.531
# Name: new_cases_smoothed_per_million, dtype: float64
# '\n'

# %%
fig.savefig("out/covid-owid-countries-daily.png")

# %% [markdown]
# ### 新規感染者数

# %%
fig = plt.figure(figsize=(12,14))

plt.subplot(2,2,1) # (rows, columns, panel number)
plt.title("New confirmed COVID-19 cases worst 50")
plt.yticks(fontsize=9)
plt.xlabel("people")
chart_data = c_df_latest.sort_values("new_cases",ascending=False).head(50).sort_values("new_cases",ascending=True)
plt.barh(chart_data["location"],chart_data["new_cases"],label="new cases a day")
plt.grid(axis="x")
mean = int(c_df_latest.new_cases.mean())
plt.plot([mean,mean],[0,50], 'k--', lw=0.5)
plt.text(mean,50,"Mean:{}".format(mean),ha="center",fontsize=9)
plt.legend()

plt.subplot(2,2,2) # (rows, columns, panel number)
plt.title("New confirmed COVID-19 cases per million worst 50")
plt.yticks(fontsize=9)
plt.xlabel("people")
chart_data = c_df_latest.sort_values("new_cases_per_million",ascending=False).head(50).sort_values("new_cases_per_million",ascending=True)
plt.barh(chart_data["location"],chart_data["new_cases_per_million"],label="new cases a day per million")
plt.grid(axis="x")
mean = int(chart_data.new_cases_per_million.mean())
plt.plot([mean,mean],[0,50], 'k--', lw=0.5)
plt.text(mean,50,"Mean:{}".format(mean),ha="center",fontsize=9)
plt.legend()

fig.text(0,0.98,"Latest: {}".format(latest_date_str),fontsize=9,ha="left",va="top")
fig.text(0,0
         ,"*Data Source : COVID-19 Dataset by Our World in Data",
        fontsize=8,ha="left",va="bottom")

plt.subplot(2,2,3) # (rows, columns, panel number)
plt.title("New deaths worst 50")
plt.yticks(fontsize=9)
plt.xlabel("people")
chart_data = c_df_latest.sort_values("new_deaths",ascending=False).head(50).sort_values("new_deaths",ascending=True)
plt.barh(chart_data["location"],chart_data["new_deaths"],label="new deaths a day")
plt.grid(axis="x")
mean = int(c_df_latest.new_deaths.mean())
plt.plot([mean,mean],[0,50], 'k--', lw=0.5)
plt.text(mean,50,"Mean:{}".format(mean),ha="center",fontsize=9)
plt.legend()

plt.subplot(2,2,4) # (rows, columns, panel number)
plt.title("Total deaths per capita worst 50")
plt.yticks(fontsize=9)
plt.xlabel("%")
chart_data = c_df_latest.copy()
chart_data["total_deaths_per_capita"] = chart_data.total_deaths / chart_data.population * 100
chart_data = chart_data.sort_values("total_deaths_per_capita",ascending=False).head(50).sort_values("total_deaths_per_capita",ascending=True)
plt.barh(chart_data["location"],chart_data["total_deaths_per_capita"],label="total deaths per capita")
plt.grid(axis="x")
mean = round(chart_data.total_deaths_per_capita.mean(),2)
plt.plot([mean,mean],[0,50], 'k--', lw=0.5)
plt.text(mean,50,"Mean:{}".format(mean),ha="center",fontsize=9)
plt.legend()


fig.tight_layout()

# %%
fig.savefig("out/covid-owid-global-latest-top.png")

# %%
a_df = df.loc[df.location=="Japan"]
c_df = df.loc[(df.date==pd.to_datetime("2021-07-27")) & (df.iso_code.str.len()==3)]

# %%
a_df.tail(10)
# Out:
#       iso_code continent location       date  total_cases  new_cases  \
# 58140      JPN      Asia    Japan 2021-10-12    1712740.0      613.0
# 58141      JPN      Asia    Japan 2021-10-13    1713471.0      731.0
# 58142      JPN      Asia    Japan 2021-10-14    1714060.0      589.0
# 58143      JPN      Asia    Japan 2021-10-15    1714201.0      141.0
# 58144      JPN      Asia    Japan 2021-10-16    1715059.0      858.0
# 58145      JPN      Asia    Japan 2021-10-17    1715515.0      456.0
# 58146      JPN      Asia    Japan 2021-10-18    1715745.0      230.0
# 58147      JPN      Asia    Japan 2021-10-19    1716117.0      372.0
# 58148      JPN      Asia    Japan 2021-10-20    1716508.0      391.0
# 58149      JPN      Asia    Japan 2021-10-21    1716858.0      350.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 58140             747.000       17999.0        27.0               27.429  ...
# 58141             691.000       18032.0        33.0               28.429  ...
# 58142             636.714       18063.0        31.0               27.286  ...
# 58143             539.286       18084.0        21.0               23.714  ...
# 58144             550.286       18099.0        15.0               22.000  ...
# 58145             537.000       18112.0        13.0               22.857  ...
# 58146             516.857       18129.0        17.0               22.429  ...
# 58147             482.429       18156.0        27.0               22.429  ...
# 58148             433.857       18166.0        10.0               19.143  ...
# 58149             399.714       18182.0        16.0               17.000  ...
#
#        female_smokers  male_smokers  handwashing_facilities  \
# 58140            11.2          33.7                     NaN
# 58141            11.2          33.7                     NaN
# 58142            11.2          33.7                     NaN
# 58143            11.2          33.7                     NaN
# 58144            11.2          33.7                     NaN
# 58145            11.2          33.7                     NaN
# 58146            11.2          33.7                     NaN
# 58147            11.2          33.7                     NaN
# 58148            11.2          33.7                     NaN
# 58149            11.2          33.7                     NaN
#
#        hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 58140                       13.05            84.63                    0.919
# 58141                       13.05            84.63                    0.919
# 58142                       13.05            84.63                    0.919
# 58143                       13.05            84.63                    0.919
# 58144                       13.05            84.63                    0.919
# 58145                       13.05            84.63                    0.919
# 58146                       13.05            84.63                    0.919
# 58147                       13.05            84.63                    0.919
# 58148                       13.05            84.63                    0.919
# 58149                       13.05            84.63                    0.919
#
#        excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 58140                                   NaN                          NaN
# 58141                                   NaN                          NaN
# 58142                                   NaN                          NaN
# 58143                                   NaN                          NaN
# 58144                                   NaN                          NaN
# 58145                                   NaN                          NaN
# 58146                                   NaN                          NaN
# 58147                                   NaN                          NaN
# 58148                                   NaN                          NaN
# 58149                                   NaN                          NaN
#
#        excess_mortality  excess_mortality_cumulative_per_million
# 58140               NaN                                      NaN
# 58141               NaN                                      NaN
# 58142               NaN                                      NaN
# 58143               NaN                                      NaN
# 58144               NaN                                      NaN
# 58145               NaN                                      NaN
# 58146               NaN                                      NaN
# 58147               NaN                                      NaN
# 58148               NaN                                      NaN
# 58149               NaN                                      NaN
#
# [10 rows x 65 columns]

# %%
c_df.sort_values("new_deaths",ascending=False).head(50)
# Out:
#        iso_code      continent        location       date  total_cases  \
# 52879       IDN           Asia       Indonesia 2021-07-27    3239936.0
# 16459       BRA  South America          Brazil 2021-07-27   19749073.0
# 93404       RUS         Europe          Russia 2021-07-27    6094379.0
# 52280       IND           Asia           India 2021-07-27   31484605.0
# 73300       MEX  North America          Mexico 2021-07-27    2771846.0
# 119311      USA  North America   United States 2021-07-27   34667713.0
# 54113       IRN           Asia            Iran 2021-07-27    3758197.0
# 77962       MMR           Asia         Myanmar 2021-07-27     279119.0
# 103903      ZAF         Africa    South Africa 2021-07-27    2391223.0
# 24693       COL  South America        Colombia 2021-07-27    4747775.0
# 10103       BGD           Asia      Bangladesh 2021-07-27    1194752.0
# 5028        ARG  South America       Argentina 2021-07-27    4875927.0
# 69346       MYS           Asia        Malaysia 2021-07-27    1044071.0
# 115050      TUN         Africa         Tunisia 2021-07-27     575002.0
# 118672      GBR         Europe  United Kingdom 2021-07-27    5771732.0
# 112394      THA           Asia        Thailand 2021-07-27     526828.0
# 125224      ZWE         Africa        Zimbabwe 2021-07-27     101711.0
# 89637       PER  South America            Peru 2021-07-27    2106371.0
# 28345       CUB  North America            Cuba 2021-07-27     349055.0
# 90268       PHL           Asia     Philippines 2021-07-27    1562420.0
# 54719       IRQ           Asia            Iraq 2021-07-27    1577013.0
# 14542       BOL  South America         Bolivia 2021-07-27     470024.0
# 46617       GTM  North America       Guatemala 2021-07-27     355223.0
# 49809       HND  North America        Honduras 2021-07-27     291687.0
# 88977       PRY  South America        Paraguay 2021-07-27     450494.0
# 106345      ESP         Europe           Spain 2021-07-27    4368453.0
# 115640      TUR           Asia          Turkey 2021-07-27    5638178.0
# 106979      LKA           Asia       Sri Lanka 2021-07-27     299892.0
# 86553       PAK           Asia        Pakistan 2021-07-27    1015827.0
# 26561       CRI  North America      Costa Rica 2021-07-27     402044.0
# 117410      UKR         Europe         Ukraine 2021-07-27    2327777.0
# 519         AFG           Asia     Afghanistan 2021-07-27     145008.0
# 78549       NAM         Africa         Namibia 2021-07-27     117293.0
# 77388       MOZ         Africa      Mozambique 2021-07-27     113426.0
# 23459       CHL  South America           Chile 2021-07-27    1611090.0
# 41007       FRA         Europe          France 2021-07-27    6089097.0
# 68709       MWI         Africa          Malawi 2021-07-27      49752.0
# 76809       MAR         Africa         Morocco 2021-07-27     588448.0
# 2346        DZA         Africa         Algeria 2021-07-27     165204.0
# 65497       LBY         Africa           Libya 2021-07-27     240309.0
# 56834       ITA         Europe           Italy 2021-07-27    4325046.0
# 124643      ZMB         Africa          Zambia 2021-07-27     192956.0
# 79331       NPL           Asia           Nepal 2021-07-27     685673.0
# 19580       KHM           Asia        Cambodia 2021-07-27      74386.0
# 43675       DEU         Europe         Germany 2021-07-27    3766501.0
# 43041       GEO           Asia         Georgia 2021-07-27     407689.0
# 85948       OMN           Asia            Oman 2021-07-27     295017.0
# 122013      VEN  South America       Venezuela 2021-07-27     301979.0
# 98537       SEN         Africa         Senegal 2021-07-27      58523.0
# 61995       KGZ           Asia      Kyrgyzstan 2021-07-27     159089.0
#
#         new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 52879     45203.0           41411.143       86835.0      2069.0
# 16459     41411.0           47090.857      551835.0      1333.0
# 93404     22486.0           23207.714      152836.0       767.0
# 52280     43654.0           38324.000      422022.0       640.0
# 73300     17408.0           13364.143      239079.0       484.0
# 119311    68414.0           61429.857      611212.0       449.0
# 54113     34951.0           26007.000       89479.0       357.0
# 77962      4964.0            5507.000        7845.0       338.0
# 103903     7733.0           11427.286       70338.0       320.0
# 24693     11426.0           11289.286      119482.0       300.0
# 10103     14925.0            9409.000       19779.0       258.0
# 5028      16757.0           13101.143      104352.0       247.0
# 69346     16117.0           14881.714        8408.0       207.0
# 115050     1608.0            2870.143       18968.0       164.0
# 118672    23401.0           32728.143      129591.0       131.0
# 112394    14150.0           14336.143        4264.0       118.0
# 125224     1767.0            1899.429        3280.0       107.0
# 89637      1366.0            1479.714      196058.0        85.0
# 28345      7903.0            7800.857        2492.0        75.0
# 90268      7024.0            6359.571       27318.0        71.0
# 54719     12185.0            9499.429       18418.0        71.0
# 14542      1601.0             985.571       17716.0        65.0
# 46617      2639.0            2494.429       10176.0        64.0
# 49809      1240.0            1285.857        7713.0        63.0
# 88977       592.0             603.857       14759.0        58.0
# 106345    26399.0           25616.714       81323.0        55.0
# 115640    19761.0           13144.571       51048.0        51.0
# 106979     1711.0            1702.714        4195.0        48.0
# 86553      4119.0            2768.000       23133.0        46.0
# 26561      3436.0            1129.857        4987.0        46.0
# 117410     1227.0            1127.286       55420.0        39.0
# 519         723.0             370.571        6515.0        38.0
# 78549       329.0             550.714        2871.0        37.0
# 77388      1703.0            1631.000        1341.0        34.0
# 23459       745.0            1318.857       35151.0        32.0
# 41007     27128.0           19515.286      111881.0        29.0
# 68709       743.0             724.000        1540.0        27.0
# 76809      6971.0            3718.857        9638.0        27.0
# 2346       1544.0            1345.714        4112.0        25.0
# 65497      3348.0            1944.000        3422.0        24.0
# 56834      4516.0            4566.143      127995.0        24.0
# 124643      640.0             764.857        3316.0        21.0
# 79331      2726.0            2102.857        9758.0        20.0
# 19580       685.0             798.571        1324.0        19.0
# 43675      2060.0            1665.000       91592.0        19.0
# 43041      3666.0            2392.000        5731.0        17.0
# 85948       491.0             853.571        3788.0        17.0
# 122013     1060.0            1159.000        3524.0        15.0
# 98537       642.0             707.143        1300.0        14.0
# 61995       969.0            1068.857        2275.0        14.0
#
#         new_deaths_smoothed  ...  female_smokers  male_smokers  \
# 52879              1519.286  ...             2.8          76.1
# 16459              1093.571  ...            10.1          17.9
# 93404               768.429  ...            23.4          58.3
# 52280               506.000  ...             1.9          20.6
# 73300               324.143  ...             6.9          21.4
# 119311              303.429  ...            19.1          24.6
# 54113               265.000  ...             0.8          21.1
# 77962               325.429  ...             6.3          35.2
# 103903              380.286  ...             8.1          33.2
# 24693               335.857  ...             4.7          13.5
# 10103               207.714  ...             1.0          44.7
# 5028                281.571  ...            16.2          27.7
# 69346               166.714  ...             1.0          42.4
# 115050              163.857  ...             1.1          65.8
# 118672               68.857  ...            20.0          24.7
# 112394              108.857  ...             1.9          38.8
# 125224               76.143  ...             1.6          30.7
# 89637               103.714  ...             4.8           NaN
# 28345                67.571  ...            17.1          53.3
# 90268                67.714  ...             7.8          40.8
# 54719                66.714  ...             NaN           NaN
# 14542                34.429  ...             NaN           NaN
# 46617                35.571  ...             NaN           NaN
# 49809                29.429  ...             2.0           NaN
# 88977                52.143  ...             5.0          21.6
# 106345               25.000  ...            27.4          31.4
# 115640               56.857  ...            14.1          41.1
# 106979               46.429  ...             0.3          27.0
# 86553                35.000  ...             2.8          36.7
# 26561                10.286  ...             6.4          17.4
# 117410               28.429  ...            13.5          47.4
# 519                  35.571  ...             NaN           NaN
# 78549                44.857  ...             9.7          34.2
# 77388                26.143  ...             5.1          29.1
# 23459                83.143  ...            34.2          41.5
# 41007                24.857  ...            30.1          35.6
# 68709                25.286  ...             4.4          24.7
# 76809                21.714  ...             0.8          47.1
# 2346                 19.000  ...             0.7          30.4
# 65497                16.143  ...             NaN           NaN
# 56834                15.857  ...            19.8          27.8
# 124643               25.429  ...             3.1          24.7
# 79331                21.571  ...             9.5          37.8
# 19580                25.000  ...             2.0          33.7
# 43675                24.143  ...            28.2          33.1
# 43041                19.857  ...             5.3          55.5
# 85948                41.429  ...             0.5          15.6
# 122013               18.857  ...             NaN           NaN
# 98537                 9.143  ...             0.4          16.6
# 61995                11.286  ...             3.6          50.5
#
#         handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 52879                   64.204                        1.04            71.72
# 16459                      NaN                        2.20            75.88
# 93404                      NaN                        8.05            72.58
# 52280                   59.550                        0.53            69.66
# 73300                   87.847                        1.38            75.05
# 119311                     NaN                        2.77            78.86
# 54113                      NaN                        1.50            76.68
# 77962                   79.287                        0.90            67.13
# 103903                  43.993                        2.32            64.13
# 24693                   65.386                        1.71            77.29
# 10103                   34.808                        0.80            72.59
# 5028                       NaN                        5.00            76.67
# 69346                      NaN                        1.90            76.16
# 115050                  78.687                        2.30            76.70
# 118672                     NaN                        2.54            81.32
# 112394                  90.670                        2.10            77.15
# 125224                  36.791                        1.70            61.49
# 89637                      NaN                        1.60            76.74
# 28345                   85.198                        5.20            78.80
# 90268                   78.463                        1.00            71.23
# 54719                   94.576                        1.40            70.60
# 14542                   25.383                        1.10            71.51
# 46617                   76.665                        0.60            74.30
# 49809                   84.169                        0.70            75.27
# 88977                   79.602                        1.30            74.25
# 106345                     NaN                        2.97            83.56
# 115640                     NaN                        2.81            77.69
# 106979                     NaN                        3.60            76.98
# 86553                   59.607                        0.60            67.27
# 26561                   83.841                        1.13            80.28
# 117410                     NaN                        8.80            72.06
# 519                     37.746                        0.50            64.83
# 78549                   44.600                         NaN            63.71
# 77388                   12.227                        0.70            60.85
# 23459                      NaN                        2.11            80.18
# 41007                      NaN                        5.98            82.66
# 68709                    8.704                        1.30            64.26
# 76809                      NaN                        1.10            76.68
# 2346                    83.741                        1.90            76.88
# 65497                      NaN                        3.70            72.91
# 56834                      NaN                        3.18            83.51
# 124643                  13.938                        2.00            63.89
# 79331                   47.782                        0.30            70.78
# 19580                   66.229                        0.80            69.82
# 43675                      NaN                        8.00            81.33
# 43041                      NaN                        2.60            73.77
# 85948                   97.400                        1.60            77.86
# 122013                     NaN                        0.80            72.06
# 98537                   20.859                         NaN            67.94
# 61995                   89.220                        4.50            71.45
#
#         human_development_index  excess_mortality_cumulative_absolute  \
# 52879                     0.718                                   NaN
# 16459                     0.765                                   NaN
# 93404                     0.824                                   NaN
# 52280                     0.645                                   NaN
# 73300                     0.779                                   NaN
# 119311                    0.926                                   NaN
# 54113                     0.783                                   NaN
# 77962                     0.583                                   NaN
# 103903                    0.709                                   NaN
# 24693                     0.767                                   NaN
# 10103                     0.632                                   NaN
# 5028                      0.845                                   NaN
# 69346                     0.810                                   NaN
# 115050                    0.740                                   NaN
# 118672                    0.932                                   NaN
# 112394                    0.777                                   NaN
# 125224                    0.571                                   NaN
# 89637                     0.777                                   NaN
# 28345                     0.783                                   NaN
# 90268                     0.718                                   NaN
# 54719                     0.674                                   NaN
# 14542                     0.718                                   NaN
# 46617                     0.663                                   NaN
# 49809                     0.634                                   NaN
# 88977                     0.728                                   NaN
# 106345                    0.904                                   NaN
# 115640                    0.820                                   NaN
# 106979                    0.782                                   NaN
# 86553                     0.557                                   NaN
# 26561                     0.810                                   NaN
# 117410                    0.779                                   NaN
# 519                       0.511                                   NaN
# 78549                     0.646                                   NaN
# 77388                     0.456                                   NaN
# 23459                     0.851                                   NaN
# 41007                     0.901                                   NaN
# 68709                     0.483                                   NaN
# 76809                     0.686                                   NaN
# 2346                      0.748                                   NaN
# 65497                     0.724                                   NaN
# 56834                     0.892                                   NaN
# 124643                    0.584                                   NaN
# 79331                     0.602                                   NaN
# 19580                     0.594                                   NaN
# 43675                     0.947                                   NaN
# 43041                     0.812                                   NaN
# 85948                     0.813                                   NaN
# 122013                    0.711                                   NaN
# 98537                     0.512                                   NaN
# 61995                     0.697                                   NaN
#
#         excess_mortality_cumulative  excess_mortality  \
# 52879                           NaN               NaN
# 16459                           NaN               NaN
# 93404                           NaN               NaN
# 52280                           NaN               NaN
# 73300                           NaN               NaN
# 119311                          NaN               NaN
# 54113                           NaN               NaN
# 77962                           NaN               NaN
# 103903                          NaN               NaN
# 24693                           NaN               NaN
# 10103                           NaN               NaN
# 5028                            NaN               NaN
# 69346                           NaN               NaN
# 115050                          NaN               NaN
# 118672                          NaN               NaN
# 112394                          NaN               NaN
# 125224                          NaN               NaN
# 89637                           NaN               NaN
# 28345                           NaN               NaN
# 90268                           NaN               NaN
# 54719                           NaN               NaN
# 14542                           NaN               NaN
# 46617                           NaN               NaN
# 49809                           NaN               NaN
# 88977                           NaN               NaN
# 106345                          NaN               NaN
# 115640                          NaN               NaN
# 106979                          NaN               NaN
# 86553                           NaN               NaN
# 26561                           NaN               NaN
# 117410                          NaN               NaN
# 519                             NaN               NaN
# 78549                           NaN               NaN
# 77388                           NaN               NaN
# 23459                           NaN               NaN
# 41007                           NaN               NaN
# 68709                           NaN               NaN
# 76809                           NaN               NaN
# 2346                            NaN               NaN
# 65497                           NaN               NaN
# 56834                           NaN               NaN
# 124643                          NaN               NaN
# 79331                           NaN               NaN
# 19580                           NaN               NaN
# 43675                           NaN               NaN
# 43041                           NaN               NaN
# 85948                           NaN               NaN
# 122013                          NaN               NaN
# 98537                           NaN               NaN
# 61995                           NaN               NaN
#
#         excess_mortality_cumulative_per_million
# 52879                                       NaN
# 16459                                       NaN
# 93404                                       NaN
# 52280                                       NaN
# 73300                                       NaN
# 119311                                      NaN
# 54113                                       NaN
# 77962                                       NaN
# 103903                                      NaN
# 24693                                       NaN
# 10103                                       NaN
# 5028                                        NaN
# 69346                                       NaN
# 115050                                      NaN
# 118672                                      NaN
# 112394                                      NaN
# 125224                                      NaN
# 89637                                       NaN
# 28345                                       NaN
# 90268                                       NaN
# 54719                                       NaN
# 14542                                       NaN
# 46617                                       NaN
# 49809                                       NaN
# 88977                                       NaN
# 106345                                      NaN
# 115640                                      NaN
# 106979                                      NaN
# 86553                                       NaN
# 26561                                       NaN
# 117410                                      NaN
# 519                                         NaN
# 78549                                       NaN
# 77388                                       NaN
# 23459                                       NaN
# 41007                                       NaN
# 68709                                       NaN
# 76809                                       NaN
# 2346                                        NaN
# 65497                                       NaN
# 56834                                       NaN
# 124643                                      NaN
# 79331                                       NaN
# 19580                                       NaN
# 43675                                       NaN
# 43041                                       NaN
# 85948                                       NaN
# 122013                                      NaN
# 98537                                       NaN
# 61995                                       NaN
#
# [50 rows x 65 columns]

# %%
c_df.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'new_tests', 'total_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'total_boosters',
#        'new_vaccinations', 'new_vaccinations_smoothed',
#        'total_vaccinations_per_hundred', 'people_vaccinated_per_hundred',
#        'people_fully_vaccinated_per_hundred', 'total_boosters_per_hundred',
#        'new_vaccinations_smoothed_per_million', 'stringency_index',
#        'population', 'population_density', 'median_age', 'aged_65_older',
#        'aged_70_older', 'gdp_per_capita', 'extreme_poverty',
#        'cardiovasc_death_rate', 'diabetes_prevalence', 'female_smokers',
#        'male_smokers', 'handwashing_facilities', 'hospital_beds_per_thousand',
#        'life_expectancy', 'human_development_index',
#        'excess_mortality_cumulative_absolute', 'excess_mortality_cumulative',
#        'excess_mortality', 'excess_mortality_cumulative_per_million'],
#       dtype='object')
