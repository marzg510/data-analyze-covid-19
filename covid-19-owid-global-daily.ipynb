# %%
import pandas as pd

# %%
df = pd.read_csv("covid-19-data/public/data/owid-covid-data.csv")
df.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1      AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    female_smokers  male_smokers  handwashing_facilities  \
# 0             NaN           NaN                  37.746
# 1             NaN           NaN                  37.746
# 2             NaN           NaN                  37.746
# 3             NaN           NaN                  37.746
# 4             NaN           NaN                  37.746
#
#    hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                         0.5            64.83                    0.511
# 1                         0.5            64.83                    0.511
# 2                         0.5            64.83                    0.511
# 3                         0.5            64.83                    0.511
# 4                         0.5            64.83                    0.511
#
#    excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                   NaN                          NaN
# 1                                   NaN                          NaN
# 2                                   NaN                          NaN
# 3                                   NaN                          NaN
# 4                                   NaN                          NaN
#
#    excess_mortality  excess_mortality_cumulative_per_million
# 0               NaN                                      NaN
# 1               NaN                                      NaN
# 2               NaN                                      NaN
# 3               NaN                                      NaN
# 4               NaN                                      NaN
#
# [5 rows x 67 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193475 entries, 0 to 193474
# Data columns (total 67 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   iso_code                                    193475 non-null  object
#  1   continent                                   182232 non-null  object
#  2   location                                    193475 non-null  object
#  3   date                                        193475 non-null  object
#  4   total_cases                                 185895 non-null  float64
#  5   new_cases                                   185610 non-null  float64
#  6   new_cases_smoothed                          184436 non-null  float64
#  7   total_deaths                                167374 non-null  float64
#  8   new_deaths                                  167357 non-null  float64
#  9   new_deaths_smoothed                         166194 non-null  float64
#  10  total_cases_per_million                     185038 non-null  float64
#  11  new_cases_per_million                       184753 non-null  float64
#  12  new_cases_smoothed_per_million              183584 non-null  float64
#  13  total_deaths_per_million                    166530 non-null  float64
#  14  new_deaths_per_million                      166513 non-null  float64
#  15  new_deaths_smoothed_per_million             165355 non-null  float64
#  16  reproduction_rate                           144528 non-null  float64
#  17  icu_patients                                25717 non-null   float64
#  18  icu_patients_per_million                    25717 non-null   float64
#  19  hosp_patients                               26959 non-null   float64
#  20  hosp_patients_per_million                   26959 non-null   float64
#  21  weekly_icu_admissions                       6288 non-null    float64
#  22  weekly_icu_admissions_per_million           6288 non-null    float64
#  23  weekly_hosp_admissions                      12524 non-null   float64
#  24  weekly_hosp_admissions_per_million          12524 non-null   float64
#  25  total_tests                                 78123 non-null   float64
#  26  new_tests                                   74376 non-null   float64
#  27  total_tests_per_thousand                    78123 non-null   float64
#  28  new_tests_per_thousand                      74376 non-null   float64
#  29  new_tests_smoothed                          101979 non-null  float64
#  30  new_tests_smoothed_per_thousand             101979 non-null  float64
#  31  positive_rate                               94068 non-null   float64
#  32  tests_per_case                              92295 non-null   float64
#  33  tests_units                                 104773 non-null  object
#  34  total_vaccinations                          53023 non-null   float64
#  35  people_vaccinated                           50499 non-null   float64
#  36  people_fully_vaccinated                     47992 non-null   float64
#  37  total_boosters                              25049 non-null   float64
#  38  new_vaccinations                            43456 non-null   float64
#  39  new_vaccinations_smoothed                   104878 non-null  float64
#  40  total_vaccinations_per_hundred              53023 non-null   float64
#  41  people_vaccinated_per_hundred               50499 non-null   float64
#  42  people_fully_vaccinated_per_hundred         47992 non-null   float64
#  43  total_boosters_per_hundred                  25049 non-null   float64
#  44  new_vaccinations_smoothed_per_million       104878 non-null  float64
#  45  new_people_vaccinated_smoothed              103921 non-null  float64
#  46  new_people_vaccinated_smoothed_per_hundred  103921 non-null  float64
#  47  stringency_index                            150458 non-null  float64
#  48  population                                  192301 non-null  float64
#  49  population_density                          172400 non-null  float64
#  50  median_age                                  159788 non-null  float64
#  51  aged_65_older                               158095 non-null  float64
#  52  aged_70_older                               158950 non-null  float64
#  53  gdp_per_capita                              158943 non-null  float64
#  54  extreme_poverty                             103750 non-null  float64
#  55  cardiovasc_death_rate                       159419 non-null  float64
#  56  diabetes_prevalence                         167218 non-null  float64
#  57  female_smokers                              120582 non-null  float64
#  58  male_smokers                                118929 non-null  float64
#  59  handwashing_facilities                      78332 non-null   float64
#  60  hospital_beds_per_thousand                  141453 non-null  float64
#  61  life_expectancy                             180939 non-null  float64
#  62  human_development_index                     155322 non-null  float64
#  63  excess_mortality_cumulative_absolute        6606 non-null    float64
#  64  excess_mortality_cumulative                 6606 non-null    float64
#  65  excess_mortality                            6606 non-null    float64
#  66  excess_mortality_cumulative_per_million     6606 non-null    float64
# dtypes: float64(62), object(5)
# memory usage: 98.9+ MB

# %%
df.describe()
# Out:
#         total_cases     new_cases  new_cases_smoothed  total_deaths  \
# count  1.858950e+05  1.856100e+05        1.844360e+05  1.673740e+05
# mean   3.370256e+06  1.229014e+04        1.233564e+04  6.541338e+04
# std    2.117364e+07  8.688183e+04        8.533851e+04  3.405914e+05
# min    1.000000e+00  0.000000e+00        0.000000e+00  1.000000e+00
# 25%    2.767000e+03  0.000000e+00        6.571000e+00  9.600000e+01
# 50%    3.645900e+04  6.900000e+01        1.000000e+02  9.360000e+02
# 75%    3.875320e+05  1.018000e+03        1.129000e+03  8.528000e+03
# max    5.352579e+08  4.079892e+06        3.437239e+06  6.309431e+06
#
#           new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  167357.000000        166194.000000            185038.000000
# mean      156.371105           157.325709             42695.795815
# std       785.994932           769.520204             79306.454572
# min         0.000000             0.000000                 0.001000
# 25%         0.000000             0.143000               794.288500
# 50%         1.000000             2.000000              6731.541000
# 75%        17.000000            18.857000             53003.774500
# max     18152.000000         14795.286000            706541.904000
#
#        new_cases_per_million  new_cases_smoothed_per_million  \
# count          184753.000000                   183584.000000
# mean              185.190462                      185.536260
# std               943.860439                      615.328464
# min                 0.000000                        0.000000
# 25%                 0.000000                        1.483000
# 50%                10.093000                       19.114500
# 75%               101.487000                      129.194250
# max            208049.887000                    37617.428000
#
#        total_deaths_per_million  ...  female_smokers   male_smokers  \
# count             166530.000000  ...   120582.000000  118929.000000
# mean                 595.391519  ...       10.642981      32.793059
# std                  880.930902  ...       10.579544      13.530813
# min                    0.000000  ...        0.100000       7.700000
# 25%                   23.992500  ...        1.900000      21.600000
# 50%                  167.685500  ...        6.300000      31.400000
# 75%                  861.047750  ...       19.300000      41.300000
# max                 6394.477000  ...       44.000000      78.100000
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# count            78332.000000               141453.000000    180939.000000
# mean                50.916734                    3.068559        73.648756
# std                 31.855170                    2.520222         7.449214
# min                  1.188000                    0.100000        53.280000
# 25%                 20.859000                    1.300000        69.500000
# 50%                 49.839000                    2.400000        75.050000
# 75%                 83.241000                    4.000000        79.070000
# max                100.000000                   13.800000        86.750000
#
#        human_development_index  excess_mortality_cumulative_absolute  \
# count            155322.000000                          6.606000e+03
# mean                  0.725186                          4.133272e+04
# std                   0.149727                          1.149811e+05
# min                   0.394000                         -3.772610e+04
# 25%                   0.602000                         -7.175000e+00
# 50%                   0.743000                          4.372200e+03
# 75%                   0.845000                          2.809065e+04
# max                   0.957000                          1.213593e+06
#
#        excess_mortality_cumulative  excess_mortality  \
# count                  6606.000000       6606.000000
# mean                      9.829420         15.626835
# std                      16.019677         29.036332
# min                     -28.450000        -95.920000
# 25%                      -0.107500         -0.250000
# 50%                       6.630000          7.465000
# 75%                      14.780000         21.750000
# max                     111.010000        375.000000
#
#        excess_mortality_cumulative_per_million
# count                              6606.000000
# mean                               1131.261367
# std                                1576.245458
# min                               -1826.595723
# 25%                                  -5.084952
# 50%                                 581.070116
# 75%                                1810.340758
# max                                9725.192865
#
# [8 rows x 62 columns]

# %%
df.continent.unique()
# Out:
# array(['Asia', nan, 'Europe', 'Africa', 'North America', 'South America',
#        'Oceania'], dtype=object)

# %%
df.loc[df.continent.isna()].location.unique()
# Out:
# array(['Africa', 'Asia', 'Europe', 'European Union', 'High income',
#        'International', 'Low income', 'Lower middle income',
#        'North America', 'Oceania', 'South America', 'Upper middle income',
#        'World'], dtype=object)

# %%
df.loc[df.location=="International"]
# Out:
#        iso_code continent       location        date  total_cases  new_cases  \
# 81684  OWID_INT       NaN  International  2020-02-07         61.0       61.0
# 81685  OWID_INT       NaN  International  2020-02-08         61.0        0.0
# 81686  OWID_INT       NaN  International  2020-02-09         64.0        3.0
# 81687  OWID_INT       NaN  International  2020-02-10        135.0       71.0
# 81688  OWID_INT       NaN  International  2020-02-11        135.0        0.0
# ...         ...       ...            ...         ...          ...        ...
# 82536  OWID_INT       NaN  International  2022-06-08        721.0        0.0
# 82537  OWID_INT       NaN  International  2022-06-09        721.0        0.0
# 82538  OWID_INT       NaN  International  2022-06-10        721.0        0.0
# 82539  OWID_INT       NaN  International  2022-06-11        721.0        0.0
# 82540  OWID_INT       NaN  International  2022-06-12        721.0        0.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 81684                 NaN           NaN         NaN                  NaN  ...
# 81685                 NaN           NaN         NaN                  NaN  ...
# 81686                 NaN           NaN         NaN                  NaN  ...
# 81687                 NaN           NaN         NaN                  NaN  ...
# 81688                 NaN           NaN         NaN                  NaN  ...
# ...                   ...           ...         ...                  ...  ...
# 82536                 0.0          15.0         0.0                  0.0  ...
# 82537                 0.0          15.0         0.0                  0.0  ...
# 82538                 0.0          15.0         0.0                  0.0  ...
# 82539                 0.0          15.0         0.0                  0.0  ...
# 82540                 0.0          15.0         0.0                  0.0  ...
#
#        female_smokers  male_smokers  handwashing_facilities  \
# 81684             NaN           NaN                     NaN
# 81685             NaN           NaN                     NaN
# 81686             NaN           NaN                     NaN
# 81687             NaN           NaN                     NaN
# 81688             NaN           NaN                     NaN
# ...               ...           ...                     ...
# 82536             NaN           NaN                     NaN
# 82537             NaN           NaN                     NaN
# 82538             NaN           NaN                     NaN
# 82539             NaN           NaN                     NaN
# 82540             NaN           NaN                     NaN
#
#        hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 81684                         NaN              NaN                      NaN
# 81685                         NaN              NaN                      NaN
# 81686                         NaN              NaN                      NaN
# 81687                         NaN              NaN                      NaN
# 81688                         NaN              NaN                      NaN
# ...                           ...              ...                      ...
# 82536                         NaN              NaN                      NaN
# 82537                         NaN              NaN                      NaN
# 82538                         NaN              NaN                      NaN
# 82539                         NaN              NaN                      NaN
# 82540                         NaN              NaN                      NaN
#
#        excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 81684                                   NaN                          NaN
# 81685                                   NaN                          NaN
# 81686                                   NaN                          NaN
# 81687                                   NaN                          NaN
# 81688                                   NaN                          NaN
# ...                                     ...                          ...
# 82536                                   NaN                          NaN
# 82537                                   NaN                          NaN
# 82538                                   NaN                          NaN
# 82539                                   NaN                          NaN
# 82540                                   NaN                          NaN
#
#        excess_mortality  excess_mortality_cumulative_per_million
# 81684               NaN                                      NaN
# 81685               NaN                                      NaN
# 81686               NaN                                      NaN
# 81687               NaN                                      NaN
# 81688               NaN                                      NaN
# ...                 ...                                      ...
# 82536               NaN                                      NaN
# 82537               NaN                                      NaN
# 82538               NaN                                      NaN
# 82539               NaN                                      NaN
# 82540               NaN                                      NaN
#
# [857 rows x 67 columns]

# %%
df.location.unique()
# Out:
# array(['Afghanistan', 'Africa', 'Albania', 'Algeria', 'Andorra', 'Angola',
#        'Anguilla', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        'Asia', 'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain',
#        'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin',
#        'Bermuda', 'Bhutan', 'Bolivia', 'Bonaire Sint Eustatius and Saba',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Brunei', 'Bulgaria', 'Burkina Faso',
#        'Burundi', 'Cambodia', 'Cameroon', 'Canada', 'Cape Verde',
#        'Cayman Islands', 'Central African Republic', 'Chad', 'Chile',
#        'China', 'Colombia', 'Comoros', 'Congo', 'Cook Islands',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Curacao',
#        'Cyprus', 'Czechia', 'Democratic Republic of Congo', 'Denmark',
#        'Djibouti', 'Dominica', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Estonia',
#        'Eswatini', 'Ethiopia', 'Europe', 'European Union',
#        'Faeroe Islands', 'Falkland Islands', 'Fiji', 'Finland', 'France',
#        'French Polynesia', 'Gabon', 'Gambia', 'Georgia', 'Germany',
#        'Ghana', 'Gibraltar', 'Greece', 'Greenland', 'Grenada', 'Guam',
#        'Guatemala', 'Guernsey', 'Guinea', 'Guinea-Bissau', 'Guyana',
#        'Haiti', 'High income', 'Honduras', 'Hong Kong', 'Hungary',
#        'Iceland', 'India', 'Indonesia', 'International', 'Iran', 'Iraq',
#        'Ireland', 'Isle of Man', 'Israel', 'Italy', 'Jamaica', 'Japan',
#        'Jersey', 'Jordan', 'Kazakhstan', 'Kenya', 'Kiribati', 'Kosovo',
#        'Kuwait', 'Kyrgyzstan', 'Laos', 'Latvia', 'Lebanon', 'Lesotho',
#        'Liberia', 'Libya', 'Liechtenstein', 'Lithuania', 'Low income',
#        'Lower middle income', 'Luxembourg', 'Macao', 'Madagascar',
#        'Malawi', 'Malaysia', 'Maldives', 'Mali', 'Malta',
#        'Marshall Islands', 'Mauritania', 'Mauritius', 'Mexico',
#        'Micronesia (country)', 'Moldova', 'Monaco', 'Mongolia',
#        'Montenegro', 'Montserrat', 'Morocco', 'Mozambique', 'Myanmar',
#        'Namibia', 'Nauru', 'Nepal', 'Netherlands', 'New Caledonia',
#        'New Zealand', 'Nicaragua', 'Niger', 'Nigeria', 'Niue',
#        'North America', 'North Korea', 'North Macedonia',
#        'Northern Cyprus', 'Northern Mariana Islands', 'Norway', 'Oceania',
#        'Oman', 'Pakistan', 'Palau', 'Palestine', 'Panama',
#        'Papua New Guinea', 'Paraguay', 'Peru', 'Philippines', 'Pitcairn',
#        'Poland', 'Portugal', 'Puerto Rico', 'Qatar', 'Romania', 'Russia',
#        'Rwanda', 'Saint Helena', 'Saint Kitts and Nevis', 'Saint Lucia',
#        'Saint Pierre and Miquelon', 'Saint Vincent and the Grenadines',
#        'Samoa', 'San Marino', 'Sao Tome and Principe', 'Saudi Arabia',
#        'Senegal', 'Serbia', 'Seychelles', 'Sierra Leone', 'Singapore',
#        'Sint Maarten (Dutch part)', 'Slovakia', 'Slovenia',
#        'Solomon Islands', 'Somalia', 'South Africa', 'South America',
#        'South Korea', 'South Sudan', 'Spain', 'Sri Lanka', 'Sudan',
#        'Suriname', 'Sweden', 'Switzerland', 'Syria', 'Taiwan',
#        'Tajikistan', 'Tanzania', 'Thailand', 'Timor', 'Togo', 'Tokelau',
#        'Tonga', 'Trinidad and Tobago', 'Tunisia', 'Turkey',
#        'Turkmenistan', 'Turks and Caicos Islands', 'Tuvalu', 'Uganda',
#        'Ukraine', 'United Arab Emirates', 'United Kingdom',
#        'United States', 'United States Virgin Islands',
#        'Upper middle income', 'Uruguay', 'Uzbekistan', 'Vanuatu',
#        'Vatican', 'Venezuela', 'Vietnam', 'Wallis and Futuna',
#        'Western Sahara', 'World', 'Yemen', 'Zambia', 'Zimbabwe'],
#       dtype=object)

# %%
df["date"] = pd.to_datetime(df["date"])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193475 entries, 0 to 193474
# Data columns (total 67 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   iso_code                                    193475 non-null  object
#  1   continent                                   182232 non-null  object
#  2   location                                    193475 non-null  object
#  3   date                                        193475 non-null  datetime64[ns]
#  4   total_cases                                 185895 non-null  float64
#  5   new_cases                                   185610 non-null  float64
#  6   new_cases_smoothed                          184436 non-null  float64
#  7   total_deaths                                167374 non-null  float64
#  8   new_deaths                                  167357 non-null  float64
#  9   new_deaths_smoothed                         166194 non-null  float64
#  10  total_cases_per_million                     185038 non-null  float64
#  11  new_cases_per_million                       184753 non-null  float64
#  12  new_cases_smoothed_per_million              183584 non-null  float64
#  13  total_deaths_per_million                    166530 non-null  float64
#  14  new_deaths_per_million                      166513 non-null  float64
#  15  new_deaths_smoothed_per_million             165355 non-null  float64
#  16  reproduction_rate                           144528 non-null  float64
#  17  icu_patients                                25717 non-null   float64
#  18  icu_patients_per_million                    25717 non-null   float64
#  19  hosp_patients                               26959 non-null   float64
#  20  hosp_patients_per_million                   26959 non-null   float64
#  21  weekly_icu_admissions                       6288 non-null    float64
#  22  weekly_icu_admissions_per_million           6288 non-null    float64
#  23  weekly_hosp_admissions                      12524 non-null   float64
#  24  weekly_hosp_admissions_per_million          12524 non-null   float64
#  25  total_tests                                 78123 non-null   float64
#  26  new_tests                                   74376 non-null   float64
#  27  total_tests_per_thousand                    78123 non-null   float64
#  28  new_tests_per_thousand                      74376 non-null   float64
#  29  new_tests_smoothed                          101979 non-null  float64
#  30  new_tests_smoothed_per_thousand             101979 non-null  float64
#  31  positive_rate                               94068 non-null   float64
#  32  tests_per_case                              92295 non-null   float64
#  33  tests_units                                 104773 non-null  object
#  34  total_vaccinations                          53023 non-null   float64
#  35  people_vaccinated                           50499 non-null   float64
#  36  people_fully_vaccinated                     47992 non-null   float64
#  37  total_boosters                              25049 non-null   float64
#  38  new_vaccinations                            43456 non-null   float64
#  39  new_vaccinations_smoothed                   104878 non-null  float64
#  40  total_vaccinations_per_hundred              53023 non-null   float64
#  41  people_vaccinated_per_hundred               50499 non-null   float64
#  42  people_fully_vaccinated_per_hundred         47992 non-null   float64
#  43  total_boosters_per_hundred                  25049 non-null   float64
#  44  new_vaccinations_smoothed_per_million       104878 non-null  float64
#  45  new_people_vaccinated_smoothed              103921 non-null  float64
#  46  new_people_vaccinated_smoothed_per_hundred  103921 non-null  float64
#  47  stringency_index                            150458 non-null  float64
#  48  population                                  192301 non-null  float64
#  49  population_density                          172400 non-null  float64
#  50  median_age                                  159788 non-null  float64
#  51  aged_65_older                               158095 non-null  float64
#  52  aged_70_older                               158950 non-null  float64
#  53  gdp_per_capita                              158943 non-null  float64
#  54  extreme_poverty                             103750 non-null  float64
#  55  cardiovasc_death_rate                       159419 non-null  float64
#  56  diabetes_prevalence                         167218 non-null  float64
#  57  female_smokers                              120582 non-null  float64
#  58  male_smokers                                118929 non-null  float64
#  59  handwashing_facilities                      78332 non-null   float64
#  60  hospital_beds_per_thousand                  141453 non-null  float64
#  61  life_expectancy                             180939 non-null  float64
#  62  human_development_index                     155322 non-null  float64
#  63  excess_mortality_cumulative_absolute        6606 non-null    float64
#  64  excess_mortality_cumulative                 6606 non-null    float64
#  65  excess_mortality                            6606 non-null    float64
#  66  excess_mortality_cumulative_per_million     6606 non-null    float64
# dtypes: datetime64[ns](1), float64(62), object(4)
# memory usage: 98.9+ MB

# %% [markdown]
# ## 最新日付チェック

# %%
import datetime
#latest_date_str = (df.date.max()-datetime.timedelta(days=1)).strftime("%Y-%m-%d")
latest_date_str = df.date.max().strftime("%Y-%m-%d")
latest_date_str
# Out:
# '2022-06-12'

# %% [markdown]
# ## 全世界のデータのみ

# %%
world_df = df.copy().loc[df.location=="World"]
world_df.tail()
# Out:
#         iso_code continent location       date  total_cases  new_cases  \
# 191044  OWID_WRL       NaN    World 2022-06-08  533662004.0   710960.0
# 191045  OWID_WRL       NaN    World 2022-06-09  534209789.0   547785.0
# 191046  OWID_WRL       NaN    World 2022-06-10  534785819.0   576030.0
# 191047  OWID_WRL       NaN    World 2022-06-11  535062191.0   276468.0
# 191048  OWID_WRL       NaN    World 2022-06-12  535257886.0   195695.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 191044          479145.571     6304835.0      2595.0             1458.286
# 191045          482962.429     6306423.0      1588.0             1459.000
# 191046          488245.714     6308113.0      1694.0             1483.286
# 191047          492167.143     6308976.0       863.0             1518.286
# 191048          483654.286     6309431.0       455.0             1483.857
#
#         ...  female_smokers  male_smokers  handwashing_facilities  \
# 191044  ...           6.434        34.635                   60.13
# 191045  ...           6.434        34.635                   60.13
# 191046  ...           6.434        34.635                   60.13
# 191047  ...           6.434        34.635                   60.13
# 191048  ...           6.434        34.635                   60.13
#
#         hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 191044                       2.705            72.58                    0.737
# 191045                       2.705            72.58                    0.737
# 191046                       2.705            72.58                    0.737
# 191047                       2.705            72.58                    0.737
# 191048                       2.705            72.58                    0.737
#
#         excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 191044                                   NaN                          NaN
# 191045                                   NaN                          NaN
# 191046                                   NaN                          NaN
# 191047                                   NaN                          NaN
# 191048                                   NaN                          NaN
#
#         excess_mortality  excess_mortality_cumulative_per_million
# 191044               NaN                                      NaN
# 191045               NaN                                      NaN
# 191046               NaN                                      NaN
# 191047               NaN                                      NaN
# 191048               NaN                                      NaN
#
# [5 rows x 67 columns]

# %% [markdown]
# ### 主要国の定義

# %%
countries = pd.DataFrame([
    ("Japan",""),
    ("United States",""),
    ("Germany",""),
#    ("India",""),
#    ("Indonesia",""),
#    ("Spain",""),
    ("Brazil",""),
    ("France",""),
    ("United Kingdom",""),
    ("Russia",""),
    ("Turkey",""),
#    ("South Africa",""),
#    ("Iran",""),
    ("Poland",""),
#    ("Ecuador",""),
],columns=["country","text_disp_date"])
countries
# Out:
#           country text_disp_date
# 0           Japan
# 1   United States
# 2         Germany
# 3          Brazil
# 4          France
# 5  United Kingdom
# 6          Russia
# 7          Turkey
# 8          Poland

# %%
# 東Asia 主要国
e_asia_c = pd.DataFrame([
    ("Japan",""),
    ("China",""),
    ("Taiwan",""),
    ("South Korea",""),
    ("Indonesia",""),
    ("Philippines",""),
    ("Vietnam",""),
    ("Myanmar",""),
    ("Thailand",""),
],columns=["country","text_disp_date"])
e_asia_c
# Out:
#        country text_disp_date
# 0        Japan
# 1        China
# 2       Taiwan
# 3  South Korea
# 4    Indonesia
# 5  Philippines
# 6      Vietnam
# 7      Myanmar
# 8     Thailand

# %%
c_trans = pd.merge(countries, df, left_on="country", right_on="location",how="inner")
c_trans.head()
# Out:
#   country text_disp_date iso_code continent location       date  total_cases  \
# 0   Japan                     JPN      Asia    Japan 2020-01-22          2.0
# 1   Japan                     JPN      Asia    Japan 2020-01-23          2.0
# 2   Japan                     JPN      Asia    Japan 2020-01-24          2.0
# 3   Japan                     JPN      Asia    Japan 2020-01-25          2.0
# 4   Japan                     JPN      Asia    Japan 2020-01-26          4.0
#
#    new_cases  new_cases_smoothed  total_deaths  ...  female_smokers  \
# 0        NaN                 NaN           NaN  ...            11.2
# 1        0.0                 NaN           NaN  ...            11.2
# 2        0.0                 NaN           NaN  ...            11.2
# 3        0.0                 NaN           NaN  ...            11.2
# 4        2.0                 NaN           NaN  ...            11.2
#
#    male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 0          33.7                     NaN                       13.05
# 1          33.7                     NaN                       13.05
# 2          33.7                     NaN                       13.05
# 3          33.7                     NaN                       13.05
# 4          33.7                     NaN                       13.05
#
#    life_expectancy  human_development_index  \
# 0            84.63                    0.919
# 1            84.63                    0.919
# 2            84.63                    0.919
# 3            84.63                    0.919
# 4            84.63                    0.919
#
#    excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                   NaN                          NaN
# 1                                   NaN                          NaN
# 2                                   NaN                          NaN
# 3                                   NaN                          NaN
# 4                                   NaN                          NaN
#
#    excess_mortality  excess_mortality_cumulative_per_million
# 0               NaN                                      NaN
# 1               NaN                                      NaN
# 2               NaN                                      NaN
# 3               NaN                                      NaN
# 4               NaN                                      NaN
#
# [5 rows x 69 columns]

# %%
c_trans.location.unique()
# Out:
# array(['Japan', 'United States', 'Germany', 'Brazil', 'France',
#        'United Kingdom', 'Russia', 'Turkey', 'Poland'], dtype=object)

# %%
c_trans.loc[c_trans.date==latest_date_str][["country","date","total_deaths","total_deaths_per_million"]].sort_values("total_deaths_per_million",ascending=False)
# Out:
#              country       date  total_deaths  total_deaths_per_million
# 3451          Brazil 2022-06-12      668110.0                  3122.105
# 7705          Poland 2022-06-12      116371.0                  3078.842
# 1745   United States 2022-06-12     1011275.0                  3037.637
# 5186  United Kingdom 2022-06-12      179393.0                  2630.122
# 6050          Russia 2022-06-12      372338.0                  2551.798
# 4322          France 2022-06-12      148818.0                  2207.262
# 2613         Germany 2022-06-12      139807.0                  1666.343
# 6874          Turkey 2022-06-12       98965.0                  1163.709
# 872            Japan 2022-06-12       30888.0                   245.044

# %%
e_a_trans = pd.merge(e_asia_c, df, left_on="country", right_on="location",how="inner")
e_a_trans
# Out:
#        country text_disp_date iso_code continent  location       date  \
# 0        Japan                     JPN      Asia     Japan 2020-01-22
# 1        Japan                     JPN      Asia     Japan 2020-01-23
# 2        Japan                     JPN      Asia     Japan 2020-01-24
# 3        Japan                     JPN      Asia     Japan 2020-01-25
# 4        Japan                     JPN      Asia     Japan 2020-01-26
# ...        ...            ...      ...       ...       ...        ...
# 7762  Thailand                     THA      Asia  Thailand 2022-06-08
# 7763  Thailand                     THA      Asia  Thailand 2022-06-09
# 7764  Thailand                     THA      Asia  Thailand 2022-06-10
# 7765  Thailand                     THA      Asia  Thailand 2022-06-11
# 7766  Thailand                     THA      Asia  Thailand 2022-06-12
#
#       total_cases  new_cases  new_cases_smoothed  total_deaths  ...  \
# 0             2.0        NaN                 NaN           NaN  ...
# 1             2.0        0.0                 NaN           NaN  ...
# 2             2.0        0.0                 NaN           NaN  ...
# 3             2.0        0.0                 NaN           NaN  ...
# 4             4.0        2.0                 NaN           NaN  ...
# ...           ...        ...                 ...           ...  ...
# 7762    4477052.0     3185.0            2781.714       30262.0  ...
# 7763    4479888.0     2836.0            2761.714       30286.0  ...
# 7764    4482389.0     2501.0            2690.286       30314.0  ...
# 7765    4484863.0     2474.0            2581.429       30334.0  ...
# 7766    4486664.0     1801.0            2529.857       30349.0  ...
#
#       female_smokers  male_smokers  handwashing_facilities  \
# 0               11.2          33.7                     NaN
# 1               11.2          33.7                     NaN
# 2               11.2          33.7                     NaN
# 3               11.2          33.7                     NaN
# 4               11.2          33.7                     NaN
# ...              ...           ...                     ...
# 7762             1.9          38.8                   90.67
# 7763             1.9          38.8                   90.67
# 7764             1.9          38.8                   90.67
# 7765             1.9          38.8                   90.67
# 7766             1.9          38.8                   90.67
#
#       hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                          13.05            84.63                    0.919
# 1                          13.05            84.63                    0.919
# 2                          13.05            84.63                    0.919
# 3                          13.05            84.63                    0.919
# 4                          13.05            84.63                    0.919
# ...                          ...              ...                      ...
# 7762                        2.10            77.15                    0.777
# 7763                        2.10            77.15                    0.777
# 7764                        2.10            77.15                    0.777
# 7765                        2.10            77.15                    0.777
# 7766                        2.10            77.15                    0.777
#
#       excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                      NaN                          NaN
# 1                                      NaN                          NaN
# 2                                      NaN                          NaN
# 3                                      NaN                          NaN
# 4                                      NaN                          NaN
# ...                                    ...                          ...
# 7762                                   NaN                          NaN
# 7763                                   NaN                          NaN
# 7764                                   NaN                          NaN
# 7765                                   NaN                          NaN
# 7766                                   NaN                          NaN
#
#       excess_mortality  excess_mortality_cumulative_per_million
# 0                  NaN                                      NaN
# 1                  NaN                                      NaN
# 2                  NaN                                      NaN
# 3                  NaN                                      NaN
# 4                  NaN                                      NaN
# ...                ...                                      ...
# 7762               NaN                                      NaN
# 7763               NaN                                      NaN
# 7764               NaN                                      NaN
# 7765               NaN                                      NaN
# 7766               NaN                                      NaN
#
# [7767 rows x 69 columns]

# %%
e_a_trans.location.unique()
# Out:
# array(['Japan', 'China', 'Taiwan', 'South Korea', 'Indonesia',
#        'Philippines', 'Vietnam', 'Myanmar', 'Thailand'], dtype=object)

# %% [markdown]
# ## 今日の新規感染者数

# %%
#c_df_latest = df.loc[(df.date==pd.to_datetime(latest_date_str)-datetime.timedelta(days=1)) & (df.iso_code.str.len()==3)]
c_df_latest = df.loc[(df.date==pd.to_datetime(latest_date_str)) & (df.iso_code.str.len()==3)]

c_df_latest
# Out:
#        iso_code continent           location       date  total_cases  \
# 839         AFG      Asia        Afghanistan 2022-06-12     180864.0
# 2529        ALB    Europe            Albania 2022-06-12     276731.0
# 3368        DZA    Africa            Algeria 2022-06-12     265927.0
# 4201        AND    Europe            Andorra 2022-06-12      43224.0
# 5016        AGO    Africa             Angola 2022-06-12      99761.0
# ...         ...       ...                ...        ...          ...
# 189572      VNM      Asia            Vietnam 2022-06-12   10731812.0
# 190174      WLF   Oceania  Wallis and Futuna 2022-06-12        454.0
# 191842      YEM      Asia              Yemen 2022-06-12      11822.0
# 192659      ZMB    Africa             Zambia 2022-06-12     323058.0
# 193474      ZWE    Africa           Zimbabwe 2022-06-12     254098.0
#
#         new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 839           0.0              35.571        7709.0         0.0
# 2529         41.0              47.143        3497.0         0.0
# 3368          2.0               4.286        6875.0         0.0
# 4201          NaN                 NaN         153.0         0.0
# 5016          0.0               0.000        1900.0         0.0
# ...           ...                 ...           ...         ...
# 189572      568.0             939.000       43083.0         0.0
# 190174        0.0               0.000           7.0         0.0
# 191842        0.0               0.000        2149.0         0.0
# 192659        NaN                 NaN        3989.0         0.0
# 193474       67.0             108.571        5521.0         3.0
#
#         new_deaths_smoothed  ...  female_smokers  male_smokers  \
# 839                   0.143  ...             NaN           NaN
# 2529                  0.000  ...             7.1          51.2
# 3368                  0.000  ...             0.7          30.4
# 4201                  0.000  ...            29.0          37.8
# 5016                  0.000  ...             NaN           NaN
# ...                     ...  ...             ...           ...
# 189572                0.429  ...             1.0          45.9
# 190174                0.000  ...             NaN           NaN
# 191842                0.000  ...             7.6          29.2
# 192659                0.143  ...             3.1          24.7
# 193474                1.571  ...             1.6          30.7
#
#         handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 839                     37.746                        0.50            64.83
# 2529                       NaN                        2.89            78.57
# 3368                    83.741                        1.90            76.88
# 4201                       NaN                         NaN            83.73
# 5016                    26.664                         NaN            61.15
# ...                        ...                         ...              ...
# 189572                  85.847                        2.60            75.40
# 190174                     NaN                         NaN            79.94
# 191842                  49.542                        0.70            66.12
# 192659                  13.938                        2.00            63.89
# 193474                  36.791                        1.70            61.49
#
#         human_development_index  excess_mortality_cumulative_absolute  \
# 839                       0.511                                   NaN
# 2529                      0.795                                   NaN
# 3368                      0.748                                   NaN
# 4201                      0.868                                   NaN
# 5016                      0.581                                   NaN
# ...                         ...                                   ...
# 189572                    0.704                                   NaN
# 190174                      NaN                                   NaN
# 191842                    0.470                                   NaN
# 192659                    0.584                                   NaN
# 193474                    0.571                                   NaN
#
#         excess_mortality_cumulative  excess_mortality  \
# 839                             NaN               NaN
# 2529                            NaN               NaN
# 3368                            NaN               NaN
# 4201                            NaN               NaN
# 5016                            NaN               NaN
# ...                             ...               ...
# 189572                          NaN               NaN
# 190174                          NaN               NaN
# 191842                          NaN               NaN
# 192659                          NaN               NaN
# 193474                          NaN               NaN
#
#         excess_mortality_cumulative_per_million
# 839                                         NaN
# 2529                                        NaN
# 3368                                        NaN
# 4201                                        NaN
# 5016                                        NaN
# ...                                         ...
# 189572                                      NaN
# 190174                                      NaN
# 191842                                      NaN
# 192659                                      NaN
# 193474                                      NaN
#
# [215 rows x 67 columns]

# %%
c_df_latest.sum()
# Out:
# /tmp/ipykernel_4472/3714355302.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   c_df_latest.sum()
# iso_code                                   AFGALBDZAANDAGOAIAATGARGARMABWAUSAUTAZEBHSBHRB...
# continent                                  AsiaEuropeAfricaEuropeAfricaNorth AmericaNorth...
# location                                   AfghanistanAlbaniaAlgeriaAndorraAngolaAnguilla...
# total_cases                                                                      535028727.0
# new_cases                                                                           195687.0
#                                                                  ...
# human_development_index                                                              135.823
# excess_mortality_cumulative_absolute                                                     0.0
# excess_mortality_cumulative                                                              0.0
# excess_mortality                                                                         0.0
# excess_mortality_cumulative_per_million                                                  0.0
# Length: 66, dtype: object

# %% [markdown]
# ## 可視化

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook
#%matplotlib inline

# %%
min_date = pd.to_datetime(datetime.datetime.now()).round("D")- datetime.timedelta(days=90)

# %%
world_df["case_rolling7ave"] = world_df.new_cases.rolling(7).mean()
world_df[["new_cases_smoothed","case_rolling7ave"]]
# Out:
#         new_cases_smoothed  case_rolling7ave
# 190176                 NaN               NaN
# 190177                 NaN               NaN
# 190178                 NaN               NaN
# 190179                 NaN               NaN
# 190180                 NaN               NaN
# ...                    ...               ...
# 191044          479145.571     479145.571429
# 191045          482962.429     482962.428571
# 191046          488245.714     488245.714286
# 191047          492167.143     492167.142857
# 191048          483654.286     483654.285714
#
# [873 rows x 2 columns]

# %%
fig=plt.figure(figsize=(20,12))
plt.subplot(2,2,1) # (rows, columns, panel number)
plt.title("Daily new confirmed COVID-19 cases in the world")
plt.bar(world_df.date,world_df.new_cases,label="New cases")
plt.plot_date(world_df["date"],world_df["new_cases_smoothed"],label="7daysMA", fmt="-", color="orange")
#plt.xticks(rotation=70)
plt.ylabel("people")
plt.grid(axis="y")
plt.legend()

plt.subplot(2,2,2) # (rows, columns, panel number)
plt.title("Daily new confirmed COVID-19 cases in the world(Recent)")
chart_data = world_df[world_df.date >= min_date]
plt.bar(chart_data["date"],chart_data["new_cases"],label="New cases")
plt.plot_date(chart_data["date"],chart_data["new_cases_smoothed"],label="7days MA", fmt="-", color="orange")
#plt.xticks(rotation=70)
plt.grid(axis="y")
plt.legend()

plt.subplot(2,2,3) # (rows, columns, panel number)
plt.title("Daily new deaths in the world")
plt.bar(world_df.date,world_df.new_deaths,label="New deaths")
plt.plot_date(world_df["date"],world_df["new_deaths_smoothed"],label="7days MA", fmt="-", color="orange")
#plt.xticks(rotation=70)
plt.ylabel("people")
plt.grid(axis="y")
plt.legend()

plt.subplot(2,2,4) # (rows, columns, panel number)
plt.title("Daily new deaths in the world(Recent)")
chart_data = world_df[world_df.date >= min_date]
plt.bar(chart_data["date"],chart_data["new_deaths"],label="New deaths")
plt.plot_date(chart_data["date"],chart_data["new_deaths_smoothed"],label="7days MA", fmt="-", color="orange")
#plt.xticks(rotation=70)
plt.grid(axis="y")
plt.legend()

fig.text(0,1,"Latest: {}".format(latest_date_str),ha="left",va="top")
fig.text(0,0
         ,"*Data Source : COVID-19 Dataset by Our World in Data",
        ha="left",va="bottom")

plt.tight_layout()
# Out:
# <div id='baff5540-0bb0-4576-bee1-12251cbf6fbb'></div>
# findfont: Font family ['Noto Sans CJK JP'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Noto Sans CJK JP'] not found. Falling back to DejaVu Sans.

# %%
fig.savefig("out/covid-owid-global-daily.png")

# %% [markdown]
# ### 国別

# %% [markdown]
# #### 人口100万人当たりの新規感染者数（直近）

# %%
"""
#min_date = pd.to_datetime("2021-05-01")
# 主要国 新規感染者
chart_data = c_trans[c_trans.date >= min_date]
dates = chart_data["date"].unique()
print(len(dates))
print(dates.max())
for i,cr in countries.iterrows():
    c = cr["country"]
    dates = chart_data.loc[chart_data["location"]==c]["date"]
    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else latest_date_str
    print(len(chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"]))
    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"],label=c, fmt="-")
    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_cases_smoothed_per_million"],c
            ,fontsize=8,va="center")
"""
# Out:
# '\n#min_date = pd.to_datetime("2021-05-01")\n# 主要国 新規感染者\nchart_data = c_trans[c_trans.date >= min_date]\ndates = chart_data["date"].unique()\nprint(len(dates))\nprint(dates.max())\nfor i,cr in countries.iterrows():\n    c = cr["country"]\n    dates = chart_data.loc[chart_data["location"]==c]["date"]\n    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else latest_date_str\n    print(len(chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"]))\n    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"],label=c, fmt="-")\n    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_cases_smoothed_per_million"],c\n            ,fontsize=8,va="center")\n'

# %%
"""
fig=plt.figure(figsize=(14,10))
min_date = pd.to_datetime("2021-03-01")
# 主要国 新規感染者
plt.subplot(2,2,1) # (rows, columns, panel number)
plt.title("Daily new confirmed COVID-19 cases\n per million population in major countries\n(rolling 7day ave.)")
plt.grid()
plt.xticks(rotation=70)
chart_data = c_trans[c_trans.date >= min_date]
dates = chart_data["date"].unique()
for i,cr in countries.iterrows():
    c = cr["country"]
    dates = chart_data.loc[chart_data["location"]==c]["date"]
    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else dates.max()
    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"],label=c, fmt="-")
    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_cases_smoothed_per_million"],c
            ,fontsize=8,va="center")
plt.legend(bbox_to_anchor=(0, 1),loc='upper left', fontsize=9)
"""
# Out:
# '\nfig=plt.figure(figsize=(14,10))\nmin_date = pd.to_datetime("2021-03-01")\n# 主要国 新規感染者\nplt.subplot(2,2,1) # (rows, columns, panel number)\nplt.title("Daily new confirmed COVID-19 cases\n per million population in major countries\n(rolling 7day ave.)")\nplt.grid()\nplt.xticks(rotation=70)\nchart_data = c_trans[c_trans.date >= min_date]\ndates = chart_data["date"].unique()\nfor i,cr in countries.iterrows():\n    c = cr["country"]\n    dates = chart_data.loc[chart_data["location"]==c]["date"]\n    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else dates.max()\n    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"],label=c, fmt="-")\n    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_cases_smoothed_per_million"],c\n            ,fontsize=8,va="center")\nplt.legend(bbox_to_anchor=(0, 1),loc=\'upper left\', fontsize=9)\n'

# %%
fig=plt.figure(figsize=(20,14))
# 主要国 新規感染者
plt.subplot(2,2,1) # (rows, columns, panel number)
plt.title("Daily new confirmed COVID-19 cases\n per million population in major countries(7daysMA)")
plt.grid()
plt.xticks(rotation=45)
chart_data = c_trans[c_trans.date >= min_date]
for i,cr in countries.iterrows():
    c = cr["country"]
    dates = chart_data.loc[chart_data["location"]==c]["date"]
    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else dates.max()
    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"],label=c, fmt="-")
    text_y = chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_cases_smoothed_per_million"]
#    print(text_y)
    print(c,text_disp_date,text_y)
#    plt.text(text_disp_date,text_y,c,fontsize=10,va="center")
    plt.text(text_disp_date,text_y,c,va="center")
plt.legend(bbox_to_anchor=(0, 1),loc='upper left')

# 主要国 死者
plt.subplot(2,2,2) # (rows, columns, panel number)
plt.title("Daily new deaths in major countries(7daysMA)")
plt.grid()
plt.xticks(rotation=45)
chart_data = c_trans[c_trans.date >= min_date]
for i,cr in countries.iterrows():
    c = cr["country"]
    dates = chart_data.loc[chart_data["location"]==c]["date"]
    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else dates.max()
    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_deaths_smoothed"],label=c, fmt="-")
    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_deaths_smoothed"],c
            ,va="center")
plt.legend(bbox_to_anchor=(0, 1),loc='upper left')

plt.subplot(2,2,3) # (rows, columns, panel number)
plt.grid()
plt.xticks(rotation=45)
plt.title("Daily new confirmed COVID-19 cases\n per million population in Eastern Asia(7daysMA)")
chart_data = e_a_trans[e_a_trans.date >= min_date]
for i,cr in e_asia_c.iterrows():
    c = cr["country"]
    dates = chart_data.loc[chart_data["location"]==c]["date"]
    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else dates.max()
    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"],label=c, fmt="-")
    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_cases_smoothed_per_million"],c
             ,va="center")
plt.legend(bbox_to_anchor=(0, 1),loc='upper left')

plt.subplot(2,2,4) # (rows, columns, panel number)
plt.grid()
plt.xticks(rotation=45)
plt.title("Daily new deaths in Eastern Asia(7daysMA)")
chart_data = e_a_trans[e_a_trans.date >= min_date]
for i,cr in e_asia_c.iterrows():
    c = cr["country"]
    dates = chart_data.loc[chart_data["location"]==c]["date"]
    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else dates.max()
    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_deaths_smoothed"],label=c, fmt="-")
    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_deaths_smoothed"],c
             ,va="center")
plt.legend(bbox_to_anchor=(0, 1),loc='upper left')

fig.text(0,0.98,"Latest: {}".format(latest_date_str),ha="left",va="top")
fig.text(0,0
         ,"*Data Source : COVID-19 Dataset by Our World in Data",
        ha="left",va="bottom")
fig.tight_layout()
"""
"""
# Out:
# <div id='b0bde423-c7be-4db8-8836-4f1f2f4950b8'></div>
# Japan 2022-06-12 00:00:00 872    119.662
# Name: new_cases_smoothed_per_million, dtype: float64
# United States 2022-06-12 00:00:00 1745    323.451
# Name: new_cases_smoothed_per_million, dtype: float64
# Germany 2022-06-12 00:00:00 2613    532.321
# Name: new_cases_smoothed_per_million, dtype: float64
# Brazil 2022-06-12 00:00:00 3451    213.215
# Name: new_cases_smoothed_per_million, dtype: float64
# France 2022-06-12 00:00:00 4322    237.091
# Name: new_cases_smoothed_per_million, dtype: float64
# United Kingdom 2022-06-12 00:00:00 5186   NaN
# Name: new_cases_smoothed_per_million, dtype: float64
# Russia 2022-06-12 00:00:00 6050    23.792
# Name: new_cases_smoothed_per_million, dtype: float64
# Turkey 2022-06-12 00:00:00 6874    0.0
# Name: new_cases_smoothed_per_million, dtype: float64
# Poland 2022-06-12 00:00:00 7705    5.416
# Name: new_cases_smoothed_per_million, dtype: float64
# '\n'

# %%
fig.savefig("out/covid-owid-countries-daily.png")
# Out:
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values

# %% [markdown]
# ### 新規感染者数

# %%
fig = plt.figure(figsize=(12,14))

plt.subplot(2,2,1) # (rows, columns, panel number)
plt.title("New confirmed COVID-19 cases worst 50")
plt.yticks(fontsize=9)
plt.xlabel("people")
chart_data = c_df_latest.sort_values("new_cases",ascending=False).head(50).sort_values("new_cases",ascending=True)
plt.barh(chart_data["location"],chart_data["new_cases"],label="new cases a day")
plt.grid(axis="x")
mean = int(c_df_latest.new_cases.mean())
plt.plot([mean,mean],[0,50], 'k--', lw=0.5)
plt.text(mean,50,"Mean:{}".format(mean),ha="center",fontsize=9)
plt.legend()

plt.subplot(2,2,2) # (rows, columns, panel number)
plt.title("New confirmed COVID-19 cases per million worst 50")
plt.yticks(fontsize=9)
plt.xlabel("people")
chart_data = c_df_latest.sort_values("new_cases_per_million",ascending=False).head(50).sort_values("new_cases_per_million",ascending=True)
plt.barh(chart_data["location"],chart_data["new_cases_per_million"],label="new cases a day per million")
plt.grid(axis="x")
mean = int(chart_data.new_cases_per_million.mean())
plt.plot([mean,mean],[0,50], 'k--', lw=0.5)
plt.text(mean,50,"Mean:{}".format(mean),ha="center",fontsize=9)
plt.legend()

fig.text(0,0.98,"Latest: {}".format(latest_date_str),fontsize=9,ha="left",va="top")
fig.text(0,0
         ,"*Data Source : COVID-19 Dataset by Our World in Data",
        fontsize=8,ha="left",va="bottom")

plt.subplot(2,2,3) # (rows, columns, panel number)
plt.title("New deaths worst 50")
plt.yticks(fontsize=9)
plt.xlabel("people")
chart_data = c_df_latest.sort_values("new_deaths",ascending=False).head(50).sort_values("new_deaths",ascending=True)
plt.barh(chart_data["location"],chart_data["new_deaths"],label="new deaths a day")
plt.grid(axis="x")
mean = int(c_df_latest.new_deaths.mean())
plt.plot([mean,mean],[0,50], 'k--', lw=0.5)
plt.text(mean,50,"Mean:{}".format(mean),ha="center",fontsize=9)
plt.legend()

plt.subplot(2,2,4) # (rows, columns, panel number)
plt.title("Total deaths per capita worst 50")
plt.yticks(fontsize=9)
plt.xlabel("%")
chart_data = c_df_latest.copy()
chart_data["total_deaths_per_capita"] = chart_data.total_deaths / chart_data.population * 100
chart_data = chart_data.sort_values("total_deaths_per_capita",ascending=False).head(50).sort_values("total_deaths_per_capita",ascending=True)
plt.barh(chart_data["location"],chart_data["total_deaths_per_capita"],label="total deaths per capita")
plt.grid(axis="x")
mean = round(chart_data.total_deaths_per_capita.mean(),2)
plt.plot([mean,mean],[0,50], 'k--', lw=0.5)
plt.text(mean,50,"Mean:{}".format(mean),ha="center",fontsize=9)
plt.legend()


fig.tight_layout()
# Out:
# <div id='db512436-2e8f-41a8-8338-fa2554af0914'></div>
# findfont: Font family ['Noto Sans CJK JP'] not found. Falling back to DejaVu Sans.

# %%
fig.savefig("out/covid-owid-global-latest-top.png")
# Out:
# findfont: Font family ['Noto Sans CJK JP'] not found. Falling back to DejaVu Sans.

# %%
a_df = df.loc[df.location=="Japan"]
c_df = df.loc[(df.date==pd.to_datetime("2021-07-27")) & (df.iso_code.str.len()==3)]

# %%
a_df.tail(10)
# Out:
#       iso_code continent location       date  total_cases  new_cases  \
# 89271      JPN      Asia    Japan 2022-06-03    8900748.0    19257.0
# 89272      JPN      Asia    Japan 2022-06-04    8918984.0    18236.0
# 89273      JPN      Asia    Japan 2022-06-05    8934078.0    15094.0
# 89274      JPN      Asia    Japan 2022-06-06    8943156.0     9078.0
# 89275      JPN      Asia    Japan 2022-06-07    8960177.0    17021.0
# 89276      JPN      Asia    Japan 2022-06-08    8978571.0    18394.0
# 89277      JPN      Asia    Japan 2022-06-09    8995359.0    16788.0
# 89278      JPN      Asia    Japan 2022-06-10    9010943.0    15584.0
# 89279      JPN      Asia    Japan 2022-06-11    9026281.0    15338.0
# 89280      JPN      Asia    Japan 2022-06-12    9039662.0    13381.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 89271           20316.571       30710.0        32.0               29.857  ...
# 89272           19256.571       30733.0        23.0               28.000  ...
# 89273           18456.000       30749.0        16.0               27.571  ...
# 89274           18030.429       30773.0        24.0               27.571  ...
# 89275           17347.143       30799.0        26.0               25.714  ...
# 89276           16738.000       30820.0        21.0               23.571  ...
# 89277           16266.857       30843.0        23.0               23.571  ...
# 89278           15742.143       30864.0        21.0               22.000  ...
# 89279           15328.143       30879.0        15.0               20.857  ...
# 89280           15083.429       30888.0         9.0               19.857  ...
#
#        female_smokers  male_smokers  handwashing_facilities  \
# 89271            11.2          33.7                     NaN
# 89272            11.2          33.7                     NaN
# 89273            11.2          33.7                     NaN
# 89274            11.2          33.7                     NaN
# 89275            11.2          33.7                     NaN
# 89276            11.2          33.7                     NaN
# 89277            11.2          33.7                     NaN
# 89278            11.2          33.7                     NaN
# 89279            11.2          33.7                     NaN
# 89280            11.2          33.7                     NaN
#
#        hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 89271                       13.05            84.63                    0.919
# 89272                       13.05            84.63                    0.919
# 89273                       13.05            84.63                    0.919
# 89274                       13.05            84.63                    0.919
# 89275                       13.05            84.63                    0.919
# 89276                       13.05            84.63                    0.919
# 89277                       13.05            84.63                    0.919
# 89278                       13.05            84.63                    0.919
# 89279                       13.05            84.63                    0.919
# 89280                       13.05            84.63                    0.919
#
#        excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 89271                                   NaN                          NaN
# 89272                                   NaN                          NaN
# 89273                                   NaN                          NaN
# 89274                                   NaN                          NaN
# 89275                                   NaN                          NaN
# 89276                                   NaN                          NaN
# 89277                                   NaN                          NaN
# 89278                                   NaN                          NaN
# 89279                                   NaN                          NaN
# 89280                                   NaN                          NaN
#
#        excess_mortality  excess_mortality_cumulative_per_million
# 89271               NaN                                      NaN
# 89272               NaN                                      NaN
# 89273               NaN                                      NaN
# 89274               NaN                                      NaN
# 89275               NaN                                      NaN
# 89276               NaN                                      NaN
# 89277               NaN                                      NaN
# 89278               NaN                                      NaN
# 89279               NaN                                      NaN
# 89280               NaN                                      NaN
#
# [10 rows x 67 columns]

# %%
c_df.sort_values("new_deaths",ascending=False).head(50)
# Out:
#        iso_code      continent        location       date  total_cases  \
# 81363       IDN           Asia       Indonesia 2021-07-27    3239936.0
# 24692       BRA  South America          Brazil 2021-07-27   19758310.0
# 144349      RUS         Europe          Russia 2021-07-27    6094379.0
# 80530       IND           Asia           India 2021-07-27   31484605.0
# 113014      MEX  North America          Mexico 2021-07-27    2771846.0
# 182832      USA  North America   United States 2021-07-27   34718965.0
# 83065       IRN           Asia            Iran 2021-07-27    3758197.0
# 120122      MMR           Asia         Myanmar 2021-07-27     279119.0
# 160642      ZAF         Africa    South Africa 2021-07-27    2391223.0
# 37166       COL  South America        Colombia 2021-07-27    4747775.0
# 14803       BGD           Asia      Bangladesh 2021-07-27    1194752.0
# 7219        ARG  South America       Argentina 2021-07-27    4875927.0
# 107248      MYS           Asia        Malaysia 2021-07-27    1044071.0
# 176236      TUN         Africa         Tunisia 2021-07-27     575002.0
# 181959      GBR         Europe  United Kingdom 2021-07-27    5754319.0
# 172407      THA           Asia        Thailand 2021-07-27     526828.0
# 193154      ZWE         Africa        Zimbabwe 2021-07-27     101711.0
# 138371      PER  South America            Peru 2021-07-27    2106371.0
# 42463       CUB  North America            Cuba 2021-07-27     349055.0
# 139236      PHL           Asia     Philippines 2021-07-27    1562420.0
# 83905       IRQ           Asia            Iraq 2021-07-27    1577013.0
# 21417       BOL  South America         Bolivia 2021-07-27     470024.0
# 71664       GTM  North America       Guatemala 2021-07-27     355223.0
# 77125       HND  North America        Honduras 2021-07-27     291687.0
# 137542      PRY  South America        Paraguay 2021-07-27     450494.0
# 164019      ESP         Europe           Spain 2021-07-27    4368453.0
# 177060      TUR           Asia          Turkey 2021-07-27    5638178.0
# 164887      LKA           Asia       Sri Lanka 2021-07-27     299892.0
# 133948      PAK           Asia        Pakistan 2021-07-27    1015827.0
# 39977       CRI  North America      Costa Rica 2021-07-27     402044.0
# 180229      UKR         Europe         Ukraine 2021-07-27    2327777.0
# 65877       DEU         Europe         Germany 2021-07-27    3758401.0
# 519         AFG           Asia     Afghanistan 2021-07-27     145008.0
# 120943      NAM         Africa         Namibia 2021-07-27     117293.0
# 119314      MOZ         Africa      Mozambique 2021-07-27     113426.0
# 35464       CHL  South America           Chile 2021-07-27    1611090.0
# 61710       FRA         Europe          France 2021-07-27    6068988.0
# 106377      MWI         Africa          Malawi 2021-07-27      49752.0
# 118501      MAR         Africa         Morocco 2021-07-27     588448.0
# 3048        DZA         Africa         Algeria 2021-07-27     165204.0
# 87263       ITA         Europe           Italy 2021-07-27    4325046.0
# 99663       LBY         Africa           Libya 2021-07-27     240309.0
# 192339      ZMB         Africa          Zambia 2021-07-27     192956.0
# 122182      NPL           Asia           Nepal 2021-07-27     685673.0
# 29649       KHM           Asia        Cambodia 2021-07-27      74386.0
# 133109      OMN           Asia            Oman 2021-07-27     295017.0
# 65009       GEO           Asia         Georgia 2021-07-27     407689.0
# 188380      VEN  South America       Venezuela 2021-07-27     301979.0
# 116009      MNG           Asia        Mongolia 2021-07-27     159101.0
# 94761       KGZ           Asia      Kyrgyzstan 2021-07-27     159089.0
#
#         new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 81363     45203.0           41411.143       86835.0      2069.0
# 24692     43591.0           47082.000      552128.0      1289.0
# 144349    22486.0           23207.714      152836.0       767.0
# 80530     43654.0           38324.000      422022.0       640.0
# 113014    17408.0           13364.143      239079.0       484.0
# 182832    65003.0           60879.286      607735.0       451.0
# 83065     34951.0           26007.000       89479.0       357.0
# 120122     4964.0            5507.000        7845.0       338.0
# 160642     7733.0           11427.286       70338.0       320.0
# 37166     11426.0           11289.286      119482.0       300.0
# 14803     14925.0            9409.000       19779.0       258.0
# 7219      16757.0           13101.143      104352.0       247.0
# 107248    16117.0           14881.714        8408.0       207.0
# 176236     1608.0            2870.143       18968.0       164.0
# 181959    23330.0           32464.571      129389.0       131.0
# 172407    14150.0           14336.143        4264.0       118.0
# 193154     1767.0            1899.429        3280.0       107.0
# 138371     1366.0            1479.714      196058.0        85.0
# 42463      7903.0            7800.857        2492.0        75.0
# 139236     7024.0            6359.571       27318.0        71.0
# 83905     12185.0            9499.429       18418.0        71.0
# 21417      1601.0             985.571       17716.0        65.0
# 71664      2639.0            2494.429       10176.0        64.0
# 77125      1240.0            1285.857        7713.0        63.0
# 137542      592.0             603.857       14759.0        58.0
# 164019    26399.0           25616.714       81323.0        55.0
# 177060    19761.0           13144.571       51048.0        51.0
# 164887     1711.0            1702.714        4195.0        48.0
# 133948     4119.0            2768.000       23133.0        46.0
# 39977      3436.0            1129.857        4987.0        46.0
# 180229     1227.0            1127.286       55420.0        39.0
# 65877      1545.0            1713.000       91565.0        38.0
# 519         723.0             370.571        6515.0        38.0
# 120943      329.0             550.714        2871.0        37.0
# 119314     1703.0            1631.000        1341.0        34.0
# 35464       745.0            1318.857       35151.0        32.0
# 61710     27024.0           19467.143      111727.0        28.0
# 106377      743.0             724.000        1540.0        27.0
# 118501     6971.0            3718.857        9638.0        27.0
# 3048       1544.0            1345.714        4112.0        25.0
# 87263      4516.0            4566.143      127995.0        24.0
# 99663      3348.0            1944.000        3422.0        24.0
# 192339      640.0             764.857        3316.0        21.0
# 122182     2726.0            2102.857        9758.0        20.0
# 29649       685.0             798.571        1324.0        19.0
# 133109      491.0             853.571        3788.0        17.0
# 65009      3666.0            2392.000        5731.0        17.0
# 188380     1060.0            1159.000        3524.0        15.0
# 116009     1127.0            1124.429         796.0        14.0
# 94761       969.0            1068.857        2275.0        14.0
#
#         new_deaths_smoothed  ...  female_smokers  male_smokers  \
# 81363              1519.286  ...             2.8          76.1
# 24692              1085.143  ...            10.1          17.9
# 144349              768.429  ...            23.4          58.3
# 80530               506.000  ...             1.9          20.6
# 113014              324.143  ...             6.9          21.4
# 182832              306.286  ...            19.1          24.6
# 83065               265.000  ...             0.8          21.1
# 120122              325.429  ...             6.3          35.2
# 160642              380.286  ...             8.1          33.2
# 37166               335.857  ...             4.7          13.5
# 14803               207.714  ...             1.0          44.7
# 7219                281.571  ...            16.2          27.7
# 107248              166.714  ...             1.0          42.4
# 176236              163.857  ...             1.1          65.8
# 181959               68.571  ...            20.0          24.7
# 172407              108.857  ...             1.9          38.8
# 193154               76.143  ...             1.6          30.7
# 138371              103.714  ...             4.8           NaN
# 42463                67.571  ...            17.1          53.3
# 139236               67.714  ...             7.8          40.8
# 83905                66.714  ...             NaN           NaN
# 21417                34.429  ...             NaN           NaN
# 71664                35.571  ...             NaN           NaN
# 77125                29.429  ...             2.0           NaN
# 137542               52.143  ...             5.0          21.6
# 164019               25.000  ...            27.4          31.4
# 177060               56.857  ...            14.1          41.1
# 164887               46.429  ...             0.3          27.0
# 133948               35.000  ...             2.8          36.7
# 39977                10.286  ...             6.4          17.4
# 180229               28.429  ...            13.5          47.4
# 65877                24.000  ...            28.2          33.1
# 519                  35.571  ...             NaN           NaN
# 120943               44.857  ...             9.7          34.2
# 119314               26.143  ...             5.1          29.1
# 35464                83.143  ...            34.2          41.5
# 61710                24.429  ...            30.1          35.6
# 106377               25.286  ...             4.4          24.7
# 118501               21.714  ...             0.8          47.1
# 3048                 19.000  ...             0.7          30.4
# 87263                15.857  ...            19.8          27.8
# 99663                16.143  ...             NaN           NaN
# 192339               25.429  ...             3.1          24.7
# 122182               21.571  ...             9.5          37.8
# 29649                25.000  ...             2.0          33.7
# 133109               41.429  ...             0.5          15.6
# 65009                19.857  ...             5.3          55.5
# 188380               18.857  ...             NaN           NaN
# 116009                7.286  ...             5.5          46.5
# 94761                11.286  ...             3.6          50.5
#
#         handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 81363                   64.204                        1.04            71.72
# 24692                      NaN                        2.20            75.88
# 144349                     NaN                        8.05            72.58
# 80530                   59.550                        0.53            69.66
# 113014                  87.847                        1.38            75.05
# 182832                     NaN                        2.77            78.86
# 83065                      NaN                        1.50            76.68
# 120122                  79.287                        0.90            67.13
# 160642                  43.993                        2.32            64.13
# 37166                   65.386                        1.71            77.29
# 14803                   34.808                        0.80            72.59
# 7219                       NaN                        5.00            76.67
# 107248                     NaN                        1.90            76.16
# 176236                  78.687                        2.30            76.70
# 181959                     NaN                        2.54            81.32
# 172407                  90.670                        2.10            77.15
# 193154                  36.791                        1.70            61.49
# 138371                     NaN                        1.60            76.74
# 42463                   85.198                        5.20            78.80
# 139236                  78.463                        1.00            71.23
# 83905                   94.576                        1.40            70.60
# 21417                   25.383                        1.10            71.51
# 71664                   76.665                        0.60            74.30
# 77125                   84.169                        0.70            75.27
# 137542                  79.602                        1.30            74.25
# 164019                     NaN                        2.97            83.56
# 177060                     NaN                        2.81            77.69
# 164887                     NaN                        3.60            76.98
# 133948                  59.607                        0.60            67.27
# 39977                   83.841                        1.13            80.28
# 180229                     NaN                        8.80            72.06
# 65877                      NaN                        8.00            81.33
# 519                     37.746                        0.50            64.83
# 120943                  44.600                         NaN            63.71
# 119314                  12.227                        0.70            60.85
# 35464                      NaN                        2.11            80.18
# 61710                      NaN                        5.98            82.66
# 106377                   8.704                        1.30            64.26
# 118501                     NaN                        1.10            76.68
# 3048                    83.741                        1.90            76.88
# 87263                      NaN                        3.18            83.51
# 99663                      NaN                        3.70            72.91
# 192339                  13.938                        2.00            63.89
# 122182                  47.782                        0.30            70.78
# 29649                   66.229                        0.80            69.82
# 133109                  97.400                        1.60            77.86
# 65009                      NaN                        2.60            73.77
# 188380                     NaN                        0.80            72.06
# 116009                  71.180                        7.00            69.87
# 94761                   89.220                        4.50            71.45
#
#         human_development_index  excess_mortality_cumulative_absolute  \
# 81363                     0.718                                   NaN
# 24692                     0.765                                   NaN
# 144349                    0.824                                   NaN
# 80530                     0.645                                   NaN
# 113014                    0.779                                   NaN
# 182832                    0.926                                   NaN
# 83065                     0.783                                   NaN
# 120122                    0.583                                   NaN
# 160642                    0.709                                   NaN
# 37166                     0.767                                   NaN
# 14803                     0.632                                   NaN
# 7219                      0.845                                   NaN
# 107248                    0.810                                   NaN
# 176236                    0.740                                   NaN
# 181959                    0.932                                   NaN
# 172407                    0.777                                   NaN
# 193154                    0.571                                   NaN
# 138371                    0.777                                   NaN
# 42463                     0.783                                   NaN
# 139236                    0.718                                   NaN
# 83905                     0.674                                   NaN
# 21417                     0.718                                   NaN
# 71664                     0.663                                   NaN
# 77125                     0.634                                   NaN
# 137542                    0.728                                   NaN
# 164019                    0.904                                   NaN
# 177060                    0.820                                   NaN
# 164887                    0.782                                   NaN
# 133948                    0.557                                   NaN
# 39977                     0.810                                   NaN
# 180229                    0.779                                   NaN
# 65877                     0.947                                   NaN
# 519                       0.511                                   NaN
# 120943                    0.646                                   NaN
# 119314                    0.456                                   NaN
# 35464                     0.851                                   NaN
# 61710                     0.901                                   NaN
# 106377                    0.483                                   NaN
# 118501                    0.686                                   NaN
# 3048                      0.748                                   NaN
# 87263                     0.892                                   NaN
# 99663                     0.724                                   NaN
# 192339                    0.584                                   NaN
# 122182                    0.602                                   NaN
# 29649                     0.594                                   NaN
# 133109                    0.813                                   NaN
# 65009                     0.812                                   NaN
# 188380                    0.711                                   NaN
# 116009                    0.737                                   NaN
# 94761                     0.697                                   NaN
#
#         excess_mortality_cumulative  excess_mortality  \
# 81363                           NaN               NaN
# 24692                           NaN               NaN
# 144349                          NaN               NaN
# 80530                           NaN               NaN
# 113014                          NaN               NaN
# 182832                          NaN               NaN
# 83065                           NaN               NaN
# 120122                          NaN               NaN
# 160642                          NaN               NaN
# 37166                           NaN               NaN
# 14803                           NaN               NaN
# 7219                            NaN               NaN
# 107248                          NaN               NaN
# 176236                          NaN               NaN
# 181959                          NaN               NaN
# 172407                          NaN               NaN
# 193154                          NaN               NaN
# 138371                          NaN               NaN
# 42463                           NaN               NaN
# 139236                          NaN               NaN
# 83905                           NaN               NaN
# 21417                           NaN               NaN
# 71664                           NaN               NaN
# 77125                           NaN               NaN
# 137542                          NaN               NaN
# 164019                          NaN               NaN
# 177060                          NaN               NaN
# 164887                          NaN               NaN
# 133948                          NaN               NaN
# 39977                           NaN               NaN
# 180229                          NaN               NaN
# 65877                           NaN               NaN
# 519                             NaN               NaN
# 120943                          NaN               NaN
# 119314                          NaN               NaN
# 35464                           NaN               NaN
# 61710                           NaN               NaN
# 106377                          NaN               NaN
# 118501                          NaN               NaN
# 3048                            NaN               NaN
# 87263                           NaN               NaN
# 99663                           NaN               NaN
# 192339                          NaN               NaN
# 122182                          NaN               NaN
# 29649                           NaN               NaN
# 133109                          NaN               NaN
# 65009                           NaN               NaN
# 188380                          NaN               NaN
# 116009                          NaN               NaN
# 94761                           NaN               NaN
#
#         excess_mortality_cumulative_per_million
# 81363                                       NaN
# 24692                                       NaN
# 144349                                      NaN
# 80530                                       NaN
# 113014                                      NaN
# 182832                                      NaN
# 83065                                       NaN
# 120122                                      NaN
# 160642                                      NaN
# 37166                                       NaN
# 14803                                       NaN
# 7219                                        NaN
# 107248                                      NaN
# 176236                                      NaN
# 181959                                      NaN
# 172407                                      NaN
# 193154                                      NaN
# 138371                                      NaN
# 42463                                       NaN
# 139236                                      NaN
# 83905                                       NaN
# 21417                                       NaN
# 71664                                       NaN
# 77125                                       NaN
# 137542                                      NaN
# 164019                                      NaN
# 177060                                      NaN
# 164887                                      NaN
# 133948                                      NaN
# 39977                                       NaN
# 180229                                      NaN
# 65877                                       NaN
# 519                                         NaN
# 120943                                      NaN
# 119314                                      NaN
# 35464                                       NaN
# 61710                                       NaN
# 106377                                      NaN
# 118501                                      NaN
# 3048                                        NaN
# 87263                                       NaN
# 99663                                       NaN
# 192339                                      NaN
# 122182                                      NaN
# 29649                                       NaN
# 133109                                      NaN
# 65009                                       NaN
# 188380                                      NaN
# 116009                                      NaN
# 94761                                       NaN
#
# [50 rows x 67 columns]

# %%
c_df.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'total_tests', 'new_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'total_boosters',
#        'new_vaccinations', 'new_vaccinations_smoothed',
#        'total_vaccinations_per_hundred', 'people_vaccinated_per_hundred',
#        'people_fully_vaccinated_per_hundred', 'total_boosters_per_hundred',
#        'new_vaccinations_smoothed_per_million',
#        'new_people_vaccinated_smoothed',
#        'new_people_vaccinated_smoothed_per_hundred', 'stringency_index',
#        'population', 'population_density', 'median_age', 'aged_65_older',
#        'aged_70_older', 'gdp_per_capita', 'extreme_poverty',
#        'cardiovasc_death_rate', 'diabetes_prevalence', 'female_smokers',
#        'male_smokers', 'handwashing_facilities', 'hospital_beds_per_thousand',
#        'life_expectancy', 'human_development_index',
#        'excess_mortality_cumulative_absolute', 'excess_mortality_cumulative',
#        'excess_mortality', 'excess_mortality_cumulative_per_million'],
#       dtype='object')
