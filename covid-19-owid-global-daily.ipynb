# %%
import pandas as pd

# %%
df = pd.read_csv("covid-19-data/public/data/owid-covid-data.csv")
df.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1      AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    female_smokers  male_smokers  handwashing_facilities  \
# 0             NaN           NaN                  37.746
# 1             NaN           NaN                  37.746
# 2             NaN           NaN                  37.746
# 3             NaN           NaN                  37.746
# 4             NaN           NaN                  37.746
#
#    hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                         0.5            64.83                    0.511
# 1                         0.5            64.83                    0.511
# 2                         0.5            64.83                    0.511
# 3                         0.5            64.83                    0.511
# 4                         0.5            64.83                    0.511
#
#    excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                   NaN                          NaN
# 1                                   NaN                          NaN
# 2                                   NaN                          NaN
# 3                                   NaN                          NaN
# 4                                   NaN                          NaN
#
#    excess_mortality  excess_mortality_cumulative_per_million
# 0               NaN                                      NaN
# 1               NaN                                      NaN
# 2               NaN                                      NaN
# 3               NaN                                      NaN
# 4               NaN                                      NaN
#
# [5 rows x 67 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 189490 entries, 0 to 189489
# Data columns (total 67 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   iso_code                                    189490 non-null  object
#  1   continent                                   178468 non-null  object
#  2   location                                    189490 non-null  object
#  3   date                                        189490 non-null  object
#  4   total_cases                                 182002 non-null  float64
#  5   new_cases                                   181799 non-null  float64
#  6   new_cases_smoothed                          180625 non-null  float64
#  7   total_deaths                                163584 non-null  float64
#  8   new_deaths                                  163588 non-null  float64
#  9   new_deaths_smoothed                         162426 non-null  float64
#  10  total_cases_per_million                     181162 non-null  float64
#  11  new_cases_per_million                       180959 non-null  float64
#  12  new_cases_smoothed_per_million              179790 non-null  float64
#  13  total_deaths_per_million                    162757 non-null  float64
#  14  new_deaths_per_million                      162761 non-null  float64
#  15  new_deaths_smoothed_per_million             161604 non-null  float64
#  16  reproduction_rate                           140710 non-null  float64
#  17  icu_patients                                25287 non-null   float64
#  18  icu_patients_per_million                    25287 non-null   float64
#  19  hosp_patients                               26547 non-null   float64
#  20  hosp_patients_per_million                   26547 non-null   float64
#  21  weekly_icu_admissions                       6147 non-null    float64
#  22  weekly_icu_admissions_per_million           6147 non-null    float64
#  23  weekly_hosp_admissions                      12266 non-null   float64
#  24  weekly_hosp_admissions_per_million          12266 non-null   float64
#  25  total_tests                                 77125 non-null   float64
#  26  new_tests                                   73556 non-null   float64
#  27  total_tests_per_thousand                    77125 non-null   float64
#  28  new_tests_per_thousand                      73556 non-null   float64
#  29  new_tests_smoothed                          99918 non-null   float64
#  30  new_tests_smoothed_per_thousand             99918 non-null   float64
#  31  positive_rate                               92182 non-null   float64
#  32  tests_per_case                              90545 non-null   float64
#  33  tests_units                                 102647 non-null  object
#  34  total_vaccinations                          51747 non-null   float64
#  35  people_vaccinated                           49304 non-null   float64
#  36  people_fully_vaccinated                     46753 non-null   float64
#  37  total_boosters                              23860 non-null   float64
#  38  new_vaccinations                            42381 non-null   float64
#  39  new_vaccinations_smoothed                   102201 non-null  float64
#  40  total_vaccinations_per_hundred              51747 non-null   float64
#  41  people_vaccinated_per_hundred               49304 non-null   float64
#  42  people_fully_vaccinated_per_hundred         46753 non-null   float64
#  43  total_boosters_per_hundred                  23860 non-null   float64
#  44  new_vaccinations_smoothed_per_million       102201 non-null  float64
#  45  new_people_vaccinated_smoothed              101194 non-null  float64
#  46  new_people_vaccinated_smoothed_per_hundred  101194 non-null  float64
#  47  stringency_index                            147585 non-null  float64
#  48  population                                  188333 non-null  float64
#  49  population_density                          168852 non-null  float64
#  50  median_age                                  156499 non-null  float64
#  51  aged_65_older                               154840 non-null  float64
#  52  aged_70_older                               155678 non-null  float64
#  53  gdp_per_capita                              155661 non-null  float64
#  54  extreme_poverty                             101625 non-null  float64
#  55  cardiovasc_death_rate                       156147 non-null  float64
#  56  diabetes_prevalence                         163776 non-null  float64
#  57  female_smokers                              118100 non-null  float64
#  58  male_smokers                                116481 non-null  float64
#  59  handwashing_facilities                      76717 non-null   float64
#  60  hospital_beds_per_thousand                  138546 non-null  float64
#  61  life_expectancy                             177204 non-null  float64
#  62  human_development_index                     152109 non-null  float64
#  63  excess_mortality_cumulative_absolute        6525 non-null    float64
#  64  excess_mortality_cumulative                 6525 non-null    float64
#  65  excess_mortality                            6525 non-null    float64
#  66  excess_mortality_cumulative_per_million     6525 non-null    float64
# dtypes: float64(62), object(5)
# memory usage: 96.9+ MB

# %%
df.describe()
# Out:
#         total_cases     new_cases  new_cases_smoothed  total_deaths  \
# count  1.820020e+05  1.817990e+05        1.806250e+05  1.635840e+05
# mean   3.230759e+06  1.237368e+04        1.241256e+04  6.418977e+04
# std    2.027619e+07  8.754872e+04        8.600721e+04  3.346718e+05
# min    1.000000e+00  0.000000e+00        0.000000e+00  1.000000e+00
# 25%    2.629000e+03  0.000000e+00        6.714000e+00  9.300000e+01
# 50%    3.469300e+04  7.200000e+01        1.017140e+02  9.090000e+02
# 75%    3.730992e+05  1.036000e+03        1.143429e+03  8.357000e+03
# max    5.278394e+08  4.079827e+06        3.437214e+06  6.284533e+06
#
#           new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  163588.000000        162426.000000            181162.000000
# mean      159.331876           160.291333             40428.192813
# std       794.199273           777.643046             75195.719415
# min         0.000000             0.000000                 0.001000
# 25%         0.000000             0.143000               772.702500
# 50%         1.000000             2.143000              6248.384500
# 75%        18.000000            19.429000             50277.595500
# max     18151.000000         14795.286000            706541.904000
#
#        new_cases_per_million  new_cases_smoothed_per_million  \
# count          180959.000000                    179790.00000
# mean              185.925128                       186.02452
# std               950.200972                       618.81225
# min                 0.000000                         0.00000
# 25%                 0.000000                         1.51200
# 50%                10.419000                        19.13550
# 75%               102.157500                       128.57950
# max            208049.887000                     37617.42800
#
#        total_deaths_per_million  ...  female_smokers   male_smokers  \
# count             162757.000000  ...   118100.000000  116481.000000
# mean                 581.850590  ...       10.644527      32.791185
# std                  866.792195  ...       10.581613      13.528975
# min                    0.000000  ...        0.100000       7.700000
# 25%                   22.968000  ...        1.900000      21.600000
# 50%                  163.167000  ...        6.300000      31.400000
# 75%                  835.020000  ...       19.300000      41.300000
# max                 6389.351000  ...       44.000000      78.100000
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# count            76717.000000               138546.000000    177204.000000
# mean                50.930331                    3.068724        73.650006
# std                 31.857840                    2.519856         7.449914
# min                  1.188000                    0.100000        53.280000
# 25%                 20.859000                    1.300000        69.500000
# 50%                 49.839000                    2.400000        75.050000
# 75%                 83.241000                    4.000000        79.070000
# max                100.000000                   13.800000        86.750000
#
#        human_development_index  excess_mortality_cumulative_absolute  \
# count            152109.000000                          6.525000e+03
# mean                  0.725242                          4.078743e+04
# std                   0.149734                          1.132332e+05
# min                   0.394000                         -3.772610e+04
# 25%                   0.602000                         -1.460000e+01
# 50%                   0.743000                          4.237200e+03
# 75%                   0.845000                          2.783340e+04
# max                   0.957000                          1.213593e+06
#
#        excess_mortality_cumulative  excess_mortality  \
# count                  6525.000000       6525.000000
# mean                      9.766654         15.598670
# std                      16.036976         28.984741
# min                     -28.450000        -95.920000
# 25%                      -0.170000         -0.300000
# 50%                       6.560000          7.440000
# 75%                      14.680000         21.880000
# max                     111.010000        375.000000
#
#        excess_mortality_cumulative_per_million
# count                              6525.000000
# mean                               1114.211895
# std                                1561.732319
# min                               -1826.595723
# 25%                                  -7.321200
# 50%                                 569.657043
# 75%                                1784.551578
# max                                9725.192865
#
# [8 rows x 62 columns]

# %%
df.continent.unique()
# Out:
# array(['Asia', nan, 'Europe', 'Africa', 'North America', 'South America',
#        'Oceania'], dtype=object)

# %%
df.loc[df.continent.isna()].location.unique()
# Out:
# array(['Africa', 'Asia', 'Europe', 'European Union', 'High income',
#        'International', 'Low income', 'Lower middle income',
#        'North America', 'Oceania', 'South America', 'Upper middle income',
#        'World'], dtype=object)

# %%
df.loc[df.location=="International"]
# Out:
#        iso_code continent       location        date  total_cases  new_cases  \
# 80006  OWID_INT       NaN  International  2020-02-07         61.0       61.0
# 80007  OWID_INT       NaN  International  2020-02-08         61.0        0.0
# 80008  OWID_INT       NaN  International  2020-02-09         64.0        3.0
# 80009  OWID_INT       NaN  International  2020-02-10        135.0       71.0
# 80010  OWID_INT       NaN  International  2020-02-11        135.0        0.0
# ...         ...       ...            ...         ...          ...        ...
# 80841  OWID_INT       NaN  International  2022-05-22        721.0        0.0
# 80842  OWID_INT       NaN  International  2022-05-23        721.0        0.0
# 80843  OWID_INT       NaN  International  2022-05-24        721.0        0.0
# 80844  OWID_INT       NaN  International  2022-05-25        721.0        0.0
# 80845  OWID_INT       NaN  International  2022-05-26        721.0        0.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 80006                 NaN           NaN         NaN                  NaN  ...
# 80007                 NaN           NaN         NaN                  NaN  ...
# 80008                 NaN           NaN         NaN                  NaN  ...
# 80009                 NaN           NaN         NaN                  NaN  ...
# 80010                 NaN           NaN         NaN                  NaN  ...
# ...                   ...           ...         ...                  ...  ...
# 80841                 0.0          15.0         0.0                  0.0  ...
# 80842                 0.0          15.0         0.0                  0.0  ...
# 80843                 0.0          15.0         0.0                  0.0  ...
# 80844                 0.0          15.0         0.0                  0.0  ...
# 80845                 0.0          15.0         0.0                  0.0  ...
#
#        female_smokers  male_smokers  handwashing_facilities  \
# 80006             NaN           NaN                     NaN
# 80007             NaN           NaN                     NaN
# 80008             NaN           NaN                     NaN
# 80009             NaN           NaN                     NaN
# 80010             NaN           NaN                     NaN
# ...               ...           ...                     ...
# 80841             NaN           NaN                     NaN
# 80842             NaN           NaN                     NaN
# 80843             NaN           NaN                     NaN
# 80844             NaN           NaN                     NaN
# 80845             NaN           NaN                     NaN
#
#        hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 80006                         NaN              NaN                      NaN
# 80007                         NaN              NaN                      NaN
# 80008                         NaN              NaN                      NaN
# 80009                         NaN              NaN                      NaN
# 80010                         NaN              NaN                      NaN
# ...                           ...              ...                      ...
# 80841                         NaN              NaN                      NaN
# 80842                         NaN              NaN                      NaN
# 80843                         NaN              NaN                      NaN
# 80844                         NaN              NaN                      NaN
# 80845                         NaN              NaN                      NaN
#
#        excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 80006                                   NaN                          NaN
# 80007                                   NaN                          NaN
# 80008                                   NaN                          NaN
# 80009                                   NaN                          NaN
# 80010                                   NaN                          NaN
# ...                                     ...                          ...
# 80841                                   NaN                          NaN
# 80842                                   NaN                          NaN
# 80843                                   NaN                          NaN
# 80844                                   NaN                          NaN
# 80845                                   NaN                          NaN
#
#        excess_mortality  excess_mortality_cumulative_per_million
# 80006               NaN                                      NaN
# 80007               NaN                                      NaN
# 80008               NaN                                      NaN
# 80009               NaN                                      NaN
# 80010               NaN                                      NaN
# ...                 ...                                      ...
# 80841               NaN                                      NaN
# 80842               NaN                                      NaN
# 80843               NaN                                      NaN
# 80844               NaN                                      NaN
# 80845               NaN                                      NaN
#
# [840 rows x 67 columns]

# %%
df.location.unique()
# Out:
# array(['Afghanistan', 'Africa', 'Albania', 'Algeria', 'Andorra', 'Angola',
#        'Anguilla', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        'Asia', 'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain',
#        'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin',
#        'Bermuda', 'Bhutan', 'Bolivia', 'Bonaire Sint Eustatius and Saba',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Brunei', 'Bulgaria', 'Burkina Faso',
#        'Burundi', 'Cambodia', 'Cameroon', 'Canada', 'Cape Verde',
#        'Cayman Islands', 'Central African Republic', 'Chad', 'Chile',
#        'China', 'Colombia', 'Comoros', 'Congo', 'Cook Islands',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Curacao',
#        'Cyprus', 'Czechia', 'Democratic Republic of Congo', 'Denmark',
#        'Djibouti', 'Dominica', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Estonia',
#        'Eswatini', 'Ethiopia', 'Europe', 'European Union',
#        'Faeroe Islands', 'Falkland Islands', 'Fiji', 'Finland', 'France',
#        'French Polynesia', 'Gabon', 'Gambia', 'Georgia', 'Germany',
#        'Ghana', 'Gibraltar', 'Greece', 'Greenland', 'Grenada', 'Guam',
#        'Guatemala', 'Guernsey', 'Guinea', 'Guinea-Bissau', 'Guyana',
#        'Haiti', 'High income', 'Honduras', 'Hong Kong', 'Hungary',
#        'Iceland', 'India', 'Indonesia', 'International', 'Iran', 'Iraq',
#        'Ireland', 'Isle of Man', 'Israel', 'Italy', 'Jamaica', 'Japan',
#        'Jersey', 'Jordan', 'Kazakhstan', 'Kenya', 'Kiribati', 'Kosovo',
#        'Kuwait', 'Kyrgyzstan', 'Laos', 'Latvia', 'Lebanon', 'Lesotho',
#        'Liberia', 'Libya', 'Liechtenstein', 'Lithuania', 'Low income',
#        'Lower middle income', 'Luxembourg', 'Macao', 'Madagascar',
#        'Malawi', 'Malaysia', 'Maldives', 'Mali', 'Malta',
#        'Marshall Islands', 'Mauritania', 'Mauritius', 'Mexico',
#        'Micronesia (country)', 'Moldova', 'Monaco', 'Mongolia',
#        'Montenegro', 'Montserrat', 'Morocco', 'Mozambique', 'Myanmar',
#        'Namibia', 'Nauru', 'Nepal', 'Netherlands', 'New Caledonia',
#        'New Zealand', 'Nicaragua', 'Niger', 'Nigeria', 'Niue',
#        'North America', 'North Korea', 'North Macedonia',
#        'Northern Cyprus', 'Northern Mariana Islands', 'Norway', 'Oceania',
#        'Oman', 'Pakistan', 'Palau', 'Palestine', 'Panama',
#        'Papua New Guinea', 'Paraguay', 'Peru', 'Philippines', 'Pitcairn',
#        'Poland', 'Portugal', 'Puerto Rico', 'Qatar', 'Romania', 'Russia',
#        'Rwanda', 'Saint Helena', 'Saint Kitts and Nevis', 'Saint Lucia',
#        'Saint Pierre and Miquelon', 'Saint Vincent and the Grenadines',
#        'Samoa', 'San Marino', 'Sao Tome and Principe', 'Saudi Arabia',
#        'Senegal', 'Serbia', 'Seychelles', 'Sierra Leone', 'Singapore',
#        'Sint Maarten (Dutch part)', 'Slovakia', 'Slovenia',
#        'Solomon Islands', 'Somalia', 'South Africa', 'South America',
#        'South Korea', 'South Sudan', 'Spain', 'Sri Lanka', 'Sudan',
#        'Suriname', 'Sweden', 'Switzerland', 'Syria', 'Taiwan',
#        'Tajikistan', 'Tanzania', 'Thailand', 'Timor', 'Togo', 'Tokelau',
#        'Tonga', 'Trinidad and Tobago', 'Tunisia', 'Turkey',
#        'Turkmenistan', 'Turks and Caicos Islands', 'Tuvalu', 'Uganda',
#        'Ukraine', 'United Arab Emirates', 'United Kingdom',
#        'United States', 'United States Virgin Islands',
#        'Upper middle income', 'Uruguay', 'Uzbekistan', 'Vanuatu',
#        'Vatican', 'Venezuela', 'Vietnam', 'Wallis and Futuna',
#        'Western Sahara', 'World', 'Yemen', 'Zambia', 'Zimbabwe'],
#       dtype=object)

# %%
df["date"] = pd.to_datetime(df["date"])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 189490 entries, 0 to 189489
# Data columns (total 67 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   iso_code                                    189490 non-null  object
#  1   continent                                   178468 non-null  object
#  2   location                                    189490 non-null  object
#  3   date                                        189490 non-null  datetime64[ns]
#  4   total_cases                                 182002 non-null  float64
#  5   new_cases                                   181799 non-null  float64
#  6   new_cases_smoothed                          180625 non-null  float64
#  7   total_deaths                                163584 non-null  float64
#  8   new_deaths                                  163588 non-null  float64
#  9   new_deaths_smoothed                         162426 non-null  float64
#  10  total_cases_per_million                     181162 non-null  float64
#  11  new_cases_per_million                       180959 non-null  float64
#  12  new_cases_smoothed_per_million              179790 non-null  float64
#  13  total_deaths_per_million                    162757 non-null  float64
#  14  new_deaths_per_million                      162761 non-null  float64
#  15  new_deaths_smoothed_per_million             161604 non-null  float64
#  16  reproduction_rate                           140710 non-null  float64
#  17  icu_patients                                25287 non-null   float64
#  18  icu_patients_per_million                    25287 non-null   float64
#  19  hosp_patients                               26547 non-null   float64
#  20  hosp_patients_per_million                   26547 non-null   float64
#  21  weekly_icu_admissions                       6147 non-null    float64
#  22  weekly_icu_admissions_per_million           6147 non-null    float64
#  23  weekly_hosp_admissions                      12266 non-null   float64
#  24  weekly_hosp_admissions_per_million          12266 non-null   float64
#  25  total_tests                                 77125 non-null   float64
#  26  new_tests                                   73556 non-null   float64
#  27  total_tests_per_thousand                    77125 non-null   float64
#  28  new_tests_per_thousand                      73556 non-null   float64
#  29  new_tests_smoothed                          99918 non-null   float64
#  30  new_tests_smoothed_per_thousand             99918 non-null   float64
#  31  positive_rate                               92182 non-null   float64
#  32  tests_per_case                              90545 non-null   float64
#  33  tests_units                                 102647 non-null  object
#  34  total_vaccinations                          51747 non-null   float64
#  35  people_vaccinated                           49304 non-null   float64
#  36  people_fully_vaccinated                     46753 non-null   float64
#  37  total_boosters                              23860 non-null   float64
#  38  new_vaccinations                            42381 non-null   float64
#  39  new_vaccinations_smoothed                   102201 non-null  float64
#  40  total_vaccinations_per_hundred              51747 non-null   float64
#  41  people_vaccinated_per_hundred               49304 non-null   float64
#  42  people_fully_vaccinated_per_hundred         46753 non-null   float64
#  43  total_boosters_per_hundred                  23860 non-null   float64
#  44  new_vaccinations_smoothed_per_million       102201 non-null  float64
#  45  new_people_vaccinated_smoothed              101194 non-null  float64
#  46  new_people_vaccinated_smoothed_per_hundred  101194 non-null  float64
#  47  stringency_index                            147585 non-null  float64
#  48  population                                  188333 non-null  float64
#  49  population_density                          168852 non-null  float64
#  50  median_age                                  156499 non-null  float64
#  51  aged_65_older                               154840 non-null  float64
#  52  aged_70_older                               155678 non-null  float64
#  53  gdp_per_capita                              155661 non-null  float64
#  54  extreme_poverty                             101625 non-null  float64
#  55  cardiovasc_death_rate                       156147 non-null  float64
#  56  diabetes_prevalence                         163776 non-null  float64
#  57  female_smokers                              118100 non-null  float64
#  58  male_smokers                                116481 non-null  float64
#  59  handwashing_facilities                      76717 non-null   float64
#  60  hospital_beds_per_thousand                  138546 non-null  float64
#  61  life_expectancy                             177204 non-null  float64
#  62  human_development_index                     152109 non-null  float64
#  63  excess_mortality_cumulative_absolute        6525 non-null    float64
#  64  excess_mortality_cumulative                 6525 non-null    float64
#  65  excess_mortality                            6525 non-null    float64
#  66  excess_mortality_cumulative_per_million     6525 non-null    float64
# dtypes: datetime64[ns](1), float64(62), object(4)
# memory usage: 96.9+ MB

# %% [markdown]
# ## 最新日付チェック

# %%
import datetime
#latest_date_str = (df.date.max()-datetime.timedelta(days=1)).strftime("%Y-%m-%d")
latest_date_str = df.date.max().strftime("%Y-%m-%d")
latest_date_str
# Out:
# '2022-05-26'

# %% [markdown]
# ## 全世界のデータのみ

# %%
world_df = df.copy().loc[df.location=="World"]
world_df.tail()
# Out:
#         iso_code continent location       date  total_cases  new_cases  \
# 187110  OWID_WRL       NaN    World 2022-05-22  525610716.0   337962.0
# 187111  OWID_WRL       NaN    World 2022-05-23  526095455.0   514392.0
# 187112  OWID_WRL       NaN    World 2022-05-24  526707203.0   611748.0
# 187113  OWID_WRL       NaN    World 2022-05-25  527349857.0   642654.0
# 187114  OWID_WRL       NaN    World 2022-05-26  527839364.0   494015.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 187110          550638.857     6277245.0       640.0             1658.429
# 187111          537245.571     6278676.0      1432.0             1612.429
# 187112          539597.429     6280424.0      1753.0             1590.286
# 187113          525451.571     6283065.0      2642.0             1627.571
# 187114          511715.429     6284533.0      1553.0             1587.000
#
#         ...  female_smokers  male_smokers  handwashing_facilities  \
# 187110  ...           6.434        34.635                   60.13
# 187111  ...           6.434        34.635                   60.13
# 187112  ...           6.434        34.635                   60.13
# 187113  ...           6.434        34.635                   60.13
# 187114  ...           6.434        34.635                   60.13
#
#         hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 187110                       2.705            72.58                    0.737
# 187111                       2.705            72.58                    0.737
# 187112                       2.705            72.58                    0.737
# 187113                       2.705            72.58                    0.737
# 187114                       2.705            72.58                    0.737
#
#         excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 187110                                   NaN                          NaN
# 187111                                   NaN                          NaN
# 187112                                   NaN                          NaN
# 187113                                   NaN                          NaN
# 187114                                   NaN                          NaN
#
#         excess_mortality  excess_mortality_cumulative_per_million
# 187110               NaN                                      NaN
# 187111               NaN                                      NaN
# 187112               NaN                                      NaN
# 187113               NaN                                      NaN
# 187114               NaN                                      NaN
#
# [5 rows x 67 columns]

# %% [markdown]
# ### 主要国の定義

# %%
countries = pd.DataFrame([
    ("Japan",""),
    ("United States",""),
    ("Germany",""),
#    ("India",""),
#    ("Indonesia",""),
#    ("Spain",""),
    ("Brazil",""),
    ("France",""),
    ("United Kingdom",""),
    ("Russia",""),
    ("Turkey",""),
#    ("South Africa",""),
#    ("Iran",""),
    ("Poland",""),
#    ("Ecuador",""),
],columns=["country","text_disp_date"])
countries
# Out:
#           country text_disp_date
# 0           Japan
# 1   United States
# 2         Germany
# 3          Brazil
# 4          France
# 5  United Kingdom
# 6          Russia
# 7          Turkey
# 8          Poland

# %%
# 東Asia 主要国
e_asia_c = pd.DataFrame([
    ("Japan",""),
    ("China",""),
    ("Taiwan",""),
    ("South Korea",""),
    ("Indonesia",""),
    ("Philippines",""),
    ("Vietnam",""),
    ("Myanmar",""),
    ("Thailand",""),
],columns=["country","text_disp_date"])
e_asia_c
# Out:
#        country text_disp_date
# 0        Japan
# 1        China
# 2       Taiwan
# 3  South Korea
# 4    Indonesia
# 5  Philippines
# 6      Vietnam
# 7      Myanmar
# 8     Thailand

# %%
c_trans = pd.merge(countries, df, left_on="country", right_on="location",how="inner")
c_trans.head()
# Out:
#   country text_disp_date iso_code continent location       date  total_cases  \
# 0   Japan                     JPN      Asia    Japan 2020-01-22          2.0
# 1   Japan                     JPN      Asia    Japan 2020-01-23          2.0
# 2   Japan                     JPN      Asia    Japan 2020-01-24          2.0
# 3   Japan                     JPN      Asia    Japan 2020-01-25          2.0
# 4   Japan                     JPN      Asia    Japan 2020-01-26          4.0
#
#    new_cases  new_cases_smoothed  total_deaths  ...  female_smokers  \
# 0        NaN                 NaN           NaN  ...            11.2
# 1        0.0                 NaN           NaN  ...            11.2
# 2        0.0                 NaN           NaN  ...            11.2
# 3        0.0                 NaN           NaN  ...            11.2
# 4        2.0                 NaN           NaN  ...            11.2
#
#    male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 0          33.7                     NaN                       13.05
# 1          33.7                     NaN                       13.05
# 2          33.7                     NaN                       13.05
# 3          33.7                     NaN                       13.05
# 4          33.7                     NaN                       13.05
#
#    life_expectancy  human_development_index  \
# 0            84.63                    0.919
# 1            84.63                    0.919
# 2            84.63                    0.919
# 3            84.63                    0.919
# 4            84.63                    0.919
#
#    excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                   NaN                          NaN
# 1                                   NaN                          NaN
# 2                                   NaN                          NaN
# 3                                   NaN                          NaN
# 4                                   NaN                          NaN
#
#    excess_mortality  excess_mortality_cumulative_per_million
# 0               NaN                                      NaN
# 1               NaN                                      NaN
# 2               NaN                                      NaN
# 3               NaN                                      NaN
# 4               NaN                                      NaN
#
# [5 rows x 69 columns]

# %%
c_trans.location.unique()
# Out:
# array(['Japan', 'United States', 'Germany', 'Brazil', 'France',
#        'United Kingdom', 'Russia', 'Turkey', 'Poland'], dtype=object)

# %%
c_trans.loc[c_trans.date==latest_date_str][["country","date","total_deaths","total_deaths_per_million"]].sort_values("total_deaths_per_million",ascending=False)
# Out:
#              country       date  total_deaths  total_deaths_per_million
# 3383          Brazil 2022-05-26      666180.0                  3113.086
# 7552          Poland 2022-05-26      116299.0                  3076.937
# 1711   United States 2022-05-26     1004121.0                  3016.148
# 5084  United Kingdom 2022-05-26      178580.0                  2618.202
# 5931          Russia 2022-05-26      371061.0                  2543.046
# 4237          France 2022-05-26      148153.0                  2197.398
# 2562         Germany 2022-05-26      138781.0                  1654.115
# 6738          Turkey 2022-05-26       98948.0                  1163.509
# 855            Japan 2022-05-26       30463.0                   241.672

# %%
e_a_trans = pd.merge(e_asia_c, df, left_on="country", right_on="location",how="inner")
e_a_trans
# Out:
#        country text_disp_date iso_code continent  location       date  \
# 0        Japan                     JPN      Asia     Japan 2020-01-22
# 1        Japan                     JPN      Asia     Japan 2020-01-23
# 2        Japan                     JPN      Asia     Japan 2020-01-24
# 3        Japan                     JPN      Asia     Japan 2020-01-25
# 4        Japan                     JPN      Asia     Japan 2020-01-26
# ...        ...            ...      ...       ...       ...        ...
# 7609  Thailand                     THA      Asia  Thailand 2022-05-22
# 7610  Thailand                     THA      Asia  Thailand 2022-05-23
# 7611  Thailand                     THA      Asia  Thailand 2022-05-24
# 7612  Thailand                     THA      Asia  Thailand 2022-05-25
# 7613  Thailand                     THA      Asia  Thailand 2022-05-26
#
#       total_cases  new_cases  new_cases_smoothed  total_deaths  ...  \
# 0             2.0        NaN                 NaN           NaN  ...
# 1             2.0        0.0                 NaN           NaN  ...
# 2             2.0        0.0                 NaN           NaN  ...
# 3             2.0        0.0                 NaN           NaN  ...
# 4             4.0        2.0                 NaN           NaN  ...
# ...           ...        ...                 ...           ...  ...
# 7609    4415593.0     4099.0            5215.571       29775.0  ...
# 7610    4419737.0     4144.0            5251.429       29811.0  ...
# 7611    4424750.0     5013.0            5162.857       29844.0  ...
# 7612    4429674.0     4924.0            5866.286       29881.0  ...
# 7613    4434511.0     4837.0            4733.286       29910.0  ...
#
#       female_smokers  male_smokers  handwashing_facilities  \
# 0               11.2          33.7                     NaN
# 1               11.2          33.7                     NaN
# 2               11.2          33.7                     NaN
# 3               11.2          33.7                     NaN
# 4               11.2          33.7                     NaN
# ...              ...           ...                     ...
# 7609             1.9          38.8                   90.67
# 7610             1.9          38.8                   90.67
# 7611             1.9          38.8                   90.67
# 7612             1.9          38.8                   90.67
# 7613             1.9          38.8                   90.67
#
#       hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                          13.05            84.63                    0.919
# 1                          13.05            84.63                    0.919
# 2                          13.05            84.63                    0.919
# 3                          13.05            84.63                    0.919
# 4                          13.05            84.63                    0.919
# ...                          ...              ...                      ...
# 7609                        2.10            77.15                    0.777
# 7610                        2.10            77.15                    0.777
# 7611                        2.10            77.15                    0.777
# 7612                        2.10            77.15                    0.777
# 7613                        2.10            77.15                    0.777
#
#       excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                      NaN                          NaN
# 1                                      NaN                          NaN
# 2                                      NaN                          NaN
# 3                                      NaN                          NaN
# 4                                      NaN                          NaN
# ...                                    ...                          ...
# 7609                                   NaN                          NaN
# 7610                                   NaN                          NaN
# 7611                                   NaN                          NaN
# 7612                                   NaN                          NaN
# 7613                                   NaN                          NaN
#
#       excess_mortality  excess_mortality_cumulative_per_million
# 0                  NaN                                      NaN
# 1                  NaN                                      NaN
# 2                  NaN                                      NaN
# 3                  NaN                                      NaN
# 4                  NaN                                      NaN
# ...                ...                                      ...
# 7609               NaN                                      NaN
# 7610               NaN                                      NaN
# 7611               NaN                                      NaN
# 7612               NaN                                      NaN
# 7613               NaN                                      NaN
#
# [7614 rows x 69 columns]

# %%
e_a_trans.location.unique()
# Out:
# array(['Japan', 'China', 'Taiwan', 'South Korea', 'Indonesia',
#        'Philippines', 'Vietnam', 'Myanmar', 'Thailand'], dtype=object)

# %% [markdown]
# ## 今日の新規感染者数

# %%
#c_df_latest = df.loc[(df.date==pd.to_datetime(latest_date_str)-datetime.timedelta(days=1)) & (df.iso_code.str.len()==3)]
c_df_latest = df.loc[(df.date==pd.to_datetime(latest_date_str)) & (df.iso_code.str.len()==3)]

c_df_latest
# Out:
#        iso_code continent           location       date  total_cases  \
# 822         AFG      Asia        Afghanistan 2022-05-26     179835.0
# 2478        ALB    Europe            Albania 2022-05-26     276012.0
# 3300        DZA    Africa            Algeria 2022-05-26     265864.0
# 4116        AND    Europe            Andorra 2022-05-26      42894.0
# 4914        AGO    Africa             Angola 2022-05-26      99527.0
# ...         ...       ...                ...        ...          ...
# 185672      VNM      Asia            Vietnam 2022-05-26   10714008.0
# 186257      WLF   Oceania  Wallis and Futuna 2022-05-26        454.0
# 187891      YEM      Asia              Yemen 2022-05-26      11819.0
# 188691      ZMB    Africa             Zambia 2022-05-26     321399.0
# 189489      ZWE    Africa           Zimbabwe 2022-05-26     251646.0
#
#         new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 822           0.0              34.000        7699.0         0.0
# 2478         27.0              40.000        3497.0         0.0
# 3300          2.0               3.286        6875.0         0.0
# 4116          NaN                 NaN         153.0         0.0
# 4914          0.0              34.286        1900.0         0.0
# ...           ...                 ...           ...         ...
# 185672     1275.0            1354.857       43078.0         0.0
# 186257        0.0               0.000           7.0         0.0
# 187891        0.0               0.000        2149.0         0.0
# 188691       57.0              64.857        3985.0         0.0
# 189489      418.0             205.714        5498.0         2.0
#
#         new_deaths_smoothed  ...  female_smokers  male_smokers  \
# 822                   0.571  ...             NaN           NaN
# 2478                  0.000  ...             7.1          51.2
# 3300                  0.000  ...             0.7          30.4
# 4116                  0.000  ...            29.0          37.8
# 4914                  0.000  ...             NaN           NaN
# ...                     ...  ...             ...           ...
# 185672                0.714  ...             1.0          45.9
# 186257                0.000  ...             NaN           NaN
# 187891                0.000  ...             7.6          29.2
# 188691                0.143  ...             3.1          24.7
# 189489                1.571  ...             1.6          30.7
#
#         handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 822                     37.746                        0.50            64.83
# 2478                       NaN                        2.89            78.57
# 3300                    83.741                        1.90            76.88
# 4116                       NaN                         NaN            83.73
# 4914                    26.664                         NaN            61.15
# ...                        ...                         ...              ...
# 185672                  85.847                        2.60            75.40
# 186257                     NaN                         NaN            79.94
# 187891                  49.542                        0.70            66.12
# 188691                  13.938                        2.00            63.89
# 189489                  36.791                        1.70            61.49
#
#         human_development_index  excess_mortality_cumulative_absolute  \
# 822                       0.511                                   NaN
# 2478                      0.795                                   NaN
# 3300                      0.748                                   NaN
# 4116                      0.868                                   NaN
# 4914                      0.581                                   NaN
# ...                         ...                                   ...
# 185672                    0.704                                   NaN
# 186257                      NaN                                   NaN
# 187891                    0.470                                   NaN
# 188691                    0.584                                   NaN
# 189489                    0.571                                   NaN
#
#         excess_mortality_cumulative  excess_mortality  \
# 822                             NaN               NaN
# 2478                            NaN               NaN
# 3300                            NaN               NaN
# 4116                            NaN               NaN
# 4914                            NaN               NaN
# ...                             ...               ...
# 185672                          NaN               NaN
# 186257                          NaN               NaN
# 187891                          NaN               NaN
# 188691                          NaN               NaN
# 189489                          NaN               NaN
#
#         excess_mortality_cumulative_per_million
# 822                                         NaN
# 2478                                        NaN
# 3300                                        NaN
# 4116                                        NaN
# 4914                                        NaN
# ...                                         ...
# 185672                                      NaN
# 186257                                      NaN
# 187891                                      NaN
# 188691                                      NaN
# 189489                                      NaN
#
# [215 rows x 67 columns]

# %%
c_df_latest.sum()
# Out:
# /tmp/ipykernel_425424/3714355302.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   c_df_latest.sum()
# iso_code                                   AFGALBDZAANDAGOAIAATGARGARMABWAUSAUTAZEBHSBHRB...
# continent                                  AsiaEuropeAfricaEuropeAfricaNorth AmericaNorth...
# location                                   AfghanistanAlbaniaAlgeriaAndorraAngolaAnguilla...
# total_cases                                                                      527610305.0
# new_cases                                                                           494006.0
#                                                                  ...
# human_development_index                                                              135.823
# excess_mortality_cumulative_absolute                                                     0.0
# excess_mortality_cumulative                                                              0.0
# excess_mortality                                                                         0.0
# excess_mortality_cumulative_per_million                                                  0.0
# Length: 65, dtype: object

# %% [markdown]
# ## 可視化

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook
#%matplotlib inline

# %%
min_date = pd.to_datetime(datetime.datetime.now()).round("D")- datetime.timedelta(days=90)

# %%
world_df["case_rolling7ave"] = world_df.new_cases.rolling(7).mean()
world_df[["new_cases_smoothed","case_rolling7ave"]]
# Out:
#         new_cases_smoothed  case_rolling7ave
# 186259                 NaN               NaN
# 186260                 NaN               NaN
# 186261                 NaN               NaN
# 186262                 NaN               NaN
# 186263                 NaN               NaN
# ...                    ...               ...
# 187110          550638.857     550638.857143
# 187111          537245.571     537245.571429
# 187112          539597.429     539597.428571
# 187113          525451.571     525451.571429
# 187114          511715.429     511715.428571
#
# [856 rows x 2 columns]

# %%
fig=plt.figure(figsize=(20,12))
plt.subplot(2,2,1) # (rows, columns, panel number)
plt.title("Daily new confirmed COVID-19 cases in the world")
plt.bar(world_df.date,world_df.new_cases,label="New cases")
plt.plot_date(world_df["date"],world_df["new_cases_smoothed"],label="7daysMA", fmt="-", color="orange")
#plt.xticks(rotation=70)
plt.ylabel("people")
plt.grid(axis="y")
plt.legend()

plt.subplot(2,2,2) # (rows, columns, panel number)
plt.title("Daily new confirmed COVID-19 cases in the world(Recent)")
chart_data = world_df[world_df.date >= min_date]
plt.bar(chart_data["date"],chart_data["new_cases"],label="New cases")
plt.plot_date(chart_data["date"],chart_data["new_cases_smoothed"],label="7days MA", fmt="-", color="orange")
#plt.xticks(rotation=70)
plt.grid(axis="y")
plt.legend()

plt.subplot(2,2,3) # (rows, columns, panel number)
plt.title("Daily new deaths in the world")
plt.bar(world_df.date,world_df.new_deaths,label="New deaths")
plt.plot_date(world_df["date"],world_df["new_deaths_smoothed"],label="7days MA", fmt="-", color="orange")
#plt.xticks(rotation=70)
plt.ylabel("people")
plt.grid(axis="y")
plt.legend()

plt.subplot(2,2,4) # (rows, columns, panel number)
plt.title("Daily new deaths in the world(Recent)")
chart_data = world_df[world_df.date >= min_date]
plt.bar(chart_data["date"],chart_data["new_deaths"],label="New deaths")
plt.plot_date(chart_data["date"],chart_data["new_deaths_smoothed"],label="7days MA", fmt="-", color="orange")
#plt.xticks(rotation=70)
plt.grid(axis="y")
plt.legend()

fig.text(0,1,"Latest: {}".format(latest_date_str),ha="left",va="top")
fig.text(0,0
         ,"*Data Source : COVID-19 Dataset by Our World in Data",
        ha="left",va="bottom")

plt.tight_layout()
# Out:
# <div id='537cae32-1a66-4c67-ab0b-50b1133032f4'></div>

# %%
fig.savefig("out/covid-owid-global-daily.png")

# %% [markdown]
# ### 国別

# %% [markdown]
# #### 人口100万人当たりの新規感染者数（直近）

# %%
"""
#min_date = pd.to_datetime("2021-05-01")
# 主要国 新規感染者
chart_data = c_trans[c_trans.date >= min_date]
dates = chart_data["date"].unique()
print(len(dates))
print(dates.max())
for i,cr in countries.iterrows():
    c = cr["country"]
    dates = chart_data.loc[chart_data["location"]==c]["date"]
    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else latest_date_str
    print(len(chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"]))
    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"],label=c, fmt="-")
    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_cases_smoothed_per_million"],c
            ,fontsize=8,va="center")
"""
# Out:
# '\n#min_date = pd.to_datetime("2021-05-01")\n# 主要国 新規感染者\nchart_data = c_trans[c_trans.date >= min_date]\ndates = chart_data["date"].unique()\nprint(len(dates))\nprint(dates.max())\nfor i,cr in countries.iterrows():\n    c = cr["country"]\n    dates = chart_data.loc[chart_data["location"]==c]["date"]\n    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else latest_date_str\n    print(len(chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"]))\n    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"],label=c, fmt="-")\n    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_cases_smoothed_per_million"],c\n            ,fontsize=8,va="center")\n'

# %%
"""
fig=plt.figure(figsize=(14,10))
min_date = pd.to_datetime("2021-03-01")
# 主要国 新規感染者
plt.subplot(2,2,1) # (rows, columns, panel number)
plt.title("Daily new confirmed COVID-19 cases\n per million population in major countries\n(rolling 7day ave.)")
plt.grid()
plt.xticks(rotation=70)
chart_data = c_trans[c_trans.date >= min_date]
dates = chart_data["date"].unique()
for i,cr in countries.iterrows():
    c = cr["country"]
    dates = chart_data.loc[chart_data["location"]==c]["date"]
    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else dates.max()
    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"],label=c, fmt="-")
    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_cases_smoothed_per_million"],c
            ,fontsize=8,va="center")
plt.legend(bbox_to_anchor=(0, 1),loc='upper left', fontsize=9)
"""
# Out:
# '\nfig=plt.figure(figsize=(14,10))\nmin_date = pd.to_datetime("2021-03-01")\n# 主要国 新規感染者\nplt.subplot(2,2,1) # (rows, columns, panel number)\nplt.title("Daily new confirmed COVID-19 cases\n per million population in major countries\n(rolling 7day ave.)")\nplt.grid()\nplt.xticks(rotation=70)\nchart_data = c_trans[c_trans.date >= min_date]\ndates = chart_data["date"].unique()\nfor i,cr in countries.iterrows():\n    c = cr["country"]\n    dates = chart_data.loc[chart_data["location"]==c]["date"]\n    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else dates.max()\n    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"],label=c, fmt="-")\n    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_cases_smoothed_per_million"],c\n            ,fontsize=8,va="center")\nplt.legend(bbox_to_anchor=(0, 1),loc=\'upper left\', fontsize=9)\n'

# %%
fig=plt.figure(figsize=(20,14))
# 主要国 新規感染者
plt.subplot(2,2,1) # (rows, columns, panel number)
plt.title("Daily new confirmed COVID-19 cases\n per million population in major countries(7daysMA)")
plt.grid()
plt.xticks(rotation=45)
chart_data = c_trans[c_trans.date >= min_date]
for i,cr in countries.iterrows():
    c = cr["country"]
    dates = chart_data.loc[chart_data["location"]==c]["date"]
    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else dates.max()
    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"],label=c, fmt="-")
    text_y = chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_cases_smoothed_per_million"]
#    print(text_y)
    print(c,text_disp_date,text_y)
#    plt.text(text_disp_date,text_y,c,fontsize=10,va="center")
    plt.text(text_disp_date,text_y,c,va="center")
plt.legend(bbox_to_anchor=(0, 1),loc='upper left')

# 主要国 死者
plt.subplot(2,2,2) # (rows, columns, panel number)
plt.title("Daily new deaths in major countries(7daysMA)")
plt.grid()
plt.xticks(rotation=45)
chart_data = c_trans[c_trans.date >= min_date]
for i,cr in countries.iterrows():
    c = cr["country"]
    dates = chart_data.loc[chart_data["location"]==c]["date"]
    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else dates.max()
    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_deaths_smoothed"],label=c, fmt="-")
    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_deaths_smoothed"],c
            ,va="center")
plt.legend(bbox_to_anchor=(0, 1),loc='upper left')

plt.subplot(2,2,3) # (rows, columns, panel number)
plt.grid()
plt.xticks(rotation=45)
plt.title("Daily new confirmed COVID-19 cases\n per million population in Eastern Asia(7daysMA)")
chart_data = e_a_trans[e_a_trans.date >= min_date]
for i,cr in e_asia_c.iterrows():
    c = cr["country"]
    dates = chart_data.loc[chart_data["location"]==c]["date"]
    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else dates.max()
    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"],label=c, fmt="-")
    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_cases_smoothed_per_million"],c
             ,va="center")
plt.legend(bbox_to_anchor=(0, 1),loc='upper left')

plt.subplot(2,2,4) # (rows, columns, panel number)
plt.grid()
plt.xticks(rotation=45)
plt.title("Daily new deaths in Eastern Asia(7daysMA)")
chart_data = e_a_trans[e_a_trans.date >= min_date]
for i,cr in e_asia_c.iterrows():
    c = cr["country"]
    dates = chart_data.loc[chart_data["location"]==c]["date"]
    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else dates.max()
    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_deaths_smoothed"],label=c, fmt="-")
    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_deaths_smoothed"],c
             ,va="center")
plt.legend(bbox_to_anchor=(0, 1),loc='upper left')

fig.text(0,0.98,"Latest: {}".format(latest_date_str),ha="left",va="top")
fig.text(0,0
         ,"*Data Source : COVID-19 Dataset by Our World in Data",
        ha="left",va="bottom")
fig.tight_layout()
"""
"""
# Out:
# <div id='3dd464a7-0cdd-4506-a578-9066c81f9311'></div>
# Japan 2022-05-26 00:00:00 855    250.719
# Name: new_cases_smoothed_per_million, dtype: float64
# United States 2022-05-26 00:00:00 1711    319.657
# Name: new_cases_smoothed_per_million, dtype: float64
# Germany 2022-05-26 00:00:00 2562    344.929
# Name: new_cases_smoothed_per_million, dtype: float64
# Brazil 2022-05-26 00:00:00 3383    119.237
# Name: new_cases_smoothed_per_million, dtype: float64
# France 2022-05-26 00:00:00 4237    294.675
# Name: new_cases_smoothed_per_million, dtype: float64
# United Kingdom 2022-05-26 00:00:00 5084   NaN
# Name: new_cases_smoothed_per_million, dtype: float64
# Russia 2022-05-26 00:00:00 5931    30.86
# Name: new_cases_smoothed_per_million, dtype: float64
# Turkey 2022-05-26 00:00:00 6738    13.408
# Name: new_cases_smoothed_per_million, dtype: float64
# Poland 2022-05-26 00:00:00 7552    6.656
# Name: new_cases_smoothed_per_million, dtype: float64
# '\n'

# %%
fig.savefig("out/covid-owid-countries-daily.png")
# Out:
# posx and posy should be finite values
# posx and posy should be finite values

# %% [markdown]
# ### 新規感染者数

# %%
fig = plt.figure(figsize=(12,14))

plt.subplot(2,2,1) # (rows, columns, panel number)
plt.title("New confirmed COVID-19 cases worst 50")
plt.yticks(fontsize=9)
plt.xlabel("people")
chart_data = c_df_latest.sort_values("new_cases",ascending=False).head(50).sort_values("new_cases",ascending=True)
plt.barh(chart_data["location"],chart_data["new_cases"],label="new cases a day")
plt.grid(axis="x")
mean = int(c_df_latest.new_cases.mean())
plt.plot([mean,mean],[0,50], 'k--', lw=0.5)
plt.text(mean,50,"Mean:{}".format(mean),ha="center",fontsize=9)
plt.legend()

plt.subplot(2,2,2) # (rows, columns, panel number)
plt.title("New confirmed COVID-19 cases per million worst 50")
plt.yticks(fontsize=9)
plt.xlabel("people")
chart_data = c_df_latest.sort_values("new_cases_per_million",ascending=False).head(50).sort_values("new_cases_per_million",ascending=True)
plt.barh(chart_data["location"],chart_data["new_cases_per_million"],label="new cases a day per million")
plt.grid(axis="x")
mean = int(chart_data.new_cases_per_million.mean())
plt.plot([mean,mean],[0,50], 'k--', lw=0.5)
plt.text(mean,50,"Mean:{}".format(mean),ha="center",fontsize=9)
plt.legend()

fig.text(0,0.98,"Latest: {}".format(latest_date_str),fontsize=9,ha="left",va="top")
fig.text(0,0
         ,"*Data Source : COVID-19 Dataset by Our World in Data",
        fontsize=8,ha="left",va="bottom")

plt.subplot(2,2,3) # (rows, columns, panel number)
plt.title("New deaths worst 50")
plt.yticks(fontsize=9)
plt.xlabel("people")
chart_data = c_df_latest.sort_values("new_deaths",ascending=False).head(50).sort_values("new_deaths",ascending=True)
plt.barh(chart_data["location"],chart_data["new_deaths"],label="new deaths a day")
plt.grid(axis="x")
mean = int(c_df_latest.new_deaths.mean())
plt.plot([mean,mean],[0,50], 'k--', lw=0.5)
plt.text(mean,50,"Mean:{}".format(mean),ha="center",fontsize=9)
plt.legend()

plt.subplot(2,2,4) # (rows, columns, panel number)
plt.title("Total deaths per capita worst 50")
plt.yticks(fontsize=9)
plt.xlabel("%")
chart_data = c_df_latest.copy()
chart_data["total_deaths_per_capita"] = chart_data.total_deaths / chart_data.population * 100
chart_data = chart_data.sort_values("total_deaths_per_capita",ascending=False).head(50).sort_values("total_deaths_per_capita",ascending=True)
plt.barh(chart_data["location"],chart_data["total_deaths_per_capita"],label="total deaths per capita")
plt.grid(axis="x")
mean = round(chart_data.total_deaths_per_capita.mean(),2)
plt.plot([mean,mean],[0,50], 'k--', lw=0.5)
plt.text(mean,50,"Mean:{}".format(mean),ha="center",fontsize=9)
plt.legend()


fig.tight_layout()
# Out:
# <div id='9fbf2c05-a5cc-4898-8892-0efd39d1ae67'></div>

# %%
fig.savefig("out/covid-owid-global-latest-top.png")

# %%
a_df = df.loc[df.location=="Japan"]
c_df = df.loc[(df.date==pd.to_datetime("2021-07-27")) & (df.iso_code.str.len()==3)]

# %%
a_df.tail(10)
# Out:
#       iso_code continent location       date  total_cases  new_cases  \
# 87440      JPN      Asia    Japan 2022-05-17    8428219.0    36795.0
# 87441      JPN      Asia    Japan 2022-05-18    8470287.0    42068.0
# 87442      JPN      Asia    Japan 2022-05-19    8509857.0    39570.0
# 87443      JPN      Asia    Japan 2022-05-20    8547200.0    37343.0
# 87444      JPN      Asia    Japan 2022-05-21    8583048.0    35848.0
# 87445      JPN      Asia    Japan 2022-05-22    8614387.0    31339.0
# 87446      JPN      Asia    Japan 2022-05-23    8632778.0    18391.0
# 87447      JPN      Asia    Japan 2022-05-24    8665068.0    32290.0
# 87448      JPN      Asia    Japan 2022-05-25    8700168.0    35100.0
# 87449      JPN      Asia    Japan 2022-05-26    8731080.0    30912.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 87440           37108.143       30126.0        39.0               32.571  ...
# 87441           36568.000       30176.0        50.0               33.857  ...
# 87442           36271.143       30212.0        36.0               34.429  ...
# 87443           35953.000       30256.0        44.0               35.714  ...
# 87444           35455.571       30287.0        31.0               35.857  ...
# 87445           34948.000       30305.0        18.0               34.857  ...
# 87446           34479.143       30336.0        31.0               35.571  ...
# 87447           33835.571       30378.0        42.0               36.000  ...
# 87448           32840.143       30421.0        43.0               35.000  ...
# 87449           31603.286       30463.0        42.0               35.857  ...
#
#        female_smokers  male_smokers  handwashing_facilities  \
# 87440            11.2          33.7                     NaN
# 87441            11.2          33.7                     NaN
# 87442            11.2          33.7                     NaN
# 87443            11.2          33.7                     NaN
# 87444            11.2          33.7                     NaN
# 87445            11.2          33.7                     NaN
# 87446            11.2          33.7                     NaN
# 87447            11.2          33.7                     NaN
# 87448            11.2          33.7                     NaN
# 87449            11.2          33.7                     NaN
#
#        hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 87440                       13.05            84.63                    0.919
# 87441                       13.05            84.63                    0.919
# 87442                       13.05            84.63                    0.919
# 87443                       13.05            84.63                    0.919
# 87444                       13.05            84.63                    0.919
# 87445                       13.05            84.63                    0.919
# 87446                       13.05            84.63                    0.919
# 87447                       13.05            84.63                    0.919
# 87448                       13.05            84.63                    0.919
# 87449                       13.05            84.63                    0.919
#
#        excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 87440                                   NaN                          NaN
# 87441                                   NaN                          NaN
# 87442                                   NaN                          NaN
# 87443                                   NaN                          NaN
# 87444                                   NaN                          NaN
# 87445                                   NaN                          NaN
# 87446                                   NaN                          NaN
# 87447                                   NaN                          NaN
# 87448                                   NaN                          NaN
# 87449                                   NaN                          NaN
#
#        excess_mortality  excess_mortality_cumulative_per_million
# 87440               NaN                                      NaN
# 87441               NaN                                      NaN
# 87442               NaN                                      NaN
# 87443               NaN                                      NaN
# 87444               NaN                                      NaN
# 87445               NaN                                      NaN
# 87446               NaN                                      NaN
# 87447               NaN                                      NaN
# 87448               NaN                                      NaN
# 87449               NaN                                      NaN
#
# [10 rows x 67 columns]

# %%
c_df.sort_values("new_deaths",ascending=False).head(50)
# Out:
#        iso_code      continent        location       date  total_cases  \
# 79702       IDN           Asia       Indonesia 2021-07-27    3239936.0
# 24199       BRA  South America          Brazil 2021-07-27   19758310.0
# 141402      RUS         Europe          Russia 2021-07-27    6094379.0
# 78886       IND           Asia           India 2021-07-27   31484605.0
# 110693      MEX  North America          Mexico 2021-07-27    2771846.0
# 179082      USA  North America   United States 2021-07-27   34718979.0
# 81370       IRN           Asia            Iran 2021-07-27    3758197.0
# 117648      MMR           Asia         Myanmar 2021-07-27     279119.0
# 157334      ZAF         Africa    South Africa 2021-07-27    2391223.0
# 36418       COL  South America        Colombia 2021-07-27    4747775.0
# 14514       BGD           Asia      Bangladesh 2021-07-27    1194752.0
# 7083        ARG  South America       Argentina 2021-07-27    4875927.0
# 105046      MYS           Asia        Malaysia 2021-07-27    1044071.0
# 172605      TUN         Africa         Tunisia 2021-07-27     575002.0
# 178226      GBR         Europe  United Kingdom 2021-07-27    5754319.0
# 168861      THA           Asia        Thailand 2021-07-27     526828.0
# 189186      ZWE         Africa        Zimbabwe 2021-07-27     101711.0
# 135540      PER  South America            Peru 2021-07-27    2106371.0
# 41596       CUB  North America            Cuba 2021-07-27     349055.0
# 136388      PHL           Asia     Philippines 2021-07-27    1562420.0
# 82193       IRQ           Asia            Iraq 2021-07-27    1577013.0
# 20992       BOL  South America         Bolivia 2021-07-27     470024.0
# 70205       GTM  North America       Guatemala 2021-07-27     355223.0
# 75549       HND  North America        Honduras 2021-07-27     291687.0
# 134728      PRY  South America        Paraguay 2021-07-27     450494.0
# 160643      ESP         Europe           Spain 2021-07-27    4368453.0
# 173412      TUR           Asia          Turkey 2021-07-27    5638178.0
# 161494      LKA           Asia       Sri Lanka 2021-07-27     299892.0
# 131219      PAK           Asia        Pakistan 2021-07-27    1015827.0
# 39161       CRI  North America      Costa Rica 2021-07-27     402044.0
# 176530      UKR         Europe         Ukraine 2021-07-27    2327777.0
# 64534       DEU         Europe         Germany 2021-07-27    3758401.0
# 519         AFG           Asia     Afghanistan 2021-07-27     145008.0
# 118452      NAM         Africa         Namibia 2021-07-27     117293.0
# 116857      MOZ         Africa      Mozambique 2021-07-27     113426.0
# 34750       CHL  South America           Chile 2021-07-27    1611090.0
# 60452       FRA         Europe          France 2021-07-27    6068988.0
# 104192      MWI         Africa          Malawi 2021-07-27      49752.0
# 116061      MAR         Africa         Morocco 2021-07-27     588448.0
# 2997        DZA         Africa         Algeria 2021-07-27     165204.0
# 85483       ITA         Europe           Italy 2021-07-27    4325046.0
# 97614       LBY         Africa           Libya 2021-07-27     240309.0
# 188388      ZMB         Africa          Zambia 2021-07-27     192956.0
# 119674      NPL           Asia           Nepal 2021-07-27     685673.0
# 29054       KHM           Asia        Cambodia 2021-07-27      74386.0
# 130397      OMN           Asia            Oman 2021-07-27     295017.0
# 63683       GEO           Asia         Georgia 2021-07-27     407689.0
# 184514      VEN  South America       Venezuela 2021-07-27     301979.0
# 113620      MNG           Asia        Mongolia 2021-07-27     159101.0
# 92814       KGZ           Asia      Kyrgyzstan 2021-07-27     159089.0
#
#         new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 79702     45203.0           41411.143       86835.0      2069.0
# 24199     43591.0           47082.000      552128.0      1289.0
# 141402    22486.0           23207.714      152836.0       767.0
# 78886     43654.0           38324.000      422022.0       640.0
# 110693    17408.0           13364.143      239079.0       484.0
# 179082    64993.0           60877.714      607697.0       445.0
# 81370     34951.0           26007.000       89479.0       357.0
# 117648     4964.0            5507.000        7845.0       338.0
# 157334     7733.0           11427.286       70338.0       320.0
# 36418     11426.0           11289.286      119482.0       300.0
# 14514     14925.0            9409.000       19779.0       258.0
# 7083      16757.0           13101.143      104352.0       247.0
# 105046    16117.0           14881.714        8408.0       207.0
# 172605     1608.0            2870.143       18968.0       164.0
# 178226    23330.0           32464.571      129389.0       131.0
# 168861    14150.0           14336.143        4264.0       118.0
# 189186     1767.0            1899.429        3280.0       107.0
# 135540     1366.0            1479.714      196058.0        85.0
# 41596      7903.0            7800.857        2492.0        75.0
# 136388     7024.0            6359.571       27318.0        71.0
# 82193     12185.0            9499.429       18418.0        71.0
# 20992      1601.0             985.571       17716.0        65.0
# 70205      2639.0            2494.429       10176.0        64.0
# 75549      1240.0            1285.857        7713.0        63.0
# 134728      592.0             603.857       14759.0        58.0
# 160643    26399.0           25616.714       81323.0        55.0
# 173412    19761.0           13144.571       51048.0        51.0
# 161494     1711.0            1702.714        4195.0        48.0
# 131219     4119.0            2768.000       23133.0        46.0
# 39161      3436.0            1129.857        4987.0        46.0
# 176530     1227.0            1127.286       55420.0        39.0
# 64534      1545.0            1713.000       91565.0        38.0
# 519         723.0             370.571        6515.0        38.0
# 118452      329.0             550.714        2871.0        37.0
# 116857     1703.0            1631.000        1341.0        34.0
# 34750       745.0            1318.857       35151.0        32.0
# 60452     27024.0           19467.143      111727.0        28.0
# 104192      743.0             724.000        1540.0        27.0
# 116061     6971.0            3718.857        9638.0        27.0
# 2997       1544.0            1345.714        4112.0        25.0
# 85483      4516.0            4566.143      127995.0        24.0
# 97614      3348.0            1944.000        3422.0        24.0
# 188388      640.0             764.857        3316.0        21.0
# 119674     2726.0            2102.857        9758.0        20.0
# 29054       685.0             798.571        1324.0        19.0
# 130397      491.0             853.571        3788.0        17.0
# 63683      3666.0            2392.000        5731.0        17.0
# 184514     1060.0            1159.000        3524.0        15.0
# 113620     1127.0            1124.429         796.0        14.0
# 92814       969.0            1068.857        2275.0        14.0
#
#         new_deaths_smoothed  ...  female_smokers  male_smokers  \
# 79702              1519.286  ...             2.8          76.1
# 24199              1085.143  ...            10.1          17.9
# 141402              768.429  ...            23.4          58.3
# 78886               506.000  ...             1.9          20.6
# 110693              324.143  ...             6.9          21.4
# 179082              305.143  ...            19.1          24.6
# 81370               265.000  ...             0.8          21.1
# 117648              325.429  ...             6.3          35.2
# 157334              380.286  ...             8.1          33.2
# 36418               335.857  ...             4.7          13.5
# 14514               207.714  ...             1.0          44.7
# 7083                281.571  ...            16.2          27.7
# 105046              166.714  ...             1.0          42.4
# 172605              163.857  ...             1.1          65.8
# 178226               68.571  ...            20.0          24.7
# 168861              108.857  ...             1.9          38.8
# 189186               76.143  ...             1.6          30.7
# 135540              103.714  ...             4.8           NaN
# 41596                67.571  ...            17.1          53.3
# 136388               67.714  ...             7.8          40.8
# 82193                66.714  ...             NaN           NaN
# 20992                34.429  ...             NaN           NaN
# 70205                35.571  ...             NaN           NaN
# 75549                29.429  ...             2.0           NaN
# 134728               52.143  ...             5.0          21.6
# 160643               25.000  ...            27.4          31.4
# 173412               56.857  ...            14.1          41.1
# 161494               46.429  ...             0.3          27.0
# 131219               35.000  ...             2.8          36.7
# 39161                10.286  ...             6.4          17.4
# 176530               28.429  ...            13.5          47.4
# 64534                24.000  ...            28.2          33.1
# 519                  35.571  ...             NaN           NaN
# 118452               44.857  ...             9.7          34.2
# 116857               26.143  ...             5.1          29.1
# 34750                83.143  ...            34.2          41.5
# 60452                24.429  ...            30.1          35.6
# 104192               25.286  ...             4.4          24.7
# 116061               21.714  ...             0.8          47.1
# 2997                 19.000  ...             0.7          30.4
# 85483                15.857  ...            19.8          27.8
# 97614                16.143  ...             NaN           NaN
# 188388               25.429  ...             3.1          24.7
# 119674               21.571  ...             9.5          37.8
# 29054                25.000  ...             2.0          33.7
# 130397               41.429  ...             0.5          15.6
# 63683                19.857  ...             5.3          55.5
# 184514               18.857  ...             NaN           NaN
# 113620                7.286  ...             5.5          46.5
# 92814                11.286  ...             3.6          50.5
#
#         handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 79702                   64.204                        1.04            71.72
# 24199                      NaN                        2.20            75.88
# 141402                     NaN                        8.05            72.58
# 78886                   59.550                        0.53            69.66
# 110693                  87.847                        1.38            75.05
# 179082                     NaN                        2.77            78.86
# 81370                      NaN                        1.50            76.68
# 117648                  79.287                        0.90            67.13
# 157334                  43.993                        2.32            64.13
# 36418                   65.386                        1.71            77.29
# 14514                   34.808                        0.80            72.59
# 7083                       NaN                        5.00            76.67
# 105046                     NaN                        1.90            76.16
# 172605                  78.687                        2.30            76.70
# 178226                     NaN                        2.54            81.32
# 168861                  90.670                        2.10            77.15
# 189186                  36.791                        1.70            61.49
# 135540                     NaN                        1.60            76.74
# 41596                   85.198                        5.20            78.80
# 136388                  78.463                        1.00            71.23
# 82193                   94.576                        1.40            70.60
# 20992                   25.383                        1.10            71.51
# 70205                   76.665                        0.60            74.30
# 75549                   84.169                        0.70            75.27
# 134728                  79.602                        1.30            74.25
# 160643                     NaN                        2.97            83.56
# 173412                     NaN                        2.81            77.69
# 161494                     NaN                        3.60            76.98
# 131219                  59.607                        0.60            67.27
# 39161                   83.841                        1.13            80.28
# 176530                     NaN                        8.80            72.06
# 64534                      NaN                        8.00            81.33
# 519                     37.746                        0.50            64.83
# 118452                  44.600                         NaN            63.71
# 116857                  12.227                        0.70            60.85
# 34750                      NaN                        2.11            80.18
# 60452                      NaN                        5.98            82.66
# 104192                   8.704                        1.30            64.26
# 116061                     NaN                        1.10            76.68
# 2997                    83.741                        1.90            76.88
# 85483                      NaN                        3.18            83.51
# 97614                      NaN                        3.70            72.91
# 188388                  13.938                        2.00            63.89
# 119674                  47.782                        0.30            70.78
# 29054                   66.229                        0.80            69.82
# 130397                  97.400                        1.60            77.86
# 63683                      NaN                        2.60            73.77
# 184514                     NaN                        0.80            72.06
# 113620                  71.180                        7.00            69.87
# 92814                   89.220                        4.50            71.45
#
#         human_development_index  excess_mortality_cumulative_absolute  \
# 79702                     0.718                                   NaN
# 24199                     0.765                                   NaN
# 141402                    0.824                                   NaN
# 78886                     0.645                                   NaN
# 110693                    0.779                                   NaN
# 179082                    0.926                                   NaN
# 81370                     0.783                                   NaN
# 117648                    0.583                                   NaN
# 157334                    0.709                                   NaN
# 36418                     0.767                                   NaN
# 14514                     0.632                                   NaN
# 7083                      0.845                                   NaN
# 105046                    0.810                                   NaN
# 172605                    0.740                                   NaN
# 178226                    0.932                                   NaN
# 168861                    0.777                                   NaN
# 189186                    0.571                                   NaN
# 135540                    0.777                                   NaN
# 41596                     0.783                                   NaN
# 136388                    0.718                                   NaN
# 82193                     0.674                                   NaN
# 20992                     0.718                                   NaN
# 70205                     0.663                                   NaN
# 75549                     0.634                                   NaN
# 134728                    0.728                                   NaN
# 160643                    0.904                                   NaN
# 173412                    0.820                                   NaN
# 161494                    0.782                                   NaN
# 131219                    0.557                                   NaN
# 39161                     0.810                                   NaN
# 176530                    0.779                                   NaN
# 64534                     0.947                                   NaN
# 519                       0.511                                   NaN
# 118452                    0.646                                   NaN
# 116857                    0.456                                   NaN
# 34750                     0.851                                   NaN
# 60452                     0.901                                   NaN
# 104192                    0.483                                   NaN
# 116061                    0.686                                   NaN
# 2997                      0.748                                   NaN
# 85483                     0.892                                   NaN
# 97614                     0.724                                   NaN
# 188388                    0.584                                   NaN
# 119674                    0.602                                   NaN
# 29054                     0.594                                   NaN
# 130397                    0.813                                   NaN
# 63683                     0.812                                   NaN
# 184514                    0.711                                   NaN
# 113620                    0.737                                   NaN
# 92814                     0.697                                   NaN
#
#         excess_mortality_cumulative  excess_mortality  \
# 79702                           NaN               NaN
# 24199                           NaN               NaN
# 141402                          NaN               NaN
# 78886                           NaN               NaN
# 110693                          NaN               NaN
# 179082                          NaN               NaN
# 81370                           NaN               NaN
# 117648                          NaN               NaN
# 157334                          NaN               NaN
# 36418                           NaN               NaN
# 14514                           NaN               NaN
# 7083                            NaN               NaN
# 105046                          NaN               NaN
# 172605                          NaN               NaN
# 178226                          NaN               NaN
# 168861                          NaN               NaN
# 189186                          NaN               NaN
# 135540                          NaN               NaN
# 41596                           NaN               NaN
# 136388                          NaN               NaN
# 82193                           NaN               NaN
# 20992                           NaN               NaN
# 70205                           NaN               NaN
# 75549                           NaN               NaN
# 134728                          NaN               NaN
# 160643                          NaN               NaN
# 173412                          NaN               NaN
# 161494                          NaN               NaN
# 131219                          NaN               NaN
# 39161                           NaN               NaN
# 176530                          NaN               NaN
# 64534                           NaN               NaN
# 519                             NaN               NaN
# 118452                          NaN               NaN
# 116857                          NaN               NaN
# 34750                           NaN               NaN
# 60452                           NaN               NaN
# 104192                          NaN               NaN
# 116061                          NaN               NaN
# 2997                            NaN               NaN
# 85483                           NaN               NaN
# 97614                           NaN               NaN
# 188388                          NaN               NaN
# 119674                          NaN               NaN
# 29054                           NaN               NaN
# 130397                          NaN               NaN
# 63683                           NaN               NaN
# 184514                          NaN               NaN
# 113620                          NaN               NaN
# 92814                           NaN               NaN
#
#         excess_mortality_cumulative_per_million
# 79702                                       NaN
# 24199                                       NaN
# 141402                                      NaN
# 78886                                       NaN
# 110693                                      NaN
# 179082                                      NaN
# 81370                                       NaN
# 117648                                      NaN
# 157334                                      NaN
# 36418                                       NaN
# 14514                                       NaN
# 7083                                        NaN
# 105046                                      NaN
# 172605                                      NaN
# 178226                                      NaN
# 168861                                      NaN
# 189186                                      NaN
# 135540                                      NaN
# 41596                                       NaN
# 136388                                      NaN
# 82193                                       NaN
# 20992                                       NaN
# 70205                                       NaN
# 75549                                       NaN
# 134728                                      NaN
# 160643                                      NaN
# 173412                                      NaN
# 161494                                      NaN
# 131219                                      NaN
# 39161                                       NaN
# 176530                                      NaN
# 64534                                       NaN
# 519                                         NaN
# 118452                                      NaN
# 116857                                      NaN
# 34750                                       NaN
# 60452                                       NaN
# 104192                                      NaN
# 116061                                      NaN
# 2997                                        NaN
# 85483                                       NaN
# 97614                                       NaN
# 188388                                      NaN
# 119674                                      NaN
# 29054                                       NaN
# 130397                                      NaN
# 63683                                       NaN
# 184514                                      NaN
# 113620                                      NaN
# 92814                                       NaN
#
# [50 rows x 67 columns]

# %%
c_df.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'total_tests', 'new_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'total_boosters',
#        'new_vaccinations', 'new_vaccinations_smoothed',
#        'total_vaccinations_per_hundred', 'people_vaccinated_per_hundred',
#        'people_fully_vaccinated_per_hundred', 'total_boosters_per_hundred',
#        'new_vaccinations_smoothed_per_million',
#        'new_people_vaccinated_smoothed',
#        'new_people_vaccinated_smoothed_per_hundred', 'stringency_index',
#        'population', 'population_density', 'median_age', 'aged_65_older',
#        'aged_70_older', 'gdp_per_capita', 'extreme_poverty',
#        'cardiovasc_death_rate', 'diabetes_prevalence', 'female_smokers',
#        'male_smokers', 'handwashing_facilities', 'hospital_beds_per_thousand',
#        'life_expectancy', 'human_development_index',
#        'excess_mortality_cumulative_absolute', 'excess_mortality_cumulative',
#        'excess_mortality', 'excess_mortality_cumulative_per_million'],
#       dtype='object')
