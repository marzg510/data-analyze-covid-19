# %%
import pandas as pd

# %%
df = pd.read_csv("covid-19-data/public/data/owid-covid-data.csv")
df.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1      AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    female_smokers  male_smokers  handwashing_facilities  \
# 0             NaN           NaN                  37.746
# 1             NaN           NaN                  37.746
# 2             NaN           NaN                  37.746
# 3             NaN           NaN                  37.746
# 4             NaN           NaN                  37.746
#
#    hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                         0.5            64.83                    0.511
# 1                         0.5            64.83                    0.511
# 2                         0.5            64.83                    0.511
# 3                         0.5            64.83                    0.511
# 4                         0.5            64.83                    0.511
#
#    excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                   NaN                          NaN
# 1                                   NaN                          NaN
# 2                                   NaN                          NaN
# 3                                   NaN                          NaN
# 4                                   NaN                          NaN
#
#    excess_mortality  excess_mortality_cumulative_per_million
# 0               NaN                                      NaN
# 1               NaN                                      NaN
# 2               NaN                                      NaN
# 3               NaN                                      NaN
# 4               NaN                                      NaN
#
# [5 rows x 67 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 138255 entries, 0 to 138254
# Data columns (total 67 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   iso_code                                    138255 non-null  object
#  1   continent                                   129456 non-null  object
#  2   location                                    138255 non-null  object
#  3   date                                        138255 non-null  object
#  4   total_cases                                 130585 non-null  float64
#  5   new_cases                                   130580 non-null  float64
#  6   new_cases_smoothed                          129540 non-null  float64
#  7   total_deaths                                119268 non-null  float64
#  8   new_deaths                                  119464 non-null  float64
#  9   new_deaths_smoothed                         129540 non-null  float64
#  10  total_cases_per_million                     129916 non-null  float64
#  11  new_cases_per_million                       129911 non-null  float64
#  12  new_cases_smoothed_per_million              128876 non-null  float64
#  13  total_deaths_per_million                    118612 non-null  float64
#  14  new_deaths_per_million                      118808 non-null  float64
#  15  new_deaths_smoothed_per_million             128876 non-null  float64
#  16  reproduction_rate                           109420 non-null  float64
#  17  icu_patients                                16938 non-null   float64
#  18  icu_patients_per_million                    16938 non-null   float64
#  19  hosp_patients                               19354 non-null   float64
#  20  hosp_patients_per_million                   19354 non-null   float64
#  21  weekly_icu_admissions                       1319 non-null    float64
#  22  weekly_icu_admissions_per_million           1319 non-null    float64
#  23  weekly_hosp_admissions                      2205 non-null    float64
#  24  weekly_hosp_admissions_per_million          2205 non-null    float64
#  25  new_tests                                   58019 non-null   float64
#  26  total_tests                                 58225 non-null   float64
#  27  total_tests_per_thousand                    58225 non-null   float64
#  28  new_tests_per_thousand                      58019 non-null   float64
#  29  new_tests_smoothed                          69872 non-null   float64
#  30  new_tests_smoothed_per_thousand             69872 non-null   float64
#  31  positive_rate                               65779 non-null   float64
#  32  tests_per_case                              65118 non-null   float64
#  33  tests_units                                 71952 non-null   object
#  34  total_vaccinations                          36190 non-null   float64
#  35  people_vaccinated                           34565 non-null   float64
#  36  people_fully_vaccinated                     31607 non-null   float64
#  37  total_boosters                              8831 non-null    float64
#  38  new_vaccinations                            30144 non-null   float64
#  39  new_vaccinations_smoothed                   64490 non-null   float64
#  40  total_vaccinations_per_hundred              36190 non-null   float64
#  41  people_vaccinated_per_hundred               34565 non-null   float64
#  42  people_fully_vaccinated_per_hundred         31607 non-null   float64
#  43  total_boosters_per_hundred                  8831 non-null    float64
#  44  new_vaccinations_smoothed_per_million       64490 non-null   float64
#  45  new_people_vaccinated_smoothed              63244 non-null   float64
#  46  new_people_vaccinated_smoothed_per_hundred  63244 non-null   float64
#  47  stringency_index                            112385 non-null  float64
#  48  population                                  137269 non-null  float64
#  49  population_density                          125142 non-null  float64
#  50  median_age                                  119180 non-null  float64
#  51  aged_65_older                               117864 non-null  float64
#  52  aged_70_older                               118530 non-null  float64
#  53  gdp_per_capita                              119961 non-null  float64
#  54  extreme_poverty                             80149 non-null   float64
#  55  cardiovasc_death_rate                       119376 non-null  float64
#  56  diabetes_prevalence                         123380 non-null  float64
#  57  female_smokers                              92982 non-null   float64
#  58  male_smokers                                91640 non-null   float64
#  59  handwashing_facilities                      60088 non-null   float64
#  60  hospital_beds_per_thousand                  108461 non-null  float64
#  61  life_expectancy                             128539 non-null  float64
#  62  human_development_index                     119499 non-null  float64
#  63  excess_mortality_cumulative_absolute        4853 non-null    float64
#  64  excess_mortality_cumulative                 4853 non-null    float64
#  65  excess_mortality                            4853 non-null    float64
#  66  excess_mortality_cumulative_per_million     4853 non-null    float64
# dtypes: float64(62), object(5)
# memory usage: 70.7+ MB

# %%
df.describe()
# Out:
#         total_cases      new_cases  new_cases_smoothed  total_deaths  \
# count  1.305850e+05  130580.000000       129540.000000  1.192680e+05
# mean   2.169847e+06    8516.221420         8526.655398  5.286268e+04
# std    1.232309e+07   44318.385922        43727.305434  2.706757e+05
# min    1.000000e+00  -74347.000000        -6223.000000  1.000000e+00
# 25%    2.597000e+03       3.000000           10.571000  8.500000e+01
# 50%    2.993300e+04     105.000000          131.429000  7.940000e+02
# 75%    2.807700e+05    1098.000000         1158.000000  6.935250e+03
# max    2.664563e+08  908289.000000       827220.000000  5.262579e+06
#
#           new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  119464.000000        129540.000000            129916.000000
# mean      182.810696           167.880778             21192.500120
# std       865.437238           812.548659             34871.855724
# min     -1918.000000          -232.143000                 0.001000
# 25%         0.000000             0.143000               450.675750
# 50%         2.000000             2.000000              3496.871500
# 75%        22.000000            18.857000             27257.663000
# max     18007.000000         14703.286000            252563.884000
#
#        new_cases_per_million  new_cases_smoothed_per_million  \
# count          129911.000000                    128876.00000
# mean               90.537796                        90.42243
# std               213.357607                       180.15698
# min             -3125.829000                      -272.97100
# 25%                 0.326000                         1.64900
# 50%                11.397000                        16.17550
# 75%                85.328000                        95.46400
# max              8620.690000                      3544.00400
#
#        total_deaths_per_million  ...  female_smokers  male_smokers  \
# count             118612.000000  ...    92982.000000  91640.000000
# mean                 425.215224  ...       10.589447     32.753735
# std                  689.250697  ...       10.502072     13.516804
# min                    0.000000  ...        0.100000      7.700000
# 25%                   12.821000  ...        1.900000     21.600000
# 50%                   87.372000  ...        6.300000     31.400000
# 75%                  569.474000  ...       19.300000     41.300000
# max                 6036.647000  ...       44.000000     78.100000
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# count            60088.000000               108461.000000    128539.000000
# mean                50.841690                    3.028329        73.261597
# std                 31.817719                    2.454281         7.529306
# min                  1.188000                    0.100000        53.280000
# 25%                 20.859000                    1.300000        67.940000
# 50%                 49.839000                    2.400000        74.620000
# 75%                 83.241000                    4.000000        78.740000
# max                100.000000                   13.800000        86.750000
#
#        human_development_index  excess_mortality_cumulative_absolute  \
# count            119499.000000                           4853.000000
# mean                  0.726066                          33380.322975
# std                   0.150019                          92740.602043
# min                   0.394000                         -31959.400000
# 25%                   0.602000                           -145.000000
# 50%                   0.744000                           2689.000000
# 75%                   0.845000                          21843.000000
# max                   0.957000                         870843.400000
#
#        excess_mortality_cumulative  excess_mortality  \
# count                  4853.000000       4853.000000
# mean                      9.232879         16.382940
# std                      17.439163         31.860042
# min                     -27.350000        -95.920000
# 25%                      -0.890000         -0.580000
# 50%                       5.450000          6.920000
# 75%                      13.960000         22.780000
# max                     121.160000        373.940000
#
#        excess_mortality_cumulative_per_million
# count                              4853.000000
# mean                                832.864696
# std                                1242.477816
# min                               -1728.844404
# 25%                                 -39.556289
# 50%                                 380.933928
# 75%                                1397.422664
# max                                6989.098338
#
# [8 rows x 62 columns]

# %%
df.continent.unique()
# Out:
# array(['Asia', nan, 'Europe', 'Africa', 'North America', 'South America',
#        'Oceania'], dtype=object)

# %%
df.loc[df.continent.isna()].location.unique()
# Out:
# array(['Africa', 'Asia', 'Europe', 'European Union', 'High income',
#        'International', 'Low income', 'Lower middle income',
#        'North America', 'Oceania', 'South America', 'Upper middle income',
#        'World'], dtype=object)

# %%
df.loc[df.location=="International"]
# Out:
#        iso_code continent       location        date  total_cases  new_cases  \
# 57932  OWID_INT       NaN  International  2020-02-07         61.0       61.0
# 57933  OWID_INT       NaN  International  2020-02-08         61.0        0.0
# 57934  OWID_INT       NaN  International  2020-02-09         64.0        3.0
# 57935  OWID_INT       NaN  International  2020-02-10        135.0       71.0
# 57936  OWID_INT       NaN  International  2020-02-11        135.0        0.0
# ...         ...       ...            ...         ...          ...        ...
# 58596  OWID_INT       NaN  International  2021-12-02        721.0        0.0
# 58597  OWID_INT       NaN  International  2021-12-03        721.0        0.0
# 58598  OWID_INT       NaN  International  2021-12-04        721.0        0.0
# 58599  OWID_INT       NaN  International  2021-12-05        721.0        0.0
# 58600  OWID_INT       NaN  International  2021-12-06        721.0        0.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 57932                 NaN           NaN         NaN                  NaN  ...
# 57933                 NaN           NaN         NaN                  NaN  ...
# 57934                 NaN           NaN         NaN                  NaN  ...
# 57935                 NaN           NaN         NaN                  NaN  ...
# 57936                 NaN           NaN         NaN                  NaN  ...
# ...                   ...           ...         ...                  ...  ...
# 58596                 0.0          15.0         0.0                  0.0  ...
# 58597                 0.0          15.0         0.0                  0.0  ...
# 58598                 0.0          15.0         0.0                  0.0  ...
# 58599                 0.0          15.0         0.0                  0.0  ...
# 58600                 0.0          15.0         0.0                  0.0  ...
#
#        female_smokers  male_smokers  handwashing_facilities  \
# 57932             NaN           NaN                     NaN
# 57933             NaN           NaN                     NaN
# 57934             NaN           NaN                     NaN
# 57935             NaN           NaN                     NaN
# 57936             NaN           NaN                     NaN
# ...               ...           ...                     ...
# 58596             NaN           NaN                     NaN
# 58597             NaN           NaN                     NaN
# 58598             NaN           NaN                     NaN
# 58599             NaN           NaN                     NaN
# 58600             NaN           NaN                     NaN
#
#        hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 57932                         NaN              NaN                      NaN
# 57933                         NaN              NaN                      NaN
# 57934                         NaN              NaN                      NaN
# 57935                         NaN              NaN                      NaN
# 57936                         NaN              NaN                      NaN
# ...                           ...              ...                      ...
# 58596                         NaN              NaN                      NaN
# 58597                         NaN              NaN                      NaN
# 58598                         NaN              NaN                      NaN
# 58599                         NaN              NaN                      NaN
# 58600                         NaN              NaN                      NaN
#
#        excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 57932                                   NaN                          NaN
# 57933                                   NaN                          NaN
# 57934                                   NaN                          NaN
# 57935                                   NaN                          NaN
# 57936                                   NaN                          NaN
# ...                                     ...                          ...
# 58596                                   NaN                          NaN
# 58597                                   NaN                          NaN
# 58598                                   NaN                          NaN
# 58599                                   NaN                          NaN
# 58600                                   NaN                          NaN
#
#        excess_mortality  excess_mortality_cumulative_per_million
# 57932               NaN                                      NaN
# 57933               NaN                                      NaN
# 57934               NaN                                      NaN
# 57935               NaN                                      NaN
# 57936               NaN                                      NaN
# ...                 ...                                      ...
# 58596               NaN                                      NaN
# 58597               NaN                                      NaN
# 58598               NaN                                      NaN
# 58599               NaN                                      NaN
# 58600               NaN                                      NaN
#
# [669 rows x 67 columns]

# %%
df.location.unique()
# Out:
# array(['Afghanistan', 'Africa', 'Albania', 'Algeria', 'Andorra', 'Angola',
#        'Anguilla', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        'Asia', 'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain',
#        'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin',
#        'Bermuda', 'Bhutan', 'Bolivia', 'Bonaire Sint Eustatius and Saba',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Brunei', 'Bulgaria', 'Burkina Faso',
#        'Burundi', 'Cambodia', 'Cameroon', 'Canada', 'Cape Verde',
#        'Cayman Islands', 'Central African Republic', 'Chad', 'Chile',
#        'China', 'Colombia', 'Comoros', 'Congo', 'Cook Islands',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Curacao',
#        'Cyprus', 'Czechia', 'Democratic Republic of Congo', 'Denmark',
#        'Djibouti', 'Dominica', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Estonia',
#        'Eswatini', 'Ethiopia', 'Europe', 'European Union',
#        'Faeroe Islands', 'Falkland Islands', 'Fiji', 'Finland', 'France',
#        'French Polynesia', 'Gabon', 'Gambia', 'Georgia', 'Germany',
#        'Ghana', 'Gibraltar', 'Greece', 'Greenland', 'Grenada',
#        'Guatemala', 'Guernsey', 'Guinea', 'Guinea-Bissau', 'Guyana',
#        'Haiti', 'High income', 'Honduras', 'Hong Kong', 'Hungary',
#        'Iceland', 'India', 'Indonesia', 'International', 'Iran', 'Iraq',
#        'Ireland', 'Isle of Man', 'Israel', 'Italy', 'Jamaica', 'Japan',
#        'Jersey', 'Jordan', 'Kazakhstan', 'Kenya', 'Kiribati', 'Kosovo',
#        'Kuwait', 'Kyrgyzstan', 'Laos', 'Latvia', 'Lebanon', 'Lesotho',
#        'Liberia', 'Libya', 'Liechtenstein', 'Lithuania', 'Low income',
#        'Lower middle income', 'Luxembourg', 'Macao', 'Madagascar',
#        'Malawi', 'Malaysia', 'Maldives', 'Mali', 'Malta',
#        'Marshall Islands', 'Mauritania', 'Mauritius', 'Mexico',
#        'Micronesia (country)', 'Moldova', 'Monaco', 'Mongolia',
#        'Montenegro', 'Montserrat', 'Morocco', 'Mozambique', 'Myanmar',
#        'Namibia', 'Nauru', 'Nepal', 'Netherlands', 'New Caledonia',
#        'New Zealand', 'Nicaragua', 'Niger', 'Nigeria', 'Niue',
#        'North America', 'North Macedonia', 'Northern Cyprus', 'Norway',
#        'Oceania', 'Oman', 'Pakistan', 'Palau', 'Palestine', 'Panama',
#        'Papua New Guinea', 'Paraguay', 'Peru', 'Philippines', 'Pitcairn',
#        'Poland', 'Portugal', 'Qatar', 'Romania', 'Russia', 'Rwanda',
#        'Saint Helena', 'Saint Kitts and Nevis', 'Saint Lucia',
#        'Saint Vincent and the Grenadines', 'Samoa', 'San Marino',
#        'Sao Tome and Principe', 'Saudi Arabia', 'Senegal', 'Serbia',
#        'Seychelles', 'Sierra Leone', 'Singapore',
#        'Sint Maarten (Dutch part)', 'Slovakia', 'Slovenia',
#        'Solomon Islands', 'Somalia', 'South Africa', 'South America',
#        'South Korea', 'South Sudan', 'Spain', 'Sri Lanka', 'Sudan',
#        'Suriname', 'Sweden', 'Switzerland', 'Syria', 'Taiwan',
#        'Tajikistan', 'Tanzania', 'Thailand', 'Timor', 'Togo', 'Tokelau',
#        'Tonga', 'Trinidad and Tobago', 'Tunisia', 'Turkey',
#        'Turkmenistan', 'Turks and Caicos Islands', 'Tuvalu', 'Uganda',
#        'Ukraine', 'United Arab Emirates', 'United Kingdom',
#        'United States', 'Upper middle income', 'Uruguay', 'Uzbekistan',
#        'Vanuatu', 'Vatican', 'Venezuela', 'Vietnam', 'Wallis and Futuna',
#        'World', 'Yemen', 'Zambia', 'Zimbabwe'], dtype=object)

# %%
df["date"] = pd.to_datetime(df["date"])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 138255 entries, 0 to 138254
# Data columns (total 67 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   iso_code                                    138255 non-null  object
#  1   continent                                   129456 non-null  object
#  2   location                                    138255 non-null  object
#  3   date                                        138255 non-null  datetime64[ns]
#  4   total_cases                                 130585 non-null  float64
#  5   new_cases                                   130580 non-null  float64
#  6   new_cases_smoothed                          129540 non-null  float64
#  7   total_deaths                                119268 non-null  float64
#  8   new_deaths                                  119464 non-null  float64
#  9   new_deaths_smoothed                         129540 non-null  float64
#  10  total_cases_per_million                     129916 non-null  float64
#  11  new_cases_per_million                       129911 non-null  float64
#  12  new_cases_smoothed_per_million              128876 non-null  float64
#  13  total_deaths_per_million                    118612 non-null  float64
#  14  new_deaths_per_million                      118808 non-null  float64
#  15  new_deaths_smoothed_per_million             128876 non-null  float64
#  16  reproduction_rate                           109420 non-null  float64
#  17  icu_patients                                16938 non-null   float64
#  18  icu_patients_per_million                    16938 non-null   float64
#  19  hosp_patients                               19354 non-null   float64
#  20  hosp_patients_per_million                   19354 non-null   float64
#  21  weekly_icu_admissions                       1319 non-null    float64
#  22  weekly_icu_admissions_per_million           1319 non-null    float64
#  23  weekly_hosp_admissions                      2205 non-null    float64
#  24  weekly_hosp_admissions_per_million          2205 non-null    float64
#  25  new_tests                                   58019 non-null   float64
#  26  total_tests                                 58225 non-null   float64
#  27  total_tests_per_thousand                    58225 non-null   float64
#  28  new_tests_per_thousand                      58019 non-null   float64
#  29  new_tests_smoothed                          69872 non-null   float64
#  30  new_tests_smoothed_per_thousand             69872 non-null   float64
#  31  positive_rate                               65779 non-null   float64
#  32  tests_per_case                              65118 non-null   float64
#  33  tests_units                                 71952 non-null   object
#  34  total_vaccinations                          36190 non-null   float64
#  35  people_vaccinated                           34565 non-null   float64
#  36  people_fully_vaccinated                     31607 non-null   float64
#  37  total_boosters                              8831 non-null    float64
#  38  new_vaccinations                            30144 non-null   float64
#  39  new_vaccinations_smoothed                   64490 non-null   float64
#  40  total_vaccinations_per_hundred              36190 non-null   float64
#  41  people_vaccinated_per_hundred               34565 non-null   float64
#  42  people_fully_vaccinated_per_hundred         31607 non-null   float64
#  43  total_boosters_per_hundred                  8831 non-null    float64
#  44  new_vaccinations_smoothed_per_million       64490 non-null   float64
#  45  new_people_vaccinated_smoothed              63244 non-null   float64
#  46  new_people_vaccinated_smoothed_per_hundred  63244 non-null   float64
#  47  stringency_index                            112385 non-null  float64
#  48  population                                  137269 non-null  float64
#  49  population_density                          125142 non-null  float64
#  50  median_age                                  119180 non-null  float64
#  51  aged_65_older                               117864 non-null  float64
#  52  aged_70_older                               118530 non-null  float64
#  53  gdp_per_capita                              119961 non-null  float64
#  54  extreme_poverty                             80149 non-null   float64
#  55  cardiovasc_death_rate                       119376 non-null  float64
#  56  diabetes_prevalence                         123380 non-null  float64
#  57  female_smokers                              92982 non-null   float64
#  58  male_smokers                                91640 non-null   float64
#  59  handwashing_facilities                      60088 non-null   float64
#  60  hospital_beds_per_thousand                  108461 non-null  float64
#  61  life_expectancy                             128539 non-null  float64
#  62  human_development_index                     119499 non-null  float64
#  63  excess_mortality_cumulative_absolute        4853 non-null    float64
#  64  excess_mortality_cumulative                 4853 non-null    float64
#  65  excess_mortality                            4853 non-null    float64
#  66  excess_mortality_cumulative_per_million     4853 non-null    float64
# dtypes: datetime64[ns](1), float64(62), object(4)
# memory usage: 70.7+ MB

# %% [markdown]
# ## 最新日付チェック

# %%
import datetime
#latest_date_str = (df.date.max()-datetime.timedelta(days=1)).strftime("%Y-%m-%d")
latest_date_str = df.date.max().strftime("%Y-%m-%d")
latest_date_str
# Out:
# '2021-12-06'

# %% [markdown]
# ## 全世界のデータのみ

# %%
world_df = df.copy().loc[df.location=="World"]
world_df.tail()
# Out:
#         iso_code continent location       date  total_cases  new_cases  \
# 136388  OWID_WRL       NaN    World 2021-12-02  264215462.0   703785.0
# 136389  OWID_WRL       NaN    World 2021-12-03  264933713.0   718251.0
# 136390  OWID_WRL       NaN    World 2021-12-04  265440690.0   506977.0
# 136391  OWID_WRL       NaN    World 2021-12-05  265864109.0   423419.0
# 136392  OWID_WRL       NaN    World 2021-12-06  266456251.0   592142.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 136388          592886.857     5234682.0      9994.0             7405.286
# 136389          610500.143     5243348.0      8666.0             7690.000
# 136390          618545.714     5248690.0      5342.0             7630.857
# 136391          621048.143     5255859.0      7169.0             7991.143
# 136392          610516.857     5262579.0      6720.0             7841.143
#
#         ...  female_smokers  male_smokers  handwashing_facilities  \
# 136388  ...           6.434        34.635                   60.13
# 136389  ...           6.434        34.635                   60.13
# 136390  ...           6.434        34.635                   60.13
# 136391  ...           6.434        34.635                   60.13
# 136392  ...           6.434        34.635                   60.13
#
#         hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 136388                       2.705            72.58                    0.737
# 136389                       2.705            72.58                    0.737
# 136390                       2.705            72.58                    0.737
# 136391                       2.705            72.58                    0.737
# 136392                       2.705            72.58                    0.737
#
#         excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 136388                                   NaN                          NaN
# 136389                                   NaN                          NaN
# 136390                                   NaN                          NaN
# 136391                                   NaN                          NaN
# 136392                                   NaN                          NaN
#
#         excess_mortality  excess_mortality_cumulative_per_million
# 136388               NaN                                      NaN
# 136389               NaN                                      NaN
# 136390               NaN                                      NaN
# 136391               NaN                                      NaN
# 136392               NaN                                      NaN
#
# [5 rows x 67 columns]

# %% [markdown]
# ### 主要国の定義

# %%
countries = pd.DataFrame([
    ("Japan",""),
    ("United States",""),
    ("Germany",""),
#    ("India",""),
#    ("Indonesia",""),
#    ("Spain",""),
    ("Brazil",""),
    ("France",""),
    ("United Kingdom",""),
    ("Russia",""),
    ("Turkey",""),
#    ("South Africa",""),
#    ("Iran",""),
    ("Poland",""),
#    ("Ecuador",""),
],columns=["country","text_disp_date"])
countries
# Out:
#           country text_disp_date
# 0           Japan
# 1   United States
# 2         Germany
# 3          Brazil
# 4          France
# 5  United Kingdom
# 6          Russia
# 7          Turkey
# 8          Poland

# %%
# 東Asia 主要国
e_asia_c = pd.DataFrame([
    ("Japan",""),
    ("China",""),
    ("Taiwan",""),
    ("South Korea",""),
    ("Indonesia",""),
    ("Philippines",""),
    ("Vietnam",""),
    ("Myanmar",""),
    ("Thailand",""),
],columns=["country","text_disp_date"])
e_asia_c
# Out:
#        country text_disp_date
# 0        Japan
# 1        China
# 2       Taiwan
# 3  South Korea
# 4    Indonesia
# 5  Philippines
# 6      Vietnam
# 7      Myanmar
# 8     Thailand

# %%
c_trans = pd.merge(countries, df, left_on="country", right_on="location",how="inner")
c_trans.head()
# Out:
#   country text_disp_date iso_code continent location       date  total_cases  \
# 0   Japan                     JPN      Asia    Japan 2020-01-22          2.0
# 1   Japan                     JPN      Asia    Japan 2020-01-23          2.0
# 2   Japan                     JPN      Asia    Japan 2020-01-24          2.0
# 3   Japan                     JPN      Asia    Japan 2020-01-25          2.0
# 4   Japan                     JPN      Asia    Japan 2020-01-26          4.0
#
#    new_cases  new_cases_smoothed  total_deaths  ...  female_smokers  \
# 0        NaN                 NaN           NaN  ...            11.2
# 1        0.0                 NaN           NaN  ...            11.2
# 2        0.0                 NaN           NaN  ...            11.2
# 3        0.0                 NaN           NaN  ...            11.2
# 4        2.0                 NaN           NaN  ...            11.2
#
#    male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 0          33.7                     NaN                       13.05
# 1          33.7                     NaN                       13.05
# 2          33.7                     NaN                       13.05
# 3          33.7                     NaN                       13.05
# 4          33.7                     NaN                       13.05
#
#    life_expectancy  human_development_index  \
# 0            84.63                    0.919
# 1            84.63                    0.919
# 2            84.63                    0.919
# 3            84.63                    0.919
# 4            84.63                    0.919
#
#    excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                   NaN                          NaN
# 1                                   NaN                          NaN
# 2                                   NaN                          NaN
# 3                                   NaN                          NaN
# 4                                   NaN                          NaN
#
#    excess_mortality  excess_mortality_cumulative_per_million
# 0               NaN                                      NaN
# 1               NaN                                      NaN
# 2               NaN                                      NaN
# 3               NaN                                      NaN
# 4               NaN                                      NaN
#
# [5 rows x 69 columns]

# %%
c_trans.location.unique()
# Out:
# array(['Japan', 'United States', 'Germany', 'Brazil', 'France',
#        'United Kingdom', 'Russia', 'Turkey', 'Poland'], dtype=object)

# %%
c_trans.loc[c_trans.date==latest_date_str][["country","date","total_deaths","total_deaths_per_million"]].sort_values("total_deaths_per_million",ascending=False)
# Out:
#              country       date  total_deaths  total_deaths_per_million
# 2699          Brazil 2021-12-06      615744.0                  2877.397
# 1369   United States 2021-12-06      789745.0                  2372.212
# 6013          Poland 2021-12-06       85700.0                  2267.376
# 4058  United Kingdom 2021-12-06      146101.0                  2142.020
# 4734          Russia 2021-12-06      276979.0                  1898.260
# 3382          France 2021-12-06      120522.0                  1783.813
# 2049         Germany 2021-12-06      103240.0                  1230.506
# 5370          Turkey 2021-12-06       78017.0                   917.386
# 684            Japan 2021-12-06       18361.0                   145.663

# %%
e_a_trans = pd.merge(e_asia_c, df, left_on="country", right_on="location",how="inner")
e_a_trans
# Out:
#        country text_disp_date iso_code continent  location       date  \
# 0        Japan                     JPN      Asia     Japan 2020-01-22
# 1        Japan                     JPN      Asia     Japan 2020-01-23
# 2        Japan                     JPN      Asia     Japan 2020-01-24
# 3        Japan                     JPN      Asia     Japan 2020-01-25
# 4        Japan                     JPN      Asia     Japan 2020-01-26
# ...        ...            ...      ...       ...       ...        ...
# 6071  Thailand                     THA      Asia  Thailand 2021-12-02
# 6072  Thailand                     THA      Asia  Thailand 2021-12-03
# 6073  Thailand                     THA      Asia  Thailand 2021-12-04
# 6074  Thailand                     THA      Asia  Thailand 2021-12-05
# 6075  Thailand                     THA      Asia  Thailand 2021-12-06
#
#       total_cases  new_cases  new_cases_smoothed  total_deaths  ...  \
# 0             2.0        NaN                 NaN           NaN  ...
# 1             2.0        0.0                 NaN           NaN  ...
# 2             2.0        0.0                 NaN           NaN  ...
# 3             2.0        0.0                 NaN           NaN  ...
# 4             4.0        2.0                 NaN           NaN  ...
# ...           ...        ...                 ...           ...  ...
# 6071    2125729.0     4971.0            4406.143       20847.0  ...
# 6072    2130641.0     4912.0            4240.286       20880.0  ...
# 6073    2136537.0     5896.0            5082.571       20917.0  ...
# 6074    2145241.0     8704.0            5489.714       20966.0  ...
# 6075    2148766.0     3525.0            5314.286       20997.0  ...
#
#       female_smokers  male_smokers  handwashing_facilities  \
# 0               11.2          33.7                     NaN
# 1               11.2          33.7                     NaN
# 2               11.2          33.7                     NaN
# 3               11.2          33.7                     NaN
# 4               11.2          33.7                     NaN
# ...              ...           ...                     ...
# 6071             1.9          38.8                   90.67
# 6072             1.9          38.8                   90.67
# 6073             1.9          38.8                   90.67
# 6074             1.9          38.8                   90.67
# 6075             1.9          38.8                   90.67
#
#       hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                          13.05            84.63                    0.919
# 1                          13.05            84.63                    0.919
# 2                          13.05            84.63                    0.919
# 3                          13.05            84.63                    0.919
# 4                          13.05            84.63                    0.919
# ...                          ...              ...                      ...
# 6071                        2.10            77.15                    0.777
# 6072                        2.10            77.15                    0.777
# 6073                        2.10            77.15                    0.777
# 6074                        2.10            77.15                    0.777
# 6075                        2.10            77.15                    0.777
#
#       excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                      NaN                          NaN
# 1                                      NaN                          NaN
# 2                                      NaN                          NaN
# 3                                      NaN                          NaN
# 4                                      NaN                          NaN
# ...                                    ...                          ...
# 6071                                   NaN                          NaN
# 6072                                   NaN                          NaN
# 6073                                   NaN                          NaN
# 6074                                   NaN                          NaN
# 6075                                   NaN                          NaN
#
#       excess_mortality  excess_mortality_cumulative_per_million
# 0                  NaN                                      NaN
# 1                  NaN                                      NaN
# 2                  NaN                                      NaN
# 3                  NaN                                      NaN
# 4                  NaN                                      NaN
# ...                ...                                      ...
# 6071               NaN                                      NaN
# 6072               NaN                                      NaN
# 6073               NaN                                      NaN
# 6074               NaN                                      NaN
# 6075               NaN                                      NaN
#
# [6076 rows x 69 columns]

# %%
e_a_trans.location.unique()
# Out:
# array(['Japan', 'China', 'Taiwan', 'South Korea', 'Indonesia',
#        'Philippines', 'Vietnam', 'Myanmar', 'Thailand'], dtype=object)

# %% [markdown]
# ## 今日の新規感染者数

# %%
#c_df_latest = df.loc[(df.date==pd.to_datetime(latest_date_str)-datetime.timedelta(days=1)) & (df.iso_code.str.len()==3)]
c_df_latest = df.loc[(df.date==pd.to_datetime(latest_date_str)) & (df.iso_code.str.len()==3)]

c_df_latest
# Out:
#        iso_code      continent     location       date  total_cases  \
# 651         AFG           Asia  Afghanistan 2021-12-06     157499.0
# 1965        ALB         Europe      Albania 2021-12-06     201902.0
# 2616        DZA         Africa      Algeria 2021-12-06     211662.0
# 3261        AND         Europe      Andorra 2021-12-06      18631.0
# 3888        AGO         Africa       Angola 2021-12-06      65259.0
# ...         ...            ...          ...        ...          ...
# 134770      VEN  South America    Venezuela 2021-12-06     434918.0
# 135454      VNM           Asia      Vietnam 2021-12-06    1323683.0
# 136998      YEM           Asia        Yemen 2021-12-06      10034.0
# 137627      ZMB         Africa       Zambia 2021-12-06     210327.0
# 138254      ZWE         Africa     Zimbabwe 2021-12-06     139046.0
#
#         new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 651          54.0              34.143        7316.0         4.0
# 1965        172.0             307.429        3115.0         5.0
# 2616        193.0             188.286        6111.0         8.0
# 3261        621.0             274.143         133.0         1.0
# 3888          0.0              14.857        1735.0         0.0
# ...           ...                 ...           ...         ...
# 134770        0.0             517.429        5193.0         0.0
# 135454    14591.0           14224.714       26483.0       223.0
# 136998        9.0               5.571        1955.0         1.0
# 137627       15.0              25.286        3668.0         1.0
# 138254        0.0             688.571        4710.0         0.0
#
#         new_deaths_smoothed  ...  female_smokers  male_smokers  \
# 651                   1.143  ...             NaN           NaN
# 1965                  3.286  ...             7.1          51.2
# 2616                  6.714  ...             0.7          30.4
# 3261                  0.286  ...            29.0          37.8
# 3888                  0.286  ...             NaN           NaN
# ...                     ...  ...             ...           ...
# 134770                7.000  ...             NaN           NaN
# 135454              204.000  ...             1.0          45.9
# 136998                0.857  ...             7.6          29.2
# 137627                0.143  ...             3.1          24.7
# 138254                0.571  ...             1.6          30.7
#
#         handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 651                     37.746                        0.50            64.83
# 1965                       NaN                        2.89            78.57
# 2616                    83.741                        1.90            76.88
# 3261                       NaN                         NaN            83.73
# 3888                    26.664                         NaN            61.15
# ...                        ...                         ...              ...
# 134770                     NaN                        0.80            72.06
# 135454                  85.847                        2.60            75.40
# 136998                  49.542                        0.70            66.12
# 137627                  13.938                        2.00            63.89
# 138254                  36.791                        1.70            61.49
#
#         human_development_index  excess_mortality_cumulative_absolute  \
# 651                       0.511                                   NaN
# 1965                      0.795                                   NaN
# 2616                      0.748                                   NaN
# 3261                      0.868                                   NaN
# 3888                      0.581                                   NaN
# ...                         ...                                   ...
# 134770                    0.711                                   NaN
# 135454                    0.704                                   NaN
# 136998                    0.470                                   NaN
# 137627                    0.584                                   NaN
# 138254                    0.571                                   NaN
#
#         excess_mortality_cumulative  excess_mortality  \
# 651                             NaN               NaN
# 1965                            NaN               NaN
# 2616                            NaN               NaN
# 3261                            NaN               NaN
# 3888                            NaN               NaN
# ...                             ...               ...
# 134770                          NaN               NaN
# 135454                          NaN               NaN
# 136998                          NaN               NaN
# 137627                          NaN               NaN
# 138254                          NaN               NaN
#
#         excess_mortality_cumulative_per_million
# 651                                         NaN
# 1965                                        NaN
# 2616                                        NaN
# 3261                                        NaN
# 3888                                        NaN
# ...                                         ...
# 134770                                      NaN
# 135454                                      NaN
# 136998                                      NaN
# 137627                                      NaN
# 138254                                      NaN
#
# [193 rows x 67 columns]

# %%
c_df_latest.sum()
# Out:
# iso_code                                   AFGALBDZAANDAGOATGARGARMAUSAUTAZEBHSBHRBGDBRBB...
# continent                                  AsiaEuropeAfricaEuropeAfricaNorth AmericaSouth...
# location                                   AfghanistanAlbaniaAlgeriaAndorraAngolaAntigua ...
# total_cases                                                                      266293526.0
# new_cases                                                                           592138.0
#                                                                  ...
# human_development_index                                                              135.823
# excess_mortality_cumulative_absolute                                                     0.0
# excess_mortality_cumulative                                                              0.0
# excess_mortality                                                                         0.0
# excess_mortality_cumulative_per_million                                                  0.0
# Length: 65, dtype: object

# %% [markdown]
# ## 可視化

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook
#%matplotlib inline
# Out:
# Duplicate key in file PosixPath('/home/masaru/.pyenv/versions/anaconda3-2021.05/lib/python3.8/site-packages/matplotlib/mpl-data/matplotlibrc'), line 250 ('font.family:  Noto Sans CJK JP')

# %%
min_date = pd.to_datetime(datetime.datetime.now()).round("D")- datetime.timedelta(days=90)

# %%
world_df["case_rolling7ave"] = world_df.new_cases.rolling(7).mean()
world_df[["new_cases_smoothed","case_rolling7ave"]]
# Out:
#         new_cases_smoothed  case_rolling7ave
# 135708                 NaN               NaN
# 135709                 NaN               NaN
# 135710                 NaN               NaN
# 135711                 NaN               NaN
# 135712                 NaN               NaN
# ...                    ...               ...
# 136388          592886.857     592886.857143
# 136389          610500.143     610500.142857
# 136390          618545.714     618545.714286
# 136391          621048.143     621048.142857
# 136392          610516.857     610516.857143
#
# [685 rows x 2 columns]

# %%
fig=plt.figure(figsize=(20,12))
plt.subplot(2,2,1) # (rows, columns, panel number)
plt.title("Daily new confirmed COVID-19 cases in the world")
plt.bar(world_df.date,world_df.new_cases,label="New cases")
plt.plot_date(world_df["date"],world_df["new_cases_smoothed"],label="7daysMA", fmt="-", color="orange")
#plt.xticks(rotation=70)
plt.ylabel("people")
plt.grid(axis="y")
plt.legend()

plt.subplot(2,2,2) # (rows, columns, panel number)
plt.title("Daily new confirmed COVID-19 cases in the world(Recent)")
chart_data = world_df[world_df.date >= min_date]
plt.bar(chart_data["date"],chart_data["new_cases"],label="New cases")
plt.plot_date(chart_data["date"],chart_data["new_cases_smoothed"],label="7days MA", fmt="-", color="orange")
#plt.xticks(rotation=70)
plt.grid(axis="y")
plt.legend()

plt.subplot(2,2,3) # (rows, columns, panel number)
plt.title("Daily new deaths in the world")
plt.bar(world_df.date,world_df.new_deaths,label="New deaths")
plt.plot_date(world_df["date"],world_df["new_deaths_smoothed"],label="7days MA", fmt="-", color="orange")
#plt.xticks(rotation=70)
plt.ylabel("people")
plt.grid(axis="y")
plt.legend()

plt.subplot(2,2,4) # (rows, columns, panel number)
plt.title("Daily new deaths in the world(Recent)")
chart_data = world_df[world_df.date >= min_date]
plt.bar(chart_data["date"],chart_data["new_deaths"],label="New deaths")
plt.plot_date(chart_data["date"],chart_data["new_deaths_smoothed"],label="7days MA", fmt="-", color="orange")
#plt.xticks(rotation=70)
plt.grid(axis="y")
plt.legend()

fig.text(0,1,"Latest: {}".format(latest_date_str),ha="left",va="top")
fig.text(0,0
         ,"*Data Source : COVID-19 Dataset by Our World in Data",
        ha="left",va="bottom")

plt.tight_layout()
# Out:
# <div id='8c479dff-e385-402b-b870-1fb4f5e0e2cd'></div>

# %%
fig.savefig("out/covid-owid-global-daily.png")

# %% [markdown]
# ### 国別

# %% [markdown]
# #### 人口100万人当たりの新規感染者数（直近）

# %%
"""
#min_date = pd.to_datetime("2021-05-01")
# 主要国 新規感染者
chart_data = c_trans[c_trans.date >= min_date]
dates = chart_data["date"].unique()
print(len(dates))
print(dates.max())
for i,cr in countries.iterrows():
    c = cr["country"]
    dates = chart_data.loc[chart_data["location"]==c]["date"]
    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else latest_date_str
    print(len(chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"]))
    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"],label=c, fmt="-")
    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_cases_smoothed_per_million"],c
            ,fontsize=8,va="center")
"""
# Out:
# '\n#min_date = pd.to_datetime("2021-05-01")\n# 主要国 新規感染者\nchart_data = c_trans[c_trans.date >= min_date]\ndates = chart_data["date"].unique()\nprint(len(dates))\nprint(dates.max())\nfor i,cr in countries.iterrows():\n    c = cr["country"]\n    dates = chart_data.loc[chart_data["location"]==c]["date"]\n    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else latest_date_str\n    print(len(chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"]))\n    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"],label=c, fmt="-")\n    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_cases_smoothed_per_million"],c\n            ,fontsize=8,va="center")\n'

# %%
"""
fig=plt.figure(figsize=(14,10))
min_date = pd.to_datetime("2021-03-01")
# 主要国 新規感染者
plt.subplot(2,2,1) # (rows, columns, panel number)
plt.title("Daily new confirmed COVID-19 cases\n per million population in major countries\n(rolling 7day ave.)")
plt.grid()
plt.xticks(rotation=70)
chart_data = c_trans[c_trans.date >= min_date]
dates = chart_data["date"].unique()
for i,cr in countries.iterrows():
    c = cr["country"]
    dates = chart_data.loc[chart_data["location"]==c]["date"]
    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else dates.max()
    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"],label=c, fmt="-")
    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_cases_smoothed_per_million"],c
            ,fontsize=8,va="center")
plt.legend(bbox_to_anchor=(0, 1),loc='upper left', fontsize=9)
"""
# Out:
# '\nfig=plt.figure(figsize=(14,10))\nmin_date = pd.to_datetime("2021-03-01")\n# 主要国 新規感染者\nplt.subplot(2,2,1) # (rows, columns, panel number)\nplt.title("Daily new confirmed COVID-19 cases\n per million population in major countries\n(rolling 7day ave.)")\nplt.grid()\nplt.xticks(rotation=70)\nchart_data = c_trans[c_trans.date >= min_date]\ndates = chart_data["date"].unique()\nfor i,cr in countries.iterrows():\n    c = cr["country"]\n    dates = chart_data.loc[chart_data["location"]==c]["date"]\n    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else dates.max()\n    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"],label=c, fmt="-")\n    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_cases_smoothed_per_million"],c\n            ,fontsize=8,va="center")\nplt.legend(bbox_to_anchor=(0, 1),loc=\'upper left\', fontsize=9)\n'

# %%
fig=plt.figure(figsize=(20,14))
# 主要国 新規感染者
plt.subplot(2,2,1) # (rows, columns, panel number)
plt.title("Daily new confirmed COVID-19 cases\n per million population in major countries(7daysMA)")
plt.grid()
plt.xticks(rotation=45)
chart_data = c_trans[c_trans.date >= min_date]
for i,cr in countries.iterrows():
    c = cr["country"]
    dates = chart_data.loc[chart_data["location"]==c]["date"]
    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else dates.max()
    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"],label=c, fmt="-")
    text_y = chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_cases_smoothed_per_million"]
#    print(text_y)
    print(c,text_disp_date,text_y)
#    plt.text(text_disp_date,text_y,c,fontsize=10,va="center")
    plt.text(text_disp_date,text_y,c,va="center")
plt.legend(bbox_to_anchor=(0, 1),loc='upper left')

# 主要国 死者
plt.subplot(2,2,2) # (rows, columns, panel number)
plt.title("Daily new deaths in major countries(7daysMA)")
plt.grid()
plt.xticks(rotation=45)
chart_data = c_trans[c_trans.date >= min_date]
for i,cr in countries.iterrows():
    c = cr["country"]
    dates = chart_data.loc[chart_data["location"]==c]["date"]
    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else dates.max()
    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_deaths_smoothed"],label=c, fmt="-")
    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_deaths_smoothed"],c
            ,va="center")
plt.legend(bbox_to_anchor=(0, 1),loc='upper left')

plt.subplot(2,2,3) # (rows, columns, panel number)
plt.grid()
plt.xticks(rotation=45)
plt.title("Daily new confirmed COVID-19 cases\n per million population in Eastern Asia(7daysMA)")
chart_data = e_a_trans[e_a_trans.date >= min_date]
for i,cr in e_asia_c.iterrows():
    c = cr["country"]
    dates = chart_data.loc[chart_data["location"]==c]["date"]
    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else dates.max()
    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"],label=c, fmt="-")
    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_cases_smoothed_per_million"],c
             ,va="center")
plt.legend(bbox_to_anchor=(0, 1),loc='upper left')

plt.subplot(2,2,4) # (rows, columns, panel number)
plt.grid()
plt.xticks(rotation=45)
plt.title("Daily new deaths in Eastern Asia(7daysMA)")
chart_data = e_a_trans[e_a_trans.date >= min_date]
for i,cr in e_asia_c.iterrows():
    c = cr["country"]
    dates = chart_data.loc[chart_data["location"]==c]["date"]
    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else dates.max()
    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_deaths_smoothed"],label=c, fmt="-")
    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_deaths_smoothed"],c
             ,va="center")
plt.legend(bbox_to_anchor=(0, 1),loc='upper left')

fig.text(0,0.98,"Latest: {}".format(latest_date_str),ha="left",va="top")
fig.text(0,0
         ,"*Data Source : COVID-19 Dataset by Our World in Data",
        ha="left",va="bottom")
fig.tight_layout()
"""
"""
# Out:
# <div id='762bb0ef-5d11-4051-acbb-5b0dd351a7da'></div>
# Japan 2021-12-06 00:00:00 684    0.825
# Name: new_cases_smoothed_per_million, dtype: float64
# United States 2021-12-06 00:00:00 1369    360.178
# Name: new_cases_smoothed_per_million, dtype: float64
# Germany 2021-12-06 00:00:00 2049    620.42
# Name: new_cases_smoothed_per_million, dtype: float64
# Brazil 2021-12-06 00:00:00 2699    41.875
# Name: new_cases_smoothed_per_million, dtype: float64
# France 2021-12-06 00:00:00 3382    613.687
# Name: new_cases_smoothed_per_million, dtype: float64
# United Kingdom 2021-12-06 00:00:00 4058    690.791
# Name: new_cases_smoothed_per_million, dtype: float64
# Russia 2021-12-06 00:00:00 4734    220.5
# Name: new_cases_smoothed_per_million, dtype: float64
# Turkey 2021-12-06 00:00:00 5370    253.281
# Name: new_cases_smoothed_per_million, dtype: float64
# Poland 2021-12-06 00:00:00 6013    618.757
# Name: new_cases_smoothed_per_million, dtype: float64
# '\n'

# %%
fig.savefig("out/covid-owid-countries-daily.png")

# %% [markdown]
# ### 新規感染者数

# %%
fig = plt.figure(figsize=(12,14))

plt.subplot(2,2,1) # (rows, columns, panel number)
plt.title("New confirmed COVID-19 cases worst 50")
plt.yticks(fontsize=9)
plt.xlabel("people")
chart_data = c_df_latest.sort_values("new_cases",ascending=False).head(50).sort_values("new_cases",ascending=True)
plt.barh(chart_data["location"],chart_data["new_cases"],label="new cases a day")
plt.grid(axis="x")
mean = int(c_df_latest.new_cases.mean())
plt.plot([mean,mean],[0,50], 'k--', lw=0.5)
plt.text(mean,50,"Mean:{}".format(mean),ha="center",fontsize=9)
plt.legend()

plt.subplot(2,2,2) # (rows, columns, panel number)
plt.title("New confirmed COVID-19 cases per million worst 50")
plt.yticks(fontsize=9)
plt.xlabel("people")
chart_data = c_df_latest.sort_values("new_cases_per_million",ascending=False).head(50).sort_values("new_cases_per_million",ascending=True)
plt.barh(chart_data["location"],chart_data["new_cases_per_million"],label="new cases a day per million")
plt.grid(axis="x")
mean = int(chart_data.new_cases_per_million.mean())
plt.plot([mean,mean],[0,50], 'k--', lw=0.5)
plt.text(mean,50,"Mean:{}".format(mean),ha="center",fontsize=9)
plt.legend()

fig.text(0,0.98,"Latest: {}".format(latest_date_str),fontsize=9,ha="left",va="top")
fig.text(0,0
         ,"*Data Source : COVID-19 Dataset by Our World in Data",
        fontsize=8,ha="left",va="bottom")

plt.subplot(2,2,3) # (rows, columns, panel number)
plt.title("New deaths worst 50")
plt.yticks(fontsize=9)
plt.xlabel("people")
chart_data = c_df_latest.sort_values("new_deaths",ascending=False).head(50).sort_values("new_deaths",ascending=True)
plt.barh(chart_data["location"],chart_data["new_deaths"],label="new deaths a day")
plt.grid(axis="x")
mean = int(c_df_latest.new_deaths.mean())
plt.plot([mean,mean],[0,50], 'k--', lw=0.5)
plt.text(mean,50,"Mean:{}".format(mean),ha="center",fontsize=9)
plt.legend()

plt.subplot(2,2,4) # (rows, columns, panel number)
plt.title("Total deaths per capita worst 50")
plt.yticks(fontsize=9)
plt.xlabel("%")
chart_data = c_df_latest.copy()
chart_data["total_deaths_per_capita"] = chart_data.total_deaths / chart_data.population * 100
chart_data = chart_data.sort_values("total_deaths_per_capita",ascending=False).head(50).sort_values("total_deaths_per_capita",ascending=True)
plt.barh(chart_data["location"],chart_data["total_deaths_per_capita"],label="total deaths per capita")
plt.grid(axis="x")
mean = round(chart_data.total_deaths_per_capita.mean(),2)
plt.plot([mean,mean],[0,50], 'k--', lw=0.5)
plt.text(mean,50,"Mean:{}".format(mean),ha="center",fontsize=9)
plt.legend()


fig.tight_layout()
# Out:
# <div id='f4819df9-0d88-494e-b7a7-1f7fb2fda0f2'></div>

# %%
fig.savefig("out/covid-owid-global-latest-top.png")

# %%
a_df = df.loc[df.location=="Japan"]
c_df = df.loc[(df.date==pd.to_datetime("2021-07-27")) & (df.iso_code.str.len()==3)]

# %%
a_df.tail(10)
# Out:
#       iso_code continent location       date  total_cases  new_cases  \
# 63518      JPN      Asia    Japan 2021-11-27    1726419.0      120.0
# 63519      JPN      Asia    Japan 2021-11-28    1726479.0       60.0
# 63520      JPN      Asia    Japan 2021-11-29    1726555.0       76.0
# 63521      JPN      Asia    Japan 2021-11-30    1726636.0       81.0
# 63522      JPN      Asia    Japan 2021-12-01    1726751.0      115.0
# 63523      JPN      Asia    Japan 2021-12-02    1726864.0      113.0
# 63524      JPN      Asia    Japan 2021-12-03    1727005.0      141.0
# 63525      JPN      Asia    Japan 2021-12-04    1727125.0      120.0
# 63526      JPN      Asia    Japan 2021-12-05    1727229.0      104.0
# 63527      JPN      Asia    Japan 2021-12-06    1727283.0       54.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 63518             100.571       18354.0         1.0                1.571  ...
# 63519              89.857       18354.0         0.0                1.571  ...
# 63520              94.429       18355.0         1.0                1.429  ...
# 63521              90.714       18357.0         2.0                1.429  ...
# 63522              96.714       18358.0         1.0                1.286  ...
# 63523              96.857       18359.0         1.0                1.143  ...
# 63524             100.857       18360.0         1.0                1.000  ...
# 63525             100.857       18360.0         0.0                0.857  ...
# 63526             107.143       18360.0         0.0                0.857  ...
# 63527             104.000       18361.0         1.0                0.857  ...
#
#        female_smokers  male_smokers  handwashing_facilities  \
# 63518            11.2          33.7                     NaN
# 63519            11.2          33.7                     NaN
# 63520            11.2          33.7                     NaN
# 63521            11.2          33.7                     NaN
# 63522            11.2          33.7                     NaN
# 63523            11.2          33.7                     NaN
# 63524            11.2          33.7                     NaN
# 63525            11.2          33.7                     NaN
# 63526            11.2          33.7                     NaN
# 63527            11.2          33.7                     NaN
#
#        hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 63518                       13.05            84.63                    0.919
# 63519                       13.05            84.63                    0.919
# 63520                       13.05            84.63                    0.919
# 63521                       13.05            84.63                    0.919
# 63522                       13.05            84.63                    0.919
# 63523                       13.05            84.63                    0.919
# 63524                       13.05            84.63                    0.919
# 63525                       13.05            84.63                    0.919
# 63526                       13.05            84.63                    0.919
# 63527                       13.05            84.63                    0.919
#
#        excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 63518                                   NaN                          NaN
# 63519                                   NaN                          NaN
# 63520                                   NaN                          NaN
# 63521                                   NaN                          NaN
# 63522                                   NaN                          NaN
# 63523                                   NaN                          NaN
# 63524                                   NaN                          NaN
# 63525                                   NaN                          NaN
# 63526                                   NaN                          NaN
# 63527                                   NaN                          NaN
#
#        excess_mortality  excess_mortality_cumulative_per_million
# 63518               NaN                                      NaN
# 63519               NaN                                      NaN
# 63520               NaN                                      NaN
# 63521               NaN                                      NaN
# 63522               NaN                                      NaN
# 63523               NaN                                      NaN
# 63524               NaN                                      NaN
# 63525               NaN                                      NaN
# 63526               NaN                                      NaN
# 63527               NaN                                      NaN
#
# [10 rows x 67 columns]

# %%
c_df.sort_values("new_deaths",ascending=False).head(50)
# Out:
#        iso_code      continent        location       date  total_cases  \
# 57799       IDN           Asia       Indonesia 2021-07-27    3239936.0
# 17720       BRA  South America          Brazil 2021-07-27   19749073.0
# 103011      RUS         Europe          Russia 2021-07-27    6094379.0
# 57154       IND           Asia           India 2021-07-27   31484605.0
# 81258       MEX  North America          Mexico 2021-07-27    2771846.0
# 131021      USA  North America   United States 2021-07-27   34694822.0
# 59125       IRN           Asia            Iran 2021-07-27    3758197.0
# 86323       MMR           Asia         Myanmar 2021-07-27     279119.0
# 114387      ZAF         Africa    South Africa 2021-07-27    2391223.0
# 26658       COL  South America        Colombia 2021-07-27    4747775.0
# 10883       BGD           Asia      Bangladesh 2021-07-27    1194752.0
# 5397        ARG  South America       Argentina 2021-07-27    4875927.0
# 76982       MYS           Asia        Malaysia 2021-07-27    1044071.0
# 126414      TUN         Africa         Tunisia 2021-07-27     575002.0
# 130336      GBR         Europe  United Kingdom 2021-07-27    5771732.0
# 123525      THA           Asia        Thailand 2021-07-27     526828.0
# 138122      ZWE         Africa        Zimbabwe 2021-07-27     101711.0
# 98976       PER  South America            Peru 2021-07-27    2106371.0
# 30607       CUB  North America            Cuba 2021-07-27     349055.0
# 99653       PHL           Asia     Philippines 2021-07-27    1562420.0
# 59777       IRQ           Asia            Iraq 2021-07-27    1577013.0
# 15665       BOL  South America         Bolivia 2021-07-27     470024.0
# 50357       GTM  North America       Guatemala 2021-07-27     355223.0
# 54499       HND  North America        Honduras 2021-07-27     291687.0
# 98270       PRY  South America        Paraguay 2021-07-27     450494.0
# 117016      ESP         Europe           Spain 2021-07-27    4368453.0
# 127050      TUR           Asia          Turkey 2021-07-27    5638178.0
# 117696      LKA           Asia       Sri Lanka 2021-07-27     299892.0
# 95616       PAK           Asia        Pakistan 2021-07-27    1015827.0
# 28685       CRI  North America      Costa Rica 2021-07-27     402044.0
# 128982      UKR         Europe         Ukraine 2021-07-27    2327777.0
# 519         AFG           Asia     Afghanistan 2021-07-27     145008.0
# 86956       NAM         Africa         Namibia 2021-07-27     117293.0
# 85703       MOZ         Africa      Mozambique 2021-07-27     113426.0
# 25332       CHL  South America           Chile 2021-07-27    1611090.0
# 44248       FRA         Europe          France 2021-07-27    6089097.0
# 76299       MWI         Africa          Malawi 2021-07-27      49752.0
# 85078       MAR         Africa         Morocco 2021-07-27     588448.0
# 2484        DZA         Africa         Algeria 2021-07-27     165204.0
# 71473       LBY         Africa           Libya 2021-07-27     240309.0
# 62074       ITA         Europe           Italy 2021-07-27    4325046.0
# 137495      ZMB         Africa          Zambia 2021-07-27     192956.0
# 87784       NPL           Asia           Nepal 2021-07-27     685673.0
# 21127       KHM           Asia        Cambodia 2021-07-27      74386.0
# 47143       DEU         Europe         Germany 2021-07-27    3766501.0
# 46463       GEO           Asia         Georgia 2021-07-27     407689.0
# 94965       OMN           Asia            Oman 2021-07-27     295017.0
# 134638      VEN  South America       Venezuela 2021-07-27     301979.0
# 108558      SEN         Africa         Senegal 2021-07-27      58523.0
# 67695       KGZ           Asia      Kyrgyzstan 2021-07-27     159089.0
#
#         new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 57799     45203.0           41411.143       86835.0      2069.0
# 17720     41411.0           47090.857      551835.0      1333.0
# 103011    22486.0           23207.714      152836.0       767.0
# 57154     43654.0           38324.000      422022.0       640.0
# 81258     17408.0           13364.143      239079.0       484.0
# 131021    68736.0           61531.429      611218.0       450.0
# 59125     34951.0           26007.000       89479.0       357.0
# 86323      4964.0            5507.000        7845.0       338.0
# 114387     7733.0           11427.286       70338.0       320.0
# 26658     11426.0           11289.286      119482.0       300.0
# 10883     14925.0            9409.000       19779.0       258.0
# 5397      16757.0           13101.143      104352.0       247.0
# 76982     16117.0           14881.714        8408.0       207.0
# 126414     1608.0            2870.143       18968.0       164.0
# 130336    23401.0           32728.143      129591.0       131.0
# 123525    14150.0           14336.143        4264.0       118.0
# 138122     1767.0            1899.429        3280.0       107.0
# 98976      1366.0            1479.714      196058.0        85.0
# 30607      7903.0            7800.857        2492.0        75.0
# 99653      7024.0            6359.571       27318.0        71.0
# 59777     12185.0            9499.429       18418.0        71.0
# 15665      1601.0             985.571       17716.0        65.0
# 50357      2639.0            2494.429       10176.0        64.0
# 54499      1240.0            1285.857        7713.0        63.0
# 98270       592.0             603.857       14759.0        58.0
# 117016    26399.0           25616.714       81323.0        55.0
# 127050    19761.0           13144.571       51048.0        51.0
# 117696     1711.0            1702.714        4195.0        48.0
# 95616      4119.0            2768.000       23133.0        46.0
# 28685      3436.0            1129.857        4987.0        46.0
# 128982     1227.0            1127.286       55420.0        39.0
# 519         723.0             370.571        6515.0        38.0
# 86956       329.0             550.714        2871.0        37.0
# 85703      1703.0            1631.000        1341.0        34.0
# 25332       745.0            1318.857       35151.0        32.0
# 44248     27128.0           19515.286      111881.0        29.0
# 76299       743.0             724.000        1540.0        27.0
# 85078      6971.0            3718.857        9638.0        27.0
# 2484       1544.0            1345.714        4112.0        25.0
# 71473      3348.0            1944.000        3422.0        24.0
# 62074      4516.0            4566.143      127995.0        24.0
# 137495      640.0             764.857        3316.0        21.0
# 87784      2726.0            2102.857        9758.0        20.0
# 21127       685.0             798.571        1324.0        19.0
# 47143      2060.0            1665.000       91592.0        19.0
# 46463      3666.0            2392.000        5731.0        17.0
# 94965       491.0             853.571        3788.0        17.0
# 134638     1060.0            1159.000        3524.0        15.0
# 108558      642.0             707.143        1300.0        14.0
# 67695       969.0            1068.857        2275.0        14.0
#
#         new_deaths_smoothed  ...  female_smokers  male_smokers  \
# 57799              1519.286  ...             2.8          76.1
# 17720              1093.571  ...            10.1          17.9
# 103011              768.429  ...            23.4          58.3
# 57154               506.000  ...             1.9          20.6
# 81258               324.143  ...             6.9          21.4
# 131021              303.571  ...            19.1          24.6
# 59125               265.000  ...             0.8          21.1
# 86323               325.429  ...             6.3          35.2
# 114387              380.286  ...             8.1          33.2
# 26658               335.857  ...             4.7          13.5
# 10883               207.714  ...             1.0          44.7
# 5397                281.571  ...            16.2          27.7
# 76982               166.714  ...             1.0          42.4
# 126414              163.857  ...             1.1          65.8
# 130336               68.857  ...            20.0          24.7
# 123525              108.857  ...             1.9          38.8
# 138122               76.143  ...             1.6          30.7
# 98976               103.714  ...             4.8           NaN
# 30607                67.571  ...            17.1          53.3
# 99653                67.714  ...             7.8          40.8
# 59777                66.714  ...             NaN           NaN
# 15665                34.429  ...             NaN           NaN
# 50357                35.571  ...             NaN           NaN
# 54499                29.429  ...             2.0           NaN
# 98270                52.143  ...             5.0          21.6
# 117016               25.000  ...            27.4          31.4
# 127050               56.857  ...            14.1          41.1
# 117696               46.429  ...             0.3          27.0
# 95616                35.000  ...             2.8          36.7
# 28685                10.286  ...             6.4          17.4
# 128982               28.429  ...            13.5          47.4
# 519                  35.571  ...             NaN           NaN
# 86956                44.857  ...             9.7          34.2
# 85703                26.143  ...             5.1          29.1
# 25332                83.143  ...            34.2          41.5
# 44248                24.857  ...            30.1          35.6
# 76299                25.286  ...             4.4          24.7
# 85078                21.714  ...             0.8          47.1
# 2484                 19.000  ...             0.7          30.4
# 71473                16.143  ...             NaN           NaN
# 62074                15.857  ...            19.8          27.8
# 137495               25.429  ...             3.1          24.7
# 87784                21.571  ...             9.5          37.8
# 21127                25.000  ...             2.0          33.7
# 47143                24.143  ...            28.2          33.1
# 46463                19.857  ...             5.3          55.5
# 94965                41.429  ...             0.5          15.6
# 134638               18.857  ...             NaN           NaN
# 108558                9.143  ...             0.4          16.6
# 67695                11.286  ...             3.6          50.5
#
#         handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 57799                   64.204                        1.04            71.72
# 17720                      NaN                        2.20            75.88
# 103011                     NaN                        8.05            72.58
# 57154                   59.550                        0.53            69.66
# 81258                   87.847                        1.38            75.05
# 131021                     NaN                        2.77            78.86
# 59125                      NaN                        1.50            76.68
# 86323                   79.287                        0.90            67.13
# 114387                  43.993                        2.32            64.13
# 26658                   65.386                        1.71            77.29
# 10883                   34.808                        0.80            72.59
# 5397                       NaN                        5.00            76.67
# 76982                      NaN                        1.90            76.16
# 126414                  78.687                        2.30            76.70
# 130336                     NaN                        2.54            81.32
# 123525                  90.670                        2.10            77.15
# 138122                  36.791                        1.70            61.49
# 98976                      NaN                        1.60            76.74
# 30607                   85.198                        5.20            78.80
# 99653                   78.463                        1.00            71.23
# 59777                   94.576                        1.40            70.60
# 15665                   25.383                        1.10            71.51
# 50357                   76.665                        0.60            74.30
# 54499                   84.169                        0.70            75.27
# 98270                   79.602                        1.30            74.25
# 117016                     NaN                        2.97            83.56
# 127050                     NaN                        2.81            77.69
# 117696                     NaN                        3.60            76.98
# 95616                   59.607                        0.60            67.27
# 28685                   83.841                        1.13            80.28
# 128982                     NaN                        8.80            72.06
# 519                     37.746                        0.50            64.83
# 86956                   44.600                         NaN            63.71
# 85703                   12.227                        0.70            60.85
# 25332                      NaN                        2.11            80.18
# 44248                      NaN                        5.98            82.66
# 76299                    8.704                        1.30            64.26
# 85078                      NaN                        1.10            76.68
# 2484                    83.741                        1.90            76.88
# 71473                      NaN                        3.70            72.91
# 62074                      NaN                        3.18            83.51
# 137495                  13.938                        2.00            63.89
# 87784                   47.782                        0.30            70.78
# 21127                   66.229                        0.80            69.82
# 47143                      NaN                        8.00            81.33
# 46463                      NaN                        2.60            73.77
# 94965                   97.400                        1.60            77.86
# 134638                     NaN                        0.80            72.06
# 108558                  20.859                         NaN            67.94
# 67695                   89.220                        4.50            71.45
#
#         human_development_index  excess_mortality_cumulative_absolute  \
# 57799                     0.718                                   NaN
# 17720                     0.765                                   NaN
# 103011                    0.824                                   NaN
# 57154                     0.645                                   NaN
# 81258                     0.779                                   NaN
# 131021                    0.926                                   NaN
# 59125                     0.783                                   NaN
# 86323                     0.583                                   NaN
# 114387                    0.709                                   NaN
# 26658                     0.767                                   NaN
# 10883                     0.632                                   NaN
# 5397                      0.845                                   NaN
# 76982                     0.810                                   NaN
# 126414                    0.740                                   NaN
# 130336                    0.932                                   NaN
# 123525                    0.777                                   NaN
# 138122                    0.571                                   NaN
# 98976                     0.777                                   NaN
# 30607                     0.783                                   NaN
# 99653                     0.718                                   NaN
# 59777                     0.674                                   NaN
# 15665                     0.718                                   NaN
# 50357                     0.663                                   NaN
# 54499                     0.634                                   NaN
# 98270                     0.728                                   NaN
# 117016                    0.904                                   NaN
# 127050                    0.820                                   NaN
# 117696                    0.782                                   NaN
# 95616                     0.557                                   NaN
# 28685                     0.810                                   NaN
# 128982                    0.779                                   NaN
# 519                       0.511                                   NaN
# 86956                     0.646                                   NaN
# 85703                     0.456                                   NaN
# 25332                     0.851                                   NaN
# 44248                     0.901                                   NaN
# 76299                     0.483                                   NaN
# 85078                     0.686                                   NaN
# 2484                      0.748                                   NaN
# 71473                     0.724                                   NaN
# 62074                     0.892                                   NaN
# 137495                    0.584                                   NaN
# 87784                     0.602                                   NaN
# 21127                     0.594                                   NaN
# 47143                     0.947                                   NaN
# 46463                     0.812                                   NaN
# 94965                     0.813                                   NaN
# 134638                    0.711                                   NaN
# 108558                    0.512                                   NaN
# 67695                     0.697                                   NaN
#
#         excess_mortality_cumulative  excess_mortality  \
# 57799                           NaN               NaN
# 17720                           NaN               NaN
# 103011                          NaN               NaN
# 57154                           NaN               NaN
# 81258                           NaN               NaN
# 131021                          NaN               NaN
# 59125                           NaN               NaN
# 86323                           NaN               NaN
# 114387                          NaN               NaN
# 26658                           NaN               NaN
# 10883                           NaN               NaN
# 5397                            NaN               NaN
# 76982                           NaN               NaN
# 126414                          NaN               NaN
# 130336                          NaN               NaN
# 123525                          NaN               NaN
# 138122                          NaN               NaN
# 98976                           NaN               NaN
# 30607                           NaN               NaN
# 99653                           NaN               NaN
# 59777                           NaN               NaN
# 15665                           NaN               NaN
# 50357                           NaN               NaN
# 54499                           NaN               NaN
# 98270                           NaN               NaN
# 117016                          NaN               NaN
# 127050                          NaN               NaN
# 117696                          NaN               NaN
# 95616                           NaN               NaN
# 28685                           NaN               NaN
# 128982                          NaN               NaN
# 519                             NaN               NaN
# 86956                           NaN               NaN
# 85703                           NaN               NaN
# 25332                           NaN               NaN
# 44248                           NaN               NaN
# 76299                           NaN               NaN
# 85078                           NaN               NaN
# 2484                            NaN               NaN
# 71473                           NaN               NaN
# 62074                           NaN               NaN
# 137495                          NaN               NaN
# 87784                           NaN               NaN
# 21127                           NaN               NaN
# 47143                           NaN               NaN
# 46463                           NaN               NaN
# 94965                           NaN               NaN
# 134638                          NaN               NaN
# 108558                          NaN               NaN
# 67695                           NaN               NaN
#
#         excess_mortality_cumulative_per_million
# 57799                                       NaN
# 17720                                       NaN
# 103011                                      NaN
# 57154                                       NaN
# 81258                                       NaN
# 131021                                      NaN
# 59125                                       NaN
# 86323                                       NaN
# 114387                                      NaN
# 26658                                       NaN
# 10883                                       NaN
# 5397                                        NaN
# 76982                                       NaN
# 126414                                      NaN
# 130336                                      NaN
# 123525                                      NaN
# 138122                                      NaN
# 98976                                       NaN
# 30607                                       NaN
# 99653                                       NaN
# 59777                                       NaN
# 15665                                       NaN
# 50357                                       NaN
# 54499                                       NaN
# 98270                                       NaN
# 117016                                      NaN
# 127050                                      NaN
# 117696                                      NaN
# 95616                                       NaN
# 28685                                       NaN
# 128982                                      NaN
# 519                                         NaN
# 86956                                       NaN
# 85703                                       NaN
# 25332                                       NaN
# 44248                                       NaN
# 76299                                       NaN
# 85078                                       NaN
# 2484                                        NaN
# 71473                                       NaN
# 62074                                       NaN
# 137495                                      NaN
# 87784                                       NaN
# 21127                                       NaN
# 47143                                       NaN
# 46463                                       NaN
# 94965                                       NaN
# 134638                                      NaN
# 108558                                      NaN
# 67695                                       NaN
#
# [50 rows x 67 columns]

# %%
c_df.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'new_tests', 'total_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'total_boosters',
#        'new_vaccinations', 'new_vaccinations_smoothed',
#        'total_vaccinations_per_hundred', 'people_vaccinated_per_hundred',
#        'people_fully_vaccinated_per_hundred', 'total_boosters_per_hundred',
#        'new_vaccinations_smoothed_per_million',
#        'new_people_vaccinated_smoothed',
#        'new_people_vaccinated_smoothed_per_hundred', 'stringency_index',
#        'population', 'population_density', 'median_age', 'aged_65_older',
#        'aged_70_older', 'gdp_per_capita', 'extreme_poverty',
#        'cardiovasc_death_rate', 'diabetes_prevalence', 'female_smokers',
#        'male_smokers', 'handwashing_facilities', 'hospital_beds_per_thousand',
#        'life_expectancy', 'human_development_index',
#        'excess_mortality_cumulative_absolute', 'excess_mortality_cumulative',
#        'excess_mortality', 'excess_mortality_cumulative_per_million'],
#       dtype='object')
