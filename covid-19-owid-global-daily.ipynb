# %%
import pandas as pd

# %%
df = pd.read_csv("covid-19-data/public/data/owid-covid-data.csv")
df.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1      AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# 0              NaN                597.029                 9.59
# 1              NaN                597.029                 9.59
# 2              NaN                597.029                 9.59
# 3              NaN                597.029                 9.59
# 4              NaN                597.029                 9.59
#
#    female_smokers  male_smokers  handwashing_facilities  \
# 0             NaN           NaN                  37.746
# 1             NaN           NaN                  37.746
# 2             NaN           NaN                  37.746
# 3             NaN           NaN                  37.746
# 4             NaN           NaN                  37.746
#
#    hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                         0.5            64.83                    0.511
# 1                         0.5            64.83                    0.511
# 2                         0.5            64.83                    0.511
# 3                         0.5            64.83                    0.511
# 4                         0.5            64.83                    0.511
#
#    excess_mortality
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
#
# [5 rows x 60 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101547 entries, 0 to 101546
# Data columns (total 60 columns):
#  #   Column                                 Non-Null Count   Dtype
# ---  ------                                 --------------   -----
#  0   iso_code                               101547 non-null  object
#  1   continent                              96797 non-null   object
#  2   location                               101547 non-null  object
#  3   date                                   101547 non-null  object
#  4   total_cases                            97790 non-null   float64
#  5   new_cases                              97787 non-null   float64
#  6   new_cases_smoothed                     96777 non-null   float64
#  7   total_deaths                           87595 non-null   float64
#  8   new_deaths                             87751 non-null   float64
#  9   new_deaths_smoothed                    96777 non-null   float64
#  10  total_cases_per_million                97270 non-null   float64
#  11  new_cases_per_million                  97267 non-null   float64
#  12  new_cases_smoothed_per_million         96262 non-null   float64
#  13  total_deaths_per_million               87088 non-null   float64
#  14  new_deaths_per_million                 87244 non-null   float64
#  15  new_deaths_smoothed_per_million        96262 non-null   float64
#  16  reproduction_rate                      81857 non-null   float64
#  17  icu_patients                           10246 non-null   float64
#  18  icu_patients_per_million               10246 non-null   float64
#  19  hosp_patients                          12725 non-null   float64
#  20  hosp_patients_per_million              12725 non-null   float64
#  21  weekly_icu_admissions                  927 non-null     float64
#  22  weekly_icu_admissions_per_million      927 non-null     float64
#  23  weekly_hosp_admissions                 1589 non-null    float64
#  24  weekly_hosp_admissions_per_million     1589 non-null    float64
#  25  new_tests                              45517 non-null   float64
#  26  total_tests                            45185 non-null   float64
#  27  total_tests_per_thousand               45185 non-null   float64
#  28  new_tests_per_thousand                 45517 non-null   float64
#  29  new_tests_smoothed                     52971 non-null   float64
#  30  new_tests_smoothed_per_thousand        52971 non-null   float64
#  31  positive_rate                          49510 non-null   float64
#  32  tests_per_case                         48912 non-null   float64
#  33  tests_units                            54656 non-null   object
#  34  total_vaccinations                     17578 non-null   float64
#  35  people_vaccinated                      16732 non-null   float64
#  36  people_fully_vaccinated                13857 non-null   float64
#  37  new_vaccinations                       14661 non-null   float64
#  38  new_vaccinations_smoothed              30570 non-null   float64
#  39  total_vaccinations_per_hundred         17578 non-null   float64
#  40  people_vaccinated_per_hundred          16732 non-null   float64
#  41  people_fully_vaccinated_per_hundred    13857 non-null   float64
#  42  new_vaccinations_smoothed_per_million  30570 non-null   float64
#  43  stringency_index                       84814 non-null   float64
#  44  population                             100893 non-null  float64
#  45  population_density                     94328 non-null   float64
#  46  median_age                             90684 non-null   float64
#  47  aged_65_older                          89666 non-null   float64
#  48  aged_70_older                          90183 non-null   float64
#  49  gdp_per_capita                         91040 non-null   float64
#  50  extreme_poverty                        61413 non-null   float64
#  51  cardiovasc_death_rate                  91053 non-null   float64
#  52  diabetes_prevalence                    93417 non-null   float64
#  53  female_smokers                         71200 non-null   float64
#  54  male_smokers                           70161 non-null   float64
#  55  handwashing_facilities                 45753 non-null   float64
#  56  hospital_beds_per_thousand             82924 non-null   float64
#  57  life_expectancy                        96428 non-null   float64
#  58  human_development_index                91192 non-null   float64
#  59  excess_mortality                       3571 non-null    float64
# dtypes: float64(55), object(5)
# memory usage: 46.5+ MB

# %%
df.describe()
# Out:
#         total_cases      new_cases  new_cases_smoothed  total_deaths  \
# count  9.779000e+04   97787.000000        96777.000000  8.759500e+04
# mean   1.098055e+06    6047.154806         6066.990903  2.951140e+04
# std    7.500627e+06   37711.617898        37437.084443  1.761454e+05
# min    1.000000e+00  -74347.000000        -6223.000000  1.000000e+00
# 25%    1.322000e+03       2.000000            7.571000  5.500000e+01
# 50%    1.394950e+04      74.000000           92.857000  4.130000e+02
# 75%    1.492405e+05     818.000000          860.143000  3.951000e+03
# max    1.864600e+08  906017.000000       826388.429000  4.024998e+06
#
#          new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  87751.000000         96777.000000             97270.000000
# mean     146.053458           131.700145             13542.278828
# std      798.882238           743.058376             24716.121529
# min    -1918.000000          -232.143000                 0.001000
# 25%        0.000000             0.000000               266.798750
# 50%        2.000000             1.429000              1871.226500
# 75%       18.000000            14.571000             14265.188750
# max    18060.000000         14735.857000            182165.275000
#
#        new_cases_per_million  new_cases_smoothed_per_million  \
# count           97267.000000                    96262.000000
# mean               76.232376                       76.453779
# std               200.260693                      158.588129
# min             -2153.437000                     -276.825000
# 25%                 0.218000                        1.306000
# 50%                 8.573000                       11.310500
# 75%                70.346500                       78.702000
# max             18293.675000                     4083.500000
#
#        total_deaths_per_million  ...  extreme_poverty  cardiovasc_death_rate  \
# count              87088.000000  ...     61413.000000           91053.000000
# mean                 297.899007  ...        13.416931             258.575024
# std                  535.685841  ...        19.964271             119.064173
# min                    0.001000  ...         0.100000              79.370000
# 25%                    8.148000  ...         0.600000             167.295000
# 50%                   52.997500  ...         2.200000             242.648000
# 75%                  326.336000  ...        21.200000             329.635000
# max                 5881.048000  ...        77.600000             724.417000
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# count         93417.000000    71200.000000  70161.000000
# mean              7.932995       10.566986     32.699704
# std               4.154680       10.466631     13.487777
# min               0.990000        0.100000      7.700000
# 25%               5.310000        1.900000     21.600000
# 50%               7.110000        6.300000     31.400000
# 75%              10.080000       19.300000     41.100000
# max              30.530000       44.000000     78.100000
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# count            45753.000000                82924.000000     96428.000000
# mean                50.822148                    3.027033        73.237631
# std                 31.758375                    2.458177         7.557373
# min                  1.188000                    0.100000        53.280000
# 25%                 19.351000                    1.300000        67.920000
# 50%                 49.839000                    2.400000        74.620000
# 75%                 83.241000                    3.861000        78.740000
# max                100.000000                   13.800000        86.750000
#
#        human_development_index  excess_mortality
# count              91192.00000       3571.000000
# mean                   0.72725         18.251563
# std                    0.15035         35.848993
# min                    0.39400        -95.590000
# 25%                    0.60200          0.450000
# 50%                    0.74800          7.390000
# 75%                    0.84800         23.995000
# max                    0.95700        409.760000
#
# [8 rows x 55 columns]

# %%
df.continent.unique()
# Out:
# array(['Asia', nan, 'Europe', 'Africa', 'North America', 'South America',
#        'Oceania'], dtype=object)

# %%
df.loc[df.continent.isna()].location.unique()
# Out:
# array(['Africa', 'Asia', 'Europe', 'European Union', 'International',
#        'North America', 'Oceania', 'South America', 'World'], dtype=object)

# %%
df.loc[df.location=="International"]
# Out:
#        iso_code continent       location        date  total_cases  new_cases  \
# 43013  OWID_INT       NaN  International  2020-02-07         61.0       61.0
# 43014  OWID_INT       NaN  International  2020-02-08         61.0        0.0
# 43015  OWID_INT       NaN  International  2020-02-09         64.0        3.0
# 43016  OWID_INT       NaN  International  2020-02-10        135.0       71.0
# 43017  OWID_INT       NaN  International  2020-02-11        135.0        0.0
# ...         ...       ...            ...         ...          ...        ...
# 43528  OWID_INT       NaN  International  2021-07-06        721.0        0.0
# 43529  OWID_INT       NaN  International  2021-07-07        721.0        0.0
# 43530  OWID_INT       NaN  International  2021-07-08        721.0        0.0
# 43531  OWID_INT       NaN  International  2021-07-09        721.0        0.0
# 43532  OWID_INT       NaN  International  2021-07-10        721.0        0.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 43013                 NaN           NaN         NaN                  NaN  ...
# 43014                 NaN           NaN         NaN                  NaN  ...
# 43015                 NaN           NaN         NaN                  NaN  ...
# 43016                 NaN           NaN         NaN                  NaN  ...
# 43017                 NaN           NaN         NaN                  NaN  ...
# ...                   ...           ...         ...                  ...  ...
# 43528                 0.0          15.0         0.0                  0.0  ...
# 43529                 0.0          15.0         0.0                  0.0  ...
# 43530                 0.0          15.0         0.0                  0.0  ...
# 43531                 0.0          15.0         0.0                  0.0  ...
# 43532                 0.0          15.0         0.0                  0.0  ...
#
#        extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# 43013              NaN                    NaN                  NaN
# 43014              NaN                    NaN                  NaN
# 43015              NaN                    NaN                  NaN
# 43016              NaN                    NaN                  NaN
# 43017              NaN                    NaN                  NaN
# ...                ...                    ...                  ...
# 43528              NaN                    NaN                  NaN
# 43529              NaN                    NaN                  NaN
# 43530              NaN                    NaN                  NaN
# 43531              NaN                    NaN                  NaN
# 43532              NaN                    NaN                  NaN
#
#        female_smokers  male_smokers  handwashing_facilities  \
# 43013             NaN           NaN                     NaN
# 43014             NaN           NaN                     NaN
# 43015             NaN           NaN                     NaN
# 43016             NaN           NaN                     NaN
# 43017             NaN           NaN                     NaN
# ...               ...           ...                     ...
# 43528             NaN           NaN                     NaN
# 43529             NaN           NaN                     NaN
# 43530             NaN           NaN                     NaN
# 43531             NaN           NaN                     NaN
# 43532             NaN           NaN                     NaN
#
#        hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 43013                         NaN              NaN                      NaN
# 43014                         NaN              NaN                      NaN
# 43015                         NaN              NaN                      NaN
# 43016                         NaN              NaN                      NaN
# 43017                         NaN              NaN                      NaN
# ...                           ...              ...                      ...
# 43528                         NaN              NaN                      NaN
# 43529                         NaN              NaN                      NaN
# 43530                         NaN              NaN                      NaN
# 43531                         NaN              NaN                      NaN
# 43532                         NaN              NaN                      NaN
#
#        excess_mortality
# 43013               NaN
# 43014               NaN
# 43015               NaN
# 43016               NaN
# 43017               NaN
# ...                 ...
# 43528               NaN
# 43529               NaN
# 43530               NaN
# 43531               NaN
# 43532               NaN
#
# [520 rows x 60 columns]

# %%
df.location.unique()
# Out:
# array(['Afghanistan', 'Africa', 'Albania', 'Algeria', 'Andorra', 'Angola',
#        'Anguilla', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        'Asia', 'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain',
#        'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin',
#        'Bermuda', 'Bhutan', 'Bolivia', 'Bonaire Sint Eustatius and Saba',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Brunei', 'Bulgaria', 'Burkina Faso',
#        'Burundi', 'Cambodia', 'Cameroon', 'Canada', 'Cape Verde',
#        'Cayman Islands', 'Central African Republic', 'Chad', 'Chile',
#        'China', 'Colombia', 'Comoros', 'Congo', 'Cook Islands',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Curacao',
#        'Cyprus', 'Czechia', 'Democratic Republic of Congo', 'Denmark',
#        'Djibouti', 'Dominica', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Estonia',
#        'Eswatini', 'Ethiopia', 'Europe', 'European Union',
#        'Faeroe Islands', 'Falkland Islands', 'Fiji', 'Finland', 'France',
#        'French Polynesia', 'Gabon', 'Gambia', 'Georgia', 'Germany',
#        'Ghana', 'Gibraltar', 'Greece', 'Greenland', 'Grenada',
#        'Guatemala', 'Guernsey', 'Guinea', 'Guinea-Bissau', 'Guyana',
#        'Haiti', 'Honduras', 'Hong Kong', 'Hungary', 'Iceland', 'India',
#        'Indonesia', 'International', 'Iran', 'Iraq', 'Ireland',
#        'Isle of Man', 'Israel', 'Italy', 'Jamaica', 'Japan', 'Jersey',
#        'Jordan', 'Kazakhstan', 'Kenya', 'Kiribati', 'Kosovo', 'Kuwait',
#        'Kyrgyzstan', 'Laos', 'Latvia', 'Lebanon', 'Lesotho', 'Liberia',
#        'Libya', 'Liechtenstein', 'Lithuania', 'Luxembourg', 'Macao',
#        'Madagascar', 'Malawi', 'Malaysia', 'Maldives', 'Mali', 'Malta',
#        'Marshall Islands', 'Mauritania', 'Mauritius', 'Mexico',
#        'Micronesia (country)', 'Moldova', 'Monaco', 'Mongolia',
#        'Montenegro', 'Montserrat', 'Morocco', 'Mozambique', 'Myanmar',
#        'Namibia', 'Nauru', 'Nepal', 'Netherlands', 'New Caledonia',
#        'New Zealand', 'Nicaragua', 'Niger', 'Nigeria', 'Niue',
#        'North America', 'North Macedonia', 'Northern Cyprus', 'Norway',
#        'Oceania', 'Oman', 'Pakistan', 'Palestine', 'Panama',
#        'Papua New Guinea', 'Paraguay', 'Peru', 'Philippines', 'Pitcairn',
#        'Poland', 'Portugal', 'Qatar', 'Romania', 'Russia', 'Rwanda',
#        'Saint Helena', 'Saint Kitts and Nevis', 'Saint Lucia',
#        'Saint Vincent and the Grenadines', 'Samoa', 'San Marino',
#        'Sao Tome and Principe', 'Saudi Arabia', 'Senegal', 'Serbia',
#        'Seychelles', 'Sierra Leone', 'Singapore',
#        'Sint Maarten (Dutch part)', 'Slovakia', 'Slovenia',
#        'Solomon Islands', 'Somalia', 'South Africa', 'South America',
#        'South Korea', 'South Sudan', 'Spain', 'Sri Lanka', 'Sudan',
#        'Suriname', 'Sweden', 'Switzerland', 'Syria', 'Taiwan',
#        'Tajikistan', 'Tanzania', 'Thailand', 'Timor', 'Togo', 'Tonga',
#        'Trinidad and Tobago', 'Tunisia', 'Turkey', 'Turkmenistan',
#        'Turks and Caicos Islands', 'Tuvalu', 'Uganda', 'Ukraine',
#        'United Arab Emirates', 'United Kingdom', 'United States',
#        'Uruguay', 'Uzbekistan', 'Vanuatu', 'Vatican', 'Venezuela',
#        'Vietnam', 'Wallis and Futuna', 'World', 'Yemen', 'Zambia',
#        'Zimbabwe'], dtype=object)

# %%
df["date"] = pd.to_datetime(df["date"])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101547 entries, 0 to 101546
# Data columns (total 60 columns):
#  #   Column                                 Non-Null Count   Dtype
# ---  ------                                 --------------   -----
#  0   iso_code                               101547 non-null  object
#  1   continent                              96797 non-null   object
#  2   location                               101547 non-null  object
#  3   date                                   101547 non-null  datetime64[ns]
#  4   total_cases                            97790 non-null   float64
#  5   new_cases                              97787 non-null   float64
#  6   new_cases_smoothed                     96777 non-null   float64
#  7   total_deaths                           87595 non-null   float64
#  8   new_deaths                             87751 non-null   float64
#  9   new_deaths_smoothed                    96777 non-null   float64
#  10  total_cases_per_million                97270 non-null   float64
#  11  new_cases_per_million                  97267 non-null   float64
#  12  new_cases_smoothed_per_million         96262 non-null   float64
#  13  total_deaths_per_million               87088 non-null   float64
#  14  new_deaths_per_million                 87244 non-null   float64
#  15  new_deaths_smoothed_per_million        96262 non-null   float64
#  16  reproduction_rate                      81857 non-null   float64
#  17  icu_patients                           10246 non-null   float64
#  18  icu_patients_per_million               10246 non-null   float64
#  19  hosp_patients                          12725 non-null   float64
#  20  hosp_patients_per_million              12725 non-null   float64
#  21  weekly_icu_admissions                  927 non-null     float64
#  22  weekly_icu_admissions_per_million      927 non-null     float64
#  23  weekly_hosp_admissions                 1589 non-null    float64
#  24  weekly_hosp_admissions_per_million     1589 non-null    float64
#  25  new_tests                              45517 non-null   float64
#  26  total_tests                            45185 non-null   float64
#  27  total_tests_per_thousand               45185 non-null   float64
#  28  new_tests_per_thousand                 45517 non-null   float64
#  29  new_tests_smoothed                     52971 non-null   float64
#  30  new_tests_smoothed_per_thousand        52971 non-null   float64
#  31  positive_rate                          49510 non-null   float64
#  32  tests_per_case                         48912 non-null   float64
#  33  tests_units                            54656 non-null   object
#  34  total_vaccinations                     17578 non-null   float64
#  35  people_vaccinated                      16732 non-null   float64
#  36  people_fully_vaccinated                13857 non-null   float64
#  37  new_vaccinations                       14661 non-null   float64
#  38  new_vaccinations_smoothed              30570 non-null   float64
#  39  total_vaccinations_per_hundred         17578 non-null   float64
#  40  people_vaccinated_per_hundred          16732 non-null   float64
#  41  people_fully_vaccinated_per_hundred    13857 non-null   float64
#  42  new_vaccinations_smoothed_per_million  30570 non-null   float64
#  43  stringency_index                       84814 non-null   float64
#  44  population                             100893 non-null  float64
#  45  population_density                     94328 non-null   float64
#  46  median_age                             90684 non-null   float64
#  47  aged_65_older                          89666 non-null   float64
#  48  aged_70_older                          90183 non-null   float64
#  49  gdp_per_capita                         91040 non-null   float64
#  50  extreme_poverty                        61413 non-null   float64
#  51  cardiovasc_death_rate                  91053 non-null   float64
#  52  diabetes_prevalence                    93417 non-null   float64
#  53  female_smokers                         71200 non-null   float64
#  54  male_smokers                           70161 non-null   float64
#  55  handwashing_facilities                 45753 non-null   float64
#  56  hospital_beds_per_thousand             82924 non-null   float64
#  57  life_expectancy                        96428 non-null   float64
#  58  human_development_index                91192 non-null   float64
#  59  excess_mortality                       3571 non-null    float64
# dtypes: datetime64[ns](1), float64(55), object(4)
# memory usage: 46.5+ MB

# %% [markdown]
# ## 最新日付チェック

# %%
import datetime
#latest_date_str = (df.date.max()-datetime.timedelta(days=1)).strftime("%Y-%m-%d")
latest_date_str = df.date.max().strftime("%Y-%m-%d")
latest_date_str
# Out:
# '2021-07-10'

# %% [markdown]
# ## 全世界のデータのみ

# %%
world_df = df.copy().loc[df.location=="World"]
world_df.tail()
# Out:
#         iso_code continent location       date  total_cases  new_cases  \
# 100127  OWID_WRL       NaN    World 2021-07-06  184612003.0   453745.0
# 100128  OWID_WRL       NaN    World 2021-07-07  185075852.0   463849.0
# 100129  OWID_WRL       NaN    World 2021-07-08  185557387.0   481535.0
# 100130  OWID_WRL       NaN    World 2021-07-09  186060062.0   502675.0
# 100131  OWID_WRL       NaN    World 2021-07-10  186459999.0   399937.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 100127          400293.857     3993160.0      8565.0             7910.143
# 100128          410496.714     4001746.0      8586.0             7828.714
# 100129          416564.714     4010591.0      8845.0             7851.857
# 100130          425069.571     4018993.0      8402.0             7870.143
# 100131          428624.000     4024998.0      6005.0             7750.571
#
#         ...  extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# 100127  ...             10.0                 233.07                 8.51
# 100128  ...             10.0                 233.07                 8.51
# 100129  ...             10.0                 233.07                 8.51
# 100130  ...             10.0                 233.07                 8.51
# 100131  ...             10.0                 233.07                 8.51
#
#         female_smokers  male_smokers  handwashing_facilities  \
# 100127           6.434        34.635                   60.13
# 100128           6.434        34.635                   60.13
# 100129           6.434        34.635                   60.13
# 100130           6.434        34.635                   60.13
# 100131           6.434        34.635                   60.13
#
#         hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 100127                       2.705            72.58                    0.737
# 100128                       2.705            72.58                    0.737
# 100129                       2.705            72.58                    0.737
# 100130                       2.705            72.58                    0.737
# 100131                       2.705            72.58                    0.737
#
#         excess_mortality
# 100127               NaN
# 100128               NaN
# 100129               NaN
# 100130               NaN
# 100131               NaN
#
# [5 rows x 60 columns]

# %% [markdown]
# ### 主要国の定義

# %%
countries = pd.DataFrame([
    ("Japan",""),
    ("United States",""),
    ("India","20210415"),
    ("Spain",""),
    ("Brazil",""),
#    ("Israel",""),
    ("United Kingdom",""),
#    ("France","20210425"),
    ("Russia",""),
    ("Colombia",""),
    ("South Africa",""),
    ("Iran",""),
],columns=["country","text_disp_date"])
countries
# Out:
#           country text_disp_date
# 0           Japan
# 1   United States
# 2           India       20210415
# 3           Spain
# 4          Brazil
# 5  United Kingdom
# 6          Russia
# 7        Colombia
# 8    South Africa
# 9            Iran

# %%
# 東Asia 主要国
e_asia_c = pd.DataFrame([
    ("Japan",""),
    ("China",""),
    ("Taiwan",""),
    ("South Korea","20210420"),
    ("Indonesia",""),
    ("Philippines","20210618"),
    ("Vietnam",""),
],columns=["country","text_disp_date"])
e_asia_c
# Out:
#        country text_disp_date
# 0        Japan
# 1        China
# 2       Taiwan
# 3  South Korea       20210420
# 4    Indonesia
# 5  Philippines       20210618
# 6      Vietnam

# %%
c_trans = pd.merge(countries, df, left_on="country", right_on="location",how="inner")
c_trans.head()
# Out:
#   country text_disp_date iso_code continent location       date  total_cases  \
# 0   Japan                     JPN      Asia    Japan 2020-01-22          2.0
# 1   Japan                     JPN      Asia    Japan 2020-01-23          2.0
# 2   Japan                     JPN      Asia    Japan 2020-01-24          2.0
# 3   Japan                     JPN      Asia    Japan 2020-01-25          2.0
# 4   Japan                     JPN      Asia    Japan 2020-01-26          4.0
#
#    new_cases  new_cases_smoothed  total_deaths  ...  extreme_poverty  \
# 0        NaN                 NaN           NaN  ...              NaN
# 1        0.0                 NaN           NaN  ...              NaN
# 2        0.0                 NaN           NaN  ...              NaN
# 3        0.0                 NaN           NaN  ...              NaN
# 4        2.0                 NaN           NaN  ...              NaN
#
#    cardiovasc_death_rate  diabetes_prevalence  female_smokers  male_smokers  \
# 0                  79.37                 5.72            11.2          33.7
# 1                  79.37                 5.72            11.2          33.7
# 2                  79.37                 5.72            11.2          33.7
# 3                  79.37                 5.72            11.2          33.7
# 4                  79.37                 5.72            11.2          33.7
#
#    handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 0                     NaN                       13.05            84.63
# 1                     NaN                       13.05            84.63
# 2                     NaN                       13.05            84.63
# 3                     NaN                       13.05            84.63
# 4                     NaN                       13.05            84.63
#
#    human_development_index  excess_mortality
# 0                    0.919               NaN
# 1                    0.919               NaN
# 2                    0.919               NaN
# 3                    0.919               NaN
# 4                    0.919               NaN
#
# [5 rows x 62 columns]

# %%
c_trans.location.unique()
# Out:
# array(['Japan', 'United States', 'India', 'Spain', 'Brazil',
#        'United Kingdom', 'Russia', 'Colombia', 'South Africa', 'Iran'],
#       dtype=object)

# %%
c_trans.loc[c_trans.date==latest_date_str][["country","date","total_deaths","total_deaths_per_million"]].sort_values("total_deaths_per_million",ascending=False)
# Out:
#              country       date  total_deaths  total_deaths_per_million
# 2626          Brazil 2021-07-10      532893.0                  2507.031
# 4172        Colombia 2021-07-10      111731.0                  2195.846
# 3153  United Kingdom 2021-07-10      128665.0                  1895.310
# 1071   United States 2021-07-10      607132.0                  1834.221
# 2125           Spain 2021-07-10       81003.0                  1732.507
# 4692    South Africa 2021-07-10       64138.0                  1081.427
# 5200            Iran 2021-07-10       85694.0                  1020.252
# 3680          Russia 2021-07-10      139896.0                   958.622
# 1599           India 2021-07-10      408040.0                   295.680
# 535            Japan 2021-07-10       14896.0                   117.777

# %%
e_a_trans = pd.merge(e_asia_c, df, left_on="country", right_on="location",how="inner")
e_a_trans
# Out:
#       country text_disp_date iso_code continent location       date  \
# 0       Japan                     JPN      Asia    Japan 2020-01-22
# 1       Japan                     JPN      Asia    Japan 2020-01-23
# 2       Japan                     JPN      Asia    Japan 2020-01-24
# 3       Japan                     JPN      Asia    Japan 2020-01-25
# 4       Japan                     JPN      Asia    Japan 2020-01-26
# ...       ...            ...      ...       ...      ...        ...
# 3705  Vietnam                     VNM      Asia  Vietnam 2021-07-06
# 3706  Vietnam                     VNM      Asia  Vietnam 2021-07-07
# 3707  Vietnam                     VNM      Asia  Vietnam 2021-07-08
# 3708  Vietnam                     VNM      Asia  Vietnam 2021-07-09
# 3709  Vietnam                     VNM      Asia  Vietnam 2021-07-10
#
#       total_cases  new_cases  new_cases_smoothed  total_deaths  ...  \
# 0             2.0        NaN                 NaN           NaN  ...
# 1             2.0        0.0                 NaN           NaN  ...
# 2             2.0        0.0                 NaN           NaN  ...
# 3             2.0        0.0                 NaN           NaN  ...
# 4             4.0        2.0                 NaN           NaN  ...
# ...           ...        ...                 ...           ...  ...
# 3705      22341.0     1029.0             833.429          97.0  ...
# 3706      23385.0     1044.0             904.714         102.0  ...
# 3707      24810.0     1425.0            1011.857         104.0  ...
# 3708      26608.0     1798.0            1212.429         110.0  ...
# 3709      28470.0     1862.0            1308.571         112.0  ...
#
#       extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# 0                 NaN                 79.370                 5.72
# 1                 NaN                 79.370                 5.72
# 2                 NaN                 79.370                 5.72
# 3                 NaN                 79.370                 5.72
# 4                 NaN                 79.370                 5.72
# ...               ...                    ...                  ...
# 3705              2.0                245.465                 6.00
# 3706              2.0                245.465                 6.00
# 3707              2.0                245.465                 6.00
# 3708              2.0                245.465                 6.00
# 3709              2.0                245.465                 6.00
#
#       female_smokers  male_smokers  handwashing_facilities  \
# 0               11.2          33.7                     NaN
# 1               11.2          33.7                     NaN
# 2               11.2          33.7                     NaN
# 3               11.2          33.7                     NaN
# 4               11.2          33.7                     NaN
# ...              ...           ...                     ...
# 3705             1.0          45.9                  85.847
# 3706             1.0          45.9                  85.847
# 3707             1.0          45.9                  85.847
# 3708             1.0          45.9                  85.847
# 3709             1.0          45.9                  85.847
#
#       hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                          13.05            84.63                    0.919
# 1                          13.05            84.63                    0.919
# 2                          13.05            84.63                    0.919
# 3                          13.05            84.63                    0.919
# 4                          13.05            84.63                    0.919
# ...                          ...              ...                      ...
# 3705                        2.60            75.40                    0.704
# 3706                        2.60            75.40                    0.704
# 3707                        2.60            75.40                    0.704
# 3708                        2.60            75.40                    0.704
# 3709                        2.60            75.40                    0.704
#
#       excess_mortality
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# ...                ...
# 3705               NaN
# 3706               NaN
# 3707               NaN
# 3708               NaN
# 3709               NaN
#
# [3710 rows x 62 columns]

# %%
e_a_trans.location.unique()
# Out:
# array(['Japan', 'China', 'Taiwan', 'South Korea', 'Indonesia',
#        'Philippines', 'Vietnam'], dtype=object)

# %% [markdown]
# ## 今日の新規感染者数

# %%
c_df_latest = df.loc[(df.date==pd.to_datetime(latest_date_str)-datetime.timedelta(days=1)) & (df.iso_code.str.len()==3)]
c_df_latest
# Out:
#        iso_code      continent     location       date  total_cases  \
# 501         AFG           Asia  Afghanistan 2021-07-09     131586.0
# 1517        ALB         Europe      Albania 2021-07-09     132580.0
# 2019        DZA         Africa      Algeria 2021-07-09     144483.0
# 2515        AND         Europe      Andorra 2021-07-09      14075.0
# 2993        AGO         Africa       Angola 2021-07-09      39791.0
# ...         ...            ...          ...        ...          ...
# 98953       VEN  South America    Venezuela 2021-07-09     282940.0
# 99488       VNM           Asia      Vietnam 2021-07-09      26608.0
# 100587      YEM           Asia        Yemen 2021-07-09       6940.0
# 101067      ZMB         Africa       Zambia 2021-07-09     172405.0
# 101545      ZWE         Africa     Zimbabwe 2021-07-09      65066.0
#
#         new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 501        1473.0            1624.286        5561.0        84.0
# 1517         15.0               7.714        2456.0         0.0
# 2019        831.0             561.857        3811.0        13.0
# 2515         25.0              22.429         127.0         0.0
# 2993        198.0             100.286         928.0         3.0
# ...           ...                 ...           ...         ...
# 98953      1033.0            1105.000        3264.0        11.0
# 99488      1798.0            1212.429         110.0         6.0
# 100587        4.0               2.286        1366.0         1.0
# 101067     1949.0            1684.571        2736.0        64.0
# 101545     2683.0            1771.857        2084.0        55.0
#
#         new_deaths_smoothed  ...  extreme_poverty  cardiovasc_death_rate  \
# 501                  85.571  ...              NaN                597.029
# 1517                  0.000  ...              1.1                304.195
# 2019                 10.857  ...              0.5                278.364
# 2515                  0.000  ...              NaN                109.135
# 2993                  3.143  ...              NaN                276.045
# ...                     ...  ...              ...                    ...
# 98953                15.714  ...              NaN                204.850
# 99488                 3.714  ...              2.0                245.465
# 100587                0.714  ...             18.8                495.003
# 101067               56.429  ...             57.5                234.499
# 101545               34.714  ...             21.4                307.846
#
#         diabetes_prevalence  female_smokers  male_smokers  \
# 501                    9.59             NaN           NaN
# 1517                  10.08             7.1          51.2
# 2019                   6.73             0.7          30.4
# 2515                   7.97            29.0          37.8
# 2993                   3.94             NaN           NaN
# ...                     ...             ...           ...
# 98953                  6.47             NaN           NaN
# 99488                  6.00             1.0          45.9
# 100587                 5.35             7.6          29.2
# 101067                 3.94             3.1          24.7
# 101545                 1.82             1.6          30.7
#
#         handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 501                     37.746                        0.50            64.83
# 1517                       NaN                        2.89            78.57
# 2019                    83.741                        1.90            76.88
# 2515                       NaN                         NaN            83.73
# 2993                    26.664                         NaN            61.15
# ...                        ...                         ...              ...
# 98953                      NaN                        0.80            72.06
# 99488                   85.847                        2.60            75.40
# 100587                  49.542                        0.70            66.12
# 101067                  13.938                        2.00            63.89
# 101545                  36.791                        1.70            61.49
#
#         human_development_index  excess_mortality
# 501                       0.511               NaN
# 1517                      0.795               NaN
# 2019                      0.748               NaN
# 2515                      0.868               NaN
# 2993                      0.581               NaN
# ...                         ...               ...
# 98953                     0.711               NaN
# 99488                     0.704               NaN
# 100587                    0.470               NaN
# 101067                    0.584               NaN
# 101545                    0.571               NaN
#
# [197 rows x 60 columns]

# %% [markdown]
# ## 可視化

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook
#%matplotlib inline

# %%
world_df["case_rolling7ave"] = world_df.new_cases.rolling(7).mean()
world_df[["new_cases_smoothed","case_rolling7ave"]]
# Out:
#         new_cases_smoothed  case_rolling7ave
# 99596                  NaN               NaN
# 99597                  NaN               NaN
# 99598                  NaN               NaN
# 99599                  NaN               NaN
# 99600                  NaN               NaN
# ...                    ...               ...
# 100127          400293.857     400293.857143
# 100128          410496.714     410496.714286
# 100129          416564.714     416564.714286
# 100130          425069.571     425069.571429
# 100131          428624.000     428624.000000
#
# [536 rows x 2 columns]

# %%
fig=plt.figure(figsize=(12,8))
plt.subplot(2,2,1) # (rows, columns, panel number)
plt.title("Daily new confirmed COVID-19 cases in the world")
plt.bar(world_df.date,world_df.new_cases,label="New cases")
plt.plot_date(world_df["date"],world_df["new_cases_smoothed"],label="rolling 7-day average", fmt="-", color="orange")
plt.xticks(rotation=70)
plt.ylabel("people")
plt.grid(axis="y")
plt.legend()

plt.subplot(2,2,2) # (rows, columns, panel number)
plt.title("Daily new confirmed COVID-19 cases in the world(Recent)")
chart_data = world_df[world_df.date >= "2021-04-01"]
plt.bar(chart_data["date"],chart_data["new_cases"],label="New cases")
plt.plot_date(chart_data["date"],chart_data["new_cases_smoothed"],label="rolling 7-day average", fmt="-", color="orange")
plt.xticks(rotation=70)
plt.grid(axis="y")
plt.legend()

plt.subplot(2,2,3) # (rows, columns, panel number)
plt.title("Daily new deaths in the world")
plt.bar(world_df.date,world_df.new_deaths,label="New deaths")
plt.plot_date(world_df["date"],world_df["new_deaths_smoothed"],label="rolling 7-day average", fmt="-", color="orange")
plt.xticks(rotation=70)
plt.ylabel("people")
plt.grid(axis="y")
plt.legend()

plt.subplot(2,2,4) # (rows, columns, panel number)
plt.title("Daily new deaths in the world(Recent)")
chart_data = world_df[world_df.date >= "2021-04-01"]
plt.bar(chart_data["date"],chart_data["new_deaths"],label="New deaths")
plt.plot_date(chart_data["date"],chart_data["new_deaths_smoothed"],label="rolling 7-day average", fmt="-", color="orange")
plt.xticks(rotation=70)
plt.grid(axis="y")
plt.legend()

fig.text(0,1,"Latest: {}".format(latest_date_str),fontsize=8,ha="left",va="top")
fig.text(0,0
         ,"*Data Source : COVID-19 Dataset by Our World in Data",
        fontsize=7,ha="left",va="bottom")

fig.tight_layout()
# Out:
# <div id='100e705b-a1ae-4a1e-b2f3-060d24a4fa7b'></div>

# %%
fig.savefig("out/covid-owid-global-daily.png")

# %% [markdown]
# ### 国別

# %% [markdown]
# #### 人口100万人当たりの新規感染者数（3月以降）

# %%
min_date = pd.to_datetime("2021-03-01")
# 主要国 新規感染者
chart_data = c_trans[c_trans.date >= min_date]
dates = chart_data["date"].unique()
print(len(dates))
print(dates.max())
for i,cr in countries.iterrows():
    c = cr["country"]
    dates = chart_data.loc[chart_data["location"]==c]["date"]
    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else latest_date_str
    print(len(chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"]))
    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"],label=c, fmt="-")
    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_cases_smoothed_per_million"],c
            ,fontsize=8,va="center")
# Out:
# 132
# 2021-07-10T00:00:00.000000000
# 132
# 132
# 132
# 132
# 132
# 132
# 132
# 132
# 132
# 132

# %%
"""
fig=plt.figure(figsize=(14,10))
min_date = pd.to_datetime("2021-03-01")
# 主要国 新規感染者
plt.subplot(2,2,1) # (rows, columns, panel number)
plt.title("Daily new confirmed COVID-19 cases\n per million population in major countries\n(rolling 7day ave.)")
plt.grid()
plt.xticks(rotation=70)
chart_data = c_trans[c_trans.date >= min_date]
dates = chart_data["date"].unique()
for i,cr in countries.iterrows():
    c = cr["country"]
    dates = chart_data.loc[chart_data["location"]==c]["date"]
    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else dates.max()
    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"],label=c, fmt="-")
    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_cases_smoothed_per_million"],c
            ,fontsize=8,va="center")
plt.legend(bbox_to_anchor=(0, 1),loc='upper left', fontsize=9)
"""
# Out:
# '\nfig=plt.figure(figsize=(14,10))\nmin_date = pd.to_datetime("2021-03-01")\n# 主要国 新規感染者\nplt.subplot(2,2,1) # (rows, columns, panel number)\nplt.title("Daily new confirmed COVID-19 cases\n per million population in major countries\n(rolling 7day ave.)")\nplt.grid()\nplt.xticks(rotation=70)\nchart_data = c_trans[c_trans.date >= min_date]\ndates = chart_data["date"].unique()\nfor i,cr in countries.iterrows():\n    c = cr["country"]\n    dates = chart_data.loc[chart_data["location"]==c]["date"]\n    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else dates.max()\n    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"],label=c, fmt="-")\n    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_cases_smoothed_per_million"],c\n            ,fontsize=8,va="center")\nplt.legend(bbox_to_anchor=(0, 1),loc=\'upper left\', fontsize=9)\n'

# %%
min_date = pd.to_datetime("2021-04-01")

# %%
fig=plt.figure(figsize=(14,10))
# 主要国 新規感染者
plt.subplot(2,2,1) # (rows, columns, panel number)
plt.title("Daily new confirmed COVID-19 cases\n per million population in major countries\n(rolling 7day ave.)")
plt.grid()
plt.xticks(rotation=45)
chart_data = c_trans[c_trans.date >= min_date]
for i,cr in countries.iterrows():
    c = cr["country"]
    dates = chart_data.loc[chart_data["location"]==c]["date"]
    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else dates.max()
    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"],label=c, fmt="-")
    text_y = chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_cases_smoothed_per_million"]
#    print(text_y)
    print(c,text_disp_date,text_y)
    plt.text(text_disp_date,text_y,c,fontsize=8,va="center")
plt.legend(bbox_to_anchor=(0, 1),loc='upper left', fontsize=9)

# 主要国 死者
plt.subplot(2,2,2) # (rows, columns, panel number)
plt.title("Daily new deaths in major countries(rolling 7day ave.)")
plt.grid()
plt.xticks(rotation=45)
chart_data = c_trans[c_trans.date >= min_date]
for i,cr in countries.iterrows():
    c = cr["country"]
    dates = chart_data.loc[chart_data["location"]==c]["date"]
    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else dates.max()
    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_deaths_smoothed"],label=c, fmt="-")
    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_deaths_smoothed"],c
            ,fontsize=8,va="center")
plt.legend(bbox_to_anchor=(0, 1),loc='upper left', fontsize=9)

plt.subplot(2,2,3) # (rows, columns, panel number)
plt.grid()
plt.xticks(rotation=45)
plt.title("Daily new confirmed COVID-19 cases\n per million population in Eastern Asia\n(rolling 7day ave.)")
chart_data = e_a_trans[e_a_trans.date >= min_date]
for i,cr in e_asia_c.iterrows():
    c = cr["country"]
    dates = chart_data.loc[chart_data["location"]==c]["date"]
    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else dates.max()
    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"],label=c, fmt="-")
    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_cases_smoothed_per_million"],c
             ,fontsize=8,va="center")
plt.legend(bbox_to_anchor=(0, 1),loc='upper left', fontsize=9)

plt.subplot(2,2,4) # (rows, columns, panel number)
plt.grid()
plt.xticks(rotation=45)
plt.title("Daily new deaths in Eastern Asia(rolling 7day ave.)")
chart_data = e_a_trans[e_a_trans.date >= min_date]
for i,cr in e_asia_c.iterrows():
    c = cr["country"]
    dates = chart_data.loc[chart_data["location"]==c]["date"]
    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else dates.max()
    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_deaths_smoothed"],label=c, fmt="-")
    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_deaths_smoothed"],c
             ,fontsize=8,va="center")
plt.legend(bbox_to_anchor=(0, 1),loc='upper left', fontsize=9)

fig.text(0,0.98,"Latest: {}".format(latest_date_str),fontsize=9,ha="left",va="top")
fig.text(0,0
         ,"*Data Source : COVID-19 Dataset by Our World in Data",
        fontsize=8,ha="left",va="bottom")
fig.tight_layout()
"""
"""
# Out:
# <div id='b7fa8675-b593-4d56-a9d2-72c56f15f1bf'></div>
# Japan 2021-07-10 00:00:00 535    15.085
# Name: new_cases_smoothed_per_million, dtype: float64
# United States 2021-07-10 00:00:00 1071    57.712
# Name: new_cases_smoothed_per_million, dtype: float64
# India 2021-04-15 00:00:00 1513    127.471
# Name: new_cases_smoothed_per_million, dtype: float64
# Spain 2021-07-10 00:00:00 2125    315.702
# Name: new_cases_smoothed_per_million, dtype: float64
# Brazil 2021-07-10 00:00:00 2626    219.756
# Name: new_cases_smoothed_per_million, dtype: float64
# United Kingdom 2021-07-10 00:00:00 3153    445.091
# Name: new_cases_smoothed_per_million, dtype: float64
# Russia 2021-07-10 00:00:00 3680    165.721
# Name: new_cases_smoothed_per_million, dtype: float64
# Colombia 2021-07-10 00:00:00 4172    413.813
# Name: new_cases_smoothed_per_million, dtype: float64
# South Africa 2021-07-10 00:00:00 4692    320.324
# Name: new_cases_smoothed_per_million, dtype: float64
# Iran 2021-07-10 00:00:00 5200    195.168
# Name: new_cases_smoothed_per_million, dtype: float64
# '\n'

# %%
fig.savefig("out/covid-owid-countries-daily.png")

# %% [markdown]
# ### 新規感染者数

# %%
fig = plt.figure(figsize=(12,8))

plt.subplot(1,2,1) # (rows, columns, panel number)
plt.title("New confirmed COVID-19 cases worst 50")
plt.yticks(fontsize=9)
plt.xlabel("people")
chart_data = c_df_latest.sort_values("new_cases",ascending=False).head(50).sort_values("new_cases",ascending=True)
plt.barh(chart_data["location"],chart_data["new_cases"],label="new cases a day")
plt.grid(axis="x")
mean = int(c_df_latest.new_cases.mean())
plt.plot([mean,mean],[0,50], 'k--', lw=0.5)
plt.text(mean,50,"Mean:{}".format(mean),ha="center",fontsize=9)
plt.legend()

plt.subplot(1,2,2) # (rows, columns, panel number)
plt.title("New confirmed COVID-19 cases per million worst 50")
plt.yticks(fontsize=9)
plt.xlabel("people")
chart_data = c_df_latest.sort_values("new_cases_per_million",ascending=False).head(50).sort_values("new_cases_per_million",ascending=True)
plt.barh(chart_data["location"],chart_data["new_cases_per_million"],label="new cases a day per million")
plt.grid(axis="x")
mean = int(chart_data.new_cases_per_million.mean())
plt.plot([mean,mean],[0,50], 'k--', lw=0.5)
plt.text(mean,50,"Mean:{}".format(mean),ha="center",fontsize=9)
plt.legend()

fig.text(0,0.98,"Latest: {}".format(latest_date_str),fontsize=9,ha="left",va="top")
fig.text(0,0
         ,"*Data Source : COVID-19 Dataset by Our World in Data",
        fontsize=8,ha="left",va="bottom")


fig.tight_layout()
# Out:
# <div id='0e820e89-843b-4163-b4d4-842a332383be'></div>

# %%
fig.savefig("out/covid-owid-global-latest-top.png")
