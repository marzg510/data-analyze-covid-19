# %%
import pandas as pd

# %%
df = pd.read_csv("covid-19-data/public/data/owid-covid-data.csv")
df.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1      AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# 0              NaN                597.029                 9.59
# 1              NaN                597.029                 9.59
# 2              NaN                597.029                 9.59
# 3              NaN                597.029                 9.59
# 4              NaN                597.029                 9.59
#
#    female_smokers  male_smokers  handwashing_facilities  \
# 0             NaN           NaN                  37.746
# 1             NaN           NaN                  37.746
# 2             NaN           NaN                  37.746
# 3             NaN           NaN                  37.746
# 4             NaN           NaN                  37.746
#
#    hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                         0.5            64.83                    0.511
# 1                         0.5            64.83                    0.511
# 2                         0.5            64.83                    0.511
# 3                         0.5            64.83                    0.511
# 4                         0.5            64.83                    0.511
#
#    excess_mortality
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
#
# [5 rows x 60 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104125 entries, 0 to 104124
# Data columns (total 60 columns):
#  #   Column                                 Non-Null Count   Dtype
# ---  ------                                 --------------   -----
#  0   iso_code                               104125 non-null  object
#  1   continent                              99276 non-null   object
#  2   location                               104125 non-null  object
#  3   date                                   104125 non-null  object
#  4   total_cases                            100001 non-null  float64
#  5   new_cases                              99998 non-null   float64
#  6   new_cases_smoothed                     98988 non-null   float64
#  7   total_deaths                           89729 non-null   float64
#  8   new_deaths                             89885 non-null   float64
#  9   new_deaths_smoothed                    98988 non-null   float64
#  10  total_cases_per_million                99470 non-null   float64
#  11  new_cases_per_million                  99467 non-null   float64
#  12  new_cases_smoothed_per_million         98462 non-null   float64
#  13  total_deaths_per_million               89211 non-null   float64
#  14  new_deaths_per_million                 89367 non-null   float64
#  15  new_deaths_smoothed_per_million        98462 non-null   float64
#  16  reproduction_rate                      84077 non-null   float64
#  17  icu_patients                           10832 non-null   float64
#  18  icu_patients_per_million               10832 non-null   float64
#  19  hosp_patients                          13093 non-null   float64
#  20  hosp_patients_per_million              13093 non-null   float64
#  21  weekly_icu_admissions                  965 non-null     float64
#  22  weekly_icu_admissions_per_million      965 non-null     float64
#  23  weekly_hosp_admissions                 1786 non-null    float64
#  24  weekly_hosp_admissions_per_million     1786 non-null    float64
#  25  new_tests                              46416 non-null   float64
#  26  total_tests                            46093 non-null   float64
#  27  total_tests_per_thousand               46093 non-null   float64
#  28  new_tests_per_thousand                 46416 non-null   float64
#  29  new_tests_smoothed                     54078 non-null   float64
#  30  new_tests_smoothed_per_thousand        54078 non-null   float64
#  31  positive_rate                          50496 non-null   float64
#  32  tests_per_case                         49866 non-null   float64
#  33  tests_units                            55803 non-null   object
#  34  total_vaccinations                     18879 non-null   float64
#  35  people_vaccinated                      18067 non-null   float64
#  36  people_fully_vaccinated                15145 non-null   float64
#  37  new_vaccinations                       15738 non-null   float64
#  38  new_vaccinations_smoothed              33054 non-null   float64
#  39  total_vaccinations_per_hundred         18879 non-null   float64
#  40  people_vaccinated_per_hundred          18067 non-null   float64
#  41  people_fully_vaccinated_per_hundred    15145 non-null   float64
#  42  new_vaccinations_smoothed_per_million  33054 non-null   float64
#  43  stringency_index                       87265 non-null   float64
#  44  population                             103429 non-null  float64
#  45  population_density                     96658 non-null   float64
#  46  median_age                             92821 non-null   float64
#  47  aged_65_older                          91781 non-null   float64
#  48  aged_70_older                          92309 non-null   float64
#  49  gdp_per_capita                         93203 non-null   float64
#  50  extreme_poverty                        62795 non-null   float64
#  51  cardiovasc_death_rate                  93168 non-null   float64
#  52  diabetes_prevalence                    95670 non-null   float64
#  53  female_smokers                         72849 non-null   float64
#  54  male_smokers                           71788 non-null   float64
#  55  handwashing_facilities                 46798 non-null   float64
#  56  hospital_beds_per_thousand             84837 non-null   float64
#  57  life_expectancy                        98854 non-null   float64
#  58  human_development_index                93293 non-null   float64
#  59  excess_mortality                       3670 non-null    float64
# dtypes: float64(55), object(5)
# memory usage: 47.7+ MB

# %%
df.describe()
# Out:
#         total_cases      new_cases  new_cases_smoothed  total_deaths  \
# count  1.000010e+05   99998.000000        98988.000000  8.972900e+04
# mean   1.139967e+06    6086.420968         6099.647824  3.040129e+04
# std    7.761302e+06   37780.489826        37468.931651  1.814832e+05
# min    1.000000e+00  -74347.000000        -6223.000000  1.000000e+00
# 25%    1.404000e+03       2.000000            7.714000  5.800000e+01
# 50%    1.466900e+04      76.000000           94.143000  4.320000e+02
# 75%    1.564260e+05     832.000000          877.857000  4.176000e+03
# max    1.920051e+08  905993.000000       826368.143000  4.127062e+06
#
#          new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  89885.000000         98988.000000             99470.000000
# mean     146.006319           131.586740             14076.565317
# std      800.362436           741.827495             25457.764617
# min    -1918.000000          -232.143000                 0.001000
# 25%        0.000000             0.000000               277.085750
# 50%        2.000000             1.429000              1972.478500
# 75%       18.000000            14.714000             14899.016250
# max    20808.000000         14736.000000            186099.786000
#
#        new_cases_per_million  new_cases_smoothed_per_million  \
# count           99467.000000                    98462.000000
# mean               76.774420                       76.929485
# std               200.780892                      158.821883
# min             -2153.437000                     -276.825000
# 25%                 0.234000                        1.343000
# 50%                 8.825000                       11.642500
# 75%                71.081000                       79.352250
# max             18293.675000                     4083.500000
#
#        total_deaths_per_million  ...  extreme_poverty  cardiovasc_death_rate  \
# count              89211.000000  ...     62795.000000           93168.000000
# mean                 307.677607  ...        13.426806             258.669093
# std                  549.434080  ...        19.967834             119.085765
# min                    0.001000  ...         0.100000              79.370000
# 25%                    8.497500  ...         0.600000             168.711000
# 50%                   55.712000  ...         2.200000             242.648000
# 75%                  340.583500  ...        21.200000             329.635000
# max                 5921.506000  ...        77.600000             724.417000
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# count         95670.000000    72849.000000  71788.000000
# mean              7.947881       10.579624     32.709926
# std               4.175486       10.479756     13.487619
# min               0.990000        0.100000      7.700000
# 25%               5.310000        1.900000     21.600000
# 50%               7.110000        6.300000     31.400000
# 75%              10.080000       19.300000     41.100000
# max              30.530000       44.000000     78.100000
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# count            46798.000000                84837.000000     98854.000000
# mean                50.809837                    3.027164        73.241390
# std                 31.757653                    2.457259         7.555364
# min                  1.188000                    0.100000        53.280000
# 25%                 19.351000                    1.300000        67.920000
# 50%                 49.839000                    2.400000        74.620000
# 75%                 83.241000                    3.861000        78.740000
# max                100.000000                   13.800000        86.750000
#
#        human_development_index  excess_mortality
# count             93293.000000       3670.000000
# mean                  0.727156         18.134202
# std                   0.150320         35.598736
# min                   0.394000        -95.590000
# 25%                   0.602000          0.432500
# 50%                   0.744000          7.440000
# 75%                   0.848000         23.927500
# max                   0.957000        410.120000
#
# [8 rows x 55 columns]

# %%
df.continent.unique()
# Out:
# array(['Asia', nan, 'Europe', 'Africa', 'North America', 'South America',
#        'Oceania'], dtype=object)

# %%
df.loc[df.continent.isna()].location.unique()
# Out:
# array(['Africa', 'Asia', 'Europe', 'European Union', 'International',
#        'North America', 'Oceania', 'South America', 'World'], dtype=object)

# %%
df.loc[df.location=="International"]
# Out:
#        iso_code continent       location        date  total_cases  new_cases  \
# 44094  OWID_INT       NaN  International  2020-02-07         61.0       61.0
# 44095  OWID_INT       NaN  International  2020-02-08         61.0        0.0
# 44096  OWID_INT       NaN  International  2020-02-09         64.0        3.0
# 44097  OWID_INT       NaN  International  2020-02-10        135.0       71.0
# 44098  OWID_INT       NaN  International  2020-02-11        135.0        0.0
# ...         ...       ...            ...         ...          ...        ...
# 44620  OWID_INT       NaN  International  2021-07-17        721.0        0.0
# 44621  OWID_INT       NaN  International  2021-07-18        721.0        0.0
# 44622  OWID_INT       NaN  International  2021-07-19        721.0        0.0
# 44623  OWID_INT       NaN  International  2021-07-20        721.0        0.0
# 44624  OWID_INT       NaN  International  2021-07-21        721.0        0.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 44094                 NaN           NaN         NaN                  NaN  ...
# 44095                 NaN           NaN         NaN                  NaN  ...
# 44096                 NaN           NaN         NaN                  NaN  ...
# 44097                 NaN           NaN         NaN                  NaN  ...
# 44098                 NaN           NaN         NaN                  NaN  ...
# ...                   ...           ...         ...                  ...  ...
# 44620                 0.0          15.0         0.0                  0.0  ...
# 44621                 0.0          15.0         0.0                  0.0  ...
# 44622                 0.0          15.0         0.0                  0.0  ...
# 44623                 0.0          15.0         0.0                  0.0  ...
# 44624                 0.0          15.0         0.0                  0.0  ...
#
#        extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# 44094              NaN                    NaN                  NaN
# 44095              NaN                    NaN                  NaN
# 44096              NaN                    NaN                  NaN
# 44097              NaN                    NaN                  NaN
# 44098              NaN                    NaN                  NaN
# ...                ...                    ...                  ...
# 44620              NaN                    NaN                  NaN
# 44621              NaN                    NaN                  NaN
# 44622              NaN                    NaN                  NaN
# 44623              NaN                    NaN                  NaN
# 44624              NaN                    NaN                  NaN
#
#        female_smokers  male_smokers  handwashing_facilities  \
# 44094             NaN           NaN                     NaN
# 44095             NaN           NaN                     NaN
# 44096             NaN           NaN                     NaN
# 44097             NaN           NaN                     NaN
# 44098             NaN           NaN                     NaN
# ...               ...           ...                     ...
# 44620             NaN           NaN                     NaN
# 44621             NaN           NaN                     NaN
# 44622             NaN           NaN                     NaN
# 44623             NaN           NaN                     NaN
# 44624             NaN           NaN                     NaN
#
#        hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 44094                         NaN              NaN                      NaN
# 44095                         NaN              NaN                      NaN
# 44096                         NaN              NaN                      NaN
# 44097                         NaN              NaN                      NaN
# 44098                         NaN              NaN                      NaN
# ...                           ...              ...                      ...
# 44620                         NaN              NaN                      NaN
# 44621                         NaN              NaN                      NaN
# 44622                         NaN              NaN                      NaN
# 44623                         NaN              NaN                      NaN
# 44624                         NaN              NaN                      NaN
#
#        excess_mortality
# 44094               NaN
# 44095               NaN
# 44096               NaN
# 44097               NaN
# 44098               NaN
# ...                 ...
# 44620               NaN
# 44621               NaN
# 44622               NaN
# 44623               NaN
# 44624               NaN
#
# [531 rows x 60 columns]

# %%
df.location.unique()
# Out:
# array(['Afghanistan', 'Africa', 'Albania', 'Algeria', 'Andorra', 'Angola',
#        'Anguilla', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        'Asia', 'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain',
#        'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin',
#        'Bermuda', 'Bhutan', 'Bolivia', 'Bonaire Sint Eustatius and Saba',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Brunei', 'Bulgaria', 'Burkina Faso',
#        'Burundi', 'Cambodia', 'Cameroon', 'Canada', 'Cape Verde',
#        'Cayman Islands', 'Central African Republic', 'Chad', 'Chile',
#        'China', 'Colombia', 'Comoros', 'Congo', 'Cook Islands',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Curacao',
#        'Cyprus', 'Czechia', 'Democratic Republic of Congo', 'Denmark',
#        'Djibouti', 'Dominica', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Estonia',
#        'Eswatini', 'Ethiopia', 'Europe', 'European Union',
#        'Faeroe Islands', 'Falkland Islands', 'Fiji', 'Finland', 'France',
#        'French Polynesia', 'Gabon', 'Gambia', 'Georgia', 'Germany',
#        'Ghana', 'Gibraltar', 'Greece', 'Greenland', 'Grenada',
#        'Guatemala', 'Guernsey', 'Guinea', 'Guinea-Bissau', 'Guyana',
#        'Haiti', 'Honduras', 'Hong Kong', 'Hungary', 'Iceland', 'India',
#        'Indonesia', 'International', 'Iran', 'Iraq', 'Ireland',
#        'Isle of Man', 'Israel', 'Italy', 'Jamaica', 'Japan', 'Jersey',
#        'Jordan', 'Kazakhstan', 'Kenya', 'Kiribati', 'Kosovo', 'Kuwait',
#        'Kyrgyzstan', 'Laos', 'Latvia', 'Lebanon', 'Lesotho', 'Liberia',
#        'Libya', 'Liechtenstein', 'Lithuania', 'Luxembourg', 'Macao',
#        'Madagascar', 'Malawi', 'Malaysia', 'Maldives', 'Mali', 'Malta',
#        'Marshall Islands', 'Mauritania', 'Mauritius', 'Mexico',
#        'Micronesia (country)', 'Moldova', 'Monaco', 'Mongolia',
#        'Montenegro', 'Montserrat', 'Morocco', 'Mozambique', 'Myanmar',
#        'Namibia', 'Nauru', 'Nepal', 'Netherlands', 'New Caledonia',
#        'New Zealand', 'Nicaragua', 'Niger', 'Nigeria', 'Niue',
#        'North America', 'North Macedonia', 'Northern Cyprus', 'Norway',
#        'Oceania', 'Oman', 'Pakistan', 'Palestine', 'Panama',
#        'Papua New Guinea', 'Paraguay', 'Peru', 'Philippines', 'Pitcairn',
#        'Poland', 'Portugal', 'Qatar', 'Romania', 'Russia', 'Rwanda',
#        'Saint Helena', 'Saint Kitts and Nevis', 'Saint Lucia',
#        'Saint Vincent and the Grenadines', 'Samoa', 'San Marino',
#        'Sao Tome and Principe', 'Saudi Arabia', 'Senegal', 'Serbia',
#        'Seychelles', 'Sierra Leone', 'Singapore',
#        'Sint Maarten (Dutch part)', 'Slovakia', 'Slovenia',
#        'Solomon Islands', 'Somalia', 'South Africa', 'South America',
#        'South Korea', 'South Sudan', 'Spain', 'Sri Lanka', 'Sudan',
#        'Suriname', 'Sweden', 'Switzerland', 'Syria', 'Taiwan',
#        'Tajikistan', 'Tanzania', 'Thailand', 'Timor', 'Togo', 'Tonga',
#        'Trinidad and Tobago', 'Tunisia', 'Turkey', 'Turkmenistan',
#        'Turks and Caicos Islands', 'Tuvalu', 'Uganda', 'Ukraine',
#        'United Arab Emirates', 'United Kingdom', 'United States',
#        'Uruguay', 'Uzbekistan', 'Vanuatu', 'Vatican', 'Venezuela',
#        'Vietnam', 'Wallis and Futuna', 'World', 'Yemen', 'Zambia',
#        'Zimbabwe'], dtype=object)

# %%
df["date"] = pd.to_datetime(df["date"])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104125 entries, 0 to 104124
# Data columns (total 60 columns):
#  #   Column                                 Non-Null Count   Dtype
# ---  ------                                 --------------   -----
#  0   iso_code                               104125 non-null  object
#  1   continent                              99276 non-null   object
#  2   location                               104125 non-null  object
#  3   date                                   104125 non-null  datetime64[ns]
#  4   total_cases                            100001 non-null  float64
#  5   new_cases                              99998 non-null   float64
#  6   new_cases_smoothed                     98988 non-null   float64
#  7   total_deaths                           89729 non-null   float64
#  8   new_deaths                             89885 non-null   float64
#  9   new_deaths_smoothed                    98988 non-null   float64
#  10  total_cases_per_million                99470 non-null   float64
#  11  new_cases_per_million                  99467 non-null   float64
#  12  new_cases_smoothed_per_million         98462 non-null   float64
#  13  total_deaths_per_million               89211 non-null   float64
#  14  new_deaths_per_million                 89367 non-null   float64
#  15  new_deaths_smoothed_per_million        98462 non-null   float64
#  16  reproduction_rate                      84077 non-null   float64
#  17  icu_patients                           10832 non-null   float64
#  18  icu_patients_per_million               10832 non-null   float64
#  19  hosp_patients                          13093 non-null   float64
#  20  hosp_patients_per_million              13093 non-null   float64
#  21  weekly_icu_admissions                  965 non-null     float64
#  22  weekly_icu_admissions_per_million      965 non-null     float64
#  23  weekly_hosp_admissions                 1786 non-null    float64
#  24  weekly_hosp_admissions_per_million     1786 non-null    float64
#  25  new_tests                              46416 non-null   float64
#  26  total_tests                            46093 non-null   float64
#  27  total_tests_per_thousand               46093 non-null   float64
#  28  new_tests_per_thousand                 46416 non-null   float64
#  29  new_tests_smoothed                     54078 non-null   float64
#  30  new_tests_smoothed_per_thousand        54078 non-null   float64
#  31  positive_rate                          50496 non-null   float64
#  32  tests_per_case                         49866 non-null   float64
#  33  tests_units                            55803 non-null   object
#  34  total_vaccinations                     18879 non-null   float64
#  35  people_vaccinated                      18067 non-null   float64
#  36  people_fully_vaccinated                15145 non-null   float64
#  37  new_vaccinations                       15738 non-null   float64
#  38  new_vaccinations_smoothed              33054 non-null   float64
#  39  total_vaccinations_per_hundred         18879 non-null   float64
#  40  people_vaccinated_per_hundred          18067 non-null   float64
#  41  people_fully_vaccinated_per_hundred    15145 non-null   float64
#  42  new_vaccinations_smoothed_per_million  33054 non-null   float64
#  43  stringency_index                       87265 non-null   float64
#  44  population                             103429 non-null  float64
#  45  population_density                     96658 non-null   float64
#  46  median_age                             92821 non-null   float64
#  47  aged_65_older                          91781 non-null   float64
#  48  aged_70_older                          92309 non-null   float64
#  49  gdp_per_capita                         93203 non-null   float64
#  50  extreme_poverty                        62795 non-null   float64
#  51  cardiovasc_death_rate                  93168 non-null   float64
#  52  diabetes_prevalence                    95670 non-null   float64
#  53  female_smokers                         72849 non-null   float64
#  54  male_smokers                           71788 non-null   float64
#  55  handwashing_facilities                 46798 non-null   float64
#  56  hospital_beds_per_thousand             84837 non-null   float64
#  57  life_expectancy                        98854 non-null   float64
#  58  human_development_index                93293 non-null   float64
#  59  excess_mortality                       3670 non-null    float64
# dtypes: datetime64[ns](1), float64(55), object(4)
# memory usage: 47.7+ MB

# %% [markdown]
# ## 最新日付チェック

# %%
import datetime
#latest_date_str = (df.date.max()-datetime.timedelta(days=1)).strftime("%Y-%m-%d")
latest_date_str = df.date.max().strftime("%Y-%m-%d")
latest_date_str
# Out:
# '2021-07-22'

# %% [markdown]
# ## 全世界のデータのみ

# %%
world_df = df.copy().loc[df.location=="World"]
world_df.tail()
# Out:
#         iso_code continent location       date  total_cases  new_cases  \
# 102672  OWID_WRL       NaN    World 2021-07-17  189998474.0   472636.0
# 102673  OWID_WRL       NaN    World 2021-07-18  190418368.0   419894.0
# 102674  OWID_WRL       NaN    World 2021-07-19  190916061.0   497693.0
# 102675  OWID_WRL       NaN    World 2021-07-20  191445502.0   529441.0
# 102676  OWID_WRL       NaN    World 2021-07-21  192005075.0   559573.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 102672          500828.571     4083633.0      7080.0             8119.571
# 102673          508764.000     4090210.0      6577.0             8024.714
# 102674          517127.714     4097529.0      7319.0             7891.143
# 102675          518452.571     4118337.0     20808.0             9680.143
# 102676          521224.714     4127062.0      8725.0             9676.857
#
#         ...  extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# 102672  ...             10.0                 233.07                 8.51
# 102673  ...             10.0                 233.07                 8.51
# 102674  ...             10.0                 233.07                 8.51
# 102675  ...             10.0                 233.07                 8.51
# 102676  ...             10.0                 233.07                 8.51
#
#         female_smokers  male_smokers  handwashing_facilities  \
# 102672           6.434        34.635                   60.13
# 102673           6.434        34.635                   60.13
# 102674           6.434        34.635                   60.13
# 102675           6.434        34.635                   60.13
# 102676           6.434        34.635                   60.13
#
#         hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 102672                       2.705            72.58                    0.737
# 102673                       2.705            72.58                    0.737
# 102674                       2.705            72.58                    0.737
# 102675                       2.705            72.58                    0.737
# 102676                       2.705            72.58                    0.737
#
#         excess_mortality
# 102672               NaN
# 102673               NaN
# 102674               NaN
# 102675               NaN
# 102676               NaN
#
# [5 rows x 60 columns]

# %% [markdown]
# ### 主要国の定義

# %%
countries = pd.DataFrame([
    ("Japan",""),
    ("United States",""),
    ("India","20210415"),
    ("Spain",""),
    ("Brazil",""),
#    ("Israel",""),
    ("United Kingdom",""),
#    ("France","20210425"),
    ("Russia",""),
    ("Colombia",""),
    ("South Africa",""),
    ("Iran",""),
    ("Ecuador",""),
],columns=["country","text_disp_date"])
countries
# Out:
#            country text_disp_date
# 0            Japan
# 1    United States
# 2            India       20210415
# 3            Spain
# 4           Brazil
# 5   United Kingdom
# 6           Russia
# 7         Colombia
# 8     South Africa
# 9             Iran
# 10         Ecuador

# %%
# 東Asia 主要国
e_asia_c = pd.DataFrame([
    ("Japan",""),
    ("China",""),
    ("Taiwan",""),
    ("South Korea","20210420"),
    ("Indonesia",""),
    ("Philippines","20210618"),
    ("Vietnam",""),
    ("Myanmar",""),
],columns=["country","text_disp_date"])
e_asia_c
# Out:
#        country text_disp_date
# 0        Japan
# 1        China
# 2       Taiwan
# 3  South Korea       20210420
# 4    Indonesia
# 5  Philippines       20210618
# 6      Vietnam
# 7      Myanmar

# %%
c_trans = pd.merge(countries, df, left_on="country", right_on="location",how="inner")
c_trans.head()
# Out:
#   country text_disp_date iso_code continent location       date  total_cases  \
# 0   Japan                     JPN      Asia    Japan 2020-01-22          2.0
# 1   Japan                     JPN      Asia    Japan 2020-01-23          2.0
# 2   Japan                     JPN      Asia    Japan 2020-01-24          2.0
# 3   Japan                     JPN      Asia    Japan 2020-01-25          2.0
# 4   Japan                     JPN      Asia    Japan 2020-01-26          4.0
#
#    new_cases  new_cases_smoothed  total_deaths  ...  extreme_poverty  \
# 0        NaN                 NaN           NaN  ...              NaN
# 1        0.0                 NaN           NaN  ...              NaN
# 2        0.0                 NaN           NaN  ...              NaN
# 3        0.0                 NaN           NaN  ...              NaN
# 4        2.0                 NaN           NaN  ...              NaN
#
#    cardiovasc_death_rate  diabetes_prevalence  female_smokers  male_smokers  \
# 0                  79.37                 5.72            11.2          33.7
# 1                  79.37                 5.72            11.2          33.7
# 2                  79.37                 5.72            11.2          33.7
# 3                  79.37                 5.72            11.2          33.7
# 4                  79.37                 5.72            11.2          33.7
#
#    handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 0                     NaN                       13.05            84.63
# 1                     NaN                       13.05            84.63
# 2                     NaN                       13.05            84.63
# 3                     NaN                       13.05            84.63
# 4                     NaN                       13.05            84.63
#
#    human_development_index  excess_mortality
# 0                    0.919               NaN
# 1                    0.919               NaN
# 2                    0.919               NaN
# 3                    0.919               NaN
# 4                    0.919               NaN
#
# [5 rows x 62 columns]

# %%
c_trans.location.unique()
# Out:
# array(['Japan', 'United States', 'India', 'Spain', 'Brazil',
#        'United Kingdom', 'Russia', 'Colombia', 'South Africa', 'Iran',
#        'Ecuador'], dtype=object)

# %%
c_trans.loc[c_trans.date==latest_date_str][["country","date","total_deaths","total_deaths_per_million"]].sort_values("total_deaths_per_million",ascending=False)
# Out:
# Empty DataFrame
# Columns: [country, date, total_deaths, total_deaths_per_million]
# Index: []

# %%
e_a_trans = pd.merge(e_asia_c, df, left_on="country", right_on="location",how="inner")
e_a_trans
# Out:
#       country text_disp_date iso_code continent location       date  \
# 0       Japan                     JPN      Asia    Japan 2020-01-22
# 1       Japan                     JPN      Asia    Japan 2020-01-23
# 2       Japan                     JPN      Asia    Japan 2020-01-24
# 3       Japan                     JPN      Asia    Japan 2020-01-25
# 4       Japan                     JPN      Asia    Japan 2020-01-26
# ...       ...            ...      ...       ...      ...        ...
# 4264  Myanmar                     MMR      Asia  Myanmar 2021-07-17
# 4265  Myanmar                     MMR      Asia  Myanmar 2021-07-18
# 4266  Myanmar                     MMR      Asia  Myanmar 2021-07-19
# 4267  Myanmar                     MMR      Asia  Myanmar 2021-07-20
# 4268  Myanmar                     MMR      Asia  Myanmar 2021-07-21
#
#       total_cases  new_cases  new_cases_smoothed  total_deaths  ...  \
# 0             2.0        NaN                 NaN           NaN  ...
# 1             2.0        0.0                 NaN           NaN  ...
# 2             2.0        0.0                 NaN           NaN  ...
# 3             2.0        0.0                 NaN           NaN  ...
# 4             4.0        2.0                 NaN           NaN  ...
# ...           ...        ...                 ...           ...  ...
# 4264     224236.0     5497.0            5069.143        4769.0  ...
# 4265     229521.0     5285.0            5329.714        5000.0  ...
# 4266     234710.0     5189.0            5354.714        5281.0  ...
# 4267     240570.0     5860.0            5613.714        5567.0  ...
# 4268     246663.0     6093.0            5472.286        5814.0  ...
#
#       extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# 0                 NaN                 79.370                 5.72
# 1                 NaN                 79.370                 5.72
# 2                 NaN                 79.370                 5.72
# 3                 NaN                 79.370                 5.72
# 4                 NaN                 79.370                 5.72
# ...               ...                    ...                  ...
# 4264              6.4                202.104                 4.61
# 4265              6.4                202.104                 4.61
# 4266              6.4                202.104                 4.61
# 4267              6.4                202.104                 4.61
# 4268              6.4                202.104                 4.61
#
#       female_smokers  male_smokers  handwashing_facilities  \
# 0               11.2          33.7                     NaN
# 1               11.2          33.7                     NaN
# 2               11.2          33.7                     NaN
# 3               11.2          33.7                     NaN
# 4               11.2          33.7                     NaN
# ...              ...           ...                     ...
# 4264             6.3          35.2                  79.287
# 4265             6.3          35.2                  79.287
# 4266             6.3          35.2                  79.287
# 4267             6.3          35.2                  79.287
# 4268             6.3          35.2                  79.287
#
#       hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                          13.05            84.63                    0.919
# 1                          13.05            84.63                    0.919
# 2                          13.05            84.63                    0.919
# 3                          13.05            84.63                    0.919
# 4                          13.05            84.63                    0.919
# ...                          ...              ...                      ...
# 4264                        0.90            67.13                    0.583
# 4265                        0.90            67.13                    0.583
# 4266                        0.90            67.13                    0.583
# 4267                        0.90            67.13                    0.583
# 4268                        0.90            67.13                    0.583
#
#       excess_mortality
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# ...                ...
# 4264               NaN
# 4265               NaN
# 4266               NaN
# 4267               NaN
# 4268               NaN
#
# [4269 rows x 62 columns]

# %%
e_a_trans.location.unique()
# Out:
# array(['Japan', 'China', 'Taiwan', 'South Korea', 'Indonesia',
#        'Philippines', 'Vietnam', 'Myanmar'], dtype=object)

# %% [markdown]
# ## 今日の新規感染者数

# %%
#c_df_latest = df.loc[(df.date==pd.to_datetime(latest_date_str)-datetime.timedelta(days=1)) & (df.iso_code.str.len()==3)]
c_df_latest = df.loc[(df.date==pd.to_datetime(latest_date_str)) & (df.iso_code.str.len()==3)]

c_df_latest
# Out:
#       iso_code continent location       date  total_cases  new_cases  \
# 46867      ISR      Asia   Israel 2021-07-22          NaN        NaN
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 46867                 NaN           NaN         NaN                  NaN  ...
#
#        extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# 46867              0.5                  93.32                 6.74
#
#        female_smokers  male_smokers  handwashing_facilities  \
# 46867            15.4          35.4                     NaN
#
#        hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 46867                        2.99            82.97                    0.919
#
#        excess_mortality
# 46867               NaN
#
# [1 rows x 60 columns]

# %%
c_df_latest.sum()
# Out:
# iso_code                                       ISR
# continent                                     Asia
# location                                    Israel
# total_cases                                    0.0
# new_cases                                      0.0
# new_cases_smoothed                             0.0
# total_deaths                                   0.0
# new_deaths                                     0.0
# new_deaths_smoothed                            0.0
# total_cases_per_million                        0.0
# new_cases_per_million                          0.0
# new_cases_smoothed_per_million                 0.0
# total_deaths_per_million                       0.0
# new_deaths_per_million                         0.0
# new_deaths_smoothed_per_million                0.0
# reproduction_rate                              0.0
# icu_patients                                  19.0
# icu_patients_per_million                     2.195
# hosp_patients                                145.0
# hosp_patients_per_million                   16.752
# weekly_icu_admissions                          0.0
# weekly_icu_admissions_per_million              0.0
# weekly_hosp_admissions                         0.0
# weekly_hosp_admissions_per_million             0.0
# new_tests                                      0.0
# total_tests                                    0.0
# total_tests_per_thousand                       0.0
# new_tests_per_thousand                         0.0
# new_tests_smoothed                             0.0
# new_tests_smoothed_per_thousand                0.0
# positive_rate                                  0.0
# tests_per_case                                 0.0
# tests_units                                      0
# total_vaccinations                             0.0
# people_vaccinated                              0.0
# people_fully_vaccinated                        0.0
# new_vaccinations                               0.0
# new_vaccinations_smoothed                      0.0
# total_vaccinations_per_hundred                 0.0
# people_vaccinated_per_hundred                  0.0
# people_fully_vaccinated_per_hundred            0.0
# new_vaccinations_smoothed_per_million          0.0
# stringency_index                               0.0
# population                               8655541.0
# population_density                         402.606
# median_age                                    30.6
# aged_65_older                               11.733
# aged_70_older                                7.359
# gdp_per_capita                            33132.32
# extreme_poverty                                0.5
# cardiovasc_death_rate                        93.32
# diabetes_prevalence                           6.74
# female_smokers                                15.4
# male_smokers                                  35.4
# handwashing_facilities                         0.0
# hospital_beds_per_thousand                    2.99
# life_expectancy                              82.97
# human_development_index                      0.919
# excess_mortality                               0.0
# dtype: object

# %% [markdown]
# ## 可視化

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook
#%matplotlib inline

# %%
world_df["case_rolling7ave"] = world_df.new_cases.rolling(7).mean()
world_df[["new_cases_smoothed","case_rolling7ave"]]
# Out:
#         new_cases_smoothed  case_rolling7ave
# 102130                 NaN               NaN
# 102131                 NaN               NaN
# 102132                 NaN               NaN
# 102133                 NaN               NaN
# 102134                 NaN               NaN
# ...                    ...               ...
# 102672          500828.571     500828.571429
# 102673          508764.000     508764.000000
# 102674          517127.714     517127.714286
# 102675          518452.571     518452.571429
# 102676          521224.714     521224.714286
#
# [547 rows x 2 columns]

# %%
fig=plt.figure(figsize=(12,8))
plt.subplot(2,2,1) # (rows, columns, panel number)
plt.title("Daily new confirmed COVID-19 cases in the world")
plt.bar(world_df.date,world_df.new_cases,label="New cases")
plt.plot_date(world_df["date"],world_df["new_cases_smoothed"],label="rolling 7-day average", fmt="-", color="orange")
plt.xticks(rotation=70)
plt.ylabel("people")
plt.grid(axis="y")
plt.legend()

plt.subplot(2,2,2) # (rows, columns, panel number)
plt.title("Daily new confirmed COVID-19 cases in the world(Recent)")
chart_data = world_df[world_df.date >= "2021-04-01"]
plt.bar(chart_data["date"],chart_data["new_cases"],label="New cases")
plt.plot_date(chart_data["date"],chart_data["new_cases_smoothed"],label="rolling 7-day average", fmt="-", color="orange")
plt.xticks(rotation=70)
plt.grid(axis="y")
plt.legend()

plt.subplot(2,2,3) # (rows, columns, panel number)
plt.title("Daily new deaths in the world")
plt.bar(world_df.date,world_df.new_deaths,label="New deaths")
plt.plot_date(world_df["date"],world_df["new_deaths_smoothed"],label="rolling 7-day average", fmt="-", color="orange")
plt.xticks(rotation=70)
plt.ylabel("people")
plt.grid(axis="y")
plt.legend()

plt.subplot(2,2,4) # (rows, columns, panel number)
plt.title("Daily new deaths in the world(Recent)")
chart_data = world_df[world_df.date >= "2021-04-01"]
plt.bar(chart_data["date"],chart_data["new_deaths"],label="New deaths")
plt.plot_date(chart_data["date"],chart_data["new_deaths_smoothed"],label="rolling 7-day average", fmt="-", color="orange")
plt.xticks(rotation=70)
plt.grid(axis="y")
plt.legend()

fig.text(0,1,"Latest: {}".format(latest_date_str),fontsize=8,ha="left",va="top")
fig.text(0,0
         ,"*Data Source : COVID-19 Dataset by Our World in Data",
        fontsize=7,ha="left",va="bottom")

fig.tight_layout()
# Out:
# <div id='bac7427b-9e7c-4f3a-b1ed-4fb300ab5a7d'></div>

# %%
fig.savefig("out/covid-owid-global-daily.png")

# %% [markdown]
# ### 国別

# %% [markdown]
# #### 人口100万人当たりの新規感染者数（3月以降）

# %%
min_date = pd.to_datetime("2021-03-01")
# 主要国 新規感染者
chart_data = c_trans[c_trans.date >= min_date]
dates = chart_data["date"].unique()
print(len(dates))
print(dates.max())
for i,cr in countries.iterrows():
    c = cr["country"]
    dates = chart_data.loc[chart_data["location"]==c]["date"]
    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else latest_date_str
    print(len(chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"]))
    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"],label=c, fmt="-")
    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_cases_smoothed_per_million"],c
            ,fontsize=8,va="center")
# Out:
# 143
# 2021-07-21T00:00:00.000000000
# 143
# 143
# 143
# 143
# 143
# 143
# 143
# 143
# 143
# 143
# 143

# %%
"""
fig=plt.figure(figsize=(14,10))
min_date = pd.to_datetime("2021-03-01")
# 主要国 新規感染者
plt.subplot(2,2,1) # (rows, columns, panel number)
plt.title("Daily new confirmed COVID-19 cases\n per million population in major countries\n(rolling 7day ave.)")
plt.grid()
plt.xticks(rotation=70)
chart_data = c_trans[c_trans.date >= min_date]
dates = chart_data["date"].unique()
for i,cr in countries.iterrows():
    c = cr["country"]
    dates = chart_data.loc[chart_data["location"]==c]["date"]
    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else dates.max()
    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"],label=c, fmt="-")
    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_cases_smoothed_per_million"],c
            ,fontsize=8,va="center")
plt.legend(bbox_to_anchor=(0, 1),loc='upper left', fontsize=9)
"""
# Out:
# '\nfig=plt.figure(figsize=(14,10))\nmin_date = pd.to_datetime("2021-03-01")\n# 主要国 新規感染者\nplt.subplot(2,2,1) # (rows, columns, panel number)\nplt.title("Daily new confirmed COVID-19 cases\n per million population in major countries\n(rolling 7day ave.)")\nplt.grid()\nplt.xticks(rotation=70)\nchart_data = c_trans[c_trans.date >= min_date]\ndates = chart_data["date"].unique()\nfor i,cr in countries.iterrows():\n    c = cr["country"]\n    dates = chart_data.loc[chart_data["location"]==c]["date"]\n    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else dates.max()\n    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"],label=c, fmt="-")\n    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_cases_smoothed_per_million"],c\n            ,fontsize=8,va="center")\nplt.legend(bbox_to_anchor=(0, 1),loc=\'upper left\', fontsize=9)\n'

# %%
min_date = pd.to_datetime("2021-04-01")

# %%
fig=plt.figure(figsize=(14,10))
# 主要国 新規感染者
plt.subplot(2,2,1) # (rows, columns, panel number)
plt.title("Daily new confirmed COVID-19 cases\n per million population in major countries\n(rolling 7day ave.)")
plt.grid()
plt.xticks(rotation=45)
chart_data = c_trans[c_trans.date >= min_date]
for i,cr in countries.iterrows():
    c = cr["country"]
    dates = chart_data.loc[chart_data["location"]==c]["date"]
    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else dates.max()
    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"],label=c, fmt="-")
    text_y = chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_cases_smoothed_per_million"]
#    print(text_y)
    print(c,text_disp_date,text_y)
    plt.text(text_disp_date,text_y,c,fontsize=8,va="center")
plt.legend(bbox_to_anchor=(0, 1),loc='upper left', fontsize=9)

# 主要国 死者
plt.subplot(2,2,2) # (rows, columns, panel number)
plt.title("Daily new deaths in major countries(rolling 7day ave.)")
plt.grid()
plt.xticks(rotation=45)
chart_data = c_trans[c_trans.date >= min_date]
for i,cr in countries.iterrows():
    c = cr["country"]
    dates = chart_data.loc[chart_data["location"]==c]["date"]
    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else dates.max()
    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_deaths_smoothed"],label=c, fmt="-")
    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_deaths_smoothed"],c
            ,fontsize=8,va="center")
plt.legend(bbox_to_anchor=(0, 1),loc='upper left', fontsize=9)

plt.subplot(2,2,3) # (rows, columns, panel number)
plt.grid()
plt.xticks(rotation=45)
plt.title("Daily new confirmed COVID-19 cases\n per million population in Eastern Asia\n(rolling 7day ave.)")
chart_data = e_a_trans[e_a_trans.date >= min_date]
for i,cr in e_asia_c.iterrows():
    c = cr["country"]
    dates = chart_data.loc[chart_data["location"]==c]["date"]
    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else dates.max()
    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"],label=c, fmt="-")
    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_cases_smoothed_per_million"],c
             ,fontsize=8,va="center")
plt.legend(bbox_to_anchor=(0, 1),loc='upper left', fontsize=9)

plt.subplot(2,2,4) # (rows, columns, panel number)
plt.grid()
plt.xticks(rotation=45)
plt.title("Daily new deaths in Eastern Asia(rolling 7day ave.)")
chart_data = e_a_trans[e_a_trans.date >= min_date]
for i,cr in e_asia_c.iterrows():
    c = cr["country"]
    dates = chart_data.loc[chart_data["location"]==c]["date"]
    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else dates.max()
    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_deaths_smoothed"],label=c, fmt="-")
    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_deaths_smoothed"],c
             ,fontsize=8,va="center")
plt.legend(bbox_to_anchor=(0, 1),loc='upper left', fontsize=9)

fig.text(0,0.98,"Latest: {}".format(latest_date_str),fontsize=9,ha="left",va="top")
fig.text(0,0
         ,"*Data Source : COVID-19 Dataset by Our World in Data",
        fontsize=8,ha="left",va="bottom")
fig.tight_layout()
"""
"""
# Out:
# <div id='e6912fdc-52e7-414a-a96b-a5f54c7718ba'></div>
# Japan 2021-07-21 00:00:00 546    28.166
# Name: new_cases_smoothed_per_million, dtype: float64
# United States 2021-07-21 00:00:00 1093    120.662
# Name: new_cases_smoothed_per_million, dtype: float64
# India 2021-04-15 00:00:00 1535    127.471
# Name: new_cases_smoothed_per_million, dtype: float64
# Spain 2021-07-21 00:00:00 2169    544.632
# Name: new_cases_smoothed_per_million, dtype: float64
# Brazil 2021-07-21 00:00:00 2681    177.581
# Name: new_cases_smoothed_per_million, dtype: float64
# United Kingdom 2021-07-21 00:00:00 3219    702.987
# Name: new_cases_smoothed_per_million, dtype: float64
# Russia 2021-07-21 00:00:00 3757    165.972
# Name: new_cases_smoothed_per_million, dtype: float64
# Colombia 2021-07-21 00:00:00 4260    321.809
# Name: new_cases_smoothed_per_million, dtype: float64
# South Africa 2021-07-21 00:00:00 4791    218.39
# Name: new_cases_smoothed_per_million, dtype: float64
# Iran 2021-07-21 00:00:00 5310    277.45
# Name: new_cases_smoothed_per_million, dtype: float64
# Ecuador 2021-07-21 00:00:00 5818    55.53
# Name: new_cases_smoothed_per_million, dtype: float64
# '\n'

# %%
fig.savefig("out/covid-owid-countries-daily.png")

# %% [markdown]
# ### 新規感染者数

# %%
fig = plt.figure(figsize=(12,14))

plt.subplot(2,2,1) # (rows, columns, panel number)
plt.title("New confirmed COVID-19 cases worst 50")
plt.yticks(fontsize=9)
plt.xlabel("people")
chart_data = c_df_latest.sort_values("new_cases",ascending=False).head(50).sort_values("new_cases",ascending=True)
plt.barh(chart_data["location"],chart_data["new_cases"],label="new cases a day")
plt.grid(axis="x")
mean = int(c_df_latest.new_cases.mean())
plt.plot([mean,mean],[0,50], 'k--', lw=0.5)
plt.text(mean,50,"Mean:{}".format(mean),ha="center",fontsize=9)
plt.legend()

plt.subplot(2,2,2) # (rows, columns, panel number)
plt.title("New confirmed COVID-19 cases per million worst 50")
plt.yticks(fontsize=9)
plt.xlabel("people")
chart_data = c_df_latest.sort_values("new_cases_per_million",ascending=False).head(50).sort_values("new_cases_per_million",ascending=True)
plt.barh(chart_data["location"],chart_data["new_cases_per_million"],label="new cases a day per million")
plt.grid(axis="x")
mean = int(chart_data.new_cases_per_million.mean())
plt.plot([mean,mean],[0,50], 'k--', lw=0.5)
plt.text(mean,50,"Mean:{}".format(mean),ha="center",fontsize=9)
plt.legend()

fig.text(0,0.98,"Latest: {}".format(latest_date_str),fontsize=9,ha="left",va="top")
fig.text(0,0
         ,"*Data Source : COVID-19 Dataset by Our World in Data",
        fontsize=8,ha="left",va="bottom")

plt.subplot(2,2,3) # (rows, columns, panel number)
plt.title("New deaths worst 50")
plt.yticks(fontsize=9)
plt.xlabel("people")
chart_data = c_df_latest.sort_values("new_deaths",ascending=False).head(50).sort_values("new_deaths",ascending=True)
plt.barh(chart_data["location"],chart_data["new_deaths"],label="new deaths a day")
plt.grid(axis="x")
mean = int(c_df_latest.new_deaths.mean())
plt.plot([mean,mean],[0,50], 'k--', lw=0.5)
plt.text(mean,50,"Mean:{}".format(mean),ha="center",fontsize=9)
plt.legend()

plt.subplot(2,2,4) # (rows, columns, panel number)
plt.title("Total deaths per population worst 50")
plt.yticks(fontsize=9)
plt.xlabel("%")
chart_data = c_df_latest.copy()
chart_data["total_deaths_per_poputaion"] = chart_data.total_deaths / chart_data.population * 100
chart_data = chart_data.sort_values("total_deaths_per_poputaion",ascending=False).head(50).sort_values("total_deaths_per_poputaion",ascending=True)
plt.barh(chart_data["location"],chart_data["total_deaths_per_poputaion"],label="total deaths per population")
plt.grid(axis="x")
mean = round(chart_data.total_deaths_per_poputaion.mean(),2)
plt.plot([mean,mean],[0,50], 'k--', lw=0.5)
plt.text(mean,50,"Mean:{}".format(mean),ha="center",fontsize=9)
plt.legend()


fig.tight_layout()
# Out:
# <div id='dc9bfc8c-0f1b-468e-85f1-78433805d25d'></div>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-508293ccaecb> in <module>
#       8 plt.barh(chart_data["location"],chart_data["new_cases"],label="new cases a day")
#       9 plt.grid(axis="x")
# ---> 10 mean = int(c_df_latest.new_cases.mean())
#      11 plt.plot([mean,mean],[0,50], 'k--', lw=0.5)
#      12 plt.text(mean,50,"Mean:{}".format(mean),ha="center",fontsize=9)
#
# ValueError: cannot convert float NaN to integer

# %%
fig.savefig("out/covid-owid-global-latest-top.png")

# %%
ecuador_df = df.loc[df.location=="Ecuador"]
c_df = df.loc[(df.date==pd.to_datetime("2021-07-21")) & (df.iso_code.str.len()==3)]

# %%
ecuador_df.tail(10)
# Out:
#       iso_code      continent location       date  total_cases  new_cases  \
# 27755      ECU  South America  Ecuador 2021-07-12     468414.0       68.0
# 27756      ECU  South America  Ecuador 2021-07-13     470882.0     2468.0
# 27757      ECU  South America  Ecuador 2021-07-14     471757.0      875.0
# 27758      ECU  South America  Ecuador 2021-07-15     472722.0      965.0
# 27759      ECU  South America  Ecuador 2021-07-16     473647.0      925.0
# 27760      ECU  South America  Ecuador 2021-07-17     475215.0     1568.0
# 27761      ECU  South America  Ecuador 2021-07-18     476065.0      850.0
# 27762      ECU  South America  Ecuador 2021-07-19     476312.0      247.0
# 27763      ECU  South America  Ecuador 2021-07-20     477946.0     1634.0
# 27764      ECU  South America  Ecuador 2021-07-21     478615.0      669.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 27755             823.571       21830.0         0.0               19.286  ...
# 27756             990.143       21832.0         2.0               17.714  ...
# 27757             961.143       21850.0        18.0               17.429  ...
# 27758             977.714       21872.0        22.0               14.857  ...
# 27759             939.143       21899.0        27.0               13.714  ...
# 27760            1034.143       21933.0        34.0               17.000  ...
# 27761            1102.714       21953.0        20.0               17.571  ...
# 27762            1128.286       21958.0         5.0               18.286  ...
# 27763            1009.143       30744.0      8786.0             1273.143  ...
# 27764             979.714       30752.0         8.0             1271.714  ...
#
#        extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# 27755              3.6                140.448                 5.55
# 27756              3.6                140.448                 5.55
# 27757              3.6                140.448                 5.55
# 27758              3.6                140.448                 5.55
# 27759              3.6                140.448                 5.55
# 27760              3.6                140.448                 5.55
# 27761              3.6                140.448                 5.55
# 27762              3.6                140.448                 5.55
# 27763              3.6                140.448                 5.55
# 27764              3.6                140.448                 5.55
#
#        female_smokers  male_smokers  handwashing_facilities  \
# 27755             2.0          12.3                  80.635
# 27756             2.0          12.3                  80.635
# 27757             2.0          12.3                  80.635
# 27758             2.0          12.3                  80.635
# 27759             2.0          12.3                  80.635
# 27760             2.0          12.3                  80.635
# 27761             2.0          12.3                  80.635
# 27762             2.0          12.3                  80.635
# 27763             2.0          12.3                  80.635
# 27764             2.0          12.3                  80.635
#
#        hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 27755                         1.5            77.01                    0.759
# 27756                         1.5            77.01                    0.759
# 27757                         1.5            77.01                    0.759
# 27758                         1.5            77.01                    0.759
# 27759                         1.5            77.01                    0.759
# 27760                         1.5            77.01                    0.759
# 27761                         1.5            77.01                    0.759
# 27762                         1.5            77.01                    0.759
# 27763                         1.5            77.01                    0.759
# 27764                         1.5            77.01                    0.759
#
#        excess_mortality
# 27755               NaN
# 27756               NaN
# 27757               NaN
# 27758               NaN
# 27759               NaN
# 27760               NaN
# 27761               NaN
# 27762               NaN
# 27763               NaN
# 27764               NaN
#
# [10 rows x 60 columns]

# %%
c_df.sort_values("new_deaths",ascending=False).head(50)
# Out:
#        iso_code      continent        location       date  total_cases  \
# 13734       BRA  South America          Brazil 2021-07-21   19473954.0
# 44093       IDN           Asia       Indonesia 2021-07-21    2983830.0
# 77816       RUS         Europe          Russia 2021-07-21    5955089.0
# 86577       ZAF         Africa    South Africa 2021-07-21    2327472.0
# 43586       IND           Asia           India 2021-07-21   31257720.0
# 4287        ARG  South America       Argentina 2021-07-21    4798851.0
# 61137       MEX  North America          Mexico 2021-07-21    2693495.0
# 20603       COL  South America        Colombia 2021-07-21    4679994.0
# 99221       USA  North America   United States 2021-07-21   34226806.0
# 64979       MMR           Asia         Myanmar 2021-07-21     246663.0
# 45143       IRN           Asia            Iran 2021-07-21    3603527.0
# 57799       MYS           Asia        Malaysia 2021-07-21     951884.0
# 8534        BGD           Asia      Bangladesh 2021-07-21    1136503.0
# 49575       KAZ           Asia      Kazakhstan 2021-07-21     568915.0
# 93781       THA           Asia        Thailand 2021-07-21     439477.0
# 95865       TUN         Africa         Tunisia 2021-07-21     555997.0
# 98674       GBR         Europe  United Kingdom 2021-07-21    5586716.0
# 12238       BOL  South America         Bolivia 2021-07-21     465351.0
# 45657       IRQ           Asia            Iraq 2021-07-21    1518837.0
# 81613       SAU           Asia    Saudi Arabia 2021-07-21     513284.0
# 65474       NAM         Africa         Namibia 2021-07-21     113905.0
# 104124      ZWE         Africa        Zimbabwe 2021-07-21      91120.0
# 96363       TUR           Asia          Turkey 2021-07-21    5554317.0
# 23613       CUB  North America            Cuba 2021-07-21     300854.0
# 74120       PRY  South America        Paraguay 2021-07-21     447146.0
# 89193       LKA           Asia       Sri Lanka 2021-07-21     289577.0
# 36456       DEU         Europe         Germany 2021-07-21    3756497.0
# 19553       CHL  South America           Chile 2021-07-21    1602854.0
# 72125       PAK           Asia        Pakistan 2021-07-21     998609.0
# 102009      VNM           Asia         Vietnam 2021-07-21      71144.0
# 101463      VEN  South America       Venezuela 2021-07-21     295746.0
# 64497       MOZ         Africa      Mozambique 2021-07-21     103713.0
# 66122       NPL           Asia           Nepal 2021-07-21     672871.0
# 75222       PHL           Asia     Philippines 2021-07-21    1524449.0
# 41484       HND  North America        Honduras 2021-07-21     284187.0
# 35911       GEO           Asia         Georgia 2021-07-21     393360.0
# 57255       MWI         Africa          Malawi 2021-07-21      45465.0
# 103635      ZMB         Africa          Zambia 2021-07-21     188573.0
# 97596       UKR         Europe         Ukraine 2021-07-21    2321081.0
# 34243       FRA         Europe          France 2021-07-21    5973912.0
# 33158       FJI        Oceania            Fiji 2021-07-21      20443.0
# 47405       ITA         Europe           Italy 2021-07-21    4297337.0
# 48450       JPN           Asia           Japan 2021-07-21     853137.0
# 16311       KHM           Asia        Cambodia 2021-07-21      69608.0
# 88651       ESP         Europe           Spain 2021-07-21    4219723.0
# 78311       RWA         Africa          Rwanda 2021-07-21      60066.0
# 2064        DZA         Africa         Algeria 2021-07-21     157005.0
# 97090       UGA         Africa          Uganda 2021-07-21      91162.0
# 76257       PRT         Europe        Portugal 2021-07-21     939622.0
# 64010       MAR         Africa         Morocco 2021-07-21     566356.0
#
#         new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 13734     54517.0           37746.429      545604.0      1424.0
# 44093     33772.0           44826.286       77583.0      1383.0
# 77816     23164.0           24221.000      148229.0       772.0
# 86577     16240.0           12952.429       68192.0       516.0
# 43586     41383.0           38548.571      418987.0       507.0
# 4287      14632.0           13742.000      102818.0       437.0
# 61137     15198.0           10952.571      237207.0       397.0
# 20603     11244.0           16374.571      117482.0       351.0
# 99221     52032.0           39939.429      609862.0       333.0
# 64979      6093.0            5472.286        5814.0       247.0
# 45143     27379.0           23303.857       87837.0       213.0
# 57799     11985.0           12045.286        7440.0       199.0
# 8534       7614.0           10995.000       18498.0       173.0
# 49575      5742.0            6291.000        5180.0       118.0
# 93781     13002.0           10921.143        3610.0       108.0
# 95865      1086.0            5341.143       17913.0        92.0
# 98674     44081.0           47723.000      129182.0        73.0
# 12238      2226.0            1219.429       17546.0        71.0
# 45657      8320.0            8806.429       18020.0        69.0
# 81613      5861.0            1364.286        8115.0        67.0
# 65474       467.0             731.429        2620.0        63.0
# 104124     2705.0            2105.571        2809.0        62.0
# 96363      8151.0            7738.000       50709.0        59.0
# 23613      6405.0            6321.000        2072.0        53.0
# 74120       879.0             870.000       14446.0        52.0
# 89193      1604.0            1502.571        3917.0        47.0
# 36456      1651.0            1366.000       91466.0        43.0
# 19553       996.0            1532.000       34611.0        42.0
# 72125      2158.0            2459.571       22928.0        40.0
# 102009     5537.0            4700.714         370.0        36.0
# 101463     1880.0            1092.429        3426.0        34.0
# 64497      1704.0            1469.143        1190.0        32.0
# 66122      1918.0            1726.143        9637.0        30.0
# 75222      6546.0            5570.286       26874.0        30.0
# 41484      1501.0            1028.286        7535.0        28.0
# 35911      2415.0            1717.714        5618.0        26.0
# 57255       781.0             678.857        1389.0        26.0
# 103635      971.0            1146.286        3162.0        24.0
# 97596      1195.0            1053.714       55245.0        24.0
# 34243     21573.0           12788.143      111737.0        22.0
# 33158      1091.0            1201.571         146.0        21.0
# 47405      4254.0            3070.143      127905.0        21.0
# 48450      4915.0            3562.286       15046.0        20.0
# 16311       812.0             856.143        1168.0        19.0
# 88651     30587.0           25464.143       81166.0        18.0
# 78311       925.0            1332.000         693.0        16.0
# 2064       1221.0            1172.571        3994.0        15.0
# 97090       252.0             355.429        2425.0        13.0
# 76257      4376.0            3294.714       17232.0        13.0
# 64010      3940.0            2726.143        9498.0        12.0
#
#         new_deaths_smoothed  ...  extreme_poverty  cardiovasc_death_rate  \
# 13734              1172.857  ...              3.4                177.961
# 44093              1196.143  ...              5.7                342.864
# 77816               764.571  ...              0.1                431.297
# 86577               371.000  ...             18.9                200.380
# 43586               999.714  ...             21.2                282.280
# 4287                366.857  ...              0.6                191.032
# 61137               242.857  ...              2.5                152.783
# 20603               449.286  ...              4.5                124.240
# 99221               245.857  ...              1.2                151.089
# 64979               233.286  ...              6.4                202.104
# 45143               206.571  ...              0.2                270.308
# 57799               133.857  ...              0.1                260.942
# 8534                206.571  ...             14.8                298.003
# 49575                58.714  ...              0.1                466.792
# 93781                96.571  ...              0.1                109.861
# 95865               152.571  ...              2.0                318.991
# 98674                55.000  ...              0.2                122.137
# 12238                37.000  ...              7.1                204.299
# 45657                49.000  ...              2.5                218.612
# 81613                15.571  ...              NaN                259.538
# 65474                54.286  ...             13.4                243.811
# 104124               68.143  ...             21.4                307.846
# 96363                48.857  ...              0.2                171.285
# 23613                59.000  ...              NaN                190.968
# 74120                54.286  ...              1.7                199.128
# 89193                43.714  ...              0.7                197.093
# 36456                20.000  ...              NaN                156.139
# 19553                80.286  ...              1.3                127.993
# 72125                34.143  ...              4.0                423.031
# 102009               33.143  ...              2.0                245.465
# 101463               14.143  ...              NaN                204.850
# 64497                22.429  ...             62.9                329.942
# 66122                29.571  ...             15.0                260.797
# 75222                91.714  ...              NaN                370.437
# 41484                25.571  ...             16.0                240.208
# 35911                18.000  ...              4.2                496.218
# 57255                16.143  ...             71.4                227.349
# 103635               30.429  ...             57.5                234.499
# 97596                25.571  ...              0.1                539.849
# 34243                18.286  ...              NaN                 86.060
# 33158                12.429  ...              1.4                412.820
# 47405                10.571  ...              2.0                113.151
# 48450                14.714  ...              NaN                 79.370
# 16311                26.000  ...              NaN                270.892
# 88651                17.571  ...              1.0                 99.403
# 78311                12.286  ...             56.0                191.375
# 2064                 16.000  ...              0.5                278.364
# 97090                31.714  ...             41.6                213.333
# 76257                 7.143  ...              0.5                127.842
# 64010                13.429  ...              1.0                419.146
#
#         diabetes_prevalence  female_smokers  male_smokers  \
# 13734                  8.11            10.1          17.9
# 44093                  6.32             2.8          76.1
# 77816                  6.18            23.4          58.3
# 86577                  5.52             8.1          33.2
# 43586                 10.39             1.9          20.6
# 4287                   5.50            16.2          27.7
# 61137                 13.06             6.9          21.4
# 20603                  7.44             4.7          13.5
# 99221                 10.79            19.1          24.6
# 64979                  4.61             6.3          35.2
# 45143                  9.59             0.8          21.1
# 57799                 16.74             1.0          42.4
# 8534                   8.38             1.0          44.7
# 49575                  7.11             7.0          43.1
# 93781                  7.04             1.9          38.8
# 95865                  8.52             1.1          65.8
# 98674                  4.28            20.0          24.7
# 12238                  6.89             NaN           NaN
# 45657                  8.83             NaN           NaN
# 81613                 17.72             1.8          25.4
# 65474                  3.94             9.7          34.2
# 104124                 1.82             1.6          30.7
# 96363                 12.13            14.1          41.1
# 23613                  8.27            17.1          53.3
# 74120                  8.27             5.0          21.6
# 89193                 10.68             0.3          27.0
# 36456                  8.31            28.2          33.1
# 19553                  8.46            34.2          41.5
# 72125                  8.35             2.8          36.7
# 102009                 6.00             1.0          45.9
# 101463                 6.47             NaN           NaN
# 64497                  3.30             5.1          29.1
# 66122                  7.26             9.5          37.8
# 75222                  7.07             7.8          40.8
# 41484                  7.21             2.0           NaN
# 35911                  7.11             5.3          55.5
# 57255                  3.94             4.4          24.7
# 103635                 3.94             3.1          24.7
# 97596                  7.11            13.5          47.4
# 34243                  4.77            30.1          35.6
# 33158                 14.49            10.2          34.8
# 47405                  4.78            19.8          27.8
# 48450                  5.72            11.2          33.7
# 16311                  4.00             2.0          33.7
# 88651                  7.17            27.4          31.4
# 78311                  4.28             4.7          21.0
# 2064                   6.73             0.7          30.4
# 97090                  2.50             3.4          16.7
# 76257                  9.85            16.3          30.0
# 64010                  7.14             0.8          47.1
#
#         handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 13734                      NaN                        2.20            75.88
# 44093                   64.204                        1.04            71.72
# 77816                      NaN                        8.05            72.58
# 86577                   43.993                        2.32            64.13
# 43586                   59.550                        0.53            69.66
# 4287                       NaN                        5.00            76.67
# 61137                   87.847                        1.38            75.05
# 20603                   65.386                        1.71            77.29
# 99221                      NaN                        2.77            78.86
# 64979                   79.287                        0.90            67.13
# 45143                      NaN                        1.50            76.68
# 57799                      NaN                        1.90            76.16
# 8534                    34.808                        0.80            72.59
# 49575                   98.999                        6.70            73.60
# 93781                   90.670                        2.10            77.15
# 95865                   78.687                        2.30            76.70
# 98674                      NaN                        2.54            81.32
# 12238                   25.383                        1.10            71.51
# 45657                   94.576                        1.40            70.60
# 81613                      NaN                        2.70            75.13
# 65474                   44.600                         NaN            63.71
# 104124                  36.791                        1.70            61.49
# 96363                      NaN                        2.81            77.69
# 23613                   85.198                        5.20            78.80
# 74120                   79.602                        1.30            74.25
# 89193                      NaN                        3.60            76.98
# 36456                      NaN                        8.00            81.33
# 19553                      NaN                        2.11            80.18
# 72125                   59.607                        0.60            67.27
# 102009                  85.847                        2.60            75.40
# 101463                     NaN                        0.80            72.06
# 64497                   12.227                        0.70            60.85
# 66122                   47.782                        0.30            70.78
# 75222                   78.463                        1.00            71.23
# 41484                   84.169                        0.70            75.27
# 35911                      NaN                        2.60            73.77
# 57255                    8.704                        1.30            64.26
# 103635                  13.938                        2.00            63.89
# 97596                      NaN                        8.80            72.06
# 34243                      NaN                        5.98            82.66
# 33158                      NaN                        2.30            67.44
# 47405                      NaN                        3.18            83.51
# 48450                      NaN                       13.05            84.63
# 16311                   66.229                        0.80            69.82
# 88651                      NaN                        2.97            83.56
# 78311                    4.617                         NaN            69.02
# 2064                    83.741                        1.90            76.88
# 97090                   21.222                        0.50            63.37
# 76257                      NaN                        3.39            82.05
# 64010                      NaN                        1.10            76.68
#
#         human_development_index  excess_mortality
# 13734                     0.765               NaN
# 44093                     0.718               NaN
# 77816                     0.824               NaN
# 86577                     0.709               NaN
# 43586                     0.645               NaN
# 4287                      0.845               NaN
# 61137                     0.779               NaN
# 20603                     0.767               NaN
# 99221                     0.926               NaN
# 64979                     0.583               NaN
# 45143                     0.783               NaN
# 57799                     0.810               NaN
# 8534                      0.632               NaN
# 49575                     0.825               NaN
# 93781                     0.777               NaN
# 95865                     0.740               NaN
# 98674                     0.932               NaN
# 12238                     0.718               NaN
# 45657                     0.674               NaN
# 81613                     0.854               NaN
# 65474                     0.646               NaN
# 104124                    0.571               NaN
# 96363                     0.820               NaN
# 23613                     0.783               NaN
# 74120                     0.728               NaN
# 89193                     0.782               NaN
# 36456                     0.947               NaN
# 19553                     0.851               NaN
# 72125                     0.557               NaN
# 102009                    0.704               NaN
# 101463                    0.711               NaN
# 64497                     0.456               NaN
# 66122                     0.602               NaN
# 75222                     0.718               NaN
# 41484                     0.634               NaN
# 35911                     0.812               NaN
# 57255                     0.483               NaN
# 103635                    0.584               NaN
# 97596                     0.779               NaN
# 34243                     0.901               NaN
# 33158                     0.743               NaN
# 47405                     0.892               NaN
# 48450                     0.919               NaN
# 16311                     0.594               NaN
# 88651                     0.904               NaN
# 78311                     0.543               NaN
# 2064                      0.748               NaN
# 97090                     0.544               NaN
# 76257                     0.864               NaN
# 64010                     0.686               NaN
#
# [50 rows x 60 columns]
