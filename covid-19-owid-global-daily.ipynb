# %%
import pandas as pd

# %%
df = pd.read_csv("covid-19-data/public/data/owid-covid-data.csv")
df.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1      AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# 0              NaN                597.029                 9.59
# 1              NaN                597.029                 9.59
# 2              NaN                597.029                 9.59
# 3              NaN                597.029                 9.59
# 4              NaN                597.029                 9.59
#
#    female_smokers  male_smokers  handwashing_facilities  \
# 0             NaN           NaN                  37.746
# 1             NaN           NaN                  37.746
# 2             NaN           NaN                  37.746
# 3             NaN           NaN                  37.746
# 4             NaN           NaN                  37.746
#
#    hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                         0.5            64.83                    0.511
# 1                         0.5            64.83                    0.511
# 2                         0.5            64.83                    0.511
# 3                         0.5            64.83                    0.511
# 4                         0.5            64.83                    0.511
#
#    excess_mortality
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
#
# [5 rows x 60 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105724 entries, 0 to 105723
# Data columns (total 60 columns):
#  #   Column                                 Non-Null Count   Dtype
# ---  ------                                 --------------   -----
#  0   iso_code                               105724 non-null  object
#  1   continent                              100812 non-null  object
#  2   location                               105724 non-null  object
#  3   date                                   105724 non-null  object
#  4   total_cases                            101408 non-null  float64
#  5   new_cases                              101405 non-null  float64
#  6   new_cases_smoothed                     100395 non-null  float64
#  7   total_deaths                           91087 non-null   float64
#  8   new_deaths                             91242 non-null   float64
#  9   new_deaths_smoothed                    100395 non-null  float64
#  10  total_cases_per_million                100870 non-null  float64
#  11  new_cases_per_million                  100867 non-null  float64
#  12  new_cases_smoothed_per_million         99862 non-null   float64
#  13  total_deaths_per_million               90562 non-null   float64
#  14  new_deaths_per_million                 90717 non-null   float64
#  15  new_deaths_smoothed_per_million        99862 non-null   float64
#  16  reproduction_rate                      85372 non-null   float64
#  17  icu_patients                           11010 non-null   float64
#  18  icu_patients_per_million               11010 non-null   float64
#  19  hosp_patients                          13300 non-null   float64
#  20  hosp_patients_per_million              13300 non-null   float64
#  21  weekly_icu_admissions                  979 non-null     float64
#  22  weekly_icu_admissions_per_million      979 non-null     float64
#  23  weekly_hosp_admissions                 1880 non-null    float64
#  24  weekly_hosp_admissions_per_million     1880 non-null    float64
#  25  new_tests                              46933 non-null   float64
#  26  total_tests                            46644 non-null   float64
#  27  total_tests_per_thousand               46644 non-null   float64
#  28  new_tests_per_thousand                 46933 non-null   float64
#  29  new_tests_smoothed                     54879 non-null   float64
#  30  new_tests_smoothed_per_thousand        54879 non-null   float64
#  31  positive_rate                          51257 non-null   float64
#  32  tests_per_case                         50625 non-null   float64
#  33  tests_units                            56630 non-null   object
#  34  total_vaccinations                     19739 non-null   float64
#  35  people_vaccinated                      18871 non-null   float64
#  36  people_fully_vaccinated                15939 non-null   float64
#  37  new_vaccinations                       16424 non-null   float64
#  38  new_vaccinations_smoothed              34500 non-null   float64
#  39  total_vaccinations_per_hundred         19739 non-null   float64
#  40  people_vaccinated_per_hundred          18871 non-null   float64
#  41  people_fully_vaccinated_per_hundred    15939 non-null   float64
#  42  new_vaccinations_smoothed_per_million  34500 non-null   float64
#  43  stringency_index                       88206 non-null   float64
#  44  population                             105021 non-null  float64
#  45  population_density                     98109 non-null   float64
#  46  median_age                             94164 non-null   float64
#  47  aged_65_older                          93110 non-null   float64
#  48  aged_70_older                          93645 non-null   float64
#  49  gdp_per_capita                         94559 non-null   float64
#  50  extreme_poverty                        63681 non-null   float64
#  51  cardiovasc_death_rate                  94504 non-null   float64
#  52  diabetes_prevalence                    97075 non-null   float64
#  53  female_smokers                         73884 non-null   float64
#  54  male_smokers                           72804 non-null   float64
#  55  handwashing_facilities                 47463 non-null   float64
#  56  hospital_beds_per_thousand             86040 non-null   float64
#  57  life_expectancy                        100340 non-null  float64
#  58  human_development_index                94622 non-null   float64
#  59  excess_mortality                       3673 non-null    float64
# dtypes: float64(55), object(5)
# memory usage: 48.4+ MB

# %%
df.describe()
# Out:
#         total_cases      new_cases  new_cases_smoothed  total_deaths  \
# count  1.014080e+05  101405.000000       100395.000000  9.108700e+04
# mean   1.166723e+06    6124.139431         6132.268732  3.096175e+04
# std    7.927362e+06   37908.396506        37556.242476  1.848286e+05
# min    1.000000e+00  -74347.000000        -6223.000000  1.000000e+00
# 25%    1.460000e+03       2.000000            7.857000  5.800000e+01
# 50%    1.517300e+04      77.000000           95.429000  4.470000e+02
# 75%    1.618530e+05     840.000000          887.571000  4.293500e+03
# max    1.959683e+08  905993.000000       826368.143000  4.187379e+06
#
#          new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  91242.000000        100395.000000            100870.000000
# mean     145.541330           131.468878             14417.264594
# std      795.923001           740.772136             25922.238300
# min    -1918.000000          -232.143000                 0.001000
# 25%        0.000000             0.000000               281.997000
# 50%        2.000000             1.429000              2055.602000
# 75%       18.000000            14.714000             15409.161500
# max    18056.000000         14735.286000            188778.878000
#
#        new_cases_per_million  new_cases_smoothed_per_million  \
# count          100867.000000                    99862.000000
# mean               77.181933                       77.304172
# std               201.519981                      158.941745
# min             -3162.163000                     -276.825000
# 25%                 0.235000                        1.363000
# 50%                 9.009000                       11.849000
# 75%                71.921500                       79.909750
# max             18293.675000                     4083.500000
#
#        total_deaths_per_million  ...  extreme_poverty  cardiovasc_death_rate  \
# count              90562.000000  ...     63681.000000           94504.000000
# mean                 313.852609  ...        13.431752             258.714235
# std                  557.896060  ...        19.969301             119.115096
# min                    0.001000  ...         0.100000              79.370000
# 25%                    8.702000  ...         0.600000             168.711000
# 50%                   57.287500  ...         2.200000             242.648000
# 75%                  350.005500  ...        21.200000             329.942000
# max                 5948.651000  ...        77.600000             724.417000
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# count         97075.000000    73884.000000  72804.000000
# mean              7.953599       10.583269     32.713892
# std               4.183531       10.483990     13.488875
# min               0.990000        0.100000      7.700000
# 25%               5.310000        1.900000     21.600000
# 50%               7.110000        6.300000     31.400000
# 75%              10.080000       19.300000     41.100000
# max              30.530000       44.000000     78.100000
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# count            47463.000000                86040.000000    100340.000000
# mean                50.802286                    3.026797        73.242928
# std                 31.757208                    2.456648         7.554822
# min                  1.188000                    0.100000        53.280000
# 25%                 19.351000                    1.300000        67.920000
# 50%                 49.839000                    2.400000        74.620000
# 75%                 83.241000                    3.861000        78.740000
# max                100.000000                   13.800000        86.750000
#
#        human_development_index  excess_mortality
# count             94622.000000       3673.000000
# mean                  0.727100         18.127661
# std                   0.150309         35.586647
# min                   0.394000        -95.590000
# 25%                   0.602000          0.430000
# 50%                   0.744000          7.440000
# 75%                   0.848000         23.940000
# max                   0.957000        410.120000
#
# [8 rows x 55 columns]

# %%
df.continent.unique()
# Out:
# array(['Asia', nan, 'Europe', 'Africa', 'North America', 'South America',
#        'Oceania'], dtype=object)

# %%
df.loc[df.continent.isna()].location.unique()
# Out:
# array(['Africa', 'Asia', 'Europe', 'European Union', 'International',
#        'North America', 'Oceania', 'South America', 'World'], dtype=object)

# %%
df.loc[df.location=="International"]
# Out:
#        iso_code continent       location        date  total_cases  new_cases  \
# 44757  OWID_INT       NaN  International  2020-02-07         61.0       61.0
# 44758  OWID_INT       NaN  International  2020-02-08         61.0        0.0
# 44759  OWID_INT       NaN  International  2020-02-09         64.0        3.0
# 44760  OWID_INT       NaN  International  2020-02-10        135.0       71.0
# 44761  OWID_INT       NaN  International  2020-02-11        135.0        0.0
# ...         ...       ...            ...         ...          ...        ...
# 45290  OWID_INT       NaN  International  2021-07-24        721.0        0.0
# 45291  OWID_INT       NaN  International  2021-07-25        721.0        0.0
# 45292  OWID_INT       NaN  International  2021-07-26        721.0        0.0
# 45293  OWID_INT       NaN  International  2021-07-27        721.0        0.0
# 45294  OWID_INT       NaN  International  2021-07-28        721.0        0.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 44757                 NaN           NaN         NaN                  NaN  ...
# 44758                 NaN           NaN         NaN                  NaN  ...
# 44759                 NaN           NaN         NaN                  NaN  ...
# 44760                 NaN           NaN         NaN                  NaN  ...
# 44761                 NaN           NaN         NaN                  NaN  ...
# ...                   ...           ...         ...                  ...  ...
# 45290                 0.0          15.0         0.0                  0.0  ...
# 45291                 0.0          15.0         0.0                  0.0  ...
# 45292                 0.0          15.0         0.0                  0.0  ...
# 45293                 0.0          15.0         0.0                  0.0  ...
# 45294                 0.0          15.0         0.0                  0.0  ...
#
#        extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# 44757              NaN                    NaN                  NaN
# 44758              NaN                    NaN                  NaN
# 44759              NaN                    NaN                  NaN
# 44760              NaN                    NaN                  NaN
# 44761              NaN                    NaN                  NaN
# ...                ...                    ...                  ...
# 45290              NaN                    NaN                  NaN
# 45291              NaN                    NaN                  NaN
# 45292              NaN                    NaN                  NaN
# 45293              NaN                    NaN                  NaN
# 45294              NaN                    NaN                  NaN
#
#        female_smokers  male_smokers  handwashing_facilities  \
# 44757             NaN           NaN                     NaN
# 44758             NaN           NaN                     NaN
# 44759             NaN           NaN                     NaN
# 44760             NaN           NaN                     NaN
# 44761             NaN           NaN                     NaN
# ...               ...           ...                     ...
# 45290             NaN           NaN                     NaN
# 45291             NaN           NaN                     NaN
# 45292             NaN           NaN                     NaN
# 45293             NaN           NaN                     NaN
# 45294             NaN           NaN                     NaN
#
#        hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 44757                         NaN              NaN                      NaN
# 44758                         NaN              NaN                      NaN
# 44759                         NaN              NaN                      NaN
# 44760                         NaN              NaN                      NaN
# 44761                         NaN              NaN                      NaN
# ...                           ...              ...                      ...
# 45290                         NaN              NaN                      NaN
# 45291                         NaN              NaN                      NaN
# 45292                         NaN              NaN                      NaN
# 45293                         NaN              NaN                      NaN
# 45294                         NaN              NaN                      NaN
#
#        excess_mortality
# 44757               NaN
# 44758               NaN
# 44759               NaN
# 44760               NaN
# 44761               NaN
# ...                 ...
# 45290               NaN
# 45291               NaN
# 45292               NaN
# 45293               NaN
# 45294               NaN
#
# [538 rows x 60 columns]

# %%
df.location.unique()
# Out:
# array(['Afghanistan', 'Africa', 'Albania', 'Algeria', 'Andorra', 'Angola',
#        'Anguilla', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        'Asia', 'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain',
#        'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin',
#        'Bermuda', 'Bhutan', 'Bolivia', 'Bonaire Sint Eustatius and Saba',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Brunei', 'Bulgaria', 'Burkina Faso',
#        'Burundi', 'Cambodia', 'Cameroon', 'Canada', 'Cape Verde',
#        'Cayman Islands', 'Central African Republic', 'Chad', 'Chile',
#        'China', 'Colombia', 'Comoros', 'Congo', 'Cook Islands',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Curacao',
#        'Cyprus', 'Czechia', 'Democratic Republic of Congo', 'Denmark',
#        'Djibouti', 'Dominica', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Estonia',
#        'Eswatini', 'Ethiopia', 'Europe', 'European Union',
#        'Faeroe Islands', 'Falkland Islands', 'Fiji', 'Finland', 'France',
#        'French Polynesia', 'Gabon', 'Gambia', 'Georgia', 'Germany',
#        'Ghana', 'Gibraltar', 'Greece', 'Greenland', 'Grenada',
#        'Guatemala', 'Guernsey', 'Guinea', 'Guinea-Bissau', 'Guyana',
#        'Haiti', 'Honduras', 'Hong Kong', 'Hungary', 'Iceland', 'India',
#        'Indonesia', 'International', 'Iran', 'Iraq', 'Ireland',
#        'Isle of Man', 'Israel', 'Italy', 'Jamaica', 'Japan', 'Jersey',
#        'Jordan', 'Kazakhstan', 'Kenya', 'Kiribati', 'Kosovo', 'Kuwait',
#        'Kyrgyzstan', 'Laos', 'Latvia', 'Lebanon', 'Lesotho', 'Liberia',
#        'Libya', 'Liechtenstein', 'Lithuania', 'Luxembourg', 'Macao',
#        'Madagascar', 'Malawi', 'Malaysia', 'Maldives', 'Mali', 'Malta',
#        'Marshall Islands', 'Mauritania', 'Mauritius', 'Mexico',
#        'Micronesia (country)', 'Moldova', 'Monaco', 'Mongolia',
#        'Montenegro', 'Montserrat', 'Morocco', 'Mozambique', 'Myanmar',
#        'Namibia', 'Nauru', 'Nepal', 'Netherlands', 'New Caledonia',
#        'New Zealand', 'Nicaragua', 'Niger', 'Nigeria', 'Niue',
#        'North America', 'North Macedonia', 'Northern Cyprus', 'Norway',
#        'Oceania', 'Oman', 'Pakistan', 'Palestine', 'Panama',
#        'Papua New Guinea', 'Paraguay', 'Peru', 'Philippines', 'Pitcairn',
#        'Poland', 'Portugal', 'Qatar', 'Romania', 'Russia', 'Rwanda',
#        'Saint Helena', 'Saint Kitts and Nevis', 'Saint Lucia',
#        'Saint Vincent and the Grenadines', 'Samoa', 'San Marino',
#        'Sao Tome and Principe', 'Saudi Arabia', 'Senegal', 'Serbia',
#        'Seychelles', 'Sierra Leone', 'Singapore',
#        'Sint Maarten (Dutch part)', 'Slovakia', 'Slovenia',
#        'Solomon Islands', 'Somalia', 'South Africa', 'South America',
#        'South Korea', 'South Sudan', 'Spain', 'Sri Lanka', 'Sudan',
#        'Suriname', 'Sweden', 'Switzerland', 'Syria', 'Taiwan',
#        'Tajikistan', 'Tanzania', 'Thailand', 'Timor', 'Togo', 'Tonga',
#        'Trinidad and Tobago', 'Tunisia', 'Turkey', 'Turkmenistan',
#        'Turks and Caicos Islands', 'Tuvalu', 'Uganda', 'Ukraine',
#        'United Arab Emirates', 'United Kingdom', 'United States',
#        'Uruguay', 'Uzbekistan', 'Vanuatu', 'Vatican', 'Venezuela',
#        'Vietnam', 'Wallis and Futuna', 'World', 'Yemen', 'Zambia',
#        'Zimbabwe'], dtype=object)

# %%
df["date"] = pd.to_datetime(df["date"])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105724 entries, 0 to 105723
# Data columns (total 60 columns):
#  #   Column                                 Non-Null Count   Dtype
# ---  ------                                 --------------   -----
#  0   iso_code                               105724 non-null  object
#  1   continent                              100812 non-null  object
#  2   location                               105724 non-null  object
#  3   date                                   105724 non-null  datetime64[ns]
#  4   total_cases                            101408 non-null  float64
#  5   new_cases                              101405 non-null  float64
#  6   new_cases_smoothed                     100395 non-null  float64
#  7   total_deaths                           91087 non-null   float64
#  8   new_deaths                             91242 non-null   float64
#  9   new_deaths_smoothed                    100395 non-null  float64
#  10  total_cases_per_million                100870 non-null  float64
#  11  new_cases_per_million                  100867 non-null  float64
#  12  new_cases_smoothed_per_million         99862 non-null   float64
#  13  total_deaths_per_million               90562 non-null   float64
#  14  new_deaths_per_million                 90717 non-null   float64
#  15  new_deaths_smoothed_per_million        99862 non-null   float64
#  16  reproduction_rate                      85372 non-null   float64
#  17  icu_patients                           11010 non-null   float64
#  18  icu_patients_per_million               11010 non-null   float64
#  19  hosp_patients                          13300 non-null   float64
#  20  hosp_patients_per_million              13300 non-null   float64
#  21  weekly_icu_admissions                  979 non-null     float64
#  22  weekly_icu_admissions_per_million      979 non-null     float64
#  23  weekly_hosp_admissions                 1880 non-null    float64
#  24  weekly_hosp_admissions_per_million     1880 non-null    float64
#  25  new_tests                              46933 non-null   float64
#  26  total_tests                            46644 non-null   float64
#  27  total_tests_per_thousand               46644 non-null   float64
#  28  new_tests_per_thousand                 46933 non-null   float64
#  29  new_tests_smoothed                     54879 non-null   float64
#  30  new_tests_smoothed_per_thousand        54879 non-null   float64
#  31  positive_rate                          51257 non-null   float64
#  32  tests_per_case                         50625 non-null   float64
#  33  tests_units                            56630 non-null   object
#  34  total_vaccinations                     19739 non-null   float64
#  35  people_vaccinated                      18871 non-null   float64
#  36  people_fully_vaccinated                15939 non-null   float64
#  37  new_vaccinations                       16424 non-null   float64
#  38  new_vaccinations_smoothed              34500 non-null   float64
#  39  total_vaccinations_per_hundred         19739 non-null   float64
#  40  people_vaccinated_per_hundred          18871 non-null   float64
#  41  people_fully_vaccinated_per_hundred    15939 non-null   float64
#  42  new_vaccinations_smoothed_per_million  34500 non-null   float64
#  43  stringency_index                       88206 non-null   float64
#  44  population                             105021 non-null  float64
#  45  population_density                     98109 non-null   float64
#  46  median_age                             94164 non-null   float64
#  47  aged_65_older                          93110 non-null   float64
#  48  aged_70_older                          93645 non-null   float64
#  49  gdp_per_capita                         94559 non-null   float64
#  50  extreme_poverty                        63681 non-null   float64
#  51  cardiovasc_death_rate                  94504 non-null   float64
#  52  diabetes_prevalence                    97075 non-null   float64
#  53  female_smokers                         73884 non-null   float64
#  54  male_smokers                           72804 non-null   float64
#  55  handwashing_facilities                 47463 non-null   float64
#  56  hospital_beds_per_thousand             86040 non-null   float64
#  57  life_expectancy                        100340 non-null  float64
#  58  human_development_index                94622 non-null   float64
#  59  excess_mortality                       3673 non-null    float64
# dtypes: datetime64[ns](1), float64(55), object(4)
# memory usage: 48.4+ MB

# %% [markdown]
# ## 最新日付チェック

# %%
import datetime
#latest_date_str = (df.date.max()-datetime.timedelta(days=1)).strftime("%Y-%m-%d")
latest_date_str = df.date.max().strftime("%Y-%m-%d")
latest_date_str
# Out:
# '2021-07-29'

# %% [markdown]
# ## 全世界のデータのみ

# %%
world_df = df.copy().loc[df.location=="World"]
world_df.tail()
# Out:
#         iso_code continent location       date  total_cases  new_cases  \
# 104250  OWID_WRL       NaN    World 2021-07-24  193739391.0   472623.0
# 104251  OWID_WRL       NaN    World 2021-07-25  194178372.0   438981.0
# 104252  OWID_WRL       NaN    World 2021-07-26  194715723.0   537351.0
# 104253  OWID_WRL       NaN    World 2021-07-27  195331673.0   615950.0
# 104254  OWID_WRL       NaN    World 2021-07-28  195968310.0   636637.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 104250          534416.714     4152839.0      9198.0             8657.000
# 104251          536910.714     4159800.0      6961.0             8697.714
# 104252          542808.857     4167672.0      7872.0             8791.000
# 104253          554459.429     4177694.0     10022.0             8494.286
# 104254          564769.571     4187379.0      9685.0             8617.571
#
#         ...  extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# 104250  ...             10.0                 233.07                 8.51
# 104251  ...             10.0                 233.07                 8.51
# 104252  ...             10.0                 233.07                 8.51
# 104253  ...             10.0                 233.07                 8.51
# 104254  ...             10.0                 233.07                 8.51
#
#         female_smokers  male_smokers  handwashing_facilities  \
# 104250           6.434        34.635                   60.13
# 104251           6.434        34.635                   60.13
# 104252           6.434        34.635                   60.13
# 104253           6.434        34.635                   60.13
# 104254           6.434        34.635                   60.13
#
#         hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 104250                       2.705            72.58                    0.737
# 104251                       2.705            72.58                    0.737
# 104252                       2.705            72.58                    0.737
# 104253                       2.705            72.58                    0.737
# 104254                       2.705            72.58                    0.737
#
#         excess_mortality
# 104250               NaN
# 104251               NaN
# 104252               NaN
# 104253               NaN
# 104254               NaN
#
# [5 rows x 60 columns]

# %% [markdown]
# ### 主要国の定義

# %%
countries = pd.DataFrame([
    ("Japan",""),
    ("United States",""),
    ("India",""),
    ("Spain",""),
    ("Brazil",""),
#    ("Israel",""),
    ("United Kingdom",""),
#    ("France","20210425"),
    ("Russia",""),
    ("Colombia",""),
    ("South Africa",""),
    ("Iran",""),
#    ("Ecuador",""),
],columns=["country","text_disp_date"])
countries
# Out:
#           country text_disp_date
# 0           Japan
# 1   United States
# 2           India
# 3           Spain
# 4          Brazil
# 5  United Kingdom
# 6          Russia
# 7        Colombia
# 8    South Africa
# 9            Iran

# %%
# 東Asia 主要国
e_asia_c = pd.DataFrame([
    ("Japan",""),
    ("China",""),
    ("Taiwan",""),
    ("South Korea",""),
    ("Indonesia",""),
    ("Philippines","20210618"),
    ("Vietnam",""),
    ("Myanmar",""),
],columns=["country","text_disp_date"])
e_asia_c
# Out:
#        country text_disp_date
# 0        Japan
# 1        China
# 2       Taiwan
# 3  South Korea
# 4    Indonesia
# 5  Philippines       20210618
# 6      Vietnam
# 7      Myanmar

# %%
c_trans = pd.merge(countries, df, left_on="country", right_on="location",how="inner")
c_trans.head()
# Out:
#   country text_disp_date iso_code continent location       date  total_cases  \
# 0   Japan                     JPN      Asia    Japan 2020-01-22          2.0
# 1   Japan                     JPN      Asia    Japan 2020-01-23          2.0
# 2   Japan                     JPN      Asia    Japan 2020-01-24          2.0
# 3   Japan                     JPN      Asia    Japan 2020-01-25          2.0
# 4   Japan                     JPN      Asia    Japan 2020-01-26          4.0
#
#    new_cases  new_cases_smoothed  total_deaths  ...  extreme_poverty  \
# 0        NaN                 NaN           NaN  ...              NaN
# 1        0.0                 NaN           NaN  ...              NaN
# 2        0.0                 NaN           NaN  ...              NaN
# 3        0.0                 NaN           NaN  ...              NaN
# 4        2.0                 NaN           NaN  ...              NaN
#
#    cardiovasc_death_rate  diabetes_prevalence  female_smokers  male_smokers  \
# 0                  79.37                 5.72            11.2          33.7
# 1                  79.37                 5.72            11.2          33.7
# 2                  79.37                 5.72            11.2          33.7
# 3                  79.37                 5.72            11.2          33.7
# 4                  79.37                 5.72            11.2          33.7
#
#    handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 0                     NaN                       13.05            84.63
# 1                     NaN                       13.05            84.63
# 2                     NaN                       13.05            84.63
# 3                     NaN                       13.05            84.63
# 4                     NaN                       13.05            84.63
#
#    human_development_index  excess_mortality
# 0                    0.919               NaN
# 1                    0.919               NaN
# 2                    0.919               NaN
# 3                    0.919               NaN
# 4                    0.919               NaN
#
# [5 rows x 62 columns]

# %%
c_trans.location.unique()
# Out:
# array(['Japan', 'United States', 'India', 'Spain', 'Brazil',
#        'United Kingdom', 'Russia', 'Colombia', 'South Africa', 'Iran'],
#       dtype=object)

# %%
c_trans.loc[c_trans.date==latest_date_str][["country","date","total_deaths","total_deaths_per_million"]].sort_values("total_deaths_per_million",ascending=False)
# Out:
# Empty DataFrame
# Columns: [country, date, total_deaths, total_deaths_per_million]
# Index: []

# %%
e_a_trans = pd.merge(e_asia_c, df, left_on="country", right_on="location",how="inner")
e_a_trans
# Out:
#       country text_disp_date iso_code continent location       date  \
# 0       Japan                     JPN      Asia    Japan 2020-01-22
# 1       Japan                     JPN      Asia    Japan 2020-01-23
# 2       Japan                     JPN      Asia    Japan 2020-01-24
# 3       Japan                     JPN      Asia    Japan 2020-01-25
# 4       Japan                     JPN      Asia    Japan 2020-01-26
# ...       ...            ...      ...       ...      ...        ...
# 4320  Myanmar                     MMR      Asia  Myanmar 2021-07-24
# 4321  Myanmar                     MMR      Asia  Myanmar 2021-07-25
# 4322  Myanmar                     MMR      Asia  Myanmar 2021-07-26
# 4323  Myanmar                     MMR      Asia  Myanmar 2021-07-27
# 4324  Myanmar                     MMR      Asia  Myanmar 2021-07-28
#
#       total_cases  new_cases  new_cases_smoothed  total_deaths  ...  \
# 0             2.0        NaN                 NaN           NaN  ...
# 1             2.0        0.0                 NaN           NaN  ...
# 2             2.0        0.0                 NaN           NaN  ...
# 3             2.0        0.0                 NaN           NaN  ...
# 4             4.0        2.0                 NaN           NaN  ...
# ...           ...        ...                 ...           ...  ...
# 4320     264527.0     5657.0            5755.857        6756.0  ...
# 4321     269525.0     4998.0            5714.857        7111.0  ...
# 4322     274155.0     4630.0            5635.000        7507.0  ...
# 4323     279119.0     4964.0            5507.000        7845.0  ...
# 4324     284099.0     4980.0            5348.000        8210.0  ...
#
#       extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# 0                 NaN                 79.370                 5.72
# 1                 NaN                 79.370                 5.72
# 2                 NaN                 79.370                 5.72
# 3                 NaN                 79.370                 5.72
# 4                 NaN                 79.370                 5.72
# ...               ...                    ...                  ...
# 4320              6.4                202.104                 4.61
# 4321              6.4                202.104                 4.61
# 4322              6.4                202.104                 4.61
# 4323              6.4                202.104                 4.61
# 4324              6.4                202.104                 4.61
#
#       female_smokers  male_smokers  handwashing_facilities  \
# 0               11.2          33.7                     NaN
# 1               11.2          33.7                     NaN
# 2               11.2          33.7                     NaN
# 3               11.2          33.7                     NaN
# 4               11.2          33.7                     NaN
# ...              ...           ...                     ...
# 4320             6.3          35.2                  79.287
# 4321             6.3          35.2                  79.287
# 4322             6.3          35.2                  79.287
# 4323             6.3          35.2                  79.287
# 4324             6.3          35.2                  79.287
#
#       hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                          13.05            84.63                    0.919
# 1                          13.05            84.63                    0.919
# 2                          13.05            84.63                    0.919
# 3                          13.05            84.63                    0.919
# 4                          13.05            84.63                    0.919
# ...                          ...              ...                      ...
# 4320                        0.90            67.13                    0.583
# 4321                        0.90            67.13                    0.583
# 4322                        0.90            67.13                    0.583
# 4323                        0.90            67.13                    0.583
# 4324                        0.90            67.13                    0.583
#
#       excess_mortality
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# ...                ...
# 4320               NaN
# 4321               NaN
# 4322               NaN
# 4323               NaN
# 4324               NaN
#
# [4325 rows x 62 columns]

# %%
e_a_trans.location.unique()
# Out:
# array(['Japan', 'China', 'Taiwan', 'South Korea', 'Indonesia',
#        'Philippines', 'Vietnam', 'Myanmar'], dtype=object)

# %% [markdown]
# ## 今日の新規感染者数

# %%
#c_df_latest = df.loc[(df.date==pd.to_datetime(latest_date_str)-datetime.timedelta(days=1)) & (df.iso_code.str.len()==3)]
c_df_latest = df.loc[(df.date==pd.to_datetime(latest_date_str)) & (df.iso_code.str.len()==3)]

c_df_latest
# Out:
#       iso_code continent location       date  total_cases  new_cases  \
# 47572      ISR      Asia   Israel 2021-07-29          NaN        NaN
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 47572                 NaN           NaN         NaN                  NaN  ...
#
#        extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# 47572              0.5                  93.32                 6.74
#
#        female_smokers  male_smokers  handwashing_facilities  \
# 47572            15.4          35.4                     NaN
#
#        hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 47572                        2.99            82.97                    0.919
#
#        excess_mortality
# 47572               NaN
#
# [1 rows x 60 columns]

# %%
c_df_latest.sum()
# Out:
# iso_code                                       ISR
# continent                                     Asia
# location                                    Israel
# total_cases                                    0.0
# new_cases                                      0.0
# new_cases_smoothed                             0.0
# total_deaths                                   0.0
# new_deaths                                     0.0
# new_deaths_smoothed                            0.0
# total_cases_per_million                        0.0
# new_cases_per_million                          0.0
# new_cases_smoothed_per_million                 0.0
# total_deaths_per_million                       0.0
# new_deaths_per_million                         0.0
# new_deaths_smoothed_per_million                0.0
# reproduction_rate                              0.0
# icu_patients                                  33.0
# icu_patients_per_million                     3.813
# hosp_patients                                275.0
# hosp_patients_per_million                   31.772
# weekly_icu_admissions                          0.0
# weekly_icu_admissions_per_million              0.0
# weekly_hosp_admissions                         0.0
# weekly_hosp_admissions_per_million             0.0
# new_tests                                      0.0
# total_tests                                    0.0
# total_tests_per_thousand                       0.0
# new_tests_per_thousand                         0.0
# new_tests_smoothed                             0.0
# new_tests_smoothed_per_thousand                0.0
# positive_rate                                  0.0
# tests_per_case                                 0.0
# tests_units                                      0
# total_vaccinations                             0.0
# people_vaccinated                              0.0
# people_fully_vaccinated                        0.0
# new_vaccinations                               0.0
# new_vaccinations_smoothed                      0.0
# total_vaccinations_per_hundred                 0.0
# people_vaccinated_per_hundred                  0.0
# people_fully_vaccinated_per_hundred            0.0
# new_vaccinations_smoothed_per_million          0.0
# stringency_index                               0.0
# population                               8655541.0
# population_density                         402.606
# median_age                                    30.6
# aged_65_older                               11.733
# aged_70_older                                7.359
# gdp_per_capita                            33132.32
# extreme_poverty                                0.5
# cardiovasc_death_rate                        93.32
# diabetes_prevalence                           6.74
# female_smokers                                15.4
# male_smokers                                  35.4
# handwashing_facilities                         0.0
# hospital_beds_per_thousand                    2.99
# life_expectancy                              82.97
# human_development_index                      0.919
# excess_mortality                               0.0
# dtype: object

# %% [markdown]
# ## 可視化

# %%
import matplotlib.pyplot as plt
#%matplotlib notebook
# %matplotlib inline

# %%
min_date = pd.to_datetime("2021-05-01")

# %%
world_df["case_rolling7ave"] = world_df.new_cases.rolling(7).mean()
world_df[["new_cases_smoothed","case_rolling7ave"]]
# Out:
#         new_cases_smoothed  case_rolling7ave
# 103701                 NaN               NaN
# 103702                 NaN               NaN
# 103703                 NaN               NaN
# 103704                 NaN               NaN
# 103705                 NaN               NaN
# ...                    ...               ...
# 104250          534416.714     534416.714286
# 104251          536910.714     536910.714286
# 104252          542808.857     542808.857143
# 104253          554459.429     554459.428571
# 104254          564769.571     564769.571429
#
# [554 rows x 2 columns]

# %%
fig=plt.figure(figsize=(20,12))
plt.subplot(2,2,1) # (rows, columns, panel number)
plt.title("Daily new confirmed COVID-19 cases in the world")
plt.bar(world_df.date,world_df.new_cases,label="New cases")
plt.plot_date(world_df["date"],world_df["new_cases_smoothed"],label="rolling 7-day average", fmt="-", color="orange")
#plt.xticks(rotation=70)
plt.ylabel("people")
plt.grid(axis="y")
plt.legend()

plt.subplot(2,2,2) # (rows, columns, panel number)
plt.title("Daily new confirmed COVID-19 cases in the world(Recent)")
chart_data = world_df[world_df.date >= min_date]
plt.bar(chart_data["date"],chart_data["new_cases"],label="New cases")
plt.plot_date(chart_data["date"],chart_data["new_cases_smoothed"],label="rolling 7-day average", fmt="-", color="orange")
#plt.xticks(rotation=70)
plt.grid(axis="y")
plt.legend()

plt.subplot(2,2,3) # (rows, columns, panel number)
plt.title("Daily new deaths in the world")
plt.bar(world_df.date,world_df.new_deaths,label="New deaths")
plt.plot_date(world_df["date"],world_df["new_deaths_smoothed"],label="rolling 7-day average", fmt="-", color="orange")
#plt.xticks(rotation=70)
plt.ylabel("people")
plt.grid(axis="y")
plt.legend()

plt.subplot(2,2,4) # (rows, columns, panel number)
plt.title("Daily new deaths in the world(Recent)")
chart_data = world_df[world_df.date >= min_date]
plt.bar(chart_data["date"],chart_data["new_deaths"],label="New deaths")
plt.plot_date(chart_data["date"],chart_data["new_deaths_smoothed"],label="rolling 7-day average", fmt="-", color="orange")
#plt.xticks(rotation=70)
plt.grid(axis="y")
plt.legend()

fig.text(0,1,"Latest: {}".format(latest_date_str),ha="left",va="top")
fig.text(0,0
         ,"*Data Source : COVID-19 Dataset by Our World in Data",
        ha="left",va="bottom")

fig.tight_layout()

# %%
fig.savefig("out/covid-owid-global-daily.png")

# %% [markdown]
# ### 国別

# %% [markdown]
# #### 人口100万人当たりの新規感染者数（直近）

# %%
"""
#min_date = pd.to_datetime("2021-05-01")
# 主要国 新規感染者
chart_data = c_trans[c_trans.date >= min_date]
dates = chart_data["date"].unique()
print(len(dates))
print(dates.max())
for i,cr in countries.iterrows():
    c = cr["country"]
    dates = chart_data.loc[chart_data["location"]==c]["date"]
    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else latest_date_str
    print(len(chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"]))
    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"],label=c, fmt="-")
    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_cases_smoothed_per_million"],c
            ,fontsize=8,va="center")
"""
# Out:
# '\n#min_date = pd.to_datetime("2021-05-01")\n# 主要国 新規感染者\nchart_data = c_trans[c_trans.date >= min_date]\ndates = chart_data["date"].unique()\nprint(len(dates))\nprint(dates.max())\nfor i,cr in countries.iterrows():\n    c = cr["country"]\n    dates = chart_data.loc[chart_data["location"]==c]["date"]\n    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else latest_date_str\n    print(len(chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"]))\n    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"],label=c, fmt="-")\n    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_cases_smoothed_per_million"],c\n            ,fontsize=8,va="center")\n'

# %%
"""
fig=plt.figure(figsize=(14,10))
min_date = pd.to_datetime("2021-03-01")
# 主要国 新規感染者
plt.subplot(2,2,1) # (rows, columns, panel number)
plt.title("Daily new confirmed COVID-19 cases\n per million population in major countries\n(rolling 7day ave.)")
plt.grid()
plt.xticks(rotation=70)
chart_data = c_trans[c_trans.date >= min_date]
dates = chart_data["date"].unique()
for i,cr in countries.iterrows():
    c = cr["country"]
    dates = chart_data.loc[chart_data["location"]==c]["date"]
    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else dates.max()
    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"],label=c, fmt="-")
    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_cases_smoothed_per_million"],c
            ,fontsize=8,va="center")
plt.legend(bbox_to_anchor=(0, 1),loc='upper left', fontsize=9)
"""
# Out:
# '\nfig=plt.figure(figsize=(14,10))\nmin_date = pd.to_datetime("2021-03-01")\n# 主要国 新規感染者\nplt.subplot(2,2,1) # (rows, columns, panel number)\nplt.title("Daily new confirmed COVID-19 cases\n per million population in major countries\n(rolling 7day ave.)")\nplt.grid()\nplt.xticks(rotation=70)\nchart_data = c_trans[c_trans.date >= min_date]\ndates = chart_data["date"].unique()\nfor i,cr in countries.iterrows():\n    c = cr["country"]\n    dates = chart_data.loc[chart_data["location"]==c]["date"]\n    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else dates.max()\n    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"],label=c, fmt="-")\n    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_cases_smoothed_per_million"],c\n            ,fontsize=8,va="center")\nplt.legend(bbox_to_anchor=(0, 1),loc=\'upper left\', fontsize=9)\n'

# %%
fig=plt.figure(figsize=(20,14))
# 主要国 新規感染者
plt.subplot(2,2,1) # (rows, columns, panel number)
plt.title("Daily new confirmed COVID-19 cases\n per million population in major countries\n(rolling 7day ave.)")
plt.grid()
plt.xticks(rotation=45)
chart_data = c_trans[c_trans.date >= min_date]
for i,cr in countries.iterrows():
    c = cr["country"]
    dates = chart_data.loc[chart_data["location"]==c]["date"]
    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else dates.max()
    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"],label=c, fmt="-")
    text_y = chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_cases_smoothed_per_million"]
#    print(text_y)
    print(c,text_disp_date,text_y)
#    plt.text(text_disp_date,text_y,c,fontsize=10,va="center")
    plt.text(text_disp_date,text_y,c,va="center")
plt.legend(bbox_to_anchor=(0, 1),loc='upper left')

# 主要国 死者
plt.subplot(2,2,2) # (rows, columns, panel number)
plt.title("Daily new deaths in major countries(rolling 7day ave.)")
plt.grid()
plt.xticks(rotation=45)
chart_data = c_trans[c_trans.date >= min_date]
for i,cr in countries.iterrows():
    c = cr["country"]
    dates = chart_data.loc[chart_data["location"]==c]["date"]
    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else dates.max()
    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_deaths_smoothed"],label=c, fmt="-")
    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_deaths_smoothed"],c
            ,va="center")
plt.legend(bbox_to_anchor=(0, 1),loc='upper left')

plt.subplot(2,2,3) # (rows, columns, panel number)
plt.grid()
plt.xticks(rotation=45)
plt.title("Daily new confirmed COVID-19 cases\n per million population in Eastern Asia\n(rolling 7day ave.)")
chart_data = e_a_trans[e_a_trans.date >= min_date]
for i,cr in e_asia_c.iterrows():
    c = cr["country"]
    dates = chart_data.loc[chart_data["location"]==c]["date"]
    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else dates.max()
    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"],label=c, fmt="-")
    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_cases_smoothed_per_million"],c
             ,va="center")
plt.legend(bbox_to_anchor=(0, 1),loc='upper left')

plt.subplot(2,2,4) # (rows, columns, panel number)
plt.grid()
plt.xticks(rotation=45)
plt.title("Daily new deaths in Eastern Asia(rolling 7day ave.)")
chart_data = e_a_trans[e_a_trans.date >= min_date]
for i,cr in e_asia_c.iterrows():
    c = cr["country"]
    dates = chart_data.loc[chart_data["location"]==c]["date"]
    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else dates.max()
    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_deaths_smoothed"],label=c, fmt="-")
    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_deaths_smoothed"],c
             ,va="center")
plt.legend(bbox_to_anchor=(0, 1),loc='upper left')

fig.text(0,0.98,"Latest: {}".format(latest_date_str),ha="left",va="top")
fig.text(0,0
         ,"*Data Source : COVID-19 Dataset by Our World in Data",
        ha="left",va="bottom")
fig.tight_layout()
"""
"""
# Out:
# Japan 2021-07-28 00:00:00 553    45.525
# Name: new_cases_smoothed_per_million, dtype: float64
# United States 2021-07-28 00:00:00 1107    192.439
# Name: new_cases_smoothed_per_million, dtype: float64
# India 2021-07-28 00:00:00 1653    27.991
# Name: new_cases_smoothed_per_million, dtype: float64
# Spain 2021-07-28 00:00:00 2197    537.39
# Name: new_cases_smoothed_per_million, dtype: float64
# Brazil 2021-07-28 00:00:00 2716    217.171
# Name: new_cases_smoothed_per_million, dtype: float64
# United Kingdom 2021-07-28 00:00:00 3261    443.451
# Name: new_cases_smoothed_per_million, dtype: float64
# Russia 2021-07-28 00:00:00 3806    157.762
# Name: new_cases_smoothed_per_million, dtype: float64
# Colombia 2021-07-28 00:00:00 4316    216.59
# Name: new_cases_smoothed_per_million, dtype: float64
# South Africa 2021-07-28 00:00:00 4854    153.557
# Name: new_cases_smoothed_per_million, dtype: float64
# Iran 2021-07-28 00:00:00 5380    320.583
# Name: new_cases_smoothed_per_million, dtype: float64
# '\n'

# %%
fig.savefig("out/covid-owid-countries-daily.png")

# %% [markdown]
# ### 新規感染者数

# %%
fig = plt.figure(figsize=(12,14))

plt.subplot(2,2,1) # (rows, columns, panel number)
plt.title("New confirmed COVID-19 cases worst 50")
plt.yticks(fontsize=9)
plt.xlabel("people")
chart_data = c_df_latest.sort_values("new_cases",ascending=False).head(50).sort_values("new_cases",ascending=True)
plt.barh(chart_data["location"],chart_data["new_cases"],label="new cases a day")
plt.grid(axis="x")
mean = int(c_df_latest.new_cases.mean())
plt.plot([mean,mean],[0,50], 'k--', lw=0.5)
plt.text(mean,50,"Mean:{}".format(mean),ha="center",fontsize=9)
plt.legend()

plt.subplot(2,2,2) # (rows, columns, panel number)
plt.title("New confirmed COVID-19 cases per million worst 50")
plt.yticks(fontsize=9)
plt.xlabel("people")
chart_data = c_df_latest.sort_values("new_cases_per_million",ascending=False).head(50).sort_values("new_cases_per_million",ascending=True)
plt.barh(chart_data["location"],chart_data["new_cases_per_million"],label="new cases a day per million")
plt.grid(axis="x")
mean = int(chart_data.new_cases_per_million.mean())
plt.plot([mean,mean],[0,50], 'k--', lw=0.5)
plt.text(mean,50,"Mean:{}".format(mean),ha="center",fontsize=9)
plt.legend()

fig.text(0,0.98,"Latest: {}".format(latest_date_str),fontsize=9,ha="left",va="top")
fig.text(0,0
         ,"*Data Source : COVID-19 Dataset by Our World in Data",
        fontsize=8,ha="left",va="bottom")

plt.subplot(2,2,3) # (rows, columns, panel number)
plt.title("New deaths worst 50")
plt.yticks(fontsize=9)
plt.xlabel("people")
chart_data = c_df_latest.sort_values("new_deaths",ascending=False).head(50).sort_values("new_deaths",ascending=True)
plt.barh(chart_data["location"],chart_data["new_deaths"],label="new deaths a day")
plt.grid(axis="x")
mean = int(c_df_latest.new_deaths.mean())
plt.plot([mean,mean],[0,50], 'k--', lw=0.5)
plt.text(mean,50,"Mean:{}".format(mean),ha="center",fontsize=9)
plt.legend()

plt.subplot(2,2,4) # (rows, columns, panel number)
plt.title("Total deaths per population worst 50")
plt.yticks(fontsize=9)
plt.xlabel("%")
chart_data = c_df_latest.copy()
chart_data["total_deaths_per_poputaion"] = chart_data.total_deaths / chart_data.population * 100
chart_data = chart_data.sort_values("total_deaths_per_poputaion",ascending=False).head(50).sort_values("total_deaths_per_poputaion",ascending=True)
plt.barh(chart_data["location"],chart_data["total_deaths_per_poputaion"],label="total deaths per population")
plt.grid(axis="x")
mean = round(chart_data.total_deaths_per_poputaion.mean(),2)
plt.plot([mean,mean],[0,50], 'k--', lw=0.5)
plt.text(mean,50,"Mean:{}".format(mean),ha="center",fontsize=9)
plt.legend()


fig.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-508293ccaecb> in <module>
#       8 plt.barh(chart_data["location"],chart_data["new_cases"],label="new cases a day")
#       9 plt.grid(axis="x")
# ---> 10 mean = int(c_df_latest.new_cases.mean())
#      11 plt.plot([mean,mean],[0,50], 'k--', lw=0.5)
#      12 plt.text(mean,50,"Mean:{}".format(mean),ha="center",fontsize=9)
#
# ValueError: cannot convert float NaN to integer

# %%
fig.savefig("out/covid-owid-global-latest-top.png")

# %%
a_df = df.loc[df.location=="Japan"]
c_df = df.loc[(df.date==pd.to_datetime("2021-07-27")) & (df.iso_code.str.len()==3)]

# %%
a_df.tail(10)
# Out:
#       iso_code continent location       date  total_cases  new_cases  \
# 49167      JPN      Asia    Japan 2021-07-19     844386.0     2368.0
# 49168      JPN      Asia    Japan 2021-07-20     848222.0     3836.0
# 49169      JPN      Asia    Japan 2021-07-21     853137.0     4915.0
# 49170      JPN      Asia    Japan 2021-07-22     858503.0     5366.0
# 49171      JPN      Asia    Japan 2021-07-23     862585.0     4082.0
# 49172      JPN      Asia    Japan 2021-07-24     866325.0     3740.0
# 49173      JPN      Asia    Japan 2021-07-25     871360.0     5035.0
# 49174      JPN      Asia    Japan 2021-07-26     876059.0     4699.0
# 49175      JPN      Asia    Japan 2021-07-27     883767.0     7708.0
# 49176      JPN      Asia    Japan 2021-07-28     893442.0     9675.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 49167            3113.143       15006.0        13.0               14.429  ...
# 49168            3318.857       15026.0        20.0               14.714  ...
# 49169            3562.286       15046.0        20.0               14.714  ...
# 49170            3840.286       15052.0         6.0               12.429  ...
# 49171            3936.571       15059.0         7.0               11.857  ...
# 49172            3910.286       15068.0         9.0               11.143  ...
# 49173            4191.714       15072.0         4.0               11.286  ...
# 49174            4524.714       15084.0        12.0               11.143  ...
# 49175            5077.857       15096.0        12.0               10.000  ...
# 49176            5757.857       15174.0        78.0               18.286  ...
#
#        extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# 49167              NaN                  79.37                 5.72
# 49168              NaN                  79.37                 5.72
# 49169              NaN                  79.37                 5.72
# 49170              NaN                  79.37                 5.72
# 49171              NaN                  79.37                 5.72
# 49172              NaN                  79.37                 5.72
# 49173              NaN                  79.37                 5.72
# 49174              NaN                  79.37                 5.72
# 49175              NaN                  79.37                 5.72
# 49176              NaN                  79.37                 5.72
#
#        female_smokers  male_smokers  handwashing_facilities  \
# 49167            11.2          33.7                     NaN
# 49168            11.2          33.7                     NaN
# 49169            11.2          33.7                     NaN
# 49170            11.2          33.7                     NaN
# 49171            11.2          33.7                     NaN
# 49172            11.2          33.7                     NaN
# 49173            11.2          33.7                     NaN
# 49174            11.2          33.7                     NaN
# 49175            11.2          33.7                     NaN
# 49176            11.2          33.7                     NaN
#
#        hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 49167                       13.05            84.63                    0.919
# 49168                       13.05            84.63                    0.919
# 49169                       13.05            84.63                    0.919
# 49170                       13.05            84.63                    0.919
# 49171                       13.05            84.63                    0.919
# 49172                       13.05            84.63                    0.919
# 49173                       13.05            84.63                    0.919
# 49174                       13.05            84.63                    0.919
# 49175                       13.05            84.63                    0.919
# 49176                       13.05            84.63                    0.919
#
#        excess_mortality
# 49167               NaN
# 49168               NaN
# 49169               NaN
# 49170               NaN
# 49171               NaN
# 49172               NaN
# 49173               NaN
# 49174               NaN
# 49175               NaN
# 49176               NaN
#
# [10 rows x 60 columns]

# %%
c_df.sort_values("new_deaths",ascending=False).head(50)
# Out:
#        iso_code      continent        location       date  total_cases  \
# 44755       IDN           Asia       Indonesia 2021-07-27    3239936.0
# 13936       BRA  South America          Brazil 2021-07-27   19749073.0
# 79029       RUS         Europe          Russia 2021-07-27    6094379.0
# 44241       IND           Asia           India 2021-07-27   31484605.0
# 62060       MEX  North America          Mexico 2021-07-27    2771846.0
# 100749      USA  North America   United States 2021-07-27   34603919.0
# 45819       IRN           Asia            Iran 2021-07-27    3758197.0
# 65965       MMR           Asia         Myanmar 2021-07-27     279119.0
# 87923       ZAF         Africa    South Africa 2021-07-27    2391223.0
# 20909       COL  South America        Colombia 2021-07-27    4747775.0
# 8659        BGD           Asia      Bangladesh 2021-07-27    1194752.0
# 4349        ARG  South America       Argentina 2021-07-27    4875927.0
# 58673       MYS           Asia        Malaysia 2021-07-27    1044071.0
# 97344       TUN         Africa         Tunisia 2021-07-27     575002.0
# 100195      GBR         Europe  United Kingdom 2021-07-27    5771732.0
# 42111       HND  North America        Honduras 2021-07-27     291687.0
# 95225       THA           Asia        Thailand 2021-07-27     526828.0
# 105722      ZWE         Africa        Zimbabwe 2021-07-27     101711.0
# 75814       PER  South America            Peru 2021-07-27    2106371.0
# 50321       KAZ           Asia      Kazakhstan 2021-07-27     609646.0
# 23961       CUB  North America            Cuba 2021-07-27     349055.0
# 76360       PHL           Asia     Philippines 2021-07-27    1562420.0
# 46340       IRQ           Asia            Iraq 2021-07-27    1577013.0
# 12419       BOL  South America         Bolivia 2021-07-27     470024.0
# 39426       GTM  North America       Guatemala 2021-07-27     355223.0
# 75239       PRY  South America        Paraguay 2021-07-27     450494.0
# 90025       ESP         Europe           Spain 2021-07-27    4368453.0
# 97849       TUR           Asia          Turkey 2021-07-27    5638178.0
# 90574       LKA           Asia       Sri Lanka 2021-07-27     299892.0
# 73216       PAK           Asia        Pakistan 2021-07-27    1015827.0
# 22432       CRI  North America      Costa Rica 2021-07-27     402044.0
# 99103       UKR         Europe         Ukraine 2021-07-27    2327777.0
# 519         AFG           Asia     Afghanistan 2021-07-27     145008.0
# 66467       NAM         Africa         Namibia 2021-07-27     117293.0
# 65476       MOZ         Africa      Mozambique 2021-07-27     113426.0
# 19845       CHL  South America           Chile 2021-07-27    1611090.0
# 34747       FRA         Europe          France 2021-07-27    6088930.0
# 58122       MWI         Africa          Malawi 2021-07-27      49752.0
# 64982       MAR         Africa         Morocco 2021-07-27     588448.0
# 2091        DZA         Africa         Algeria 2021-07-27     165204.0
# 48116       ITA         Europe           Italy 2021-07-27    4325046.0
# 55417       LBY         Africa           Libya 2021-07-27     240309.0
# 105226      ZMB         Africa          Zambia 2021-07-27     192956.0
# 67129       NPL           Asia           Nepal 2021-07-27     685673.0
# 16555       KHM           Asia        Cambodia 2021-07-27      74386.0
# 36995       DEU         Europe         Germany 2021-07-27    3766501.0
# 72696       OMN           Asia            Oman 2021-07-27     295017.0
# 36443       GEO           Asia         Georgia 2021-07-27     407689.0
# 103026      VEN  South America       Venezuela 2021-07-27     301979.0
# 83399       SEN         Africa         Senegal 2021-07-27      58523.0
#
#         new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 44755     45203.0           41411.143       86835.0      2069.0
# 13936     41411.0           47090.857      551835.0      1333.0
# 79029     22486.0           23207.714      152836.0       767.0
# 44241     43654.0           38324.000      422022.0       640.0
# 62060     17408.0           13364.143      239079.0       484.0
# 100749    70740.0           61306.429      611414.0       462.0
# 45819     34951.0           26007.000       89479.0       357.0
# 65965      4964.0            5507.000        7845.0       338.0
# 87923      7733.0           11427.286       70338.0       320.0
# 20909     11426.0           11289.286      119482.0       300.0
# 8659      14925.0            9409.000       19779.0       258.0
# 4349      16757.0           13101.143      104352.0       247.0
# 58673     16117.0           14881.714        8408.0       207.0
# 97344      1608.0            2870.143       18968.0       164.0
# 100195    23401.0           32728.143      129591.0       131.0
# 42111      5052.0            1285.857        7713.0       119.0
# 95225     14150.0           14336.143        4264.0       118.0
# 105722     1767.0            1899.429        3280.0       107.0
# 75814      1366.0            1479.714      196058.0        85.0
# 50321      7249.0            6639.000        5619.0        81.0
# 23961      7903.0            7800.857        2492.0        75.0
# 76360      7024.0            6359.571       27318.0        71.0
# 46340     12185.0            9499.429       18418.0        71.0
# 12419      1601.0             985.571       17716.0        65.0
# 39426      2639.0            2494.429       10176.0        64.0
# 75239       592.0             603.857       14759.0        58.0
# 90025     26399.0           25616.714       81323.0        55.0
# 97849     19761.0           13144.571       51048.0        51.0
# 90574      1711.0            1702.714        4195.0        48.0
# 73216      4119.0            2768.000       23133.0        46.0
# 22432      3436.0            1129.857        4987.0        46.0
# 99103      1227.0            1127.286       55420.0        39.0
# 519         723.0             370.571        6515.0        38.0
# 66467       329.0             550.714        2871.0        37.0
# 65476      1703.0            1631.000        1341.0        34.0
# 19845       745.0            1318.857       35151.0        32.0
# 34747     27128.0           19513.000      111883.0        32.0
# 58122       743.0             724.000        1540.0        27.0
# 64982      6971.0            3718.857        9638.0        27.0
# 2091       1544.0            1345.714        4112.0        25.0
# 48116      4516.0            4566.143      127995.0        24.0
# 55417      3348.0            1944.000        3422.0        24.0
# 105226      640.0             764.857        3316.0        21.0
# 67129      2726.0            2102.857        9758.0        20.0
# 16555       685.0             798.571        1324.0        19.0
# 36995      2060.0            1665.000       91592.0        19.0
# 72696       491.0             853.571        3788.0        17.0
# 36443      3666.0            2392.000        5731.0        17.0
# 103026     1060.0            1159.000        3524.0        15.0
# 83399       642.0             707.143        1300.0        14.0
#
#         new_deaths_smoothed  ...  extreme_poverty  cardiovasc_death_rate  \
# 44755              1519.286  ...              5.7                342.864
# 13936              1093.571  ...              3.4                177.961
# 79029               768.429  ...              0.1                431.297
# 44241               506.000  ...             21.2                282.280
# 62060               324.143  ...              2.5                152.783
# 100749              296.714  ...              1.2                151.089
# 45819               265.000  ...              0.2                270.308
# 65965               325.429  ...              6.4                202.104
# 87923               380.286  ...             18.9                200.380
# 20909               335.857  ...              4.5                124.240
# 8659                207.714  ...             14.8                298.003
# 4349                281.571  ...              0.6                191.032
# 58673               166.714  ...              0.1                260.942
# 97344               163.857  ...              2.0                318.991
# 100195               68.857  ...              0.2                122.137
# 42111                29.429  ...             16.0                240.208
# 95225               108.857  ...              0.1                109.861
# 105722               76.143  ...             21.4                307.846
# 75814               103.714  ...              3.5                 85.755
# 50321                79.571  ...              0.1                466.792
# 23961                67.571  ...              NaN                190.968
# 76360                67.714  ...              NaN                370.437
# 46340                66.714  ...              2.5                218.612
# 12419                34.429  ...              7.1                204.299
# 39426                35.571  ...              8.7                155.898
# 75239                52.143  ...              1.7                199.128
# 90025                25.000  ...              1.0                 99.403
# 97849                56.857  ...              0.2                171.285
# 90574                46.429  ...              0.7                197.093
# 73216                35.000  ...              4.0                423.031
# 22432                10.286  ...              1.3                137.973
# 99103                28.429  ...              0.1                539.849
# 519                  35.571  ...              NaN                597.029
# 66467                44.857  ...             13.4                243.811
# 65476                26.143  ...             62.9                329.942
# 19845                83.143  ...              1.3                127.993
# 34747                24.000  ...              NaN                 86.060
# 58122                25.286  ...             71.4                227.349
# 64982                21.714  ...              1.0                419.146
# 2091                 19.000  ...              0.5                278.364
# 48116                15.857  ...              2.0                113.151
# 55417                16.143  ...              NaN                341.862
# 105226               25.429  ...             57.5                234.499
# 67129                21.571  ...             15.0                260.797
# 16555                25.000  ...              NaN                270.892
# 36995                24.143  ...              NaN                156.139
# 72696                41.429  ...              NaN                266.342
# 36443                19.857  ...              4.2                496.218
# 103026               18.857  ...              NaN                204.850
# 83399                 9.143  ...             38.0                241.219
#
#         diabetes_prevalence  female_smokers  male_smokers  \
# 44755                  6.32             2.8          76.1
# 13936                  8.11            10.1          17.9
# 79029                  6.18            23.4          58.3
# 44241                 10.39             1.9          20.6
# 62060                 13.06             6.9          21.4
# 100749                10.79            19.1          24.6
# 45819                  9.59             0.8          21.1
# 65965                  4.61             6.3          35.2
# 87923                  5.52             8.1          33.2
# 20909                  7.44             4.7          13.5
# 8659                   8.38             1.0          44.7
# 4349                   5.50            16.2          27.7
# 58673                 16.74             1.0          42.4
# 97344                  8.52             1.1          65.8
# 100195                 4.28            20.0          24.7
# 42111                  7.21             2.0           NaN
# 95225                  7.04             1.9          38.8
# 105722                 1.82             1.6          30.7
# 75814                  5.95             4.8           NaN
# 50321                  7.11             7.0          43.1
# 23961                  8.27            17.1          53.3
# 76360                  7.07             7.8          40.8
# 46340                  8.83             NaN           NaN
# 12419                  6.89             NaN           NaN
# 39426                 10.18             NaN           NaN
# 75239                  8.27             5.0          21.6
# 90025                  7.17            27.4          31.4
# 97849                 12.13            14.1          41.1
# 90574                 10.68             0.3          27.0
# 73216                  8.35             2.8          36.7
# 22432                  8.78             6.4          17.4
# 99103                  7.11            13.5          47.4
# 519                    9.59             NaN           NaN
# 66467                  3.94             9.7          34.2
# 65476                  3.30             5.1          29.1
# 19845                  8.46            34.2          41.5
# 34747                  4.77            30.1          35.6
# 58122                  3.94             4.4          24.7
# 64982                  7.14             0.8          47.1
# 2091                   6.73             0.7          30.4
# 48116                  4.78            19.8          27.8
# 55417                 10.43             NaN           NaN
# 105226                 3.94             3.1          24.7
# 67129                  7.26             9.5          37.8
# 16555                  4.00             2.0          33.7
# 36995                  8.31            28.2          33.1
# 72696                 12.61             0.5          15.6
# 36443                  7.11             5.3          55.5
# 103026                 6.47             NaN           NaN
# 83399                  2.42             0.4          16.6
#
#         handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 44755                   64.204                        1.04            71.72
# 13936                      NaN                        2.20            75.88
# 79029                      NaN                        8.05            72.58
# 44241                   59.550                        0.53            69.66
# 62060                   87.847                        1.38            75.05
# 100749                     NaN                        2.77            78.86
# 45819                      NaN                        1.50            76.68
# 65965                   79.287                        0.90            67.13
# 87923                   43.993                        2.32            64.13
# 20909                   65.386                        1.71            77.29
# 8659                    34.808                        0.80            72.59
# 4349                       NaN                        5.00            76.67
# 58673                      NaN                        1.90            76.16
# 97344                   78.687                        2.30            76.70
# 100195                     NaN                        2.54            81.32
# 42111                   84.169                        0.70            75.27
# 95225                   90.670                        2.10            77.15
# 105722                  36.791                        1.70            61.49
# 75814                      NaN                        1.60            76.74
# 50321                   98.999                        6.70            73.60
# 23961                   85.198                        5.20            78.80
# 76360                   78.463                        1.00            71.23
# 46340                   94.576                        1.40            70.60
# 12419                   25.383                        1.10            71.51
# 39426                   76.665                        0.60            74.30
# 75239                   79.602                        1.30            74.25
# 90025                      NaN                        2.97            83.56
# 97849                      NaN                        2.81            77.69
# 90574                      NaN                        3.60            76.98
# 73216                   59.607                        0.60            67.27
# 22432                   83.841                        1.13            80.28
# 99103                      NaN                        8.80            72.06
# 519                     37.746                        0.50            64.83
# 66467                   44.600                         NaN            63.71
# 65476                   12.227                        0.70            60.85
# 19845                      NaN                        2.11            80.18
# 34747                      NaN                        5.98            82.66
# 58122                    8.704                        1.30            64.26
# 64982                      NaN                        1.10            76.68
# 2091                    83.741                        1.90            76.88
# 48116                      NaN                        3.18            83.51
# 55417                      NaN                        3.70            72.91
# 105226                  13.938                        2.00            63.89
# 67129                   47.782                        0.30            70.78
# 16555                   66.229                        0.80            69.82
# 36995                      NaN                        8.00            81.33
# 72696                   97.400                        1.60            77.86
# 36443                      NaN                        2.60            73.77
# 103026                     NaN                        0.80            72.06
# 83399                   20.859                         NaN            67.94
#
#         human_development_index  excess_mortality
# 44755                     0.718               NaN
# 13936                     0.765               NaN
# 79029                     0.824               NaN
# 44241                     0.645               NaN
# 62060                     0.779               NaN
# 100749                    0.926               NaN
# 45819                     0.783               NaN
# 65965                     0.583               NaN
# 87923                     0.709               NaN
# 20909                     0.767               NaN
# 8659                      0.632               NaN
# 4349                      0.845               NaN
# 58673                     0.810               NaN
# 97344                     0.740               NaN
# 100195                    0.932               NaN
# 42111                     0.634               NaN
# 95225                     0.777               NaN
# 105722                    0.571               NaN
# 75814                     0.777               NaN
# 50321                     0.825               NaN
# 23961                     0.783               NaN
# 76360                     0.718               NaN
# 46340                     0.674               NaN
# 12419                     0.718               NaN
# 39426                     0.663               NaN
# 75239                     0.728               NaN
# 90025                     0.904               NaN
# 97849                     0.820               NaN
# 90574                     0.782               NaN
# 73216                     0.557               NaN
# 22432                     0.810               NaN
# 99103                     0.779               NaN
# 519                       0.511               NaN
# 66467                     0.646               NaN
# 65476                     0.456               NaN
# 19845                     0.851               NaN
# 34747                     0.901               NaN
# 58122                     0.483               NaN
# 64982                     0.686               NaN
# 2091                      0.748               NaN
# 48116                     0.892               NaN
# 55417                     0.724               NaN
# 105226                    0.584               NaN
# 67129                     0.602               NaN
# 16555                     0.594               NaN
# 36995                     0.947               NaN
# 72696                     0.813               NaN
# 36443                     0.812               NaN
# 103026                    0.711               NaN
# 83399                     0.512               NaN
#
# [50 rows x 60 columns]

# %%
c_df.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'new_tests', 'total_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'new_vaccinations',
#        'new_vaccinations_smoothed', 'total_vaccinations_per_hundred',
#        'people_vaccinated_per_hundred', 'people_fully_vaccinated_per_hundred',
#        'new_vaccinations_smoothed_per_million', 'stringency_index',
#        'population', 'population_density', 'median_age', 'aged_65_older',
#        'aged_70_older', 'gdp_per_capita', 'extreme_poverty',
#        'cardiovasc_death_rate', 'diabetes_prevalence', 'female_smokers',
#        'male_smokers', 'handwashing_facilities', 'hospital_beds_per_thousand',
#        'life_expectancy', 'human_development_index', 'excess_mortality'],
#       dtype='object')
