# %%
import pandas as pd

# %%
df = pd.read_csv("covid-19-data/public/data/owid-covid-data.csv")
df.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1      AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    female_smokers  male_smokers  handwashing_facilities  \
# 0             NaN           NaN                  37.746
# 1             NaN           NaN                  37.746
# 2             NaN           NaN                  37.746
# 3             NaN           NaN                  37.746
# 4             NaN           NaN                  37.746
#
#    hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                         0.5            64.83                    0.511
# 1                         0.5            64.83                    0.511
# 2                         0.5            64.83                    0.511
# 3                         0.5            64.83                    0.511
# 4                         0.5            64.83                    0.511
#
#    excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                   NaN                          NaN
# 1                                   NaN                          NaN
# 2                                   NaN                          NaN
# 3                                   NaN                          NaN
# 4                                   NaN                          NaN
#
#    excess_mortality  excess_mortality_cumulative_per_million
# 0               NaN                                      NaN
# 1               NaN                                      NaN
# 2               NaN                                      NaN
# 3               NaN                                      NaN
# 4               NaN                                      NaN
#
# [5 rows x 65 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123539 entries, 0 to 123538
# Data columns (total 65 columns):
#  #   Column                                   Non-Null Count   Dtype
# ---  ------                                   --------------   -----
#  0   iso_code                                 123539 non-null  object
#  1   continent                                117934 non-null  object
#  2   location                                 123539 non-null  object
#  3   date                                     123539 non-null  object
#  4   total_cases                              116932 non-null  float64
#  5   new_cases                                116928 non-null  float64
#  6   new_cases_smoothed                       115914 non-null  float64
#  7   total_deaths                             106073 non-null  float64
#  8   new_deaths                               106226 non-null  float64
#  9   new_deaths_smoothed                      115914 non-null  float64
#  10  total_cases_per_million                  116317 non-null  float64
#  11  new_cases_per_million                    116313 non-null  float64
#  12  new_cases_smoothed_per_million           115304 non-null  float64
#  13  total_deaths_per_million                 105471 non-null  float64
#  14  new_deaths_per_million                   105624 non-null  float64
#  15  new_deaths_smoothed_per_million          115304 non-null  float64
#  16  reproduction_rate                        99616 non-null   float64
#  17  icu_patients                             15188 non-null   float64
#  18  icu_patients_per_million                 15188 non-null   float64
#  19  hosp_patients                            17335 non-null   float64
#  20  hosp_patients_per_million                17335 non-null   float64
#  21  weekly_icu_admissions                    1276 non-null    float64
#  22  weekly_icu_admissions_per_million        1276 non-null    float64
#  23  weekly_hosp_admissions                   2099 non-null    float64
#  24  weekly_hosp_admissions_per_million       2099 non-null    float64
#  25  new_tests                                52735 non-null   float64
#  26  total_tests                              52837 non-null   float64
#  27  total_tests_per_thousand                 52837 non-null   float64
#  28  new_tests_per_thousand                   52735 non-null   float64
#  29  new_tests_smoothed                       63453 non-null   float64
#  30  new_tests_smoothed_per_thousand          63453 non-null   float64
#  31  positive_rate                            59569 non-null   float64
#  32  tests_per_case                           58929 non-null   float64
#  33  tests_units                              65397 non-null   object
#  34  total_vaccinations                       28978 non-null   float64
#  35  people_vaccinated                        27547 non-null   float64
#  36  people_fully_vaccinated                  24420 non-null   float64
#  37  total_boosters                           3294 non-null    float64
#  38  new_vaccinations                         24040 non-null   float64
#  39  new_vaccinations_smoothed                51887 non-null   float64
#  40  total_vaccinations_per_hundred           28978 non-null   float64
#  41  people_vaccinated_per_hundred            27547 non-null   float64
#  42  people_fully_vaccinated_per_hundred      24420 non-null   float64
#  43  total_boosters_per_hundred               3294 non-null    float64
#  44  new_vaccinations_smoothed_per_million    51887 non-null   float64
#  45  stringency_index                         103149 non-null  float64
#  46  population                               122668 non-null  float64
#  47  population_density                       114119 non-null  float64
#  48  median_age                               108920 non-null  float64
#  49  aged_65_older                            107712 non-null  float64
#  50  aged_70_older                            108324 non-null  float64
#  51  gdp_per_capita                           109566 non-null  float64
#  52  extreme_poverty                          73356 non-null   float64
#  53  cardiovasc_death_rate                    109193 non-null  float64
#  54  diabetes_prevalence                      112631 non-null  float64
#  55  female_smokers                           85092 non-null   float64
#  56  male_smokers                             83858 non-null   float64
#  57  handwashing_facilities                   54958 non-null   float64
#  58  hospital_beds_per_thousand               99275 non-null   float64
#  59  life_expectancy                          117175 non-null  float64
#  60  human_development_index                  109287 non-null  float64
#  61  excess_mortality_cumulative_absolute     4494 non-null    float64
#  62  excess_mortality_cumulative              4494 non-null    float64
#  63  excess_mortality                         4494 non-null    float64
#  64  excess_mortality_cumulative_per_million  4494 non-null    float64
# dtypes: float64(60), object(5)
# memory usage: 61.3+ MB

# %%
df.describe()
# Out:
#         total_cases      new_cases  new_cases_smoothed  total_deaths  \
# count  1.169320e+05  116928.000000       115914.000000  1.060730e+05
# mean   1.470301e+06    6453.694222         6476.966786  3.707613e+04
# std    9.825325e+06   39259.333618        38870.207302  2.208234e+05
# min    1.000000e+00  -74347.000000        -6223.000000  1.000000e+00
# 25%    2.051750e+03       3.000000            9.429000  6.900000e+01
# 50%    2.147200e+04      93.000000          116.000000  6.140000e+02
# 75%    2.201828e+05     931.000000          983.250250  5.346000e+03
# max    2.391679e+08  905955.000000       826438.429000  4.874258e+06
#
#           new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  106226.000000        115914.000000            116317.000000
# mean      144.526698           131.884621             18230.281818
# std       788.051680           738.136351             30838.076193
# min     -1918.000000          -232.143000                 0.001000
# 25%         0.000000             0.000000               359.415000
# 50%         2.000000             1.714000              2820.902000
# 75%        19.000000            15.857000             22302.856000
# max     17978.000000         14722.857000            220665.251000
#
#        new_cases_per_million  new_cases_smoothed_per_million  \
# count          116313.000000                   115304.000000
# mean               84.014054                       84.115859
# std               195.045736                      164.554944
# min             -3125.829000                     -272.971000
# 25%                 0.290000                        1.570000
# 50%                10.813000                       14.956500
# 75%                81.945000                       91.508500
# max              8620.690000                     3385.473000
#
#        total_deaths_per_million  ...  female_smokers  male_smokers  \
# count             105471.000000  ...    85092.000000  83858.000000
# mean                 379.408308  ...       10.591460     32.740613
# std                  637.917010  ...       10.504611     13.507392
# min                    0.001000  ...        0.100000      7.700000
# 25%                   10.544000  ...        1.900000     21.600000
# 50%                   70.693000  ...        6.300000     31.400000
# 75%                  464.036500  ...       19.300000     41.100000
# max                 5987.695000  ...       44.000000     78.100000
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# count            54958.000000                99275.000000    117175.000000
# mean                50.894977                    3.031066        73.257625
# std                 31.826175                    2.457407         7.535979
# min                  1.188000                    0.100000        53.280000
# 25%                 20.859000                    1.300000        67.920000
# 50%                 49.839000                    2.400000        74.620000
# 75%                 83.241000                    4.000000        78.740000
# max                100.000000                   13.800000        86.750000
#
#        human_development_index  excess_mortality_cumulative_absolute  \
# count            109287.000000                           4494.000000
# mean                  0.726400                          29717.778238
# std                   0.150081                          84270.522270
# min                   0.394000                         -31959.400000
# 25%                   0.602000                           -236.350000
# 50%                   0.744000                           1789.450000
# 75%                   0.848000                          18552.800000
# max                   0.957000                         746026.500000
#
#        excess_mortality_cumulative  excess_mortality  \
# count                  4494.000000       4494.000000
# mean                      8.240681         15.502345
# std                      15.763349         31.220916
# min                     -27.350000        -95.920000
# 25%                      -1.260000         -1.200000
# 50%                       4.795000          6.075000
# 75%                      13.315000         21.617500
# max                     106.830000        373.280000
#
#        excess_mortality_cumulative_per_million
# count                              4494.000000
# mean                                723.937534
# std                                1111.831698
# min                               -1728.844404
# 25%                                 -52.268601
# 50%                                 293.322962
# 75%                                1254.375796
# max                                6109.081949
#
# [8 rows x 60 columns]

# %%
df.continent.unique()
# Out:
# array(['Asia', nan, 'Europe', 'Africa', 'North America', 'South America',
#        'Oceania'], dtype=object)

# %%
df.loc[df.continent.isna()].location.unique()
# Out:
# array(['Africa', 'Asia', 'Europe', 'European Union', 'International',
#        'North America', 'Oceania', 'South America', 'World'], dtype=object)

# %%
df.loc[df.location=="International"]
# Out:
#        iso_code continent       location        date  total_cases  new_cases  \
# 52220  OWID_INT       NaN  International  2020-02-07         61.0       61.0
# 52221  OWID_INT       NaN  International  2020-02-08         61.0        0.0
# 52222  OWID_INT       NaN  International  2020-02-09         64.0        3.0
# 52223  OWID_INT       NaN  International  2020-02-10        135.0       71.0
# 52224  OWID_INT       NaN  International  2020-02-11        135.0        0.0
# ...         ...       ...            ...         ...          ...        ...
# 52830  OWID_INT       NaN  International  2021-10-09        721.0        0.0
# 52831  OWID_INT       NaN  International  2021-10-10        721.0        0.0
# 52832  OWID_INT       NaN  International  2021-10-11        721.0        0.0
# 52833  OWID_INT       NaN  International  2021-10-12        721.0        0.0
# 52834  OWID_INT       NaN  International  2021-10-13        721.0        0.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 52220                 NaN           NaN         NaN                  NaN  ...
# 52221                 NaN           NaN         NaN                  NaN  ...
# 52222                 NaN           NaN         NaN                  NaN  ...
# 52223                 NaN           NaN         NaN                  NaN  ...
# 52224                 NaN           NaN         NaN                  NaN  ...
# ...                   ...           ...         ...                  ...  ...
# 52830                 0.0          15.0         0.0                  0.0  ...
# 52831                 0.0          15.0         0.0                  0.0  ...
# 52832                 0.0          15.0         0.0                  0.0  ...
# 52833                 0.0          15.0         0.0                  0.0  ...
# 52834                 0.0          15.0         0.0                  0.0  ...
#
#        female_smokers  male_smokers  handwashing_facilities  \
# 52220             NaN           NaN                     NaN
# 52221             NaN           NaN                     NaN
# 52222             NaN           NaN                     NaN
# 52223             NaN           NaN                     NaN
# 52224             NaN           NaN                     NaN
# ...               ...           ...                     ...
# 52830             NaN           NaN                     NaN
# 52831             NaN           NaN                     NaN
# 52832             NaN           NaN                     NaN
# 52833             NaN           NaN                     NaN
# 52834             NaN           NaN                     NaN
#
#        hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 52220                         NaN              NaN                      NaN
# 52221                         NaN              NaN                      NaN
# 52222                         NaN              NaN                      NaN
# 52223                         NaN              NaN                      NaN
# 52224                         NaN              NaN                      NaN
# ...                           ...              ...                      ...
# 52830                         NaN              NaN                      NaN
# 52831                         NaN              NaN                      NaN
# 52832                         NaN              NaN                      NaN
# 52833                         NaN              NaN                      NaN
# 52834                         NaN              NaN                      NaN
#
#        excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 52220                                   NaN                          NaN
# 52221                                   NaN                          NaN
# 52222                                   NaN                          NaN
# 52223                                   NaN                          NaN
# 52224                                   NaN                          NaN
# ...                                     ...                          ...
# 52830                                   NaN                          NaN
# 52831                                   NaN                          NaN
# 52832                                   NaN                          NaN
# 52833                                   NaN                          NaN
# 52834                                   NaN                          NaN
#
#        excess_mortality  excess_mortality_cumulative_per_million
# 52220               NaN                                      NaN
# 52221               NaN                                      NaN
# 52222               NaN                                      NaN
# 52223               NaN                                      NaN
# 52224               NaN                                      NaN
# ...                 ...                                      ...
# 52830               NaN                                      NaN
# 52831               NaN                                      NaN
# 52832               NaN                                      NaN
# 52833               NaN                                      NaN
# 52834               NaN                                      NaN
#
# [615 rows x 65 columns]

# %%
df.location.unique()
# Out:
# array(['Afghanistan', 'Africa', 'Albania', 'Algeria', 'Andorra', 'Angola',
#        'Anguilla', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        'Asia', 'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain',
#        'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin',
#        'Bermuda', 'Bhutan', 'Bolivia', 'Bonaire Sint Eustatius and Saba',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Brunei', 'Bulgaria', 'Burkina Faso',
#        'Burundi', 'Cambodia', 'Cameroon', 'Canada', 'Cape Verde',
#        'Cayman Islands', 'Central African Republic', 'Chad', 'Chile',
#        'China', 'Colombia', 'Comoros', 'Congo', 'Cook Islands',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Curacao',
#        'Cyprus', 'Czechia', 'Democratic Republic of Congo', 'Denmark',
#        'Djibouti', 'Dominica', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Estonia',
#        'Eswatini', 'Ethiopia', 'Europe', 'European Union',
#        'Faeroe Islands', 'Falkland Islands', 'Fiji', 'Finland', 'France',
#        'French Polynesia', 'Gabon', 'Gambia', 'Georgia', 'Germany',
#        'Ghana', 'Gibraltar', 'Greece', 'Greenland', 'Grenada',
#        'Guatemala', 'Guernsey', 'Guinea', 'Guinea-Bissau', 'Guyana',
#        'Haiti', 'Honduras', 'Hong Kong', 'Hungary', 'Iceland', 'India',
#        'Indonesia', 'International', 'Iran', 'Iraq', 'Ireland',
#        'Isle of Man', 'Israel', 'Italy', 'Jamaica', 'Japan', 'Jersey',
#        'Jordan', 'Kazakhstan', 'Kenya', 'Kiribati', 'Kosovo', 'Kuwait',
#        'Kyrgyzstan', 'Laos', 'Latvia', 'Lebanon', 'Lesotho', 'Liberia',
#        'Libya', 'Liechtenstein', 'Lithuania', 'Luxembourg', 'Macao',
#        'Madagascar', 'Malawi', 'Malaysia', 'Maldives', 'Mali', 'Malta',
#        'Marshall Islands', 'Mauritania', 'Mauritius', 'Mexico',
#        'Micronesia (country)', 'Moldova', 'Monaco', 'Mongolia',
#        'Montenegro', 'Montserrat', 'Morocco', 'Mozambique', 'Myanmar',
#        'Namibia', 'Nauru', 'Nepal', 'Netherlands', 'New Caledonia',
#        'New Zealand', 'Nicaragua', 'Niger', 'Nigeria', 'Niue',
#        'North America', 'North Macedonia', 'Northern Cyprus', 'Norway',
#        'Oceania', 'Oman', 'Pakistan', 'Palau', 'Palestine', 'Panama',
#        'Papua New Guinea', 'Paraguay', 'Peru', 'Philippines', 'Pitcairn',
#        'Poland', 'Portugal', 'Qatar', 'Romania', 'Russia', 'Rwanda',
#        'Saint Helena', 'Saint Kitts and Nevis', 'Saint Lucia',
#        'Saint Vincent and the Grenadines', 'Samoa', 'San Marino',
#        'Sao Tome and Principe', 'Saudi Arabia', 'Senegal', 'Serbia',
#        'Seychelles', 'Sierra Leone', 'Singapore',
#        'Sint Maarten (Dutch part)', 'Slovakia', 'Slovenia',
#        'Solomon Islands', 'Somalia', 'South Africa', 'South America',
#        'South Korea', 'South Sudan', 'Spain', 'Sri Lanka', 'Sudan',
#        'Suriname', 'Sweden', 'Switzerland', 'Syria', 'Taiwan',
#        'Tajikistan', 'Tanzania', 'Thailand', 'Timor', 'Togo', 'Tokelau',
#        'Tonga', 'Trinidad and Tobago', 'Tunisia', 'Turkey',
#        'Turkmenistan', 'Turks and Caicos Islands', 'Tuvalu', 'Uganda',
#        'Ukraine', 'United Arab Emirates', 'United Kingdom',
#        'United States', 'Uruguay', 'Uzbekistan', 'Vanuatu', 'Vatican',
#        'Venezuela', 'Vietnam', 'Wallis and Futuna', 'World', 'Yemen',
#        'Zambia', 'Zimbabwe'], dtype=object)

# %%
df["date"] = pd.to_datetime(df["date"])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123539 entries, 0 to 123538
# Data columns (total 65 columns):
#  #   Column                                   Non-Null Count   Dtype
# ---  ------                                   --------------   -----
#  0   iso_code                                 123539 non-null  object
#  1   continent                                117934 non-null  object
#  2   location                                 123539 non-null  object
#  3   date                                     123539 non-null  datetime64[ns]
#  4   total_cases                              116932 non-null  float64
#  5   new_cases                                116928 non-null  float64
#  6   new_cases_smoothed                       115914 non-null  float64
#  7   total_deaths                             106073 non-null  float64
#  8   new_deaths                               106226 non-null  float64
#  9   new_deaths_smoothed                      115914 non-null  float64
#  10  total_cases_per_million                  116317 non-null  float64
#  11  new_cases_per_million                    116313 non-null  float64
#  12  new_cases_smoothed_per_million           115304 non-null  float64
#  13  total_deaths_per_million                 105471 non-null  float64
#  14  new_deaths_per_million                   105624 non-null  float64
#  15  new_deaths_smoothed_per_million          115304 non-null  float64
#  16  reproduction_rate                        99616 non-null   float64
#  17  icu_patients                             15188 non-null   float64
#  18  icu_patients_per_million                 15188 non-null   float64
#  19  hosp_patients                            17335 non-null   float64
#  20  hosp_patients_per_million                17335 non-null   float64
#  21  weekly_icu_admissions                    1276 non-null    float64
#  22  weekly_icu_admissions_per_million        1276 non-null    float64
#  23  weekly_hosp_admissions                   2099 non-null    float64
#  24  weekly_hosp_admissions_per_million       2099 non-null    float64
#  25  new_tests                                52735 non-null   float64
#  26  total_tests                              52837 non-null   float64
#  27  total_tests_per_thousand                 52837 non-null   float64
#  28  new_tests_per_thousand                   52735 non-null   float64
#  29  new_tests_smoothed                       63453 non-null   float64
#  30  new_tests_smoothed_per_thousand          63453 non-null   float64
#  31  positive_rate                            59569 non-null   float64
#  32  tests_per_case                           58929 non-null   float64
#  33  tests_units                              65397 non-null   object
#  34  total_vaccinations                       28978 non-null   float64
#  35  people_vaccinated                        27547 non-null   float64
#  36  people_fully_vaccinated                  24420 non-null   float64
#  37  total_boosters                           3294 non-null    float64
#  38  new_vaccinations                         24040 non-null   float64
#  39  new_vaccinations_smoothed                51887 non-null   float64
#  40  total_vaccinations_per_hundred           28978 non-null   float64
#  41  people_vaccinated_per_hundred            27547 non-null   float64
#  42  people_fully_vaccinated_per_hundred      24420 non-null   float64
#  43  total_boosters_per_hundred               3294 non-null    float64
#  44  new_vaccinations_smoothed_per_million    51887 non-null   float64
#  45  stringency_index                         103149 non-null  float64
#  46  population                               122668 non-null  float64
#  47  population_density                       114119 non-null  float64
#  48  median_age                               108920 non-null  float64
#  49  aged_65_older                            107712 non-null  float64
#  50  aged_70_older                            108324 non-null  float64
#  51  gdp_per_capita                           109566 non-null  float64
#  52  extreme_poverty                          73356 non-null   float64
#  53  cardiovasc_death_rate                    109193 non-null  float64
#  54  diabetes_prevalence                      112631 non-null  float64
#  55  female_smokers                           85092 non-null   float64
#  56  male_smokers                             83858 non-null   float64
#  57  handwashing_facilities                   54958 non-null   float64
#  58  hospital_beds_per_thousand               99275 non-null   float64
#  59  life_expectancy                          117175 non-null  float64
#  60  human_development_index                  109287 non-null  float64
#  61  excess_mortality_cumulative_absolute     4494 non-null    float64
#  62  excess_mortality_cumulative              4494 non-null    float64
#  63  excess_mortality                         4494 non-null    float64
#  64  excess_mortality_cumulative_per_million  4494 non-null    float64
# dtypes: datetime64[ns](1), float64(60), object(4)
# memory usage: 61.3+ MB

# %% [markdown]
# ## 最新日付チェック

# %%
import datetime
#latest_date_str = (df.date.max()-datetime.timedelta(days=1)).strftime("%Y-%m-%d")
latest_date_str = df.date.max().strftime("%Y-%m-%d")
latest_date_str
# Out:
# '2021-10-13'

# %% [markdown]
# ## 全世界のデータのみ

# %%
world_df = df.copy().loc[df.location=="World"]
world_df.tail()
# Out:
#         iso_code continent location       date  total_cases  new_cases  \
# 121834  OWID_WRL       NaN    World 2021-10-09  237578599.0   329269.0
# 121835  OWID_WRL       NaN    World 2021-10-10  237879268.0   300669.0
# 121836  OWID_WRL       NaN    World 2021-10-11  238272643.0   393375.0
# 121837  OWID_WRL       NaN    World 2021-10-12  238705193.0   432550.0
# 121838  OWID_WRL       NaN    World 2021-10-13  239167859.0   462666.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 121834          417272.857     4847106.0      4674.0             6966.571
# 121835          418504.429     4851586.0      4480.0             7033.000
# 121836          409207.429     4857420.0      5834.0             6818.857
# 121837          411372.571     4865619.0      8199.0             6955.143
# 121838          404155.143     4874258.0      8639.0             6838.571
#
#         ...  female_smokers  male_smokers  handwashing_facilities  \
# 121834  ...           6.434        34.635                   60.13
# 121835  ...           6.434        34.635                   60.13
# 121836  ...           6.434        34.635                   60.13
# 121837  ...           6.434        34.635                   60.13
# 121838  ...           6.434        34.635                   60.13
#
#         hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 121834                       2.705            72.58                    0.737
# 121835                       2.705            72.58                    0.737
# 121836                       2.705            72.58                    0.737
# 121837                       2.705            72.58                    0.737
# 121838                       2.705            72.58                    0.737
#
#         excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 121834                                   NaN                          NaN
# 121835                                   NaN                          NaN
# 121836                                   NaN                          NaN
# 121837                                   NaN                          NaN
# 121838                                   NaN                          NaN
#
#         excess_mortality  excess_mortality_cumulative_per_million
# 121834               NaN                                      NaN
# 121835               NaN                                      NaN
# 121836               NaN                                      NaN
# 121837               NaN                                      NaN
# 121838               NaN                                      NaN
#
# [5 rows x 65 columns]

# %% [markdown]
# ### 主要国の定義

# %%
countries = pd.DataFrame([
    ("Japan",""),
    ("United States",""),
    ("India",""),
    ("Indonesia",""),
    ("Spain",""),
    ("Brazil",""),
    ("France",""),
    ("United Kingdom",""),
    ("Russia",""),
    ("Turkey",""),
#    ("South Africa",""),
    ("Iran",""),
#    ("Ecuador",""),
],columns=["country","text_disp_date"])
countries
# Out:
#            country text_disp_date
# 0            Japan
# 1    United States
# 2            India
# 3        Indonesia
# 4            Spain
# 5           Brazil
# 6           France
# 7   United Kingdom
# 8           Russia
# 9           Turkey
# 10            Iran

# %%
# 東Asia 主要国
e_asia_c = pd.DataFrame([
    ("Japan",""),
    ("China",""),
    ("Taiwan",""),
    ("South Korea",""),
    ("Indonesia",""),
    ("Philippines",""),
    ("Vietnam",""),
    ("Myanmar","20210718"),
    ("Thailand",""),
],columns=["country","text_disp_date"])
e_asia_c
# Out:
#        country text_disp_date
# 0        Japan
# 1        China
# 2       Taiwan
# 3  South Korea
# 4    Indonesia
# 5  Philippines
# 6      Vietnam
# 7      Myanmar       20210718
# 8     Thailand

# %%
c_trans = pd.merge(countries, df, left_on="country", right_on="location",how="inner")
c_trans.head()
# Out:
#   country text_disp_date iso_code continent location       date  total_cases  \
# 0   Japan                     JPN      Asia    Japan 2020-01-22          2.0
# 1   Japan                     JPN      Asia    Japan 2020-01-23          2.0
# 2   Japan                     JPN      Asia    Japan 2020-01-24          2.0
# 3   Japan                     JPN      Asia    Japan 2020-01-25          2.0
# 4   Japan                     JPN      Asia    Japan 2020-01-26          4.0
#
#    new_cases  new_cases_smoothed  total_deaths  ...  female_smokers  \
# 0        NaN                 NaN           NaN  ...            11.2
# 1        0.0                 NaN           NaN  ...            11.2
# 2        0.0                 NaN           NaN  ...            11.2
# 3        0.0                 NaN           NaN  ...            11.2
# 4        2.0                 NaN           NaN  ...            11.2
#
#    male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 0          33.7                     NaN                       13.05
# 1          33.7                     NaN                       13.05
# 2          33.7                     NaN                       13.05
# 3          33.7                     NaN                       13.05
# 4          33.7                     NaN                       13.05
#
#    life_expectancy  human_development_index  \
# 0            84.63                    0.919
# 1            84.63                    0.919
# 2            84.63                    0.919
# 3            84.63                    0.919
# 4            84.63                    0.919
#
#    excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                   NaN                          NaN
# 1                                   NaN                          NaN
# 2                                   NaN                          NaN
# 3                                   NaN                          NaN
# 4                                   NaN                          NaN
#
#    excess_mortality  excess_mortality_cumulative_per_million
# 0               NaN                                      NaN
# 1               NaN                                      NaN
# 2               NaN                                      NaN
# 3               NaN                                      NaN
# 4               NaN                                      NaN
#
# [5 rows x 67 columns]

# %%
c_trans.location.unique()
# Out:
# array(['Japan', 'United States', 'India', 'Indonesia', 'Spain', 'Brazil',
#        'France', 'United Kingdom', 'Russia', 'Turkey', 'Iran'],
#       dtype=object)

# %%
c_trans.loc[c_trans.date==latest_date_str][["country","date","total_deaths","total_deaths_per_million"]].sort_values("total_deaths_per_million",ascending=False)
# Out:
#              country       date  total_deaths  total_deaths_per_million
# 3692          Brazil 2021-10-13      601574.0                  2811.180
# 1261   United States 2021-10-13      719558.0                  2161.386
# 4943  United Kingdom 2021-10-13      138487.0                  2030.389
# 3096           Spain 2021-10-13       86869.0                  1858.351
# 4321          France 2021-10-13      118080.0                  1747.670
# 5565          Russia 2021-10-13      215438.0                  1476.492
# 6750            Iran 2021-10-13      123275.0                  1449.804
# 6147          Turkey 2021-10-13       66841.0                   785.970
# 2475       Indonesia 2021-10-13      142811.0                   516.754
# 1884           India 2021-10-13      451435.0                   323.979
# 630            Japan 2021-10-13       18032.0                   143.053

# %%
e_a_trans = pd.merge(e_asia_c, df, left_on="country", right_on="location",how="inner")
e_a_trans
# Out:
#        country text_disp_date iso_code continent  location       date  \
# 0        Japan                     JPN      Asia     Japan 2020-01-22
# 1        Japan                     JPN      Asia     Japan 2020-01-23
# 2        Japan                     JPN      Asia     Japan 2020-01-24
# 3        Japan                     JPN      Asia     Japan 2020-01-25
# 4        Japan                     JPN      Asia     Japan 2020-01-26
# ...        ...            ...      ...       ...       ...        ...
# 5585  Thailand                     THA      Asia  Thailand 2021-10-09
# 5586  Thailand                     THA      Asia  Thailand 2021-10-10
# 5587  Thailand                     THA      Asia  Thailand 2021-10-11
# 5588  Thailand                     THA      Asia  Thailand 2021-10-12
# 5589  Thailand                     THA      Asia  Thailand 2021-10-13
#
#       total_cases  new_cases  new_cases_smoothed  total_deaths  ...  \
# 0             2.0        NaN                 NaN           NaN  ...
# 1             2.0        0.0                 NaN           NaN  ...
# 2             2.0        0.0                 NaN           NaN  ...
# 3             2.0        0.0                 NaN           NaN  ...
# 4             4.0        2.0                 NaN           NaN  ...
# ...           ...        ...                 ...           ...  ...
# 5585    1700067.0    10630.0           10494.714       17607.0  ...
# 5586    1710884.0    10817.0           10493.143       17691.0  ...
# 5587    1720919.0    10035.0           10508.143       17751.0  ...
# 5588    1730364.0     9445.0           10447.571       17835.0  ...
# 5589    1740428.0    10064.0            8875.857       17917.0  ...
#
#       female_smokers  male_smokers  handwashing_facilities  \
# 0               11.2          33.7                     NaN
# 1               11.2          33.7                     NaN
# 2               11.2          33.7                     NaN
# 3               11.2          33.7                     NaN
# 4               11.2          33.7                     NaN
# ...              ...           ...                     ...
# 5585             1.9          38.8                   90.67
# 5586             1.9          38.8                   90.67
# 5587             1.9          38.8                   90.67
# 5588             1.9          38.8                   90.67
# 5589             1.9          38.8                   90.67
#
#       hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                          13.05            84.63                    0.919
# 1                          13.05            84.63                    0.919
# 2                          13.05            84.63                    0.919
# 3                          13.05            84.63                    0.919
# 4                          13.05            84.63                    0.919
# ...                          ...              ...                      ...
# 5585                        2.10            77.15                    0.777
# 5586                        2.10            77.15                    0.777
# 5587                        2.10            77.15                    0.777
# 5588                        2.10            77.15                    0.777
# 5589                        2.10            77.15                    0.777
#
#       excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                      NaN                          NaN
# 1                                      NaN                          NaN
# 2                                      NaN                          NaN
# 3                                      NaN                          NaN
# 4                                      NaN                          NaN
# ...                                    ...                          ...
# 5585                                   NaN                          NaN
# 5586                                   NaN                          NaN
# 5587                                   NaN                          NaN
# 5588                                   NaN                          NaN
# 5589                                   NaN                          NaN
#
#       excess_mortality  excess_mortality_cumulative_per_million
# 0                  NaN                                      NaN
# 1                  NaN                                      NaN
# 2                  NaN                                      NaN
# 3                  NaN                                      NaN
# 4                  NaN                                      NaN
# ...                ...                                      ...
# 5585               NaN                                      NaN
# 5586               NaN                                      NaN
# 5587               NaN                                      NaN
# 5588               NaN                                      NaN
# 5589               NaN                                      NaN
#
# [5590 rows x 67 columns]

# %%
e_a_trans.location.unique()
# Out:
# array(['Japan', 'China', 'Taiwan', 'South Korea', 'Indonesia',
#        'Philippines', 'Vietnam', 'Myanmar', 'Thailand'], dtype=object)

# %% [markdown]
# ## 今日の新規感染者数

# %%
#c_df_latest = df.loc[(df.date==pd.to_datetime(latest_date_str)-datetime.timedelta(days=1)) & (df.iso_code.str.len()==3)]
c_df_latest = df.loc[(df.date==pd.to_datetime(latest_date_str)) & (df.iso_code.str.len()==3)]

c_df_latest
# Out:
#        iso_code      continent     location       date  total_cases  \
# 597         AFG           Asia  Afghanistan 2021-10-13     155627.0
# 1803        ALB         Europe      Albania 2021-10-13     176172.0
# 2400        DZA         Africa      Algeria 2021-10-13     204900.0
# 2991        AND         Europe      Andorra 2021-10-13      15314.0
# 3564        AGO         Africa       Angola 2021-10-13      62143.0
# ...         ...            ...          ...        ...          ...
# 120373      VEN  South America    Venezuela 2021-10-13     385952.0
# 121003      VNM           Asia      Vietnam 2021-10-13     849691.0
# 122390      YEM           Asia        Yemen 2021-10-13       9439.0
# 122965      ZMB         Africa       Zambia 2021-10-13     209411.0
# 123538      ZWE         Africa     Zimbabwe 2021-10-13     132108.0
#
#         new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 597          28.0              35.286        7234.0         4.0
# 1803        508.0             426.000        2788.0         5.0
# 2400        110.0             104.143        5862.0         3.0
# 2991          7.0               4.286         130.0         0.0
# 3564        349.0             242.143        1650.0         8.0
# ...           ...                 ...           ...         ...
# 120373     1284.0            1159.857        4652.0        18.0
# 121003     3461.0            3857.714       20869.0       106.0
# 122390       27.0              24.000        1789.0         2.0
# 122965       15.0              23.286        3657.0         3.0
# 123538       92.0              96.286        4648.0         3.0
#
#         new_deaths_smoothed  ...  female_smokers  male_smokers  \
# 597                   2.000  ...             NaN           NaN
# 1803                  7.714  ...             7.1          51.2
# 2400                  3.429  ...             0.7          30.4
# 2991                  0.000  ...            29.0          37.8
# 3564                  7.429  ...             NaN           NaN
# ...                     ...  ...             ...           ...
# 120373               13.429  ...             NaN           NaN
# 121003              110.143  ...             1.0          45.9
# 122390                3.714  ...             7.6          29.2
# 122965                0.714  ...             3.1          24.7
# 123538                2.571  ...             1.6          30.7
#
#         handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 597                     37.746                        0.50            64.83
# 1803                       NaN                        2.89            78.57
# 2400                    83.741                        1.90            76.88
# 2991                       NaN                         NaN            83.73
# 3564                    26.664                         NaN            61.15
# ...                        ...                         ...              ...
# 120373                     NaN                        0.80            72.06
# 121003                  85.847                        2.60            75.40
# 122390                  49.542                        0.70            66.12
# 122965                  13.938                        2.00            63.89
# 123538                  36.791                        1.70            61.49
#
#         human_development_index  excess_mortality_cumulative_absolute  \
# 597                       0.511                                   NaN
# 1803                      0.795                                   NaN
# 2400                      0.748                                   NaN
# 2991                      0.868                                   NaN
# 3564                      0.581                                   NaN
# ...                         ...                                   ...
# 120373                    0.711                                   NaN
# 121003                    0.704                                   NaN
# 122390                    0.470                                   NaN
# 122965                    0.584                                   NaN
# 123538                    0.571                                   NaN
#
#         excess_mortality_cumulative  excess_mortality  \
# 597                             NaN               NaN
# 1803                            NaN               NaN
# 2400                            NaN               NaN
# 2991                            NaN               NaN
# 3564                            NaN               NaN
# ...                             ...               ...
# 120373                          NaN               NaN
# 121003                          NaN               NaN
# 122390                          NaN               NaN
# 122965                          NaN               NaN
# 123538                          NaN               NaN
#
#         excess_mortality_cumulative_per_million
# 597                                         NaN
# 1803                                        NaN
# 2400                                        NaN
# 2991                                        NaN
# 3564                                        NaN
# ...                                         ...
# 120373                                      NaN
# 121003                                      NaN
# 122390                                      NaN
# 122965                                      NaN
# 123538                                      NaN
#
# [200 rows x 65 columns]

# %%
c_df_latest.sum()
# Out:
# iso_code                                   AFGALBDZAANDAGOATGARGARMABWAUSAUTAZEBHSBHRBGDB...
# continent                                  AsiaEuropeAfricaEuropeAfricaNorth AmericaSouth...
# location                                   AfghanistanAlbaniaAlgeriaAndorraAngolaAntigua ...
# total_cases                                                                      239005809.0
# new_cases                                                                           462637.0
#                                                                  ...
# human_development_index                                                              135.098
# excess_mortality_cumulative_absolute                                                     0.0
# excess_mortality_cumulative                                                              0.0
# excess_mortality                                                                         0.0
# excess_mortality_cumulative_per_million                                                  0.0
# Length: 64, dtype: object

# %% [markdown]
# ## 可視化

# %%
import matplotlib.pyplot as plt
#%matplotlib notebook
# %matplotlib inline

# %%
min_date = pd.to_datetime("2021-07-01")

# %%
world_df["case_rolling7ave"] = world_df.new_cases.rolling(7).mean()
world_df[["new_cases_smoothed","case_rolling7ave"]]
# Out:
#         new_cases_smoothed  case_rolling7ave
# 121208                 NaN               NaN
# 121209                 NaN               NaN
# 121210                 NaN               NaN
# 121211                 NaN               NaN
# 121212                 NaN               NaN
# ...                    ...               ...
# 121834          417272.857     417272.857143
# 121835          418504.429     418504.428571
# 121836          409207.429     409207.428571
# 121837          411372.571     411372.571429
# 121838          404155.143     404155.142857
#
# [631 rows x 2 columns]

# %%
fig=plt.figure(figsize=(20,12))
plt.subplot(2,2,1) # (rows, columns, panel number)
plt.title("Daily new confirmed COVID-19 cases in the world")
plt.bar(world_df.date,world_df.new_cases,label="New cases")
plt.plot_date(world_df["date"],world_df["new_cases_smoothed"],label="rolling 7-day average", fmt="-", color="orange")
#plt.xticks(rotation=70)
plt.ylabel("people")
plt.grid(axis="y")
plt.legend()

plt.subplot(2,2,2) # (rows, columns, panel number)
plt.title("Daily new confirmed COVID-19 cases in the world(Recent)")
chart_data = world_df[world_df.date >= min_date]
plt.bar(chart_data["date"],chart_data["new_cases"],label="New cases")
plt.plot_date(chart_data["date"],chart_data["new_cases_smoothed"],label="rolling 7-day average", fmt="-", color="orange")
#plt.xticks(rotation=70)
plt.grid(axis="y")
plt.legend()

plt.subplot(2,2,3) # (rows, columns, panel number)
plt.title("Daily new deaths in the world")
plt.bar(world_df.date,world_df.new_deaths,label="New deaths")
plt.plot_date(world_df["date"],world_df["new_deaths_smoothed"],label="rolling 7-day average", fmt="-", color="orange")
#plt.xticks(rotation=70)
plt.ylabel("people")
plt.grid(axis="y")
plt.legend()

plt.subplot(2,2,4) # (rows, columns, panel number)
plt.title("Daily new deaths in the world(Recent)")
chart_data = world_df[world_df.date >= min_date]
plt.bar(chart_data["date"],chart_data["new_deaths"],label="New deaths")
plt.plot_date(chart_data["date"],chart_data["new_deaths_smoothed"],label="rolling 7-day average", fmt="-", color="orange")
#plt.xticks(rotation=70)
plt.grid(axis="y")
plt.legend()

fig.text(0,1,"Latest: {}".format(latest_date_str),ha="left",va="top")
fig.text(0,0
         ,"*Data Source : COVID-19 Dataset by Our World in Data",
        ha="left",va="bottom")

fig.tight_layout()

# %%
fig.savefig("out/covid-owid-global-daily.png")

# %% [markdown]
# ### 国別

# %% [markdown]
# #### 人口100万人当たりの新規感染者数（直近）

# %%
"""
#min_date = pd.to_datetime("2021-05-01")
# 主要国 新規感染者
chart_data = c_trans[c_trans.date >= min_date]
dates = chart_data["date"].unique()
print(len(dates))
print(dates.max())
for i,cr in countries.iterrows():
    c = cr["country"]
    dates = chart_data.loc[chart_data["location"]==c]["date"]
    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else latest_date_str
    print(len(chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"]))
    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"],label=c, fmt="-")
    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_cases_smoothed_per_million"],c
            ,fontsize=8,va="center")
"""
# Out:
# '\n#min_date = pd.to_datetime("2021-05-01")\n# 主要国 新規感染者\nchart_data = c_trans[c_trans.date >= min_date]\ndates = chart_data["date"].unique()\nprint(len(dates))\nprint(dates.max())\nfor i,cr in countries.iterrows():\n    c = cr["country"]\n    dates = chart_data.loc[chart_data["location"]==c]["date"]\n    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else latest_date_str\n    print(len(chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"]))\n    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"],label=c, fmt="-")\n    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_cases_smoothed_per_million"],c\n            ,fontsize=8,va="center")\n'

# %%
"""
fig=plt.figure(figsize=(14,10))
min_date = pd.to_datetime("2021-03-01")
# 主要国 新規感染者
plt.subplot(2,2,1) # (rows, columns, panel number)
plt.title("Daily new confirmed COVID-19 cases\n per million population in major countries\n(rolling 7day ave.)")
plt.grid()
plt.xticks(rotation=70)
chart_data = c_trans[c_trans.date >= min_date]
dates = chart_data["date"].unique()
for i,cr in countries.iterrows():
    c = cr["country"]
    dates = chart_data.loc[chart_data["location"]==c]["date"]
    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else dates.max()
    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"],label=c, fmt="-")
    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_cases_smoothed_per_million"],c
            ,fontsize=8,va="center")
plt.legend(bbox_to_anchor=(0, 1),loc='upper left', fontsize=9)
"""
# Out:
# '\nfig=plt.figure(figsize=(14,10))\nmin_date = pd.to_datetime("2021-03-01")\n# 主要国 新規感染者\nplt.subplot(2,2,1) # (rows, columns, panel number)\nplt.title("Daily new confirmed COVID-19 cases\n per million population in major countries\n(rolling 7day ave.)")\nplt.grid()\nplt.xticks(rotation=70)\nchart_data = c_trans[c_trans.date >= min_date]\ndates = chart_data["date"].unique()\nfor i,cr in countries.iterrows():\n    c = cr["country"]\n    dates = chart_data.loc[chart_data["location"]==c]["date"]\n    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else dates.max()\n    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"],label=c, fmt="-")\n    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_cases_smoothed_per_million"],c\n            ,fontsize=8,va="center")\nplt.legend(bbox_to_anchor=(0, 1),loc=\'upper left\', fontsize=9)\n'

# %%
fig=plt.figure(figsize=(20,14))
# 主要国 新規感染者
plt.subplot(2,2,1) # (rows, columns, panel number)
plt.title("Daily new confirmed COVID-19 cases\n per million population in major countries\n(rolling 7day ave.)")
plt.grid()
plt.xticks(rotation=45)
chart_data = c_trans[c_trans.date >= min_date]
for i,cr in countries.iterrows():
    c = cr["country"]
    dates = chart_data.loc[chart_data["location"]==c]["date"]
    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else dates.max()
    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"],label=c, fmt="-")
    text_y = chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_cases_smoothed_per_million"]
#    print(text_y)
    print(c,text_disp_date,text_y)
#    plt.text(text_disp_date,text_y,c,fontsize=10,va="center")
    plt.text(text_disp_date,text_y,c,va="center")
plt.legend(bbox_to_anchor=(0, 1),loc='upper left')

# 主要国 死者
plt.subplot(2,2,2) # (rows, columns, panel number)
plt.title("Daily new deaths in major countries(rolling 7day ave.)")
plt.grid()
plt.xticks(rotation=45)
chart_data = c_trans[c_trans.date >= min_date]
for i,cr in countries.iterrows():
    c = cr["country"]
    dates = chart_data.loc[chart_data["location"]==c]["date"]
    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else dates.max()
    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_deaths_smoothed"],label=c, fmt="-")
    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_deaths_smoothed"],c
            ,va="center")
plt.legend(bbox_to_anchor=(0, 1),loc='upper left')

plt.subplot(2,2,3) # (rows, columns, panel number)
plt.grid()
plt.xticks(rotation=45)
plt.title("Daily new confirmed COVID-19 cases\n per million population in Eastern Asia\n(rolling 7day ave.)")
chart_data = e_a_trans[e_a_trans.date >= min_date]
for i,cr in e_asia_c.iterrows():
    c = cr["country"]
    dates = chart_data.loc[chart_data["location"]==c]["date"]
    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else dates.max()
    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"],label=c, fmt="-")
    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_cases_smoothed_per_million"],c
             ,va="center")
plt.legend(bbox_to_anchor=(0, 1),loc='upper left')

plt.subplot(2,2,4) # (rows, columns, panel number)
plt.grid()
plt.xticks(rotation=45)
plt.title("Daily new deaths in Eastern Asia(rolling 7day ave.)")
chart_data = e_a_trans[e_a_trans.date >= min_date]
for i,cr in e_asia_c.iterrows():
    c = cr["country"]
    dates = chart_data.loc[chart_data["location"]==c]["date"]
    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else dates.max()
    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_deaths_smoothed"],label=c, fmt="-")
    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_deaths_smoothed"],c
             ,va="center")
plt.legend(bbox_to_anchor=(0, 1),loc='upper left')

fig.text(0,0.98,"Latest: {}".format(latest_date_str),ha="left",va="top")
fig.text(0,0
         ,"*Data Source : COVID-19 Dataset by Our World in Data",
        ha="left",va="bottom")
fig.tight_layout()
"""
"""
# Out:
# Japan 2021-10-13 00:00:00 630    5.482
# Name: new_cases_smoothed_per_million, dtype: float64
# United States 2021-10-13 00:00:00 1261    268.332
# Name: new_cases_smoothed_per_million, dtype: float64
# India 2021-10-13 00:00:00 1884    12.961
# Name: new_cases_smoothed_per_million, dtype: float64
# Indonesia 2021-10-13 00:00:00 2475    4.111
# Name: new_cases_smoothed_per_million, dtype: float64
# Spain 2021-10-13 00:00:00 3096    32.709
# Name: new_cases_smoothed_per_million, dtype: float64
# Brazil 2021-10-13 00:00:00 3692    54.062
# Name: new_cases_smoothed_per_million, dtype: float64
# France 2021-10-13 00:00:00 4321    58.668
# Name: new_cases_smoothed_per_million, dtype: float64
# United Kingdom 2021-10-13 00:00:00 4943    560.115
# Name: new_cases_smoothed_per_million, dtype: float64
# Russia 2021-10-13 00:00:00 5565    189.894
# Name: new_cases_smoothed_per_million, dtype: float64
# Turkey 2021-10-13 00:00:00 6147    357.595
# Name: new_cases_smoothed_per_million, dtype: float64
# Iran 2021-10-13 00:00:00 6750    133.778
# Name: new_cases_smoothed_per_million, dtype: float64
# '\n'

# %%
fig.savefig("out/covid-owid-countries-daily.png")

# %% [markdown]
# ### 新規感染者数

# %%
fig = plt.figure(figsize=(12,14))

plt.subplot(2,2,1) # (rows, columns, panel number)
plt.title("New confirmed COVID-19 cases worst 50")
plt.yticks(fontsize=9)
plt.xlabel("people")
chart_data = c_df_latest.sort_values("new_cases",ascending=False).head(50).sort_values("new_cases",ascending=True)
plt.barh(chart_data["location"],chart_data["new_cases"],label="new cases a day")
plt.grid(axis="x")
mean = int(c_df_latest.new_cases.mean())
plt.plot([mean,mean],[0,50], 'k--', lw=0.5)
plt.text(mean,50,"Mean:{}".format(mean),ha="center",fontsize=9)
plt.legend()

plt.subplot(2,2,2) # (rows, columns, panel number)
plt.title("New confirmed COVID-19 cases per million worst 50")
plt.yticks(fontsize=9)
plt.xlabel("people")
chart_data = c_df_latest.sort_values("new_cases_per_million",ascending=False).head(50).sort_values("new_cases_per_million",ascending=True)
plt.barh(chart_data["location"],chart_data["new_cases_per_million"],label="new cases a day per million")
plt.grid(axis="x")
mean = int(chart_data.new_cases_per_million.mean())
plt.plot([mean,mean],[0,50], 'k--', lw=0.5)
plt.text(mean,50,"Mean:{}".format(mean),ha="center",fontsize=9)
plt.legend()

fig.text(0,0.98,"Latest: {}".format(latest_date_str),fontsize=9,ha="left",va="top")
fig.text(0,0
         ,"*Data Source : COVID-19 Dataset by Our World in Data",
        fontsize=8,ha="left",va="bottom")

plt.subplot(2,2,3) # (rows, columns, panel number)
plt.title("New deaths worst 50")
plt.yticks(fontsize=9)
plt.xlabel("people")
chart_data = c_df_latest.sort_values("new_deaths",ascending=False).head(50).sort_values("new_deaths",ascending=True)
plt.barh(chart_data["location"],chart_data["new_deaths"],label="new deaths a day")
plt.grid(axis="x")
mean = int(c_df_latest.new_deaths.mean())
plt.plot([mean,mean],[0,50], 'k--', lw=0.5)
plt.text(mean,50,"Mean:{}".format(mean),ha="center",fontsize=9)
plt.legend()

plt.subplot(2,2,4) # (rows, columns, panel number)
plt.title("Total deaths per capita worst 50")
plt.yticks(fontsize=9)
plt.xlabel("%")
chart_data = c_df_latest.copy()
chart_data["total_deaths_per_capita"] = chart_data.total_deaths / chart_data.population * 100
chart_data = chart_data.sort_values("total_deaths_per_capita",ascending=False).head(50).sort_values("total_deaths_per_capita",ascending=True)
plt.barh(chart_data["location"],chart_data["total_deaths_per_capita"],label="total deaths per capita")
plt.grid(axis="x")
mean = round(chart_data.total_deaths_per_capita.mean(),2)
plt.plot([mean,mean],[0,50], 'k--', lw=0.5)
plt.text(mean,50,"Mean:{}".format(mean),ha="center",fontsize=9)
plt.legend()


fig.tight_layout()

# %%
fig.savefig("out/covid-owid-global-latest-top.png")

# %%
a_df = df.loc[df.location=="Japan"]
c_df = df.loc[(df.date==pd.to_datetime("2021-07-27")) & (df.iso_code.str.len()==3)]

# %%
a_df.tail(10)
# Out:
#       iso_code continent location       date  total_cases  new_cases  \
# 57322      JPN      Asia    Japan 2021-10-04    1706525.0      606.0
# 57323      JPN      Asia    Japan 2021-10-05    1707511.0      986.0
# 57324      JPN      Asia    Japan 2021-10-06    1708634.0     1123.0
# 57325      JPN      Asia    Japan 2021-10-07    1709603.0      969.0
# 57326      JPN      Asia    Japan 2021-10-08    1710426.0      823.0
# 57327      JPN      Asia    Japan 2021-10-09    1711207.0      781.0
# 57328      JPN      Asia    Japan 2021-10-10    1711756.0      549.0
# 57329      JPN      Asia    Japan 2021-10-11    1712127.0      371.0
# 57330      JPN      Asia    Japan 2021-10-12    1712740.0      613.0
# 57331      JPN      Asia    Japan 2021-10-13    1713471.0      731.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 57322            1364.857       17771.0        24.0               35.286  ...
# 57323            1259.714       17807.0        36.0               33.286  ...
# 57324            1135.286       17833.0        26.0               30.143  ...
# 57325            1049.714       17872.0        39.0               29.714  ...
# 57326             960.000       17918.0        46.0               31.429  ...
# 57327             892.714       17945.0        27.0               30.714  ...
# 57328             833.857       17952.0         7.0               29.286  ...
# 57329             800.286       17972.0        20.0               28.714  ...
# 57330             747.000       17999.0        27.0               27.429  ...
# 57331             691.000       18032.0        33.0               28.429  ...
#
#        female_smokers  male_smokers  handwashing_facilities  \
# 57322            11.2          33.7                     NaN
# 57323            11.2          33.7                     NaN
# 57324            11.2          33.7                     NaN
# 57325            11.2          33.7                     NaN
# 57326            11.2          33.7                     NaN
# 57327            11.2          33.7                     NaN
# 57328            11.2          33.7                     NaN
# 57329            11.2          33.7                     NaN
# 57330            11.2          33.7                     NaN
# 57331            11.2          33.7                     NaN
#
#        hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 57322                       13.05            84.63                    0.919
# 57323                       13.05            84.63                    0.919
# 57324                       13.05            84.63                    0.919
# 57325                       13.05            84.63                    0.919
# 57326                       13.05            84.63                    0.919
# 57327                       13.05            84.63                    0.919
# 57328                       13.05            84.63                    0.919
# 57329                       13.05            84.63                    0.919
# 57330                       13.05            84.63                    0.919
# 57331                       13.05            84.63                    0.919
#
#        excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 57322                                   NaN                          NaN
# 57323                                   NaN                          NaN
# 57324                                   NaN                          NaN
# 57325                                   NaN                          NaN
# 57326                                   NaN                          NaN
# 57327                                   NaN                          NaN
# 57328                                   NaN                          NaN
# 57329                                   NaN                          NaN
# 57330                                   NaN                          NaN
# 57331                                   NaN                          NaN
#
#        excess_mortality  excess_mortality_cumulative_per_million
# 57322               NaN                                      NaN
# 57323               NaN                                      NaN
# 57324               NaN                                      NaN
# 57325               NaN                                      NaN
# 57326               NaN                                      NaN
# 57327               NaN                                      NaN
# 57328               NaN                                      NaN
# 57329               NaN                                      NaN
# 57330               NaN                                      NaN
# 57331               NaN                                      NaN
#
# [10 rows x 65 columns]

# %%
c_df.sort_values("new_deaths",ascending=False).head(50)
# Out:
#        iso_code      continent        location       date  total_cases  \
# 52141       IDN           Asia       Indonesia 2021-07-27    3239936.0
# 16230       BRA  South America          Brazil 2021-07-27   19749073.0
# 92082       RUS         Europe          Russia 2021-07-27    6094379.0
# 51550       IND           Asia           India 2021-07-27   31484605.0
# 72256       MEX  North America          Mexico 2021-07-27    2771846.0
# 117633      USA  North America   United States 2021-07-27   34667713.0
# 53359       IRN           Asia            Iran 2021-07-27    3758197.0
# 76854       MMR           Asia         Myanmar 2021-07-27     279119.0
# 102430      ZAF         Africa    South Africa 2021-07-27    2391223.0
# 24359       COL  South America        Colombia 2021-07-27    4747775.0
# 9961        BGD           Asia      Bangladesh 2021-07-27    1194752.0
# 4958        ARG  South America       Argentina 2021-07-27    4875927.0
# 68358       MYS           Asia        Malaysia 2021-07-27    1044071.0
# 113420      TUN         Africa         Tunisia 2021-07-27     575002.0
# 117002      GBR         Europe  United Kingdom 2021-07-27    5771732.0
# 110809      THA           Asia        Thailand 2021-07-27     526828.0
# 123460      ZWE         Africa        Zimbabwe 2021-07-27     101711.0
# 88371       PER  South America            Peru 2021-07-27    2106371.0
# 27950       CUB  North America            Cuba 2021-07-27     349055.0
# 88994       PHL           Asia     Philippines 2021-07-27    1562420.0
# 53957       IRQ           Asia            Iraq 2021-07-27    1577013.0
# 14337       BOL  South America         Bolivia 2021-07-27     470024.0
# 45964       GTM  North America       Guatemala 2021-07-27     355223.0
# 49111       HND  North America        Honduras 2021-07-27     291687.0
# 87719       PRY  South America        Paraguay 2021-07-27     450494.0
# 104840      ESP         Europe           Spain 2021-07-27    4368453.0
# 114002      TUR           Asia          Turkey 2021-07-27    5638178.0
# 105466      LKA           Asia       Sri Lanka 2021-07-27     299892.0
# 85335       PAK           Asia        Pakistan 2021-07-27    1015827.0
# 26190       CRI  North America      Costa Rica 2021-07-27     402044.0
# 115756      UKR         Europe         Ukraine 2021-07-27    2327777.0
# 519         AFG           Asia     Afghanistan 2021-07-27     145008.0
# 77433       NAM         Africa         Namibia 2021-07-27     117293.0
# 76288       MOZ         Africa      Mozambique 2021-07-27     113426.0
# 23141       CHL  South America           Chile 2021-07-27    1611090.0
# 40436       FRA         Europe          France 2021-07-27    6089097.0
# 67729       MWI         Africa          Malawi 2021-07-27      49752.0
# 75717       MAR         Africa         Morocco 2021-07-27     588448.0
# 2322        DZA         Africa         Algeria 2021-07-27     165204.0
# 64572       LBY         Africa           Libya 2021-07-27     240309.0
# 56040       ITA         Europe           Italy 2021-07-27    4325046.0
# 122887      ZMB         Africa          Zambia 2021-07-27     192956.0
# 78207       NPL           Asia           Nepal 2021-07-27     685673.0
# 19311       KHM           Asia        Cambodia 2021-07-27      74386.0
# 43069       DEU         Europe         Germany 2021-07-27    3766501.0
# 42440       GEO           Asia         Georgia 2021-07-27     407689.0
# 84738       OMN           Asia            Oman 2021-07-27     295017.0
# 120295      VEN  South America       Venezuela 2021-07-27     301979.0
# 97143       SEN         Africa         Senegal 2021-07-27      58523.0
# 61118       KGZ           Asia      Kyrgyzstan 2021-07-27     159089.0
#
#         new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 52141     45203.0           41411.143       86835.0      2069.0
# 16230     41411.0           47090.857      551835.0      1333.0
# 92082     22486.0           23207.714      152836.0       767.0
# 51550     43654.0           38324.000      422022.0       640.0
# 72256     17408.0           13364.143      239079.0       484.0
# 117633    68414.0           61429.857      611592.0       444.0
# 53359     34951.0           26007.000       89479.0       357.0
# 76854      4964.0            5507.000        7845.0       338.0
# 102430     7733.0           11427.286       70338.0       320.0
# 24359     11426.0           11289.286      119482.0       300.0
# 9961      14925.0            9409.000       19779.0       258.0
# 4958      16757.0           13101.143      104352.0       247.0
# 68358     16117.0           14881.714        8408.0       207.0
# 113420     1608.0            2870.143       18968.0       164.0
# 117002    23401.0           32728.143      129591.0       131.0
# 110809    14150.0           14336.143        4264.0       118.0
# 123460     1767.0            1899.429        3280.0       107.0
# 88371      1366.0            1479.714      196058.0        85.0
# 27950      7903.0            7800.857        2492.0        75.0
# 88994      7024.0            6359.571       27318.0        71.0
# 53957     12185.0            9499.429       18418.0        71.0
# 14337      1601.0             985.571       17716.0        65.0
# 45964      2639.0            2494.429       10176.0        64.0
# 49111      1240.0            1285.857        7713.0        63.0
# 87719       592.0             603.857       14759.0        58.0
# 104840    26399.0           25616.714       81323.0        55.0
# 114002    19761.0           13144.571       51048.0        51.0
# 105466     1711.0            1702.714        4195.0        48.0
# 85335      4119.0            2768.000       23133.0        46.0
# 26190      3436.0            1129.857        4987.0        46.0
# 115756     1227.0            1127.286       55420.0        39.0
# 519         723.0             370.571        6515.0        38.0
# 77433       329.0             550.714        2871.0        37.0
# 76288      1703.0            1631.000        1341.0        34.0
# 23141       745.0            1318.857       35151.0        32.0
# 40436     27128.0           19515.286      111881.0        29.0
# 67729       743.0             724.000        1540.0        27.0
# 75717      6971.0            3718.857        9638.0        27.0
# 2322       1544.0            1345.714        4112.0        25.0
# 64572      3348.0            1944.000        3422.0        24.0
# 56040      4516.0            4566.143      127995.0        24.0
# 122887      640.0             764.857        3316.0        21.0
# 78207      2726.0            2102.857        9758.0        20.0
# 19311       685.0             798.571        1324.0        19.0
# 43069      2060.0            1665.000       91592.0        19.0
# 42440      3666.0            2392.000        5731.0        17.0
# 84738       491.0             853.571        3788.0        17.0
# 120295     1060.0            1159.000        3524.0        15.0
# 97143       642.0             707.143        1300.0        14.0
# 61118       969.0            1068.857        2275.0        14.0
#
#         new_deaths_smoothed  ...  female_smokers  male_smokers  \
# 52141              1519.286  ...             2.8          76.1
# 16230              1093.571  ...            10.1          17.9
# 92082               768.429  ...            23.4          58.3
# 51550               506.000  ...             1.9          20.6
# 72256               324.143  ...             6.9          21.4
# 117633              299.000  ...            19.1          24.6
# 53359               265.000  ...             0.8          21.1
# 76854               325.429  ...             6.3          35.2
# 102430              380.286  ...             8.1          33.2
# 24359               335.857  ...             4.7          13.5
# 9961                207.714  ...             1.0          44.7
# 4958                281.571  ...            16.2          27.7
# 68358               166.714  ...             1.0          42.4
# 113420              163.857  ...             1.1          65.8
# 117002               68.857  ...            20.0          24.7
# 110809              108.857  ...             1.9          38.8
# 123460               76.143  ...             1.6          30.7
# 88371               103.714  ...             4.8           NaN
# 27950                67.571  ...            17.1          53.3
# 88994                67.714  ...             7.8          40.8
# 53957                66.714  ...             NaN           NaN
# 14337                34.429  ...             NaN           NaN
# 45964                35.571  ...             NaN           NaN
# 49111                29.429  ...             2.0           NaN
# 87719                52.143  ...             5.0          21.6
# 104840               25.000  ...            27.4          31.4
# 114002               56.857  ...            14.1          41.1
# 105466               46.429  ...             0.3          27.0
# 85335                35.000  ...             2.8          36.7
# 26190                10.286  ...             6.4          17.4
# 115756               28.429  ...            13.5          47.4
# 519                  35.571  ...             NaN           NaN
# 77433                44.857  ...             9.7          34.2
# 76288                26.143  ...             5.1          29.1
# 23141                83.143  ...            34.2          41.5
# 40436                24.857  ...            30.1          35.6
# 67729                25.286  ...             4.4          24.7
# 75717                21.714  ...             0.8          47.1
# 2322                 19.000  ...             0.7          30.4
# 64572                16.143  ...             NaN           NaN
# 56040                15.857  ...            19.8          27.8
# 122887               25.429  ...             3.1          24.7
# 78207                21.571  ...             9.5          37.8
# 19311                25.000  ...             2.0          33.7
# 43069                24.143  ...            28.2          33.1
# 42440                19.857  ...             5.3          55.5
# 84738                41.429  ...             0.5          15.6
# 120295               18.857  ...             NaN           NaN
# 97143                 9.143  ...             0.4          16.6
# 61118                11.286  ...             3.6          50.5
#
#         handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 52141                   64.204                        1.04            71.72
# 16230                      NaN                        2.20            75.88
# 92082                      NaN                        8.05            72.58
# 51550                   59.550                        0.53            69.66
# 72256                   87.847                        1.38            75.05
# 117633                     NaN                        2.77            78.86
# 53359                      NaN                        1.50            76.68
# 76854                   79.287                        0.90            67.13
# 102430                  43.993                        2.32            64.13
# 24359                   65.386                        1.71            77.29
# 9961                    34.808                        0.80            72.59
# 4958                       NaN                        5.00            76.67
# 68358                      NaN                        1.90            76.16
# 113420                  78.687                        2.30            76.70
# 117002                     NaN                        2.54            81.32
# 110809                  90.670                        2.10            77.15
# 123460                  36.791                        1.70            61.49
# 88371                      NaN                        1.60            76.74
# 27950                   85.198                        5.20            78.80
# 88994                   78.463                        1.00            71.23
# 53957                   94.576                        1.40            70.60
# 14337                   25.383                        1.10            71.51
# 45964                   76.665                        0.60            74.30
# 49111                   84.169                        0.70            75.27
# 87719                   79.602                        1.30            74.25
# 104840                     NaN                        2.97            83.56
# 114002                     NaN                        2.81            77.69
# 105466                     NaN                        3.60            76.98
# 85335                   59.607                        0.60            67.27
# 26190                   83.841                        1.13            80.28
# 115756                     NaN                        8.80            72.06
# 519                     37.746                        0.50            64.83
# 77433                   44.600                         NaN            63.71
# 76288                   12.227                        0.70            60.85
# 23141                      NaN                        2.11            80.18
# 40436                      NaN                        5.98            82.66
# 67729                    8.704                        1.30            64.26
# 75717                      NaN                        1.10            76.68
# 2322                    83.741                        1.90            76.88
# 64572                      NaN                        3.70            72.91
# 56040                      NaN                        3.18            83.51
# 122887                  13.938                        2.00            63.89
# 78207                   47.782                        0.30            70.78
# 19311                   66.229                        0.80            69.82
# 43069                      NaN                        8.00            81.33
# 42440                      NaN                        2.60            73.77
# 84738                   97.400                        1.60            77.86
# 120295                     NaN                        0.80            72.06
# 97143                   20.859                         NaN            67.94
# 61118                   89.220                        4.50            71.45
#
#         human_development_index  excess_mortality_cumulative_absolute  \
# 52141                     0.718                                   NaN
# 16230                     0.765                                   NaN
# 92082                     0.824                                   NaN
# 51550                     0.645                                   NaN
# 72256                     0.779                                   NaN
# 117633                    0.926                                   NaN
# 53359                     0.783                                   NaN
# 76854                     0.583                                   NaN
# 102430                    0.709                                   NaN
# 24359                     0.767                                   NaN
# 9961                      0.632                                   NaN
# 4958                      0.845                                   NaN
# 68358                     0.810                                   NaN
# 113420                    0.740                                   NaN
# 117002                    0.932                                   NaN
# 110809                    0.777                                   NaN
# 123460                    0.571                                   NaN
# 88371                     0.777                                   NaN
# 27950                     0.783                                   NaN
# 88994                     0.718                                   NaN
# 53957                     0.674                                   NaN
# 14337                     0.718                                   NaN
# 45964                     0.663                                   NaN
# 49111                     0.634                                   NaN
# 87719                     0.728                                   NaN
# 104840                    0.904                                   NaN
# 114002                    0.820                                   NaN
# 105466                    0.782                                   NaN
# 85335                     0.557                                   NaN
# 26190                     0.810                                   NaN
# 115756                    0.779                                   NaN
# 519                       0.511                                   NaN
# 77433                     0.646                                   NaN
# 76288                     0.456                                   NaN
# 23141                     0.851                                   NaN
# 40436                     0.901                                   NaN
# 67729                     0.483                                   NaN
# 75717                     0.686                                   NaN
# 2322                      0.748                                   NaN
# 64572                     0.724                                   NaN
# 56040                     0.892                                   NaN
# 122887                    0.584                                   NaN
# 78207                     0.602                                   NaN
# 19311                     0.594                                   NaN
# 43069                     0.947                                   NaN
# 42440                     0.812                                   NaN
# 84738                     0.813                                   NaN
# 120295                    0.711                                   NaN
# 97143                     0.512                                   NaN
# 61118                     0.697                                   NaN
#
#         excess_mortality_cumulative  excess_mortality  \
# 52141                           NaN               NaN
# 16230                           NaN               NaN
# 92082                           NaN               NaN
# 51550                           NaN               NaN
# 72256                           NaN               NaN
# 117633                          NaN               NaN
# 53359                           NaN               NaN
# 76854                           NaN               NaN
# 102430                          NaN               NaN
# 24359                           NaN               NaN
# 9961                            NaN               NaN
# 4958                            NaN               NaN
# 68358                           NaN               NaN
# 113420                          NaN               NaN
# 117002                          NaN               NaN
# 110809                          NaN               NaN
# 123460                          NaN               NaN
# 88371                           NaN               NaN
# 27950                           NaN               NaN
# 88994                           NaN               NaN
# 53957                           NaN               NaN
# 14337                           NaN               NaN
# 45964                           NaN               NaN
# 49111                           NaN               NaN
# 87719                           NaN               NaN
# 104840                          NaN               NaN
# 114002                          NaN               NaN
# 105466                          NaN               NaN
# 85335                           NaN               NaN
# 26190                           NaN               NaN
# 115756                          NaN               NaN
# 519                             NaN               NaN
# 77433                           NaN               NaN
# 76288                           NaN               NaN
# 23141                           NaN               NaN
# 40436                           NaN               NaN
# 67729                           NaN               NaN
# 75717                           NaN               NaN
# 2322                            NaN               NaN
# 64572                           NaN               NaN
# 56040                           NaN               NaN
# 122887                          NaN               NaN
# 78207                           NaN               NaN
# 19311                           NaN               NaN
# 43069                           NaN               NaN
# 42440                           NaN               NaN
# 84738                           NaN               NaN
# 120295                          NaN               NaN
# 97143                           NaN               NaN
# 61118                           NaN               NaN
#
#         excess_mortality_cumulative_per_million
# 52141                                       NaN
# 16230                                       NaN
# 92082                                       NaN
# 51550                                       NaN
# 72256                                       NaN
# 117633                                      NaN
# 53359                                       NaN
# 76854                                       NaN
# 102430                                      NaN
# 24359                                       NaN
# 9961                                        NaN
# 4958                                        NaN
# 68358                                       NaN
# 113420                                      NaN
# 117002                                      NaN
# 110809                                      NaN
# 123460                                      NaN
# 88371                                       NaN
# 27950                                       NaN
# 88994                                       NaN
# 53957                                       NaN
# 14337                                       NaN
# 45964                                       NaN
# 49111                                       NaN
# 87719                                       NaN
# 104840                                      NaN
# 114002                                      NaN
# 105466                                      NaN
# 85335                                       NaN
# 26190                                       NaN
# 115756                                      NaN
# 519                                         NaN
# 77433                                       NaN
# 76288                                       NaN
# 23141                                       NaN
# 40436                                       NaN
# 67729                                       NaN
# 75717                                       NaN
# 2322                                        NaN
# 64572                                       NaN
# 56040                                       NaN
# 122887                                      NaN
# 78207                                       NaN
# 19311                                       NaN
# 43069                                       NaN
# 42440                                       NaN
# 84738                                       NaN
# 120295                                      NaN
# 97143                                       NaN
# 61118                                       NaN
#
# [50 rows x 65 columns]

# %%
c_df.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'new_tests', 'total_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'total_boosters',
#        'new_vaccinations', 'new_vaccinations_smoothed',
#        'total_vaccinations_per_hundred', 'people_vaccinated_per_hundred',
#        'people_fully_vaccinated_per_hundred', 'total_boosters_per_hundred',
#        'new_vaccinations_smoothed_per_million', 'stringency_index',
#        'population', 'population_density', 'median_age', 'aged_65_older',
#        'aged_70_older', 'gdp_per_capita', 'extreme_poverty',
#        'cardiovasc_death_rate', 'diabetes_prevalence', 'female_smokers',
#        'male_smokers', 'handwashing_facilities', 'hospital_beds_per_thousand',
#        'life_expectancy', 'human_development_index',
#        'excess_mortality_cumulative_absolute', 'excess_mortality_cumulative',
#        'excess_mortality', 'excess_mortality_cumulative_per_million'],
#       dtype='object')
