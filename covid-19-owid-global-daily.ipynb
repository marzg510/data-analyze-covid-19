# %%
import pandas as pd

# %%
df = pd.read_csv("covid-19-data/public/data/owid-covid-data.csv")
df.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1      AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# 0              NaN                597.029                 9.59
# 1              NaN                597.029                 9.59
# 2              NaN                597.029                 9.59
# 3              NaN                597.029                 9.59
# 4              NaN                597.029                 9.59
#
#    female_smokers  male_smokers  handwashing_facilities  \
# 0             NaN           NaN                  37.746
# 1             NaN           NaN                  37.746
# 2             NaN           NaN                  37.746
# 3             NaN           NaN                  37.746
# 4             NaN           NaN                  37.746
#
#    hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                         0.5            64.83                    0.511
# 1                         0.5            64.83                    0.511
# 2                         0.5            64.83                    0.511
# 3                         0.5            64.83                    0.511
# 4                         0.5            64.83                    0.511
#
#    excess_mortality
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
#
# [5 rows x 60 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99776 entries, 0 to 99775
# Data columns (total 60 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   iso_code                               99776 non-null  object
#  1   continent                              95098 non-null  object
#  2   location                               99776 non-null  object
#  3   date                                   99776 non-null  object
#  4   total_cases                            96182 non-null  float64
#  5   new_cases                              96179 non-null  float64
#  6   new_cases_smoothed                     95169 non-null  float64
#  7   total_deaths                           86043 non-null  float64
#  8   new_deaths                             86199 non-null  float64
#  9   new_deaths_smoothed                    95169 non-null  float64
#  10  total_cases_per_million                95670 non-null  float64
#  11  new_cases_per_million                  95667 non-null  float64
#  12  new_cases_smoothed_per_million         94662 non-null  float64
#  13  total_deaths_per_million               85544 non-null  float64
#  14  new_deaths_per_million                 85700 non-null  float64
#  15  new_deaths_smoothed_per_million        94662 non-null  float64
#  16  reproduction_rate                      80359 non-null  float64
#  17  icu_patients                           10100 non-null  float64
#  18  icu_patients_per_million               10100 non-null  float64
#  19  hosp_patients                          12551 non-null  float64
#  20  hosp_patients_per_million              12551 non-null  float64
#  21  weekly_icu_admissions                  883 non-null    float64
#  22  weekly_icu_admissions_per_million      883 non-null    float64
#  23  weekly_hosp_admissions                 1568 non-null   float64
#  24  weekly_hosp_admissions_per_million     1568 non-null   float64
#  25  new_tests                              44897 non-null  float64
#  26  total_tests                            44571 non-null  float64
#  27  total_tests_per_thousand               44571 non-null  float64
#  28  new_tests_per_thousand                 44897 non-null  float64
#  29  new_tests_smoothed                     52223 non-null  float64
#  30  new_tests_smoothed_per_thousand        52223 non-null  float64
#  31  positive_rate                          48752 non-null  float64
#  32  tests_per_case                         48154 non-null  float64
#  33  tests_units                            53890 non-null  object
#  34  total_vaccinations                     16696 non-null  float64
#  35  people_vaccinated                      15873 non-null  float64
#  36  people_fully_vaccinated                13037 non-null  float64
#  37  new_vaccinations                       13923 non-null  float64
#  38  new_vaccinations_smoothed              28906 non-null  float64
#  39  total_vaccinations_per_hundred         16696 non-null  float64
#  40  people_vaccinated_per_hundred          15873 non-null  float64
#  41  people_fully_vaccinated_per_hundred    13037 non-null  float64
#  42  new_vaccinations_smoothed_per_million  28906 non-null  float64
#  43  stringency_index                       83617 non-null  float64
#  44  population                             99130 non-null  float64
#  45  population_density                     92704 non-null  float64
#  46  median_age                             89163 non-null  float64
#  47  aged_65_older                          88161 non-null  float64
#  48  aged_70_older                          88670 non-null  float64
#  49  gdp_per_capita                         89509 non-null  float64
#  50  extreme_poverty                        60413 non-null  float64
#  51  cardiovasc_death_rate                  89535 non-null  float64
#  52  diabetes_prevalence                    91839 non-null  float64
#  53  female_smokers                         70029 non-null  float64
#  54  male_smokers                           69006 non-null  float64
#  55  handwashing_facilities                 44993 non-null  float64
#  56  hospital_beds_per_thousand             81561 non-null  float64
#  57  life_expectancy                        94743 non-null  float64
#  58  human_development_index                89677 non-null  float64
#  59  excess_mortality                       3503 non-null   float64
# dtypes: float64(55), object(5)
# memory usage: 45.7+ MB

# %%
df.describe()
# Out:
#         total_cases      new_cases  new_cases_smoothed  total_deaths  \
# count  9.618200e+04   96179.000000        95169.000000  8.604300e+04
# mean   1.067540e+06    6040.415018         6065.335362  2.886042e+04
# std    7.309619e+06   37772.160533        37518.903015  1.722124e+05
# min    1.000000e+00  -74347.000000        -6223.000000  1.000000e+00
# 25%    1.267000e+03       2.000000            7.429000  5.400000e+01
# 50%    1.353700e+04      74.000000           92.000000  3.930000e+02
# 75%    1.442520e+05     808.500000          850.714000  3.807000e+03
# max    1.830843e+08  906017.000000       826388.429000  3.963988e+06
#
#          new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  86199.000000         95169.000000             95670.000000
# mean     146.543661           131.939949             13153.650719
# std      801.561494           744.818904             24164.085861
# min    -1918.000000          -232.143000                 0.001000
# 25%        0.000000             0.000000               261.252250
# 50%        2.000000             1.429000              1801.888500
# 75%       18.000000            14.429000             13742.420500
# max    18050.000000         14737.000000            180133.307000
#
#        new_cases_per_million  new_cases_smoothed_per_million  \
# count           95667.000000                    94662.000000
# mean               76.087072                       76.371622
# std               200.057882                      158.762301
# min             -2153.437000                     -276.825000
# 25%                 0.215000                        1.289250
# 50%                 8.441000                       11.159000
# 75%                70.114000                       78.557750
# max             18293.675000                     4083.500000
#
#        total_deaths_per_million  ...  extreme_poverty  cardiovasc_death_rate  \
# count              85544.000000  ...     60413.000000           89535.000000
# mean                 290.731068  ...        13.408392             258.492785
# std                  525.260690  ...        19.961076             119.039725
# min                    0.001000  ...         0.100000              79.370000
# 25%                    8.036000  ...         0.600000             167.295000
# 50%                   51.724000  ...         2.200000             242.648000
# 75%                  317.237000  ...        21.200000             329.635000
# max                 5843.986000  ...        77.600000             724.417000
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# count         91839.000000    70029.000000  69006.000000
# mean              7.927972       10.566425     32.693634
# std               4.148719       10.466660     13.485490
# min               0.990000        0.100000      7.700000
# 25%               5.310000        1.900000     21.600000
# 50%               7.110000        6.300000     31.400000
# 75%              10.080000       19.300000     41.100000
# max              30.530000       44.000000     78.100000
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# count            44993.000000                81561.000000     94743.000000
# mean                50.831461                    3.027697        73.236862
# std                 31.758917                    2.458866         7.559530
# min                  1.188000                    0.100000        53.280000
# 25%                 19.351000                    1.300000        67.920000
# 50%                 49.839000                    2.400000        74.620000
# 75%                 83.241000                    3.861000        78.740000
# max                100.000000                   13.800000        86.750000
#
#        human_development_index  excess_mortality
# count             89677.000000       3503.000000
# mean                  0.727338         18.243991
# std                   0.150370         36.030922
# min                   0.394000        -95.590000
# 25%                   0.602000          0.405000
# 50%                   0.748000          7.340000
# 75%                   0.848000         23.855000
# max                   0.957000        409.690000
#
# [8 rows x 55 columns]

# %%
df.continent.unique()
# Out:
# array(['Asia', nan, 'Europe', 'Africa', 'North America', 'South America',
#        'Oceania'], dtype=object)

# %%
df.loc[df.continent.isna()].location.unique()
# Out:
# array(['Africa', 'Asia', 'Europe', 'European Union', 'International',
#        'North America', 'Oceania', 'South America', 'World'], dtype=object)

# %%
df.loc[df.location=="International"]
# Out:
#        iso_code continent       location        date  total_cases  new_cases  \
# 42285  OWID_INT       NaN  International  2020-02-07         61.0       61.0
# 42286  OWID_INT       NaN  International  2020-02-08         61.0        0.0
# 42287  OWID_INT       NaN  International  2020-02-09         64.0        3.0
# 42288  OWID_INT       NaN  International  2020-02-10        135.0       71.0
# 42289  OWID_INT       NaN  International  2020-02-11        135.0        0.0
# ...         ...       ...            ...         ...          ...        ...
# 42792  OWID_INT       NaN  International  2021-06-28        722.0       -5.0
# 42793  OWID_INT       NaN  International  2021-06-29        722.0        0.0
# 42794  OWID_INT       NaN  International  2021-06-30        722.0        0.0
# 42795  OWID_INT       NaN  International  2021-07-01        722.0        0.0
# 42796  OWID_INT       NaN  International  2021-07-02        722.0        0.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 42285                 NaN           NaN         NaN                  NaN  ...
# 42286                 NaN           NaN         NaN                  NaN  ...
# 42287                 NaN           NaN         NaN                  NaN  ...
# 42288                 NaN           NaN         NaN                  NaN  ...
# 42289                 NaN           NaN         NaN                  NaN  ...
# ...                   ...           ...         ...                  ...  ...
# 42792               0.000          15.0         0.0                  0.0  ...
# 42793               0.000          15.0         0.0                  0.0  ...
# 42794               0.000          15.0         0.0                  0.0  ...
# 42795              -0.714          15.0         0.0                  0.0  ...
# 42796              -0.714          15.0         0.0                  0.0  ...
#
#        extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# 42285              NaN                    NaN                  NaN
# 42286              NaN                    NaN                  NaN
# 42287              NaN                    NaN                  NaN
# 42288              NaN                    NaN                  NaN
# 42289              NaN                    NaN                  NaN
# ...                ...                    ...                  ...
# 42792              NaN                    NaN                  NaN
# 42793              NaN                    NaN                  NaN
# 42794              NaN                    NaN                  NaN
# 42795              NaN                    NaN                  NaN
# 42796              NaN                    NaN                  NaN
#
#        female_smokers  male_smokers  handwashing_facilities  \
# 42285             NaN           NaN                     NaN
# 42286             NaN           NaN                     NaN
# 42287             NaN           NaN                     NaN
# 42288             NaN           NaN                     NaN
# 42289             NaN           NaN                     NaN
# ...               ...           ...                     ...
# 42792             NaN           NaN                     NaN
# 42793             NaN           NaN                     NaN
# 42794             NaN           NaN                     NaN
# 42795             NaN           NaN                     NaN
# 42796             NaN           NaN                     NaN
#
#        hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 42285                         NaN              NaN                      NaN
# 42286                         NaN              NaN                      NaN
# 42287                         NaN              NaN                      NaN
# 42288                         NaN              NaN                      NaN
# 42289                         NaN              NaN                      NaN
# ...                           ...              ...                      ...
# 42792                         NaN              NaN                      NaN
# 42793                         NaN              NaN                      NaN
# 42794                         NaN              NaN                      NaN
# 42795                         NaN              NaN                      NaN
# 42796                         NaN              NaN                      NaN
#
#        excess_mortality
# 42285               NaN
# 42286               NaN
# 42287               NaN
# 42288               NaN
# 42289               NaN
# ...                 ...
# 42792               NaN
# 42793               NaN
# 42794               NaN
# 42795               NaN
# 42796               NaN
#
# [512 rows x 60 columns]

# %%
df.location.unique()
# Out:
# array(['Afghanistan', 'Africa', 'Albania', 'Algeria', 'Andorra', 'Angola',
#        'Anguilla', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        'Asia', 'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain',
#        'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin',
#        'Bermuda', 'Bhutan', 'Bolivia', 'Bonaire Sint Eustatius and Saba',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Brunei', 'Bulgaria', 'Burkina Faso',
#        'Burundi', 'Cambodia', 'Cameroon', 'Canada', 'Cape Verde',
#        'Cayman Islands', 'Central African Republic', 'Chad', 'Chile',
#        'China', 'Colombia', 'Comoros', 'Congo', 'Cook Islands',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Curacao',
#        'Cyprus', 'Czechia', 'Democratic Republic of Congo', 'Denmark',
#        'Djibouti', 'Dominica', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Estonia',
#        'Eswatini', 'Ethiopia', 'Europe', 'European Union',
#        'Faeroe Islands', 'Falkland Islands', 'Fiji', 'Finland', 'France',
#        'French Polynesia', 'Gabon', 'Gambia', 'Georgia', 'Germany',
#        'Ghana', 'Gibraltar', 'Greece', 'Greenland', 'Grenada',
#        'Guatemala', 'Guernsey', 'Guinea', 'Guinea-Bissau', 'Guyana',
#        'Haiti', 'Honduras', 'Hong Kong', 'Hungary', 'Iceland', 'India',
#        'Indonesia', 'International', 'Iran', 'Iraq', 'Ireland',
#        'Isle of Man', 'Israel', 'Italy', 'Jamaica', 'Japan', 'Jersey',
#        'Jordan', 'Kazakhstan', 'Kenya', 'Kiribati', 'Kosovo', 'Kuwait',
#        'Kyrgyzstan', 'Laos', 'Latvia', 'Lebanon', 'Lesotho', 'Liberia',
#        'Libya', 'Liechtenstein', 'Lithuania', 'Luxembourg', 'Macao',
#        'Madagascar', 'Malawi', 'Malaysia', 'Maldives', 'Mali', 'Malta',
#        'Marshall Islands', 'Mauritania', 'Mauritius', 'Mexico',
#        'Micronesia (country)', 'Moldova', 'Monaco', 'Mongolia',
#        'Montenegro', 'Montserrat', 'Morocco', 'Mozambique', 'Myanmar',
#        'Namibia', 'Nauru', 'Nepal', 'Netherlands', 'New Caledonia',
#        'New Zealand', 'Nicaragua', 'Niger', 'Nigeria', 'North America',
#        'North Macedonia', 'Northern Cyprus', 'Norway', 'Oceania', 'Oman',
#        'Pakistan', 'Palestine', 'Panama', 'Papua New Guinea', 'Paraguay',
#        'Peru', 'Philippines', 'Pitcairn', 'Poland', 'Portugal', 'Qatar',
#        'Romania', 'Russia', 'Rwanda', 'Saint Helena',
#        'Saint Kitts and Nevis', 'Saint Lucia',
#        'Saint Vincent and the Grenadines', 'Samoa', 'San Marino',
#        'Sao Tome and Principe', 'Saudi Arabia', 'Senegal', 'Serbia',
#        'Seychelles', 'Sierra Leone', 'Singapore',
#        'Sint Maarten (Dutch part)', 'Slovakia', 'Slovenia',
#        'Solomon Islands', 'Somalia', 'South Africa', 'South America',
#        'South Korea', 'South Sudan', 'Spain', 'Sri Lanka', 'Sudan',
#        'Suriname', 'Sweden', 'Switzerland', 'Syria', 'Taiwan',
#        'Tajikistan', 'Tanzania', 'Thailand', 'Timor', 'Togo', 'Tonga',
#        'Trinidad and Tobago', 'Tunisia', 'Turkey', 'Turkmenistan',
#        'Turks and Caicos Islands', 'Tuvalu', 'Uganda', 'Ukraine',
#        'United Arab Emirates', 'United Kingdom', 'United States',
#        'Uruguay', 'Uzbekistan', 'Vanuatu', 'Vatican', 'Venezuela',
#        'Vietnam', 'Wallis and Futuna', 'World', 'Yemen', 'Zambia',
#        'Zimbabwe'], dtype=object)

# %%
df["date"] = pd.to_datetime(df["date"])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99776 entries, 0 to 99775
# Data columns (total 60 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   iso_code                               99776 non-null  object
#  1   continent                              95098 non-null  object
#  2   location                               99776 non-null  object
#  3   date                                   99776 non-null  datetime64[ns]
#  4   total_cases                            96182 non-null  float64
#  5   new_cases                              96179 non-null  float64
#  6   new_cases_smoothed                     95169 non-null  float64
#  7   total_deaths                           86043 non-null  float64
#  8   new_deaths                             86199 non-null  float64
#  9   new_deaths_smoothed                    95169 non-null  float64
#  10  total_cases_per_million                95670 non-null  float64
#  11  new_cases_per_million                  95667 non-null  float64
#  12  new_cases_smoothed_per_million         94662 non-null  float64
#  13  total_deaths_per_million               85544 non-null  float64
#  14  new_deaths_per_million                 85700 non-null  float64
#  15  new_deaths_smoothed_per_million        94662 non-null  float64
#  16  reproduction_rate                      80359 non-null  float64
#  17  icu_patients                           10100 non-null  float64
#  18  icu_patients_per_million               10100 non-null  float64
#  19  hosp_patients                          12551 non-null  float64
#  20  hosp_patients_per_million              12551 non-null  float64
#  21  weekly_icu_admissions                  883 non-null    float64
#  22  weekly_icu_admissions_per_million      883 non-null    float64
#  23  weekly_hosp_admissions                 1568 non-null   float64
#  24  weekly_hosp_admissions_per_million     1568 non-null   float64
#  25  new_tests                              44897 non-null  float64
#  26  total_tests                            44571 non-null  float64
#  27  total_tests_per_thousand               44571 non-null  float64
#  28  new_tests_per_thousand                 44897 non-null  float64
#  29  new_tests_smoothed                     52223 non-null  float64
#  30  new_tests_smoothed_per_thousand        52223 non-null  float64
#  31  positive_rate                          48752 non-null  float64
#  32  tests_per_case                         48154 non-null  float64
#  33  tests_units                            53890 non-null  object
#  34  total_vaccinations                     16696 non-null  float64
#  35  people_vaccinated                      15873 non-null  float64
#  36  people_fully_vaccinated                13037 non-null  float64
#  37  new_vaccinations                       13923 non-null  float64
#  38  new_vaccinations_smoothed              28906 non-null  float64
#  39  total_vaccinations_per_hundred         16696 non-null  float64
#  40  people_vaccinated_per_hundred          15873 non-null  float64
#  41  people_fully_vaccinated_per_hundred    13037 non-null  float64
#  42  new_vaccinations_smoothed_per_million  28906 non-null  float64
#  43  stringency_index                       83617 non-null  float64
#  44  population                             99130 non-null  float64
#  45  population_density                     92704 non-null  float64
#  46  median_age                             89163 non-null  float64
#  47  aged_65_older                          88161 non-null  float64
#  48  aged_70_older                          88670 non-null  float64
#  49  gdp_per_capita                         89509 non-null  float64
#  50  extreme_poverty                        60413 non-null  float64
#  51  cardiovasc_death_rate                  89535 non-null  float64
#  52  diabetes_prevalence                    91839 non-null  float64
#  53  female_smokers                         70029 non-null  float64
#  54  male_smokers                           69006 non-null  float64
#  55  handwashing_facilities                 44993 non-null  float64
#  56  hospital_beds_per_thousand             81561 non-null  float64
#  57  life_expectancy                        94743 non-null  float64
#  58  human_development_index                89677 non-null  float64
#  59  excess_mortality                       3503 non-null   float64
# dtypes: datetime64[ns](1), float64(55), object(4)
# memory usage: 45.7+ MB

# %% [markdown]
# ## 最新日付チェック

# %%
import datetime
#latest_date_str = (df.date.max()-datetime.timedelta(days=1)).strftime("%Y-%m-%d")
latest_date_str = df.date.max().strftime("%Y-%m-%d")
latest_date_str
# Out:
# '2021-07-02'

# %% [markdown]
# ## 全世界のデータのみ

# %%
world_df = df.copy().loc[df.location=="World"]
world_df.tail()
# Out:
#        iso_code continent location       date  total_cases  new_cases  \
# 98380  OWID_WRL       NaN    World 2021-06-28  181425785.0   331944.0
# 98381  OWID_WRL       NaN    World 2021-06-29  181810531.0   384746.0
# 98382  OWID_WRL       NaN    World 2021-06-30  182202370.0   391839.0
# 98383  OWID_WRL       NaN    World 2021-07-01  182641391.0   439021.0
# 98384  OWID_WRL       NaN    World 2021-07-02  183084338.0   442947.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 98380          377089.429     3929739.0      6646.0             8048.714  ...
# 98381          378890.714     3937868.0      8129.0             7933.571  ...
# 98382          372402.714     3947020.0      9152.0             7880.571  ...
# 98383          377428.286     3955679.0      8659.0             7887.286  ...
# 98384          380457.857     3963988.0      8309.0             7758.000  ...
#
#        extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# 98380             10.0                 233.07                 8.51
# 98381             10.0                 233.07                 8.51
# 98382             10.0                 233.07                 8.51
# 98383             10.0                 233.07                 8.51
# 98384             10.0                 233.07                 8.51
#
#        female_smokers  male_smokers  handwashing_facilities  \
# 98380           6.434        34.635                   60.13
# 98381           6.434        34.635                   60.13
# 98382           6.434        34.635                   60.13
# 98383           6.434        34.635                   60.13
# 98384           6.434        34.635                   60.13
#
#        hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 98380                       2.705            72.58                    0.737
# 98381                       2.705            72.58                    0.737
# 98382                       2.705            72.58                    0.737
# 98383                       2.705            72.58                    0.737
# 98384                       2.705            72.58                    0.737
#
#        excess_mortality
# 98380               NaN
# 98381               NaN
# 98382               NaN
# 98383               NaN
# 98384               NaN
#
# [5 rows x 60 columns]

# %% [markdown]
# ### 主要国の定義

# %%
countries = pd.DataFrame([
    ("Japan",""),
    ("United States","20210501"),
    ("India","20210415"),
    ("Sweden","20210511"),
    ("Brazil",""),
    ("Israel",""),
    ("United Kingdom",""),
    ("France","20210425"),
    ("Russia",""),
    ("Colombia",""),
    ("South Africa",""),
],columns=["country","text_disp_date"])
countries
# Out:
#            country text_disp_date
# 0            Japan
# 1    United States       20210501
# 2            India       20210415
# 3           Sweden       20210511
# 4           Brazil
# 5           Israel
# 6   United Kingdom
# 7           France       20210425
# 8           Russia
# 9         Colombia
# 10    South Africa

# %%
# 東Asia 主要国
e_asia_c = pd.DataFrame([
    ("Japan",""),
    ("China",""),
    ("Taiwan",""),
    ("South Korea","20210420"),
    ("Indonesia",""),
    ("Philippines","20210618"),
    ("Vietnam",""),
],columns=["country","text_disp_date"])
e_asia_c
# Out:
#        country text_disp_date
# 0        Japan
# 1        China
# 2       Taiwan
# 3  South Korea       20210420
# 4    Indonesia
# 5  Philippines       20210618
# 6      Vietnam

# %%
c_trans = pd.merge(countries, df, left_on="country", right_on="location",how="inner")
c_trans.head()
# Out:
#   country text_disp_date iso_code continent location       date  total_cases  \
# 0   Japan                     JPN      Asia    Japan 2020-01-22          2.0
# 1   Japan                     JPN      Asia    Japan 2020-01-23          2.0
# 2   Japan                     JPN      Asia    Japan 2020-01-24          2.0
# 3   Japan                     JPN      Asia    Japan 2020-01-25          2.0
# 4   Japan                     JPN      Asia    Japan 2020-01-26          4.0
#
#    new_cases  new_cases_smoothed  total_deaths  ...  extreme_poverty  \
# 0        NaN                 NaN           NaN  ...              NaN
# 1        0.0                 NaN           NaN  ...              NaN
# 2        0.0                 NaN           NaN  ...              NaN
# 3        0.0                 NaN           NaN  ...              NaN
# 4        2.0                 NaN           NaN  ...              NaN
#
#    cardiovasc_death_rate  diabetes_prevalence  female_smokers  male_smokers  \
# 0                  79.37                 5.72            11.2          33.7
# 1                  79.37                 5.72            11.2          33.7
# 2                  79.37                 5.72            11.2          33.7
# 3                  79.37                 5.72            11.2          33.7
# 4                  79.37                 5.72            11.2          33.7
#
#    handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 0                     NaN                       13.05            84.63
# 1                     NaN                       13.05            84.63
# 2                     NaN                       13.05            84.63
# 3                     NaN                       13.05            84.63
# 4                     NaN                       13.05            84.63
#
#    human_development_index  excess_mortality
# 0                    0.919               NaN
# 1                    0.919               NaN
# 2                    0.919               NaN
# 3                    0.919               NaN
# 4                    0.919               NaN
#
# [5 rows x 62 columns]

# %%
c_trans.location.unique()
# Out:
# array(['Japan', 'United States', 'India', 'Sweden', 'Brazil', 'Israel',
#        'United Kingdom', 'France', 'Russia', 'Colombia', 'South Africa'],
#       dtype=object)

# %%
c_trans.loc[c_trans.date==latest_date_str][["country","date","total_deaths","total_deaths_per_million"]].sort_values("total_deaths_per_million",ascending=False)
# Out:
#              country       date  total_deaths  total_deaths_per_million
# 2586          Brazil 2021-07-02      521952.0                  2455.558
# 5133        Colombia 2021-07-02      107723.0                  2117.077
# 3604  United Kingdom 2021-07-02      128453.0                  1892.187
# 1055   United States 2021-07-02      605524.0                  1829.363
# 4130          France 2021-07-02      111297.0                  1647.276
# 2093          Sweden 2021-07-02       14631.0                  1448.719
# 5645    South Africa 2021-07-02       61332.0                  1034.115
# 4649          Russia 2021-07-02      134302.0                   920.290
# 3085          Israel 2021-07-02        6429.0                   742.761
# 1575           India 2021-07-02      401050.0                   290.615
# 527            Japan 2021-07-02       14779.0                   116.852

# %%
e_a_trans = pd.merge(e_asia_c, df, left_on="country", right_on="location",how="inner")
e_a_trans
# Out:
#       country text_disp_date iso_code continent location       date  \
# 0       Japan                     JPN      Asia    Japan 2020-01-22
# 1       Japan                     JPN      Asia    Japan 2020-01-23
# 2       Japan                     JPN      Asia    Japan 2020-01-24
# 3       Japan                     JPN      Asia    Japan 2020-01-25
# 4       Japan                     JPN      Asia    Japan 2020-01-26
# ...       ...            ...      ...       ...      ...        ...
# 3649  Vietnam                     VNM      Asia  Vietnam 2021-06-28
# 3650  Vietnam                     VNM      Asia  Vietnam 2021-06-29
# 3651  Vietnam                     VNM      Asia  Vietnam 2021-06-30
# 3652  Vietnam                     VNM      Asia  Vietnam 2021-07-01
# 3653  Vietnam                     VNM      Asia  Vietnam 2021-07-02
#
#       total_cases  new_cases  new_cases_smoothed  total_deaths  ...  \
# 0             2.0        NaN                 NaN           NaN  ...
# 1             2.0        0.0                 NaN           NaN  ...
# 2             2.0        0.0                 NaN           NaN  ...
# 3             2.0        0.0                 NaN           NaN  ...
# 4             4.0        2.0                 NaN           NaN  ...
# ...           ...        ...                 ...           ...  ...
# 3649      16136.0      396.0             372.286          78.0  ...
# 3650      16507.0      371.0             389.286          80.0  ...
# 3651      17052.0      545.0             437.571          81.0  ...
# 3652      17727.0      675.0             486.286          81.0  ...
# 3653      18121.0      394.0             512.000          84.0  ...
#
#       extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# 0                 NaN                 79.370                 5.72
# 1                 NaN                 79.370                 5.72
# 2                 NaN                 79.370                 5.72
# 3                 NaN                 79.370                 5.72
# 4                 NaN                 79.370                 5.72
# ...               ...                    ...                  ...
# 3649              2.0                245.465                 6.00
# 3650              2.0                245.465                 6.00
# 3651              2.0                245.465                 6.00
# 3652              2.0                245.465                 6.00
# 3653              2.0                245.465                 6.00
#
#       female_smokers  male_smokers  handwashing_facilities  \
# 0               11.2          33.7                     NaN
# 1               11.2          33.7                     NaN
# 2               11.2          33.7                     NaN
# 3               11.2          33.7                     NaN
# 4               11.2          33.7                     NaN
# ...              ...           ...                     ...
# 3649             1.0          45.9                  85.847
# 3650             1.0          45.9                  85.847
# 3651             1.0          45.9                  85.847
# 3652             1.0          45.9                  85.847
# 3653             1.0          45.9                  85.847
#
#       hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                          13.05            84.63                    0.919
# 1                          13.05            84.63                    0.919
# 2                          13.05            84.63                    0.919
# 3                          13.05            84.63                    0.919
# 4                          13.05            84.63                    0.919
# ...                          ...              ...                      ...
# 3649                        2.60            75.40                    0.704
# 3650                        2.60            75.40                    0.704
# 3651                        2.60            75.40                    0.704
# 3652                        2.60            75.40                    0.704
# 3653                        2.60            75.40                    0.704
#
#       excess_mortality
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# ...                ...
# 3649               NaN
# 3650               NaN
# 3651               NaN
# 3652               NaN
# 3653               NaN
#
# [3654 rows x 62 columns]

# %%
e_a_trans.location.unique()
# Out:
# array(['Japan', 'China', 'Taiwan', 'South Korea', 'Indonesia',
#        'Philippines', 'Vietnam'], dtype=object)

# %% [markdown]
# ## 今日の新規感染者数

# %%
c_df_latest= df.loc[(df.date==latest_date_str) & (df.iso_code.str.len()==3)]
c_df_latest
# Out:
#       iso_code      continent     location       date  total_cases  new_cases  \
# 494        AFG           Asia  Afghanistan 2021-07-02     120216.0        0.0
# 1494       ALB         Europe      Albania 2021-07-02     132526.0        3.0
# 1988       DZA         Africa      Algeria 2021-07-02     140550.0      475.0
# 2476       AND         Europe      Andorra 2021-07-02      13918.0        0.0
# 2946       AGO         Africa       Angola 2021-07-02      39089.0      124.0
# ...        ...            ...          ...        ...          ...        ...
# 97230      VEN  South America    Venezuela 2021-07-02     275205.0     1181.0
# 97757      VNM           Asia      Vietnam 2021-07-02      18121.0      394.0
# 98833      YEM           Asia        Yemen 2021-07-02       6924.0        1.0
# 99305      ZMB         Africa       Zambia 2021-07-02     160613.0     2781.0
# 99775      ZWE         Africa     Zimbabwe 2021-07-02      52663.0     1442.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 494              1232.000        4962.0         0.0               63.286  ...
# 1494                2.857        2456.0         0.0                0.143  ...
# 1988              396.857        3735.0         9.0                8.143  ...
# 2476                5.143         127.0         0.0                0.000  ...
# 2946              102.571         906.0         3.0                3.286  ...
# ...                   ...           ...         ...                  ...  ...
# 97230            1179.000        3154.0        18.0               16.571  ...
# 97757             512.000          84.0         3.0                1.429  ...
# 98833               2.714        1361.0         0.0                0.571  ...
# 99305            2485.429        2341.0        70.0               60.857  ...
# 99775            1063.714        1841.0        33.0               17.143  ...
#
#        extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# 494                NaN                597.029                 9.59
# 1494               1.1                304.195                10.08
# 1988               0.5                278.364                 6.73
# 2476               NaN                109.135                 7.97
# 2946               NaN                276.045                 3.94
# ...                ...                    ...                  ...
# 97230              NaN                204.850                 6.47
# 97757              2.0                245.465                 6.00
# 98833             18.8                495.003                 5.35
# 99305             57.5                234.499                 3.94
# 99775             21.4                307.846                 1.82
#
#        female_smokers  male_smokers  handwashing_facilities  \
# 494               NaN           NaN                  37.746
# 1494              7.1          51.2                     NaN
# 1988              0.7          30.4                  83.741
# 2476             29.0          37.8                     NaN
# 2946              NaN           NaN                  26.664
# ...               ...           ...                     ...
# 97230             NaN           NaN                     NaN
# 97757             1.0          45.9                  85.847
# 98833             7.6          29.2                  49.542
# 99305             3.1          24.7                  13.938
# 99775             1.6          30.7                  36.791
#
#        hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 494                          0.50            64.83                    0.511
# 1494                         2.89            78.57                    0.795
# 1988                         1.90            76.88                    0.748
# 2476                          NaN            83.73                    0.868
# 2946                          NaN            61.15                    0.581
# ...                           ...              ...                      ...
# 97230                        0.80            72.06                    0.711
# 97757                        2.60            75.40                    0.704
# 98833                        0.70            66.12                    0.470
# 99305                        2.00            63.89                    0.584
# 99775                        1.70            61.49                    0.571
#
#        excess_mortality
# 494                 NaN
# 1494                NaN
# 1988                NaN
# 2476                NaN
# 2946                NaN
# ...                 ...
# 97230               NaN
# 97757               NaN
# 98833               NaN
# 99305               NaN
# 99775               NaN
#
# [198 rows x 60 columns]

# %% [markdown]
# ## 可視化

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook
#%matplotlib inline

# %%
world_df["case_rolling7ave"] = world_df.new_cases.rolling(7).mean()
world_df[["new_cases_smoothed","case_rolling7ave"]]
# Out:
#        new_cases_smoothed  case_rolling7ave
# 97857                 NaN               NaN
# 97858                 NaN               NaN
# 97859                 NaN               NaN
# 97860                 NaN               NaN
# 97861                 NaN               NaN
# ...                   ...               ...
# 98380          377089.429     377089.428571
# 98381          378890.714     378890.714286
# 98382          372402.714     372402.714286
# 98383          377428.286     377428.285714
# 98384          380457.857     380457.857143
#
# [528 rows x 2 columns]

# %%
fig=plt.figure(figsize=(12,8))
plt.subplot(2,2,1) # (rows, columns, panel number)
plt.title("Daily new confirmed COVID-19 cases in the world")
plt.bar(world_df.date,world_df.new_cases,label="New cases")
plt.plot_date(world_df["date"],world_df["new_cases_smoothed"],label="rolling 7-day average", fmt="-", color="orange")
plt.xticks(rotation=70)
plt.ylabel("people")
plt.grid(axis="y")
plt.legend()

plt.subplot(2,2,2) # (rows, columns, panel number)
plt.title("Daily new confirmed COVID-19 cases in the world(Recent)")
chart_data = world_df[world_df.date >= "2021-04-01"]
plt.bar(chart_data["date"],chart_data["new_cases"],label="New cases")
plt.plot_date(chart_data["date"],chart_data["new_cases_smoothed"],label="rolling 7-day average", fmt="-", color="orange")
plt.xticks(rotation=70)
plt.grid(axis="y")
plt.legend()

plt.subplot(2,2,3) # (rows, columns, panel number)
plt.title("Daily new deaths in the world")
plt.bar(world_df.date,world_df.new_deaths,label="New deaths")
plt.plot_date(world_df["date"],world_df["new_deaths_smoothed"],label="rolling 7-day average", fmt="-", color="orange")
plt.xticks(rotation=70)
plt.ylabel("people")
plt.grid(axis="y")
plt.legend()

plt.subplot(2,2,4) # (rows, columns, panel number)
plt.title("Daily new deaths in the world(Recent)")
chart_data = world_df[world_df.date >= "2021-04-01"]
plt.bar(chart_data["date"],chart_data["new_deaths"],label="New deaths")
plt.plot_date(chart_data["date"],chart_data["new_deaths_smoothed"],label="rolling 7-day average", fmt="-", color="orange")
plt.xticks(rotation=70)
plt.grid(axis="y")
plt.legend()

fig.text(0,1,"Latest: {}".format(latest_date_str),fontsize=8,ha="left",va="top")
fig.text(0,0
         ,"*Data Source : COVID-19 Dataset by Our World in Data",
        fontsize=7,ha="left",va="bottom")

fig.tight_layout()
# Out:
# <div id='15081737-c772-4d31-8515-cd2abf194beb'></div>

# %%
fig.savefig("out/covid-owid-global-daily.png")

# %% [markdown]
# ### 国別

# %% [markdown]
# #### 人口100万人当たりの新規感染者数（3月以降）

# %%
min_date = pd.to_datetime("2021-03-01")
# 主要国 新規感染者
chart_data = c_trans[c_trans.date >= min_date]
dates = chart_data["date"].unique()
print(len(dates))
print(dates.max())
for i,cr in countries.iterrows():
    c = cr["country"]
    dates = chart_data.loc[chart_data["location"]==c]["date"]
    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else latest_date_str
    print(len(chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"]))
    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"],label=c, fmt="-")
    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_cases_smoothed_per_million"],c
            ,fontsize=8,va="center")
# Out:
# 124
# 2021-07-02T00:00:00.000000000
# 124
# 124
# 124
# 124
# 124
# 124
# 124
# 124
# 124
# 124
# 124

# %%
"""
fig=plt.figure(figsize=(14,10))
min_date = pd.to_datetime("2021-03-01")
# 主要国 新規感染者
plt.subplot(2,2,1) # (rows, columns, panel number)
plt.title("Daily new confirmed COVID-19 cases\n per million population in major countries\n(rolling 7day ave.)")
plt.grid()
plt.xticks(rotation=70)
chart_data = c_trans[c_trans.date >= min_date]
dates = chart_data["date"].unique()
for i,cr in countries.iterrows():
    c = cr["country"]
    dates = chart_data.loc[chart_data["location"]==c]["date"]
    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else dates.max()
    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"],label=c, fmt="-")
    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_cases_smoothed_per_million"],c
            ,fontsize=8,va="center")
plt.legend(bbox_to_anchor=(0, 1),loc='upper left', fontsize=9)
"""
# Out:
# '\nfig=plt.figure(figsize=(14,10))\nmin_date = pd.to_datetime("2021-03-01")\n# 主要国 新規感染者\nplt.subplot(2,2,1) # (rows, columns, panel number)\nplt.title("Daily new confirmed COVID-19 cases\n per million population in major countries\n(rolling 7day ave.)")\nplt.grid()\nplt.xticks(rotation=70)\nchart_data = c_trans[c_trans.date >= min_date]\ndates = chart_data["date"].unique()\nfor i,cr in countries.iterrows():\n    c = cr["country"]\n    dates = chart_data.loc[chart_data["location"]==c]["date"]\n    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else dates.max()\n    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"],label=c, fmt="-")\n    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_cases_smoothed_per_million"],c\n            ,fontsize=8,va="center")\nplt.legend(bbox_to_anchor=(0, 1),loc=\'upper left\', fontsize=9)\n'

# %%
min_date = pd.to_datetime("2021-04-01")

# %%
fig=plt.figure(figsize=(14,10))
# 主要国 新規感染者
plt.subplot(2,2,1) # (rows, columns, panel number)
plt.title("Daily new confirmed COVID-19 cases\n per million population in major countries\n(rolling 7day ave.)")
plt.grid()
plt.xticks(rotation=45)
chart_data = c_trans[c_trans.date >= min_date]
for i,cr in countries.iterrows():
    c = cr["country"]
    dates = chart_data.loc[chart_data["location"]==c]["date"]
    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else pd.to_datetime(latest_date_str)
    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"],label=c, fmt="-")
    text_y = chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_cases_smoothed_per_million"]
#    print(text_y)
    print(c,text_disp_date,text_y)
    plt.text(text_disp_date,text_y,c,fontsize=8,va="center")
plt.legend(bbox_to_anchor=(0, 1),loc='upper left', fontsize=9)

# 主要国 死者
plt.subplot(2,2,2) # (rows, columns, panel number)
plt.title("Daily new deaths in major countries(rolling 7day ave.)")
plt.grid()
plt.xticks(rotation=45)
chart_data = c_trans[c_trans.date >= min_date]
for i,cr in countries.iterrows():
    c = cr["country"]
    dates = chart_data.loc[chart_data["location"]==c]["date"]
    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else pd.to_datetime(latest_date_str)
    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_deaths_smoothed"],label=c, fmt="-")
    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_deaths_smoothed"],c
            ,fontsize=8,va="center")
plt.legend(bbox_to_anchor=(0, 1),loc='upper left', fontsize=9)

plt.subplot(2,2,3) # (rows, columns, panel number)
plt.grid()
plt.xticks(rotation=45)
plt.title("Daily new confirmed COVID-19 cases\n per million population in Eastern Asia\n(rolling 7day ave.)")
chart_data = e_a_trans[e_a_trans.date >= min_date]
for i,cr in e_asia_c.iterrows():
    c = cr["country"]
    dates = chart_data.loc[chart_data["location"]==c]["date"]
    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else pd.to_datetime(latest_date_str)
    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"],label=c, fmt="-")
    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_cases_smoothed_per_million"],c
             ,fontsize=8,va="center")
plt.legend(bbox_to_anchor=(0, 1),loc='upper left', fontsize=9)

plt.subplot(2,2,4) # (rows, columns, panel number)
plt.grid()
plt.xticks(rotation=45)
plt.title("Daily new deaths in Eastern Asia(rolling 7day ave.)")
chart_data = e_a_trans[e_a_trans.date >= min_date]
for i,cr in e_asia_c.iterrows():
    c = cr["country"]
    dates = chart_data.loc[chart_data["location"]==c]["date"]
    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else pd.to_datetime(latest_date_str)
    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_deaths_smoothed"],label=c, fmt="-")
    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_deaths_smoothed"],c
             ,fontsize=8,va="center")
plt.legend(bbox_to_anchor=(0, 1),loc='upper left', fontsize=9)

fig.text(0,0.98,"Latest: {}".format(latest_date_str),fontsize=9,ha="left",va="top")
fig.text(0,0
         ,"*Data Source : COVID-19 Dataset by Our World in Data",
        fontsize=8,ha="left",va="bottom")
fig.tight_layout()
"""
"""
# Out:
# <div id='86be0c97-0aa8-4810-abbb-df40f9b38ba6'></div>
# Japan 2021-07-02 00:00:00 527    12.01
# Name: new_cases_smoothed_per_million, dtype: float64
# United States 2021-05-01 00:00:00 993    149.877
# Name: new_cases_smoothed_per_million, dtype: float64
# India 2021-04-15 00:00:00 1497    127.471
# Name: new_cases_smoothed_per_million, dtype: float64
# Sweden 2021-05-11 00:00:00 2041    467.502
# Name: new_cases_smoothed_per_million, dtype: float64
# Brazil 2021-07-02 00:00:00 2586    245.114
# Name: new_cases_smoothed_per_million, dtype: float64
# Israel 2021-07-02 00:00:00 3085    28.603
# Name: new_cases_smoothed_per_million, dtype: float64
# United Kingdom 2021-07-02 00:00:00 3604    327.739
# Name: new_cases_smoothed_per_million, dtype: float64
# France 2021-04-25 00:00:00 4062    441.062
# Name: new_cases_smoothed_per_million, dtype: float64
# Russia 2021-07-02 00:00:00 4649    146.355
# Name: new_cases_smoothed_per_million, dtype: float64
# Colombia 2021-07-02 00:00:00 5133    574.305
# Name: new_cases_smoothed_per_million, dtype: float64
# South Africa 2021-07-02 00:00:00 5645    298.489
# Name: new_cases_smoothed_per_million, dtype: float64
# '\n'

# %%
fig.savefig("out/covid-owid-countries-daily.png")

# %% [markdown]
# ### 新規感染者数

# %%
fig = plt.figure(figsize=(12,8))

plt.subplot(1,2,1) # (rows, columns, panel number)
plt.title("New confirmed COVID-19 cases worst 50")
plt.yticks(fontsize=9)
plt.xlabel("people")
chart_data = c_df_latest.sort_values("new_cases",ascending=False).head(50).sort_values("new_cases",ascending=True)
plt.barh(chart_data["location"],chart_data["new_cases"],label="new cases a day")
plt.grid(axis="x")
mean = int(c_df_latest.new_cases.mean())
plt.plot([mean,mean],[0,50], 'k--', lw=0.5)
plt.text(mean,50,"Mean:{}".format(mean),ha="center",fontsize=9)
plt.legend()

plt.subplot(1,2,2) # (rows, columns, panel number)
plt.title("New confirmed COVID-19 cases per million worst 50")
plt.yticks(fontsize=9)
plt.xlabel("people")
chart_data = c_df_latest.sort_values("new_cases_per_million",ascending=False).head(50).sort_values("new_cases_per_million",ascending=True)
plt.barh(chart_data["location"],chart_data["new_cases_per_million"],label="new cases a day per million")
plt.grid(axis="x")
mean = int(chart_data.new_cases_per_million.mean())
plt.plot([mean,mean],[0,50], 'k--', lw=0.5)
plt.text(mean,50,"Mean:{}".format(mean),ha="center",fontsize=9)
plt.legend()

fig.text(0,0.98,"Latest: {}".format(latest_date_str),fontsize=9,ha="left",va="top")
fig.text(0,0
         ,"*Data Source : COVID-19 Dataset by Our World in Data",
        fontsize=8,ha="left",va="bottom")


fig.tight_layout()
# Out:
# <div id='0ae3edca-1dd5-4f19-abc9-60ed816b72d1'></div>

# %%
fig.savefig("out/covid-owid-global-latest-top.png")
