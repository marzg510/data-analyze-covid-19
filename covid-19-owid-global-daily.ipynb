# %%
import pandas as pd

# %%
df = pd.read_csv("covid-19-data/public/data/owid-covid-data.csv")
df.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1      AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# 0              NaN                597.029                 9.59
# 1              NaN                597.029                 9.59
# 2              NaN                597.029                 9.59
# 3              NaN                597.029                 9.59
# 4              NaN                597.029                 9.59
#
#    female_smokers  male_smokers  handwashing_facilities  \
# 0             NaN           NaN                  37.746
# 1             NaN           NaN                  37.746
# 2             NaN           NaN                  37.746
# 3             NaN           NaN                  37.746
# 4             NaN           NaN                  37.746
#
#    hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                         0.5            64.83                    0.511
# 1                         0.5            64.83                    0.511
# 2                         0.5            64.83                    0.511
# 3                         0.5            64.83                    0.511
# 4                         0.5            64.83                    0.511
#
#    excess_mortality
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
#
# [5 rows x 60 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98229 entries, 0 to 98228
# Data columns (total 60 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   iso_code                               98229 non-null  object
#  1   continent                              93614 non-null  object
#  2   location                               98229 non-null  object
#  3   date                                   98229 non-null  object
#  4   total_cases                            94775 non-null  float64
#  5   new_cases                              94772 non-null  float64
#  6   new_cases_smoothed                     93762 non-null  float64
#  7   total_deaths                           84685 non-null  float64
#  8   new_deaths                             84841 non-null  float64
#  9   new_deaths_smoothed                    93762 non-null  float64
#  10  total_cases_per_million                94270 non-null  float64
#  11  new_cases_per_million                  94267 non-null  float64
#  12  new_cases_smoothed_per_million         93262 non-null  float64
#  13  total_deaths_per_million               84193 non-null  float64
#  14  new_deaths_per_million                 84349 non-null  float64
#  15  new_deaths_smoothed_per_million        93262 non-null  float64
#  16  reproduction_rate                      78887 non-null  float64
#  17  icu_patients                           9924 non-null   float64
#  18  icu_patients_per_million               9924 non-null   float64
#  19  hosp_patients                          12333 non-null  float64
#  20  hosp_patients_per_million              12333 non-null  float64
#  21  weekly_icu_admissions                  873 non-null    float64
#  22  weekly_icu_admissions_per_million      873 non-null    float64
#  23  weekly_hosp_admissions                 1544 non-null   float64
#  24  weekly_hosp_admissions_per_million     1544 non-null   float64
#  25  new_tests                              44261 non-null  float64
#  26  total_tests                            43942 non-null  float64
#  27  total_tests_per_thousand               43942 non-null  float64
#  28  new_tests_per_thousand                 44261 non-null  float64
#  29  new_tests_smoothed                     51454 non-null  float64
#  30  new_tests_smoothed_per_thousand        51454 non-null  float64
#  31  positive_rate                          48007 non-null  float64
#  32  tests_per_case                         47409 non-null  float64
#  33  tests_units                            53102 non-null  object
#  34  total_vaccinations                     15858 non-null  float64
#  35  people_vaccinated                      15064 non-null  float64
#  36  people_fully_vaccinated                12225 non-null  float64
#  37  new_vaccinations                       13218 non-null  float64
#  38  new_vaccinations_smoothed              27410 non-null  float64
#  39  total_vaccinations_per_hundred         15858 non-null  float64
#  40  people_vaccinated_per_hundred          15064 non-null  float64
#  41  people_fully_vaccinated_per_hundred    12225 non-null  float64
#  42  new_vaccinations_smoothed_per_million  27410 non-null  float64
#  43  stringency_index                       82388 non-null  float64
#  44  population                             97590 non-null  float64
#  45  population_density                     91285 non-null  float64
#  46  median_age                             87837 non-null  float64
#  47  aged_65_older                          86849 non-null  float64
#  48  aged_70_older                          87351 non-null  float64
#  49  gdp_per_capita                         88173 non-null  float64
#  50  extreme_poverty                        59538 non-null  float64
#  51  cardiovasc_death_rate                  88222 non-null  float64
#  52  diabetes_prevalence                    90452 non-null  float64
#  53  female_smokers                         69013 non-null  float64
#  54  male_smokers                           68004 non-null  float64
#  55  handwashing_facilities                 44328 non-null  float64
#  56  hospital_beds_per_thousand             80377 non-null  float64
#  57  life_expectancy                        93273 non-null  float64
#  58  human_development_index                88368 non-null  float64
#  59  excess_mortality                       3463 non-null   float64
# dtypes: float64(55), object(5)
# memory usage: 45.0+ MB

# %%
df.describe()
# Out:
#         total_cases      new_cases  new_cases_smoothed  total_deaths  \
# count  9.477500e+04   94772.000000        93762.000000  8.468500e+04
# mean   1.040674e+06    6044.209682         6071.178116  2.828512e+04
# std    7.139992e+06   37866.216616        37617.047442  1.687084e+05
# min    1.000000e+00  -74347.000000        -6223.000000  1.000000e+00
# 25%    1.224000e+03       2.000000            7.429000  5.300000e+01
# 50%    1.330800e+04      73.000000           91.429000  3.780000e+02
# 75%    1.414915e+05     803.250000          846.499750  3.687000e+03
# max    1.804101e+08  906008.000000       826389.571000  3.909437e+06
#
#          new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  84841.000000         93762.000000             94270.000000
# mean     146.934065           132.103936             12813.407304
# std      803.712713           746.114443             23671.436137
# min    -1918.000000          -232.143000                 0.001000
# 25%        0.000000             0.000000               255.129500
# 50%        2.000000             1.429000              1752.937000
# 75%       18.000000            14.429000             13252.876750
# max    18050.000000         14737.000000            179667.379000
#
#        new_cases_per_million  new_cases_smoothed_per_million  \
# count           94267.000000                    93262.000000
# mean               76.126470                       76.408417
# std               200.149082                      158.864582
# min             -2153.437000                     -276.825000
# 25%                 0.211000                        1.281250
# 50%                 8.342000                       10.995000
# 75%                70.261000                       78.701250
# max             18293.675000                     4083.500000
#
#        total_deaths_per_million  ...  extreme_poverty  cardiovasc_death_rate  \
# count              84193.000000  ...     59538.000000           88222.000000
# mean                 284.402427  ...        13.400685             258.413930
# std                  515.827853  ...        19.958188             119.007582
# min                    0.001000  ...         0.100000              79.370000
# 25%                    7.890000  ...         0.600000             167.295000
# 50%                   50.844000  ...         2.200000             242.648000
# 75%                  309.667000  ...        21.200000             329.635000
# max                 5806.378000  ...        77.600000             724.417000
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# count         90452.000000    69013.000000  68004.000000
# mean              7.921591       10.562455     32.690520
# std               4.138841       10.460222     13.483733
# min               0.990000        0.100000      7.700000
# 25%               5.310000        1.900000     21.600000
# 50%               7.110000        6.300000     31.400000
# 75%              10.080000       19.300000     41.100000
# max              30.530000       44.000000     78.100000
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# count            44328.000000                80377.000000     93273.000000
# mean                50.839871                    3.028012        73.236288
# std                 31.759405                    2.459285         7.560131
# min                  1.188000                    0.100000        53.280000
# 25%                 19.351000                    1.300000        67.920000
# 50%                 49.839000                    2.400000        74.620000
# 75%                 83.241000                    3.861000        78.740000
# max                100.000000                   13.800000        86.750000
#
#        human_development_index  excess_mortality
# count             88368.000000       3463.000000
# mean                  0.727418         18.259939
# std                   0.150374         36.111776
# min                   0.394000        -95.590000
# 25%                   0.602000          0.365000
# 50%                   0.748000          7.340000
# 75%                   0.848000         23.875000
# max                   0.957000        409.690000
#
# [8 rows x 55 columns]

# %%
df.continent.unique()
# Out:
# array(['Asia', nan, 'Europe', 'Africa', 'North America', 'South America',
#        'Oceania'], dtype=object)

# %%
df.loc[df.continent.isna()].location.unique()
# Out:
# array(['Africa', 'Asia', 'Europe', 'European Union', 'International',
#        'North America', 'Oceania', 'South America', 'World'], dtype=object)

# %%
df.loc[df.location=="International"]
# Out:
#        iso_code continent       location        date  total_cases  new_cases  \
# 41623  OWID_INT       NaN  International  2020-02-07         61.0       61.0
# 41624  OWID_INT       NaN  International  2020-02-08         61.0        0.0
# 41625  OWID_INT       NaN  International  2020-02-09         64.0        3.0
# 41626  OWID_INT       NaN  International  2020-02-10        135.0       71.0
# 41627  OWID_INT       NaN  International  2020-02-11        135.0        0.0
# ...         ...       ...            ...         ...          ...        ...
# 42123  OWID_INT       NaN  International  2021-06-21        722.0        0.0
# 42124  OWID_INT       NaN  International  2021-06-22        722.0        0.0
# 42125  OWID_INT       NaN  International  2021-06-23        722.0        0.0
# 42126  OWID_INT       NaN  International  2021-06-24        722.0        0.0
# 42127  OWID_INT       NaN  International  2021-06-25        722.0        0.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 41623                 NaN           NaN         NaN                  NaN  ...
# 41624                 NaN           NaN         NaN                  NaN  ...
# 41625                 NaN           NaN         NaN                  NaN  ...
# 41626                 NaN           NaN         NaN                  NaN  ...
# 41627                 NaN           NaN         NaN                  NaN  ...
# ...                   ...           ...         ...                  ...  ...
# 42123               0.143          15.0         0.0                  0.0  ...
# 42124               0.143          15.0         0.0                  0.0  ...
# 42125               0.143          15.0         0.0                  0.0  ...
# 42126               0.143          15.0         0.0                  0.0  ...
# 42127               0.143          15.0         0.0                  0.0  ...
#
#        extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# 41623              NaN                    NaN                  NaN
# 41624              NaN                    NaN                  NaN
# 41625              NaN                    NaN                  NaN
# 41626              NaN                    NaN                  NaN
# 41627              NaN                    NaN                  NaN
# ...                ...                    ...                  ...
# 42123              NaN                    NaN                  NaN
# 42124              NaN                    NaN                  NaN
# 42125              NaN                    NaN                  NaN
# 42126              NaN                    NaN                  NaN
# 42127              NaN                    NaN                  NaN
#
#        female_smokers  male_smokers  handwashing_facilities  \
# 41623             NaN           NaN                     NaN
# 41624             NaN           NaN                     NaN
# 41625             NaN           NaN                     NaN
# 41626             NaN           NaN                     NaN
# 41627             NaN           NaN                     NaN
# ...               ...           ...                     ...
# 42123             NaN           NaN                     NaN
# 42124             NaN           NaN                     NaN
# 42125             NaN           NaN                     NaN
# 42126             NaN           NaN                     NaN
# 42127             NaN           NaN                     NaN
#
#        hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 41623                         NaN              NaN                      NaN
# 41624                         NaN              NaN                      NaN
# 41625                         NaN              NaN                      NaN
# 41626                         NaN              NaN                      NaN
# 41627                         NaN              NaN                      NaN
# ...                           ...              ...                      ...
# 42123                         NaN              NaN                      NaN
# 42124                         NaN              NaN                      NaN
# 42125                         NaN              NaN                      NaN
# 42126                         NaN              NaN                      NaN
# 42127                         NaN              NaN                      NaN
#
#        excess_mortality
# 41623               NaN
# 41624               NaN
# 41625               NaN
# 41626               NaN
# 41627               NaN
# ...                 ...
# 42123               NaN
# 42124               NaN
# 42125               NaN
# 42126               NaN
# 42127               NaN
#
# [505 rows x 60 columns]

# %%
df.location.unique()
# Out:
# array(['Afghanistan', 'Africa', 'Albania', 'Algeria', 'Andorra', 'Angola',
#        'Anguilla', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        'Asia', 'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain',
#        'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin',
#        'Bermuda', 'Bhutan', 'Bolivia', 'Bonaire Sint Eustatius and Saba',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Brunei', 'Bulgaria', 'Burkina Faso',
#        'Burundi', 'Cambodia', 'Cameroon', 'Canada', 'Cape Verde',
#        'Cayman Islands', 'Central African Republic', 'Chad', 'Chile',
#        'China', 'Colombia', 'Comoros', 'Congo', 'Cook Islands',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Curacao',
#        'Cyprus', 'Czechia', 'Democratic Republic of Congo', 'Denmark',
#        'Djibouti', 'Dominica', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Estonia',
#        'Eswatini', 'Ethiopia', 'Europe', 'European Union',
#        'Faeroe Islands', 'Falkland Islands', 'Fiji', 'Finland', 'France',
#        'French Polynesia', 'Gabon', 'Gambia', 'Georgia', 'Germany',
#        'Ghana', 'Gibraltar', 'Greece', 'Greenland', 'Grenada',
#        'Guatemala', 'Guernsey', 'Guinea', 'Guinea-Bissau', 'Guyana',
#        'Haiti', 'Honduras', 'Hong Kong', 'Hungary', 'Iceland', 'India',
#        'Indonesia', 'International', 'Iran', 'Iraq', 'Ireland',
#        'Isle of Man', 'Israel', 'Italy', 'Jamaica', 'Japan', 'Jersey',
#        'Jordan', 'Kazakhstan', 'Kenya', 'Kiribati', 'Kosovo', 'Kuwait',
#        'Kyrgyzstan', 'Laos', 'Latvia', 'Lebanon', 'Lesotho', 'Liberia',
#        'Libya', 'Liechtenstein', 'Lithuania', 'Luxembourg', 'Macao',
#        'Madagascar', 'Malawi', 'Malaysia', 'Maldives', 'Mali', 'Malta',
#        'Marshall Islands', 'Mauritania', 'Mauritius', 'Mexico',
#        'Micronesia (country)', 'Moldova', 'Monaco', 'Mongolia',
#        'Montenegro', 'Montserrat', 'Morocco', 'Mozambique', 'Myanmar',
#        'Namibia', 'Nauru', 'Nepal', 'Netherlands', 'New Caledonia',
#        'New Zealand', 'Nicaragua', 'Niger', 'Nigeria', 'North America',
#        'North Macedonia', 'Northern Cyprus', 'Norway', 'Oceania', 'Oman',
#        'Pakistan', 'Palestine', 'Panama', 'Papua New Guinea', 'Paraguay',
#        'Peru', 'Philippines', 'Pitcairn', 'Poland', 'Portugal', 'Qatar',
#        'Romania', 'Russia', 'Rwanda', 'Saint Helena',
#        'Saint Kitts and Nevis', 'Saint Lucia',
#        'Saint Vincent and the Grenadines', 'Samoa', 'San Marino',
#        'Sao Tome and Principe', 'Saudi Arabia', 'Senegal', 'Serbia',
#        'Seychelles', 'Sierra Leone', 'Singapore',
#        'Sint Maarten (Dutch part)', 'Slovakia', 'Slovenia',
#        'Solomon Islands', 'Somalia', 'South Africa', 'South America',
#        'South Korea', 'South Sudan', 'Spain', 'Sri Lanka', 'Sudan',
#        'Suriname', 'Sweden', 'Switzerland', 'Syria', 'Taiwan',
#        'Tajikistan', 'Tanzania', 'Thailand', 'Timor', 'Togo', 'Tonga',
#        'Trinidad and Tobago', 'Tunisia', 'Turkey', 'Turkmenistan',
#        'Turks and Caicos Islands', 'Tuvalu', 'Uganda', 'Ukraine',
#        'United Arab Emirates', 'United Kingdom', 'United States',
#        'Uruguay', 'Uzbekistan', 'Vanuatu', 'Vatican', 'Venezuela',
#        'Vietnam', 'Wallis and Futuna', 'World', 'Yemen', 'Zambia',
#        'Zimbabwe'], dtype=object)

# %%
df["date"] = pd.to_datetime(df["date"])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98229 entries, 0 to 98228
# Data columns (total 60 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   iso_code                               98229 non-null  object
#  1   continent                              93614 non-null  object
#  2   location                               98229 non-null  object
#  3   date                                   98229 non-null  datetime64[ns]
#  4   total_cases                            94775 non-null  float64
#  5   new_cases                              94772 non-null  float64
#  6   new_cases_smoothed                     93762 non-null  float64
#  7   total_deaths                           84685 non-null  float64
#  8   new_deaths                             84841 non-null  float64
#  9   new_deaths_smoothed                    93762 non-null  float64
#  10  total_cases_per_million                94270 non-null  float64
#  11  new_cases_per_million                  94267 non-null  float64
#  12  new_cases_smoothed_per_million         93262 non-null  float64
#  13  total_deaths_per_million               84193 non-null  float64
#  14  new_deaths_per_million                 84349 non-null  float64
#  15  new_deaths_smoothed_per_million        93262 non-null  float64
#  16  reproduction_rate                      78887 non-null  float64
#  17  icu_patients                           9924 non-null   float64
#  18  icu_patients_per_million               9924 non-null   float64
#  19  hosp_patients                          12333 non-null  float64
#  20  hosp_patients_per_million              12333 non-null  float64
#  21  weekly_icu_admissions                  873 non-null    float64
#  22  weekly_icu_admissions_per_million      873 non-null    float64
#  23  weekly_hosp_admissions                 1544 non-null   float64
#  24  weekly_hosp_admissions_per_million     1544 non-null   float64
#  25  new_tests                              44261 non-null  float64
#  26  total_tests                            43942 non-null  float64
#  27  total_tests_per_thousand               43942 non-null  float64
#  28  new_tests_per_thousand                 44261 non-null  float64
#  29  new_tests_smoothed                     51454 non-null  float64
#  30  new_tests_smoothed_per_thousand        51454 non-null  float64
#  31  positive_rate                          48007 non-null  float64
#  32  tests_per_case                         47409 non-null  float64
#  33  tests_units                            53102 non-null  object
#  34  total_vaccinations                     15858 non-null  float64
#  35  people_vaccinated                      15064 non-null  float64
#  36  people_fully_vaccinated                12225 non-null  float64
#  37  new_vaccinations                       13218 non-null  float64
#  38  new_vaccinations_smoothed              27410 non-null  float64
#  39  total_vaccinations_per_hundred         15858 non-null  float64
#  40  people_vaccinated_per_hundred          15064 non-null  float64
#  41  people_fully_vaccinated_per_hundred    12225 non-null  float64
#  42  new_vaccinations_smoothed_per_million  27410 non-null  float64
#  43  stringency_index                       82388 non-null  float64
#  44  population                             97590 non-null  float64
#  45  population_density                     91285 non-null  float64
#  46  median_age                             87837 non-null  float64
#  47  aged_65_older                          86849 non-null  float64
#  48  aged_70_older                          87351 non-null  float64
#  49  gdp_per_capita                         88173 non-null  float64
#  50  extreme_poverty                        59538 non-null  float64
#  51  cardiovasc_death_rate                  88222 non-null  float64
#  52  diabetes_prevalence                    90452 non-null  float64
#  53  female_smokers                         69013 non-null  float64
#  54  male_smokers                           68004 non-null  float64
#  55  handwashing_facilities                 44328 non-null  float64
#  56  hospital_beds_per_thousand             80377 non-null  float64
#  57  life_expectancy                        93273 non-null  float64
#  58  human_development_index                88368 non-null  float64
#  59  excess_mortality                       3463 non-null   float64
# dtypes: datetime64[ns](1), float64(55), object(4)
# memory usage: 45.0+ MB

# %%
latest_date_str = df.date.max().strftime("%Y-%m-%d")

# %% [markdown]
# ## 全世界のデータのみ

# %%
world_df = df.copy().loc[df.location=="World"]
world_df.tail()
# Out:
#        iso_code continent location       date  total_cases  new_cases  \
# 96854  OWID_WRL       NaN    World 2021-06-21  178786159.0   297395.0
# 96855  OWID_WRL       NaN    World 2021-06-22  179158296.0   372137.0
# 96856  OWID_WRL       NaN    World 2021-06-23  179595551.0   437255.0
# 96857  OWID_WRL       NaN    World 2021-06-24  179999388.0   403837.0
# 96858  OWID_WRL       NaN    World 2021-06-25  180410080.0   410692.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 96854          359093.571     3873255.0      7076.0             8723.429  ...
# 96855          359184.571     3882237.0      8982.0             8498.857  ...
# 96856          364715.429     3891760.0      9523.0             8382.714  ...
# 96857          366334.714     3900372.0      8612.0             8289.571  ...
# 96858          367012.429     3909437.0      9065.0             8269.143  ...
#
#        extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# 96854             10.0                 233.07                 8.51
# 96855             10.0                 233.07                 8.51
# 96856             10.0                 233.07                 8.51
# 96857             10.0                 233.07                 8.51
# 96858             10.0                 233.07                 8.51
#
#        female_smokers  male_smokers  handwashing_facilities  \
# 96854           6.434        34.635                   60.13
# 96855           6.434        34.635                   60.13
# 96856           6.434        34.635                   60.13
# 96857           6.434        34.635                   60.13
# 96858           6.434        34.635                   60.13
#
#        hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 96854                       2.705            72.58                    0.737
# 96855                       2.705            72.58                    0.737
# 96856                       2.705            72.58                    0.737
# 96857                       2.705            72.58                    0.737
# 96858                       2.705            72.58                    0.737
#
#        excess_mortality
# 96854               NaN
# 96855               NaN
# 96856               NaN
# 96857               NaN
# 96858               NaN
#
# [5 rows x 60 columns]

# %% [markdown]
# ### 主要国の定義

# %%
countries = pd.DataFrame([
    ("Japan",""),
    ("United States",""),
    ("India","20210415"),
    ("Sweden","20210511"),
    ("Brazil",""),
    ("Israel","20210315"),
    ("United Kingdom",""),
    ("France","20210425"),
    ("Russia",""),
],columns=["country","text_disp_date"])
countries
# Out:
#           country text_disp_date
# 0           Japan
# 1   United States
# 2           India       20210415
# 3          Sweden       20210511
# 4          Brazil
# 5          Israel       20210315
# 6  United Kingdom
# 7          France       20210425
# 8          Russia

# %%
# 東Asia 主要国
e_asia_c = pd.DataFrame([
    ("Japan",""),
    ("China",""),
    ("Taiwan",""),
    ("South Korea","20210420"),
    ("Indonesia",""),
    ("Philippines","20210618"),
    ("Vietnam",""),
],columns=["country","text_disp_date"])
e_asia_c
# Out:
#        country text_disp_date
# 0        Japan
# 1        China
# 2       Taiwan
# 3  South Korea       20210420
# 4    Indonesia
# 5  Philippines       20210618
# 6      Vietnam

# %%
c_trans = pd.merge(countries, df, left_on="country", right_on="location",how="inner")
c_trans.head()
# Out:
#   country text_disp_date iso_code continent location       date  total_cases  \
# 0   Japan                     JPN      Asia    Japan 2020-01-22          2.0
# 1   Japan                     JPN      Asia    Japan 2020-01-23          2.0
# 2   Japan                     JPN      Asia    Japan 2020-01-24          2.0
# 3   Japan                     JPN      Asia    Japan 2020-01-25          2.0
# 4   Japan                     JPN      Asia    Japan 2020-01-26          4.0
#
#    new_cases  new_cases_smoothed  total_deaths  ...  extreme_poverty  \
# 0        NaN                 NaN           NaN  ...              NaN
# 1        0.0                 NaN           NaN  ...              NaN
# 2        0.0                 NaN           NaN  ...              NaN
# 3        0.0                 NaN           NaN  ...              NaN
# 4        2.0                 NaN           NaN  ...              NaN
#
#    cardiovasc_death_rate  diabetes_prevalence  female_smokers  male_smokers  \
# 0                  79.37                 5.72            11.2          33.7
# 1                  79.37                 5.72            11.2          33.7
# 2                  79.37                 5.72            11.2          33.7
# 3                  79.37                 5.72            11.2          33.7
# 4                  79.37                 5.72            11.2          33.7
#
#    handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 0                     NaN                       13.05            84.63
# 1                     NaN                       13.05            84.63
# 2                     NaN                       13.05            84.63
# 3                     NaN                       13.05            84.63
# 4                     NaN                       13.05            84.63
#
#    human_development_index  excess_mortality
# 0                    0.919               NaN
# 1                    0.919               NaN
# 2                    0.919               NaN
# 3                    0.919               NaN
# 4                    0.919               NaN
#
# [5 rows x 62 columns]

# %%
c_trans.location.unique()
# Out:
# array(['Japan', 'United States', 'India', 'Sweden', 'Brazil', 'Israel',
#        'United Kingdom', 'France', 'Russia'], dtype=object)

# %%
e_a_trans = pd.merge(e_asia_c, df, left_on="country", right_on="location",how="inner")
e_a_trans
# Out:
#       country text_disp_date iso_code continent location       date  \
# 0       Japan                     JPN      Asia    Japan 2020-01-22
# 1       Japan                     JPN      Asia    Japan 2020-01-23
# 2       Japan                     JPN      Asia    Japan 2020-01-24
# 3       Japan                     JPN      Asia    Japan 2020-01-25
# 4       Japan                     JPN      Asia    Japan 2020-01-26
# ...       ...            ...      ...       ...      ...        ...
# 3600  Vietnam                     VNM      Asia  Vietnam 2021-06-21
# 3601  Vietnam                     VNM      Asia  Vietnam 2021-06-22
# 3602  Vietnam                     VNM      Asia  Vietnam 2021-06-23
# 3603  Vietnam                     VNM      Asia  Vietnam 2021-06-24
# 3604  Vietnam                     VNM      Asia  Vietnam 2021-06-25
#
#       total_cases  new_cases  new_cases_smoothed  total_deaths  ...  \
# 0             2.0        NaN                 NaN           NaN  ...
# 1             2.0        0.0                 NaN           NaN  ...
# 2             2.0        0.0                 NaN           NaN  ...
# 3             2.0        0.0                 NaN           NaN  ...
# 4             4.0        2.0                 NaN           NaN  ...
# ...           ...        ...                 ...           ...  ...
# 3600      13530.0      272.0             378.429          69.0  ...
# 3601      13782.0      252.0             354.000          69.0  ...
# 3602      13989.0      207.0             313.571          70.0  ...
# 3603      14323.0      334.0             310.429          72.0  ...
# 3604      14537.0      214.0             289.857          74.0  ...
#
#       extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# 0                 NaN                 79.370                 5.72
# 1                 NaN                 79.370                 5.72
# 2                 NaN                 79.370                 5.72
# 3                 NaN                 79.370                 5.72
# 4                 NaN                 79.370                 5.72
# ...               ...                    ...                  ...
# 3600              2.0                245.465                 6.00
# 3601              2.0                245.465                 6.00
# 3602              2.0                245.465                 6.00
# 3603              2.0                245.465                 6.00
# 3604              2.0                245.465                 6.00
#
#       female_smokers  male_smokers  handwashing_facilities  \
# 0               11.2          33.7                     NaN
# 1               11.2          33.7                     NaN
# 2               11.2          33.7                     NaN
# 3               11.2          33.7                     NaN
# 4               11.2          33.7                     NaN
# ...              ...           ...                     ...
# 3600             1.0          45.9                  85.847
# 3601             1.0          45.9                  85.847
# 3602             1.0          45.9                  85.847
# 3603             1.0          45.9                  85.847
# 3604             1.0          45.9                  85.847
#
#       hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                          13.05            84.63                    0.919
# 1                          13.05            84.63                    0.919
# 2                          13.05            84.63                    0.919
# 3                          13.05            84.63                    0.919
# 4                          13.05            84.63                    0.919
# ...                          ...              ...                      ...
# 3600                        2.60            75.40                    0.704
# 3601                        2.60            75.40                    0.704
# 3602                        2.60            75.40                    0.704
# 3603                        2.60            75.40                    0.704
# 3604                        2.60            75.40                    0.704
#
#       excess_mortality
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# ...                ...
# 3600               NaN
# 3601               NaN
# 3602               NaN
# 3603               NaN
# 3604               NaN
#
# [3605 rows x 62 columns]

# %%
e_a_trans.location.unique()
# Out:
# array(['Japan', 'China', 'Taiwan', 'South Korea', 'Indonesia',
#        'Philippines', 'Vietnam'], dtype=object)

# %% [markdown]
# ## 可視化

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook
#%matplotlib inline

# %%
world_df["case_rolling7ave"] = world_df.new_cases.rolling(7).mean()
world_df[["new_cases_smoothed","case_rolling7ave"]]
# Out:
#        new_cases_smoothed  case_rolling7ave
# 96338                 NaN               NaN
# 96339                 NaN               NaN
# 96340                 NaN               NaN
# 96341                 NaN               NaN
# 96342                 NaN               NaN
# ...                   ...               ...
# 96854          359093.571     359093.571429
# 96855          359184.571     359184.571429
# 96856          364715.429     364715.428571
# 96857          366334.714     366334.714286
# 96858          367012.429     367012.428571
#
# [521 rows x 2 columns]

# %%
fig=plt.figure(figsize=(12,8))
plt.subplot(2,2,1) # (rows, columns, panel number)
plt.title("Daily new confirmed COVID-19 cases in the world")
plt.bar(world_df.date,world_df.new_cases,label="New cases")
plt.plot_date(world_df["date"],world_df["new_cases_smoothed"],label="rolling 7-day average", fmt="-", color="orange")
plt.xticks(rotation=70)
plt.ylabel("people")
plt.grid(axis="y")
plt.legend()

plt.subplot(2,2,2) # (rows, columns, panel number)
plt.title("Daily new confirmed COVID-19 cases in the world(after 2021 Apr 1st)")
chart_data = world_df[world_df.date >= "2021-04-01"]
plt.bar(chart_data["date"],chart_data["new_cases"],label="New deaths")
plt.plot_date(chart_data["date"],chart_data["new_cases_smoothed"],label="rolling 7-day average", fmt="-", color="orange")
plt.xticks(rotation=70)
plt.grid(axis="y")
plt.legend()

plt.subplot(2,2,3) # (rows, columns, panel number)
plt.title("Daily new deaths in the world")
plt.bar(world_df.date,world_df.new_deaths,label="New cases")
plt.plot_date(world_df["date"],world_df["new_deaths_smoothed"],label="rolling 7-day average", fmt="-", color="orange")
plt.xticks(rotation=70)
plt.ylabel("people")
plt.grid(axis="y")
plt.legend()

plt.subplot(2,2,4) # (rows, columns, panel number)
plt.title("Daily new deaths in the world(after 2021 Apr 1st)")
chart_data = world_df[world_df.date >= "2021-04-01"]
plt.bar(chart_data["date"],chart_data["new_deaths"],label="New deaths")
plt.plot_date(chart_data["date"],chart_data["new_deaths_smoothed"],label="rolling 7-day average", fmt="-", color="orange")
plt.xticks(rotation=70)
plt.grid(axis="y")
plt.legend()

fig.text(0,1,"Latest: {}".format(latest_date_str),fontsize=8,ha="left",va="top")
fig.text(0,0
         ,"*Data Source : COVID-19 Dataset by Our World in Data",
        fontsize=7,ha="left",va="bottom")

fig.tight_layout()
# Out:
# <div id='8c7e2a5e-d052-4756-aba4-cc86b215c346'></div>

# %%
fig.savefig("out/covid-owid-global-daily.png")

# %% [markdown]
# ### 国別

# %% [markdown]
# #### 人口100万人当たりの新規感染者数（3月以降）

# %%
min_date = pd.to_datetime("2021-03-01")
# 主要国 新規感染者
chart_data = c_trans[c_trans.date >= min_date]
dates = chart_data["date"].unique()
print(len(dates))
print(dates.max())
for i,cr in countries.iterrows():
    c = cr["country"]
    dates = chart_data.loc[chart_data["location"]==c]["date"]
    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else dates.max()
    print(len(chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"]))
    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"],label=c, fmt="-")
    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_cases_smoothed_per_million"],c
            ,fontsize=8,va="center")
# Out:
# 117
# 2021-06-25T00:00:00.000000000
# 117
# 117
# 117
# 117
# 117
# 117
# 117
# 117
# 117

# %%
fig=plt.figure(figsize=(14,10))
min_date = pd.to_datetime("2021-03-01")
# 主要国 新規感染者
plt.subplot(2,2,1) # (rows, columns, panel number)
plt.title("Daily new confirmed COVID-19 cases\n per million population in major countries\n(rolling 7day ave.)")
plt.grid()
plt.xticks(rotation=70)
chart_data = c_trans[c_trans.date >= min_date]
dates = chart_data["date"].unique()
for i,cr in countries.iterrows():
    c = cr["country"]
    dates = chart_data.loc[chart_data["location"]==c]["date"]
    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else dates.max()
    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"],label=c, fmt="-")
    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_cases_smoothed_per_million"],c
            ,fontsize=8,va="center")
plt.legend(bbox_to_anchor=(0, 1),loc='upper left', fontsize=9)
# Out:
# <div id='fd83f98a-c90c-4bed-8dac-51ecad7cc6d5'></div>

# %%
fig=plt.figure(figsize=(14,10))
min_date = pd.to_datetime("2021-03-01")
# 主要国 新規感染者
plt.subplot(2,2,1) # (rows, columns, panel number)
plt.title("Daily new confirmed COVID-19 cases\n per million population in major countries\n(rolling 7day ave.)")
plt.grid()
plt.xticks(rotation=45)
chart_data = c_trans[c_trans.date >= min_date]
for i,cr in countries.iterrows():
    c = cr["country"]
    dates = chart_data.loc[chart_data["location"]==c]["date"]
    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else dates.max()
    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"],label=c, fmt="-")
    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_cases_smoothed_per_million"],c
            ,fontsize=8,va="center")
plt.legend(bbox_to_anchor=(0, 1),loc='upper left', fontsize=9)

# 主要国 死者
plt.subplot(2,2,2) # (rows, columns, panel number)
plt.title("Daily new deaths in major countries(rolling 7day ave.)")
plt.grid()
plt.xticks(rotation=45)
chart_data = c_trans[c_trans.date >= min_date]
for i,cr in countries.iterrows():
    c = cr["country"]
    dates = chart_data.loc[chart_data["location"]==c]["date"]
    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else dates.max()
    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_deaths_smoothed"],label=c, fmt="-")
    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_deaths_smoothed"],c
            ,fontsize=8,va="center")
plt.legend(bbox_to_anchor=(0, 1),loc='upper left', fontsize=9)

plt.subplot(2,2,3) # (rows, columns, panel number)
plt.grid()
plt.xticks(rotation=45)
plt.title("Daily new confirmed COVID-19 cases\n per million population in Eastern Asia\n(rolling 7day ave.)")
chart_data = e_a_trans[e_a_trans.date >= min_date]
for i,cr in e_asia_c.iterrows():
    c = cr["country"]
    dates = chart_data.loc[chart_data["location"]==c]["date"]
    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else dates.max()
    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"],label=c, fmt="-")
    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_cases_smoothed_per_million"],c
             ,fontsize=8,va="center")
plt.legend(bbox_to_anchor=(0, 1),loc='upper left', fontsize=9)

plt.subplot(2,2,4) # (rows, columns, panel number)
plt.grid()
plt.xticks(rotation=45)
plt.title("Daily new deaths in Eastern Asia(rolling 7day ave.)")
chart_data = e_a_trans[e_a_trans.date >= min_date]
for i,cr in e_asia_c.iterrows():
    c = cr["country"]
    dates = chart_data.loc[chart_data["location"]==c]["date"]
    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else dates.max()
    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_deaths_smoothed"],label=c, fmt="-")
    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_deaths_smoothed"],c
             ,fontsize=8,va="center")
plt.legend(bbox_to_anchor=(0, 1),loc='upper left', fontsize=9)

fig.text(0,1,"Latest: {}".format(latest_date_str),fontsize=8,ha="left",va="top")
fig.text(0,0
         ,"*Data Source : COVID-19 Dataset by Our World in Data",
        fontsize=7,ha="left",va="bottom")
fig.tight_layout()
# Out:
# <div id='231976a4-5d56-4b9b-860b-1c04f3adba63'></div>

# %%
fig.savefig("out/covid-owid-countries-daily.png")
