# %%
import pandas as pd

# %%
df = pd.read_csv("covid-19-data/public/data/owid-covid-data.csv")
df.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1      AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    female_smokers  male_smokers  handwashing_facilities  \
# 0             NaN           NaN                  37.746
# 1             NaN           NaN                  37.746
# 2             NaN           NaN                  37.746
# 3             NaN           NaN                  37.746
# 4             NaN           NaN                  37.746
#
#    hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                         0.5            64.83                    0.511
# 1                         0.5            64.83                    0.511
# 2                         0.5            64.83                    0.511
# 3                         0.5            64.83                    0.511
# 4                         0.5            64.83                    0.511
#
#    excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                   NaN                          NaN
# 1                                   NaN                          NaN
# 2                                   NaN                          NaN
# 3                                   NaN                          NaN
# 4                                   NaN                          NaN
#
#    excess_mortality  excess_mortality_cumulative_per_million
# 0               NaN                                      NaN
# 1               NaN                                      NaN
# 2               NaN                                      NaN
# 3               NaN                                      NaN
# 4               NaN                                      NaN
#
# [5 rows x 65 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130600 entries, 0 to 130599
# Data columns (total 65 columns):
#  #   Column                                   Non-Null Count   Dtype
# ---  ------                                   --------------   -----
#  0   iso_code                                 130600 non-null  object
#  1   continent                                122243 non-null  object
#  2   location                                 130600 non-null  object
#  3   date                                     130600 non-null  object
#  4   total_cases                              123547 non-null  float64
#  5   new_cases                                123545 non-null  float64
#  6   new_cases_smoothed                       122502 non-null  float64
#  7   total_deaths                             112502 non-null  float64
#  8   new_deaths                               112698 non-null  float64
#  9   new_deaths_smoothed                      122502 non-null  float64
#  10  total_cases_per_million                  122912 non-null  float64
#  11  new_cases_per_million                    122910 non-null  float64
#  12  new_cases_smoothed_per_million           121872 non-null  float64
#  13  total_deaths_per_million                 111880 non-null  float64
#  14  new_deaths_per_million                   112076 non-null  float64
#  15  new_deaths_smoothed_per_million          121872 non-null  float64
#  16  reproduction_rate                        103316 non-null  float64
#  17  icu_patients                             15619 non-null   float64
#  18  icu_patients_per_million                 15619 non-null   float64
#  19  hosp_patients                            18310 non-null   float64
#  20  hosp_patients_per_million                18310 non-null   float64
#  21  weekly_icu_admissions                    1262 non-null    float64
#  22  weekly_icu_admissions_per_million        1262 non-null    float64
#  23  weekly_hosp_admissions                   2186 non-null    float64
#  24  weekly_hosp_admissions_per_million       2186 non-null    float64
#  25  new_tests                                54508 non-null   float64
#  26  total_tests                              54699 non-null   float64
#  27  total_tests_per_thousand                 54699 non-null   float64
#  28  new_tests_per_thousand                   54508 non-null   float64
#  29  new_tests_smoothed                       65945 non-null   float64
#  30  new_tests_smoothed_per_thousand          65945 non-null   float64
#  31  positive_rate                            61972 non-null   float64
#  32  tests_per_case                           61316 non-null   float64
#  33  tests_units                              67934 non-null   object
#  34  total_vaccinations                       32339 non-null   float64
#  35  people_vaccinated                        30847 non-null   float64
#  36  people_fully_vaccinated                  27820 non-null   float64
#  37  total_boosters                           5353 non-null    float64
#  38  new_vaccinations                         26969 non-null   float64
#  39  new_vaccinations_smoothed                57375 non-null   float64
#  40  total_vaccinations_per_hundred           32339 non-null   float64
#  41  people_vaccinated_per_hundred            30847 non-null   float64
#  42  people_fully_vaccinated_per_hundred      27820 non-null   float64
#  43  total_boosters_per_hundred               5353 non-null    float64
#  44  new_vaccinations_smoothed_per_million    57375 non-null   float64
#  45  stringency_index                         106737 non-null  float64
#  46  population                               129676 non-null  float64
#  47  population_density                       118248 non-null  float64
#  48  median_age                               112730 non-null  float64
#  49  aged_65_older                            111482 non-null  float64
#  50  aged_70_older                            112114 non-null  float64
#  51  gdp_per_capita                           113459 non-null  float64
#  52  extreme_poverty                          75896 non-null   float64
#  53  cardiovasc_death_rate                    112985 non-null  float64
#  54  diabetes_prevalence                      116659 non-null  float64
#  55  female_smokers                           88023 non-null   float64
#  56  male_smokers                             86749 non-null   float64
#  57  handwashing_facilities                   56858 non-null   float64
#  58  hospital_beds_per_thousand               102686 non-null  float64
#  59  life_expectancy                          121411 non-null  float64
#  60  human_development_index                  113078 non-null  float64
#  61  excess_mortality_cumulative_absolute     4580 non-null    float64
#  62  excess_mortality_cumulative              4580 non-null    float64
#  63  excess_mortality                         4580 non-null    float64
#  64  excess_mortality_cumulative_per_million  4580 non-null    float64
# dtypes: float64(60), object(5)
# memory usage: 64.8+ MB

# %%
df.describe()
# Out:
#         total_cases      new_cases  new_cases_smoothed  total_deaths  \
# count  1.235470e+05  123545.000000       122502.000000  1.125020e+05
# mean   1.993874e+06    8325.824752         8354.281304  4.957409e+04
# std    1.140401e+07   43496.028089        43032.176985  2.546703e+05
# min    1.000000e+00  -74347.000000        -6223.000000  1.000000e+00
# 25%    2.315000e+03       3.000000           10.286000  7.800000e+01
# 50%    2.606400e+04     104.000000          129.571000  7.190000e+02
# 75%    2.573505e+05    1069.000000         1125.000000  6.371000e+03
# max    2.475743e+08  905975.000000       826467.571000  5.013591e+06
#
#           new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  112698.000000        122502.000000            122912.000000
# mean      184.453034           169.027681             19161.451466
# std       874.025180           820.126987             31981.956175
# min     -1918.000000          -232.143000                 0.001000
# 25%         0.000000             0.143000               396.021500
# 50%         2.000000             2.000000              3058.347000
# 75%        22.000000            18.429000             24007.066250
# max     18007.000000         14703.286000            231372.930000
#
#        new_cases_per_million  new_cases_smoothed_per_million  \
# count          122910.000000                   121872.000000
# mean               85.103623                       85.170643
# std               196.268669                      166.215454
# min             -3125.829000                     -272.971000
# 25%                 0.335000                        1.649000
# 50%                11.260500                       15.757000
# 75%                82.523750                       92.027250
# max              8620.690000                     3385.473000
#
#        total_deaths_per_million  ...  female_smokers  male_smokers  \
# count             111880.000000  ...    88023.000000  86749.000000
# mean                 394.851076  ...       10.591160     32.746564
# std                  653.541611  ...       10.503238     13.510660
# min                    0.000000  ...        0.100000      7.700000
# 25%                   11.541000  ...        1.900000     21.600000
# 50%                   76.929500  ...        6.300000     31.400000
# 75%                  501.653500  ...       19.300000     41.300000
# max                 6003.582000  ...       44.000000     78.100000
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# count            56858.000000               102686.000000    121411.000000
# mean                50.874120                    3.030145        73.257895
# std                 31.822876                    2.456188         7.532961
# min                  1.188000                    0.100000        53.280000
# 25%                 20.859000                    1.300000        67.920000
# 50%                 49.839000                    2.400000        74.620000
# 75%                 83.241000                    4.000000        78.740000
# max                100.000000                   13.800000        86.750000
#
#        human_development_index  excess_mortality_cumulative_absolute  \
# count            113078.000000                           4580.000000
# mean                  0.726273                          30724.468472
# std                   0.150052                          86337.136808
# min                   0.394000                         -31959.400000
# 25%                   0.602000                           -186.075000
# 50%                   0.744000                           1992.150000
# 75%                   0.845000                          19256.700000
# max                   0.957000                         754457.300000
#
#        excess_mortality_cumulative  excess_mortality  \
# count                  4580.000000       4580.000000
# mean                      8.455262         15.658900
# std                      15.822375         31.093173
# min                     -27.350000        -95.920000
# 25%                      -1.090000         -0.990000
# 50%                       5.030000          6.275000
# 75%                      13.440000         21.742500
# max                     106.830000        373.480000
#
#        excess_mortality_cumulative_per_million
# count                              4580.000000
# mean                                755.471243
# std                                1139.369805
# min                               -1749.128494
# 25%                                 -46.895400
# 50%                                 345.233709
# 75%                                1304.780877
# max                                6142.922470
#
# [8 rows x 60 columns]

# %%
df.continent.unique()
# Out:
# array(['Asia', nan, 'Europe', 'Africa', 'North America', 'South America',
#        'Oceania'], dtype=object)

# %%
df.loc[df.continent.isna()].location.unique()
# Out:
# array(['Africa', 'Asia', 'Europe', 'European Union', 'High income',
#        'International', 'Low income', 'Lower middle income',
#        'North America', 'Oceania', 'South America', 'Upper middle income',
#        'World'], dtype=object)

# %%
df.loc[df.location=="International"]
# Out:
#        iso_code continent       location        date  total_cases  new_cases  \
# 54747  OWID_INT       NaN  International  2020-02-07         61.0       61.0
# 54748  OWID_INT       NaN  International  2020-02-08         61.0        0.0
# 54749  OWID_INT       NaN  International  2020-02-09         64.0        3.0
# 54750  OWID_INT       NaN  International  2020-02-10        135.0       71.0
# 54751  OWID_INT       NaN  International  2020-02-11        135.0        0.0
# ...         ...       ...            ...         ...          ...        ...
# 55377  OWID_INT       NaN  International  2021-10-29        721.0        0.0
# 55378  OWID_INT       NaN  International  2021-10-30        721.0        0.0
# 55379  OWID_INT       NaN  International  2021-10-31        721.0        0.0
# 55380  OWID_INT       NaN  International  2021-11-01        721.0        0.0
# 55381  OWID_INT       NaN  International  2021-11-02        721.0        0.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 54747                 NaN           NaN         NaN                  NaN  ...
# 54748                 NaN           NaN         NaN                  NaN  ...
# 54749                 NaN           NaN         NaN                  NaN  ...
# 54750                 NaN           NaN         NaN                  NaN  ...
# 54751                 NaN           NaN         NaN                  NaN  ...
# ...                   ...           ...         ...                  ...  ...
# 55377                 0.0          15.0         0.0                  0.0  ...
# 55378                 0.0          15.0         0.0                  0.0  ...
# 55379                 0.0          15.0         0.0                  0.0  ...
# 55380                 0.0          15.0         0.0                  0.0  ...
# 55381                 0.0          15.0         0.0                  0.0  ...
#
#        female_smokers  male_smokers  handwashing_facilities  \
# 54747             NaN           NaN                     NaN
# 54748             NaN           NaN                     NaN
# 54749             NaN           NaN                     NaN
# 54750             NaN           NaN                     NaN
# 54751             NaN           NaN                     NaN
# ...               ...           ...                     ...
# 55377             NaN           NaN                     NaN
# 55378             NaN           NaN                     NaN
# 55379             NaN           NaN                     NaN
# 55380             NaN           NaN                     NaN
# 55381             NaN           NaN                     NaN
#
#        hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 54747                         NaN              NaN                      NaN
# 54748                         NaN              NaN                      NaN
# 54749                         NaN              NaN                      NaN
# 54750                         NaN              NaN                      NaN
# 54751                         NaN              NaN                      NaN
# ...                           ...              ...                      ...
# 55377                         NaN              NaN                      NaN
# 55378                         NaN              NaN                      NaN
# 55379                         NaN              NaN                      NaN
# 55380                         NaN              NaN                      NaN
# 55381                         NaN              NaN                      NaN
#
#        excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 54747                                   NaN                          NaN
# 54748                                   NaN                          NaN
# 54749                                   NaN                          NaN
# 54750                                   NaN                          NaN
# 54751                                   NaN                          NaN
# ...                                     ...                          ...
# 55377                                   NaN                          NaN
# 55378                                   NaN                          NaN
# 55379                                   NaN                          NaN
# 55380                                   NaN                          NaN
# 55381                                   NaN                          NaN
#
#        excess_mortality  excess_mortality_cumulative_per_million
# 54747               NaN                                      NaN
# 54748               NaN                                      NaN
# 54749               NaN                                      NaN
# 54750               NaN                                      NaN
# 54751               NaN                                      NaN
# ...                 ...                                      ...
# 55377               NaN                                      NaN
# 55378               NaN                                      NaN
# 55379               NaN                                      NaN
# 55380               NaN                                      NaN
# 55381               NaN                                      NaN
#
# [635 rows x 65 columns]

# %%
df.location.unique()
# Out:
# array(['Afghanistan', 'Africa', 'Albania', 'Algeria', 'Andorra', 'Angola',
#        'Anguilla', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        'Asia', 'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain',
#        'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin',
#        'Bermuda', 'Bhutan', 'Bolivia', 'Bonaire Sint Eustatius and Saba',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Brunei', 'Bulgaria', 'Burkina Faso',
#        'Burundi', 'Cambodia', 'Cameroon', 'Canada', 'Cape Verde',
#        'Cayman Islands', 'Central African Republic', 'Chad', 'Chile',
#        'China', 'Colombia', 'Comoros', 'Congo', 'Cook Islands',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Curacao',
#        'Cyprus', 'Czechia', 'Democratic Republic of Congo', 'Denmark',
#        'Djibouti', 'Dominica', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Estonia',
#        'Eswatini', 'Ethiopia', 'Europe', 'European Union',
#        'Faeroe Islands', 'Falkland Islands', 'Fiji', 'Finland', 'France',
#        'French Polynesia', 'Gabon', 'Gambia', 'Georgia', 'Germany',
#        'Ghana', 'Gibraltar', 'Greece', 'Greenland', 'Grenada',
#        'Guatemala', 'Guernsey', 'Guinea', 'Guinea-Bissau', 'Guyana',
#        'Haiti', 'High income', 'Honduras', 'Hong Kong', 'Hungary',
#        'Iceland', 'India', 'Indonesia', 'International', 'Iran', 'Iraq',
#        'Ireland', 'Isle of Man', 'Israel', 'Italy', 'Jamaica', 'Japan',
#        'Jersey', 'Jordan', 'Kazakhstan', 'Kenya', 'Kiribati', 'Kosovo',
#        'Kuwait', 'Kyrgyzstan', 'Laos', 'Latvia', 'Lebanon', 'Lesotho',
#        'Liberia', 'Libya', 'Liechtenstein', 'Lithuania', 'Low income',
#        'Lower middle income', 'Luxembourg', 'Macao', 'Madagascar',
#        'Malawi', 'Malaysia', 'Maldives', 'Mali', 'Malta',
#        'Marshall Islands', 'Mauritania', 'Mauritius', 'Mexico',
#        'Micronesia (country)', 'Moldova', 'Monaco', 'Mongolia',
#        'Montenegro', 'Montserrat', 'Morocco', 'Mozambique', 'Myanmar',
#        'Namibia', 'Nauru', 'Nepal', 'Netherlands', 'New Caledonia',
#        'New Zealand', 'Nicaragua', 'Niger', 'Nigeria', 'Niue',
#        'North America', 'North Macedonia', 'Northern Cyprus', 'Norway',
#        'Oceania', 'Oman', 'Pakistan', 'Palau', 'Palestine', 'Panama',
#        'Papua New Guinea', 'Paraguay', 'Peru', 'Philippines', 'Pitcairn',
#        'Poland', 'Portugal', 'Qatar', 'Romania', 'Russia', 'Rwanda',
#        'Saint Helena', 'Saint Kitts and Nevis', 'Saint Lucia',
#        'Saint Vincent and the Grenadines', 'Samoa', 'San Marino',
#        'Sao Tome and Principe', 'Saudi Arabia', 'Senegal', 'Serbia',
#        'Seychelles', 'Sierra Leone', 'Singapore',
#        'Sint Maarten (Dutch part)', 'Slovakia', 'Slovenia',
#        'Solomon Islands', 'Somalia', 'South Africa', 'South America',
#        'South Korea', 'South Sudan', 'Spain', 'Sri Lanka', 'Sudan',
#        'Suriname', 'Sweden', 'Switzerland', 'Syria', 'Taiwan',
#        'Tajikistan', 'Tanzania', 'Thailand', 'Timor', 'Togo', 'Tokelau',
#        'Tonga', 'Trinidad and Tobago', 'Tunisia', 'Turkey',
#        'Turkmenistan', 'Turks and Caicos Islands', 'Tuvalu', 'Uganda',
#        'Ukraine', 'United Arab Emirates', 'United Kingdom',
#        'United States', 'Upper middle income', 'Uruguay', 'Uzbekistan',
#        'Vanuatu', 'Vatican', 'Venezuela', 'Vietnam', 'Wallis and Futuna',
#        'World', 'Yemen', 'Zambia', 'Zimbabwe'], dtype=object)

# %%
df["date"] = pd.to_datetime(df["date"])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130600 entries, 0 to 130599
# Data columns (total 65 columns):
#  #   Column                                   Non-Null Count   Dtype
# ---  ------                                   --------------   -----
#  0   iso_code                                 130600 non-null  object
#  1   continent                                122243 non-null  object
#  2   location                                 130600 non-null  object
#  3   date                                     130600 non-null  datetime64[ns]
#  4   total_cases                              123547 non-null  float64
#  5   new_cases                                123545 non-null  float64
#  6   new_cases_smoothed                       122502 non-null  float64
#  7   total_deaths                             112502 non-null  float64
#  8   new_deaths                               112698 non-null  float64
#  9   new_deaths_smoothed                      122502 non-null  float64
#  10  total_cases_per_million                  122912 non-null  float64
#  11  new_cases_per_million                    122910 non-null  float64
#  12  new_cases_smoothed_per_million           121872 non-null  float64
#  13  total_deaths_per_million                 111880 non-null  float64
#  14  new_deaths_per_million                   112076 non-null  float64
#  15  new_deaths_smoothed_per_million          121872 non-null  float64
#  16  reproduction_rate                        103316 non-null  float64
#  17  icu_patients                             15619 non-null   float64
#  18  icu_patients_per_million                 15619 non-null   float64
#  19  hosp_patients                            18310 non-null   float64
#  20  hosp_patients_per_million                18310 non-null   float64
#  21  weekly_icu_admissions                    1262 non-null    float64
#  22  weekly_icu_admissions_per_million        1262 non-null    float64
#  23  weekly_hosp_admissions                   2186 non-null    float64
#  24  weekly_hosp_admissions_per_million       2186 non-null    float64
#  25  new_tests                                54508 non-null   float64
#  26  total_tests                              54699 non-null   float64
#  27  total_tests_per_thousand                 54699 non-null   float64
#  28  new_tests_per_thousand                   54508 non-null   float64
#  29  new_tests_smoothed                       65945 non-null   float64
#  30  new_tests_smoothed_per_thousand          65945 non-null   float64
#  31  positive_rate                            61972 non-null   float64
#  32  tests_per_case                           61316 non-null   float64
#  33  tests_units                              67934 non-null   object
#  34  total_vaccinations                       32339 non-null   float64
#  35  people_vaccinated                        30847 non-null   float64
#  36  people_fully_vaccinated                  27820 non-null   float64
#  37  total_boosters                           5353 non-null    float64
#  38  new_vaccinations                         26969 non-null   float64
#  39  new_vaccinations_smoothed                57375 non-null   float64
#  40  total_vaccinations_per_hundred           32339 non-null   float64
#  41  people_vaccinated_per_hundred            30847 non-null   float64
#  42  people_fully_vaccinated_per_hundred      27820 non-null   float64
#  43  total_boosters_per_hundred               5353 non-null    float64
#  44  new_vaccinations_smoothed_per_million    57375 non-null   float64
#  45  stringency_index                         106737 non-null  float64
#  46  population                               129676 non-null  float64
#  47  population_density                       118248 non-null  float64
#  48  median_age                               112730 non-null  float64
#  49  aged_65_older                            111482 non-null  float64
#  50  aged_70_older                            112114 non-null  float64
#  51  gdp_per_capita                           113459 non-null  float64
#  52  extreme_poverty                          75896 non-null   float64
#  53  cardiovasc_death_rate                    112985 non-null  float64
#  54  diabetes_prevalence                      116659 non-null  float64
#  55  female_smokers                           88023 non-null   float64
#  56  male_smokers                             86749 non-null   float64
#  57  handwashing_facilities                   56858 non-null   float64
#  58  hospital_beds_per_thousand               102686 non-null  float64
#  59  life_expectancy                          121411 non-null  float64
#  60  human_development_index                  113078 non-null  float64
#  61  excess_mortality_cumulative_absolute     4580 non-null    float64
#  62  excess_mortality_cumulative              4580 non-null    float64
#  63  excess_mortality                         4580 non-null    float64
#  64  excess_mortality_cumulative_per_million  4580 non-null    float64
# dtypes: datetime64[ns](1), float64(60), object(4)
# memory usage: 64.8+ MB

# %% [markdown]
# ## 最新日付チェック

# %%
import datetime
#latest_date_str = (df.date.max()-datetime.timedelta(days=1)).strftime("%Y-%m-%d")
latest_date_str = df.date.max().strftime("%Y-%m-%d")
latest_date_str
# Out:
# '2021-11-02'

# %% [markdown]
# ## 全世界のデータのみ

# %%
world_df = df.copy().loc[df.location=="World"]
world_df.tail()
# Out:
#         iso_code continent location       date  total_cases  new_cases  \
# 128835  OWID_WRL       NaN    World 2021-10-29  246025710.0   507058.0
# 128836  OWID_WRL       NaN    World 2021-10-30  246407251.0   381541.0
# 128837  OWID_WRL       NaN    World 2021-10-31  246713221.0   305970.0
# 128838  OWID_WRL       NaN    World 2021-11-01  247144542.0   431321.0
# 128839  OWID_WRL       NaN    World 2021-11-02  247574342.0   429800.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 128835          431056.429     4989532.0      7983.0             7178.000
# 128836          433163.714     4995464.0      5932.0             7214.571
# 128837          431582.143     4999871.0      4407.0             7202.000
# 128838          435225.000     5006105.0      6234.0             7149.857
# 128839          432002.857     5013591.0      7486.0             7095.143
#
#         ...  female_smokers  male_smokers  handwashing_facilities  \
# 128835  ...           6.434        34.635                   60.13
# 128836  ...           6.434        34.635                   60.13
# 128837  ...           6.434        34.635                   60.13
# 128838  ...           6.434        34.635                   60.13
# 128839  ...           6.434        34.635                   60.13
#
#         hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 128835                       2.705            72.58                    0.737
# 128836                       2.705            72.58                    0.737
# 128837                       2.705            72.58                    0.737
# 128838                       2.705            72.58                    0.737
# 128839                       2.705            72.58                    0.737
#
#         excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 128835                                   NaN                          NaN
# 128836                                   NaN                          NaN
# 128837                                   NaN                          NaN
# 128838                                   NaN                          NaN
# 128839                                   NaN                          NaN
#
#         excess_mortality  excess_mortality_cumulative_per_million
# 128835               NaN                                      NaN
# 128836               NaN                                      NaN
# 128837               NaN                                      NaN
# 128838               NaN                                      NaN
# 128839               NaN                                      NaN
#
# [5 rows x 65 columns]

# %% [markdown]
# ### 主要国の定義

# %%
countries = pd.DataFrame([
    ("Japan",""),
    ("United States",""),
    ("India",""),
    ("Indonesia",""),
    ("Spain",""),
    ("Brazil",""),
    ("France",""),
    ("United Kingdom",""),
    ("Russia",""),
    ("Turkey",""),
#    ("South Africa",""),
    ("Iran",""),
#    ("Ecuador",""),
],columns=["country","text_disp_date"])
countries
# Out:
#            country text_disp_date
# 0            Japan
# 1    United States
# 2            India
# 3        Indonesia
# 4            Spain
# 5           Brazil
# 6           France
# 7   United Kingdom
# 8           Russia
# 9           Turkey
# 10            Iran

# %%
# 東Asia 主要国
e_asia_c = pd.DataFrame([
    ("Japan",""),
    ("China",""),
    ("Taiwan",""),
    ("South Korea",""),
    ("Indonesia",""),
    ("Philippines",""),
    ("Vietnam",""),
    ("Myanmar",""),
    ("Thailand",""),
],columns=["country","text_disp_date"])
e_asia_c
# Out:
#        country text_disp_date
# 0        Japan
# 1        China
# 2       Taiwan
# 3  South Korea
# 4    Indonesia
# 5  Philippines
# 6      Vietnam
# 7      Myanmar
# 8     Thailand

# %%
c_trans = pd.merge(countries, df, left_on="country", right_on="location",how="inner")
c_trans.head()
# Out:
#   country text_disp_date iso_code continent location       date  total_cases  \
# 0   Japan                     JPN      Asia    Japan 2020-01-22          2.0
# 1   Japan                     JPN      Asia    Japan 2020-01-23          2.0
# 2   Japan                     JPN      Asia    Japan 2020-01-24          2.0
# 3   Japan                     JPN      Asia    Japan 2020-01-25          2.0
# 4   Japan                     JPN      Asia    Japan 2020-01-26          4.0
#
#    new_cases  new_cases_smoothed  total_deaths  ...  female_smokers  \
# 0        NaN                 NaN           NaN  ...            11.2
# 1        0.0                 NaN           NaN  ...            11.2
# 2        0.0                 NaN           NaN  ...            11.2
# 3        0.0                 NaN           NaN  ...            11.2
# 4        2.0                 NaN           NaN  ...            11.2
#
#    male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 0          33.7                     NaN                       13.05
# 1          33.7                     NaN                       13.05
# 2          33.7                     NaN                       13.05
# 3          33.7                     NaN                       13.05
# 4          33.7                     NaN                       13.05
#
#    life_expectancy  human_development_index  \
# 0            84.63                    0.919
# 1            84.63                    0.919
# 2            84.63                    0.919
# 3            84.63                    0.919
# 4            84.63                    0.919
#
#    excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                   NaN                          NaN
# 1                                   NaN                          NaN
# 2                                   NaN                          NaN
# 3                                   NaN                          NaN
# 4                                   NaN                          NaN
#
#    excess_mortality  excess_mortality_cumulative_per_million
# 0               NaN                                      NaN
# 1               NaN                                      NaN
# 2               NaN                                      NaN
# 3               NaN                                      NaN
# 4               NaN                                      NaN
#
# [5 rows x 67 columns]

# %%
c_trans.location.unique()
# Out:
# array(['Japan', 'United States', 'India', 'Indonesia', 'Spain', 'Brazil',
#        'France', 'United Kingdom', 'Russia', 'Turkey', 'Iran'],
#       dtype=object)

# %%
c_trans.loc[c_trans.date==latest_date_str][["country","date","total_deaths","total_deaths_per_million"]].sort_values("total_deaths_per_million",ascending=False)
# Out:
#              country       date  total_deaths  total_deaths_per_million
# 3812          Brazil 2021-11-02      608071.0                  2841.540
# 1301   United States 2021-11-02      748518.0                  2248.375
# 5103  United Kingdom 2021-11-02      141390.0                  2072.951
# 3196           Spain 2021-11-02       87423.0                  1870.202
# 4461          France 2021-11-02      118720.0                  1757.142
# 5745          Russia 2021-11-02      236462.0                  1620.579
# 6970            Iran 2021-11-02      126616.0                  1489.096
# 6347          Turkey 2021-11-02       71052.0                   835.486
# 2555       Indonesia 2021-11-02      143457.0                   519.091
# 1944           India 2021-11-02      459191.0                   329.545
# 650            Japan 2021-11-02       18289.0                   145.092

# %%
e_a_trans = pd.merge(e_asia_c, df, left_on="country", right_on="location",how="inner")
e_a_trans
# Out:
#        country text_disp_date iso_code continent  location       date  \
# 0        Japan                     JPN      Asia     Japan 2020-01-22
# 1        Japan                     JPN      Asia     Japan 2020-01-23
# 2        Japan                     JPN      Asia     Japan 2020-01-24
# 3        Japan                     JPN      Asia     Japan 2020-01-25
# 4        Japan                     JPN      Asia     Japan 2020-01-26
# ...        ...            ...      ...       ...       ...        ...
# 5765  Thailand                     THA      Asia  Thailand 2021-10-29
# 5766  Thailand                     THA      Asia  Thailand 2021-10-30
# 5767  Thailand                     THA      Asia  Thailand 2021-10-31
# 5768  Thailand                     THA      Asia  Thailand 2021-11-01
# 5769  Thailand                     THA      Asia  Thailand 2021-11-02
#
#       total_cases  new_cases  new_cases_smoothed  total_deaths  ...  \
# 0             2.0        NaN                 NaN           NaN  ...
# 1             2.0        0.0                 NaN           NaN  ...
# 2             2.0        0.0                 NaN           NaN  ...
# 3             2.0        0.0                 NaN           NaN  ...
# 4             4.0        2.0                 NaN           NaN  ...
# ...           ...        ...                 ...           ...  ...
# 5765    1893941.0     8968.0            8936.000       19070.0  ...
# 5766    1903165.0     9224.0            8862.000       19158.0  ...
# 5767    1912024.0     8859.0            8791.714       19205.0  ...
# 5768    1920189.0     8165.0            8718.857       19260.0  ...
# 5769    1935442.0    15253.0            9797.000       19394.0  ...
#
#       female_smokers  male_smokers  handwashing_facilities  \
# 0               11.2          33.7                     NaN
# 1               11.2          33.7                     NaN
# 2               11.2          33.7                     NaN
# 3               11.2          33.7                     NaN
# 4               11.2          33.7                     NaN
# ...              ...           ...                     ...
# 5765             1.9          38.8                   90.67
# 5766             1.9          38.8                   90.67
# 5767             1.9          38.8                   90.67
# 5768             1.9          38.8                   90.67
# 5769             1.9          38.8                   90.67
#
#       hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                          13.05            84.63                    0.919
# 1                          13.05            84.63                    0.919
# 2                          13.05            84.63                    0.919
# 3                          13.05            84.63                    0.919
# 4                          13.05            84.63                    0.919
# ...                          ...              ...                      ...
# 5765                        2.10            77.15                    0.777
# 5766                        2.10            77.15                    0.777
# 5767                        2.10            77.15                    0.777
# 5768                        2.10            77.15                    0.777
# 5769                        2.10            77.15                    0.777
#
#       excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                      NaN                          NaN
# 1                                      NaN                          NaN
# 2                                      NaN                          NaN
# 3                                      NaN                          NaN
# 4                                      NaN                          NaN
# ...                                    ...                          ...
# 5765                                   NaN                          NaN
# 5766                                   NaN                          NaN
# 5767                                   NaN                          NaN
# 5768                                   NaN                          NaN
# 5769                                   NaN                          NaN
#
#       excess_mortality  excess_mortality_cumulative_per_million
# 0                  NaN                                      NaN
# 1                  NaN                                      NaN
# 2                  NaN                                      NaN
# 3                  NaN                                      NaN
# 4                  NaN                                      NaN
# ...                ...                                      ...
# 5765               NaN                                      NaN
# 5766               NaN                                      NaN
# 5767               NaN                                      NaN
# 5768               NaN                                      NaN
# 5769               NaN                                      NaN
#
# [5770 rows x 67 columns]

# %%
e_a_trans.location.unique()
# Out:
# array(['Japan', 'China', 'Taiwan', 'South Korea', 'Indonesia',
#        'Philippines', 'Vietnam', 'Myanmar', 'Thailand'], dtype=object)

# %% [markdown]
# ## 今日の新規感染者数

# %%
#c_df_latest = df.loc[(df.date==pd.to_datetime(latest_date_str)-datetime.timedelta(days=1)) & (df.iso_code.str.len()==3)]
c_df_latest = df.loc[(df.date==pd.to_datetime(latest_date_str)) & (df.iso_code.str.len()==3)]

c_df_latest
# Out:
#        iso_code      continent     location       date  total_cases  \
# 617         AFG           Asia  Afghanistan 2021-11-02     156307.0
# 1863        ALB         Europe      Albania 2021-11-02     186222.0
# 2480        DZA         Africa      Algeria 2021-11-02     206649.0
# 3091        AND         Europe      Andorra 2021-11-02      15516.0
# 3684        AGO         Africa       Angola 2021-11-02      64487.0
# ...         ...            ...          ...        ...          ...
# 127314      VEN  South America    Venezuela 2021-11-02     408727.0
# 127964      VNM           Asia      Vietnam 2021-11-02     932357.0
# 129411      YEM           Asia        Yemen 2021-11-02       9806.0
# 130006      ZMB         Africa       Zambia 2021-11-02     209760.0
# 130599      ZWE         Africa     Zimbabwe 2021-11-02     133047.0
#
#         new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 617          23.0              33.714        7281.0         0.0
# 1863        725.0             516.000        2937.0         6.0
# 2480         83.0              94.143        5927.0         3.0
# 3091          0.0              13.000         130.0         0.0
# 3684         29.0              64.857        1713.0         0.0
# ...           ...                 ...           ...         ...
# 127314      861.0            1066.857        4915.0        13.0
# 127964     5637.0            5169.000       22205.0        74.0
# 129411        7.0              13.571        1894.0         4.0
# 130006       21.0              16.000        3661.0         0.0
# 130599       40.0              46.143        4683.0         4.0
#
#         new_deaths_smoothed  ...  female_smokers  male_smokers  \
# 617                   2.714  ...             NaN           NaN
# 1863                  7.000  ...             7.1          51.2
# 2480                  4.000  ...             0.7          30.4
# 3091                  0.000  ...            29.0          37.8
# 3684                  1.571  ...             NaN           NaN
# ...                     ...  ...             ...           ...
# 127314               13.286  ...             NaN           NaN
# 127964               57.571  ...             1.0          45.9
# 129411                5.143  ...             7.6          29.2
# 130006                0.143  ...             3.1          24.7
# 130599                1.286  ...             1.6          30.7
#
#         handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 617                     37.746                        0.50            64.83
# 1863                       NaN                        2.89            78.57
# 2480                    83.741                        1.90            76.88
# 3091                       NaN                         NaN            83.73
# 3684                    26.664                         NaN            61.15
# ...                        ...                         ...              ...
# 127314                     NaN                        0.80            72.06
# 127964                  85.847                        2.60            75.40
# 129411                  49.542                        0.70            66.12
# 130006                  13.938                        2.00            63.89
# 130599                  36.791                        1.70            61.49
#
#         human_development_index  excess_mortality_cumulative_absolute  \
# 617                       0.511                                   NaN
# 1863                      0.795                                   NaN
# 2480                      0.748                                   NaN
# 3091                      0.868                                   NaN
# 3684                      0.581                                   NaN
# ...                         ...                                   ...
# 127314                    0.711                                   NaN
# 127964                    0.704                                   NaN
# 129411                    0.470                                   NaN
# 130006                    0.584                                   NaN
# 130599                    0.571                                   NaN
#
#         excess_mortality_cumulative  excess_mortality  \
# 617                             NaN               NaN
# 1863                            NaN               NaN
# 2480                            NaN               NaN
# 3091                            NaN               NaN
# 3684                            NaN               NaN
# ...                             ...               ...
# 127314                          NaN               NaN
# 127964                          NaN               NaN
# 129411                          NaN               NaN
# 130006                          NaN               NaN
# 130599                          NaN               NaN
#
#         excess_mortality_cumulative_per_million
# 617                                         NaN
# 1863                                        NaN
# 2480                                        NaN
# 3091                                        NaN
# 3684                                        NaN
# ...                                         ...
# 127314                                      NaN
# 127964                                      NaN
# 129411                                      NaN
# 130006                                      NaN
# 130599                                      NaN
#
# [197 rows x 65 columns]

# %%
c_df_latest.sum()
# Out:
# iso_code                                   AFGALBDZAANDAGOATGARGARMABWAUSAUTAZEBHSBHRBGDB...
# continent                                  AsiaEuropeAfricaEuropeAfricaNorth AmericaSouth...
# location                                   AfghanistanAlbaniaAlgeriaAndorraAngolaAntigua ...
# total_cases                                                                      247411968.0
# new_cases                                                                           429779.0
#                                                                  ...
# human_development_index                                                              135.823
# excess_mortality_cumulative_absolute                                                     0.0
# excess_mortality_cumulative                                                              0.0
# excess_mortality                                                                         0.0
# excess_mortality_cumulative_per_million                                                  0.0
# Length: 64, dtype: object

# %% [markdown]
# ## 可視化

# %%
import matplotlib.pyplot as plt
#%matplotlib notebook
# %matplotlib inline

# %%
min_date = pd.to_datetime(datetime.datetime.now()).round("D")- datetime.timedelta(days=90)

# %%
world_df["case_rolling7ave"] = world_df.new_cases.rolling(7).mean()
world_df[["new_cases_smoothed","case_rolling7ave"]]
# Out:
#         new_cases_smoothed  case_rolling7ave
# 128189                 NaN               NaN
# 128190                 NaN               NaN
# 128191                 NaN               NaN
# 128192                 NaN               NaN
# 128193                 NaN               NaN
# ...                    ...               ...
# 128835          431056.429     431056.428571
# 128836          433163.714     433163.714286
# 128837          431582.143     431582.142857
# 128838          435225.000     435225.000000
# 128839          432002.857     432002.857143
#
# [651 rows x 2 columns]

# %%
fig=plt.figure(figsize=(20,12))
plt.subplot(2,2,1) # (rows, columns, panel number)
plt.title("Daily new confirmed COVID-19 cases in the world")
plt.bar(world_df.date,world_df.new_cases,label="New cases")
plt.plot_date(world_df["date"],world_df["new_cases_smoothed"],label="rolling 7-day average", fmt="-", color="orange")
#plt.xticks(rotation=70)
plt.ylabel("people")
plt.grid(axis="y")
plt.legend()

plt.subplot(2,2,2) # (rows, columns, panel number)
plt.title("Daily new confirmed COVID-19 cases in the world(Recent)")
chart_data = world_df[world_df.date >= min_date]
plt.bar(chart_data["date"],chart_data["new_cases"],label="New cases")
plt.plot_date(chart_data["date"],chart_data["new_cases_smoothed"],label="rolling 7-day average", fmt="-", color="orange")
#plt.xticks(rotation=70)
plt.grid(axis="y")
plt.legend()

plt.subplot(2,2,3) # (rows, columns, panel number)
plt.title("Daily new deaths in the world")
plt.bar(world_df.date,world_df.new_deaths,label="New deaths")
plt.plot_date(world_df["date"],world_df["new_deaths_smoothed"],label="rolling 7-day average", fmt="-", color="orange")
#plt.xticks(rotation=70)
plt.ylabel("people")
plt.grid(axis="y")
plt.legend()

plt.subplot(2,2,4) # (rows, columns, panel number)
plt.title("Daily new deaths in the world(Recent)")
chart_data = world_df[world_df.date >= min_date]
plt.bar(chart_data["date"],chart_data["new_deaths"],label="New deaths")
plt.plot_date(chart_data["date"],chart_data["new_deaths_smoothed"],label="rolling 7-day average", fmt="-", color="orange")
#plt.xticks(rotation=70)
plt.grid(axis="y")
plt.legend()

fig.text(0,1,"Latest: {}".format(latest_date_str),ha="left",va="top")
fig.text(0,0
         ,"*Data Source : COVID-19 Dataset by Our World in Data",
        ha="left",va="bottom")

fig.tight_layout()

# %%
fig.savefig("out/covid-owid-global-daily.png")

# %% [markdown]
# ### 国別

# %% [markdown]
# #### 人口100万人当たりの新規感染者数（直近）

# %%
"""
#min_date = pd.to_datetime("2021-05-01")
# 主要国 新規感染者
chart_data = c_trans[c_trans.date >= min_date]
dates = chart_data["date"].unique()
print(len(dates))
print(dates.max())
for i,cr in countries.iterrows():
    c = cr["country"]
    dates = chart_data.loc[chart_data["location"]==c]["date"]
    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else latest_date_str
    print(len(chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"]))
    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"],label=c, fmt="-")
    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_cases_smoothed_per_million"],c
            ,fontsize=8,va="center")
"""
# Out:
# '\n#min_date = pd.to_datetime("2021-05-01")\n# 主要国 新規感染者\nchart_data = c_trans[c_trans.date >= min_date]\ndates = chart_data["date"].unique()\nprint(len(dates))\nprint(dates.max())\nfor i,cr in countries.iterrows():\n    c = cr["country"]\n    dates = chart_data.loc[chart_data["location"]==c]["date"]\n    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else latest_date_str\n    print(len(chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"]))\n    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"],label=c, fmt="-")\n    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_cases_smoothed_per_million"],c\n            ,fontsize=8,va="center")\n'

# %%
"""
fig=plt.figure(figsize=(14,10))
min_date = pd.to_datetime("2021-03-01")
# 主要国 新規感染者
plt.subplot(2,2,1) # (rows, columns, panel number)
plt.title("Daily new confirmed COVID-19 cases\n per million population in major countries\n(rolling 7day ave.)")
plt.grid()
plt.xticks(rotation=70)
chart_data = c_trans[c_trans.date >= min_date]
dates = chart_data["date"].unique()
for i,cr in countries.iterrows():
    c = cr["country"]
    dates = chart_data.loc[chart_data["location"]==c]["date"]
    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else dates.max()
    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"],label=c, fmt="-")
    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_cases_smoothed_per_million"],c
            ,fontsize=8,va="center")
plt.legend(bbox_to_anchor=(0, 1),loc='upper left', fontsize=9)
"""
# Out:
# '\nfig=plt.figure(figsize=(14,10))\nmin_date = pd.to_datetime("2021-03-01")\n# 主要国 新規感染者\nplt.subplot(2,2,1) # (rows, columns, panel number)\nplt.title("Daily new confirmed COVID-19 cases\n per million population in major countries\n(rolling 7day ave.)")\nplt.grid()\nplt.xticks(rotation=70)\nchart_data = c_trans[c_trans.date >= min_date]\ndates = chart_data["date"].unique()\nfor i,cr in countries.iterrows():\n    c = cr["country"]\n    dates = chart_data.loc[chart_data["location"]==c]["date"]\n    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else dates.max()\n    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"],label=c, fmt="-")\n    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_cases_smoothed_per_million"],c\n            ,fontsize=8,va="center")\nplt.legend(bbox_to_anchor=(0, 1),loc=\'upper left\', fontsize=9)\n'

# %%
fig=plt.figure(figsize=(20,14))
# 主要国 新規感染者
plt.subplot(2,2,1) # (rows, columns, panel number)
plt.title("Daily new confirmed COVID-19 cases\n per million population in major countries\n(rolling 7day ave.)")
plt.grid()
plt.xticks(rotation=45)
chart_data = c_trans[c_trans.date >= min_date]
for i,cr in countries.iterrows():
    c = cr["country"]
    dates = chart_data.loc[chart_data["location"]==c]["date"]
    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else dates.max()
    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"],label=c, fmt="-")
    text_y = chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_cases_smoothed_per_million"]
#    print(text_y)
    print(c,text_disp_date,text_y)
#    plt.text(text_disp_date,text_y,c,fontsize=10,va="center")
    plt.text(text_disp_date,text_y,c,va="center")
plt.legend(bbox_to_anchor=(0, 1),loc='upper left')

# 主要国 死者
plt.subplot(2,2,2) # (rows, columns, panel number)
plt.title("Daily new deaths in major countries(rolling 7day ave.)")
plt.grid()
plt.xticks(rotation=45)
chart_data = c_trans[c_trans.date >= min_date]
for i,cr in countries.iterrows():
    c = cr["country"]
    dates = chart_data.loc[chart_data["location"]==c]["date"]
    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else dates.max()
    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_deaths_smoothed"],label=c, fmt="-")
    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_deaths_smoothed"],c
            ,va="center")
plt.legend(bbox_to_anchor=(0, 1),loc='upper left')

plt.subplot(2,2,3) # (rows, columns, panel number)
plt.grid()
plt.xticks(rotation=45)
plt.title("Daily new confirmed COVID-19 cases\n per million population in Eastern Asia\n(rolling 7day ave.)")
chart_data = e_a_trans[e_a_trans.date >= min_date]
for i,cr in e_asia_c.iterrows():
    c = cr["country"]
    dates = chart_data.loc[chart_data["location"]==c]["date"]
    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else dates.max()
    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_cases_smoothed_per_million"],label=c, fmt="-")
    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_cases_smoothed_per_million"],c
             ,va="center")
plt.legend(bbox_to_anchor=(0, 1),loc='upper left')

plt.subplot(2,2,4) # (rows, columns, panel number)
plt.grid()
plt.xticks(rotation=45)
plt.title("Daily new deaths in Eastern Asia(rolling 7day ave.)")
chart_data = e_a_trans[e_a_trans.date >= min_date]
for i,cr in e_asia_c.iterrows():
    c = cr["country"]
    dates = chart_data.loc[chart_data["location"]==c]["date"]
    text_disp_date = pd.to_datetime(cr["text_disp_date"]) if cr["text_disp_date"]!="" else dates.max()
    plt.plot_date(dates,chart_data.loc[chart_data["location"]==c]["new_deaths_smoothed"],label=c, fmt="-")
    plt.text(text_disp_date,chart_data.loc[(chart_data["location"]==c) & (chart_data["date"]==text_disp_date)]["new_deaths_smoothed"],c
             ,va="center")
plt.legend(bbox_to_anchor=(0, 1),loc='upper left')

fig.text(0,0.98,"Latest: {}".format(latest_date_str),ha="left",va="top")
fig.text(0,0
         ,"*Data Source : COVID-19 Dataset by Our World in Data",
        ha="left",va="bottom")
fig.tight_layout()
"""
"""
# Out:
# Japan 2021-11-02 00:00:00 650    6.458
# Name: new_cases_smoothed_per_million, dtype: float64
# United States 2021-11-02 00:00:00 1301    223.271
# Name: new_cases_smoothed_per_million, dtype: float64
# India 2021-11-02 00:00:00 1944    9.482
# Name: new_cases_smoothed_per_million, dtype: float64
# Indonesia 2021-11-02 00:00:00 2555    2.214
# Name: new_cases_smoothed_per_million, dtype: float64
# Spain 2021-11-02 00:00:00 3196    39.194
# Name: new_cases_smoothed_per_million, dtype: float64
# Brazil 2021-11-02 00:00:00 3812    48.159
# Name: new_cases_smoothed_per_million, dtype: float64
# France 2021-11-02 00:00:00 4461    79.112
# Name: new_cases_smoothed_per_million, dtype: float64
# United Kingdom 2021-11-02 00:00:00 5103    585.004
# Name: new_cases_smoothed_per_million, dtype: float64
# Russia 2021-11-02 00:00:00 5745    264.183
# Name: new_cases_smoothed_per_million, dtype: float64
# Turkey 2021-11-02 00:00:00 6347    306.318
# Name: new_cases_smoothed_per_million, dtype: float64
# Iran 2021-11-02 00:00:00 6970    112.807
# Name: new_cases_smoothed_per_million, dtype: float64
# '\n'

# %%
fig.savefig("out/covid-owid-countries-daily.png")

# %% [markdown]
# ### 新規感染者数

# %%
fig = plt.figure(figsize=(12,14))

plt.subplot(2,2,1) # (rows, columns, panel number)
plt.title("New confirmed COVID-19 cases worst 50")
plt.yticks(fontsize=9)
plt.xlabel("people")
chart_data = c_df_latest.sort_values("new_cases",ascending=False).head(50).sort_values("new_cases",ascending=True)
plt.barh(chart_data["location"],chart_data["new_cases"],label="new cases a day")
plt.grid(axis="x")
mean = int(c_df_latest.new_cases.mean())
plt.plot([mean,mean],[0,50], 'k--', lw=0.5)
plt.text(mean,50,"Mean:{}".format(mean),ha="center",fontsize=9)
plt.legend()

plt.subplot(2,2,2) # (rows, columns, panel number)
plt.title("New confirmed COVID-19 cases per million worst 50")
plt.yticks(fontsize=9)
plt.xlabel("people")
chart_data = c_df_latest.sort_values("new_cases_per_million",ascending=False).head(50).sort_values("new_cases_per_million",ascending=True)
plt.barh(chart_data["location"],chart_data["new_cases_per_million"],label="new cases a day per million")
plt.grid(axis="x")
mean = int(chart_data.new_cases_per_million.mean())
plt.plot([mean,mean],[0,50], 'k--', lw=0.5)
plt.text(mean,50,"Mean:{}".format(mean),ha="center",fontsize=9)
plt.legend()

fig.text(0,0.98,"Latest: {}".format(latest_date_str),fontsize=9,ha="left",va="top")
fig.text(0,0
         ,"*Data Source : COVID-19 Dataset by Our World in Data",
        fontsize=8,ha="left",va="bottom")

plt.subplot(2,2,3) # (rows, columns, panel number)
plt.title("New deaths worst 50")
plt.yticks(fontsize=9)
plt.xlabel("people")
chart_data = c_df_latest.sort_values("new_deaths",ascending=False).head(50).sort_values("new_deaths",ascending=True)
plt.barh(chart_data["location"],chart_data["new_deaths"],label="new deaths a day")
plt.grid(axis="x")
mean = int(c_df_latest.new_deaths.mean())
plt.plot([mean,mean],[0,50], 'k--', lw=0.5)
plt.text(mean,50,"Mean:{}".format(mean),ha="center",fontsize=9)
plt.legend()

plt.subplot(2,2,4) # (rows, columns, panel number)
plt.title("Total deaths per capita worst 50")
plt.yticks(fontsize=9)
plt.xlabel("%")
chart_data = c_df_latest.copy()
chart_data["total_deaths_per_capita"] = chart_data.total_deaths / chart_data.population * 100
chart_data = chart_data.sort_values("total_deaths_per_capita",ascending=False).head(50).sort_values("total_deaths_per_capita",ascending=True)
plt.barh(chart_data["location"],chart_data["total_deaths_per_capita"],label="total deaths per capita")
plt.grid(axis="x")
mean = round(chart_data.total_deaths_per_capita.mean(),2)
plt.plot([mean,mean],[0,50], 'k--', lw=0.5)
plt.text(mean,50,"Mean:{}".format(mean),ha="center",fontsize=9)
plt.legend()


fig.tight_layout()

# %%
fig.savefig("out/covid-owid-global-latest-top.png")

# %%
a_df = df.loc[df.location=="Japan"]
c_df = df.loc[(df.date==pd.to_datetime("2021-07-27")) & (df.iso_code.str.len()==3)]

# %%
a_df.tail(10)
# Out:
#       iso_code continent location       date  total_cases  new_cases  \
# 60029      JPN      Asia    Japan 2021-10-24    1717698.0      236.0
# 60030      JPN      Asia    Japan 2021-10-25    1717851.0      153.0
# 60031      JPN      Asia    Japan 2021-10-26    1718165.0      314.0
# 60032      JPN      Asia    Japan 2021-10-27    1718486.0      321.0
# 60033      JPN      Asia    Japan 2021-10-28    1718764.0      278.0
# 60034      JPN      Asia    Japan 2021-10-29    1719043.0      279.0
# 60035      JPN      Asia    Japan 2021-10-30    1723327.0     4284.0
# 60036      JPN      Asia    Japan 2021-10-31    1723559.0      232.0
# 60037      JPN      Asia    Japan 2021-11-01    1723645.0       86.0
# 60038      JPN      Asia    Japan 2021-11-02    1723863.0      218.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 60029             311.857       18207.0         8.0               13.571  ...
# 60030             300.857       18214.0         7.0               12.143  ...
# 60031             292.571       18229.0        15.0               10.429  ...
# 60032             282.571       18236.0         7.0               10.000  ...
# 60033             272.286       18245.0         9.0                9.000  ...
# 60034             266.571       18261.0        16.0                9.571  ...
# 60035             837.857       18268.0         7.0                9.857  ...
# 60036             837.286       18275.0         7.0                9.714  ...
# 60037             827.714       18282.0         7.0                9.714  ...
# 60038             814.000       18289.0         7.0                8.571  ...
#
#        female_smokers  male_smokers  handwashing_facilities  \
# 60029            11.2          33.7                     NaN
# 60030            11.2          33.7                     NaN
# 60031            11.2          33.7                     NaN
# 60032            11.2          33.7                     NaN
# 60033            11.2          33.7                     NaN
# 60034            11.2          33.7                     NaN
# 60035            11.2          33.7                     NaN
# 60036            11.2          33.7                     NaN
# 60037            11.2          33.7                     NaN
# 60038            11.2          33.7                     NaN
#
#        hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 60029                       13.05            84.63                    0.919
# 60030                       13.05            84.63                    0.919
# 60031                       13.05            84.63                    0.919
# 60032                       13.05            84.63                    0.919
# 60033                       13.05            84.63                    0.919
# 60034                       13.05            84.63                    0.919
# 60035                       13.05            84.63                    0.919
# 60036                       13.05            84.63                    0.919
# 60037                       13.05            84.63                    0.919
# 60038                       13.05            84.63                    0.919
#
#        excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 60029                                   NaN                          NaN
# 60030                                   NaN                          NaN
# 60031                                   NaN                          NaN
# 60032                                   NaN                          NaN
# 60033                                   NaN                          NaN
# 60034                                   NaN                          NaN
# 60035                                   NaN                          NaN
# 60036                                   NaN                          NaN
# 60037                                   NaN                          NaN
# 60038                                   NaN                          NaN
#
#        excess_mortality  excess_mortality_cumulative_per_million
# 60029               NaN                                      NaN
# 60030               NaN                                      NaN
# 60031               NaN                                      NaN
# 60032               NaN                                      NaN
# 60033               NaN                                      NaN
# 60034               NaN                                      NaN
# 60035               NaN                                      NaN
# 60036               NaN                                      NaN
# 60037               NaN                                      NaN
# 60038               NaN                                      NaN
#
# [10 rows x 65 columns]

# %%
c_df.sort_values("new_deaths",ascending=False).head(50)
# Out:
#        iso_code      continent        location       date  total_cases  \
# 54648       IDN           Asia       Indonesia 2021-07-27    3239936.0
# 16785       BRA  South America          Brazil 2021-07-27   19749073.0
# 97321       RUS         Europe          Russia 2021-07-27    6094379.0
# 54037       IND           Asia           India 2021-07-27   31484605.0
# 76774       MEX  North America          Mexico 2021-07-27    2771846.0
# 123803      USA  North America   United States 2021-07-27   34684737.0
# 55906       IRN           Asia            Iran 2021-07-27    3758197.0
# 81532       MMR           Asia         Myanmar 2021-07-27     279119.0
# 108050      ZAF         Africa    South Africa 2021-07-27    2391223.0
# 25211       COL  South America        Colombia 2021-07-27    4747775.0
# 10295       BGD           Asia      Bangladesh 2021-07-27    1194752.0
# 5112        ARG  South America       Argentina 2021-07-27    4875927.0
# 72736       MYS           Asia        Malaysia 2021-07-27    1044071.0
# 119428      TUN         Africa         Tunisia 2021-07-27     575002.0
# 123152      GBR         Europe  United Kingdom 2021-07-27    5771732.0
# 116709      THA           Asia        Thailand 2021-07-27     526828.0
# 130501      ZWE         Africa        Zimbabwe 2021-07-27     101711.0
# 93482       PER  South America            Peru 2021-07-27    2106371.0
# 28935       CUB  North America            Cuba 2021-07-27     349055.0
# 94125       PHL           Asia     Philippines 2021-07-27    1562420.0
# 56524       IRQ           Asia            Iraq 2021-07-27    1577013.0
# 14832       BOL  South America         Bolivia 2021-07-27     470024.0
# 47601       GTM  North America       Guatemala 2021-07-27     355223.0
# 51518       HND  North America        Honduras 2021-07-27     291687.0
# 92810       PRY  South America        Paraguay 2021-07-27     450494.0
# 110540      ESP         Europe           Spain 2021-07-27    4368453.0
# 120030      TUR           Asia          Turkey 2021-07-27    5638178.0
# 111186      LKA           Asia       Sri Lanka 2021-07-27     299892.0
# 90326       PAK           Asia        Pakistan 2021-07-27    1015827.0
# 27115       CRI  North America      Costa Rica 2021-07-27     402044.0
# 121866      UKR         Europe         Ukraine 2021-07-27    2327777.0
# 519         AFG           Asia     Afghanistan 2021-07-27     145008.0
# 82131       NAM         Africa         Namibia 2021-07-27     117293.0
# 80946       MOZ         Africa      Mozambique 2021-07-27     113426.0
# 23953       CHL  South America           Chile 2021-07-27    1611090.0
# 41858       FRA         Europe          France 2021-07-27    6089097.0
# 72087       MWI         Africa          Malawi 2021-07-27      49752.0
# 80355       MAR         Africa         Morocco 2021-07-27     588448.0
# 2382        DZA         Africa         Algeria 2021-07-27     165204.0
# 67540       LBY         Africa           Libya 2021-07-27     240309.0
# 58687       ITA         Europe           Italy 2021-07-27    4325046.0
# 129908      ZMB         Africa          Zambia 2021-07-27     192956.0
# 82925       NPL           Asia           Nepal 2021-07-27     685673.0
# 19987       KHM           Asia        Cambodia 2021-07-27      74386.0
# 44588       DEU         Europe         Germany 2021-07-27    3766501.0
# 43942       GEO           Asia         Georgia 2021-07-27     407689.0
# 89709       OMN           Asia            Oman 2021-07-27     295017.0
# 127216      VEN  South America       Venezuela 2021-07-27     301979.0
# 102562      SEN         Africa         Senegal 2021-07-27      58523.0
# 63966       KGZ           Asia      Kyrgyzstan 2021-07-27     159089.0
#
#         new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 54648     45203.0           41411.143       86835.0      2069.0
# 16785     41411.0           47090.857      551835.0      1333.0
# 97321     22486.0           23207.714      152836.0       767.0
# 54037     43654.0           38324.000      422022.0       640.0
# 76774     17408.0           13364.143      239079.0       484.0
# 123803    68488.0           61492.429      611216.0       449.0
# 55906     34951.0           26007.000       89479.0       357.0
# 81532      4964.0            5507.000        7845.0       338.0
# 108050     7733.0           11427.286       70338.0       320.0
# 25211     11426.0           11289.286      119482.0       300.0
# 10295     14925.0            9409.000       19779.0       258.0
# 5112      16757.0           13101.143      104352.0       247.0
# 72736     16117.0           14881.714        8408.0       207.0
# 119428     1608.0            2870.143       18968.0       164.0
# 123152    23401.0           32728.143      129591.0       131.0
# 116709    14150.0           14336.143        4264.0       118.0
# 130501     1767.0            1899.429        3280.0       107.0
# 93482      1366.0            1479.714      196058.0        85.0
# 28935      7903.0            7800.857        2492.0        75.0
# 94125      7024.0            6359.571       27318.0        71.0
# 56524     12185.0            9499.429       18418.0        71.0
# 14832      1601.0             985.571       17716.0        65.0
# 47601      2639.0            2494.429       10176.0        64.0
# 51518      1240.0            1285.857        7713.0        63.0
# 92810       592.0             603.857       14759.0        58.0
# 110540    26399.0           25616.714       81323.0        55.0
# 120030    19761.0           13144.571       51048.0        51.0
# 111186     1711.0            1702.714        4195.0        48.0
# 90326      4119.0            2768.000       23133.0        46.0
# 27115      3436.0            1129.857        4987.0        46.0
# 121866     1227.0            1127.286       55420.0        39.0
# 519         723.0             370.571        6515.0        38.0
# 82131       329.0             550.714        2871.0        37.0
# 80946      1703.0            1631.000        1341.0        34.0
# 23953       745.0            1318.857       35151.0        32.0
# 41858     27128.0           19515.286      111881.0        29.0
# 72087       743.0             724.000        1540.0        27.0
# 80355      6971.0            3718.857        9638.0        27.0
# 2382       1544.0            1345.714        4112.0        25.0
# 67540      3348.0            1944.000        3422.0        24.0
# 58687      4516.0            4566.143      127995.0        24.0
# 129908      640.0             764.857        3316.0        21.0
# 82925      2726.0            2102.857        9758.0        20.0
# 19987       685.0             798.571        1324.0        19.0
# 44588      2060.0            1665.000       91592.0        19.0
# 43942      3666.0            2392.000        5731.0        17.0
# 89709       491.0             853.571        3788.0        17.0
# 127216     1060.0            1159.000        3524.0        15.0
# 102562      642.0             707.143        1300.0        14.0
# 63966       969.0            1068.857        2275.0        14.0
#
#         new_deaths_smoothed  ...  female_smokers  male_smokers  \
# 54648              1519.286  ...             2.8          76.1
# 16785              1093.571  ...            10.1          17.9
# 97321               768.429  ...            23.4          58.3
# 54037               506.000  ...             1.9          20.6
# 76774               324.143  ...             6.9          21.4
# 123803              303.429  ...            19.1          24.6
# 55906               265.000  ...             0.8          21.1
# 81532               325.429  ...             6.3          35.2
# 108050              380.286  ...             8.1          33.2
# 25211               335.857  ...             4.7          13.5
# 10295               207.714  ...             1.0          44.7
# 5112                281.571  ...            16.2          27.7
# 72736               166.714  ...             1.0          42.4
# 119428              163.857  ...             1.1          65.8
# 123152               68.857  ...            20.0          24.7
# 116709              108.857  ...             1.9          38.8
# 130501               76.143  ...             1.6          30.7
# 93482               103.714  ...             4.8           NaN
# 28935                67.571  ...            17.1          53.3
# 94125                67.714  ...             7.8          40.8
# 56524                66.714  ...             NaN           NaN
# 14832                34.429  ...             NaN           NaN
# 47601                35.571  ...             NaN           NaN
# 51518                29.429  ...             2.0           NaN
# 92810                52.143  ...             5.0          21.6
# 110540               25.000  ...            27.4          31.4
# 120030               56.857  ...            14.1          41.1
# 111186               46.429  ...             0.3          27.0
# 90326                35.000  ...             2.8          36.7
# 27115                10.286  ...             6.4          17.4
# 121866               28.429  ...            13.5          47.4
# 519                  35.571  ...             NaN           NaN
# 82131                44.857  ...             9.7          34.2
# 80946                26.143  ...             5.1          29.1
# 23953                83.143  ...            34.2          41.5
# 41858                24.857  ...            30.1          35.6
# 72087                25.286  ...             4.4          24.7
# 80355                21.714  ...             0.8          47.1
# 2382                 19.000  ...             0.7          30.4
# 67540                16.143  ...             NaN           NaN
# 58687                15.857  ...            19.8          27.8
# 129908               25.429  ...             3.1          24.7
# 82925                21.571  ...             9.5          37.8
# 19987                25.000  ...             2.0          33.7
# 44588                24.143  ...            28.2          33.1
# 43942                19.857  ...             5.3          55.5
# 89709                41.429  ...             0.5          15.6
# 127216               18.857  ...             NaN           NaN
# 102562                9.143  ...             0.4          16.6
# 63966                11.286  ...             3.6          50.5
#
#         handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 54648                   64.204                        1.04            71.72
# 16785                      NaN                        2.20            75.88
# 97321                      NaN                        8.05            72.58
# 54037                   59.550                        0.53            69.66
# 76774                   87.847                        1.38            75.05
# 123803                     NaN                        2.77            78.86
# 55906                      NaN                        1.50            76.68
# 81532                   79.287                        0.90            67.13
# 108050                  43.993                        2.32            64.13
# 25211                   65.386                        1.71            77.29
# 10295                   34.808                        0.80            72.59
# 5112                       NaN                        5.00            76.67
# 72736                      NaN                        1.90            76.16
# 119428                  78.687                        2.30            76.70
# 123152                     NaN                        2.54            81.32
# 116709                  90.670                        2.10            77.15
# 130501                  36.791                        1.70            61.49
# 93482                      NaN                        1.60            76.74
# 28935                   85.198                        5.20            78.80
# 94125                   78.463                        1.00            71.23
# 56524                   94.576                        1.40            70.60
# 14832                   25.383                        1.10            71.51
# 47601                   76.665                        0.60            74.30
# 51518                   84.169                        0.70            75.27
# 92810                   79.602                        1.30            74.25
# 110540                     NaN                        2.97            83.56
# 120030                     NaN                        2.81            77.69
# 111186                     NaN                        3.60            76.98
# 90326                   59.607                        0.60            67.27
# 27115                   83.841                        1.13            80.28
# 121866                     NaN                        8.80            72.06
# 519                     37.746                        0.50            64.83
# 82131                   44.600                         NaN            63.71
# 80946                   12.227                        0.70            60.85
# 23953                      NaN                        2.11            80.18
# 41858                      NaN                        5.98            82.66
# 72087                    8.704                        1.30            64.26
# 80355                      NaN                        1.10            76.68
# 2382                    83.741                        1.90            76.88
# 67540                      NaN                        3.70            72.91
# 58687                      NaN                        3.18            83.51
# 129908                  13.938                        2.00            63.89
# 82925                   47.782                        0.30            70.78
# 19987                   66.229                        0.80            69.82
# 44588                      NaN                        8.00            81.33
# 43942                      NaN                        2.60            73.77
# 89709                   97.400                        1.60            77.86
# 127216                     NaN                        0.80            72.06
# 102562                  20.859                         NaN            67.94
# 63966                   89.220                        4.50            71.45
#
#         human_development_index  excess_mortality_cumulative_absolute  \
# 54648                     0.718                                   NaN
# 16785                     0.765                                   NaN
# 97321                     0.824                                   NaN
# 54037                     0.645                                   NaN
# 76774                     0.779                                   NaN
# 123803                    0.926                                   NaN
# 55906                     0.783                                   NaN
# 81532                     0.583                                   NaN
# 108050                    0.709                                   NaN
# 25211                     0.767                                   NaN
# 10295                     0.632                                   NaN
# 5112                      0.845                                   NaN
# 72736                     0.810                                   NaN
# 119428                    0.740                                   NaN
# 123152                    0.932                                   NaN
# 116709                    0.777                                   NaN
# 130501                    0.571                                   NaN
# 93482                     0.777                                   NaN
# 28935                     0.783                                   NaN
# 94125                     0.718                                   NaN
# 56524                     0.674                                   NaN
# 14832                     0.718                                   NaN
# 47601                     0.663                                   NaN
# 51518                     0.634                                   NaN
# 92810                     0.728                                   NaN
# 110540                    0.904                                   NaN
# 120030                    0.820                                   NaN
# 111186                    0.782                                   NaN
# 90326                     0.557                                   NaN
# 27115                     0.810                                   NaN
# 121866                    0.779                                   NaN
# 519                       0.511                                   NaN
# 82131                     0.646                                   NaN
# 80946                     0.456                                   NaN
# 23953                     0.851                                   NaN
# 41858                     0.901                                   NaN
# 72087                     0.483                                   NaN
# 80355                     0.686                                   NaN
# 2382                      0.748                                   NaN
# 67540                     0.724                                   NaN
# 58687                     0.892                                   NaN
# 129908                    0.584                                   NaN
# 82925                     0.602                                   NaN
# 19987                     0.594                                   NaN
# 44588                     0.947                                   NaN
# 43942                     0.812                                   NaN
# 89709                     0.813                                   NaN
# 127216                    0.711                                   NaN
# 102562                    0.512                                   NaN
# 63966                     0.697                                   NaN
#
#         excess_mortality_cumulative  excess_mortality  \
# 54648                           NaN               NaN
# 16785                           NaN               NaN
# 97321                           NaN               NaN
# 54037                           NaN               NaN
# 76774                           NaN               NaN
# 123803                          NaN               NaN
# 55906                           NaN               NaN
# 81532                           NaN               NaN
# 108050                          NaN               NaN
# 25211                           NaN               NaN
# 10295                           NaN               NaN
# 5112                            NaN               NaN
# 72736                           NaN               NaN
# 119428                          NaN               NaN
# 123152                          NaN               NaN
# 116709                          NaN               NaN
# 130501                          NaN               NaN
# 93482                           NaN               NaN
# 28935                           NaN               NaN
# 94125                           NaN               NaN
# 56524                           NaN               NaN
# 14832                           NaN               NaN
# 47601                           NaN               NaN
# 51518                           NaN               NaN
# 92810                           NaN               NaN
# 110540                          NaN               NaN
# 120030                          NaN               NaN
# 111186                          NaN               NaN
# 90326                           NaN               NaN
# 27115                           NaN               NaN
# 121866                          NaN               NaN
# 519                             NaN               NaN
# 82131                           NaN               NaN
# 80946                           NaN               NaN
# 23953                           NaN               NaN
# 41858                           NaN               NaN
# 72087                           NaN               NaN
# 80355                           NaN               NaN
# 2382                            NaN               NaN
# 67540                           NaN               NaN
# 58687                           NaN               NaN
# 129908                          NaN               NaN
# 82925                           NaN               NaN
# 19987                           NaN               NaN
# 44588                           NaN               NaN
# 43942                           NaN               NaN
# 89709                           NaN               NaN
# 127216                          NaN               NaN
# 102562                          NaN               NaN
# 63966                           NaN               NaN
#
#         excess_mortality_cumulative_per_million
# 54648                                       NaN
# 16785                                       NaN
# 97321                                       NaN
# 54037                                       NaN
# 76774                                       NaN
# 123803                                      NaN
# 55906                                       NaN
# 81532                                       NaN
# 108050                                      NaN
# 25211                                       NaN
# 10295                                       NaN
# 5112                                        NaN
# 72736                                       NaN
# 119428                                      NaN
# 123152                                      NaN
# 116709                                      NaN
# 130501                                      NaN
# 93482                                       NaN
# 28935                                       NaN
# 94125                                       NaN
# 56524                                       NaN
# 14832                                       NaN
# 47601                                       NaN
# 51518                                       NaN
# 92810                                       NaN
# 110540                                      NaN
# 120030                                      NaN
# 111186                                      NaN
# 90326                                       NaN
# 27115                                       NaN
# 121866                                      NaN
# 519                                         NaN
# 82131                                       NaN
# 80946                                       NaN
# 23953                                       NaN
# 41858                                       NaN
# 72087                                       NaN
# 80355                                       NaN
# 2382                                        NaN
# 67540                                       NaN
# 58687                                       NaN
# 129908                                      NaN
# 82925                                       NaN
# 19987                                       NaN
# 44588                                       NaN
# 43942                                       NaN
# 89709                                       NaN
# 127216                                      NaN
# 102562                                      NaN
# 63966                                       NaN
#
# [50 rows x 65 columns]

# %%
c_df.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'new_tests', 'total_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'total_boosters',
#        'new_vaccinations', 'new_vaccinations_smoothed',
#        'total_vaccinations_per_hundred', 'people_vaccinated_per_hundred',
#        'people_fully_vaccinated_per_hundred', 'total_boosters_per_hundred',
#        'new_vaccinations_smoothed_per_million', 'stringency_index',
#        'population', 'population_density', 'median_age', 'aged_65_older',
#        'aged_70_older', 'gdp_per_capita', 'extreme_poverty',
#        'cardiovasc_death_rate', 'diabetes_prevalence', 'female_smokers',
#        'male_smokers', 'handwashing_facilities', 'hospital_beds_per_thousand',
#        'life_expectancy', 'human_development_index',
#        'excess_mortality_cumulative_absolute', 'excess_mortality_cumulative',
#        'excess_mortality', 'excess_mortality_cumulative_per_million'],
#       dtype='object')
