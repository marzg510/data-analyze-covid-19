# %%
import pandas as pd

# %%
pref = pd.read_csv("COVID-19-jp/nhk_news_covid19_prefectures_daily_data.csv")
pref["日付"] = pd.to_datetime(pref["日付"] )
print(len(pref))
pref.info()
# Out:
# 22184
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22184 entries, 0 to 22183
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   日付                22184 non-null  datetime64[ns]
#  1   都道府県コード           22184 non-null  int64
#  2   都道府県名             22184 non-null  object
#  3   各地の感染者数_1日ごとの発表数  22184 non-null  int64
#  4   各地の感染者数_累計        22184 non-null  int64
#  5   各地の死者数_1日ごとの発表数   22184 non-null  int64
#  6   各地の死者数_累計         22184 non-null  int64
# dtypes: datetime64[ns](1), int64(5), object(1)
# memory usage: 1.2+ MB

# %%
saitama = pref.loc[pref["都道府県名"]=="埼玉県"]
saitama.tail(3)
# Out:
#              日付  都道府県コード 都道府県名  各地の感染者数_1日ごとの発表数  各地の感染者数_累計  各地の死者数_1日ごとの発表数  \
# 5189 2021-04-29       11   埼玉県               256       37652                0
# 5190 2021-04-30       11   埼玉県               146       37798                0
# 5191 2021-05-01       11   埼玉県               236       38034                0
#
#       各地の死者数_累計
# 5189        745
# 5190        745
# 5191        745

# %%
tokyo = pref.loc[pref["都道府県名"]=="東京都"]
tokyo.tail(3)
# Out:
#              日付  都道府県コード 都道府県名  各地の感染者数_1日ごとの発表数  各地の感染者数_累計  各地の死者数_1日ごとの発表数  \
# 6133 2021-04-29       13   東京都              1027      138378                9
# 6134 2021-04-30       13   東京都               698      139076                2
# 6135 2021-05-01       13   東京都              1050      140126                6
#
#       各地の死者数_累計
# 6133       1889
# 6134       1891
# 6135       1897

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook
#%matplotlib inline

# %%
plt.figure(figsize=(10.5,7))
dates = pref["日付"].unique()
plt.plot_date(dates,pref.loc[pref["都道府県名"]=="東京都"]["各地の感染者数_1日ごとの発表数"],label="東京都", fmt="-", lw=1)
plt.plot_date(dates,pref.loc[pref["都道府県名"]=="大阪府"]["各地の感染者数_1日ごとの発表数"],label="大阪府", fmt="-", lw=1)
plt.plot_date(dates,pref.loc[pref["都道府県名"]=="京都府"]["各地の感染者数_1日ごとの発表数"],label="京都府", fmt="-", lw=1)
plt.plot_date(dates,pref.loc[pref["都道府県名"]=="兵庫県"]["各地の感染者数_1日ごとの発表数"],label="兵庫県", fmt="-", lw=1)
plt.plot_date(dates,pref.loc[pref["都道府県名"]=="神奈川県"]["各地の感染者数_1日ごとの発表数"],label="神奈川県", fmt="--", lw=1)
plt.plot_date(dates,pref.loc[pref["都道府県名"]=="埼玉県"]["各地の感染者数_1日ごとの発表数"],label="埼玉県", fmt="--", lw=1.5)
plt.plot_date(dates,pref.loc[pref["都道府県名"]=="千葉県"]["各地の感染者数_1日ごとの発表数"],label="千葉県", fmt="--", lw=1.5)
plt.plot_date(dates,pref.loc[pref["都道府県名"]=="愛知県"]["各地の感染者数_1日ごとの発表数"],label="愛知県", fmt="--", lw=1.5)
plt.plot_date(dates,pref.loc[pref["都道府県名"]=="宮城県"]["各地の感染者数_1日ごとの発表数"],label="宮城県", fmt="--", lw=1.5)
plt.plot_date(dates,pref.loc[pref["都道府県名"]=="沖縄県"]["各地の感染者数_1日ごとの発表数"],label="沖縄県", fmt="--", lw=1.5)
plt.plot_date(dates,pref.loc[pref["都道府県名"]=="福岡県"]["各地の感染者数_1日ごとの発表数"],label="福岡県", fmt=":", lw=1)

plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="1050">
