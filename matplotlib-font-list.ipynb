# %%
import matplotlib
matplotlib.matplotlib_fname()
# Out:
# '/home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/mpl-data/matplotlibrc'

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm


fonts = set([fm.FontProperties(fname=font).get_name() for font in fm.findSystemFonts()])

fig = plt.figure(figsize=(8, 100))
ax = fig.add_subplot(1, 1, 1)
ax.set_ylim([-0.5, len(fonts)])

for i, f in enumerate(fonts):
    ax.text(0.2, i,  '日本語 {}'.format(f), fontdict={'family': f, 'fontsize': 16})

plt.show()
# Out:
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 108 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 112 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 26085 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 26412 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 35486 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 32 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 78 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 111 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 116 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 83 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 97 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 110 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 115 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 84 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 109 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 105 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 117 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 101 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 26085 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 26412 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 35486 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 32 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 78 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 111 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 116 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 83 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 97 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 110 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 115 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 84 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 109 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 105 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 108 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 117 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 112 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 101 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 80 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 67 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 72 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 80 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 67 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 72 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 76 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 99 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 104 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 76 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 99 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 104 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 85 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 73 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 85 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 73 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 82 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 106 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 103 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 82 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 106 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 103 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 75 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 75 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 74 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 118 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 74 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 118 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 98 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 98 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 77 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 77 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 87 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 100 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 87 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 100 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 114 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 114 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 79 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 79 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 71 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 71 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 121 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 121 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 89 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 89 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 68 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 68 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 69 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 69 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 119 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 119 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 107 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 107 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 66 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 66 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 65 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 65 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 49 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 49 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 120 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 95 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 86 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 45 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 120 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 95 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 86 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 45 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 102 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 102 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 122 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 52 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 122 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 52 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 70 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 70 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 50 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 50 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 81 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 81 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 51 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 51 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 113 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 113 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 54 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/masaru/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 54 missing from current font.
#   font.set_text(s, 0, flags=flags)
