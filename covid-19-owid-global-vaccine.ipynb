# %%
import pandas as pd

# %%
df = pd.read_csv("covid-19-data/public/data/vaccinations/vaccinations.csv")
df.head()
# Out:
#       location iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG  2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG  2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG  2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG  2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN              1367.0
# 2                      NaN                     NaN              1367.0
# 3                      NaN                     NaN              1367.0
# 4                      NaN                     NaN              1367.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                             0.0                            0.0
# 1                             NaN                            NaN
# 2                             NaN                            NaN
# 3                             NaN                            NaN
# 4                             NaN                            NaN
#
#    people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# 0                                  NaN                             NaN
# 1                                  NaN                            35.0
# 2                                  NaN                            35.0
# 3                                  NaN                            35.0
# 4                                  NaN                            35.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35163 entries, 0 to 35162
# Data columns (total 12 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   location                             35163 non-null  object
#  1   iso_code                             35163 non-null  object
#  2   date                                 35163 non-null  object
#  3   total_vaccinations                   20578 non-null  float64
#  4   people_vaccinated                    19765 non-null  float64
#  5   people_fully_vaccinated              16719 non-null  float64
#  6   daily_vaccinations_raw               17387 non-null  float64
#  7   daily_vaccinations                   34902 non-null  float64
#  8   total_vaccinations_per_hundred       20578 non-null  float64
#  9   people_vaccinated_per_hundred        19765 non-null  float64
#  10  people_fully_vaccinated_per_hundred  16719 non-null  float64
#  11  daily_vaccinations_per_million       34902 non-null  float64
# dtypes: float64(9), object(3)
# memory usage: 3.2+ MB

# %%
df.describe()
# Out:
#        total_vaccinations  people_vaccinated  people_fully_vaccinated  \
# count        2.057800e+04       1.976500e+04             1.671900e+04
# mean         4.834277e+07       2.683580e+07             1.486042e+07
# std          2.276768e+08       1.267271e+08             6.475550e+07
# min          0.000000e+00       0.000000e+00             1.000000e+00
# 25%          1.662212e+05       1.402700e+05             6.086300e+04
# 50%          1.300552e+06       9.153020e+05             5.243060e+05
# 75%          8.138582e+06       5.149993e+06             3.245194e+06
# max          3.787027e+09       2.092904e+09             1.048364e+09
#
#        daily_vaccinations_raw  daily_vaccinations  \
# count            1.738700e+04        3.490200e+04
# mean             8.780545e+05        4.383342e+05
# std              3.552802e+06        2.474233e+06
# min              0.000000e+00        0.000000e+00
# 25%              5.764000e+03        9.600000e+02
# 50%              3.050300e+04        8.131000e+03
# 75%              1.880345e+05        5.346750e+04
# max              4.794441e+07        4.329428e+07
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# count                    20578.000000                   19765.000000
# mean                        29.165589                      18.757497
# std                         35.025427                      20.606460
# min                          0.000000                       0.000000
# 25%                          2.780000                       2.260000
# 50%                         14.330000                      10.200000
# 75%                         44.475000                      30.360000
# max                        232.650000                     116.710000
#
#        people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# count                         16719.000000                    34902.000000
# mean                             12.133760                     3385.899089
# std                              15.866769                     4451.938219
# min                               0.000000                        0.000000
# 25%                               1.100000                      415.000000
# 50%                               5.230000                     1891.000000
# 75%                              17.005000                     5082.750000
# max                             115.940000                   118759.000000

# %%
df["date"] = pd.to_datetime(df["date"])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35163 entries, 0 to 35162
# Data columns (total 12 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   location                             35163 non-null  object
#  1   iso_code                             35163 non-null  object
#  2   date                                 35163 non-null  datetime64[ns]
#  3   total_vaccinations                   20578 non-null  float64
#  4   people_vaccinated                    19765 non-null  float64
#  5   people_fully_vaccinated              16719 non-null  float64
#  6   daily_vaccinations_raw               17387 non-null  float64
#  7   daily_vaccinations                   34902 non-null  float64
#  8   total_vaccinations_per_hundred       20578 non-null  float64
#  9   people_vaccinated_per_hundred        19765 non-null  float64
#  10  people_fully_vaccinated_per_hundred  16719 non-null  float64
#  11  daily_vaccinations_per_million       34902 non-null  float64
# dtypes: datetime64[ns](1), float64(9), object(2)
# memory usage: 3.2+ MB

# %%
import datetime
latest_date_str = (df.date.max() - datetime.timedelta(days=1)).strftime("%Y-%m-%d")
latest_date_str
# Out:
# '2021-07-21'

# %% [markdown]
# ## 全世界のデータ

# %%
world_df = df.copy().loc[df.location=="World"]
world_df.tail()
# Out:
#       location  iso_code       date  total_vaccinations  people_vaccinated  \
# 34840    World  OWID_WRL 2021-07-18        3.662774e+09       2.055135e+09
# 34841    World  OWID_WRL 2021-07-19        3.695078e+09       2.067338e+09
# 34842    World  OWID_WRL 2021-07-20        3.727059e+09       2.079488e+09
# 34843    World  OWID_WRL 2021-07-21        3.760632e+09       2.087375e+09
# 34844    World  OWID_WRL 2021-07-22        3.787027e+09       2.092904e+09
#
#        people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 34840             1.015653e+09              19296764.0          30735269.0
# 34841             1.025288e+09              32304332.0          31101056.0
# 34842             1.033198e+09              31980155.0          30874061.0
# 34843             1.043255e+09              33573399.0          30413169.0
# 34844             1.048364e+09              26394993.0          29076881.0
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 34840                           46.99                          26.37
# 34841                           47.40                          26.52
# 34842                           47.81                          26.68
# 34843                           48.25                          26.78
# 34844                           48.58                          26.85
#
#        people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# 34840                                13.03                          3943.0
# 34841                                13.15                          3990.0
# 34842                                13.25                          3961.0
# 34843                                13.38                          3902.0
# 34844                                13.45                          3730.0

# %% [markdown]
# ## 国別

# %%
country_df = df.loc[df.iso_code.str.len()==3]
country_df.head()
# Out:
#       location iso_code       date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG 2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG 2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG 2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG 2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG 2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN              1367.0
# 2                      NaN                     NaN              1367.0
# 3                      NaN                     NaN              1367.0
# 4                      NaN                     NaN              1367.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                             0.0                            0.0
# 1                             NaN                            NaN
# 2                             NaN                            NaN
# 3                             NaN                            NaN
# 4                             NaN                            NaN
#
#    people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# 0                                  NaN                             NaN
# 1                                  NaN                            35.0
# 2                                  NaN                            35.0
# 3                                  NaN                            35.0
# 4                                  NaN                            35.0

# %%
latest_df = country_df.loc[country_df.date==latest_date_str]
latest_df.head()
# Out:
#        location iso_code       date  total_vaccinations  people_vaccinated  \
# 534     Albania      ALB 2021-07-21           1095453.0           616592.0
# 1503  Argentina      ARG 2021-07-21          28264151.0         22573282.0
# 1729      Aruba      ABW 2021-07-21            134983.0            71650.0
# 2107  Australia      AUS 2021-07-21          10470033.0          7475337.0
# 2315    Austria      AUT 2021-07-21           9193617.0          5184970.0
#
#       people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 534                  478861.0                 13029.0              7422.0
# 1503                5690869.0                438923.0            363660.0
# 1729                  63333.0                   462.0               258.0
# 2107                2994696.0                174589.0            142984.0
# 2315                4183592.0                 66170.0             52163.0
#
#       total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 534                            38.07                          21.43
# 1503                           62.54                          49.95
# 1729                          126.43                          67.11
# 2107                           41.06                          29.32
# 2315                          102.08                          57.57
#
#       people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# 534                                 16.64                          2579.0
# 1503                                12.59                          8046.0
# 1729                                59.32                          2416.0
# 2107                                11.74                          5607.0
# 2315                                46.45                          5792.0

# %% [markdown]
# ### ワクチン接種完了率トップ20

# %%
latest_df.sort_values(by="people_fully_vaccinated_per_hundred",ascending=False).head(20)[["location","iso_code","date","people_fully_vaccinated_per_hundred"]]
# Out:
#              location iso_code       date  people_fully_vaccinated_per_hundred
# 12266       Gibraltar      GIB 2021-07-21                               115.94
# 19861           Malta      MLT 2021-07-21                                82.20
# 5896   Cayman Islands      CYM 2021-07-21                                71.41
# 15457     Isle of Man      IMN 2021-07-21                                66.55
# 2841          Bahrain      BHR 2021-07-21                                60.93
# 15672          Israel      ISR 2021-07-21                                60.89
# 33823         Uruguay      URY 2021-07-21                                60.37
# 1729            Aruba      ABW 2021-07-21                                59.32
# 20851        Mongolia      MNG 2021-07-21                                57.39
# 25948           Qatar      QAT 2021-07-21                                57.00
# 10572  Faeroe Islands      FRO 2021-07-21                                56.05
# 14204         Hungary      HUN 2021-07-21                                55.32
# 33243  United Kingdom      GBR 2021-07-21                                53.90
# 30167           Spain      ESP 2021-07-21                                53.60
# 5563           Canada      CAN 2021-07-21                                52.42
# 15275         Ireland      IRL 2021-07-21                                50.44
# 3549          Belgium      BEL 2021-07-21                                49.97
# 7548          Curacao      CUW 2021-07-21                                49.39
# 7745           Cyprus      CYP 2021-07-21                                48.91
# 25735        Portugal      PRT 2021-07-21                                48.75

# %% [markdown]
# ### ワクチン接種完了率ワースト20

# %%
latest_df.sort_values(by="people_fully_vaccinated_per_hundred",ascending=True).head(20)[["location","iso_code","date","people_fully_vaccinated_per_hundred"]]
# Out:
#                 location iso_code       date  \
# 13482              Haiti      HTI 2021-07-21
# 6008                Chad      TCD 2021-07-21
# 34269            Vietnam      VNM 2021-07-21
# 35008             Zambia      ZMB 2021-07-21
# 31297             Taiwan      TWN 2021-07-21
# 16793              Kenya      KEN 2021-07-21
# 12953          Guatemala      GTM 2021-07-21
# 9828            Eswatini      SWZ 2021-07-21
# 3019          Bangladesh      BGD 2021-07-21
# 24463           Pakistan      PAK 2021-07-21
# 32824            Ukraine      UKR 2021-07-21
# 35162           Zimbabwe      ZWE 2021-07-21
# 25315        Philippines      PHL 2021-07-21
# 4833              Brunei      BRN 2021-07-21
# 31507           Thailand      THA 2021-07-21
# 14782          Indonesia      IDN 2021-07-21
# 14591              India      IND 2021-07-21
# 30342          Sri Lanka      LKA 2021-07-21
# 30624           Suriname      SUR 2021-07-21
# 9506   Equatorial Guinea      GNQ 2021-07-21
#
#        people_fully_vaccinated_per_hundred
# 13482                                 0.00
# 6008                                  0.04
# 34269                                 0.33
# 35008                                 0.37
# 31297                                 0.74
# 16793                                 1.11
# 12953                                 1.60
# 9828                                  2.36
# 3019                                  2.60
# 24463                                 3.11
# 32824                                 3.56
# 35162                                 4.42
# 25315                                 4.59
# 4833                                  4.84
# 31507                                 5.08
# 14782                                 6.07
# 14591                                 6.35
# 30342                                 8.00
# 30624                                 8.45
# 9506                                  8.53

# %% [markdown]
# ### 日本

# %%
jp = df.loc[df.location=="Japan"]
jp.tail()
# Out:
#       location iso_code       date  total_vaccinations  people_vaccinated  \
# 16161    Japan      JPN 2021-07-16          70129318.0         42866264.0
# 16162    Japan      JPN 2021-07-17          71264328.0         43437340.0
# 16163    Japan      JPN 2021-07-18          72284157.0         43874639.0
# 16164    Japan      JPN 2021-07-19          73183518.0         44211972.0
# 16165    Japan      JPN 2021-07-20          73970888.0         44586506.0
#
#        people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 16161               27263054.0               1114296.0           1214611.0
# 16162               27826988.0               1135010.0           1183591.0
# 16163               28409518.0               1019829.0           1159774.0
# 16164               28971546.0                899361.0           1109519.0
# 16165               29384382.0                787370.0           1046847.0
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 16161                           55.45                          33.89
# 16162                           56.35                          34.34
# 16163                           57.15                          34.69
# 16164                           57.86                          34.96
# 16165                           58.49                          35.25
#
#        people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# 16161                                21.56                          9603.0
# 16162                                22.00                          9358.0
# 16163                                22.46                          9170.0
# 16164                                22.91                          8773.0
# 16165                                23.23                          8277.0

# %% [markdown]
# ### 英国

# %%
uk = df.loc[df.location=="United Kingdom"]
#uk.append(pd.Series([uk.location.unique()[0],1,latest_date_str]),ignore_index=True).tail()
#uk.append(pd.Series(["UK","GBR",latest_date_str],index=uk.columns),ignore_index=True).tail()
uk.tail()
# Out:
#              location iso_code       date  total_vaccinations  \
# 33239  United Kingdom      GBR 2021-07-17          82266702.0
# 33240  United Kingdom      GBR 2021-07-18          82413766.0
# 33241  United Kingdom      GBR 2021-07-19          82592996.0
# 33242  United Kingdom      GBR 2021-07-20          82793310.0
# 33243  United Kingdom      GBR 2021-07-21          83021749.0
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 33239         46295853.0               35970849.0                292431.0
# 33240         46314039.0               36099727.0                147064.0
# 33241         46349709.0               36243287.0                179230.0
# 33242         46388744.0               36404566.0                200314.0
# 33243         46433845.0               36587904.0                228439.0
#
#        daily_vaccinations  total_vaccinations_per_hundred  \
# 33239            231496.0                          121.18
# 33240            231131.0                          121.40
# 33241            231070.0                          121.66
# 33242            228636.0                          121.96
# 33243            226122.0                          122.30
#
#        people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 33239                          68.20                                52.99
# 33240                          68.22                                53.18
# 33241                          68.28                                53.39
# 33242                          68.33                                53.63
# 33243                          68.40                                53.90
#
#        daily_vaccinations_per_million
# 33239                          3410.0
# 33240                          3405.0
# 33241                          3404.0
# 33242                          3368.0
# 33243                          3331.0

# %% [markdown]
# ## 可視化

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook
#%matplotlib inline

# %%
fig=plt.figure(figsize=(14,8))
ax1 = plt.subplot(1,2,1) # (rows, columns, panel number)
plt.title("Daily COVID-19 vacctinated in the world")
ax1.set_zorder(2)
ax1.patch.set_alpha(0)
plt.ylim(0,100)
plt.ylabel("vaccination %")
ax1.grid()
plt.xticks(rotation=70)
ax2 = plt.twinx()
ax2.set_zorder(1)
plt.ylabel("million people")
ax1.plot_date(world_df["date"],world_df["people_vaccinated_per_hundred"],label="Vaccinated at least once per population", fmt="-")
ax1.plot_date(world_df["date"],world_df["people_fully_vaccinated_per_hundred"],label="Fully vaccinated per population", fmt="-")
ax1.plot_date(jp["date"],jp["people_vaccinated_per_hundred"],label="Vaccinated at least once per population in Japan", fmt="-")
ax1.plot_date(jp["date"],jp["people_fully_vaccinated_per_hundred"],label="Fully vaccinated per population in Japan", fmt="-")
#ax1.plot_date(uk["date"],jp["people_vaccinated_per_hundred"],label="Vaccinated at least once per population in UK", fmt="-")
#ax1.plot_date(uk["date"],jp["people_fully_vaccinated_per_hundred"],label="Fully vaccinated per population in UK", fmt="-")
ax2.bar(world_df["date"],world_df["people_vaccinated"]/1000/1000,label="People vaccinated at least once", color="pink")
ax2.bar(world_df["date"],world_df["people_fully_vaccinated"]/1000/1000,label="People fully vaccinated", color="lightgray",zorder=1)
#plt.grid(axis="y")
h1,l1 = ax1.get_legend_handles_labels()
h2,l2 = ax2.get_legend_handles_labels()
plt.legend(h1+h2,l1+l2)

# fully vactinated
ax1 = plt.subplot(1,2,2) # (rows, columns, panel number)
plt.title("Daily COVID-19 fully vacctinated per population Top 50")
plt.ylabel("vaccination %")
plt.grid(axis="x")
plt.yticks(fontsize=9)
plt.xticks(rotation=70)
plt.xlim(0,100)
chart_data=latest_df.copy().sort_values(by="people_fully_vaccinated_per_hundred",ascending=False).head(50)
chart_data=chart_data.sort_values(by="people_fully_vaccinated_per_hundred",ascending=True)
plt.barh(chart_data["location"],chart_data["people_fully_vaccinated_per_hundred"],label="People fully vaccinated")
#plt.grid(axis="y")
#h1,l1 = ax1.get_legend_handles_labels()
#h2,l2 = ax2.get_legend_handles_labels()
#plt.legend(h1+h2,l1+l2)

"""
plt.subplot(2,2,2) # (rows, columns, panel number)
plt.title("Daily new confirmed COVID-19 cases in the world(after 2021 Apr 1st)")
chart_data = world_df[world_df.date >= "2021-04-01"]
plt.bar(chart_data["date"],chart_data["new_cases"],label="New deaths")
plt.plot_date(chart_data["date"],chart_data["new_cases_smoothed"],label="rolling 7-day average", fmt="-", color="orange")
plt.xticks(rotation=70)
plt.grid(axis="y")
plt.legend()

plt.subplot(2,2,3) # (rows, columns, panel number)
plt.title("Daily new deaths in the world")
plt.bar(world_df.date,world_df.new_deaths,label="New cases")
plt.plot_date(world_df["date"],world_df["new_deaths_smoothed"],label="rolling 7-day average", fmt="-", color="orange")
plt.xticks(rotation=70)
plt.ylabel("people")
plt.grid(axis="y")
plt.legend()

plt.subplot(2,2,4) # (rows, columns, panel number)
plt.title("Daily new deaths in the world(after 2021 Apr 1st)")
chart_data = world_df[world_df.date >= "2021-04-01"]
plt.bar(chart_data["date"],chart_data["new_deaths"],label="New deaths")
plt.plot_date(chart_data["date"],chart_data["new_deaths_smoothed"],label="rolling 7-day average", fmt="-", color="orange")
plt.xticks(rotation=70)
plt.grid(axis="y")
plt.legend()
"""

fig.text(0,1,"Latest: {}".format(latest_date_str),fontsize=8,ha="left",va="top")
fig.text(0,0
         ,"*Data reference from:COVID-19 Dataset by Our World in Data",
        fontsize=7,ha="left",va="bottom")

fig.tight_layout()
# Out:
# <div id='21a63f81-355a-44c8-a3ce-c4af80db310b'></div>

# %%
fig.savefig("out/covid-owid-global-vaccinations-daily.png")
