# %%
import pandas as pd

# %%
df = pd.read_csv("covid-19-data/public/data/vaccinations/vaccinations.csv")
df.head()
# Out:
#       location iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG  2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG  2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG  2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG  2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  total_boosters  daily_vaccinations_raw  \
# 0                      NaN             NaN                     NaN
# 1                      NaN             NaN                     NaN
# 2                      NaN             NaN                     NaN
# 3                      NaN             NaN                     NaN
# 4                      NaN             NaN                     NaN
#
#    daily_vaccinations  total_vaccinations_per_hundred  \
# 0                 NaN                             0.0
# 1              1367.0                             NaN
# 2              1367.0                             NaN
# 3              1367.0                             NaN
# 4              1367.0                             NaN
#
#    people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 0                            0.0                                  NaN
# 1                            NaN                                  NaN
# 2                            NaN                                  NaN
# 3                            NaN                                  NaN
# 4                            NaN                                  NaN
#
#    total_boosters_per_hundred  daily_vaccinations_per_million  \
# 0                         NaN                             NaN
# 1                         NaN                            33.0
# 2                         NaN                            33.0
# 3                         NaN                            33.0
# 4                         NaN                            33.0
#
#    daily_people_vaccinated  daily_people_vaccinated_per_hundred
# 0                      NaN                                  NaN
# 1                   1367.0                                0.003
# 2                   1367.0                                0.003
# 3                   1367.0                                0.003
# 4                   1367.0                                0.003

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 138947 entries, 0 to 138946
# Data columns (total 16 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   location                             138947 non-null  object
#  1   iso_code                             138947 non-null  object
#  2   date                                 138947 non-null  object
#  3   total_vaccinations                   67258 non-null   float64
#  4   people_vaccinated                    64380 non-null   float64
#  5   people_fully_vaccinated              61690 non-null   float64
#  6   total_boosters                       36732 non-null   float64
#  7   daily_vaccinations_raw               55783 non-null   float64
#  8   daily_vaccinations                   138057 non-null  float64
#  9   total_vaccinations_per_hundred       67258 non-null   float64
#  10  people_vaccinated_per_hundred        64380 non-null   float64
#  11  people_fully_vaccinated_per_hundred  61690 non-null   float64
#  12  total_boosters_per_hundred           36732 non-null   float64
#  13  daily_vaccinations_per_million       138057 non-null  float64
#  14  daily_people_vaccinated              137558 non-null  float64
#  15  daily_people_vaccinated_per_hundred  137558 non-null  float64
# dtypes: float64(13), object(3)
# memory usage: 17.0+ MB

# %%
df.describe()
# Out:
#        total_vaccinations  people_vaccinated  people_fully_vaccinated  \
# count        6.725800e+04       6.438000e+04             6.169000e+04
# mean         2.947041e+08       1.344422e+08             1.174321e+08
# std          1.201085e+09       5.485944e+08             4.920347e+08
# min          0.000000e+00       0.000000e+00             1.000000e+00
# 25%          1.266747e+06       7.144102e+05             5.894400e+05
# 50%          9.092336e+06       4.645512e+06             4.113650e+06
# 75%          6.012168e+07       2.894325e+07             2.608701e+07
# max          1.294191e+10       5.441864e+09             5.004409e+09
#
#        total_boosters  daily_vaccinations_raw  daily_vaccinations  \
# count    3.673200e+04            5.578300e+04        1.380570e+05
# mean     6.365990e+07            9.033383e+05        3.820979e+05
# std      2.502220e+08            3.562572e+06        2.270880e+06
# min      1.000000e+00            0.000000e+00        0.000000e+00
# 25%      1.301960e+05            4.024000e+03        5.750000e+02
# 50%      2.801636e+06            3.040500e+04        6.064000e+03
# 75%      1.727271e+07            2.314210e+05        4.591300e+04
# max      2.592760e+09            4.967794e+07        4.369074e+07
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# count                    67258.000000                   64380.000000
# mean                       104.740564                      48.126043
# std                         79.940707                      29.988573
# min                          0.000000                       0.000000
# 25%                         27.890000                      19.010000
# 50%                        101.800000                      55.690000
# 75%                        168.040000                      74.870000
# max                        378.680000                     128.760000
#
#        people_fully_vaccinated_per_hundred  total_boosters_per_hundred  \
# count                         61690.000000                36732.000000
# mean                             42.990292                   27.236660
# std                              29.510717                   26.328706
# min                               0.000000                    0.000000
# 25%                              12.540000                    1.450000
# 50%                              46.960000                   21.020000
# 75%                              69.260000                   49.082500
# max                             126.760000                  139.520000
#
#        daily_vaccinations_per_million  daily_people_vaccinated  \
# count                   138057.000000             1.375580e+05
# mean                      2450.245529             1.426296e+05
# std                       3469.674441             9.256960e+05
# min                          0.000000             0.000000e+00
# 25%                        293.000000             1.360000e+02
# 50%                       1177.000000             1.733000e+03
# 75%                       3388.000000             1.556100e+04
# max                     117113.000000             2.107279e+07
#
#        daily_people_vaccinated_per_hundred
# count                        137558.000000
# mean                              0.101006
# std                               0.200756
# min                               0.000000
# 25%                               0.006000
# 50%                               0.032000
# 75%                               0.117000
# max                              11.711000

# %%
df["date"] = pd.to_datetime(df["date"])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 138947 entries, 0 to 138946
# Data columns (total 16 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   location                             138947 non-null  object
#  1   iso_code                             138947 non-null  object
#  2   date                                 138947 non-null  datetime64[ns]
#  3   total_vaccinations                   67258 non-null   float64
#  4   people_vaccinated                    64380 non-null   float64
#  5   people_fully_vaccinated              61690 non-null   float64
#  6   total_boosters                       36732 non-null   float64
#  7   daily_vaccinations_raw               55783 non-null   float64
#  8   daily_vaccinations                   138057 non-null  float64
#  9   total_vaccinations_per_hundred       67258 non-null   float64
#  10  people_vaccinated_per_hundred        64380 non-null   float64
#  11  people_fully_vaccinated_per_hundred  61690 non-null   float64
#  12  total_boosters_per_hundred           36732 non-null   float64
#  13  daily_vaccinations_per_million       138057 non-null  float64
#  14  daily_people_vaccinated              137558 non-null  float64
#  15  daily_people_vaccinated_per_hundred  137558 non-null  float64
# dtypes: datetime64[ns](1), float64(13), object(2)
# memory usage: 17.0+ MB

# %%
import datetime
latest_date_str = (df.date.max() - datetime.timedelta(days=1)).strftime("%Y-%m-%d")
latest_date_str
# Out:
# '2022-11-16'

# %% [markdown]
# ## 全世界のデータ

# %%
world_df = df.copy().loc[df.location=="World"]
world_df.tail()
# Out:
#        location  iso_code       date  total_vaccinations  people_vaccinated  \
# 137225    World  OWID_WRL 2022-11-13        1.293896e+10       5.441297e+09
# 137226    World  OWID_WRL 2022-11-14        1.293959e+10       5.441331e+09
# 137227    World  OWID_WRL 2022-11-15        1.294044e+10       5.441476e+09
# 137228    World  OWID_WRL 2022-11-16        1.294148e+10       5.441789e+09
# 137229    World  OWID_WRL 2022-11-17        1.294191e+10       5.441864e+09
#
#         people_fully_vaccinated  total_boosters  daily_vaccinations_raw  \
# 137225             5.003904e+09    2.591045e+09                     NaN
# 137226             5.003940e+09    2.591506e+09                     NaN
# 137227             5.003994e+09    2.591995e+09                     NaN
# 137228             5.004362e+09    2.592441e+09                     NaN
# 137229             5.004409e+09    2.592760e+09                     NaN
#
#         daily_vaccinations  total_vaccinations_per_hundred  \
# 137225                 NaN                          162.24
# 137226                 NaN                          162.25
# 137227                 NaN                          162.26
# 137228                 NaN                          162.27
# 137229                 NaN                          162.28
#
#         people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 137225                          68.23                                62.74
# 137226                          68.23                                62.74
# 137227                          68.23                                62.75
# 137228                          68.23                                62.75
# 137229                          68.24                                62.75
#
#         total_boosters_per_hundred  daily_vaccinations_per_million  \
# 137225                       32.49                             NaN
# 137226                       32.49                             NaN
# 137227                       32.50                             NaN
# 137228                       32.51                             NaN
# 137229                       32.51                             NaN
#
#         daily_people_vaccinated  daily_people_vaccinated_per_hundred
# 137225                      NaN                                  NaN
# 137226                      NaN                                  NaN
# 137227                      NaN                                  NaN
# 137228                      NaN                                  NaN
# 137229                      NaN                                  NaN

# %% [markdown]
# ## 国別

# %%
country_df = df.loc[df.iso_code.str.len()==3]
country_df.head()
# Out:
#       location iso_code       date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG 2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG 2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG 2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG 2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG 2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  total_boosters  daily_vaccinations_raw  \
# 0                      NaN             NaN                     NaN
# 1                      NaN             NaN                     NaN
# 2                      NaN             NaN                     NaN
# 3                      NaN             NaN                     NaN
# 4                      NaN             NaN                     NaN
#
#    daily_vaccinations  total_vaccinations_per_hundred  \
# 0                 NaN                             0.0
# 1              1367.0                             NaN
# 2              1367.0                             NaN
# 3              1367.0                             NaN
# 4              1367.0                             NaN
#
#    people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 0                            0.0                                  NaN
# 1                            NaN                                  NaN
# 2                            NaN                                  NaN
# 3                            NaN                                  NaN
# 4                            NaN                                  NaN
#
#    total_boosters_per_hundred  daily_vaccinations_per_million  \
# 0                         NaN                             NaN
# 1                         NaN                            33.0
# 2                         NaN                            33.0
# 3                         NaN                            33.0
# 4                         NaN                            33.0
#
#    daily_people_vaccinated  daily_people_vaccinated_per_hundred
# 0                      NaN                                  NaN
# 1                   1367.0                                0.003
# 2                   1367.0                                0.003
# 3                   1367.0                                0.003
# 4                   1367.0                                0.003

# %%
latest_df = country_df.loc[country_df.date==latest_date_str]
latest_df.head()
# Out:
#         location iso_code       date  total_vaccinations  people_vaccinated  \
# 5668   Argentina      ARG 2022-11-16         110206354.0         41364593.0
# 6684       Aruba      ABW 2022-11-16            173887.0            90034.0
# 8663     Austria      AUT 2022-11-16          20001321.0          6893280.0
# 9866     Bahamas      BHS 2022-11-16            364701.0           174147.0
# 10560    Bahrain      BHR 2022-11-16           3474985.0          1241015.0
#
#        people_fully_vaccinated  total_boosters  daily_vaccinations_raw  \
# 5668                37862654.0      31300995.0                 20329.0
# 6684                   83853.0             NaN                    20.0
# 8663                       NaN       6476829.0                 15009.0
# 9866                  165633.0         36670.0                     NaN
# 10560                1226577.0       1007393.0                    65.0
#
#        daily_vaccinations  total_vaccinations_per_hundred  \
# 5668              17335.0                          242.16
# 6684                 10.0                          163.34
# 8663              12320.0                          223.74
# 9866                136.0                           88.95
# 10560                70.0                          236.03
#
#        people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 5668                           90.89                                83.20
# 6684                           84.57                                78.77
# 8663                           77.11                                  NaN
# 9866                           42.48                                40.40
# 10560                          84.29                                83.31
#
#        total_boosters_per_hundred  daily_vaccinations_per_million  \
# 5668                        68.78                           381.0
# 6684                          NaN                            94.0
# 8663                        72.45                          1378.0
# 9866                         8.94                           332.0
# 10560                       68.43                            48.0
#
#        daily_people_vaccinated  daily_people_vaccinated_per_hundred
# 5668                     712.0                                0.002
# 6684                       4.0                                0.004
# 8663                      95.0                                0.001
# 9866                      48.0                                0.012
# 10560                      7.0                                0.000

# %% [markdown]
# ### ワクチン接種完了率トップ20

# %%
latest_df.sort_values(by="people_fully_vaccinated_per_hundred",ascending=False).head(20)[["location","iso_code","date","people_fully_vaccinated_per_hundred"]]
# Out:
#            location iso_code       date  people_fully_vaccinated_per_hundred
# 25265         Chile      CHL 2022-11-16                                90.24
# 78655         Malta      MLT 2022-11-16                                88.35
# 116485  South Korea      KOR 2022-11-16                                86.26
# 121821       Taiwan      TWN 2022-11-16                                85.90
# 133163      Uruguay      URY 2022-11-16                                84.56
# 10560       Bahrain      BHR 2022-11-16                                83.31
# 5668      Argentina      ARG 2022-11-16                                83.20
# 22339        Canada      CAN 2022-11-16                                82.35
# 61656         Italy      ITA 2022-11-16                                81.26
# 76775      Malaysia      MYS 2022-11-16                                81.10
# 33813       Denmark      DNK 2022-11-16                                81.09
# 59748       Ireland      IRL 2022-11-16                                80.72
# 17821        Brazil      BRA 2022-11-16                                80.20
# 6684          Aruba      ABW 2022-11-16                                78.77
# 44198        France      FRA 2022-11-16                                78.31
# 47300       Germany      DEU 2022-11-16                                76.17
# 49065        Greece      GRC 2022-11-16                                73.58
# 72422     Lithuania      LTU 2022-11-16                                68.34
# 57138         India      IND 2022-11-16                                67.07
# 32557       Czechia      CZE 2022-11-16                                65.67

# %% [markdown]
# ### ワクチン接種完了率ワースト20

# %%
latest_df.sort_values(by="people_fully_vaccinated_per_hundred",ascending=True).head(20)[["location","iso_code","date","people_fully_vaccinated_per_hundred"]]
# Out:
#                   location iso_code       date  \
# 67753           Kyrgyzstan      KGZ 2022-11-16
# 19568             Bulgaria      BGR 2022-11-16
# 115161        South Africa      ZAF 2022-11-16
# 50740            Guatemala      GTM 2022-11-16
# 9866               Bahamas      BHS 2022-11-16
# 31237              Curacao      CUW 2022-11-16
# 35626   Dominican Republic      DOM 2022-11-16
# 30086              Croatia      HRV 2022-11-16
# 100570              Poland      POL 2022-11-16
# 60965               Israel      ISR 2022-11-16
# 32557              Czechia      CZE 2022-11-16
# 57138                India      IND 2022-11-16
# 72422            Lithuania      LTU 2022-11-16
# 49065               Greece      GRC 2022-11-16
# 47300              Germany      DEU 2022-11-16
# 44198               France      FRA 2022-11-16
# 6684                 Aruba      ABW 2022-11-16
# 17821               Brazil      BRA 2022-11-16
# 59748              Ireland      IRL 2022-11-16
# 33813              Denmark      DNK 2022-11-16
#
#         people_fully_vaccinated_per_hundred
# 67753                                 20.41
# 19568                                 30.58
# 115161                                32.57
# 50740                                 39.29
# 9866                                  40.40
# 31237                                 52.29
# 35626                                 53.99
# 30086                                 55.82
# 100570                                56.68
# 60965                                 65.16
# 32557                                 65.67
# 57138                                 67.07
# 72422                                 68.34
# 49065                                 73.58
# 47300                                 76.17
# 44198                                 78.31
# 6684                                  78.77
# 17821                                 80.20
# 59748                                 80.72
# 33813                                 81.09

# %% [markdown]
# ### 日本

# %%
jp = df.loc[df.location=="Japan"]
jp.tail()
# Out:
#       location iso_code       date  total_vaccinations  people_vaccinated  \
# 62895    Japan      JPN 2022-11-10         334890921.0        104312395.0
# 62896    Japan      JPN 2022-11-11         335231422.0        104315745.0
# 62897    Japan      JPN 2022-11-12         335638415.0        104320906.0
# 62898    Japan      JPN 2022-11-13         335805806.0        104322386.0
# 62899    Japan      JPN 2022-11-14         335919769.0        104323897.0
#
#        people_fully_vaccinated  total_boosters  daily_vaccinations_raw  \
# 62895              102955617.0     127622909.0                188178.0
# 62896              102957534.0     127958143.0                340501.0
# 62897              102960496.0     128357013.0                406993.0
# 62898              102961360.0     128522060.0                167391.0
# 62899              102961975.0     128633897.0                113963.0
#
#        daily_vaccinations  total_vaccinations_per_hundred  \
# 62895            265960.0                          270.18
# 62896            257267.0                          270.45
# 62897            243570.0                          270.78
# 62898            238424.0                          270.92
# 62899            227704.0                          271.01
#
#        people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 62895                          84.16                                83.06
# 62896                          84.16                                83.06
# 62897                          84.16                                83.07
# 62898                          84.16                                83.07
# 62899                          84.16                                83.07
#
#        total_boosters_per_hundred  daily_vaccinations_per_million  \
# 62895                      102.96                          2146.0
# 62896                      103.23                          2076.0
# 62897                      103.55                          1965.0
# 62898                      103.69                          1924.0
# 62899                      103.78                          1837.0
#
#        daily_people_vaccinated  daily_people_vaccinated_per_hundred
# 62895                   2300.0                                0.002
# 62896                   2378.0                                0.002
# 62897                   2346.0                                0.002
# 62898                   2313.0                                0.002
# 62899                   2342.0                                0.002

# %% [markdown]
# ### 英国

# %%
uk = df.loc[df.location=="United Kingdom"]
#uk.append(pd.Series([uk.location.unique()[0],1,latest_date_str]),ignore_index=True).tail()
#uk.append(pd.Series(["UK","GBR",latest_date_str],index=uk.columns),ignore_index=True).tail()
uk.tail()
# Out:
#               location iso_code       date  total_vaccinations  \
# 131132  United Kingdom      GBR 2022-09-07                 NaN
# 131133  United Kingdom      GBR 2022-09-08                 NaN
# 131134  United Kingdom      GBR 2022-09-09                 NaN
# 131135  United Kingdom      GBR 2022-09-10                 NaN
# 131136  United Kingdom      GBR 2022-09-11                 NaN
#
#         people_vaccinated  people_fully_vaccinated  total_boosters  \
# 131132         53808854.0               50750722.0             NaN
# 131133         53809727.0               50752513.0             NaN
# 131134         53810757.0               50754555.0             NaN
# 131135         53812756.0               50760564.0             NaN
# 131136         53813491.0               50762968.0             NaN
#
#         daily_vaccinations_raw  daily_vaccinations  \
# 131132                     NaN                 NaN
# 131133                     NaN                 NaN
# 131134                     NaN                 NaN
# 131135                     NaN                 NaN
# 131136                     NaN                 NaN
#
#         total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 131132                             NaN                          79.71
# 131133                             NaN                          79.71
# 131134                             NaN                          79.71
# 131135                             NaN                          79.71
# 131136                             NaN                          79.71
#
#         people_fully_vaccinated_per_hundred  total_boosters_per_hundred  \
# 131132                                75.18                         NaN
# 131133                                75.18                         NaN
# 131134                                75.18                         NaN
# 131135                                75.19                         NaN
# 131136                                75.19                         NaN
#
#         daily_vaccinations_per_million  daily_people_vaccinated  \
# 131132                             NaN                   1209.0
# 131133                             NaN                   1086.0
# 131134                             NaN                   1034.0
# 131135                             NaN                    957.0
# 131136                             NaN                    933.0
#
#         daily_people_vaccinated_per_hundred
# 131132                                0.002
# 131133                                0.002
# 131134                                0.002
# 131135                                0.001
# 131136                                0.001

# %% [markdown]
# ### イラン

# %%
iran = df.loc[df.location=="Iran"]
iran.tail()
# Out:
#       location iso_code       date  total_vaccinations  people_vaccinated  \
# 58438     Iran      IRN 2022-11-02                 NaN                NaN
# 58439     Iran      IRN 2022-11-03                 NaN                NaN
# 58440     Iran      IRN 2022-11-04                 NaN                NaN
# 58441     Iran      IRN 2022-11-05                 NaN                NaN
# 58442     Iran      IRN 2022-11-06         154521421.0         65070315.0
#
#        people_fully_vaccinated  total_boosters  daily_vaccinations_raw  \
# 58438                      NaN             NaN                     NaN
# 58439                      NaN             NaN                     NaN
# 58440                      NaN             NaN                     NaN
# 58441                      NaN             NaN                     NaN
# 58442               58472263.0      30978843.0                     NaN
#
#        daily_vaccinations  total_vaccinations_per_hundred  \
# 58438              2194.0                             NaN
# 58439              2723.0                             NaN
# 58440              3252.0                             NaN
# 58441              3781.0                             NaN
# 58442              4310.0                           174.5
#
#        people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 58438                            NaN                                  NaN
# 58439                            NaN                                  NaN
# 58440                            NaN                                  NaN
# 58441                            NaN                                  NaN
# 58442                          73.48                                66.03
#
#        total_boosters_per_hundred  daily_vaccinations_per_million  \
# 58438                         NaN                            25.0
# 58439                         NaN                            31.0
# 58440                         NaN                            37.0
# 58441                         NaN                            43.0
# 58442                       34.98                            49.0
#
#        daily_people_vaccinated  daily_people_vaccinated_per_hundred
# 58438                    392.0                                0.000
# 58439                    499.0                                0.001
# 58440                    606.0                                0.001
# 58441                    713.0                                0.001
# 58442                    821.0                                0.001

# %% [markdown]
# ## 可視化

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook
#%matplotlib inline

# %%
fig=plt.figure(figsize=(14,8))
ax1 = plt.subplot(1,2,1) # (rows, columns, panel number)
plt.title("Daily COVID-19 vacctinated in the world")
ax1.set_zorder(2)
ax1.patch.set_alpha(0)
plt.ylim(0,100)
plt.ylabel("vaccination %")
ax1.grid()
plt.xticks(rotation=70)
ax2 = plt.twinx()
ax2.set_zorder(1)
plt.ylabel("million people")
ax1.plot_date(world_df["date"],world_df["people_vaccinated_per_hundred"],label="Vaccinated at least once per population", fmt="-")
ax1.plot_date(world_df["date"],world_df["people_fully_vaccinated_per_hundred"],label="Fully vaccinated per population", fmt="-")
ax1.plot_date(jp["date"],jp["people_vaccinated_per_hundred"],label="Vaccinated at least once per population in Japan", fmt="-")
ax1.plot_date(jp["date"],jp["people_fully_vaccinated_per_hundred"],label="Fully vaccinated per population in Japan", fmt="-")
#ax1.plot_date(uk["date"],jp["people_vaccinated_per_hundred"],label="Vaccinated at least once per population in UK", fmt="-")
#ax1.plot_date(uk["date"],jp["people_fully_vaccinated_per_hundred"],label="Fully vaccinated per population in UK", fmt="-")
ax2.bar(world_df["date"],world_df["people_vaccinated"]/1000/1000,label="People vaccinated at least once", color="pink")
ax2.bar(world_df["date"],world_df["people_fully_vaccinated"]/1000/1000,label="People fully vaccinated", color="lightgray",zorder=1)
#plt.grid(axis="y")
h1,l1 = ax1.get_legend_handles_labels()
h2,l2 = ax2.get_legend_handles_labels()
plt.legend(h1+h2,l1+l2)

# fully vactinated
ax1 = plt.subplot(1,2,2) # (rows, columns, panel number)
plt.title("Daily COVID-19 fully vacctinated per population Top 50")
plt.ylabel("vaccination %")
plt.grid(axis="x")
plt.yticks(fontsize=9)
plt.xticks(rotation=70)
plt.xlim(0,100)
chart_data=latest_df.copy().sort_values(by="people_fully_vaccinated_per_hundred",ascending=False).head(50)
chart_data=chart_data.sort_values(by="people_fully_vaccinated_per_hundred",ascending=True)
plt.barh(chart_data["location"],chart_data["people_fully_vaccinated_per_hundred"],label="People fully vaccinated")
#plt.grid(axis="y")
#h1,l1 = ax1.get_legend_handles_labels()
#h2,l2 = ax2.get_legend_handles_labels()
#plt.legend(h1+h2,l1+l2)

"""
plt.subplot(2,2,2) # (rows, columns, panel number)
plt.title("Daily new confirmed COVID-19 cases in the world(after 2021 Apr 1st)")
chart_data = world_df[world_df.date >= "2021-04-01"]
plt.bar(chart_data["date"],chart_data["new_cases"],label="New deaths")
plt.plot_date(chart_data["date"],chart_data["new_cases_smoothed"],label="rolling 7-day average", fmt="-", color="orange")
plt.xticks(rotation=70)
plt.grid(axis="y")
plt.legend()

plt.subplot(2,2,3) # (rows, columns, panel number)
plt.title("Daily new deaths in the world")
plt.bar(world_df.date,world_df.new_deaths,label="New cases")
plt.plot_date(world_df["date"],world_df["new_deaths_smoothed"],label="rolling 7-day average", fmt="-", color="orange")
plt.xticks(rotation=70)
plt.ylabel("people")
plt.grid(axis="y")
plt.legend()

plt.subplot(2,2,4) # (rows, columns, panel number)
plt.title("Daily new deaths in the world(after 2021 Apr 1st)")
chart_data = world_df[world_df.date >= "2021-04-01"]
plt.bar(chart_data["date"],chart_data["new_deaths"],label="New deaths")
plt.plot_date(chart_data["date"],chart_data["new_deaths_smoothed"],label="rolling 7-day average", fmt="-", color="orange")
plt.xticks(rotation=70)
plt.grid(axis="y")
plt.legend()
"""

fig.text(0,1,"Latest: {}".format(latest_date_str),fontsize=8,ha="left",va="top")
fig.text(0,0
         ,"*Data reference from:COVID-19 Dataset by Our World in Data",
        fontsize=7,ha="left",va="bottom")

fig.tight_layout()
# Out:
# <div id='90cfc88b-2369-43e6-bae4-49f91fb07efd'></div>

# %%
fig.savefig("out/covid-owid-global-vaccinations-daily.png")
