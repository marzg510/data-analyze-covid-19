# %%
import pandas as pd

# %%
df = pd.read_csv("covid-19-data/public/data/vaccinations/vaccinations.csv")
df.head()
# Out:
#       location iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG  2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG  2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG  2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG  2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  total_boosters  daily_vaccinations_raw  \
# 0                      NaN             NaN                     NaN
# 1                      NaN             NaN                     NaN
# 2                      NaN             NaN                     NaN
# 3                      NaN             NaN                     NaN
# 4                      NaN             NaN                     NaN
#
#    daily_vaccinations  total_vaccinations_per_hundred  \
# 0                 NaN                             0.0
# 1              1367.0                             NaN
# 2              1367.0                             NaN
# 3              1367.0                             NaN
# 4              1367.0                             NaN
#
#    people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 0                            0.0                                  NaN
# 1                            NaN                                  NaN
# 2                            NaN                                  NaN
# 3                            NaN                                  NaN
# 4                            NaN                                  NaN
#
#    total_boosters_per_hundred  daily_vaccinations_per_million  \
# 0                         NaN                             NaN
# 1                         NaN                            34.0
# 2                         NaN                            34.0
# 3                         NaN                            34.0
# 4                         NaN                            34.0
#
#    daily_people_vaccinated  daily_people_vaccinated_per_hundred
# 0                      NaN                                  NaN
# 1                   1367.0                                0.003
# 2                   1367.0                                0.003
# 3                   1367.0                                0.003
# 4                   1367.0                                0.003

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107381 entries, 0 to 107380
# Data columns (total 16 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   location                             107381 non-null  object
#  1   iso_code                             107381 non-null  object
#  2   date                                 107381 non-null  object
#  3   total_vaccinations                   55050 non-null   float64
#  4   people_vaccinated                    52460 non-null   float64
#  5   people_fully_vaccinated              50002 non-null   float64
#  6   total_boosters                       25999 non-null   float64
#  7   daily_vaccinations_raw               45464 non-null   float64
#  8   daily_vaccinations                   106925 non-null  float64
#  9   total_vaccinations_per_hundred       55050 non-null   float64
#  10  people_vaccinated_per_hundred        52460 non-null   float64
#  11  people_fully_vaccinated_per_hundred  50002 non-null   float64
#  12  total_boosters_per_hundred           25999 non-null   float64
#  13  daily_vaccinations_per_million       106925 non-null  float64
#  14  daily_people_vaccinated              105968 non-null  float64
#  15  daily_people_vaccinated_per_hundred  105968 non-null  float64
# dtypes: float64(13), object(3)
# memory usage: 13.1+ MB

# %%
df.describe()
# Out:
#        total_vaccinations  people_vaccinated  people_fully_vaccinated  \
# count        5.505000e+04       5.246000e+04             5.000200e+04
# mean         2.222287e+08       1.077104e+08             8.956868e+07
# std          9.671817e+08       4.674177e+08             4.041321e+08
# min          0.000000e+00       0.000000e+00             1.000000e+00
# 25%          8.856050e+05       5.146305e+05             4.186628e+05
# 50%          6.766052e+06       3.941672e+06             3.186728e+06
# 75%          4.283535e+07       2.287314e+07             1.941527e+07
# max          1.193092e+10       5.222138e+09             4.772215e+09
#
#        total_boosters  daily_vaccinations_raw  daily_vaccinations  \
# count    2.599900e+04            4.546400e+04        1.069250e+05
# mean     3.808008e+07            1.025166e+06        4.535410e+05
# std      1.679441e+08            3.896221e+06        2.548935e+06
# min      1.000000e+00            0.000000e+00        0.000000e+00
# 25%      3.629050e+04            5.421000e+03        8.530000e+02
# 50%      1.199681e+06            3.682800e+04        7.941000e+03
# 75%      9.249098e+06            2.602995e+05        5.751100e+04
# max      2.046617e+09            4.967008e+07        4.368578e+07
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# count                    55050.000000                   52460.000000
# mean                        88.962306                      43.534118
# std                         72.718343                      29.828297
# min                          0.000000                       0.000000
# 25%                         19.032500                      13.040000
# 50%                         79.425000                      46.960000
# 75%                        144.980000                      70.710000
# max                        355.750000                     124.880000
#
#        people_fully_vaccinated_per_hundred  total_boosters_per_hundred  \
# count                         50002.000000                25999.000000
# mean                             38.130396                   19.870165
# std                              29.005797                   22.143658
# min                               0.000000                    0.000000
# 25%                               8.140000                    0.250000
# 50%                              38.080000                    9.790000
# 75%                              64.670000                   36.455000
# max                             122.940000                  119.570000
#
#        daily_vaccinations_per_million  daily_people_vaccinated  \
# count                   106925.000000             1.059680e+05
# mean                      2961.876296             1.765829e+05
# std                       3778.612900             1.049736e+06
# min                          0.000000             0.000000e+00
# 25%                        495.000000             2.850000e+02
# 50%                       1731.000000             2.964000e+03
# 75%                       4190.000000             2.127000e+04
# max                     117497.000000             2.106742e+07
#
#        daily_people_vaccinated_per_hundred
# count                        105968.000000
# mean                              0.127005
# std                               0.229328
# min                               0.000000
# 25%                               0.014000
# 50%                               0.054000
# 75%                               0.156000
# max                              11.750000

# %%
df["date"] = pd.to_datetime(df["date"])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107381 entries, 0 to 107380
# Data columns (total 16 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   location                             107381 non-null  object
#  1   iso_code                             107381 non-null  object
#  2   date                                 107381 non-null  datetime64[ns]
#  3   total_vaccinations                   55050 non-null   float64
#  4   people_vaccinated                    52460 non-null   float64
#  5   people_fully_vaccinated              50002 non-null   float64
#  6   total_boosters                       25999 non-null   float64
#  7   daily_vaccinations_raw               45464 non-null   float64
#  8   daily_vaccinations                   106925 non-null  float64
#  9   total_vaccinations_per_hundred       55050 non-null   float64
#  10  people_vaccinated_per_hundred        52460 non-null   float64
#  11  people_fully_vaccinated_per_hundred  50002 non-null   float64
#  12  total_boosters_per_hundred           25999 non-null   float64
#  13  daily_vaccinations_per_million       106925 non-null  float64
#  14  daily_people_vaccinated              105968 non-null  float64
#  15  daily_people_vaccinated_per_hundred  105968 non-null  float64
# dtypes: datetime64[ns](1), float64(13), object(2)
# memory usage: 13.1+ MB

# %%
import datetime
latest_date_str = (df.date.max() - datetime.timedelta(days=1)).strftime("%Y-%m-%d")
latest_date_str
# Out:
# '2022-06-10'

# %% [markdown]
# ## 全世界のデータ

# %%
world_df = df.copy().loc[df.location=="World"]
world_df.tail()
# Out:
#        location  iso_code       date  total_vaccinations  people_vaccinated  \
# 106097    World  OWID_WRL 2022-06-07        1.190646e+10       5.220080e+09
# 106098    World  OWID_WRL 2022-06-08        1.191632e+10       5.220740e+09
# 106099    World  OWID_WRL 2022-06-09        1.192203e+10       5.221274e+09
# 106100    World  OWID_WRL 2022-06-10        1.192706e+10       5.221803e+09
# 106101    World  OWID_WRL 2022-06-11        1.193092e+10       5.222138e+09
#
#         people_fully_vaccinated  total_boosters  daily_vaccinations_raw  \
# 106097             4.765112e+09    2.034393e+09                     NaN
# 106098             4.767113e+09    2.040743e+09                     NaN
# 106099             4.769521e+09    2.042682e+09                     NaN
# 106100             4.770941e+09    2.044997e+09                     NaN
# 106101             4.772215e+09    2.046617e+09                     NaN
#
#         daily_vaccinations  total_vaccinations_per_hundred  \
# 106097                 NaN                          151.19
# 106098                 NaN                          151.32
# 106099                 NaN                          151.39
# 106100                 NaN                          151.46
# 106101                 NaN                          151.50
#
#         people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 106097                          66.29                                60.51
# 106098                          66.30                                60.54
# 106099                          66.30                                60.57
# 106100                          66.31                                60.58
# 106101                          66.31                                60.60
#
#         total_boosters_per_hundred  daily_vaccinations_per_million  \
# 106097                       25.83                             NaN
# 106098                       25.91                             NaN
# 106099                       25.94                             NaN
# 106100                       25.97                             NaN
# 106101                       25.99                             NaN
#
#         daily_people_vaccinated  daily_people_vaccinated_per_hundred
# 106097                      NaN                                  NaN
# 106098                      NaN                                  NaN
# 106099                      NaN                                  NaN
# 106100                      NaN                                  NaN
# 106101                      NaN                                  NaN

# %% [markdown]
# ## 国別

# %%
country_df = df.loc[df.iso_code.str.len()==3]
country_df.head()
# Out:
#       location iso_code       date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG 2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG 2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG 2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG 2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG 2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  total_boosters  daily_vaccinations_raw  \
# 0                      NaN             NaN                     NaN
# 1                      NaN             NaN                     NaN
# 2                      NaN             NaN                     NaN
# 3                      NaN             NaN                     NaN
# 4                      NaN             NaN                     NaN
#
#    daily_vaccinations  total_vaccinations_per_hundred  \
# 0                 NaN                             0.0
# 1              1367.0                             NaN
# 2              1367.0                             NaN
# 3              1367.0                             NaN
# 4              1367.0                             NaN
#
#    people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 0                            0.0                                  NaN
# 1                            NaN                                  NaN
# 2                            NaN                                  NaN
# 3                            NaN                                  NaN
# 4                            NaN                                  NaN
#
#    total_boosters_per_hundred  daily_vaccinations_per_million  \
# 0                         NaN                             NaN
# 1                         NaN                            34.0
# 2                         NaN                            34.0
# 3                         NaN                            34.0
# 4                         NaN                            34.0
#
#    daily_people_vaccinated  daily_people_vaccinated_per_hundred
# 0                      NaN                                  NaN
# 1                   1367.0                                0.003
# 2                   1367.0                                0.003
# 3                   1367.0                                0.003
# 4                   1367.0                                0.003

# %%
latest_df = country_df.loc[country_df.date==latest_date_str]
latest_df.head()
# Out:
#        location iso_code       date  total_vaccinations  people_vaccinated  \
# 3411   Anguilla      AIA 2022-06-10             23685.0            10764.0
# 4409  Argentina      ARG 2022-06-10         104226082.0         41130945.0
# 5267      Aruba      ABW 2022-06-10            171589.0            89001.0
# 6286  Australia      AUS 2022-06-10          57750638.0         22331988.0
# 8249    Bahrain      BHR 2022-06-10           3447875.0          1237395.0
#
#       people_fully_vaccinated  total_boosters  daily_vaccinations_raw  \
# 3411                  10094.0          2827.0                     NaN
# 4409               37508909.0      25902441.0                110380.0
# 5267                  82588.0             NaN                    67.0
# 6286               21635697.0      13782953.0                 11464.0
# 8249                1221586.0        988894.0                   294.0
#
#       daily_vaccinations  total_vaccinations_per_hundred  \
# 3411                 6.0                          156.60
# 4409             93244.0                          228.54
# 5267                33.0                          160.07
# 6286              9661.0                          223.94
# 8249               299.0                          197.21
#
#       people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 3411                          71.17                                66.74
# 4409                          90.19                                82.25
# 5267                          83.03                                77.04
# 6286                          86.60                                83.90
# 8249                          70.78                                69.87
#
#       total_boosters_per_hundred  daily_vaccinations_per_million  \
# 3411                       18.69                           397.0
# 4409                       56.80                          2045.0
# 5267                         NaN                           308.0
# 6286                       53.45                           375.0
# 8249                       56.56                           171.0
#
#       daily_people_vaccinated  daily_people_vaccinated_per_hundred
# 3411                      1.0                                0.007
# 4409                   1267.0                                0.003
# 5267                     14.0                                0.013
# 6286                   1099.0                                0.004
# 8249                     48.0                                0.003

# %% [markdown]
# ### ワクチン接種完了率トップ20

# %%
latest_df.sort_values(by="people_fully_vaccinated_per_hundred",ascending=False).head(20)[["location","iso_code","date","people_fully_vaccinated_per_hundred"]]
# Out:
#              location iso_code       date  people_fully_vaccinated_per_hundred
# 60994           Malta      MLT 2022-06-10                                90.97
# 58272           Macao      MAC 2022-06-10                                88.37
# 90208     South Korea      KOR 2022-06-10                                86.95
# 6286        Australia      AUS 2022-06-10                                83.90
# 59567        Malaysia      MYS 2022-06-10                                82.76
# 103013        Uruguay      URY 2022-06-10                                82.70
# 4409        Argentina      ARG 2022-06-10                                82.25
# 104631        Vietnam      VNM 2022-06-10                                81.00
# 94499          Taiwan      TWN 2022-06-10                                80.08
# 47947           Italy      ITA 2022-06-10                                79.41
# 5267            Aruba      ABW 2022-06-10                                77.04
# 36582         Germany      DEU 2022-06-10                                76.91
# 95623        Thailand      THA 2022-06-10                                75.27
# 38034          Greece      GRC 2022-06-10                                73.54
# 75242          Panama      PAN 2022-06-10                                70.92
# 8249          Bahrain      BHR 2022-06-10                                69.87
# 56271       Lithuania      LTU 2022-06-10                                69.75
# 67338           Nepal      NPL 2022-06-10                                67.32
# 102000  United States      USA 2022-06-10                                66.77
# 3411         Anguilla      AIA 2022-06-10                                66.74

# %% [markdown]
# ### ワクチン接種完了率ワースト20

# %%
latest_df.sort_values(by="people_fully_vaccinated_per_hundred",ascending=True).head(20)[["location","iso_code","date","people_fully_vaccinated_per_hundred"]]
# Out:
#                   location iso_code       date  \
# 52543           Kyrgyzstan      KGZ 2022-06-10
# 48407              Jamaica      JAM 2022-06-10
# 81237          Saint Lucia      LCA 2022-06-10
# 15323             Bulgaria      BGR 2022-06-10
# 89202         South Africa      ZAF 2022-06-10
# 38925              Grenada      GRD 2022-06-10
# 39396            Guatemala      GTM 2022-06-10
# 26933             Dominica      DMA 2022-06-10
# 79283              Romania      ROU 2022-06-10
# 64153           Montenegro      MNE 2022-06-10
# 76150             Paraguay      PRY 2022-06-10
# 50333           Kazakhstan      KAZ 2022-06-10
# 79826               Russia      RUS 2022-06-10
# 97464  Trinidad and Tobago      TTO 2022-06-10
# 10743               Belize      BLZ 2022-06-10
# 9230              Barbados      BRB 2022-06-10
# 27414   Dominican Republic      DOM 2022-06-10
# 23233              Croatia      HRV 2022-06-10
# 74315             Pakistan      PAK 2022-06-10
# 87883             Slovenia      SVN 2022-06-10
#
#        people_fully_vaccinated_per_hundred
# 52543                                19.78
# 48407                                23.66
# 81237                                29.32
# 15323                                29.88
# 89202                                31.47
# 38925                                34.03
# 39396                                34.39
# 26933                                42.08
# 79283                                42.42
# 64153                                45.13
# 76150                                47.68
# 50333                                48.91
# 79826                                50.71
# 97464                                50.81
# 10743                                52.39
# 9230                                 53.19
# 27414                                54.66
# 23233                                54.99
# 74315                                55.01
# 87883                                58.78

# %% [markdown]
# ### 日本

# %%
jp = df.loc[df.location=="Japan"]
jp.tail()
# Out:
#       location iso_code       date  total_vaccinations  people_vaccinated  \
# 48881    Japan      JPN 2022-06-05         281840793.0        103631281.0
# 48882    Japan      JPN 2022-06-06         281912581.0        103635001.0
# 48883    Japan      JPN 2022-06-07         281978375.0        103638762.0
# 48884    Japan      JPN 2022-06-08         282034986.0        103641579.0
# 48885    Japan      JPN 2022-06-09         282077041.0        103643585.0
#
#        people_fully_vaccinated  total_boosters  daily_vaccinations_raw  \
# 48881              102152921.0      76056591.0                 73436.0
# 48882              102158249.0      76119331.0                 71788.0
# 48883              102163402.0      76176211.0                 65794.0
# 48884              102167696.0      76225711.0                 56611.0
# 48885              102170351.0      76263105.0                 42055.0
#
#        daily_vaccinations  total_vaccinations_per_hundred  \
# 48881            135573.0                          223.59
# 48882            128347.0                          223.65
# 48883            120910.0                          223.70
# 48884            117565.0                          223.75
# 48885            112375.0                          223.78
#
#        people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 48881                          82.21                                81.04
# 48882                          82.22                                81.05
# 48883                          82.22                                81.05
# 48884                          82.22                                81.05
# 48885                          82.22                                81.05
#
#        total_boosters_per_hundred  daily_vaccinations_per_million  \
# 48881                       60.34                          1076.0
# 48882                       60.39                          1018.0
# 48883                       60.43                           959.0
# 48884                       60.47                           933.0
# 48885                       60.50                           892.0
#
#        daily_people_vaccinated  daily_people_vaccinated_per_hundred
# 48881                   6996.0                                0.006
# 48882                   6805.0                                0.005
# 48883                   6638.0                                0.005
# 48884                   6452.0                                0.005
# 48885                   6225.0                                0.005

# %% [markdown]
# ### 英国

# %%
uk = df.loc[df.location=="United Kingdom"]
#uk.append(pd.Series([uk.location.unique()[0],1,latest_date_str]),ignore_index=True).tail()
#uk.append(pd.Series(["UK","GBR",latest_date_str],index=uk.columns),ignore_index=True).tail()
uk.tail()
# Out:
#               location iso_code       date  total_vaccinations  \
# 101451  United Kingdom      GBR 2022-05-27         148339935.0
# 101452  United Kingdom      GBR 2022-05-28         148406012.0
# 101453  United Kingdom      GBR 2022-05-29         148435348.0
# 101454  United Kingdom      GBR 2022-05-30         148489319.0
# 101455  United Kingdom      GBR 2022-05-31         148549749.0
#
#         people_vaccinated  people_fully_vaccinated  total_boosters  \
# 101451         53453902.0               49969833.0      39704802.0
# 101452         53466470.0               49981337.0      39717748.0
# 101453         53472488.0               49986833.0      39724316.0
# 101454         53479257.0               49994884.0      39737176.0
# 101455         53486907.0               50003659.0      39750799.0
#
#         daily_vaccinations_raw  daily_vaccinations  \
# 101451                 60684.0             64063.0
# 101452                 66077.0             60478.0
# 101453                 29336.0             60125.0
# 101454                 53971.0             59753.0
# 101455                 60430.0             59035.0
#
#         total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 101451                          217.48                          78.37
# 101452                          217.58                          78.39
# 101453                          217.62                          78.40
# 101454                          217.70                          78.41
# 101455                          217.79                          78.42
#
#         people_fully_vaccinated_per_hundred  total_boosters_per_hundred  \
# 101451                                73.26                       58.21
# 101452                                73.28                       58.23
# 101453                                73.29                       58.24
# 101454                                73.30                       58.26
# 101455                                73.31                       58.28
#
#         daily_vaccinations_per_million  daily_people_vaccinated  \
# 101451                           939.0                   5707.0
# 101452                           887.0                   5192.0
# 101453                           882.0                   5120.0
# 101454                           876.0                   5612.0
# 101455                           866.0                   6027.0
#
#         daily_people_vaccinated_per_hundred
# 101451                                0.008
# 101452                                0.008
# 101453                                0.008
# 101454                                0.008
# 101455                                0.009

# %% [markdown]
# ### イラン

# %%
iran = df.loc[df.location=="Iran"]
iran.tail()
# Out:
#       location iso_code       date  total_vaccinations  people_vaccinated  \
# 45450     Iran      IRN 2022-05-28         149839257.0         64518897.0
# 45451     Iran      IRN 2022-05-29                 NaN                NaN
# 45452     Iran      IRN 2022-05-30         149903496.0         64533076.0
# 45453     Iran      IRN 2022-05-31                 NaN                NaN
# 45454     Iran      IRN 2022-06-01         149957751.0         64545209.0
#
#        people_fully_vaccinated  total_boosters  daily_vaccinations_raw  \
# 45450               57824686.0      27495674.0                     NaN
# 45451                      NaN             NaN                     NaN
# 45452               57843962.0      27526458.0                     NaN
# 45453                      NaN             NaN                     NaN
# 45454               57860379.0      27552163.0                     NaN
#
#        daily_vaccinations  total_vaccinations_per_hundred  \
# 45450             25393.0                          176.22
# 45451             24626.0                             NaN
# 45452             24821.0                          176.30
# 45453             23633.0                             NaN
# 45454             22970.0                          176.36
#
#        people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 45450                          75.88                                68.01
# 45451                            NaN                                  NaN
# 45452                          75.90                                68.03
# 45453                            NaN                                  NaN
# 45454                          75.91                                68.05
#
#        total_boosters_per_hundred  daily_vaccinations_per_million  \
# 45450                       32.34                           299.0
# 45451                         NaN                           290.0
# 45452                       32.37                           292.0
# 45453                         NaN                           278.0
# 45454                       32.40                           270.0
#
#        daily_people_vaccinated  daily_people_vaccinated_per_hundred
# 45450                   5683.0                                0.007
# 45451                   5479.0                                0.006
# 45452                   5462.0                                0.006
# 45453                   5217.0                                0.006
# 45454                   5082.0                                0.006

# %% [markdown]
# ## 可視化

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook
#%matplotlib inline

# %%
fig=plt.figure(figsize=(14,8))
ax1 = plt.subplot(1,2,1) # (rows, columns, panel number)
plt.title("Daily COVID-19 vacctinated in the world")
ax1.set_zorder(2)
ax1.patch.set_alpha(0)
plt.ylim(0,100)
plt.ylabel("vaccination %")
ax1.grid()
plt.xticks(rotation=70)
ax2 = plt.twinx()
ax2.set_zorder(1)
plt.ylabel("million people")
ax1.plot_date(world_df["date"],world_df["people_vaccinated_per_hundred"],label="Vaccinated at least once per population", fmt="-")
ax1.plot_date(world_df["date"],world_df["people_fully_vaccinated_per_hundred"],label="Fully vaccinated per population", fmt="-")
ax1.plot_date(jp["date"],jp["people_vaccinated_per_hundred"],label="Vaccinated at least once per population in Japan", fmt="-")
ax1.plot_date(jp["date"],jp["people_fully_vaccinated_per_hundred"],label="Fully vaccinated per population in Japan", fmt="-")
#ax1.plot_date(uk["date"],jp["people_vaccinated_per_hundred"],label="Vaccinated at least once per population in UK", fmt="-")
#ax1.plot_date(uk["date"],jp["people_fully_vaccinated_per_hundred"],label="Fully vaccinated per population in UK", fmt="-")
ax2.bar(world_df["date"],world_df["people_vaccinated"]/1000/1000,label="People vaccinated at least once", color="pink")
ax2.bar(world_df["date"],world_df["people_fully_vaccinated"]/1000/1000,label="People fully vaccinated", color="lightgray",zorder=1)
#plt.grid(axis="y")
h1,l1 = ax1.get_legend_handles_labels()
h2,l2 = ax2.get_legend_handles_labels()
plt.legend(h1+h2,l1+l2)

# fully vactinated
ax1 = plt.subplot(1,2,2) # (rows, columns, panel number)
plt.title("Daily COVID-19 fully vacctinated per population Top 50")
plt.ylabel("vaccination %")
plt.grid(axis="x")
plt.yticks(fontsize=9)
plt.xticks(rotation=70)
plt.xlim(0,100)
chart_data=latest_df.copy().sort_values(by="people_fully_vaccinated_per_hundred",ascending=False).head(50)
chart_data=chart_data.sort_values(by="people_fully_vaccinated_per_hundred",ascending=True)
plt.barh(chart_data["location"],chart_data["people_fully_vaccinated_per_hundred"],label="People fully vaccinated")
#plt.grid(axis="y")
#h1,l1 = ax1.get_legend_handles_labels()
#h2,l2 = ax2.get_legend_handles_labels()
#plt.legend(h1+h2,l1+l2)

"""
plt.subplot(2,2,2) # (rows, columns, panel number)
plt.title("Daily new confirmed COVID-19 cases in the world(after 2021 Apr 1st)")
chart_data = world_df[world_df.date >= "2021-04-01"]
plt.bar(chart_data["date"],chart_data["new_cases"],label="New deaths")
plt.plot_date(chart_data["date"],chart_data["new_cases_smoothed"],label="rolling 7-day average", fmt="-", color="orange")
plt.xticks(rotation=70)
plt.grid(axis="y")
plt.legend()

plt.subplot(2,2,3) # (rows, columns, panel number)
plt.title("Daily new deaths in the world")
plt.bar(world_df.date,world_df.new_deaths,label="New cases")
plt.plot_date(world_df["date"],world_df["new_deaths_smoothed"],label="rolling 7-day average", fmt="-", color="orange")
plt.xticks(rotation=70)
plt.ylabel("people")
plt.grid(axis="y")
plt.legend()

plt.subplot(2,2,4) # (rows, columns, panel number)
plt.title("Daily new deaths in the world(after 2021 Apr 1st)")
chart_data = world_df[world_df.date >= "2021-04-01"]
plt.bar(chart_data["date"],chart_data["new_deaths"],label="New deaths")
plt.plot_date(chart_data["date"],chart_data["new_deaths_smoothed"],label="rolling 7-day average", fmt="-", color="orange")
plt.xticks(rotation=70)
plt.grid(axis="y")
plt.legend()
"""

fig.text(0,1,"Latest: {}".format(latest_date_str),fontsize=8,ha="left",va="top")
fig.text(0,0
         ,"*Data reference from:COVID-19 Dataset by Our World in Data",
        fontsize=7,ha="left",va="bottom")

fig.tight_layout()
# Out:
# <div id='bd9c71c3-5f7a-46a7-b3e7-b46510e4a567'></div>
# findfont: Font family ['Noto Sans CJK JP'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Noto Sans CJK JP'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Noto Sans CJK JP'] not found. Falling back to DejaVu Sans.

# %%
fig.savefig("out/covid-owid-global-vaccinations-daily.png")
# Out:
# findfont: Font family ['Noto Sans CJK JP'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Noto Sans CJK JP'] not found. Falling back to DejaVu Sans.
