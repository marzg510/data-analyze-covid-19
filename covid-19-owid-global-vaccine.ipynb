# %%
import pandas as pd

# %%
df = pd.read_csv("covid-19-data/public/data/vaccinations/vaccinations.csv")
df.head()
# Out:
#       location iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG  2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG  2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG  2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG  2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN              1367.0
# 2                      NaN                     NaN              1367.0
# 3                      NaN                     NaN              1367.0
# 4                      NaN                     NaN              1367.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                             0.0                            0.0
# 1                             NaN                            NaN
# 2                             NaN                            NaN
# 3                             NaN                            NaN
# 4                             NaN                            NaN
#
#    people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# 0                                  NaN                             NaN
# 1                                  NaN                            35.0
# 2                                  NaN                            35.0
# 3                                  NaN                            35.0
# 4                                  NaN                            35.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34992 entries, 0 to 34991
# Data columns (total 12 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   location                             34992 non-null  object
#  1   iso_code                             34992 non-null  object
#  2   date                                 34992 non-null  object
#  3   total_vaccinations                   20478 non-null  float64
#  4   people_vaccinated                    19666 non-null  float64
#  5   people_fully_vaccinated              16621 non-null  float64
#  6   daily_vaccinations_raw               17304 non-null  float64
#  7   daily_vaccinations                   34735 non-null  float64
#  8   total_vaccinations_per_hundred       20478 non-null  float64
#  9   people_vaccinated_per_hundred        19666 non-null  float64
#  10  people_fully_vaccinated_per_hundred  16621 non-null  float64
#  11  daily_vaccinations_per_million       34735 non-null  float64
# dtypes: float64(9), object(3)
# memory usage: 3.2+ MB

# %%
df.describe()
# Out:
#        total_vaccinations  people_vaccinated  people_fully_vaccinated  \
# count        2.047800e+04       1.966600e+04             1.662100e+04
# mean         4.784940e+07       2.658705e+07             1.470639e+07
# std          2.252244e+08       1.255245e+08             6.408014e+07
# min          0.000000e+00       0.000000e+00             1.000000e+00
# 25%          1.655222e+05       1.393135e+05             6.065300e+04
# 50%          1.291022e+06       9.068945e+05             5.183020e+05
# 75%          8.095965e+06       5.126615e+06             3.206915e+06
# max          3.756279e+09       2.084915e+09             1.041183e+09
#
#        daily_vaccinations_raw  daily_vaccinations  \
# count            1.730400e+04        3.473500e+04
# mean             8.749855e+05        4.370520e+05
# std              3.544286e+06        2.469792e+06
# min              0.000000e+00        0.000000e+00
# 25%              5.742000e+03        9.600000e+02
# 50%              3.044200e+04        8.158000e+03
# 75%              1.875272e+05        5.338400e+04
# max              4.794321e+07        4.329348e+07
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# count                    20478.000000                   19666.000000
# mean                        28.995398                      18.662942
# std                         34.888435                      20.550617
# min                          0.000000                       0.000000
# 25%                          2.760000                       2.240000
# 50%                         14.200000                      10.125000
# 75%                         44.130000                      30.160000
# max                        232.520000                     116.680000
#
#        people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# count                         16621.000000                    34735.000000
# mean                             12.040896                     3387.377775
# std                              15.777454                     4457.910923
# min                               0.000000                        0.000000
# 25%                               1.090000                      413.500000
# 50%                               5.170000                     1890.000000
# 75%                              16.790000                     5085.000000
# max                             115.840000                   118759.000000

# %%
df["date"] = pd.to_datetime(df["date"])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34992 entries, 0 to 34991
# Data columns (total 12 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   location                             34992 non-null  object
#  1   iso_code                             34992 non-null  object
#  2   date                                 34992 non-null  datetime64[ns]
#  3   total_vaccinations                   20478 non-null  float64
#  4   people_vaccinated                    19666 non-null  float64
#  5   people_fully_vaccinated              16621 non-null  float64
#  6   daily_vaccinations_raw               17304 non-null  float64
#  7   daily_vaccinations                   34735 non-null  float64
#  8   total_vaccinations_per_hundred       20478 non-null  float64
#  9   people_vaccinated_per_hundred        19666 non-null  float64
#  10  people_fully_vaccinated_per_hundred  16621 non-null  float64
#  11  daily_vaccinations_per_million       34735 non-null  float64
# dtypes: datetime64[ns](1), float64(9), object(2)
# memory usage: 3.2+ MB

# %%
import datetime
latest_date_str = (df.date.max() - datetime.timedelta(days=1)).strftime("%Y-%m-%d")
latest_date_str
# Out:
# '2021-07-20'

# %% [markdown]
# ## 全世界のデータ

# %%
world_df = df.copy().loc[df.location=="World"]
world_df.tail()
# Out:
#       location  iso_code       date  total_vaccinations  people_vaccinated  \
# 34671    World  OWID_WRL 2021-07-17        3.643405e+09       2.050047e+09
# 34672    World  OWID_WRL 2021-07-18        3.662698e+09       2.055083e+09
# 34673    World  OWID_WRL 2021-07-19        3.694995e+09       2.067282e+09
# 34674    World  OWID_WRL 2021-07-20        3.725888e+09       2.078850e+09
# 34675    World  OWID_WRL 2021-07-21        3.756279e+09       2.084915e+09
#
#        people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 34671             1.010298e+09              27992227.0          31307706.0
# 34672             1.015631e+09              19293600.0          30731495.0
# 34673             1.025262e+09              32296276.0          31096314.0
# 34674             1.032582e+09              30892894.0          30714277.0
# 34675             1.041183e+09              30391246.0          29799058.0
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 34671                           46.74                          26.30
# 34672                           46.99                          26.36
# 34673                           47.40                          26.52
# 34674                           47.80                          26.67
# 34675                           48.19                          26.75
#
#        people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# 34671                                12.96                          4016.0
# 34672                                13.03                          3943.0
# 34673                                13.15                          3989.0
# 34674                                13.25                          3940.0
# 34675                                13.36                          3823.0

# %% [markdown]
# ## 国別

# %%
country_df = df.loc[df.iso_code.str.len()==3]
country_df.head()
# Out:
#       location iso_code       date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG 2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG 2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG 2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG 2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG 2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN              1367.0
# 2                      NaN                     NaN              1367.0
# 3                      NaN                     NaN              1367.0
# 4                      NaN                     NaN              1367.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                             0.0                            0.0
# 1                             NaN                            NaN
# 2                             NaN                            NaN
# 3                             NaN                            NaN
# 4                             NaN                            NaN
#
#    people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# 0                                  NaN                             NaN
# 1                                  NaN                            35.0
# 2                                  NaN                            35.0
# 3                                  NaN                            35.0
# 4                                  NaN                            35.0

# %%
latest_df = country_df.loc[country_df.date==latest_date_str]
latest_df.head()
# Out:
#                  location iso_code       date  total_vaccinations  \
# 532               Albania      ALB 2021-07-20           1082424.0
# 1297  Antigua and Barbuda      ATG 2021-07-20             66408.0
# 1501            Argentina      ARG 2021-07-20          27825228.0
# 1726                Aruba      ABW 2021-07-20            134521.0
# 2102            Australia      AUS 2021-07-20          10295444.0
#
#       people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 532            609538.0                 472886.0                     NaN
# 1297            37448.0                  28960.0                     NaN
# 1501         22342067.0                5483161.0                394697.0
# 1726            71415.0                  63106.0                    11.0
# 2102          7388641.0                2906803.0                169911.0
#
#       daily_vaccinations  total_vaccinations_per_hundred  \
# 532               6680.0                           37.61
# 1297               107.0                           67.81
# 1501            367278.0                           61.57
# 1726               258.0                          126.00
# 2102            141631.0                           40.37
#
#       people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 532                           21.18                                16.43
# 1297                          38.24                                29.57
# 1501                          49.43                                12.13
# 1726                          66.89                                59.11
# 2102                          28.98                                11.40
#
#       daily_vaccinations_per_million
# 532                           2321.0
# 1297                          1093.0
# 1501                          8126.0
# 1726                          2416.0
# 2102                          5554.0

# %% [markdown]
# ### ワクチン接種完了率トップ20

# %%
latest_df.sort_values(by="people_fully_vaccinated_per_hundred",ascending=False).head(20)[["location","iso_code","date","people_fully_vaccinated_per_hundred"]]
# Out:
#                    location iso_code       date  \
# 19765                 Malta      MLT 2021-07-20
# 32860  United Arab Emirates      ARE 2021-07-20
# 15379           Isle of Man      IMN 2021-07-20
# 21754                 Nauru      NRU 2021-07-20
# 2833                Bahrain      BHR 2021-07-20
# 15594                Israel      ISR 2021-07-20
# 33657               Uruguay      URY 2021-07-20
# 1726                  Aruba      ABW 2021-07-20
# 25838                 Qatar      QAT 2021-07-20
# 20753              Mongolia      MNG 2021-07-20
# 10537        Faeroe Islands      FRO 2021-07-20
# 6797           Cook Islands      COK 2021-07-20
# 33080        United Kingdom      GBR 2021-07-20
# 30012                 Spain      ESP 2021-07-20
# 5548                 Canada      CAN 2021-07-20
# 3539                Belgium      BEL 2021-07-20
# 7527                Curacao      CUW 2021-07-20
# 7724                 Cyprus      CYP 2021-07-20
# 33293         United States      USA 2021-07-20
# 25626              Portugal      PRT 2021-07-20
#
#        people_fully_vaccinated_per_hundred
# 19765                                81.73
# 32860                                68.40
# 15379                                65.43
# 21754                                64.14
# 2833                                 60.86
# 15594                                60.75
# 33657                                60.05
# 1726                                 59.11
# 25838                                56.81
# 20753                                56.75
# 10537                                54.76
# 6797                                 54.53
# 33080                                53.63
# 30012                                52.83
# 5548                                 51.50
# 3539                                 49.49
# 7527                                 49.39
# 7724                                 48.75
# 33293                                48.33
# 25626                                48.22

# %% [markdown]
# ### ワクチン接種完了率ワースト20

# %%
latest_df.sort_values(by="people_fully_vaccinated_per_hundred",ascending=True).head(20)[["location","iso_code","date","people_fully_vaccinated_per_hundred"]]
# Out:
#               location iso_code       date  \
# 34102          Vietnam      VNM 2021-07-20
# 34838           Zambia      ZMB 2021-07-20
# 31138           Taiwan      TWN 2021-07-20
# 29111  Solomon Islands      SLB 2021-07-20
# 16711            Kenya      KEN 2021-07-20
# 12894        Guatemala      GTM 2021-07-20
# 29352     South Africa      ZAF 2021-07-20
# 33770       Uzbekistan      UZB 2021-07-20
# 32662          Ukraine      UKR 2021-07-20
# 21930            Nepal      NPL 2021-07-20
# 31347         Thailand      THA 2021-07-20
# 14705        Indonesia      IDN 2021-07-20
# 14514            India      IND 2021-07-20
# 31664            Tonga      TON 2021-07-20
# 26998            Samoa      WSM 2021-07-20
# 30186        Sri Lanka      LKA 2021-07-20
# 30467         Suriname      SUR 2021-07-20
# 10731             Fiji      FJI 2021-07-20
# 17601          Lebanon      LBN 2021-07-20
# 8803           Ecuador      ECU 2021-07-20
#
#        people_fully_vaccinated_per_hundred
# 34102                                 0.33
# 34838                                 0.37
# 31138                                 0.65
# 29111                                 1.06
# 16711                                 1.11
# 12894                                 1.55
# 29352                                 3.01
# 33770                                 3.06
# 32662                                 3.43
# 21930                                 3.97
# 31347                                 5.03
# 14705                                 6.02
# 14514                                 6.29
# 31664                                 6.53
# 26998                                 7.89
# 30186                                 7.93
# 30467                                 8.31
# 10731                                 8.77
# 17601                                 9.79
# 8803                                 10.93

# %% [markdown]
# ### 日本

# %%
jp = df.loc[df.location=="Japan"]
jp.tail()
# Out:
#       location iso_code       date  total_vaccinations  people_vaccinated  \
# 16082    Japan      JPN 2021-07-16          70129318.0         42866264.0
# 16083    Japan      JPN 2021-07-17          71264328.0         43437340.0
# 16084    Japan      JPN 2021-07-18          72284157.0         43874639.0
# 16085    Japan      JPN 2021-07-19          73183518.0         44211972.0
# 16086    Japan      JPN 2021-07-20          73970888.0         44586506.0
#
#        people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 16082               27263054.0               1114296.0           1214611.0
# 16083               27826988.0               1135010.0           1183591.0
# 16084               28409518.0               1019829.0           1159774.0
# 16085               28971546.0                899361.0           1109519.0
# 16086               29384382.0                787370.0           1046847.0
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 16082                           55.45                          33.89
# 16083                           56.35                          34.34
# 16084                           57.15                          34.69
# 16085                           57.86                          34.96
# 16086                           58.49                          35.25
#
#        people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# 16082                                21.56                          9603.0
# 16083                                22.00                          9358.0
# 16084                                22.46                          9170.0
# 16085                                22.91                          8773.0
# 16086                                23.23                          8277.0

# %% [markdown]
# ### 英国

# %%
uk = df.loc[df.location=="United Kingdom"]
#uk.append(pd.Series([uk.location.unique()[0],1,latest_date_str]),ignore_index=True).tail()
#uk.append(pd.Series(["UK","GBR",latest_date_str],index=uk.columns),ignore_index=True).tail()
uk.tail()
# Out:
#              location iso_code       date  total_vaccinations  \
# 33076  United Kingdom      GBR 2021-07-16          81974271.0
# 33077  United Kingdom      GBR 2021-07-17          82266702.0
# 33078  United Kingdom      GBR 2021-07-18          82413766.0
# 33079  United Kingdom      GBR 2021-07-19          82592996.0
# 33080  United Kingdom      GBR 2021-07-20          82793310.0
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 33076         46228636.0               35745635.0                271805.0
# 33077         46295853.0               35970849.0                292431.0
# 33078         46314039.0               36099727.0                147064.0
# 33079         46349709.0               36243287.0                179230.0
# 33080         46388744.0               36404566.0                200314.0
#
#        daily_vaccinations  total_vaccinations_per_hundred  \
# 33076            233321.0                          120.75
# 33077            231496.0                          121.18
# 33078            231131.0                          121.40
# 33079            231070.0                          121.66
# 33080            228636.0                          121.96
#
#        people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 33076                          68.10                                52.66
# 33077                          68.20                                52.99
# 33078                          68.22                                53.18
# 33079                          68.28                                53.39
# 33080                          68.33                                53.63
#
#        daily_vaccinations_per_million
# 33076                          3437.0
# 33077                          3410.0
# 33078                          3405.0
# 33079                          3404.0
# 33080                          3368.0

# %% [markdown]
# ## 可視化

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook
#%matplotlib inline

# %%
fig=plt.figure(figsize=(14,8))
ax1 = plt.subplot(1,2,1) # (rows, columns, panel number)
plt.title("Daily COVID-19 vacctinated in the world")
ax1.set_zorder(2)
ax1.patch.set_alpha(0)
plt.ylim(0,100)
plt.ylabel("vaccination %")
ax1.grid()
plt.xticks(rotation=70)
ax2 = plt.twinx()
ax2.set_zorder(1)
plt.ylabel("million people")
ax1.plot_date(world_df["date"],world_df["people_vaccinated_per_hundred"],label="Vaccinated at least once per population", fmt="-")
ax1.plot_date(world_df["date"],world_df["people_fully_vaccinated_per_hundred"],label="Fully vaccinated per population", fmt="-")
ax1.plot_date(jp["date"],jp["people_vaccinated_per_hundred"],label="Vaccinated at least once per population in Japan", fmt="-")
ax1.plot_date(jp["date"],jp["people_fully_vaccinated_per_hundred"],label="Fully vaccinated per population in Japan", fmt="-")
#ax1.plot_date(uk["date"],jp["people_vaccinated_per_hundred"],label="Vaccinated at least once per population in UK", fmt="-")
#ax1.plot_date(uk["date"],jp["people_fully_vaccinated_per_hundred"],label="Fully vaccinated per population in UK", fmt="-")
ax2.bar(world_df["date"],world_df["people_vaccinated"]/1000/1000,label="People vaccinated at least once", color="pink")
ax2.bar(world_df["date"],world_df["people_fully_vaccinated"]/1000/1000,label="People fully vaccinated", color="lightgray",zorder=1)
#plt.grid(axis="y")
h1,l1 = ax1.get_legend_handles_labels()
h2,l2 = ax2.get_legend_handles_labels()
plt.legend(h1+h2,l1+l2)

# fully vactinated
ax1 = plt.subplot(1,2,2) # (rows, columns, panel number)
plt.title("Daily COVID-19 fully vacctinated per population Top 50")
plt.ylabel("vaccination %")
plt.grid(axis="x")
plt.yticks(fontsize=9)
plt.xticks(rotation=70)
plt.xlim(0,100)
chart_data=latest_df.copy().sort_values(by="people_fully_vaccinated_per_hundred",ascending=False).head(50)
chart_data=chart_data.sort_values(by="people_fully_vaccinated_per_hundred",ascending=True)
plt.barh(chart_data["location"],chart_data["people_fully_vaccinated_per_hundred"],label="People fully vaccinated")
#plt.grid(axis="y")
#h1,l1 = ax1.get_legend_handles_labels()
#h2,l2 = ax2.get_legend_handles_labels()
#plt.legend(h1+h2,l1+l2)

"""
plt.subplot(2,2,2) # (rows, columns, panel number)
plt.title("Daily new confirmed COVID-19 cases in the world(after 2021 Apr 1st)")
chart_data = world_df[world_df.date >= "2021-04-01"]
plt.bar(chart_data["date"],chart_data["new_cases"],label="New deaths")
plt.plot_date(chart_data["date"],chart_data["new_cases_smoothed"],label="rolling 7-day average", fmt="-", color="orange")
plt.xticks(rotation=70)
plt.grid(axis="y")
plt.legend()

plt.subplot(2,2,3) # (rows, columns, panel number)
plt.title("Daily new deaths in the world")
plt.bar(world_df.date,world_df.new_deaths,label="New cases")
plt.plot_date(world_df["date"],world_df["new_deaths_smoothed"],label="rolling 7-day average", fmt="-", color="orange")
plt.xticks(rotation=70)
plt.ylabel("people")
plt.grid(axis="y")
plt.legend()

plt.subplot(2,2,4) # (rows, columns, panel number)
plt.title("Daily new deaths in the world(after 2021 Apr 1st)")
chart_data = world_df[world_df.date >= "2021-04-01"]
plt.bar(chart_data["date"],chart_data["new_deaths"],label="New deaths")
plt.plot_date(chart_data["date"],chart_data["new_deaths_smoothed"],label="rolling 7-day average", fmt="-", color="orange")
plt.xticks(rotation=70)
plt.grid(axis="y")
plt.legend()
"""

fig.text(0,1,"Latest: {}".format(latest_date_str),fontsize=8,ha="left",va="top")
fig.text(0,0
         ,"*Data reference from:COVID-19 Dataset by Our World in Data",
        fontsize=7,ha="left",va="bottom")

fig.tight_layout()
# Out:
# <div id='66789b13-1c29-4c23-858f-69378d438372'></div>

# %%
fig.savefig("out/covid-owid-global-vaccinations-daily.png")
