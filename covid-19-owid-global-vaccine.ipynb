# %%
import pandas as pd

# %%
df = pd.read_csv("covid-19-data/public/data/vaccinations/vaccinations.csv")
df.head()
# Out:
#       location iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG  2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG  2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG  2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG  2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN              1367.0
# 2                      NaN                     NaN              1367.0
# 3                      NaN                     NaN              1367.0
# 4                      NaN                     NaN              1367.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                             0.0                            0.0
# 1                             NaN                            NaN
# 2                             NaN                            NaN
# 3                             NaN                            NaN
# 4                             NaN                            NaN
#
#    people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# 0                                  NaN                             NaN
# 1                                  NaN                            35.0
# 2                                  NaN                            35.0
# 3                                  NaN                            35.0
# 4                                  NaN                            35.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30719 entries, 0 to 30718
# Data columns (total 12 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   location                             30719 non-null  object
#  1   iso_code                             30719 non-null  object
#  2   date                                 30719 non-null  object
#  3   total_vaccinations                   18150 non-null  float64
#  4   people_vaccinated                    17327 non-null  float64
#  5   people_fully_vaccinated              14353 non-null  float64
#  6   daily_vaccinations_raw               15347 non-null  float64
#  7   daily_vaccinations                   30432 non-null  float64
#  8   total_vaccinations_per_hundred       18150 non-null  float64
#  9   people_vaccinated_per_hundred        17327 non-null  float64
#  10  people_fully_vaccinated_per_hundred  14353 non-null  float64
#  11  daily_vaccinations_per_million       30432 non-null  float64
# dtypes: float64(9), object(3)
# memory usage: 2.8+ MB

# %%
df.describe()
# Out:
#        total_vaccinations  people_vaccinated  people_fully_vaccinated  \
# count        1.815000e+04       1.732700e+04             1.435300e+04
# mean         3.910412e+07       2.195008e+07             1.203130e+07
# std          1.802049e+08       1.013477e+08             5.171692e+07
# min          0.000000e+00       0.000000e+00             1.000000e+00
# 25%          1.431022e+05       1.160835e+05             5.294400e+04
# 50%          1.097391e+06       7.800050e+05             4.435120e+05
# 75%          6.787976e+06       4.474632e+06             2.634856e+06
# max          3.162653e+09       1.852518e+09             8.670597e+08
#
#        daily_vaccinations_raw  daily_vaccinations  \
# count            1.534700e+04        3.043200e+04
# mean             8.312760e+05        4.149777e+05
# std              3.440183e+06        2.373191e+06
# min              0.000000e+00        0.000000e+00
# 25%              5.487500e+03        9.570000e+02
# 50%              2.920600e+04        8.133000e+03
# 75%              1.746175e+05        4.974175e+04
# max              4.784870e+07        4.308728e+07
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# count                    18150.000000                   17327.000000
# mean                        25.039466                      16.498352
# std                         31.618621                      19.144326
# min                          0.000000                       0.000000
# 25%                          2.280000                       1.900000
# 50%                         11.680000                       8.450000
# 75%                         36.427500                      25.705000
# max                        231.780000                     116.460000
#
#        people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# count                         14353.000000                    30432.000000
# mean                             10.050596                     3289.533287
# std                              13.944773                     4394.845349
# min                               0.000000                        0.000000
# 25%                               0.880000                      387.000000
# 50%                               4.090000                     1765.500000
# 75%                              13.260000                     4897.000000
# max                             115.320000                   118759.000000

# %%
df["date"] = pd.to_datetime(df["date"])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30719 entries, 0 to 30718
# Data columns (total 12 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   location                             30719 non-null  object
#  1   iso_code                             30719 non-null  object
#  2   date                                 30719 non-null  datetime64[ns]
#  3   total_vaccinations                   18150 non-null  float64
#  4   people_vaccinated                    17327 non-null  float64
#  5   people_fully_vaccinated              14353 non-null  float64
#  6   daily_vaccinations_raw               15347 non-null  float64
#  7   daily_vaccinations                   30432 non-null  float64
#  8   total_vaccinations_per_hundred       18150 non-null  float64
#  9   people_vaccinated_per_hundred        17327 non-null  float64
#  10  people_fully_vaccinated_per_hundred  14353 non-null  float64
#  11  daily_vaccinations_per_million       30432 non-null  float64
# dtypes: datetime64[ns](1), float64(9), object(2)
# memory usage: 2.8+ MB

# %%
import datetime
latest_date_str = (df.date.max() - datetime.timedelta(days=1)).strftime("%Y-%m-%d")
latest_date_str
# Out:
# '2021-07-01'

# %% [markdown]
# ## 全世界のデータ

# %%
world_df = df.copy().loc[df.location=="World"]
world_df.tail()
# Out:
#       location  iso_code       date  total_vaccinations  people_vaccinated  \
# 30451    World  OWID_WRL 2021-06-28        3.009105e+09       1.809228e+09
# 30452    World  OWID_WRL 2021-06-29        3.051992e+09       1.823159e+09
# 30453    World  OWID_WRL 2021-06-30        3.088328e+09       1.832439e+09
# 30454    World  OWID_WRL 2021-07-01        3.133794e+09       1.847180e+09
# 30455    World  OWID_WRL 2021-07-02        3.162653e+09       1.852518e+09
#
#        people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 30451              837349963.0              37602621.0          42319920.0
# 30452              847125860.0              42886527.0          42267553.0
# 30453              854829219.0              36336144.0          41124547.0
# 30454              863061425.0              45465895.0          40784146.0
# 30455              867059690.0              28859214.0          38688062.0
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 30451                           38.60                          23.21
# 30452                           39.15                          23.39
# 30453                           39.62                          23.51
# 30454                           40.20                          23.70
# 30455                           40.57                          23.77
#
#        people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# 30451                                10.74                          5429.0
# 30452                                10.87                          5423.0
# 30453                                10.97                          5276.0
# 30454                                11.07                          5232.0
# 30455                                11.12                          4963.0

# %% [markdown]
# ## 国別

# %%
country_df = df.loc[df.iso_code.str.len()==3]
country_df.head()
# Out:
#       location iso_code       date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG 2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG 2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG 2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG 2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG 2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN              1367.0
# 2                      NaN                     NaN              1367.0
# 3                      NaN                     NaN              1367.0
# 4                      NaN                     NaN              1367.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                             0.0                            0.0
# 1                             NaN                            NaN
# 2                             NaN                            NaN
# 3                             NaN                            NaN
# 4                             NaN                            NaN
#
#    people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# 0                                  NaN                             NaN
# 1                                  NaN                            35.0
# 2                                  NaN                            35.0
# 3                                  NaN                            35.0
# 4                                  NaN                            35.0

# %%
latest_df = country_df.loc[country_df.date==latest_date_str]
latest_df.head()
# Out:
#        location iso_code       date  total_vaccinations  people_vaccinated  \
# 476     Albania      ALB 2021-07-01            974486.0           567084.0
# 1341  Argentina      ARG 2021-07-01          20907721.0         16821968.0
# 1526      Aruba      ABW 2021-07-01            127416.0            67890.0
# 1864  Australia      AUS 2021-07-01                 NaN                NaN
# 2052    Austria      AUT 2021-07-01           7870853.0          4794826.0
#
#       people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 476                  407402.0                  6452.0              7371.0
# 1341                4085753.0                364396.0            283720.0
# 1526                  59526.0                   160.0               304.0
# 1864                      NaN                     NaN            115524.0
# 2052                3190372.0                111834.0             86166.0
#
#       total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 476                            33.86                          19.71
# 1341                           46.26                          37.22
# 1526                          119.34                          63.59
# 1864                             NaN                            NaN
# 2052                           87.39                          53.24
#
#       people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# 476                                 14.16                          2561.0
# 1341                                 9.04                          6278.0
# 1526                                55.75                          2847.0
# 1864                                  NaN                          4530.0
# 2052                                35.42                          9567.0

# %% [markdown]
# ### ワクチン接種完了率トップ20

# %%
latest_df.sort_values(by="people_fully_vaccinated_per_hundred",ascending=False).head(20)[["location","iso_code","date","people_fully_vaccinated_per_hundred"]]
# Out:
#              location iso_code       date  people_fully_vaccinated_per_hundred
# 17469           Malta      MLT 2021-07-01                                74.50
# 5203   Cayman Islands      CYM 2021-07-01                                69.24
# 12644         Iceland      ISL 2021-07-01                                62.47
# 13777          Israel      ISR 2021-07-01                                59.77
# 2517          Bahrain      BHR 2021-07-01                                58.25
# 1526            Aruba      ABW 2021-07-01                                55.75
# 18341        Mongolia      MNG 2021-07-01                                53.39
# 13581     Isle of Man      IMN 2021-07-01                                51.85
# 22781           Qatar      QAT 2021-07-01                                50.29
# 29582         Uruguay      URY 2021-07-01                                49.16
# 29062  United Kingdom      GBR 2021-07-01                                48.97
# 6593          Curacao      CUW 2021-07-01                                47.99
# 29256   United States      USA 2021-07-01                                46.61
# 18211          Monaco      MCO 2021-07-01                                45.09
# 9283   Faeroe Islands      FRO 2021-07-01                                40.42
# 26458           Spain      ESP 2021-07-01                                39.50
# 16148       Lithuania      LTU 2021-07-01                                38.93
# 10485         Germany      DEU 2021-07-01                                37.58
# 10954          Greece      GRC 2021-07-01                                36.76
# 22400          Poland      POL 2021-07-01                                35.74

# %% [markdown]
# ### ワクチン接種完了率ワースト20

# %%
latest_df.sort_values(by="people_fully_vaccinated_per_hundred",ascending=True).head(20)[["location","iso_code","date","people_fully_vaccinated_per_hundred"]]
# Out:
#                   location iso_code       date  \
# 30584               Zambia      ZMB 2021-07-01
# 27419               Taiwan      TWN 2021-07-01
# 29941              Vietnam      VNM 2021-07-01
# 14761                Kenya      KEN 2021-07-01
# 25875         South Africa      ZAF 2021-07-01
# 11374            Guatemala      GTM 2021-07-01
# 19116              Namibia      NAM 2021-07-01
# 21466             Pakistan      PAK 2021-07-01
# 28682              Ukraine      UKR 2021-07-01
# 22207          Philippines      PHL 2021-07-01
# 10298              Georgia      GEO 2021-07-01
# 19356                Nepal      NPL 2021-07-01
# 4275                Brunei      BRN 2021-07-01
# 27595             Thailand      THA 2021-07-01
# 12813                India      IND 2021-07-01
# 12985            Indonesia      IDN 2021-07-01
# 26613            Sri Lanka      LKA 2021-07-01
# 26856             Suriname      SUR 2021-07-01
# 15573              Lebanon      LBN 2021-07-01
# 27947  Trinidad and Tobago      TTO 2021-07-01
#
#        people_fully_vaccinated_per_hundred
# 30584                                 0.08
# 27419                                 0.18
# 29941                                 0.21
# 14761                                 0.76
# 25875                                 0.81
# 11374                                 0.90
# 19116                                 1.39
# 21466                                 1.41
# 28682                                 1.75
# 22207                                 2.46
# 10298                                 2.59
# 19356                                 2.60
# 4275                                  3.45
# 27595                                 4.10
# 12813                                 4.28
# 12985                                 5.00
# 26613                                 5.03
# 26856                                 6.17
# 15573                                 6.51
# 27947                                 6.95

# %% [markdown]
# ### 日本

# %%
jp = df.loc[df.location=="Japan"]
jp.head()
# Out:
#       location iso_code       date  total_vaccinations  people_vaccinated  \
# 14076    Japan      JPN 2021-02-17               125.0              125.0
# 14077    Japan      JPN 2021-02-18               611.0              611.0
# 14078    Japan      JPN 2021-02-19              5039.0             5039.0
# 14079    Japan      JPN 2021-02-20                 NaN                NaN
# 14080    Japan      JPN 2021-02-21                 NaN                NaN
#
#        people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 14076                      NaN                     NaN                 NaN
# 14077                      NaN                   486.0               486.0
# 14078                      NaN                  4428.0              2457.0
# 14079                      NaN                     NaN              2404.0
# 14080                      NaN                     NaN              2378.0
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 14076                             0.0                            0.0
# 14077                             0.0                            0.0
# 14078                             0.0                            0.0
# 14079                             NaN                            NaN
# 14080                             NaN                            NaN
#
#        people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# 14076                                  NaN                             NaN
# 14077                                  NaN                             4.0
# 14078                                  NaN                            19.0
# 14079                                  NaN                            19.0
# 14080                                  NaN                            19.0

# %% [markdown]
# ### 英国

# %%
uk = df.loc[df.location=="United Kingdom"]
#uk.append(pd.Series([uk.location.unique()[0],1,latest_date_str]),ignore_index=True).tail()
#uk.append(pd.Series(["UK","GBR",latest_date_str],index=uk.columns),ignore_index=True).tail()
uk.tail()
# Out:
#              location iso_code       date  total_vaccinations  \
# 29058  United Kingdom      GBR 2021-06-27          77038257.0
# 29059  United Kingdom      GBR 2021-06-28          77303533.0
# 29060  United Kingdom      GBR 2021-06-29          77592212.0
# 29061  United Kingdom      GBR 2021-06-30          77909177.0
# 29062  United Kingdom      GBR 2021-07-01          78254768.0
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 29058         44454511.0               32583746.0                263267.0
# 29059         44581771.0               32721762.0                265276.0
# 29060         44719762.0               32872450.0                288679.0
# 29061         44860978.0               33048199.0                316965.0
# 29062         45013503.0               33241265.0                345591.0
#
#        daily_vaccinations  total_vaccinations_per_hundred  \
# 29058            351511.0                          113.48
# 29059            380779.0                          113.87
# 29060            343345.0                          114.30
# 29061            334964.0                          114.76
# 29062            327284.0                          115.27
#
#        people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 29058                          65.48                                48.00
# 29059                          65.67                                48.20
# 29060                          65.87                                48.42
# 29061                          66.08                                48.68
# 29062                          66.31                                48.97
#
#        daily_vaccinations_per_million
# 29058                          5178.0
# 29059                          5609.0
# 29060                          5058.0
# 29061                          4934.0
# 29062                          4821.0

# %% [markdown]
# ## 可視化

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook
#%matplotlib inline

# %%
fig=plt.figure(figsize=(14,8))
ax1 = plt.subplot(1,2,1) # (rows, columns, panel number)
plt.title("Daily COVID-19 vacctinated in the world")
ax1.set_zorder(2)
ax1.patch.set_alpha(0)
plt.ylim(0,100)
plt.ylabel("vaccination %")
ax1.grid()
plt.xticks(rotation=70)
ax2 = plt.twinx()
ax2.set_zorder(1)
plt.ylabel("million people")
ax1.plot_date(world_df["date"],world_df["people_vaccinated_per_hundred"],label="Vaccinated at least once per population", fmt="-")
ax1.plot_date(world_df["date"],world_df["people_fully_vaccinated_per_hundred"],label="Fully vaccinated per population", fmt="-")
ax1.plot_date(jp["date"],jp["people_vaccinated_per_hundred"],label="Vaccinated at least once per population in Japan", fmt="-")
ax1.plot_date(jp["date"],jp["people_fully_vaccinated_per_hundred"],label="Fully vaccinated per population in Japan", fmt="-")
#ax1.plot_date(uk["date"],jp["people_vaccinated_per_hundred"],label="Vaccinated at least once per population in UK", fmt="-")
#ax1.plot_date(uk["date"],jp["people_fully_vaccinated_per_hundred"],label="Fully vaccinated per population in UK", fmt="-")
ax2.bar(world_df["date"],world_df["people_vaccinated"]/1000/1000,label="People vaccinated at least once", color="pink")
ax2.bar(world_df["date"],world_df["people_fully_vaccinated"]/1000/1000,label="People fully vaccinated", color="lightgray",zorder=1)
#plt.grid(axis="y")
h1,l1 = ax1.get_legend_handles_labels()
h2,l2 = ax2.get_legend_handles_labels()
plt.legend(h1+h2,l1+l2)

# fully vactinated
ax1 = plt.subplot(1,2,2) # (rows, columns, panel number)
plt.title("Daily COVID-19 fully vacctinated per population Top 50")
plt.ylabel("vaccination %")
plt.grid(axis="x")
plt.yticks(fontsize=9)
plt.xticks(rotation=70)
chart_data=latest_df.copy().sort_values(by="people_fully_vaccinated_per_hundred",ascending=False).head(50)
chart_data=chart_data.sort_values(by="people_fully_vaccinated_per_hundred",ascending=True)
plt.barh(chart_data["location"],chart_data["people_fully_vaccinated_per_hundred"],label="People fully vaccinated")
#plt.grid(axis="y")
#h1,l1 = ax1.get_legend_handles_labels()
#h2,l2 = ax2.get_legend_handles_labels()
#plt.legend(h1+h2,l1+l2)

"""
plt.subplot(2,2,2) # (rows, columns, panel number)
plt.title("Daily new confirmed COVID-19 cases in the world(after 2021 Apr 1st)")
chart_data = world_df[world_df.date >= "2021-04-01"]
plt.bar(chart_data["date"],chart_data["new_cases"],label="New deaths")
plt.plot_date(chart_data["date"],chart_data["new_cases_smoothed"],label="rolling 7-day average", fmt="-", color="orange")
plt.xticks(rotation=70)
plt.grid(axis="y")
plt.legend()

plt.subplot(2,2,3) # (rows, columns, panel number)
plt.title("Daily new deaths in the world")
plt.bar(world_df.date,world_df.new_deaths,label="New cases")
plt.plot_date(world_df["date"],world_df["new_deaths_smoothed"],label="rolling 7-day average", fmt="-", color="orange")
plt.xticks(rotation=70)
plt.ylabel("people")
plt.grid(axis="y")
plt.legend()

plt.subplot(2,2,4) # (rows, columns, panel number)
plt.title("Daily new deaths in the world(after 2021 Apr 1st)")
chart_data = world_df[world_df.date >= "2021-04-01"]
plt.bar(chart_data["date"],chart_data["new_deaths"],label="New deaths")
plt.plot_date(chart_data["date"],chart_data["new_deaths_smoothed"],label="rolling 7-day average", fmt="-", color="orange")
plt.xticks(rotation=70)
plt.grid(axis="y")
plt.legend()
"""

fig.text(0,1,"Latest: {}".format(latest_date_str),fontsize=8,ha="left",va="top")
fig.text(0,0
         ,"*Data reference from:COVID-19 Dataset by Our World in Data",
        fontsize=7,ha="left",va="bottom")

fig.tight_layout()
# Out:
# <div id='aa91c60b-f990-47a9-865a-63a36662087d'></div>

# %%
fig.savefig("out/covid-owid-global-vaccinations-daily.png")
