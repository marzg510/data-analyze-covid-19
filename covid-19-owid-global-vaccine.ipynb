# %%
import pandas as pd

# %%
df = pd.read_csv("covid-19-data/public/data/vaccinations/vaccinations.csv")
df.head()
# Out:
#       location iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG  2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG  2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG  2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG  2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN              1367.0
# 2                      NaN                     NaN              1367.0
# 3                      NaN                     NaN              1367.0
# 4                      NaN                     NaN              1367.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                             0.0                            0.0
# 1                             NaN                            NaN
# 2                             NaN                            NaN
# 3                             NaN                            NaN
# 4                             NaN                            NaN
#
#    people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# 0                                  NaN                             NaN
# 1                                  NaN                            35.0
# 2                                  NaN                            35.0
# 3                                  NaN                            35.0
# 4                                  NaN                            35.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36511 entries, 0 to 36510
# Data columns (total 12 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   location                             36511 non-null  object
#  1   iso_code                             36511 non-null  object
#  2   date                                 36511 non-null  object
#  3   total_vaccinations                   21394 non-null  float64
#  4   people_vaccinated                    20526 non-null  float64
#  5   people_fully_vaccinated              17471 non-null  float64
#  6   daily_vaccinations_raw               18046 non-null  float64
#  7   daily_vaccinations                   36237 non-null  float64
#  8   total_vaccinations_per_hundred       21394 non-null  float64
#  9   people_vaccinated_per_hundred        20526 non-null  float64
#  10  people_fully_vaccinated_per_hundred  17471 non-null  float64
#  11  daily_vaccinations_per_million       36237 non-null  float64
# dtypes: float64(9), object(3)
# memory usage: 3.3+ MB

# %%
df.describe()
# Out:
#        total_vaccinations  people_vaccinated  people_fully_vaccinated  \
# count        2.139400e+04       2.052600e+04             1.747100e+04
# mean         5.104986e+07       2.822915e+07             1.570793e+07
# std          2.416146e+08       1.333908e+08             6.854929e+07
# min          0.000000e+00       0.000000e+00             1.000000e+00
# 25%          1.738960e+05       1.469695e+05             6.404250e+04
# 50%          1.383816e+06       9.568695e+05             5.552750e+05
# 75%          8.540647e+06       5.338512e+06             3.454752e+06
# max          4.014996e+09       2.167147e+09             1.106355e+09
#
#        daily_vaccinations_raw  daily_vaccinations  \
# count            1.804600e+04        3.623700e+04
# mean             8.968176e+05        4.458404e+05
# std              3.628568e+06        2.512566e+06
# min              0.000000e+00        0.000000e+00
# 25%              5.906250e+03        9.550000e+02
# 50%              3.147600e+04        8.175000e+03
# 75%              1.921988e+05        5.454800e+04
# max              4.804160e+07        4.338509e+07
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# count                    21394.000000                   20526.000000
# mean                        30.622805                      19.489177
# std                         36.128844                      21.039311
# min                          0.000000                       0.000000
# 25%                          2.982500                       2.390000
# 50%                         15.420000                      10.900000
# 75%                         47.350000                      31.930000
# max                        232.720000                     116.730000
#
#        people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# count                         17471.000000                    36237.000000
# mean                             12.825762                     3428.971714
# std                              16.487361                     4459.334678
# min                               0.000000                        0.000000
# 25%                               1.200000                      421.000000
# 50%                               5.600000                     1972.000000
# 75%                              18.355000                     5152.000000
# max                             115.990000                   118759.000000

# %%
df["date"] = pd.to_datetime(df["date"])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36511 entries, 0 to 36510
# Data columns (total 12 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   location                             36511 non-null  object
#  1   iso_code                             36511 non-null  object
#  2   date                                 36511 non-null  datetime64[ns]
#  3   total_vaccinations                   21394 non-null  float64
#  4   people_vaccinated                    20526 non-null  float64
#  5   people_fully_vaccinated              17471 non-null  float64
#  6   daily_vaccinations_raw               18046 non-null  float64
#  7   daily_vaccinations                   36237 non-null  float64
#  8   total_vaccinations_per_hundred       21394 non-null  float64
#  9   people_vaccinated_per_hundred        20526 non-null  float64
#  10  people_fully_vaccinated_per_hundred  17471 non-null  float64
#  11  daily_vaccinations_per_million       36237 non-null  float64
# dtypes: datetime64[ns](1), float64(9), object(2)
# memory usage: 3.3+ MB

# %%
import datetime
latest_date_str = (df.date.max() - datetime.timedelta(days=1)).strftime("%Y-%m-%d")
latest_date_str
# Out:
# '2021-07-27'

# %% [markdown]
# ## 全世界のデータ

# %%
world_df = df.copy().loc[df.location=="World"]
world_df.tail()
# Out:
#       location  iso_code       date  total_vaccinations  people_vaccinated  \
# 36161    World  OWID_WRL 2021-07-24        3.871500e+09       2.122548e+09
# 36162    World  OWID_WRL 2021-07-25        3.898593e+09       2.130228e+09
# 36163    World  OWID_WRL 2021-07-26        3.939658e+09       2.145050e+09
# 36164    World  OWID_WRL 2021-07-27        3.977495e+09       2.156179e+09
# 36165    World  OWID_WRL 2021-07-28        4.014996e+09       2.167147e+09
#
#        people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 36161             1.070933e+09              29031850.0          32120476.0
# 36162             1.078918e+09              27092128.0          32997641.0
# 36163             1.088839e+09              41065850.0          34102389.0
# 36164             1.098357e+09              37837117.0          34838778.0
# 36165             1.106355e+09              37500149.0          35600493.0
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 36161                           49.67                          27.23
# 36162                           50.02                          27.33
# 36163                           50.54                          27.52
# 36164                           51.03                          27.66
# 36165                           51.51                          27.80
#
#        people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# 36161                                13.74                          4121.0
# 36162                                13.84                          4233.0
# 36163                                13.97                          4375.0
# 36164                                14.09                          4469.0
# 36165                                14.19                          4567.0

# %% [markdown]
# ## 国別

# %%
country_df = df.loc[df.iso_code.str.len()==3]
country_df.head()
# Out:
#       location iso_code       date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG 2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG 2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG 2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG 2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG 2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN              1367.0
# 2                      NaN                     NaN              1367.0
# 3                      NaN                     NaN              1367.0
# 4                      NaN                     NaN              1367.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                             0.0                            0.0
# 1                             NaN                            NaN
# 2                             NaN                            NaN
# 3                             NaN                            NaN
# 4                             NaN                            NaN
#
#    people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# 0                                  NaN                             NaN
# 1                                  NaN                            35.0
# 2                                  NaN                            35.0
# 3                                  NaN                            35.0
# 4                                  NaN                            35.0

# %%
latest_df = country_df.loc[country_df.date==latest_date_str]
latest_df.head()
# Out:
#          location iso_code       date  total_vaccinations  people_vaccinated  \
# 155   Afghanistan      AFG 2021-07-27           1277085.0           939835.0
# 1433    Argentina      ARG 2021-07-27          30230385.0         24096445.0
# 1672        Aruba      ABW 2021-07-27            136496.0            72440.0
# 2062    Australia      AUS 2021-07-27          11396784.0          7951762.0
# 2276      Austria      AUT 2021-07-27           9500367.0          5256754.0
#
#       people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 155                       NaN                     NaN             22461.0
# 1433                6133940.0                350138.0            343594.0
# 1672                  64056.0                   508.0               282.0
# 2062                3445022.0                185337.0            157334.0
# 2276                4432559.0                 50620.0             51863.0
#
#       total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 155                             3.28                           2.41
# 1433                           66.89                          53.32
# 1672                          127.85                          67.85
# 2062                           44.69                          31.18
# 2276                          105.48                          58.37
#
#       people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# 155                                   NaN                           577.0
# 1433                                13.57                          7602.0
# 1672                                60.00                          2641.0
# 2062                                13.51                          6170.0
# 2276                                49.22                          5758.0

# %% [markdown]
# ### ワクチン接種完了率トップ20

# %%
latest_df.sort_values(by="people_fully_vaccinated_per_hundred",ascending=False).head(20)[["location","iso_code","date","people_fully_vaccinated_per_hundred"]]
# Out:
#                    location iso_code       date  \
# 20619                 Malta      MLT 2021-07-27
# 6080         Cayman Islands      CYM 2021-07-27
# 34293  United Arab Emirates      ARE 2021-07-27
# 15975           Isle of Man      IMN 2021-07-27
# 22699                 Nauru      NRU 2021-07-27
# 26327              Pitcairn      PCN 2021-07-27
# 35119               Uruguay      URY 2021-07-27
# 16197                Israel      ISR 2021-07-27
# 2821                Bahrain      BHR 2021-07-27
# 1672                  Aruba      ABW 2021-07-27
# 21649              Mongolia      MNG 2021-07-27
# 4128                 Bhutan      BTN 2021-07-27
# 26972                 Qatar      QAT 2021-07-27
# 10931        Faeroe Islands      FRO 2021-07-27
# 5734                 Canada      CAN 2021-07-27
# 31321                 Spain      ESP 2021-07-27
# 14681               Hungary      HUN 2021-07-27
# 34521        United Kingdom      GBR 2021-07-27
# 3590                Belgium      BEL 2021-07-27
# 29767             Singapore      SGP 2021-07-27
#
#        people_fully_vaccinated_per_hundred
# 20619                                84.65
# 6080                                 72.00
# 34293                                69.40
# 15975                                67.97
# 22699                                66.93
# 26327                                63.83
# 35119                                62.46
# 16197                                61.63
# 2821                                 61.58
# 1672                                 60.00
# 21649                                59.67
# 4128                                 59.39
# 26972                                58.85
# 10931                                58.15
# 5734                                 56.74
# 31321                                56.51
# 14681                                55.96
# 34521                                55.40
# 3590                                 55.02
# 29767                                53.99

# %% [markdown]
# ### ワクチン接種完了率ワースト20

# %%
latest_df.sort_values(by="people_fully_vaccinated_per_hundred",ascending=True).head(20)[["location","iso_code","date","people_fully_vaccinated_per_hundred"]]
# Out:
#               location iso_code       date  \
# 13937            Haiti      HTI 2021-07-27
# 36245            Yemen      YEM 2021-07-27
# 35289          Vanuatu      VUT 2021-07-27
# 19992           Malawi      MWI 2021-07-27
# 35578          Vietnam      VNM 2021-07-27
# 36350           Zambia      ZMB 2021-07-27
# 17363            Kenya      KEN 2021-07-27
# 32483           Taiwan      TWN 2021-07-27
# 30392  Solomon Islands      SLB 2021-07-27
# 17796       Kyrgyzstan      KGZ 2021-07-27
# 13383        Guatemala      GTM 2021-07-27
# 22588          Namibia      NAM 2021-07-27
# 3005        Bangladesh      BGD 2021-07-27
# 12119          Georgia      GEO 2021-07-27
# 34088          Ukraine      UKR 2021-07-27
# 30640     South Africa      ZAF 2021-07-27
# 22882            Nepal      NPL 2021-07-27
# 26284      Philippines      PHL 2021-07-27
# 32816            Timor      TLS 2021-07-27
# 15280        Indonesia      IDN 2021-07-27
#
#        people_fully_vaccinated_per_hundred
# 13937                                 0.00
# 36245                                 0.04
# 35289                                 0.04
# 19992                                 0.30
# 35578                                 0.46
# 36350                                 0.61
# 17363                                 1.18
# 32483                                 1.21
# 30392                                 1.45
# 17796                                 1.72
# 13383                                 1.76
# 22588                                 1.82
# 3005                                  2.61
# 12119                                 3.62
# 34088                                 4.16
# 30640                                 4.35
# 22882                                 5.00
# 26284                                 5.76
# 32816                                 6.58
# 15280                                 6.82

# %% [markdown]
# ### 日本

# %%
jp = df.loc[df.location=="Japan"]
jp.tail()
# Out:
#       location iso_code       date  total_vaccinations  people_vaccinated  \
# 16707    Japan      JPN 2021-07-24          78989925.0         46987307.0
# 16708    Japan      JPN 2021-07-25          79912123.0         47281033.0
# 16709    Japan      JPN 2021-07-26          80910003.0         47635128.0
# 16710    Japan      JPN 2021-07-27          81850433.0         47990762.0
# 16711    Japan      JPN 2021-07-28          82593468.0         48270230.0
#
#        people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 16707               32002618.0                999313.0            910469.0
# 16708               32631090.0                922198.0            877241.0
# 16709               33274875.0                997880.0            868862.0
# 16710               33859671.0                940430.0            836410.0
# 16711               34323238.0                743035.0            782452.0
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 16707                           62.45                          37.15
# 16708                           63.18                          37.38
# 16709                           63.97                          37.66
# 16710                           64.72                          37.94
# 16711                           65.30                          38.17
#
#        people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# 16707                                25.30                          7199.0
# 16708                                25.80                          6936.0
# 16709                                26.31                          6870.0
# 16710                                26.77                          6613.0
# 16711                                27.14                          6187.0

# %% [markdown]
# ### 英国

# %%
uk = df.loc[df.location=="United Kingdom"]
#uk.append(pd.Series([uk.location.unique()[0],1,latest_date_str]),ignore_index=True).tail()
#uk.append(pd.Series(["UK","GBR",latest_date_str],index=uk.columns),ignore_index=True).tail()
uk.tail()
# Out:
#              location iso_code       date  total_vaccinations  \
# 34517  United Kingdom      GBR 2021-07-23          83486397.0
# 34518  United Kingdom      GBR 2021-07-24          83734088.0
# 34519  United Kingdom      GBR 2021-07-25          83876595.0
# 34520  United Kingdom      GBR 2021-07-26          84112856.0
# 34521  United Kingdom      GBR 2021-07-27          84300153.0
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 34517         46520855.0               36965542.0                232315.0
# 34518         46564660.0               37169428.0                247691.0
# 34519         46589211.0               37287384.0                142507.0
# 34520         46653796.0               37459060.0                236261.0
# 34521         46689242.0               37610911.0                187297.0
#
#        daily_vaccinations  total_vaccinations_per_hundred  \
# 34517            216018.0                          122.98
# 34518            209627.0                          123.35
# 34519            208976.0                          123.56
# 34520            217123.0                          123.90
# 34521            215263.0                          124.18
#
#        people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 34517                          68.53                                54.45
# 34518                          68.59                                54.75
# 34519                          68.63                                54.93
# 34520                          68.72                                55.18
# 34521                          68.78                                55.40
#
#        daily_vaccinations_per_million
# 34517                          3182.0
# 34518                          3088.0
# 34519                          3078.0
# 34520                          3198.0
# 34521                          3171.0

# %% [markdown]
# ## 可視化

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook
#%matplotlib inline

# %%
fig=plt.figure(figsize=(14,8))
ax1 = plt.subplot(1,2,1) # (rows, columns, panel number)
plt.title("Daily COVID-19 vacctinated in the world")
ax1.set_zorder(2)
ax1.patch.set_alpha(0)
plt.ylim(0,100)
plt.ylabel("vaccination %")
ax1.grid()
plt.xticks(rotation=70)
ax2 = plt.twinx()
ax2.set_zorder(1)
plt.ylabel("million people")
ax1.plot_date(world_df["date"],world_df["people_vaccinated_per_hundred"],label="Vaccinated at least once per population", fmt="-")
ax1.plot_date(world_df["date"],world_df["people_fully_vaccinated_per_hundred"],label="Fully vaccinated per population", fmt="-")
ax1.plot_date(jp["date"],jp["people_vaccinated_per_hundred"],label="Vaccinated at least once per population in Japan", fmt="-")
ax1.plot_date(jp["date"],jp["people_fully_vaccinated_per_hundred"],label="Fully vaccinated per population in Japan", fmt="-")
#ax1.plot_date(uk["date"],jp["people_vaccinated_per_hundred"],label="Vaccinated at least once per population in UK", fmt="-")
#ax1.plot_date(uk["date"],jp["people_fully_vaccinated_per_hundred"],label="Fully vaccinated per population in UK", fmt="-")
ax2.bar(world_df["date"],world_df["people_vaccinated"]/1000/1000,label="People vaccinated at least once", color="pink")
ax2.bar(world_df["date"],world_df["people_fully_vaccinated"]/1000/1000,label="People fully vaccinated", color="lightgray",zorder=1)
#plt.grid(axis="y")
h1,l1 = ax1.get_legend_handles_labels()
h2,l2 = ax2.get_legend_handles_labels()
plt.legend(h1+h2,l1+l2)

# fully vactinated
ax1 = plt.subplot(1,2,2) # (rows, columns, panel number)
plt.title("Daily COVID-19 fully vacctinated per population Top 50")
plt.ylabel("vaccination %")
plt.grid(axis="x")
plt.yticks(fontsize=9)
plt.xticks(rotation=70)
plt.xlim(0,100)
chart_data=latest_df.copy().sort_values(by="people_fully_vaccinated_per_hundred",ascending=False).head(50)
chart_data=chart_data.sort_values(by="people_fully_vaccinated_per_hundred",ascending=True)
plt.barh(chart_data["location"],chart_data["people_fully_vaccinated_per_hundred"],label="People fully vaccinated")
#plt.grid(axis="y")
#h1,l1 = ax1.get_legend_handles_labels()
#h2,l2 = ax2.get_legend_handles_labels()
#plt.legend(h1+h2,l1+l2)

"""
plt.subplot(2,2,2) # (rows, columns, panel number)
plt.title("Daily new confirmed COVID-19 cases in the world(after 2021 Apr 1st)")
chart_data = world_df[world_df.date >= "2021-04-01"]
plt.bar(chart_data["date"],chart_data["new_cases"],label="New deaths")
plt.plot_date(chart_data["date"],chart_data["new_cases_smoothed"],label="rolling 7-day average", fmt="-", color="orange")
plt.xticks(rotation=70)
plt.grid(axis="y")
plt.legend()

plt.subplot(2,2,3) # (rows, columns, panel number)
plt.title("Daily new deaths in the world")
plt.bar(world_df.date,world_df.new_deaths,label="New cases")
plt.plot_date(world_df["date"],world_df["new_deaths_smoothed"],label="rolling 7-day average", fmt="-", color="orange")
plt.xticks(rotation=70)
plt.ylabel("people")
plt.grid(axis="y")
plt.legend()

plt.subplot(2,2,4) # (rows, columns, panel number)
plt.title("Daily new deaths in the world(after 2021 Apr 1st)")
chart_data = world_df[world_df.date >= "2021-04-01"]
plt.bar(chart_data["date"],chart_data["new_deaths"],label="New deaths")
plt.plot_date(chart_data["date"],chart_data["new_deaths_smoothed"],label="rolling 7-day average", fmt="-", color="orange")
plt.xticks(rotation=70)
plt.grid(axis="y")
plt.legend()
"""

fig.text(0,1,"Latest: {}".format(latest_date_str),fontsize=8,ha="left",va="top")
fig.text(0,0
         ,"*Data reference from:COVID-19 Dataset by Our World in Data",
        fontsize=7,ha="left",va="bottom")

fig.tight_layout()
# Out:
# <div id='3ddae93a-8f76-4516-99fb-20a76ba74951'></div>

# %%
fig.savefig("out/covid-owid-global-vaccinations-daily.png")
