# %%
import pandas as pd

# %%
df = pd.read_csv("covid-19-data/public/data/vaccinations/vaccinations.csv")
df.head()
# Out:
#       location iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG  2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG  2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG  2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG  2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  total_boosters  daily_vaccinations_raw  \
# 0                      NaN             NaN                     NaN
# 1                      NaN             NaN                     NaN
# 2                      NaN             NaN                     NaN
# 3                      NaN             NaN                     NaN
# 4                      NaN             NaN                     NaN
#
#    daily_vaccinations  total_vaccinations_per_hundred  \
# 0                 NaN                             0.0
# 1              1367.0                             NaN
# 2              1367.0                             NaN
# 3              1367.0                             NaN
# 4              1367.0                             NaN
#
#    people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 0                            0.0                                  NaN
# 1                            NaN                                  NaN
# 2                            NaN                                  NaN
# 3                            NaN                                  NaN
# 4                            NaN                                  NaN
#
#    total_boosters_per_hundred  daily_vaccinations_per_million
# 0                         NaN                             NaN
# 1                         NaN                            34.0
# 2                         NaN                            34.0
# 3                         NaN                            34.0
# 4                         NaN                            34.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56208 entries, 0 to 56207
# Data columns (total 14 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   location                             56208 non-null  object
#  1   iso_code                             56208 non-null  object
#  2   date                                 56208 non-null  object
#  3   total_vaccinations                   31966 non-null  float64
#  4   people_vaccinated                    30641 non-null  float64
#  5   people_fully_vaccinated              27445 non-null  float64
#  6   total_boosters                       4678 non-null   float64
#  7   daily_vaccinations_raw               26758 non-null  float64
#  8   daily_vaccinations                   55935 non-null  float64
#  9   total_vaccinations_per_hundred       31966 non-null  float64
#  10  people_vaccinated_per_hundred        30641 non-null  float64
#  11  people_fully_vaccinated_per_hundred  27445 non-null  float64
#  12  total_boosters_per_hundred           4678 non-null   float64
#  13  daily_vaccinations_per_million       55935 non-null  float64
# dtypes: float64(11), object(3)
# memory usage: 6.0+ MB

# %%
df.describe()
# Out:
#        total_vaccinations  people_vaccinated  people_fully_vaccinated  \
# count        3.196600e+04       3.064100e+04             2.744500e+04
# mean         9.375903e+07       5.102834e+07             3.360312e+07
# std          4.505777e+08       2.491343e+08             1.749947e+08
# min          0.000000e+00       0.000000e+00             1.000000e+00
# 25%          3.427288e+05       2.560180e+05             1.404090e+05
# 50%          2.491748e+06       1.714201e+06             1.106254e+06
# 75%          1.455377e+07       9.034539e+06             6.139953e+06
# max          6.795880e+09       3.805015e+09             2.895282e+09
#
#        total_boosters  daily_vaccinations_raw  daily_vaccinations  \
# count    4.678000e+03            2.675800e+04        5.593500e+04
# mean     1.685053e+06            1.006242e+06        4.923623e+05
# std      4.636020e+06            4.010165e+06        2.753151e+06
# min      1.000000e+00            0.000000e+00        0.000000e+00
# 25%      9.900000e+01            6.275000e+03        1.064000e+03
# 50%      1.715700e+04            3.488300e+04        8.687000e+03
# 75%      7.645945e+05            2.272188e+05        6.030450e+04
# max      4.860305e+07            5.627903e+07        4.339118e+07
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# count                    31966.000000                   30641.000000
# mean                        48.532379                      28.636123
# std                         48.143012                      25.539923
# min                          0.000000                       0.000000
# 25%                          5.880000                       4.380000
# 50%                         31.605000                      21.870000
# 75%                         83.407500                      50.570000
# max                        250.740000                     119.240000
#
#        people_fully_vaccinated_per_hundred  total_boosters_per_hundred  \
# count                         27445.000000                 4678.000000
# mean                             21.888518                    1.792828
# std                              22.945337                    5.422404
# min                               0.000000                    0.000000
# 25%                               2.440000                    0.000000
# 50%                              12.430000                    0.020000
# 75%                              38.020000                    0.600000
# max                             118.120000                   44.240000
#
#        daily_vaccinations_per_million
# count                    55935.000000
# mean                      3487.050380
# std                       4219.343421
# min                          0.000000
# 25%                        569.000000
# 50%                       2248.000000
# 75%                       5155.500000
# max                     117497.000000

# %%
df["date"] = pd.to_datetime(df["date"])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56208 entries, 0 to 56207
# Data columns (total 14 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   location                             56208 non-null  object
#  1   iso_code                             56208 non-null  object
#  2   date                                 56208 non-null  datetime64[ns]
#  3   total_vaccinations                   31966 non-null  float64
#  4   people_vaccinated                    30641 non-null  float64
#  5   people_fully_vaccinated              27445 non-null  float64
#  6   total_boosters                       4678 non-null   float64
#  7   daily_vaccinations_raw               26758 non-null  float64
#  8   daily_vaccinations                   55935 non-null  float64
#  9   total_vaccinations_per_hundred       31966 non-null  float64
#  10  people_vaccinated_per_hundred        30641 non-null  float64
#  11  people_fully_vaccinated_per_hundred  27445 non-null  float64
#  12  total_boosters_per_hundred           4678 non-null   float64
#  13  daily_vaccinations_per_million       55935 non-null  float64
# dtypes: datetime64[ns](1), float64(11), object(2)
# memory usage: 6.0+ MB

# %%
import datetime
latest_date_str = (df.date.max() - datetime.timedelta(days=1)).strftime("%Y-%m-%d")
latest_date_str
# Out:
# '2021-10-20'

# %% [markdown]
# ## 全世界のデータ

# %%
world_df = df.copy().loc[df.location=="World"]
world_df.tail()
# Out:
#       location  iso_code       date  total_vaccinations  people_vaccinated  \
# 55624    World  OWID_WRL 2021-10-17        6.688588e+09       3.759135e+09
# 55625    World  OWID_WRL 2021-10-18        6.715143e+09       3.769706e+09
# 55626    World  OWID_WRL 2021-10-19        6.741722e+09       3.779972e+09
# 55627    World  OWID_WRL 2021-10-20        6.773375e+09       3.795447e+09
# 55628    World  OWID_WRL 2021-10-21        6.795880e+09       3.805015e+09
#
#        people_fully_vaccinated  total_boosters  daily_vaccinations_raw  \
# 55624             2.845897e+09      45460979.0              27372730.0
# 55625             2.859137e+09      46088684.0              26555380.0
# 55626             2.872166e+09      46801356.0              26579136.0
# 55627             2.885615e+09      47625143.0              31652556.0
# 55628             2.895282e+09      48603049.0              22505463.0
#
#        daily_vaccinations  total_vaccinations_per_hundred  \
# 55624          21278253.0                           84.93
# 55625          22510344.0                           85.27
# 55626          22932945.0                           85.61
# 55627          24391844.0                           86.01
# 55628          24354210.0                           86.30
#
#        people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 55624                          47.74                                36.14
# 55625                          47.87                                36.31
# 55626                          48.00                                36.47
# 55627                          48.20                                36.64
# 55628                          48.32                                36.77
#
#        total_boosters_per_hundred  daily_vaccinations_per_million
# 55624                        0.58                          2702.0
# 55625                        0.59                          2858.0
# 55626                        0.59                          2912.0
# 55627                        0.60                          3097.0
# 55628                        0.62                          3093.0

# %% [markdown]
# ## 国別

# %%
country_df = df.loc[df.iso_code.str.len()==3]
country_df.head()
# Out:
#       location iso_code       date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG 2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG 2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG 2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG 2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG 2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  total_boosters  daily_vaccinations_raw  \
# 0                      NaN             NaN                     NaN
# 1                      NaN             NaN                     NaN
# 2                      NaN             NaN                     NaN
# 3                      NaN             NaN                     NaN
# 4                      NaN             NaN                     NaN
#
#    daily_vaccinations  total_vaccinations_per_hundred  \
# 0                 NaN                             0.0
# 1              1367.0                             NaN
# 2              1367.0                             NaN
# 3              1367.0                             NaN
# 4              1367.0                             NaN
#
#    people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 0                            0.0                                  NaN
# 1                            NaN                                  NaN
# 2                            NaN                                  NaN
# 3                            NaN                                  NaN
# 4                            NaN                                  NaN
#
#    total_boosters_per_hundred  daily_vaccinations_per_million
# 0                         NaN                             NaN
# 1                         NaN                            34.0
# 2                         NaN                            34.0
# 3                         NaN                            34.0
# 4                         NaN                            34.0

# %%
latest_df = country_df.loc[country_df.date==latest_date_str]
latest_df.head()
# Out:
#        location iso_code       date  total_vaccinations  people_vaccinated  \
# 1507     Angola      AGO 2021-10-20           5661085.0          4126328.0
# 2303  Argentina      ARG 2021-10-20          56722315.0         31916195.0
# 2705      Aruba      ABW 2021-10-20            158552.0            82236.0
# 3266  Australia      AUS 2021-10-20          33489485.0         18542786.0
# 3565    Austria      AUT 2021-10-20          11295932.0          5828483.0
#
#       people_fully_vaccinated  total_boosters  daily_vaccinations_raw  \
# 1507                1534757.0             NaN                     NaN
# 2303               24898034.0             NaN                504943.0
# 2705                  76316.0             NaN                   112.0
# 3266               14946699.0             NaN                277315.0
# 3565                5555305.0        232055.0                 28592.0
#
#       daily_vaccinations  total_vaccinations_per_hundred  \
# 1507            182109.0                           16.68
# 2303            338428.0                          124.38
# 2705                98.0                          147.91
# 3266            258586.0                          129.86
# 3565             19161.0                          124.91
#
#       people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 1507                          12.16                                 4.52
# 2303                          69.98                                54.59
# 2705                          76.72                                71.19
# 3266                          71.90                                57.96
# 3565                          64.45                                61.43
#
#       total_boosters_per_hundred  daily_vaccinations_per_million
# 1507                         NaN                          5367.0
# 2303                         NaN                          7421.0
# 2705                         NaN                           914.0
# 3266                         NaN                         10027.0
# 3565                        2.57                          2119.0

# %% [markdown]
# ### ワクチン接種完了率トップ20

# %%
latest_df.sort_values(by="people_fully_vaccinated_per_hundred",ascending=False).head(20)[["location","iso_code","date","people_fully_vaccinated_per_hundred"]]
# Out:
#                    location iso_code       date  \
# 19592             Gibraltar      GIB 2021-10-20
# 52869  United Arab Emirates      ARE 2021-10-20
# 31787                 Malta      MLT 2021-10-20
# 47822                 Spain      ESP 2021-10-20
# 45407             Singapore      SGP 2021-10-20
# 16999        Faeroe Islands      FRO 2021-10-20
# 8475               Cambodia      KHM 2021-10-20
# 13439               Denmark      DNK 2021-10-20
# 24350               Ireland      IRL 2021-10-20
# 54007               Uruguay      URY 2021-10-20
# 5470                Belgium      BEL 2021-10-20
# 8977                 Canada      CAN 2021-10-20
# 2705                  Aruba      ABW 2021-10-20
# 31051              Malaysia      MYS 2021-10-20
# 25229                 Italy      ITA 2021-10-20
# 25703                 Japan      JPN 2021-10-20
# 38087                Norway      NOR 2021-10-20
# 47332           South Korea      KOR 2021-10-20
# 17876                France      FRA 2021-10-20
# 48854                Sweden      SWE 2021-10-20
#
#        people_fully_vaccinated_per_hundred
# 19592                               118.12
# 52869                                85.73
# 31787                                82.74
# 47822                                79.53
# 45407                                79.52
# 16999                                76.09
# 8475                                 75.87
# 13439                                75.71
# 24350                                74.97
# 54007                                74.87
# 5470                                 73.20
# 8977                                 73.18
# 2705                                 71.19
# 31051                                70.98
# 25229                                70.41
# 25703                                68.64
# 38087                                67.99
# 47332                                67.44
# 17876                                67.43
# 48854                                67.19

# %% [markdown]
# ### ワクチン接種完了率ワースト20

# %%
latest_df.sort_values(by="people_fully_vaccinated_per_hundred",ascending=True).head(20)[["location","iso_code","date","people_fully_vaccinated_per_hundred"]]
# Out:
#           location iso_code       date  people_fully_vaccinated_per_hundred
# 47532  South Sudan      SSD 2021-10-20                                 0.34
# 30595   Madagascar      MDG 2021-10-20                                 0.65
# 26700        Kenya      KEN 2021-10-20                                 2.40
# 55960       Zambia      ZMB 2021-10-20                                 2.66
# 1507        Angola      AGO 2021-10-20                                 4.52
# 44340      Senegal      SEN 2021-10-20                                 5.11
# 27437   Kyrgyzstan      KGZ 2021-10-20                                10.64
# 52579      Ukraine      UKR 2021-10-20                                15.51
# 38898     Pakistan      PAK 2021-10-20                                16.64
# 56206     Zimbabwe      ZWE 2021-10-20                                16.72
# 20643    Guatemala      GTM 2021-10-20                                16.80
# 54212   Uzbekistan      UZB 2021-10-20                                17.33
# 54809      Vietnam      VNM 2021-10-20                                19.82
# 8088      Bulgaria      BGR 2021-10-20                                20.32
# 23282        India      IND 2021-10-20                                20.92
# 28188      Lebanon      LBN 2021-10-20                                21.34
# 40285  Philippines      PHL 2021-10-20                                22.40
# 23565    Indonesia      IDN 2021-10-20                                23.38
# 49595       Taiwan      TWN 2021-10-20                                23.86
# 21527       Guyana      GUY 2021-10-20                                29.53

# %% [markdown]
# ### 日本

# %%
jp = df.loc[df.location=="Japan"]
jp.tail()
# Out:
#       location iso_code       date  total_vaccinations  people_vaccinated  \
# 25700    Japan      JPN 2021-10-17         180219121.0         95356325.0
# 25701    Japan      JPN 2021-10-18         180976061.0         95638769.0
# 25702    Japan      JPN 2021-10-19         182079899.0         95991219.0
# 25703    Japan      JPN 2021-10-20         182719236.0         96203522.0
# 25704    Japan      JPN 2021-10-21         183344047.0         96406686.0
#
#        people_fully_vaccinated  total_boosters  daily_vaccinations_raw  \
# 25700               84862796.0             NaN                     NaN
# 25701               85337292.0             NaN                756940.0
# 25702               86088680.0             NaN               1103838.0
# 25703               86515714.0             NaN                639337.0
# 25704               86937361.0             NaN                624811.0
#
#        daily_vaccinations  total_vaccinations_per_hundred  \
# 25700            798182.0                          142.97
# 25701            753614.0                          143.57
# 25702            742676.0                          144.45
# 25703            728159.0                          144.96
# 25704            726934.0                          145.45
#
#        people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 25700                          75.65                                67.32
# 25701                          75.87                                67.70
# 25702                          76.15                                68.30
# 25703                          76.32                                68.64
# 25704                          76.48                                68.97
#
#        total_boosters_per_hundred  daily_vaccinations_per_million
# 25700                         NaN                          6332.0
# 25701                         NaN                          5979.0
# 25702                         NaN                          5892.0
# 25703                         NaN                          5777.0
# 25704                         NaN                          5767.0

# %% [markdown]
# ### 英国

# %%
uk = df.loc[df.location=="United Kingdom"]
#uk.append(pd.Series([uk.location.unique()[0],1,latest_date_str]),ignore_index=True).tail()
#uk.append(pd.Series(["UK","GBR",latest_date_str],index=uk.columns),ignore_index=True).tail()
uk.tail()
# Out:
#              location iso_code       date  total_vaccinations  \
# 53150  United Kingdom      GBR 2021-10-16          94765062.0
# 53151  United Kingdom      GBR 2021-10-17          94800164.0
# 53152  United Kingdom      GBR 2021-10-18          94863415.0
# 53153  United Kingdom      GBR 2021-10-19          94939084.0
# 53154  United Kingdom      GBR 2021-10-20          95014529.0
#
#        people_vaccinated  people_fully_vaccinated  total_boosters  \
# 53150         49404916.0               45360146.0             NaN
# 53151         49422753.0               45377411.0             NaN
# 53152         49462425.0               45400990.0             NaN
# 53153         49505327.0               45433757.0             NaN
# 53154         49554407.0               45460122.0             NaN
#
#        daily_vaccinations_raw  daily_vaccinations  \
# 53150                 62482.0             61503.0
# 53151                 35102.0             60580.0
# 53152                 63251.0             62073.0
# 53153                 75669.0             63769.0
# 53154                 75445.0             64803.0
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 53150                          138.94                          72.43
# 53151                          138.99                          72.46
# 53152                          139.08                          72.52
# 53153                          139.19                          72.58
# 53154                          139.30                          72.65
#
#        people_fully_vaccinated_per_hundred  total_boosters_per_hundred  \
# 53150                                66.50                         NaN
# 53151                                66.53                         NaN
# 53152                                66.56                         NaN
# 53153                                66.61                         NaN
# 53154                                66.65                         NaN
#
#        daily_vaccinations_per_million
# 53150                           902.0
# 53151                           888.0
# 53152                           910.0
# 53153                           935.0
# 53154                           950.0

# %% [markdown]
# ### イラン

# %%
iran = df.loc[df.location=="Iran"]
iran.tail()
# Out:
#       location iso_code       date  total_vaccinations  people_vaccinated  \
# 23818     Iran      IRN 2021-10-17                 NaN                NaN
# 23819     Iran      IRN 2021-10-18          74113680.0         48956693.0
# 23820     Iran      IRN 2021-10-19                 NaN                NaN
# 23821     Iran      IRN 2021-10-20                 NaN                NaN
# 23822     Iran      IRN 2021-10-21          77641350.0         50036416.0
#
#        people_fully_vaccinated  total_boosters  daily_vaccinations_raw  \
# 23818                      NaN             NaN                     NaN
# 23819               25156987.0             NaN                     NaN
# 23820                      NaN             NaN                     NaN
# 23821                      NaN             NaN                     NaN
# 23822               27604934.0             NaN                     NaN
#
#        daily_vaccinations  total_vaccinations_per_hundred  \
# 23818           1214026.0                             NaN
# 23819           1214026.0                           87.16
# 23820           1208578.0                             NaN
# 23821           1203130.0                             NaN
# 23822           1197682.0                           91.31
#
#        people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 23818                            NaN                                  NaN
# 23819                          57.58                                29.59
# 23820                            NaN                                  NaN
# 23821                            NaN                                  NaN
# 23822                          58.85                                32.47
#
#        total_boosters_per_hundred  daily_vaccinations_per_million
# 23818                         NaN                         14278.0
# 23819                         NaN                         14278.0
# 23820                         NaN                         14214.0
# 23821                         NaN                         14150.0
# 23822                         NaN                         14086.0

# %% [markdown]
# ## 可視化

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook
#%matplotlib inline

# %%
fig=plt.figure(figsize=(14,8))
ax1 = plt.subplot(1,2,1) # (rows, columns, panel number)
plt.title("Daily COVID-19 vacctinated in the world")
ax1.set_zorder(2)
ax1.patch.set_alpha(0)
plt.ylim(0,100)
plt.ylabel("vaccination %")
ax1.grid()
plt.xticks(rotation=70)
ax2 = plt.twinx()
ax2.set_zorder(1)
plt.ylabel("million people")
ax1.plot_date(world_df["date"],world_df["people_vaccinated_per_hundred"],label="Vaccinated at least once per population", fmt="-")
ax1.plot_date(world_df["date"],world_df["people_fully_vaccinated_per_hundred"],label="Fully vaccinated per population", fmt="-")
ax1.plot_date(jp["date"],jp["people_vaccinated_per_hundred"],label="Vaccinated at least once per population in Japan", fmt="-")
ax1.plot_date(jp["date"],jp["people_fully_vaccinated_per_hundred"],label="Fully vaccinated per population in Japan", fmt="-")
#ax1.plot_date(uk["date"],jp["people_vaccinated_per_hundred"],label="Vaccinated at least once per population in UK", fmt="-")
#ax1.plot_date(uk["date"],jp["people_fully_vaccinated_per_hundred"],label="Fully vaccinated per population in UK", fmt="-")
ax2.bar(world_df["date"],world_df["people_vaccinated"]/1000/1000,label="People vaccinated at least once", color="pink")
ax2.bar(world_df["date"],world_df["people_fully_vaccinated"]/1000/1000,label="People fully vaccinated", color="lightgray",zorder=1)
#plt.grid(axis="y")
h1,l1 = ax1.get_legend_handles_labels()
h2,l2 = ax2.get_legend_handles_labels()
plt.legend(h1+h2,l1+l2)

# fully vactinated
ax1 = plt.subplot(1,2,2) # (rows, columns, panel number)
plt.title("Daily COVID-19 fully vacctinated per population Top 50")
plt.ylabel("vaccination %")
plt.grid(axis="x")
plt.yticks(fontsize=9)
plt.xticks(rotation=70)
plt.xlim(0,100)
chart_data=latest_df.copy().sort_values(by="people_fully_vaccinated_per_hundred",ascending=False).head(50)
chart_data=chart_data.sort_values(by="people_fully_vaccinated_per_hundred",ascending=True)
plt.barh(chart_data["location"],chart_data["people_fully_vaccinated_per_hundred"],label="People fully vaccinated")
#plt.grid(axis="y")
#h1,l1 = ax1.get_legend_handles_labels()
#h2,l2 = ax2.get_legend_handles_labels()
#plt.legend(h1+h2,l1+l2)

"""
plt.subplot(2,2,2) # (rows, columns, panel number)
plt.title("Daily new confirmed COVID-19 cases in the world(after 2021 Apr 1st)")
chart_data = world_df[world_df.date >= "2021-04-01"]
plt.bar(chart_data["date"],chart_data["new_cases"],label="New deaths")
plt.plot_date(chart_data["date"],chart_data["new_cases_smoothed"],label="rolling 7-day average", fmt="-", color="orange")
plt.xticks(rotation=70)
plt.grid(axis="y")
plt.legend()

plt.subplot(2,2,3) # (rows, columns, panel number)
plt.title("Daily new deaths in the world")
plt.bar(world_df.date,world_df.new_deaths,label="New cases")
plt.plot_date(world_df["date"],world_df["new_deaths_smoothed"],label="rolling 7-day average", fmt="-", color="orange")
plt.xticks(rotation=70)
plt.ylabel("people")
plt.grid(axis="y")
plt.legend()

plt.subplot(2,2,4) # (rows, columns, panel number)
plt.title("Daily new deaths in the world(after 2021 Apr 1st)")
chart_data = world_df[world_df.date >= "2021-04-01"]
plt.bar(chart_data["date"],chart_data["new_deaths"],label="New deaths")
plt.plot_date(chart_data["date"],chart_data["new_deaths_smoothed"],label="rolling 7-day average", fmt="-", color="orange")
plt.xticks(rotation=70)
plt.grid(axis="y")
plt.legend()
"""

fig.text(0,1,"Latest: {}".format(latest_date_str),fontsize=8,ha="left",va="top")
fig.text(0,0
         ,"*Data reference from:COVID-19 Dataset by Our World in Data",
        fontsize=7,ha="left",va="bottom")

fig.tight_layout()
# Out:
# <div id='dc80ae7c-8568-4f11-88c6-c3d11a9c50d4'></div>

# %%
fig.savefig("out/covid-owid-global-vaccinations-daily.png")
