# %%
import pandas as pd

# %%
df = pd.read_csv("covid-19-data/public/data/vaccinations/vaccinations.csv")
df.head()
# Out:
#       location iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG  2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG  2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG  2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG  2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN              1367.0
# 2                      NaN                     NaN              1367.0
# 3                      NaN                     NaN              1367.0
# 4                      NaN                     NaN              1367.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                             0.0                            0.0
# 1                             NaN                            NaN
# 2                             NaN                            NaN
# 3                             NaN                            NaN
# 4                             NaN                            NaN
#
#    people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# 0                                  NaN                             NaN
# 1                                  NaN                            35.0
# 2                                  NaN                            35.0
# 3                                  NaN                            35.0
# 4                                  NaN                            35.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36995 entries, 0 to 36994
# Data columns (total 12 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   location                             36995 non-null  object
#  1   iso_code                             36995 non-null  object
#  2   date                                 36995 non-null  object
#  3   total_vaccinations                   21629 non-null  float64
#  4   people_vaccinated                    20751 non-null  float64
#  5   people_fully_vaccinated              17699 non-null  float64
#  6   daily_vaccinations_raw               18247 non-null  float64
#  7   daily_vaccinations                   36718 non-null  float64
#  8   total_vaccinations_per_hundred       21629 non-null  float64
#  9   people_vaccinated_per_hundred        20751 non-null  float64
#  10  people_fully_vaccinated_per_hundred  17699 non-null  float64
#  11  daily_vaccinations_per_million       36718 non-null  float64
# dtypes: float64(9), object(3)
# memory usage: 3.4+ MB

# %%
df.describe()
# Out:
#        total_vaccinations  people_vaccinated  people_fully_vaccinated  \
# count        2.162900e+04       2.075100e+04             1.769900e+04
# mean         5.204998e+07       2.873095e+07             1.601566e+07
# std          2.465441e+08       1.356746e+08             6.986428e+07
# min          0.000000e+00       0.000000e+00             1.000000e+00
# 25%          1.776800e+05       1.486765e+05             6.596600e+04
# 50%          1.410273e+06       9.719730e+05             5.671170e+05
# 75%          8.667367e+06       5.399419e+06             3.528405e+06
# max          4.106018e+09       2.197539e+09             1.129705e+09
#
#        daily_vaccinations_raw  daily_vaccinations  \
# count            1.824700e+04        3.671800e+04
# mean             9.069523e+05        4.485976e+05
# std              3.671286e+06        2.530015e+06
# min              0.000000e+00        0.000000e+00
# 25%              5.975500e+03        9.600000e+02
# 50%              3.177600e+04        8.399000e+03
# 75%              1.949130e+05        5.465600e+04
# max              4.875049e+07        4.338987e+07
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# count                    21629.000000                   20751.000000
# mean                        31.074104                      19.737453
# std                         36.487479                      21.192934
# min                          0.000000                       0.000000
# 25%                          3.030000                       2.420000
# 50%                         15.690000                      11.110000
# 75%                         48.220000                      32.525000
# max                        232.720000                     116.730000
#
#        people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# count                         17699.000000                    36718.000000
# mean                             13.067078                     3423.917397
# std                              16.708250                     4449.654239
# min                               0.000000                        0.000000
# 25%                               1.220000                      424.000000
# 50%                               5.740000                     1966.000000
# 75%                              18.765000                     5148.250000
# max                             115.990000                   118759.000000

# %%
df["date"] = pd.to_datetime(df["date"])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36995 entries, 0 to 36994
# Data columns (total 12 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   location                             36995 non-null  object
#  1   iso_code                             36995 non-null  object
#  2   date                                 36995 non-null  datetime64[ns]
#  3   total_vaccinations                   21629 non-null  float64
#  4   people_vaccinated                    20751 non-null  float64
#  5   people_fully_vaccinated              17699 non-null  float64
#  6   daily_vaccinations_raw               18247 non-null  float64
#  7   daily_vaccinations                   36718 non-null  float64
#  8   total_vaccinations_per_hundred       21629 non-null  float64
#  9   people_vaccinated_per_hundred        20751 non-null  float64
#  10  people_fully_vaccinated_per_hundred  17699 non-null  float64
#  11  daily_vaccinations_per_million       36718 non-null  float64
# dtypes: datetime64[ns](1), float64(9), object(2)
# memory usage: 3.4+ MB

# %%
import datetime
latest_date_str = (df.date.max() - datetime.timedelta(days=1)).strftime("%Y-%m-%d")
latest_date_str
# Out:
# '2021-07-29'

# %% [markdown]
# ## 全世界のデータ

# %%
world_df = df.copy().loc[df.location=="World"]
world_df.tail()
# Out:
#       location  iso_code       date  total_vaccinations  people_vaccinated  \
# 36641    World  OWID_WRL 2021-07-26        3.941038e+09       2.145639e+09
# 36642    World  OWID_WRL 2021-07-27        3.980259e+09       2.157421e+09
# 36643    World  OWID_WRL 2021-07-28        4.021196e+09       2.170219e+09
# 36644    World  OWID_WRL 2021-07-29        4.069947e+09       2.187561e+09
# 36645    World  OWID_WRL 2021-07-30        4.106018e+09       2.197539e+09
#
#        people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 36641             1.089484e+09              41855107.0          34243775.0
# 36642             1.099596e+09              39221507.0          35172372.0
# 36643             1.109342e+09              40936890.0          36430356.0
# 36644             1.122437e+09              48750487.0          37734718.0
# 36645             1.129705e+09              36071413.0          37577724.0
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 36641                           50.56                          27.53
# 36642                           51.06                          27.68
# 36643                           51.59                          27.84
# 36644                           52.21                          28.06
# 36645                           52.68                          28.19
#
#        people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# 36641                                13.98                          4393.0
# 36642                                14.11                          4512.0
# 36643                                14.23                          4674.0
# 36644                                14.40                          4841.0
# 36645                                14.49                          4821.0

# %% [markdown]
# ## 国別

# %%
country_df = df.loc[df.iso_code.str.len()==3]
country_df.head()
# Out:
#       location iso_code       date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG 2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG 2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG 2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG 2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG 2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN              1367.0
# 2                      NaN                     NaN              1367.0
# 3                      NaN                     NaN              1367.0
# 4                      NaN                     NaN              1367.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                             0.0                            0.0
# 1                             NaN                            NaN
# 2                             NaN                            NaN
# 3                             NaN                            NaN
# 4                             NaN                            NaN
#
#    people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# 0                                  NaN                             NaN
# 1                                  NaN                            35.0
# 2                                  NaN                            35.0
# 3                                  NaN                            35.0
# 4                                  NaN                            35.0

# %%
latest_df = country_df.loc[country_df.date==latest_date_str]
latest_df.head()
# Out:
#          location iso_code       date  total_vaccinations  people_vaccinated  \
# 157   Afghanistan      AFG 2021-07-29           1381416.0           763020.0
# 739       Algeria      DZA 2021-07-29           3421279.0          3421279.0
# 1602    Argentina      ARG 2021-07-29          31075801.0         24542819.0
# 1843        Aruba      ABW 2021-07-29            137305.0            72758.0
# 2237    Australia      AUS 2021-07-29          11795236.0          8170354.0
#
#       people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 157                       NaN                     NaN             33708.0
# 739                  724812.0                     NaN             20914.0
# 1602                6532982.0                420529.0            343062.0
# 1843                  64547.0                   398.0               265.0
# 2237                3624882.0                201470.0            162953.0
#
#       total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 157                             3.55                           1.96
# 739                             7.80                           7.80
# 1602                           68.76                          54.30
# 1843                          128.60                          68.15
# 2237                           46.26                          32.04
#
#       people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# 157                                   NaN                           866.0
# 739                                  1.65                           477.0
# 1602                                14.45                          7591.0
# 1843                                60.46                          2482.0
# 2237                                14.22                          6390.0

# %% [markdown]
# ### ワクチン接種完了率トップ20

# %%
latest_df.sort_values(by="people_fully_vaccinated_per_hundred",ascending=False).head(20)[["location","iso_code","date","people_fully_vaccinated_per_hundred"]]
# Out:
#                    location iso_code       date  \
# 20994                 Malta      MLT 2021-07-29
# 6296         Cayman Islands      CYM 2021-07-29
# 34760  United Arab Emirates      ARE 2021-07-29
# 35593               Uruguay      URY 2021-07-29
# 16533                Israel      ISR 2021-07-29
# 3008                Bahrain      BHR 2021-07-29
# 4333                 Bhutan      BTN 2021-07-29
# 1843                  Aruba      ABW 2021-07-29
# 27387                 Qatar      QAT 2021-07-29
# 5948                 Canada      CAN 2021-07-29
# 31768                 Spain      ESP 2021-07-29
# 3782                Belgium      BEL 2021-07-29
# 15001               Hungary      HUN 2021-07-29
# 34989        United Kingdom      GBR 2021-07-29
# 30203             Singapore      SGP 2021-07-29
# 27166              Portugal      PRT 2021-07-29
# 8809                Denmark      DNK 2021-07-29
# 12630               Germany      DEU 2021-07-29
# 16749                 Italy      ITA 2021-07-29
# 8266                 Cyprus      CYP 2021-07-29
#
#        people_fully_vaccinated_per_hundred
# 20994                                85.84
# 6296                                 72.14
# 34760                                69.90
# 35593                                63.50
# 16533                                61.93
# 3008                                 61.78
# 4333                                 61.71
# 1843                                 60.46
# 27387                                59.27
# 5948                                 57.98
# 31768                                57.61
# 3782                                 57.21
# 15001                                56.20
# 34989                                55.92
# 30203                                55.75
# 27166                                54.60
# 8809                                 54.21
# 12630                                51.14
# 16749                                51.05
# 8266                                 50.62

# %% [markdown]
# ### ワクチン接種完了率ワースト20

# %%
latest_df.sort_values(by="people_fully_vaccinated_per_hundred",ascending=True).head(20)[["location","iso_code","date","people_fully_vaccinated_per_hundred"]]
# Out:
#            location iso_code       date  people_fully_vaccinated_per_hundred
# 6421           Chad      TCD 2021-07-29                                 0.05
# 21121    Mauritania      MRT 2021-07-29                                 0.33
# 36054       Vietnam      VNM 2021-07-29                                 0.56
# 36832        Zambia      ZMB 2021-07-29                                 0.71
# 7231          Congo      COG 2021-07-29                                 1.20
# 17713         Kenya      KEN 2021-07-29                                 1.21
# 32940        Taiwan      TWN 2021-07-29                                 1.44
# 739         Algeria      DZA 2021-07-29                                 1.65
# 18148    Kyrgyzstan      KGZ 2021-07-29                                 1.77
# 13688     Guatemala      GTM 2021-07-29                                 1.83
# 3194     Bangladesh      BGD 2021-07-29                                 2.61
# 25783      Pakistan      PAK 2021-07-29                                 2.67
# 12415       Georgia      GEO 2021-07-29                                 3.84
# 34553       Ukraine      UKR 2021-07-29                                 4.43
# 31082  South Africa      ZAF 2021-07-29                                 4.78
# 23274         Nepal      NPL 2021-07-29                                 5.32
# 26693   Philippines      PHL 2021-07-29                                 7.15
# 15610     Indonesia      IDN 2021-07-29                                 7.19
# 15410         India      IND 2021-07-29                                 7.24
# 25906     Palestine      PSE 2021-07-29                                 8.12

# %% [markdown]
# ### 日本

# %%
jp = df.loc[df.location=="Japan"]
jp.tail()
# Out:
#       location iso_code       date  total_vaccinations  people_vaccinated  \
# 17046    Japan      JPN 2021-07-25          80254532.0         47456190.0
# 17047    Japan      JPN 2021-07-26          81306889.0         47829908.0
# 17048    Japan      JPN 2021-07-27          82335683.0         48220346.0
# 17049    Japan      JPN 2021-07-28          83285122.0         48580388.0
# 17050    Japan      JPN 2021-07-29          84009438.0         48862145.0
#
#        people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 17046               32798342.0                954189.0            889206.0
# 17047               33476981.0               1052357.0            900296.0
# 17048               34115337.0               1028794.0            875432.0
# 17049               34704734.0                949439.0            845301.0
# 17050               35147293.0                724316.0            875173.0
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 17046                           63.45                          37.52
# 17047                           64.29                          37.82
# 17048                           65.10                          38.13
# 17049                           65.85                          38.41
# 17050                           66.42                          38.63
#
#        people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# 17046                                25.93                          7031.0
# 17047                                26.47                          7118.0
# 17048                                26.97                          6922.0
# 17049                                27.44                          6683.0
# 17050                                27.79                          6920.0

# %% [markdown]
# ### 英国

# %%
uk = df.loc[df.location=="United Kingdom"]
#uk.append(pd.Series([uk.location.unique()[0],1,latest_date_str]),ignore_index=True).tail()
#uk.append(pd.Series(["UK","GBR",latest_date_str],index=uk.columns),ignore_index=True).tail()
uk.tail()
# Out:
#              location iso_code       date  total_vaccinations  \
# 34985  United Kingdom      GBR 2021-07-25          83876595.0
# 34986  United Kingdom      GBR 2021-07-26          84112856.0
# 34987  United Kingdom      GBR 2021-07-27          84300153.0
# 34988  United Kingdom      GBR 2021-07-28          84515367.0
# 34989  United Kingdom      GBR 2021-07-29          84737932.0
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 34985         46589211.0               37287384.0                142507.0
# 34986         46653796.0               37459060.0                236261.0
# 34987         46689242.0               37610911.0                187297.0
# 34988         46733115.0               37782252.0                215214.0
# 34989         46775525.0               37962407.0                222565.0
#
#        daily_vaccinations  total_vaccinations_per_hundred  \
# 34985            208976.0                          123.56
# 34986            217123.0                          123.90
# 34987            215263.0                          124.18
# 34988            213374.0                          124.50
# 34989            211979.0                          124.82
#
#        people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 34985                          68.63                                54.93
# 34986                          68.72                                55.18
# 34987                          68.78                                55.40
# 34988                          68.84                                55.66
# 34989                          68.90                                55.92
#
#        daily_vaccinations_per_million
# 34985                          3078.0
# 34986                          3198.0
# 34987                          3171.0
# 34988                          3143.0
# 34989                          3123.0

# %% [markdown]
# ### イラン

# %%
iran = df.loc[df.location=="Iran"]
iran.tail()
# Out:
#       location iso_code       date  total_vaccinations  people_vaccinated  \
# 15776     Iran      IRN 2021-07-22                 NaN                NaN
# 15777     Iran      IRN 2021-07-23                 NaN                NaN
# 15778     Iran      IRN 2021-07-24                 NaN                NaN
# 15779     Iran      IRN 2021-07-25                 NaN                NaN
# 15780     Iran      IRN 2021-07-26          10168674.0          7741936.0
#
#        people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 15776                      NaN                     NaN            278050.0
# 15777                      NaN                     NaN            280440.0
# 15778                      NaN                     NaN            282830.0
# 15779                      NaN                     NaN            285219.0
# 15780                2426738.0                     NaN            287609.0
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 15776                             NaN                            NaN
# 15777                             NaN                            NaN
# 15778                             NaN                            NaN
# 15779                             NaN                            NaN
# 15780                           12.11                           9.22
#
#        people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# 15776                                  NaN                          3310.0
# 15777                                  NaN                          3339.0
# 15778                                  NaN                          3367.0
# 15779                                  NaN                          3396.0
# 15780                                 2.89                          3424.0

# %% [markdown]
# ## 可視化

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook
#%matplotlib inline

# %%
fig=plt.figure(figsize=(14,8))
ax1 = plt.subplot(1,2,1) # (rows, columns, panel number)
plt.title("Daily COVID-19 vacctinated in the world")
ax1.set_zorder(2)
ax1.patch.set_alpha(0)
plt.ylim(0,100)
plt.ylabel("vaccination %")
ax1.grid()
plt.xticks(rotation=70)
ax2 = plt.twinx()
ax2.set_zorder(1)
plt.ylabel("million people")
ax1.plot_date(world_df["date"],world_df["people_vaccinated_per_hundred"],label="Vaccinated at least once per population", fmt="-")
ax1.plot_date(world_df["date"],world_df["people_fully_vaccinated_per_hundred"],label="Fully vaccinated per population", fmt="-")
ax1.plot_date(jp["date"],jp["people_vaccinated_per_hundred"],label="Vaccinated at least once per population in Japan", fmt="-")
ax1.plot_date(jp["date"],jp["people_fully_vaccinated_per_hundred"],label="Fully vaccinated per population in Japan", fmt="-")
#ax1.plot_date(uk["date"],jp["people_vaccinated_per_hundred"],label="Vaccinated at least once per population in UK", fmt="-")
#ax1.plot_date(uk["date"],jp["people_fully_vaccinated_per_hundred"],label="Fully vaccinated per population in UK", fmt="-")
ax2.bar(world_df["date"],world_df["people_vaccinated"]/1000/1000,label="People vaccinated at least once", color="pink")
ax2.bar(world_df["date"],world_df["people_fully_vaccinated"]/1000/1000,label="People fully vaccinated", color="lightgray",zorder=1)
#plt.grid(axis="y")
h1,l1 = ax1.get_legend_handles_labels()
h2,l2 = ax2.get_legend_handles_labels()
plt.legend(h1+h2,l1+l2)

# fully vactinated
ax1 = plt.subplot(1,2,2) # (rows, columns, panel number)
plt.title("Daily COVID-19 fully vacctinated per population Top 50")
plt.ylabel("vaccination %")
plt.grid(axis="x")
plt.yticks(fontsize=9)
plt.xticks(rotation=70)
plt.xlim(0,100)
chart_data=latest_df.copy().sort_values(by="people_fully_vaccinated_per_hundred",ascending=False).head(50)
chart_data=chart_data.sort_values(by="people_fully_vaccinated_per_hundred",ascending=True)
plt.barh(chart_data["location"],chart_data["people_fully_vaccinated_per_hundred"],label="People fully vaccinated")
#plt.grid(axis="y")
#h1,l1 = ax1.get_legend_handles_labels()
#h2,l2 = ax2.get_legend_handles_labels()
#plt.legend(h1+h2,l1+l2)

"""
plt.subplot(2,2,2) # (rows, columns, panel number)
plt.title("Daily new confirmed COVID-19 cases in the world(after 2021 Apr 1st)")
chart_data = world_df[world_df.date >= "2021-04-01"]
plt.bar(chart_data["date"],chart_data["new_cases"],label="New deaths")
plt.plot_date(chart_data["date"],chart_data["new_cases_smoothed"],label="rolling 7-day average", fmt="-", color="orange")
plt.xticks(rotation=70)
plt.grid(axis="y")
plt.legend()

plt.subplot(2,2,3) # (rows, columns, panel number)
plt.title("Daily new deaths in the world")
plt.bar(world_df.date,world_df.new_deaths,label="New cases")
plt.plot_date(world_df["date"],world_df["new_deaths_smoothed"],label="rolling 7-day average", fmt="-", color="orange")
plt.xticks(rotation=70)
plt.ylabel("people")
plt.grid(axis="y")
plt.legend()

plt.subplot(2,2,4) # (rows, columns, panel number)
plt.title("Daily new deaths in the world(after 2021 Apr 1st)")
chart_data = world_df[world_df.date >= "2021-04-01"]
plt.bar(chart_data["date"],chart_data["new_deaths"],label="New deaths")
plt.plot_date(chart_data["date"],chart_data["new_deaths_smoothed"],label="rolling 7-day average", fmt="-", color="orange")
plt.xticks(rotation=70)
plt.grid(axis="y")
plt.legend()
"""

fig.text(0,1,"Latest: {}".format(latest_date_str),fontsize=8,ha="left",va="top")
fig.text(0,0
         ,"*Data reference from:COVID-19 Dataset by Our World in Data",
        fontsize=7,ha="left",va="bottom")

fig.tight_layout()
# Out:
# <div id='c8d18577-5a14-4215-a73f-545d2650ac12'></div>

# %%
fig.savefig("out/covid-owid-global-vaccinations-daily.png")
