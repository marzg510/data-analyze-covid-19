# %%
import pandas as pd

# %%
df = pd.read_csv("covid-19-data/public/data/vaccinations/vaccinations.csv")
df.head()
# Out:
#       location iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG  2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG  2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG  2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG  2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  total_boosters  daily_vaccinations_raw  \
# 0                      NaN             NaN                     NaN
# 1                      NaN             NaN                     NaN
# 2                      NaN             NaN                     NaN
# 3                      NaN             NaN                     NaN
# 4                      NaN             NaN                     NaN
#
#    daily_vaccinations  total_vaccinations_per_hundred  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58818 entries, 0 to 58817
# Data columns (total 14 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   location                             58818 non-null  object
#  1   iso_code                             58818 non-null  object
#  2   date                                 58818 non-null  object
#  3   total_vaccinations                   33504 non-null  float64
#  4   people_vaccinated                    32012 non-null  float64
#  5   people_fully_vaccinated              28985 non-null  float64
#  6   total_boosters                       5451 non-null   float64
#  7   daily_vaccinations_raw               28122 non-null  float64
#  8   daily_vaccinations                   58555 non-null  float64
#  9   total_vaccinations_per_hundred       33504 non-null  float64
#  10  people_vaccinated_per_hundred        32012 non-null  float64
# ...

# %%
df.describe()
# Out:
#        total_vaccinations  people_vaccinated  people_fully_vaccinated  \
# count        3.350400e+04       3.201200e+04             2.898500e+04
# mean         9.986710e+07       5.437861e+07             3.661890e+07
# std          4.769042e+08       2.639861e+08             1.894296e+08
# min          0.000000e+00       0.000000e+00             1.000000e+00
# 25%          3.706320e+05       2.751228e+05             1.490160e+05
# 50%          2.660704e+06       1.838417e+06             1.158130e+06
# 75%          1.558921e+07       9.609705e+06             6.568942e+06
# max          7.127910e+09       3.914788e+09             3.068814e+09
#
#        total_boosters  daily_vaccinations_raw  daily_vaccinations  \
# count    5.451000e+03            2.812200e+04        5.855500e+04
# mean     2.371107e+06            1.004048e+06        4.931641e+05
# std      6.837261e+06            3.988970e+06        2.740589e+06
# min      1.000000e+00            0.000000e+00        0.000000e+00
# ...

# %%
df["date"] = pd.to_datetime(df["date"])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58818 entries, 0 to 58817
# Data columns (total 14 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   location                             58818 non-null  object
#  1   iso_code                             58818 non-null  object
#  2   date                                 58818 non-null  datetime64[ns]
#  3   total_vaccinations                   33504 non-null  float64
#  4   people_vaccinated                    32012 non-null  float64
#  5   people_fully_vaccinated              28985 non-null  float64
#  6   total_boosters                       5451 non-null   float64
#  7   daily_vaccinations_raw               28122 non-null  float64
#  8   daily_vaccinations                   58555 non-null  float64
#  9   total_vaccinations_per_hundred       33504 non-null  float64
#  10  people_vaccinated_per_hundred        32012 non-null  float64
# ...

# %%
import datetime
latest_date_str = (df.date.max() - datetime.timedelta(days=1)).strftime("%Y-%m-%d")
latest_date_str
# Out:
# '2021-11-01'

# %% [markdown]
# ## 全世界のデータ

# %%
world_df = df.copy().loc[df.location=="World"]
world_df.tail()
# Out:
#       location  iso_code       date  total_vaccinations  people_vaccinated  \
# 58188    World  OWID_WRL 2021-10-29        7.022491e+09       3.884886e+09
# 58189    World  OWID_WRL 2021-10-30        7.053995e+09       3.896129e+09
# 58190    World  OWID_WRL 2021-10-31        7.086747e+09       3.903487e+09
# 58191    World  OWID_WRL 2021-11-01        7.108123e+09       3.910298e+09
# 58192    World  OWID_WRL 2021-11-02        7.127910e+09       3.914788e+09
#
#        people_fully_vaccinated  total_boosters  daily_vaccinations_raw  \
# 58188             3.021668e+09      81928592.0              36318025.0
# 58189             3.035478e+09      83213107.0              31504320.0
# 58190             3.053184e+09      84556372.0              32752225.0
# 58191             3.061687e+09      85219661.0              21375348.0
# 58192             3.068814e+09      85758177.0              19787563.0
#
#        daily_vaccinations  total_vaccinations_per_hundred  \
# ...

# %% [markdown]
# ## 国別

# %%
country_df = df.loc[df.iso_code.str.len()==3]
country_df.head()
# Out:
#       location iso_code       date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG 2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG 2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG 2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG 2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG 2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  total_boosters  daily_vaccinations_raw  \
# 0                      NaN             NaN                     NaN
# 1                      NaN             NaN                     NaN
# 2                      NaN             NaN                     NaN
# 3                      NaN             NaN                     NaN
# 4                      NaN             NaN                     NaN
#
#    daily_vaccinations  total_vaccinations_per_hundred  \
# 0                 NaN                             0.0
# ...

# %%
latest_df = country_df.loc[country_df.date==latest_date_str]
latest_df.head()
# Out:
#        location iso_code       date  total_vaccinations  people_vaccinated  \
# 844     Albania      ALB 2021-11-01           1909861.0          1018154.0
# 2431  Argentina      ARG 2021-11-01          60203627.0         34328689.0
# 2858      Aruba      ABW 2021-11-01            159537.0            82682.0
# 3436  Australia      AUS 2021-11-01          35786323.0         19100734.0
# 3747    Austria      AUT 2021-11-01          11527622.0          5905785.0
#
#       people_fully_vaccinated  total_boosters  daily_vaccinations_raw  \
# 844                  891707.0             NaN                     NaN
# 2431               25983978.0             NaN                148623.0
# 2858                  76855.0             NaN                     NaN
# 3436               16678894.0          6695.0                200834.0
# 3747                5624394.0        324698.0                  3350.0
#
#       daily_vaccinations  total_vaccinations_per_hundred  \
# ...

# %% [markdown]
# ### ワクチン接種完了率トップ20

# %%
latest_df.sort_values(by="people_fully_vaccinated_per_hundred",ascending=False).head(20)[["location","iso_code","date","people_fully_vaccinated_per_hundred"]]
# Out:
#                    location iso_code       date  \
# 55296  United Arab Emirates      ARE 2021-11-01
# 33262                 Malta      MLT 2021-11-01
# 14099               Denmark      DNK 2021-11-01
# 49481           South Korea      KOR 2021-11-01
# 56489               Uruguay      URY 2021-11-01
# 32489              Malaysia      MYS 2021-11-01
# 9455                 Canada      CAN 2021-11-01
# 5733                Belgium      BEL 2021-11-01
# 26918                 Japan      JPN 2021-11-01
# 2858                  Aruba      ABW 2021-11-01
# 26420                 Italy      ITA 2021-11-01
# 39833                Norway      NOR 2021-11-01
# 18717                France      FRA 2021-11-01
# 55593        United Kingdom      GBR 2021-11-01
# 19977               Germany      DEU 2021-11-01
# 37586           New Zealand      NZL 2021-11-01
# 4583                Bahrain      BHR 2021-11-01
# 26109                Israel      ISR 2021-11-01
# ...

# %% [markdown]
# ### ワクチン接種完了率ワースト20

# %%
latest_df.sort_values(by="people_fully_vaccinated_per_hundred",ascending=True).head(20)[["location","iso_code","date","people_fully_vaccinated_per_hundred"]]
# Out:
#                        location iso_code       date  \
# 58559                    Zambia      ZMB 2021-11-01
# 27960                     Kenya      KEN 2021-11-01
# 19215                     Gabon      GAB 2021-11-01
# 10166  Central African Republic      CAF 2021-11-01
# 56861                   Vanuatu      VUT 2021-11-01
# 28732                Kyrgyzstan      KGZ 2021-11-01
# 26659                   Jamaica      JAM 2021-11-01
# 58816                  Zimbabwe      ZWE 2021-11-01
# 54994                   Ukraine      UKR 2021-11-01
# 4864                 Bangladesh      BGD 2021-11-01
# 21616                 Guatemala      GTM 2021-11-01
# 40680                  Pakistan      PAK 2021-11-01
# 34312                   Moldova      MDA 2021-11-01
# 8506                   Bulgaria      BGR 2021-11-01
# 29511                   Lebanon      LBN 2021-11-01
# 24393                     India      IND 2021-11-01
# 42153               Philippines      PHL 2021-11-01
# ...

# %% [markdown]
# ### 日本

# %%
jp = df.loc[df.location=="Japan"]
jp.tail()
# Out:
#       location iso_code       date  total_vaccinations  people_vaccinated  \
# 26914    Japan      JPN 2021-10-28         187865740.0         97711358.0
# 26915    Japan      JPN 2021-10-29                 NaN                NaN
# 26916    Japan      JPN 2021-10-30                 NaN                NaN
# 26917    Japan      JPN 2021-10-31         189319619.0         98090221.0
# 26918    Japan      JPN 2021-11-01         190022071.0         98250592.0
#
#        people_fully_vaccinated  total_boosters  daily_vaccinations_raw  \
# 26914               90154382.0             NaN               1123334.0
# 26915                      NaN             NaN                     NaN
# 26916                      NaN             NaN                     NaN
# 26917               91229398.0             NaN                     NaN
# 26918               91771479.0             NaN                702452.0
#
#        daily_vaccinations  total_vaccinations_per_hundred  \
# ...

# %% [markdown]
# ### 英国

# %%
uk = df.loc[df.location=="United Kingdom"]
#uk.append(pd.Series([uk.location.unique()[0],1,latest_date_str]),ignore_index=True).tail()
#uk.append(pd.Series(["UK","GBR",latest_date_str],index=uk.columns),ignore_index=True).tail()
uk.tail()
# Out:
#              location iso_code       date  total_vaccinations  \
# 55589  United Kingdom      GBR 2021-10-28         102827764.0
# 55590  United Kingdom      GBR 2021-10-29         103176238.0
# 55591  United Kingdom      GBR 2021-10-30         103610105.0
# 55592  United Kingdom      GBR 2021-10-31         103814905.0
# 55593  United Kingdom      GBR 2021-11-01         104112757.0
#
#        people_vaccinated  people_fully_vaccinated  total_boosters  \
# 55589         49882904.0               45651222.0       7293638.0
# 55590         49923871.0               45673501.0       7578866.0
# 55591         49959923.0               45698902.0       7951280.0
# 55592         49987325.0               45712351.0       8115229.0
# 55593         50025020.0               45731565.0       8356172.0
#
#        daily_vaccinations_raw  daily_vaccinations  \
# 55589                366081.0            340041.0
# 55590                348474.0            336808.0
# ...

# %% [markdown]
# ### イラン

# %%
iran = df.loc[df.location=="Iran"]
iran.tail()
# Out:
#       location iso_code       date  total_vaccinations  people_vaccinated  \
# 24953     Iran      IRN 2021-10-29          85369917.0         52199440.0
# 24954     Iran      IRN 2021-10-30                 NaN                NaN
# 24955     Iran      IRN 2021-10-31                 NaN                NaN
# 24956     Iran      IRN 2021-11-01                 NaN                NaN
# 24957     Iran      IRN 2021-11-02          89255211.0         53102837.0
#
#        people_fully_vaccinated  total_boosters  daily_vaccinations_raw  \
# 24953               33088940.0         81537.0                     NaN
# 24954                      NaN             NaN                     NaN
# 24955                      NaN             NaN                     NaN
# 24956                      NaN             NaN                     NaN
# 24957               36054893.0         97481.0                     NaN
#
#        daily_vaccinations  total_vaccinations_per_hundred  \
# ...

# %% [markdown]
# ## 可視化

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook
#%matplotlib inline

# %%
fig=plt.figure(figsize=(14,8))
ax1 = plt.subplot(1,2,1) # (rows, columns, panel number)
plt.title("Daily COVID-19 vacctinated in the world")
ax1.set_zorder(2)
ax1.patch.set_alpha(0)
plt.ylim(0,100)
plt.ylabel("vaccination %")
ax1.grid()
plt.xticks(rotation=70)
ax2 = plt.twinx()
ax2.set_zorder(1)
plt.ylabel("million people")
ax1.plot_date(world_df["date"],world_df["people_vaccinated_per_hundred"],label="Vaccinated at least once per population", fmt="-")
ax1.plot_date(world_df["date"],world_df["people_fully_vaccinated_per_hundred"],label="Fully vaccinated per population", fmt="-")
ax1.plot_date(jp["date"],jp["people_vaccinated_per_hundred"],label="Vaccinated at least once per population in Japan", fmt="-")
ax1.plot_date(jp["date"],jp["people_fully_vaccinated_per_hundred"],label="Fully vaccinated per population in Japan", fmt="-")
#ax1.plot_date(uk["date"],jp["people_vaccinated_per_hundred"],label="Vaccinated at least once per population in UK", fmt="-")
#ax1.plot_date(uk["date"],jp["people_fully_vaccinated_per_hundred"],label="Fully vaccinated per population in UK", fmt="-")
ax2.bar(world_df["date"],world_df["people_vaccinated"]/1000/1000,label="People vaccinated at least once", color="pink")
ax2.bar(world_df["date"],world_df["people_fully_vaccinated"]/1000/1000,label="People fully vaccinated", color="lightgray",zorder=1)
#plt.grid(axis="y")
h1,l1 = ax1.get_legend_handles_labels()
h2,l2 = ax2.get_legend_handles_labels()
plt.legend(h1+h2,l1+l2)

# fully vactinated
ax1 = plt.subplot(1,2,2) # (rows, columns, panel number)
plt.title("Daily COVID-19 fully vacctinated per population Top 50")
plt.ylabel("vaccination %")
plt.grid(axis="x")
plt.yticks(fontsize=9)
plt.xticks(rotation=70)
plt.xlim(0,100)
chart_data=latest_df.copy().sort_values(by="people_fully_vaccinated_per_hundred",ascending=False).head(50)
chart_data=chart_data.sort_values(by="people_fully_vaccinated_per_hundred",ascending=True)
plt.barh(chart_data["location"],chart_data["people_fully_vaccinated_per_hundred"],label="People fully vaccinated")
#plt.grid(axis="y")
#h1,l1 = ax1.get_legend_handles_labels()
#h2,l2 = ax2.get_legend_handles_labels()
#plt.legend(h1+h2,l1+l2)

"""
plt.subplot(2,2,2) # (rows, columns, panel number)
plt.title("Daily new confirmed COVID-19 cases in the world(after 2021 Apr 1st)")
chart_data = world_df[world_df.date >= "2021-04-01"]
plt.bar(chart_data["date"],chart_data["new_cases"],label="New deaths")
plt.plot_date(chart_data["date"],chart_data["new_cases_smoothed"],label="rolling 7-day average", fmt="-", color="orange")
plt.xticks(rotation=70)
plt.grid(axis="y")
plt.legend()

plt.subplot(2,2,3) # (rows, columns, panel number)
plt.title("Daily new deaths in the world")
plt.bar(world_df.date,world_df.new_deaths,label="New cases")
plt.plot_date(world_df["date"],world_df["new_deaths_smoothed"],label="rolling 7-day average", fmt="-", color="orange")
plt.xticks(rotation=70)
plt.ylabel("people")
plt.grid(axis="y")
plt.legend()

plt.subplot(2,2,4) # (rows, columns, panel number)
plt.title("Daily new deaths in the world(after 2021 Apr 1st)")
chart_data = world_df[world_df.date >= "2021-04-01"]
plt.bar(chart_data["date"],chart_data["new_deaths"],label="New deaths")
plt.plot_date(chart_data["date"],chart_data["new_deaths_smoothed"],label="rolling 7-day average", fmt="-", color="orange")
plt.xticks(rotation=70)
plt.grid(axis="y")
plt.legend()
"""

fig.text(0,1,"Latest: {}".format(latest_date_str),fontsize=8,ha="left",va="top")
fig.text(0,0
         ,"*Data reference from:COVID-19 Dataset by Our World in Data",
        fontsize=7,ha="left",va="bottom")

fig.tight_layout()
# Out:
# <div id='24e729a5-8fc3-4a54-ba92-f812e4133688'></div>

# %%
fig.savefig("out/covid-owid-global-vaccinations-daily.png")
