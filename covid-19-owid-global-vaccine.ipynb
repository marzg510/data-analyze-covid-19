# %%
import pandas as pd

# %%
df = pd.read_csv("covid-19-data/public/data/vaccinations/vaccinations.csv")
df.head()
# Out:
#       location iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG  2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG  2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG  2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG  2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN              1367.0
# 2                      NaN                     NaN              1367.0
# 3                      NaN                     NaN              1367.0
# 4                      NaN                     NaN              1367.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                             0.0                            0.0
# 1                             NaN                            NaN
# 2                             NaN                            NaN
# 3                             NaN                            NaN
# 4                             NaN                            NaN
#
#    people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# 0                                  NaN                             NaN
# 1                                  NaN                            35.0
# 2                                  NaN                            35.0
# 3                                  NaN                            35.0
# 4                                  NaN                            35.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29170 entries, 0 to 29169
# Data columns (total 12 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   location                             29170 non-null  object
#  1   iso_code                             29170 non-null  object
#  2   date                                 29170 non-null  object
#  3   total_vaccinations                   17256 non-null  float64
#  4   people_vaccinated                    16462 non-null  float64
#  5   people_fully_vaccinated              13486 non-null  float64
#  6   daily_vaccinations_raw               14586 non-null  float64
#  7   daily_vaccinations                   28880 non-null  float64
#  8   total_vaccinations_per_hundred       17256 non-null  float64
#  9   people_vaccinated_per_hundred        16462 non-null  float64
#  10  people_fully_vaccinated_per_hundred  13486 non-null  float64
#  11  daily_vaccinations_per_million       28880 non-null  float64
# dtypes: float64(9), object(3)
# memory usage: 2.7+ MB

# %%
df.describe()
# Out:
#        total_vaccinations  people_vaccinated  people_fully_vaccinated  \
# count        1.725600e+04       1.646200e+04             1.348600e+04
# mean         3.603773e+07       2.018024e+07             1.109262e+07
# std          1.633819e+08       9.100839e+07             4.694246e+07
# min          0.000000e+00       0.000000e+00             1.000000e+00
# 25%          1.338822e+05       1.078128e+05             5.049850e+04
# 50%          1.029112e+06       7.347845e+05             4.147570e+05
# 75%          6.327619e+06       4.274108e+06             2.471920e+06
# max          2.882824e+09       1.771817e+09             8.132862e+08
#
#        daily_vaccinations_raw  daily_vaccinations  \
# count            1.458600e+04        2.888000e+04
# mean             7.967097e+05        3.952659e+05
# std              3.275576e+06        2.222716e+06
# min              0.000000e+00        0.000000e+00
# 25%              5.314250e+03        9.570000e+02
# 50%              2.850750e+04        8.066000e+03
# 75%              1.691985e+05        4.840650e+04
# max              4.702836e+07        4.193655e+07
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# count                    17256.000000                   16462.000000
# mean                        23.704255                      15.753442
# std                         30.477984                      18.646170
# min                          0.000000                       0.000000
# 25%                          2.130000                       1.790000
# 50%                         10.830000                       7.800000
# 75%                         33.912500                      24.017500
# max                        231.660000                     116.380000
#
#        people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# count                         13486.000000                    28880.000000
# mean                              9.410471                     3249.897022
# std                              13.341053                     4401.098558
# min                               0.000000                        0.000000
# 25%                               0.820000                      378.000000
# 50%                               3.740000                     1706.500000
# 75%                              12.237500                     4804.000000
# max                             115.270000                   118759.000000

# %%
df["date"] = pd.to_datetime(df["date"])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29170 entries, 0 to 29169
# Data columns (total 12 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   location                             29170 non-null  object
#  1   iso_code                             29170 non-null  object
#  2   date                                 29170 non-null  datetime64[ns]
#  3   total_vaccinations                   17256 non-null  float64
#  4   people_vaccinated                    16462 non-null  float64
#  5   people_fully_vaccinated              13486 non-null  float64
#  6   daily_vaccinations_raw               14586 non-null  float64
#  7   daily_vaccinations                   28880 non-null  float64
#  8   total_vaccinations_per_hundred       17256 non-null  float64
#  9   people_vaccinated_per_hundred        16462 non-null  float64
#  10  people_fully_vaccinated_per_hundred  13486 non-null  float64
#  11  daily_vaccinations_per_million       28880 non-null  float64
# dtypes: datetime64[ns](1), float64(9), object(2)
# memory usage: 2.7+ MB

# %%
latest_date_str = df.date.max().strftime("%Y-%m-%d")
latest_date_str
# Out:
# '2021-06-25'

# %% [markdown]
# ## 全世界のデータ

# %%
world_df = df.copy().loc[df.location=="World"]
world_df.tail()
# Out:
#       location  iso_code       date  total_vaccinations  people_vaccinated  \
# 28923    World  OWID_WRL 2021-06-21        2.709035e+09       1.719212e+09
# 28924    World  OWID_WRL 2021-06-22        2.753389e+09       1.732612e+09
# 28925    World  OWID_WRL 2021-06-23        2.796521e+09       1.746109e+09
# 28926    World  OWID_WRL 2021-06-24        2.843549e+09       1.761036e+09
# 28927    World  OWID_WRL 2021-06-25        2.882824e+09       1.771817e+09
#
#        people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 28923              786046397.0              42911822.0          40861937.0
# 28924              793538331.0              44353761.0          41649716.0
# 28925              801150431.0              43131816.0          41899692.0
# 28926              808701757.0              47028363.0          41936547.0
# 28927              813286186.0              39275142.0          41654719.0
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 28923                           34.75                          22.06
# 28924                           35.32                          22.23
# 28925                           35.88                          22.40
# 28926                           36.48                          22.59
# 28927                           36.98                          22.73
#
#        people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# 28923                                10.08                          5242.0
# 28924                                10.18                          5343.0
# 28925                                10.28                          5375.0
# 28926                                10.37                          5380.0
# 28927                                10.43                          5344.0

# %% [markdown]
# ## 国別

# %%
country_df = df.loc[df.iso_code.str.len()==3]
country_df.head()
# Out:
#       location iso_code       date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG 2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG 2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG 2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG 2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG 2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN              1367.0
# 2                      NaN                     NaN              1367.0
# 3                      NaN                     NaN              1367.0
# 4                      NaN                     NaN              1367.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                             0.0                            0.0
# 1                             NaN                            NaN
# 2                             NaN                            NaN
# 3                             NaN                            NaN
# 4                             NaN                            NaN
#
#    people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# 0                                  NaN                             NaN
# 1                                  NaN                            35.0
# 2                                  NaN                            35.0
# 3                                  NaN                            35.0
# 4                                  NaN                            35.0

# %%
latest_df = country_df.loc[country_df.date==country_df.date.max()]
latest_df.head()
# Out:
#         location iso_code       date  total_vaccinations  people_vaccinated  \
# 1288   Argentina      ARG 2021-06-25          19205808.0         15374817.0
# 1776   Australia      AUS 2021-06-25           7137632.0          5949765.0
# 1957     Austria      AUT 2021-06-25           7359382.0          4621626.0
# 2117  Azerbaijan      AZE 2021-06-25           3218651.0          2070526.0
# 2401     Bahrain      BHR 2021-06-25           2009717.0          1050190.0
#
#       people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 1288                3830991.0                284128.0            247125.0
# 1776                1187867.0                138434.0            110995.0
# 1957                2838002.0                112713.0             81199.0
# 2117                1148125.0                 72301.0             43242.0
# 2401                 959527.0                 16396.0             12041.0
#
#       total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 1288                           42.49                          34.02
# 1776                           27.99                          23.33
# 1957                           81.71                          51.31
# 2117                           31.74                          20.42
# 2401                          118.11                          61.72
#
#       people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# 1288                                 8.48                          5468.0
# 1776                                 4.66                          4353.0
# 1957                                31.51                          9016.0
# 2117                                11.32                          4265.0
# 2401                                56.39                          7076.0

# %% [markdown]
# ### ワクチン接種完了率トップ20

# %%
latest_df.sort_values(by="people_fully_vaccinated_per_hundred",ascending=False).head(20)[["location","iso_code","date","people_fully_vaccinated_per_hundred"]]
# Out:
#              location iso_code       date  people_fully_vaccinated_per_hundred
# 16567           Malta      MLT 2021-06-25                                69.66
# 4930   Cayman Islands      CYM 2021-06-25                                65.99
# 13063          Israel      ISR 2021-06-25                                59.57
# 2401          Bahrain      BHR 2021-06-25                                56.39
# 17406        Mongolia      MNG 2021-06-25                                52.58
# 11973         Iceland      ISL 2021-06-25                                52.03
# 6232          Curacao      CUW 2021-06-25                                47.23
# 21622           Qatar      QAT 2021-06-25                                46.18
# 27786   United States      USA 2021-06-25                                45.33
# 12874     Isle of Man      IMN 2021-06-25                                45.22
# 28098         Uruguay      URY 2021-06-25                                44.67
# 8791   Faeroe Islands      FRO 2021-06-25                                38.16
# 15300       Lithuania      LTU 2021-06-25                                35.78
# 9918          Germany      DEU 2021-06-25                                34.51
# 10376          Greece      GRC 2021-06-25                                33.21
# 18515     Netherlands      NLD 2021-06-25                                31.91
# 1957          Austria      AUT 2021-06-25                                31.51
# 15771      Luxembourg      LUX 2021-06-25                                31.32
# 24285        Slovenia      SVN 2021-06-25                                30.79
# 21436        Portugal      PRT 2021-06-25                                30.53

# %% [markdown]
# ### ワクチン接種完了率ワースト20

# %%
latest_df.sort_values(by="people_fully_vaccinated_per_hundred",ascending=True).head(20)[["location","iso_code","date","people_fully_vaccinated_per_hundred"]]
# Out:
#                   location iso_code       date  \
# 28436              Vietnam      VNM 2021-06-25
# 26022               Taiwan      TWN 2021-06-25
# 16054               Malawi      MWI 2021-06-25
# 28325            Venezuela      VEN 2021-06-25
# 24549         South Africa      ZAF 2021-06-25
# 8168              Eswatini      SWZ 2021-06-25
# 27232              Ukraine      UKR 2021-06-25
# 9737               Georgia      GEO 2021-06-25
# 26184             Thailand      THA 2021-06-25
# 12135                India      IND 2021-06-25
# 1776             Australia      AUS 2021-06-25
# 12300            Indonesia      IDN 2021-06-25
# 26523  Trinidad and Tobago      TTO 2021-06-25
# 14749              Lebanon      LBN 2021-06-25
# 25481             Suriname      SUR 2021-06-25
# 16177             Malaysia      MYS 2021-06-25
# 17105              Moldova      MDA 2021-06-25
# 1288             Argentina      ARG 2021-06-25
# 13877           Kazakhstan      KAZ 2021-06-25
# 4230              Bulgaria      BGR 2021-06-25
#
#        people_fully_vaccinated_per_hundred
# 28436                                 0.15
# 26022                                 0.15
# 16054                                 0.22
# 28325                                 0.79
# 24549                                 0.81
# 8168                                  0.84
# 27232                                 1.26
# 9737                                  2.28
# 26184                                 3.65
# 12135                                 3.86
# 1776                                  4.66
# 12300                                 4.72
# 26523                                 4.93
# 14749                                 5.82
# 25481                                 5.83
# 16177                                 6.08
# 17105                                 6.34
# 1288                                  8.48
# 13877                                 9.74
# 4230                                 11.27

# %% [markdown]
# ### 日本

# %%
jp = df.loc[df.location=="Japan"]
jp.head()
# Out:
#       location iso_code       date  total_vaccinations  people_vaccinated  \
# 13340    Japan      JPN 2021-02-17               125.0              125.0
# 13341    Japan      JPN 2021-02-18               611.0              611.0
# 13342    Japan      JPN 2021-02-19              5039.0             5039.0
# 13343    Japan      JPN 2021-02-20                 NaN                NaN
# 13344    Japan      JPN 2021-02-21                 NaN                NaN
#
#        people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 13340                      NaN                     NaN                 NaN
# 13341                      NaN                   486.0               486.0
# 13342                      NaN                  4428.0              2457.0
# 13343                      NaN                     NaN              2404.0
# 13344                      NaN                     NaN              2378.0
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 13340                             0.0                            0.0
# 13341                             0.0                            0.0
# 13342                             0.0                            0.0
# 13343                             NaN                            NaN
# 13344                             NaN                            NaN
#
#        people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# 13340                                  NaN                             NaN
# 13341                                  NaN                             4.0
# 13342                                  NaN                            19.0
# 13343                                  NaN                            19.0
# 13344                                  NaN                            19.0

# %% [markdown]
# ## 可視化

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook
#%matplotlib inline

# %%
fig=plt.figure(figsize=(12,8))
ax1 = plt.subplot(1,1,1) # (rows, columns, panel number)
plt.title("Daily COVID-19 vacctinated in the world")
ax1.set_zorder(2)
ax1.patch.set_alpha(0)
plt.ylim(0,100)
plt.ylabel("vaccination %")
ax1.grid()
plt.xticks(rotation=70)
ax2 = plt.twinx()
ax2.set_zorder(1)
plt.ylabel("million people")
ax1.plot_date(world_df["date"],world_df["people_vaccinated_per_hundred"],label="Vaccinated at least once per population", fmt="-")
ax1.plot_date(world_df["date"],world_df["people_fully_vaccinated_per_hundred"],label="Fully vaccinated per population", fmt="-")
ax1.plot_date(jp["date"],jp["people_vaccinated_per_hundred"],label="Vaccinated at least once per population in Japan", fmt="-")
ax1.plot_date(jp["date"],jp["people_fully_vaccinated_per_hundred"],label="Fully vaccinated per population in Japan", fmt="-")
ax2.bar(world_df["date"],world_df["people_vaccinated"]/1000/1000,label="People vaccinated at least once", color="pink")
ax2.bar(world_df["date"],world_df["people_fully_vaccinated"]/1000/1000,label="People fully vaccinated", color="lightgray",zorder=1)
#plt.grid(axis="y")
h1,l1 = ax1.get_legend_handles_labels()
h2,l2 = ax2.get_legend_handles_labels()
plt.legend(h1+h2,l1+l2)
"""
plt.subplot(2,2,2) # (rows, columns, panel number)
plt.title("Daily new confirmed COVID-19 cases in the world(after 2021 Apr 1st)")
chart_data = world_df[world_df.date >= "2021-04-01"]
plt.bar(chart_data["date"],chart_data["new_cases"],label="New deaths")
plt.plot_date(chart_data["date"],chart_data["new_cases_smoothed"],label="rolling 7-day average", fmt="-", color="orange")
plt.xticks(rotation=70)
plt.grid(axis="y")
plt.legend()

plt.subplot(2,2,3) # (rows, columns, panel number)
plt.title("Daily new deaths in the world")
plt.bar(world_df.date,world_df.new_deaths,label="New cases")
plt.plot_date(world_df["date"],world_df["new_deaths_smoothed"],label="rolling 7-day average", fmt="-", color="orange")
plt.xticks(rotation=70)
plt.ylabel("people")
plt.grid(axis="y")
plt.legend()

plt.subplot(2,2,4) # (rows, columns, panel number)
plt.title("Daily new deaths in the world(after 2021 Apr 1st)")
chart_data = world_df[world_df.date >= "2021-04-01"]
plt.bar(chart_data["date"],chart_data["new_deaths"],label="New deaths")
plt.plot_date(chart_data["date"],chart_data["new_deaths_smoothed"],label="rolling 7-day average", fmt="-", color="orange")
plt.xticks(rotation=70)
plt.grid(axis="y")
plt.legend()
"""

fig.text(0,1,"Latest: {}".format(latest_date_str),fontsize=8,ha="left",va="top")
fig.text(0,0
         ,"*Data reference from:COVID-19 Dataset by Our World in Data",
        fontsize=7,ha="left",va="bottom")

fig.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="1200">

# %%
fig.savefig("out/covid-owid-global-vaccinations-daily.png")
