# %%
import pandas as pd

# %%
df = pd.read_csv("covid-19-data/public/data/vaccinations/vaccinations.csv")
df.head()
# Out:
#       location iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG  2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG  2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG  2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG  2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  total_boosters  daily_vaccinations_raw  \
# 0                      NaN             NaN                     NaN
# 1                      NaN             NaN                     NaN
# 2                      NaN             NaN                     NaN
# 3                      NaN             NaN                     NaN
# 4                      NaN             NaN                     NaN
#
#    daily_vaccinations  total_vaccinations_per_hundred  \
# 0                 NaN                             0.0
# 1              1367.0                             NaN
# 2              1367.0                             NaN
# 3              1367.0                             NaN
# 4              1367.0                             NaN
#
#    people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 0                            0.0                                  NaN
# 1                            NaN                                  NaN
# 2                            NaN                                  NaN
# 3                            NaN                                  NaN
# 4                            NaN                                  NaN
#
#    total_boosters_per_hundred  daily_vaccinations_per_million  \
# 0                         NaN                             NaN
# 1                         NaN                            34.0
# 2                         NaN                            34.0
# 3                         NaN                            34.0
# 4                         NaN                            34.0
#
#    daily_people_vaccinated  daily_people_vaccinated_per_hundred
# 0                      NaN                                  NaN
# 1                   1367.0                                0.003
# 2                   1367.0                                0.003
# 3                   1367.0                                0.003
# 4                   1367.0                                0.003

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66146 entries, 0 to 66145
# Data columns (total 16 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   location                             66146 non-null  object
#  1   iso_code                             66146 non-null  object
#  2   date                                 66146 non-null  object
#  3   total_vaccinations                   37489 non-null  float64
#  4   people_vaccinated                    35864 non-null  float64
#  5   people_fully_vaccinated              32906 non-null  float64
#  6   total_boosters                       9058 non-null   float64
#  7   daily_vaccinations_raw               31433 non-null  float64
#  8   daily_vaccinations                   65802 non-null  float64
#  9   total_vaccinations_per_hundred       37489 non-null  float64
#  10  people_vaccinated_per_hundred        35864 non-null  float64
#  11  people_fully_vaccinated_per_hundred  32906 non-null  float64
#  12  total_boosters_per_hundred           9058 non-null   float64
#  13  daily_vaccinations_per_million       65802 non-null  float64
#  14  daily_people_vaccinated              64556 non-null  float64
#  15  daily_people_vaccinated_per_hundred  64556 non-null  float64
# dtypes: float64(13), object(3)
# memory usage: 8.1+ MB

# %%
df.describe()
# Out:
#        total_vaccinations  people_vaccinated  people_fully_vaccinated  \
# count        3.748900e+04       3.586400e+04             3.290600e+04
# mean         1.165495e+08       6.280333e+07             4.454124e+07
# std          5.499106e+08       3.014818e+08             2.262237e+08
# min          0.000000e+00       0.000000e+00             1.000000e+00
# 25%          4.549370e+05       3.159368e+05             1.880788e+05
# 50%          3.249820e+06       2.155348e+06             1.447440e+06
# 75%          1.860536e+07       1.183008e+07             8.222352e+06
# max          8.210434e+09       4.334362e+09             3.496412e+09
#
#        total_boosters  daily_vaccinations_raw  daily_vaccinations  \
# count    9.058000e+03            3.143300e+04        6.580200e+04
# mean     4.344929e+06            1.034780e+06        5.047494e+05
# std      1.730502e+07            4.043484e+06        2.772630e+06
# min      1.000000e+00            0.000000e+00        0.000000e+00
# 25%      1.430000e+02            6.655000e+03        1.146000e+03
# 50%      6.155850e+04            3.678200e+04        9.375000e+03
# 75%      1.317187e+06            2.397810e+05        6.264250e+04
# max      2.720351e+08            5.514737e+07        4.302815e+07
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# count                    37489.000000                   35864.000000
# mean                        57.079665                      32.479621
# std                         53.138047                      27.033348
# min                          0.000000                       0.000000
# 25%                          8.090000                       5.950000
# 50%                         41.540000                      27.660000
# 75%                         99.790000                      57.050000
# max                        297.990000                     121.700000
#
#        people_fully_vaccinated_per_hundred  total_boosters_per_hundred  \
# count                         32906.000000                 9058.000000
# mean                             25.916097                    3.706891
# std                              25.019610                    7.752895
# min                               0.000000                    0.000000
# 25%                               3.070000                    0.000000
# 50%                              17.435000                    0.150000
# 75%                              46.667500                    3.540000
# max                             118.250000                   58.040000
#
#        daily_vaccinations_per_million  daily_people_vaccinated  \
# count                    65802.000000             6.455600e+04
# mean                      3450.746892             2.630687e+05
# std                       4071.012171             2.431023e+06
# min                          0.000000             0.000000e+00
# 25%                        654.000000             5.790000e+02
# 50%                       2291.000000             4.721500e+03
# 75%                       5028.000000             3.150725e+04
# max                     117497.000000             1.005908e+08
#
#        daily_people_vaccinated_per_hundred
# count                         64556.000000
# mean                              0.177153
# std                               0.276863
# min                               0.000000
# 25%                               0.031000
# 50%                               0.095000
# 75%                               0.235000
# max                              11.750000

# %%
df["date"] = pd.to_datetime(df["date"])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66146 entries, 0 to 66145
# Data columns (total 16 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   location                             66146 non-null  object
#  1   iso_code                             66146 non-null  object
#  2   date                                 66146 non-null  datetime64[ns]
#  3   total_vaccinations                   37489 non-null  float64
#  4   people_vaccinated                    35864 non-null  float64
#  5   people_fully_vaccinated              32906 non-null  float64
#  6   total_boosters                       9058 non-null   float64
#  7   daily_vaccinations_raw               31433 non-null  float64
#  8   daily_vaccinations                   65802 non-null  float64
#  9   total_vaccinations_per_hundred       37489 non-null  float64
#  10  people_vaccinated_per_hundred        35864 non-null  float64
#  11  people_fully_vaccinated_per_hundred  32906 non-null  float64
#  12  total_boosters_per_hundred           9058 non-null   float64
#  13  daily_vaccinations_per_million       65802 non-null  float64
#  14  daily_people_vaccinated              64556 non-null  float64
#  15  daily_people_vaccinated_per_hundred  64556 non-null  float64
# dtypes: datetime64[ns](1), float64(13), object(2)
# memory usage: 8.1+ MB

# %%
import datetime
latest_date_str = (df.date.max() - datetime.timedelta(days=1)).strftime("%Y-%m-%d")
latest_date_str
# Out:
# '2021-12-04'

# %% [markdown]
# ## 全世界のデータ

# %%
world_df = df.copy().loc[df.location=="World"]
world_df.tail()
# Out:
#       location  iso_code       date  total_vaccinations  people_vaccinated  \
# 65412    World  OWID_WRL 2021-12-01        8.087953e+09       4.308047e+09
# 65413    World  OWID_WRL 2021-12-02        8.127661e+09       4.318008e+09
# 65414    World  OWID_WRL 2021-12-03        8.154247e+09       4.322711e+09
# 65415    World  OWID_WRL 2021-12-04        8.185032e+09       4.329029e+09
# 65416    World  OWID_WRL 2021-12-05        8.210434e+09       4.334362e+09
#
#        people_fully_vaccinated  total_boosters  daily_vaccinations_raw  \
# 65412             3.453044e+09     256086757.0              42582713.0
# 65413             3.468448e+09     261691538.0              39707716.0
# 65414             3.476826e+09     267815477.0              26586547.0
# 65415             3.487949e+09     270540559.0              30784327.0
# 65416             3.496412e+09     272035138.0              25401936.0
#
#        daily_vaccinations  total_vaccinations_per_hundred  \
# 65412          35323514.0                          102.70
# 65413          36837008.0                          103.21
# 65414          35572233.0                          103.55
# 65415          35680557.0                          103.94
# 65416          33871664.0                          104.26
#
#        people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 65412                          54.71                                43.85
# 65413                          54.83                                44.04
# 65414                          54.89                                44.15
# 65415                          54.97                                44.29
# 65416                          55.04                                44.40
#
#        total_boosters_per_hundred  daily_vaccinations_per_million  \
# 65412                        3.25                          4486.0
# 65413                        3.32                          4678.0
# 65414                        3.40                          4517.0
# 65415                        3.44                          4531.0
# 65416                        3.45                          4301.0
#
#        daily_people_vaccinated  daily_people_vaccinated_per_hundred
# 65412                9286189.0                                0.118
# 65413                9715692.0                                0.123
# 65414                9125063.0                                0.116
# 65415                8970740.0                                0.114
# 65416                8058855.0                                0.102

# %% [markdown]
# ## 国別

# %%
country_df = df.loc[df.iso_code.str.len()==3]
country_df.head()
# Out:
#       location iso_code       date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG 2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG 2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG 2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG 2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG 2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  total_boosters  daily_vaccinations_raw  \
# 0                      NaN             NaN                     NaN
# 1                      NaN             NaN                     NaN
# 2                      NaN             NaN                     NaN
# 3                      NaN             NaN                     NaN
# 4                      NaN             NaN                     NaN
#
#    daily_vaccinations  total_vaccinations_per_hundred  \
# 0                 NaN                             0.0
# 1              1367.0                             NaN
# 2              1367.0                             NaN
# 3              1367.0                             NaN
# 4              1367.0                             NaN
#
#    people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 0                            0.0                                  NaN
# 1                            NaN                                  NaN
# 2                            NaN                                  NaN
# 3                            NaN                                  NaN
# 4                            NaN                                  NaN
#
#    total_boosters_per_hundred  daily_vaccinations_per_million  \
# 0                         NaN                             NaN
# 1                         NaN                            34.0
# 2                         NaN                            34.0
# 3                         NaN                            34.0
# 4                         NaN                            34.0
#
#    daily_people_vaccinated  daily_people_vaccinated_per_hundred
#
# 9524       Bulgaria      BGR 2021-12-04                                26.11
# 61843       Ukraine      UKR 2021-12-04                                27.11
# 27405         India      IND 2021-12-04                                34.02
# 27733     Indonesia      IDN 2021-12-04                                35.83
# 30818        Jordan      JOR 2021-12-04                                36.70
# 48972       Romania      ROU 2021-12-04                                39.25
# 49327        Russia      RUS 2021-12-04                                40.08
# 39606    Montenegro      MNE 2021-12-04                                41.22
# 31127    Kazakhstan      KAZ 2021-12-04                                42.99
# 60317       Tunisia      TUN 2021-12-04                                43.83

# %% [markdown]
# ### 日本

# %%
jp = df.loc[df.location=="Japan"]
jp.tail()
# Out:
#       location iso_code       date  total_vaccinations  people_vaccinated  \
# 30223    Japan      JPN 2021-12-01                 NaN                NaN
# 30224    Japan      JPN 2021-12-02         197423151.0         99861506.0
# 30225    Japan      JPN 2021-12-03                 NaN                NaN
# 30226    Japan      JPN 2021-12-04                 NaN                NaN
# 30227    Japan      JPN 2021-12-05         197620701.0         99926796.0
#
#        people_fully_vaccinated  total_boosters  daily_vaccinations_raw  \
# 30223                      NaN             NaN                     NaN
# 30224               97558098.0             NaN                     NaN
# 30225                      NaN             NaN                     NaN
# 30226                      NaN             NaN                     NaN
# 30227               97685248.0             NaN                     NaN
#
#        daily_vaccinations  total_vaccinations_per_hundred  \
# 30223            129172.0                             NaN
# 30224            120965.0                          156.62
# 30225            114219.0                             NaN
# 30226            107473.0                             NaN
# 30227            100727.0                          156.78
#
#        people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 30223                            NaN                                  NaN
# 30224                          79.22                                 77.4
# 30225                            NaN                                  NaN
# 30226                            NaN                                  NaN
# 30227                          79.28                                 77.5
#
#        total_boosters_per_hundred  daily_vaccinations_per_million  \
# 30223                         NaN                          1025.0
# 30224                         NaN                           960.0
# 30225                         NaN                           906.0
# 30226                         NaN                           853.0
# 30227                         NaN                           799.0
#
#        daily_people_vaccinated  daily_people_vaccinated_per_hundred
# 30223                  31141.0                                0.025
# 30224                  29665.0                                0.024
# 30225                  29327.0                                0.023
# 30226                  28989.0                                0.023
# 30227                  28652.0                                0.023

# %% [markdown]
# ### 英国

# %%
uk = df.loc[df.location=="United Kingdom"]
#uk.append(pd.Series([uk.location.unique()[0],1,latest_date_str]),ignore_index=True).tail()
#uk.append(pd.Series(["UK","GBR",latest_date_str],index=uk.columns),ignore_index=True).tail()
uk.tail()
# Out:
#              location iso_code       date  total_vaccinations  \
# 62484  United Kingdom      GBR 2021-11-30         116001687.0
# 62485  United Kingdom      GBR 2021-12-01         116467922.0
# 62486  United Kingdom      GBR 2021-12-02         116945656.0
# 62487  United Kingdom      GBR 2021-12-03         117369986.0
# 62488  United Kingdom      GBR 2021-12-04         117880359.0
#
#        people_vaccinated  people_fully_vaccinated  total_boosters  \
# 62484         50994257.0               46399306.0      18608124.0
# 62485         51020285.0               46431662.0      19015975.0
# 62486         51046133.0               46462638.0      19436885.0
# 62487         51068961.0               46491583.0      19809442.0
# 62488         51094640.0               46527302.0      20258417.0
#
#        daily_vaccinations_raw  daily_vaccinations  \
# 62484                455285.0            422955.0
# 62485                466235.0            428565.0
# 62486                477734.0            433601.0
# 62487                424330.0            435542.0
# 62488                510373.0            433912.0
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 62484                          170.07                          74.76
# 62485                          170.76                          74.80
# 62486                          171.46                          74.84
# 62487                          172.08                          74.87
# 62488                          172.83                          74.91
#
#        people_fully_vaccinated_per_hundred  total_boosters_per_hundred  \
# 62484                                68.03                       27.28
# 62485                                68.07                       27.88
# 62486                                68.12                       28.50
# 62487                                68.16                       29.04
# 62488                                68.21                       29.70
#
#        daily_vaccinations_per_million  daily_people_vaccinated  \
# 62484                          6201.0                  23815.0
# 62485                          6283.0                  24022.0
# 62486                          6357.0                  24346.0
# 62487                          6386.0                  24705.0
# 62488                          6362.0                  24972.0
#
#        daily_people_vaccinated_per_hundred
# 62484                                0.035
# 62485                                0.035
# 62486                                0.036
# 62487                                0.036
# 62488                                0.037

# %% [markdown]
# ### イラン

# %%
iran = df.loc[df.location=="Iran"]
iran.tail()
# Out:
#       location iso_code       date  total_vaccinations  people_vaccinated  \
# 28030     Iran      IRN 2021-12-01                 NaN                NaN
# 28031     Iran      IRN 2021-12-02                 NaN                NaN
# 28032     Iran      IRN 2021-12-03                 NaN                NaN
# 28033     Iran      IRN 2021-12-04                 NaN                NaN
# 28034     Iran      IRN 2021-12-05         107531771.0         58094169.0
#
#        people_fully_vaccinated  total_boosters  daily_vaccinations_raw  \
# 28030                      NaN             NaN                     NaN
# 28031                      NaN             NaN                     NaN
# 28032                      NaN             NaN                     NaN
# 28033                      NaN             NaN                     NaN
# 28034               48149791.0       1287811.0                     NaN
#
#        daily_vaccinations  total_vaccinations_per_hundred  \
# 28030            368950.0                             NaN
# 28031            366417.0                             NaN
# 28032            363884.0                             NaN
# 28033            361351.0                             NaN
# 28034            392956.0                          126.47
#
#        people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 28030                            NaN                                  NaN
# 28031                            NaN                                  NaN
# 28032                            NaN                                  NaN
# 28033                            NaN                                  NaN
# 28034                          68.32                                56.63
#
#        total_boosters_per_hundred  daily_vaccinations_per_million  \
# 28030                         NaN                          4339.0
# 28031                         NaN                          4309.0
# 28032                         NaN                          4280.0
# 28033                         NaN                          4250.0
# 28034                        1.51                          4621.0
#
#        daily_people_vaccinated  daily_people_vaccinated_per_hundred
# 28030                  99364.0                                0.117
# 28031                  97672.0                                0.115
# 28032                  95980.0                                0.113
# 28033                  94287.0                                0.111
# 28034                 101305.0                                0.119

# %% [markdown]
# ## 可視化

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook
#%matplotlib inline
# Out:
# Duplicate key in file PosixPath('/home/masaru/.pyenv/versions/anaconda3-2021.05/lib/python3.8/site-packages/matplotlib/mpl-data/matplotlibrc'), line 250 ('font.family:  Noto Sans CJK JP')

# %%
fig=plt.figure(figsize=(14,8))
ax1 = plt.subplot(1,2,1) # (rows, columns, panel number)
plt.title("Daily COVID-19 vacctinated in the world")
ax1.set_zorder(2)
ax1.patch.set_alpha(0)
plt.ylim(0,100)
plt.ylabel("vaccination %")
ax1.grid()
plt.xticks(rotation=70)
ax2 = plt.twinx()
ax2.set_zorder(1)
plt.ylabel("million people")
ax1.plot_date(world_df["date"],world_df["people_vaccinated_per_hundred"],label="Vaccinated at least once per population", fmt="-")
ax1.plot_date(world_df["date"],world_df["people_fully_vaccinated_per_hundred"],label="Fully vaccinated per population", fmt="-")
ax1.plot_date(jp["date"],jp["people_vaccinated_per_hundred"],label="Vaccinated at least once per population in Japan", fmt="-")
ax1.plot_date(jp["date"],jp["people_fully_vaccinated_per_hundred"],label="Fully vaccinated per population in Japan", fmt="-")
#ax1.plot_date(uk["date"],jp["people_vaccinated_per_hundred"],label="Vaccinated at least once per population in UK", fmt="-")
#ax1.plot_date(uk["date"],jp["people_fully_vaccinated_per_hundred"],label="Fully vaccinated per population in UK", fmt="-")
ax2.bar(world_df["date"],world_df["people_vaccinated"]/1000/1000,label="People vaccinated at least once", color="pink")
ax2.bar(world_df["date"],world_df["people_fully_vaccinated"]/1000/1000,label="People fully vaccinated", color="lightgray",zorder=1)
#plt.grid(axis="y")
h1,l1 = ax1.get_legend_handles_labels()
h2,l2 = ax2.get_legend_handles_labels()
plt.legend(h1+h2,l1+l2)

# fully vactinated
ax1 = plt.subplot(1,2,2) # (rows, columns, panel number)
plt.title("Daily COVID-19 fully vacctinated per population Top 50")
plt.ylabel("vaccination %")
plt.grid(axis="x")
plt.yticks(fontsize=9)
plt.xticks(rotation=70)
plt.xlim(0,100)
chart_data=latest_df.copy().sort_values(by="people_fully_vaccinated_per_hundred",ascending=False).head(50)
chart_data=chart_data.sort_values(by="people_fully_vaccinated_per_hundred",ascending=True)
plt.barh(chart_data["location"],chart_data["people_fully_vaccinated_per_hundred"],label="People fully vaccinated")
#plt.grid(axis="y")
#h1,l1 = ax1.get_legend_handles_labels()
#h2,l2 = ax2.get_legend_handles_labels()
#plt.legend(h1+h2,l1+l2)

"""
plt.subplot(2,2,2) # (rows, columns, panel number)
plt.title("Daily new confirmed COVID-19 cases in the world(after 2021 Apr 1st)")
chart_data = world_df[world_df.date >= "2021-04-01"]
plt.bar(chart_data["date"],chart_data["new_cases"],label="New deaths")
plt.plot_date(chart_data["date"],chart_data["new_cases_smoothed"],label="rolling 7-day average", fmt="-", color="orange")
plt.xticks(rotation=70)
plt.grid(axis="y")
plt.legend()

plt.subplot(2,2,3) # (rows, columns, panel number)
plt.title("Daily new deaths in the world")
plt.bar(world_df.date,world_df.new_deaths,label="New cases")
plt.plot_date(world_df["date"],world_df["new_deaths_smoothed"],label="rolling 7-day average", fmt="-", color="orange")
plt.xticks(rotation=70)
plt.ylabel("people")
plt.grid(axis="y")
plt.legend()

plt.subplot(2,2,4) # (rows, columns, panel number)
plt.title("Daily new deaths in the world(after 2021 Apr 1st)")
chart_data = world_df[world_df.date >= "2021-04-01"]
plt.bar(chart_data["date"],chart_data["new_deaths"],label="New deaths")
plt.plot_date(chart_data["date"],chart_data["new_deaths_smoothed"],label="rolling 7-day average", fmt="-", color="orange")
plt.xticks(rotation=70)
plt.grid(axis="y")
plt.legend()
"""

fig.text(0,1,"Latest: {}".format(latest_date_str),fontsize=8,ha="left",va="top")
fig.text(0,0
         ,"*Data reference from:COVID-19 Dataset by Our World in Data",
        fontsize=7,ha="left",va="bottom")

fig.tight_layout()
# Out:
# <div id='53fd96e3-5e89-4edd-b6fe-f20813883623'></div>

# %%
fig.savefig("out/covid-owid-global-vaccinations-daily.png")
