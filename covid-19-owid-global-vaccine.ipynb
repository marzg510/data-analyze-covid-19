# %%
import pandas as pd

# %%
df = pd.read_csv("covid-19-data/public/data/vaccinations/vaccinations.csv")
df.head()
# Out:
#       location iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG  2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG  2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG  2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG  2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  total_boosters  daily_vaccinations_raw  \
# 0                      NaN             NaN                     NaN
# 1                      NaN             NaN                     NaN
# 2                      NaN             NaN                     NaN
# 3                      NaN             NaN                     NaN
# 4                      NaN             NaN                     NaN
#
#    daily_vaccinations  total_vaccinations_per_hundred  \
# 0                 NaN                             0.0
# 1              1367.0                             NaN
# 2              1367.0                             NaN
# 3              1367.0                             NaN
# 4              1367.0                             NaN
#
#    people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 0                            0.0                                  NaN
# 1                            NaN                                  NaN
# 2                            NaN                                  NaN
# 3                            NaN                                  NaN
# 4                            NaN                                  NaN
#
#    total_boosters_per_hundred  daily_vaccinations_per_million  \
# 0                         NaN                             NaN
# 1                         NaN                            34.0
# 2                         NaN                            34.0
# 3                         NaN                            34.0
# 4                         NaN                            34.0
#
#    daily_people_vaccinated  daily_people_vaccinated_per_hundred
# 0                      NaN                                  NaN
# 1                   1367.0                                0.003
# 2                   1367.0                                0.003
# 3                   1367.0                                0.003
# 4                   1367.0                                0.003

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104612 entries, 0 to 104611
# Data columns (total 16 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   location                             104612 non-null  object
#  1   iso_code                             104612 non-null  object
#  2   date                                 104612 non-null  object
#  3   total_vaccinations                   53688 non-null   float64
#  4   people_vaccinated                    51245 non-null   float64
#  5   people_fully_vaccinated              48694 non-null   float64
#  6   total_boosters                       24734 non-null   float64
#  7   daily_vaccinations_raw               44295 non-null   float64
#  8   daily_vaccinations                   104190 non-null  float64
#  9   total_vaccinations_per_hundred       53688 non-null   float64
#  10  people_vaccinated_per_hundred        51245 non-null   float64
#  11  people_fully_vaccinated_per_hundred  48694 non-null   float64
#  12  total_boosters_per_hundred           24734 non-null   float64
#  13  daily_vaccinations_per_million       104190 non-null  float64
#  14  daily_people_vaccinated              103183 non-null  float64
#  15  daily_people_vaccinated_per_hundred  103183 non-null  float64
# dtypes: float64(13), object(3)
# memory usage: 12.8+ MB

# %%
df.describe()
# Out:
#        total_vaccinations  people_vaccinated  people_fully_vaccinated  \
# count        5.368800e+04       5.124500e+04             4.869400e+04
# mean         2.141219e+08       1.044069e+08             8.631250e+07
# std          9.387113e+08       4.567649e+08             3.928740e+08
# min          0.000000e+00       0.000000e+00             1.000000e+00
# 25%          8.416350e+05       4.964570e+05             3.970282e+05
# 50%          6.481965e+06       3.823116e+06             3.020874e+06
# 75%          4.068485e+07       2.238821e+07             1.864643e+07
# max          1.180513e+10       5.182451e+09             4.720838e+09
#
#        total_boosters  daily_vaccinations_raw  daily_vaccinations  \
# count    2.473400e+04            4.429500e+04        1.041900e+05
# mean     3.519066e+07            1.042641e+06        4.610243e+05
# std      1.574526e+08            3.941586e+06        2.579027e+06
# min      1.000000e+00            0.000000e+00        0.000000e+00
# 25%      2.842550e+04            5.631000e+03        8.910000e+02
# 50%      1.048338e+06            3.732700e+04        8.155500e+03
# 75%      8.011938e+06            2.645505e+05        5.759650e+04
# max      1.966632e+09            4.967084e+07        4.368584e+07
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# count                    53688.000000                   51245.000000
# mean                        86.814475                      42.898100
# std                         71.646459                      29.750903
# min                          0.000000                       0.000000
# 25%                         18.090000                      12.450000
# 50%                         76.695000                      45.890000
# 75%                        142.692500                      69.920000
# max                        355.750000                     124.880000
#
#        people_fully_vaccinated_per_hundred  total_boosters_per_hundred  \
# count                         48694.000000                24734.000000
# mean                             37.408658                   18.809822
# std                              28.879757                   21.533904
# min                               0.000000                    0.000000
# 25%                               7.640000                    0.170000
# 50%                              36.360000                    8.490000
# 75%                              64.030000                   34.410000
# max                             122.940000                  109.570000
#
#        daily_vaccinations_per_million  daily_people_vaccinated  \
# count                   104190.000000             1.031830e+05
# mean                      3010.100864             1.800812e+05
# std                       3790.822545             1.062840e+06
# min                          0.000000             0.000000e+00
# 25%                        521.000000             3.020000e+02
# 50%                       1794.000000             3.081000e+03
# 75%                       4268.000000             2.173000e+04
# max                     117497.000000             2.106750e+07
#
#        daily_people_vaccinated_per_hundred
# count                        103183.000000
# mean                              0.129442
# std                               0.229572
# min                               0.000000
# 25%                               0.016000
# 50%                               0.057000
# 75%                               0.160000
# max                              11.750000

# %%
df["date"] = pd.to_datetime(df["date"])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104612 entries, 0 to 104611
# Data columns (total 16 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   location                             104612 non-null  object
#  1   iso_code                             104612 non-null  object
#  2   date                                 104612 non-null  datetime64[ns]
#  3   total_vaccinations                   53688 non-null   float64
#  4   people_vaccinated                    51245 non-null   float64
#  5   people_fully_vaccinated              48694 non-null   float64
#  6   total_boosters                       24734 non-null   float64
#  7   daily_vaccinations_raw               44295 non-null   float64
#  8   daily_vaccinations                   104190 non-null  float64
#  9   total_vaccinations_per_hundred       53688 non-null   float64
#  10  people_vaccinated_per_hundred        51245 non-null   float64
#  11  people_fully_vaccinated_per_hundred  48694 non-null   float64
#  12  total_boosters_per_hundred           24734 non-null   float64
#  13  daily_vaccinations_per_million       104190 non-null  float64
#  14  daily_people_vaccinated              103183 non-null  float64
#  15  daily_people_vaccinated_per_hundred  103183 non-null  float64
# dtypes: datetime64[ns](1), float64(13), object(2)
# memory usage: 12.8+ MB

# %%
import datetime
latest_date_str = (df.date.max() - datetime.timedelta(days=1)).strftime("%Y-%m-%d")
latest_date_str
# Out:
# '2022-05-25'

# %% [markdown]
# ## 全世界のデータ

# %%
world_df = df.copy().loc[df.location=="World"]
world_df.tail()
# Out:
#        location  iso_code       date  total_vaccinations  people_vaccinated  \
# 103360    World  OWID_WRL 2022-05-22        1.178178e+10       5.179291e+09
# 103361    World  OWID_WRL 2022-05-23        1.179079e+10       5.180210e+09
# 103362    World  OWID_WRL 2022-05-24        1.179671e+10       5.180971e+09
# 103363    World  OWID_WRL 2022-05-25        1.180091e+10       5.181536e+09
# 103364    World  OWID_WRL 2022-05-26        1.180513e+10       5.182451e+09
#
#         people_fully_vaccinated  total_boosters  daily_vaccinations_raw  \
# 103360             4.714260e+09    1.960032e+09                     NaN
# 103361             4.716152e+09    1.961500e+09                     NaN
# 103362             4.717825e+09    1.963703e+09                     NaN
# 103363             4.719175e+09    1.964886e+09                     NaN
# 103364             4.720838e+09    1.966632e+09                     NaN
#
#         daily_vaccinations  total_vaccinations_per_hundred  \
# 103360                 NaN                          149.61
# 103361                 NaN                          149.72
# 103362                 NaN                          149.80
# 103363                 NaN                          149.85
# 103364                 NaN                          149.91
#
#         people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 103360                          65.77                                59.86
# 103361                          65.78                                59.89
# 103362                          65.79                                59.91
# 103363                          65.80                                59.93
# 103364                          65.81                                59.95
#
#         total_boosters_per_hundred  daily_vaccinations_per_million  \
# 103360                       24.89                             NaN
# 103361                       24.91                             NaN
# 103362                       24.94                             NaN
# 103363                       24.95                             NaN
# 103364                       24.97                             NaN
#
#         daily_people_vaccinated  daily_people_vaccinated_per_hundred
# 103360                      NaN                                  NaN
# 103361                      NaN                                  NaN
# 103362                      NaN                                  NaN
# 103363                      NaN                                  NaN
# 103364                      NaN                                  NaN

# %% [markdown]
# ## 国別

# %%
country_df = df.loc[df.iso_code.str.len()==3]
country_df.head()
# Out:
#       location iso_code       date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG 2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG 2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG 2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG 2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG 2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  total_boosters  daily_vaccinations_raw  \
# 0                      NaN             NaN                     NaN
# 1                      NaN             NaN                     NaN
# 2                      NaN             NaN                     NaN
# 3                      NaN             NaN                     NaN
# 4                      NaN             NaN                     NaN
#
#    daily_vaccinations  total_vaccinations_per_hundred  \
# 0                 NaN                             0.0
# 1              1367.0                             NaN
# 2              1367.0                             NaN
# 3              1367.0                             NaN
# 4              1367.0                             NaN
#
#    people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 0                            0.0                                  NaN
# 1                            NaN                                  NaN
# 2                            NaN                                  NaN
# 3                            NaN                                  NaN
# 4                            NaN                                  NaN
#
#    total_boosters_per_hundred  daily_vaccinations_per_million  \
# 0                         NaN                             NaN
# 1                         NaN                            34.0
# 2                         NaN                            34.0
# 3                         NaN                            34.0
# 4                         NaN                            34.0
#
#    daily_people_vaccinated  daily_people_vaccinated_per_hundred
# 0                      NaN                                  NaN
# 1                   1367.0                                0.003
# 2                   1367.0                                0.003
# 3                   1367.0                                0.003
# 4                   1367.0                                0.003

# %%
latest_df = country_df.loc[country_df.date==latest_date_str]
latest_df.head()
# Out:
#         location iso_code       date  total_vaccinations  people_vaccinated  \
# 4203   Argentina      ARG 2022-05-25         101922843.0         41089772.0
# 5009       Aruba      ABW 2022-05-25            171064.0            88772.0
# 5996   Australia      AUS 2022-05-25          57574701.0         22312642.0
# 8866    Barbados      BRB 2022-05-25            315016.0           162312.0
# 13517     Brazil      BRA 2022-05-25                 NaN                NaN
#
#        people_fully_vaccinated  total_boosters  daily_vaccinations_raw  \
# 4203                37415280.0      23732328.0                     7.0
# 5009                   82292.0             NaN                    47.0
# 5996                21600827.0      13661232.0                 13897.0
# 8866                  152704.0             NaN                    45.0
# 13517                      NaN             NaN                     NaN
#
#        daily_vaccinations  total_vaccinations_per_hundred  \
# 4203             123651.0                          223.49
# 5009                 30.0                          159.58
# 5996              12226.0                          223.26
# 8866                 47.0                          109.49
# 13517            317619.0                             NaN
#
#        people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 4203                           90.10                                82.04
# 5009                           82.81                                76.77
# 5996                           86.52                                83.76
# 8866                           56.42                                53.08
# 13517                            NaN                                  NaN
#
#        total_boosters_per_hundred  daily_vaccinations_per_million  \
# 4203                        52.04                          2711.0
# 5009                          NaN                           280.0
# 5996                        52.97                           474.0
# 8866                          NaN                           163.0
# 13517                         NaN                          1484.0
#
#        daily_people_vaccinated  daily_people_vaccinated_per_hundred
# 4203                    1735.0                                0.004
# 5009                      16.0                                0.015
# 5996                    1297.0                                0.005
# 8866                      20.0                                0.007
# 13517                  57903.0                                0.027

# %% [markdown]
# ### ワクチン接種完了率トップ20

# %%
latest_df.sort_values(by="people_fully_vaccinated_per_hundred",ascending=False).head(20)[["location","iso_code","date","people_fully_vaccinated_per_hundred"]]
# Out:
#                     location iso_code       date  \
# 98330   United Arab Emirates      ARE 2022-05-25
# 18958                  Chile      CHL 2022-05-25
# 59317                  Malta      MLT 2022-05-25
# 56683                  Macao      MAC 2022-05-25
# 87797            South Korea      KOR 2022-05-25
# 5996               Australia      AUS 2022-05-25
# 100335               Uruguay      URY 2022-05-25
# 57941               Malaysia      MYS 2022-05-25
# 4203               Argentina      ARG 2022-05-25
# 47514                  Japan      JPN 2022-05-25
# 101923               Vietnam      VNM 2022-05-25
# 46607                  Italy      ITA 2022-05-25
# 91958                 Taiwan      TWN 2022-05-25
# 33214                 France      FRA 2022-05-25
# 32699                Finland      FIN 2022-05-25
# 35509                Germany      DEU 2022-05-25
# 5009                   Aruba      ABW 2022-05-25
# 93067               Thailand      THA 2022-05-25
# 70886                 Norway      NOR 2022-05-25
# 36938                 Greece      GRC 2022-05-25
#
#         people_fully_vaccinated_per_hundred
# 98330                                 97.01
# 18958                                 91.16
# 59317                                 90.89
# 56683                                 87.27
# 87797                                 86.88
# 5996                                  83.76
# 100335                                82.47
# 57941                                 82.45
# 4203                                  82.04
# 47514                                 80.90
# 101923                                80.39
# 46607                                 79.40
# 91958                                 79.35
# 33214                                 78.33
# 32699                                 78.00
# 35509                                 76.87
# 5009                                  76.77
# 93067                                 74.72
# 70886                                 73.89
# 36938                                 73.51

# %% [markdown]
# ### ワクチン接種完了率ワースト20

# %%
latest_df.sort_values(by="people_fully_vaccinated_per_hundred",ascending=True).head(20)[["location","iso_code","date","people_fully_vaccinated_per_hundred"]]
# Out:
#                   location iso_code       date  \
# 51087           Kyrgyzstan      KGZ 2022-05-25
# 47051              Jamaica      JAM 2022-05-25
# 14803             Bulgaria      BGR 2022-05-25
# 86823         South Africa      ZAF 2022-05-25
# 77164              Romania      ROU 2022-05-25
# 62408           Montenegro      MNE 2022-05-25
# 82697               Serbia      SRB 2022-05-25
# 48923           Kazakhstan      KAZ 2022-05-25
# 77691               Russia      RUS 2022-05-25
# 94871  Trinidad and Tobago      TTO 2022-05-25
# 8866              Barbados      BRB 2022-05-25
# 26602   Dominican Republic      DOM 2022-05-25
# 72348             Pakistan      PAK 2022-05-25
# 22529              Croatia      HRV 2022-05-25
# 85534             Slovenia      SVN 2022-05-25
# 75630               Poland      POL 2022-05-25
# 23330              Curacao      CUW 2022-05-25
# 43695            Indonesia      IDN 2022-05-25
# 95802               Turkey      TUR 2022-05-25
# 43195                India      IND 2022-05-25
#
#        people_fully_vaccinated_per_hundred
# 51087                                19.59
# 47051                                23.42
# 14803                                29.85
# 86823                                31.13
# 77164                                42.39
# 62408                                45.09
# 82697                                47.68
# 48923                                48.82
# 77691                                50.50
# 94871                                50.76
# 8866                                 53.08
# 26602                                54.57
# 72348                                54.63
# 22529                                54.97
# 85534                                58.78
# 75630                                59.51
# 23330                                60.23
# 43695                                60.45
# 95802                                62.39
# 43195                                63.42

# %% [markdown]
# ### 日本

# %%
jp = df.loc[df.location=="Japan"]
jp.tail()
# Out:
#       location iso_code       date  total_vaccinations  people_vaccinated  \
# 47510    Japan      JPN 2022-05-21         278768356.0        103495512.0
# 47511    Japan      JPN 2022-05-22         278912853.0        103501234.0
# 47512    Japan      JPN 2022-05-23         279037264.0        103507177.0
# 47513    Japan      JPN 2022-05-24         279140162.0        103512289.0
# 47514    Japan      JPN 2022-05-25         279218860.0        103516276.0
#
#        people_fully_vaccinated  total_boosters  daily_vaccinations_raw  \
# 47510              101961039.0      73311805.0                430351.0
# 47511              101969556.0      73442063.0                144497.0
# 47512              101975203.0      73554884.0                124411.0
# 47513              101977243.0      73650630.0                102898.0
# 47514              101978653.0      73723931.0                 78698.0
#
#        daily_vaccinations  total_vaccinations_per_hundred  \
# 47510            244658.0                          221.16
# 47511            235217.0                          221.27
# 47512            226149.0                          221.37
# 47513            214631.0                          221.45
# 47514            201315.0                          221.51
#
#        people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 47510                          82.11                                80.89
# 47511                          82.11                                80.90
# 47512                          82.12                                80.90
# 47513                          82.12                                80.90
# 47514                          82.12                                80.90
#
#        total_boosters_per_hundred  daily_vaccinations_per_million  \
# 47510                       58.16                          1941.0
# 47511                       58.26                          1866.0
# 47512                       58.35                          1794.0
# 47513                       58.43                          1703.0
# 47514                       58.49                          1597.0
#
#        daily_people_vaccinated  daily_people_vaccinated_per_hundred
# 47510                   9370.0                                0.007
# 47511                   9030.0                                0.007
# 47512                   8941.0                                0.007
# 47513                   8747.0                                0.007
# 47514                   8445.0                                0.007

# %% [markdown]
# ### 英国

# %%
uk = df.loc[df.location=="United Kingdom"]
#uk.append(pd.Series([uk.location.unique()[0],1,latest_date_str]),ignore_index=True).tail()
#uk.append(pd.Series(["UK","GBR",latest_date_str],index=uk.columns),ignore_index=True).tail()
uk.tail()
# Out:
#              location iso_code       date  total_vaccinations  \
# 98821  United Kingdom      GBR 2022-05-14         142772518.0
# 98822  United Kingdom      GBR 2022-05-15         142796436.0
# 98823  United Kingdom      GBR 2022-05-16         142822424.0
# 98824  United Kingdom      GBR 2022-05-17         142851106.0
# 98825  United Kingdom      GBR 2022-05-18         142879403.0
#
#        people_vaccinated  people_fully_vaccinated  total_boosters  \
# 98821         53372858.0               49872067.0      39527593.0
# 98822         53382948.0               49877776.0      39535712.0
# 98823         53387722.0               49883377.0      39551325.0
# 98824         53393153.0               49889298.0      39568655.0
# 98825         53398518.0               49895254.0      39585631.0
#
#        daily_vaccinations_raw  daily_vaccinations  \
# 98821                 49184.0             35131.0
# 98822                 23918.0             34697.0
# 98823                 25988.0             33871.0
# 98824                 28682.0             32930.0
# 98825                 28297.0             31827.0
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 98821                          209.32                          78.25
# 98822                          209.36                          78.27
# 98823                          209.40                          78.27
# 98824                          209.44                          78.28
# 98825                          209.48                          78.29
#
#        people_fully_vaccinated_per_hundred  total_boosters_per_hundred  \
# 98821                                73.12                       57.95
# 98822                                73.13                       57.96
# 98823                                73.14                       57.99
# 98824                                73.14                       58.01
# 98825                                73.15                       58.04
#
#        daily_vaccinations_per_million  daily_people_vaccinated  \
# 98821                           515.0                   9437.0
# 98822                           509.0                   9355.0
# 98823                           497.0                   9193.0
# 98824                           483.0                   8937.0
# 98825                           467.0                   8732.0
#
#        daily_people_vaccinated_per_hundred
# 98821                                0.014
# 98822                                0.014
# 98823                                0.013
# 98824                                0.013
# 98825                                0.013

# %% [markdown]
# ### イラン

# %%
iran = df.loc[df.location=="Iran"]
iran.tail()
# Out:
#       location iso_code       date  total_vaccinations  people_vaccinated  \
# 44164     Iran      IRN 2022-05-21         149661505.0         64479119.0
# 44165     Iran      IRN 2022-05-22         149698995.0         64487631.0
# 44166     Iran      IRN 2022-05-23         149729751.0         64494842.0
# 44167     Iran      IRN 2022-05-24         149765193.0         64502622.0
# 44168     Iran      IRN 2022-05-25         149796958.0         64509636.0
#
#        people_fully_vaccinated  total_boosters  daily_vaccinations_raw  \
# 44164               57770615.0      27411771.0                 33984.0
# 44165               57781757.0      27429607.0                 37490.0
# 44166               57790865.0      27444044.0                 30756.0
# 44167               57801487.0      27461084.0                 35442.0
# 44168               57810690.0      27476632.0                 31765.0
#
#        daily_vaccinations  total_vaccinations_per_hundred  \
# 44164             31862.0                          176.01
# 44165             31984.0                          176.06
# 44166             30960.0                          176.09
# 44167             30605.0                          176.13
# 44168             29725.0                          176.17
#
#        people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 44164                          75.83                                67.94
# 44165                          75.84                                67.96
# 44166                          75.85                                67.97
# 44167                          75.86                                67.98
# 44168                          75.87                                67.99
#
#        total_boosters_per_hundred  daily_vaccinations_per_million  \
# 44164                       32.24                           375.0
# 44165                       32.26                           376.0
# 44166                       32.28                           364.0
# 44167                       32.30                           360.0
# 44168                       32.31                           350.0
#
#        daily_people_vaccinated  daily_people_vaccinated_per_hundred
# 44164                   6692.0                                0.008
# 44165                   6795.0                                0.008
# 44166                   6664.0                                0.008
# 44167                   6615.0                                0.008
# 44168                   6456.0                                0.008

# %% [markdown]
# ## 可視化

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook
#%matplotlib inline

# %%
fig=plt.figure(figsize=(14,8))
ax1 = plt.subplot(1,2,1) # (rows, columns, panel number)
plt.title("Daily COVID-19 vacctinated in the world")
ax1.set_zorder(2)
ax1.patch.set_alpha(0)
plt.ylim(0,100)
plt.ylabel("vaccination %")
ax1.grid()
plt.xticks(rotation=70)
ax2 = plt.twinx()
ax2.set_zorder(1)
plt.ylabel("million people")
ax1.plot_date(world_df["date"],world_df["people_vaccinated_per_hundred"],label="Vaccinated at least once per population", fmt="-")
ax1.plot_date(world_df["date"],world_df["people_fully_vaccinated_per_hundred"],label="Fully vaccinated per population", fmt="-")
ax1.plot_date(jp["date"],jp["people_vaccinated_per_hundred"],label="Vaccinated at least once per population in Japan", fmt="-")
ax1.plot_date(jp["date"],jp["people_fully_vaccinated_per_hundred"],label="Fully vaccinated per population in Japan", fmt="-")
#ax1.plot_date(uk["date"],jp["people_vaccinated_per_hundred"],label="Vaccinated at least once per population in UK", fmt="-")
#ax1.plot_date(uk["date"],jp["people_fully_vaccinated_per_hundred"],label="Fully vaccinated per population in UK", fmt="-")
ax2.bar(world_df["date"],world_df["people_vaccinated"]/1000/1000,label="People vaccinated at least once", color="pink")
ax2.bar(world_df["date"],world_df["people_fully_vaccinated"]/1000/1000,label="People fully vaccinated", color="lightgray",zorder=1)
#plt.grid(axis="y")
h1,l1 = ax1.get_legend_handles_labels()
h2,l2 = ax2.get_legend_handles_labels()
plt.legend(h1+h2,l1+l2)

# fully vactinated
ax1 = plt.subplot(1,2,2) # (rows, columns, panel number)
plt.title("Daily COVID-19 fully vacctinated per population Top 50")
plt.ylabel("vaccination %")
plt.grid(axis="x")
plt.yticks(fontsize=9)
plt.xticks(rotation=70)
plt.xlim(0,100)
chart_data=latest_df.copy().sort_values(by="people_fully_vaccinated_per_hundred",ascending=False).head(50)
chart_data=chart_data.sort_values(by="people_fully_vaccinated_per_hundred",ascending=True)
plt.barh(chart_data["location"],chart_data["people_fully_vaccinated_per_hundred"],label="People fully vaccinated")
#plt.grid(axis="y")
#h1,l1 = ax1.get_legend_handles_labels()
#h2,l2 = ax2.get_legend_handles_labels()
#plt.legend(h1+h2,l1+l2)

"""
plt.subplot(2,2,2) # (rows, columns, panel number)
plt.title("Daily new confirmed COVID-19 cases in the world(after 2021 Apr 1st)")
chart_data = world_df[world_df.date >= "2021-04-01"]
plt.bar(chart_data["date"],chart_data["new_cases"],label="New deaths")
plt.plot_date(chart_data["date"],chart_data["new_cases_smoothed"],label="rolling 7-day average", fmt="-", color="orange")
plt.xticks(rotation=70)
plt.grid(axis="y")
plt.legend()

plt.subplot(2,2,3) # (rows, columns, panel number)
plt.title("Daily new deaths in the world")
plt.bar(world_df.date,world_df.new_deaths,label="New cases")
plt.plot_date(world_df["date"],world_df["new_deaths_smoothed"],label="rolling 7-day average", fmt="-", color="orange")
plt.xticks(rotation=70)
plt.ylabel("people")
plt.grid(axis="y")
plt.legend()

plt.subplot(2,2,4) # (rows, columns, panel number)
plt.title("Daily new deaths in the world(after 2021 Apr 1st)")
chart_data = world_df[world_df.date >= "2021-04-01"]
plt.bar(chart_data["date"],chart_data["new_deaths"],label="New deaths")
plt.plot_date(chart_data["date"],chart_data["new_deaths_smoothed"],label="rolling 7-day average", fmt="-", color="orange")
plt.xticks(rotation=70)
plt.grid(axis="y")
plt.legend()
"""

fig.text(0,1,"Latest: {}".format(latest_date_str),fontsize=8,ha="left",va="top")
fig.text(0,0
         ,"*Data reference from:COVID-19 Dataset by Our World in Data",
        fontsize=7,ha="left",va="bottom")

fig.tight_layout()
# Out:
# <div id='626f0519-da2b-478a-bccb-5e191894fc63'></div>

# %%
fig.savefig("out/covid-owid-global-vaccinations-daily.png")
