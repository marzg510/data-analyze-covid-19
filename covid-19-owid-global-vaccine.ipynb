# %%
import pandas as pd

# %%
df = pd.read_csv("covid-19-data/public/data/vaccinations/vaccinations.csv")
df.head()
# Out:
#       location iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG  2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG  2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG  2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG  2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN              1367.0
# 2                      NaN                     NaN              1367.0
# 3                      NaN                     NaN              1367.0
# 4                      NaN                     NaN              1367.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                             0.0                            0.0
# 1                             NaN                            NaN
# 2                             NaN                            NaN
# 3                             NaN                            NaN
# 4                             NaN                            NaN
#
#    people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# 0                                  NaN                             NaN
# 1                                  NaN                            35.0
# 2                                  NaN                            35.0
# 3                                  NaN                            35.0
# 4                                  NaN                            35.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29889 entries, 0 to 29888
# Data columns (total 12 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   location                             29889 non-null  object
#  1   iso_code                             29889 non-null  object
#  2   date                                 29889 non-null  object
#  3   total_vaccinations                   17641 non-null  float64
#  4   people_vaccinated                    16843 non-null  float64
#  5   people_fully_vaccinated              13839 non-null  float64
#  6   daily_vaccinations_raw               14915 non-null  float64
#  7   daily_vaccinations                   29607 non-null  float64
#  8   total_vaccinations_per_hundred       17641 non-null  float64
#  9   people_vaccinated_per_hundred        16843 non-null  float64
#  10  people_fully_vaccinated_per_hundred  13839 non-null  float64
#  11  daily_vaccinations_per_million       29607 non-null  float64
# dtypes: float64(9), object(3)
# memory usage: 2.7+ MB

# %%
df.describe()
# Out:
#        total_vaccinations  people_vaccinated  people_fully_vaccinated  \
# count        1.764100e+04       1.684300e+04             1.383900e+04
# mean         3.735706e+07       2.095626e+07             1.151837e+07
# std          1.705551e+08       9.561494e+07             4.906201e+07
# min          0.000000e+00       0.000000e+00             1.000000e+00
# 25%          1.382640e+05       1.114270e+05             5.254700e+04
# 50%          1.066860e+06       7.582750e+05             4.343010e+05
# 75%          6.578881e+06       4.380701e+06             2.570570e+06
# max          3.001137e+09       1.806865e+09             8.338254e+08
#
#        daily_vaccinations_raw  daily_vaccinations  \
# count            1.491500e+04        2.960700e+04
# mean             8.117367e+05        4.036105e+05
# std              3.349222e+06        2.292802e+06
# min              0.000000e+00        0.000000e+00
# 25%              5.405000e+03        9.535000e+02
# 50%              2.898900e+04        8.025000e+03
# 75%              1.713655e+05        4.863600e+04
# max              4.739749e+07        4.258012e+07
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# count                    17641.000000                   16843.000000
# mean                        24.235090                      16.050292
# std                         30.892795                      18.830660
# min                          0.000000                       0.000000
# 25%                          2.210000                       1.830000
# 50%                         11.230000                       8.060000
# 75%                         34.900000                      24.690000
# max                        231.660000                     116.380000
#
#        people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# count                         13839.000000                    29607.000000
# mean                              9.682328                     3248.387611
# std                              13.563547                     4377.167704
# min                               0.000000                        0.000000
# 25%                               0.850000                      379.000000
# 50%                               3.910000                     1714.000000
# 75%                              12.660000                     4817.000000
# max                             115.270000                   118759.000000

# %%
df["date"] = pd.to_datetime(df["date"])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29889 entries, 0 to 29888
# Data columns (total 12 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   location                             29889 non-null  object
#  1   iso_code                             29889 non-null  object
#  2   date                                 29889 non-null  datetime64[ns]
#  3   total_vaccinations                   17641 non-null  float64
#  4   people_vaccinated                    16843 non-null  float64
#  5   people_fully_vaccinated              13839 non-null  float64
#  6   daily_vaccinations_raw               14915 non-null  float64
#  7   daily_vaccinations                   29607 non-null  float64
#  8   total_vaccinations_per_hundred       17641 non-null  float64
#  9   people_vaccinated_per_hundred        16843 non-null  float64
#  10  people_fully_vaccinated_per_hundred  13839 non-null  float64
#  11  daily_vaccinations_per_million       29607 non-null  float64
# dtypes: datetime64[ns](1), float64(9), object(2)
# memory usage: 2.7+ MB

# %%
latest_date_str = df.date.max().strftime("%Y-%m-%d")
latest_date_str
# Out:
# '2021-06-28'

# %% [markdown]
# ## 全世界のデータ

# %%
world_df = df.copy().loc[df.location=="World"]
world_df.tail()
# Out:
#       location  iso_code       date  total_vaccinations  people_vaccinated  \
# 29629    World  OWID_WRL 2021-06-24        2.846234e+09       1.762834e+09
# 29630    World  OWID_WRL 2021-06-25        2.889816e+09       1.775780e+09
# 29631    World  OWID_WRL 2021-06-26        2.929432e+09       1.787844e+09
# 29632    World  OWID_WRL 2021-06-27        2.967484e+09       1.799237e+09
# 29633    World  OWID_WRL 2021-06-28        3.001137e+09       1.806865e+09
#
#        people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 29629              809716846.0              47397494.0          41978456.0
# 29630              816507178.0              43582795.0          41960623.0
# 29631              822526174.0              39615451.0          42375404.0
# 29632              828793566.0              38051657.0          42580121.0
# 29633              833825402.0              33653029.0          41255949.0
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 29629                           36.51                          22.62
# 29630                           37.07                          22.78
# 29631                           37.58                          22.94
# 29632                           38.07                          23.08
# 29633                           38.50                          23.18
#
#        people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# 29629                                10.39                          5385.0
# 29630                                10.48                          5383.0
# 29631                                10.55                          5436.0
# 29632                                10.63                          5463.0
# 29633                                10.70                          5293.0

# %% [markdown]
# ## 国別

# %%
country_df = df.loc[df.iso_code.str.len()==3]
country_df.head()
# Out:
#       location iso_code       date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG 2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG 2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG 2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG 2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG 2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN              1367.0
# 2                      NaN                     NaN              1367.0
# 3                      NaN                     NaN              1367.0
# 4                      NaN                     NaN              1367.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                             0.0                            0.0
# 1                             NaN                            NaN
# 2                             NaN                            NaN
# 3                             NaN                            NaN
# 4                             NaN                            NaN
#
#    people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# 0                                  NaN                             NaN
# 1                                  NaN                            35.0
# 2                                  NaN                            35.0
# 3                                  NaN                            35.0
# 4                                  NaN                            35.0

# %%
latest_df = country_df.loc[country_df.date==country_df.date.max()]
latest_df.head()
# Out:
#        location iso_code       date  total_vaccinations  people_vaccinated  \
# 466     Albania      ALB 2021-06-28            943439.0           547300.0
# 863      Angola      AGO 2021-06-28           1488292.0           943301.0
# 1318  Argentina      ARG 2021-06-28          19951580.0         15993494.0
# 1486      Aruba      ABW 2021-06-28            125875.0            67457.0
# 1816  Australia      AUS 2021-06-28           7374666.0          6152645.0
#
#       people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 466                  396139.0                     NaN              7627.0
# 863                  544991.0                     NaN             13570.0
# 1318                3958086.0                202112.0            250383.0
# 1486                  58418.0                   585.0               223.0
# 1816                1222021.0                 48346.0            111989.0
#
#       total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 466                            32.78                          19.02
# 863                             4.53                           2.87
# 1318                           44.14                          35.39
# 1486                          117.90                          63.18
# 1816                           28.92                          24.13
#
#       people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# 466                                 13.77                          2650.0
# 863                                  1.66                           413.0
# 1318                                 8.76                          5540.0
# 1486                                54.72                          2089.0
# 1816                                 4.79                          4392.0

# %% [markdown]
# ### ワクチン接種完了率トップ20

# %%
latest_df.sort_values(by="people_fully_vaccinated_per_hundred",ascending=False).head(20)[["location","iso_code","date","people_fully_vaccinated_per_hundred"]]
# Out:
#              location iso_code       date  people_fully_vaccinated_per_hundred
# 16992           Malta      MLT 2021-06-28                                71.52
# 5082   Cayman Islands      CYM 2021-06-28                                68.16
# 13391          Israel      ISR 2021-06-28                                59.65
# 2450          Bahrain      BHR 2021-06-28                                57.54
# 1486            Aruba      ABW 2021-06-28                                54.72
# 17839        Mongolia      MNG 2021-06-28                                53.03
# 12111         Hungary      HUN 2021-06-28                                50.45
# 13199     Isle of Man      IMN 2021-06-28                                48.24
# 22144           Qatar      QAT 2021-06-28                                48.09
# 6412          Curacao      CUW 2021-06-28                                47.72
# 28478   United States      USA 2021-06-28                                45.98
# 9023   Faeroe Islands      FRO 2021-06-28                                38.50
# 15697       Lithuania      LTU 2021-06-28                                36.89
# 10182         Germany      DEU 2021-06-28                                35.57
# 10643          Greece      GRC 2021-06-28                                35.17
# 21771          Poland      POL 2021-06-28                                33.85
# 3088          Belgium      BEL 2021-06-28                                33.65
# 2000          Austria      AUT 2021-06-28                                32.74
# 7032          Denmark      DNK 2021-06-28                                32.53
# 16177      Luxembourg      LUX 2021-06-28                                31.73

# %% [markdown]
# ### ワクチン接種完了率ワースト20

# %%
latest_df.sort_values(by="people_fully_vaccinated_per_hundred",ascending=True).head(20)[["location","iso_code","date","people_fully_vaccinated_per_hundred"]]
# Out:
#             location iso_code       date  people_fully_vaccinated_per_hundred
# 25555    South Sudan      SSD 2021-06-28                                 0.02
# 15257        Liberia      LBR 2021-06-28                                 0.05
# 11342  Guinea-Bissau      GNB 2021-06-28                                 0.05
# 4597        Cameroon      CMR 2021-06-28                                 0.08
# 3252           Benin      BEN 2021-06-28                                 0.08
# 26668         Taiwan      TWN 2021-06-28                                 0.16
# 29136        Vietnam      VNM 2021-06-28                                 0.18
# 16470         Malawi      MWI 2021-06-28                                 0.23
# 25993          Sudan      SDN 2021-06-28                                 0.28
# 25026        Somalia      SOM 2021-06-28                                 0.42
# 14352          Kenya      KEN 2021-06-28                                 0.54
# 25159   South Africa      ZAF 2021-06-28                                 0.81
# 23860        Senegal      SEN 2021-06-28                                 0.89
# 4897      Cape Verde      CPV 2021-06-28                                 1.09
# 27915        Ukraine      UKR 2021-06-28                                 1.35
# 863           Angola      AGO 2021-06-28                                 1.66
# 9998         Georgia      GEO 2021-06-28                                 2.37
# 18806          Nepal      NPL 2021-06-28                                 2.58
# 2604      Bangladesh      BGD 2021-06-28                                 2.60
# 26833       Thailand      THA 2021-06-28                                 3.86

# %% [markdown]
# ### 日本

# %%
jp = df.loc[df.location=="Japan"]
jp.head()
# Out:
#       location iso_code       date  total_vaccinations  people_vaccinated  \
# 13685    Japan      JPN 2021-02-17               125.0              125.0
# 13686    Japan      JPN 2021-02-18               611.0              611.0
# 13687    Japan      JPN 2021-02-19              5039.0             5039.0
# 13688    Japan      JPN 2021-02-20                 NaN                NaN
# 13689    Japan      JPN 2021-02-21                 NaN                NaN
#
#        people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 13685                      NaN                     NaN                 NaN
# 13686                      NaN                   486.0               486.0
# 13687                      NaN                  4428.0              2457.0
# 13688                      NaN                     NaN              2404.0
# 13689                      NaN                     NaN              2378.0
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 13685                             0.0                            0.0
# 13686                             0.0                            0.0
# 13687                             0.0                            0.0
# 13688                             NaN                            NaN
# 13689                             NaN                            NaN
#
#        people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# 13685                                  NaN                             NaN
# 13686                                  NaN                             4.0
# 13687                                  NaN                            19.0
# 13688                                  NaN                            19.0
# 13689                                  NaN                            19.0

# %% [markdown]
# ### 英国

# %%
uk = df.loc[df.location=="United Kingdom"]
#uk.append(pd.Series([uk.location.unique()[0],1,latest_date_str]),ignore_index=True).tail()
#uk.append(pd.Series(["UK","GBR",latest_date_str],index=uk.columns),ignore_index=True).tail()
uk.tail()
# Out:
#              location iso_code       date  total_vaccinations  \
# 28283  United Kingdom      GBR 2021-06-23          75564430.0
# 28284  United Kingdom      GBR 2021-06-24          75963777.0
# 28285  United Kingdom      GBR 2021-06-25          76341044.0
# 28286  United Kingdom      GBR 2021-06-26          76774990.0
# 28287  United Kingdom      GBR 2021-06-27          77038257.0
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 28283         43656327.0               31908103.0                375635.0
# 28284         43877861.0               32085916.0                399347.0
# 28285         44080358.0               32260686.0                377267.0
# 28286         44314799.0               32460191.0                433946.0
# 28287         44454511.0               32583746.0                263267.0
#
#        daily_vaccinations  total_vaccinations_per_hundred  \
# 28283            381796.0                          111.31
# 28284            372097.0                          111.90
# 28285            364733.0                          112.45
# 28286            352924.0                          113.09
# 28287            351511.0                          113.48
#
#        people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 28283                          64.31                                47.00
# 28284                          64.63                                47.26
# 28285                          64.93                                47.52
# 28286                          65.28                                47.82
# 28287                          65.48                                48.00
#
#        daily_vaccinations_per_million
# 28283                          5624.0
# 28284                          5481.0
# 28285                          5373.0
# 28286                          5199.0
# 28287                          5178.0

# %% [markdown]
# ## 可視化

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook
#%matplotlib inline

# %%
fig=plt.figure(figsize=(14,8))
ax1 = plt.subplot(1,2,1) # (rows, columns, panel number)
plt.title("Daily COVID-19 vacctinated in the world")
ax1.set_zorder(2)
ax1.patch.set_alpha(0)
plt.ylim(0,100)
plt.ylabel("vaccination %")
ax1.grid()
plt.xticks(rotation=70)
ax2 = plt.twinx()
ax2.set_zorder(1)
plt.ylabel("million people")
ax1.plot_date(world_df["date"],world_df["people_vaccinated_per_hundred"],label="Vaccinated at least once per population", fmt="-")
ax1.plot_date(world_df["date"],world_df["people_fully_vaccinated_per_hundred"],label="Fully vaccinated per population", fmt="-")
ax1.plot_date(jp["date"],jp["people_vaccinated_per_hundred"],label="Vaccinated at least once per population in Japan", fmt="-")
ax1.plot_date(jp["date"],jp["people_fully_vaccinated_per_hundred"],label="Fully vaccinated per population in Japan", fmt="-")
#ax1.plot_date(uk["date"],jp["people_vaccinated_per_hundred"],label="Vaccinated at least once per population in UK", fmt="-")
#ax1.plot_date(uk["date"],jp["people_fully_vaccinated_per_hundred"],label="Fully vaccinated per population in UK", fmt="-")
ax2.bar(world_df["date"],world_df["people_vaccinated"]/1000/1000,label="People vaccinated at least once", color="pink")
ax2.bar(world_df["date"],world_df["people_fully_vaccinated"]/1000/1000,label="People fully vaccinated", color="lightgray",zorder=1)
#plt.grid(axis="y")
h1,l1 = ax1.get_legend_handles_labels()
h2,l2 = ax2.get_legend_handles_labels()
plt.legend(h1+h2,l1+l2)

# fully vactinated
ax1 = plt.subplot(1,2,2) # (rows, columns, panel number)
plt.title("Daily COVID-19 fully vacctinated per population Top 50")
plt.ylabel("vaccination %")
plt.grid(axis="x")
plt.yticks(fontsize=9)
plt.xticks(rotation=70)
chart_data=latest_df.copy().sort_values(by="people_fully_vaccinated_per_hundred",ascending=False).head(50)
chart_data=chart_data.sort_values(by="people_fully_vaccinated_per_hundred",ascending=True)
plt.barh(chart_data["location"],chart_data["people_fully_vaccinated_per_hundred"],label="People fully vaccinated")
#plt.grid(axis="y")
#h1,l1 = ax1.get_legend_handles_labels()
#h2,l2 = ax2.get_legend_handles_labels()
#plt.legend(h1+h2,l1+l2)

"""
plt.subplot(2,2,2) # (rows, columns, panel number)
plt.title("Daily new confirmed COVID-19 cases in the world(after 2021 Apr 1st)")
chart_data = world_df[world_df.date >= "2021-04-01"]
plt.bar(chart_data["date"],chart_data["new_cases"],label="New deaths")
plt.plot_date(chart_data["date"],chart_data["new_cases_smoothed"],label="rolling 7-day average", fmt="-", color="orange")
plt.xticks(rotation=70)
plt.grid(axis="y")
plt.legend()

plt.subplot(2,2,3) # (rows, columns, panel number)
plt.title("Daily new deaths in the world")
plt.bar(world_df.date,world_df.new_deaths,label="New cases")
plt.plot_date(world_df["date"],world_df["new_deaths_smoothed"],label="rolling 7-day average", fmt="-", color="orange")
plt.xticks(rotation=70)
plt.ylabel("people")
plt.grid(axis="y")
plt.legend()

plt.subplot(2,2,4) # (rows, columns, panel number)
plt.title("Daily new deaths in the world(after 2021 Apr 1st)")
chart_data = world_df[world_df.date >= "2021-04-01"]
plt.bar(chart_data["date"],chart_data["new_deaths"],label="New deaths")
plt.plot_date(chart_data["date"],chart_data["new_deaths_smoothed"],label="rolling 7-day average", fmt="-", color="orange")
plt.xticks(rotation=70)
plt.grid(axis="y")
plt.legend()
"""

fig.text(0,1,"Latest: {}".format(latest_date_str),fontsize=8,ha="left",va="top")
fig.text(0,0
         ,"*Data reference from:COVID-19 Dataset by Our World in Data",
        fontsize=7,ha="left",va="bottom")

fig.tight_layout()
# Out:
# <div id='b7b3929f-5cf2-496f-a85f-73e60a92cbcf'></div>

# %%
fig.savefig("out/covid-owid-global-vaccinations-daily.png")
