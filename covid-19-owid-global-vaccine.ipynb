# %%
import pandas as pd

# %%
df = pd.read_csv("covid-19-data/public/data/vaccinations/vaccinations.csv")
df.head()
# Out:
#       location iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG  2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG  2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG  2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG  2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  total_boosters  daily_vaccinations_raw  \
# 0                      NaN             NaN                     NaN
# 1                      NaN             NaN                     NaN
# 2                      NaN             NaN                     NaN
# 3                      NaN             NaN                     NaN
# 4                      NaN             NaN                     NaN
#
#    daily_vaccinations  total_vaccinations_per_hundred  \
# 0                 NaN                             0.0
# 1              1367.0                             NaN
# 2              1367.0                             NaN
# 3              1367.0                             NaN
# 4              1367.0                             NaN
#
#    people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 0                            0.0                                  NaN
# 1                            NaN                                  NaN
# 2                            NaN                                  NaN
# 3                            NaN                                  NaN
# 4                            NaN                                  NaN
#
#    total_boosters_per_hundred  daily_vaccinations_per_million
# 0                         NaN                             NaN
# 1                         NaN                            34.0
# 2                         NaN                            34.0
# 3                         NaN                            34.0
# 4                         NaN                            34.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54503 entries, 0 to 54502
# Data columns (total 14 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   location                             54503 non-null  object
#  1   iso_code                             54503 non-null  object
#  2   date                                 54503 non-null  object
#  3   total_vaccinations                   31243 non-null  float64
#  4   people_vaccinated                    29812 non-null  float64
#  5   people_fully_vaccinated              26544 non-null  float64
#  6   total_boosters                       3756 non-null   float64
#  7   daily_vaccinations_raw               26270 non-null  float64
#  8   daily_vaccinations                   54240 non-null  float64
#  9   total_vaccinations_per_hundred       31243 non-null  float64
#  10  people_vaccinated_per_hundred        29812 non-null  float64
#  11  people_fully_vaccinated_per_hundred  26544 non-null  float64
#  12  total_boosters_per_hundred           3756 non-null   float64
#  13  daily_vaccinations_per_million       54240 non-null  float64
# dtypes: float64(11), object(3)
# memory usage: 5.8+ MB

# %%
df.describe()
# Out:
#        total_vaccinations  people_vaccinated  people_fully_vaccinated  \
# count        3.124300e+04       2.981200e+04             2.654400e+04
# mean         8.901567e+07       4.882330e+07             3.159984e+07
# std          4.307001e+08       2.393010e+08             1.649154e+08
# min          0.000000e+00       0.000000e+00             1.000000e+00
# 25%          3.239940e+05       2.430998e+05             1.286182e+05
# 50%          2.375090e+06       1.618686e+06             1.048825e+06
# 75%          1.366178e+07       8.578142e+06             5.833118e+06
# max          6.596507e+09       3.777779e+09             2.800365e+09
#
#        total_boosters  daily_vaccinations_raw  daily_vaccinations  \
# count    3.756000e+03            2.627000e+04        5.424000e+04
# mean     1.693571e+06            9.971772e+05        4.934816e+05
# std      4.292028e+06            4.001369e+06        2.767473e+06
# min      1.000000e+00            0.000000e+00        0.000000e+00
# 25%      8.900000e+01            6.394250e+03        1.044750e+03
# 50%      3.572100e+04            3.527350e+04        8.657000e+03
# 75%      8.711760e+05            2.214130e+05        6.029350e+04
# max      4.178318e+07            5.627299e+07        4.338870e+07
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# count                    31243.000000                   29812.000000
# mean                        46.787098                      27.797050
# std                         47.086241                      25.184397
# min                          0.000000                       0.000000
# 25%                          5.510000                       4.120000
# 50%                         29.700000                      20.620000
# 75%                         80.175000                      48.880000
# max                        240.660000                     118.610000
#
#        people_fully_vaccinated_per_hundred  total_boosters_per_hundred  \
# count                         26544.000000                 3756.000000
# mean                             21.051099                    1.806387
# std                              22.454429                    5.346059
# min                               0.000000                    0.000000
# 25%                               2.270000                    0.000000
# 50%                              11.610000                    0.020000
# 75%                              35.980000                    0.570000
# max                             117.910000                   43.210000
#
#        daily_vaccinations_per_million
# count                    54240.000000
# mean                      3499.525055
# std                       4247.182311
# min                          0.000000
# 25%                        559.000000
# 50%                       2250.000000
# 75%                       5206.250000
# max                     117497.000000

# %%
df["date"] = pd.to_datetime(df["date"])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54503 entries, 0 to 54502
# Data columns (total 14 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   location                             54503 non-null  object
#  1   iso_code                             54503 non-null  object
#  2   date                                 54503 non-null  datetime64[ns]
#  3   total_vaccinations                   31243 non-null  float64
#  4   people_vaccinated                    29812 non-null  float64
#  5   people_fully_vaccinated              26544 non-null  float64
#  6   total_boosters                       3756 non-null   float64
#  7   daily_vaccinations_raw               26270 non-null  float64
#  8   daily_vaccinations                   54240 non-null  float64
#  9   total_vaccinations_per_hundred       31243 non-null  float64
#  10  people_vaccinated_per_hundred        29812 non-null  float64
#  11  people_fully_vaccinated_per_hundred  26544 non-null  float64
#  12  total_boosters_per_hundred           3756 non-null   float64
#  13  daily_vaccinations_per_million       54240 non-null  float64
# dtypes: datetime64[ns](1), float64(11), object(2)
# memory usage: 5.8+ MB

# %%
import datetime
latest_date_str = (df.date.max() - datetime.timedelta(days=1)).strftime("%Y-%m-%d")
latest_date_str
# Out:
# '2021-10-12'

# %% [markdown]
# ## 全世界のデータ

# %%
world_df = df.copy().loc[df.location=="World"]
world_df.tail()
# Out:
#       location  iso_code       date  total_vaccinations  people_vaccinated  \
# 53935    World  OWID_WRL 2021-10-09        6.508304e+09       3.735915e+09
# 53936    World  OWID_WRL 2021-10-10        6.530059e+09       3.745246e+09
# 53937    World  OWID_WRL 2021-10-11        6.547856e+09       3.752131e+09
# 53938    World  OWID_WRL 2021-10-12        6.570296e+09       3.761296e+09
# 53939    World  OWID_WRL 2021-10-13        6.596507e+09       3.777779e+09
#
#        people_fully_vaccinated  total_boosters  daily_vaccinations_raw  \
# 53935             2.761948e+09      38527065.0              20146054.0
# 53936             2.773112e+09      38733935.0              21755217.0
# 53937             2.782358e+09      39124631.0              17797160.0
# 53938             2.792832e+09      40430080.0              22439854.0
# 53939             2.800365e+09      41783178.0              26210886.0
#
#        daily_vaccinations  total_vaccinations_per_hundred  \
# 53935          25508155.0                           82.65
# 53936          24658609.0                           82.92
# 53937          24000769.0                           83.15
# 53938          22500005.0                           83.43
# 53939          23173375.0                           83.77
#
#        people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 53935                          47.44                                35.07
# 53936                          47.56                                35.21
# 53937                          47.65                                35.33
# 53938                          47.76                                35.46
# 53939                          47.97                                35.56
#
#        total_boosters_per_hundred  daily_vaccinations_per_million
# 53935                        0.49                          3239.0
# 53936                        0.49                          3131.0
# 53937                        0.50                          3048.0
# 53938                        0.51                          2857.0
# 53939                        0.53                          2943.0

# %% [markdown]
# ## 国別

# %%
country_df = df.loc[df.iso_code.str.len()==3]
country_df.head()
# Out:
#       location iso_code       date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG 2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG 2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG 2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG 2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG 2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  total_boosters  daily_vaccinations_raw  \
# 0                      NaN             NaN                     NaN
# 1                      NaN             NaN                     NaN
# 2                      NaN             NaN                     NaN
# 3                      NaN             NaN                     NaN
# 4                      NaN             NaN                     NaN
#
#    daily_vaccinations  total_vaccinations_per_hundred  \
# 0                 NaN                             0.0
# 1              1367.0                             NaN
# 2              1367.0                             NaN
# 3              1367.0                             NaN
# 4              1367.0                             NaN
#
#    people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 0                            0.0                                  NaN
# 1                            NaN                                  NaN
# 2                            NaN                                  NaN
# 3                            NaN                                  NaN
# 4                            NaN                                  NaN
#
#    total_boosters_per_hundred  daily_vaccinations_per_million
# 0                         NaN                             NaN
# 1                         NaN                            34.0
# 2                         NaN                            34.0
# 3                         NaN                            34.0
# 4                         NaN                            34.0

# %%
latest_df = country_df.loc[country_df.date==latest_date_str]
latest_df.head()
# Out:
#        location iso_code       date  total_vaccinations  people_vaccinated  \
# 774     Albania      ALB 2021-10-12           1810433.0           968117.0
# 2245  Argentina      ARG 2021-10-12                 NaN                NaN
# 2639      Aruba      ABW 2021-10-12            157665.0            81916.0
# 3184  Australia      AUS 2021-10-12          31358609.0         17914026.0
# 3475    Austria      AUT 2021-10-12          10970384.0          5796064.0
#
#       people_fully_vaccinated  total_boosters  daily_vaccinations_raw  \
# 774                  842316.0             NaN                  6634.0
# 2245                      NaN             NaN                     NaN
# 2639                  75749.0             NaN                     NaN
# 3184               13444583.0             NaN                338127.0
# 3475                5491392.0             NaN                 10684.0
#
#       daily_vaccinations  total_vaccinations_per_hundred  \
# 774               5556.0                           63.02
# 2245            193386.0                             NaN
# 2639               129.0                          147.08
# 3184            293248.0                          121.60
# 3475              9843.0                          121.31
#
#       people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 774                           33.70                                29.32
# 2245                            NaN                                  NaN
# 2639                          76.42                                70.66
# 3184                          69.47                                52.13
# 3475                          64.09                                60.72
#
#       total_boosters_per_hundred  daily_vaccinations_per_million
# 774                          NaN                          1934.0
# 2245                         NaN                          4240.0
# 2639                         NaN                          1203.0
# 3184                         NaN                         11371.0
# 3475                         NaN                          1088.0

# %% [markdown]
# ### ワクチン接種完了率トップ20

# %%
latest_df.sort_values(by="people_fully_vaccinated_per_hundred",ascending=False).head(20)[["location","iso_code","date","people_fully_vaccinated_per_hundred"]]
# Out:
#              location iso_code       date  people_fully_vaccinated_per_hundred
# 19013       Gibraltar      GIB 2021-10-12                               117.88
# 9222   Cayman Islands      CYM 2021-10-12                                83.69
# 30779           Malta      MLT 2021-10-12                                82.41
# 44013       Singapore      SGP 2021-10-12                                79.17
# 46351           Spain      ESP 2021-10-12                                79.07
# 13005         Denmark      DNK 2021-10-12                                75.54
# 23863     Isle of Man      IMN 2021-10-12                                74.94
# 52334         Uruguay      URY 2021-10-12                                74.61
# 9777            Chile      CHL 2021-10-12                                74.18
# 5319          Belgium      BEL 2021-10-12                                72.86
# 48983         Tokelau      TKL 2021-10-12                                70.76
# 2639            Aruba      ABW 2021-10-12                                70.66
# 8241         Cambodia      KHM 2021-10-12                                70.47
# 24453           Italy      ITA 2021-10-12                                69.35
# 36909          Norway      NOR 2021-10-12                                67.62
# 17354          France      FRA 2021-10-12                                66.88
# 47328          Sweden      SWE 2021-10-12                                66.46
# 51505  United Kingdom      GBR 2021-10-12                                66.33
# 30071        Malaysia      MYS 2021-10-12                                65.87
# 24911           Japan      JPN 2021-10-12                                65.71

# %% [markdown]
# ### ワクチン接種完了率ワースト20

# %%
latest_df.sort_values(by="people_fully_vaccinated_per_hundred",ascending=True).head(20)[["location","iso_code","date","people_fully_vaccinated_per_hundred"]]
# Out:
#                 location iso_code       date  \
# 15608           Ethiopia      ETH 2021-10-12
# 25873              Kenya      KEN 2021-10-12
# 54263             Zambia      ZMB 2021-10-12
# 29840             Malawi      MWI 2021-10-12
# 44945    Solomon Islands      SLB 2021-10-12
# 20495             Guinea      GIN 2021-10-12
# 26007           Kiribati      KIR 2021-10-12
# 52660            Vanuatu      VUT 2021-10-12
# 26595         Kyrgyzstan      KGZ 2021-10-12
# 24672            Jamaica      JAM 2021-10-12
# 4510          Bangladesh      BGD 2021-10-12
# 14935  Equatorial Guinea      GNQ 2021-10-12
# 50918            Ukraine      UKR 2021-10-12
# 37704           Pakistan      PAK 2021-10-12
# 20034          Guatemala      GTM 2021-10-12
# 54501           Zimbabwe      ZWE 2021-10-12
# 53114            Vietnam      VNM 2021-10-12
# 22586              India      IND 2021-10-12
# 41410        Saint Lucia      LCA 2021-10-12
# 48043             Taiwan      TWN 2021-10-12
#
#        people_fully_vaccinated_per_hundred
# 15608                                 0.79
# 25873                                 1.92
# 54263                                 2.48
# 29840                                 2.61
# 44945                                 4.05
# 20495                                 4.65
# 26007                                 6.91
# 52660                                 9.02
# 26595                                10.09
# 24672                                10.86
# 4510                                 11.05
# 14935                                12.31
# 50918                                14.43
# 37704                                15.46
# 20034                                15.80
# 54501                                16.10
# 53114                                16.80
# 22586                                19.57
# 41410                                19.66
# 48043                                19.70

# %% [markdown]
# ### 日本

# %%
jp = df.loc[df.location=="Japan"]
jp.tail()
# Out:
#       location iso_code       date  total_vaccinations  people_vaccinated  \
# 24908    Japan      JPN 2021-10-09                 NaN                NaN
# 24909    Japan      JPN 2021-10-10         174631850.0         93169823.0
# 24910    Japan      JPN 2021-10-11         175700765.0         93651522.0
# 24911    Japan      JPN 2021-10-12         176881164.0         94051403.0
# 24912    Japan      JPN 2021-10-13         177622120.0         94311115.0
#
#        people_fully_vaccinated  total_boosters  daily_vaccinations_raw  \
# 24908                      NaN             NaN                     NaN
# 24909               81462027.0             NaN                     NaN
# 24910               82049243.0             NaN               1068915.0
# 24911               82829761.0             NaN               1180399.0
# 24912               83311005.0             NaN                740956.0
#
#        daily_vaccinations  total_vaccinations_per_hundred  \
# 24908           1030142.0                             NaN
# 24909           1026067.0                          138.54
# 24910            991194.0                          139.39
# 24911            942699.0                          140.33
# 24912            918410.0                          140.91
#
#        people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 24908                            NaN                                  NaN
# 24909                          73.91                                64.63
# 24910                          74.30                                65.09
# 24911                          74.61                                65.71
# 24912                          74.82                                66.09
#
#        total_boosters_per_hundred  daily_vaccinations_per_million
# 24908                         NaN                          8172.0
# 24909                         NaN                          8140.0
# 24910                         NaN                          7863.0
# 24911                         NaN                          7479.0
# 24912                         NaN                          7286.0

# %% [markdown]
# ### 英国

# %%
uk = df.loc[df.location=="United Kingdom"]
#uk.append(pd.Series([uk.location.unique()[0],1,latest_date_str]),ignore_index=True).tail()
#uk.append(pd.Series(["UK","GBR",latest_date_str],index=uk.columns),ignore_index=True).tail()
uk.tail()
# Out:
#              location iso_code       date  total_vaccinations  \
# 51501  United Kingdom      GBR 2021-10-08          94269672.0
# 51502  United Kingdom      GBR 2021-10-09          94334544.0
# 51503  United Kingdom      GBR 2021-10-10          94376101.0
# 51504  United Kingdom      GBR 2021-10-11          94428905.0
# 51505  United Kingdom      GBR 2021-10-12          94492698.0
#
#        people_vaccinated  people_fully_vaccinated  total_boosters  \
# 51501         49133419.0               45136253.0             NaN
# 51502         49164814.0               45169730.0             NaN
# 51503         49186920.0               45189181.0             NaN
# 51504         49216092.0               45212813.0             NaN
# 51505         49252939.0               45239759.0             NaN
#
#        daily_vaccinations_raw  daily_vaccinations  \
# 51501                 60753.0             61697.0
# 51502                 64872.0             61614.0
# 51503                 41557.0             61028.0
# 51504                 52804.0             58999.0
# 51505                 63793.0             58124.0
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 51501                          138.21                          72.04
# 51502                          138.31                          72.08
# 51503                          138.37                          72.11
# 51504                          138.44                          72.16
# 51505                          138.54                          72.21
#
#        people_fully_vaccinated_per_hundred  total_boosters_per_hundred  \
# 51501                                66.18                         NaN
# 51502                                66.22                         NaN
# 51503                                66.25                         NaN
# 51504                                66.29                         NaN
# 51505                                66.33                         NaN
#
#        daily_vaccinations_per_million
# 51501                           905.0
# 51502                           903.0
# 51503                           895.0
# 51504                           865.0
# 51505                           852.0

# %% [markdown]
# ### イラン

# %%
iran = df.loc[df.location=="Iran"]
iran.tail()
# Out:
#       location iso_code       date  total_vaccinations  people_vaccinated  \
# 23096     Iran      IRN 2021-09-29                 NaN                NaN
# 23097     Iran      IRN 2021-09-30                 NaN                NaN
# 23098     Iran      IRN 2021-10-01                 NaN                NaN
# 23099     Iran      IRN 2021-10-02                 NaN                NaN
# 23100     Iran      IRN 2021-10-03          57676540.0         40961153.0
#
#        people_fully_vaccinated  total_boosters  daily_vaccinations_raw  \
# 23096                      NaN             NaN                     NaN
# 23097                      NaN             NaN                     NaN
# 23098                      NaN             NaN                     NaN
# 23099                      NaN             NaN                     NaN
# 23100               16715387.0             NaN                     NaN
#
#        daily_vaccinations  total_vaccinations_per_hundred  \
# 23096           1148014.0                             NaN
# 23097           1109269.0                             NaN
# 23098           1070525.0                             NaN
# 23099           1031781.0                             NaN
# 23100            993037.0                           67.83
#
#        people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 23096                            NaN                                  NaN
# 23097                            NaN                                  NaN
# 23098                            NaN                                  NaN
# 23099                            NaN                                  NaN
# 23100                          48.17                                19.66
#
#        total_boosters_per_hundred  daily_vaccinations_per_million
# 23096                         NaN                         13501.0
# 23097                         NaN                         13046.0
# 23098                         NaN                         12590.0
# 23099                         NaN                         12134.0
# 23100                         NaN                         11679.0

# %% [markdown]
# ## 可視化

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook
#%matplotlib inline

# %%
fig=plt.figure(figsize=(14,8))
ax1 = plt.subplot(1,2,1) # (rows, columns, panel number)
plt.title("Daily COVID-19 vacctinated in the world")
ax1.set_zorder(2)
ax1.patch.set_alpha(0)
plt.ylim(0,100)
plt.ylabel("vaccination %")
ax1.grid()
plt.xticks(rotation=70)
ax2 = plt.twinx()
ax2.set_zorder(1)
plt.ylabel("million people")
ax1.plot_date(world_df["date"],world_df["people_vaccinated_per_hundred"],label="Vaccinated at least once per population", fmt="-")
ax1.plot_date(world_df["date"],world_df["people_fully_vaccinated_per_hundred"],label="Fully vaccinated per population", fmt="-")
ax1.plot_date(jp["date"],jp["people_vaccinated_per_hundred"],label="Vaccinated at least once per population in Japan", fmt="-")
ax1.plot_date(jp["date"],jp["people_fully_vaccinated_per_hundred"],label="Fully vaccinated per population in Japan", fmt="-")
#ax1.plot_date(uk["date"],jp["people_vaccinated_per_hundred"],label="Vaccinated at least once per population in UK", fmt="-")
#ax1.plot_date(uk["date"],jp["people_fully_vaccinated_per_hundred"],label="Fully vaccinated per population in UK", fmt="-")
ax2.bar(world_df["date"],world_df["people_vaccinated"]/1000/1000,label="People vaccinated at least once", color="pink")
ax2.bar(world_df["date"],world_df["people_fully_vaccinated"]/1000/1000,label="People fully vaccinated", color="lightgray",zorder=1)
#plt.grid(axis="y")
h1,l1 = ax1.get_legend_handles_labels()
h2,l2 = ax2.get_legend_handles_labels()
plt.legend(h1+h2,l1+l2)

# fully vactinated
ax1 = plt.subplot(1,2,2) # (rows, columns, panel number)
plt.title("Daily COVID-19 fully vacctinated per population Top 50")
plt.ylabel("vaccination %")
plt.grid(axis="x")
plt.yticks(fontsize=9)
plt.xticks(rotation=70)
plt.xlim(0,100)
chart_data=latest_df.copy().sort_values(by="people_fully_vaccinated_per_hundred",ascending=False).head(50)
chart_data=chart_data.sort_values(by="people_fully_vaccinated_per_hundred",ascending=True)
plt.barh(chart_data["location"],chart_data["people_fully_vaccinated_per_hundred"],label="People fully vaccinated")
#plt.grid(axis="y")
#h1,l1 = ax1.get_legend_handles_labels()
#h2,l2 = ax2.get_legend_handles_labels()
#plt.legend(h1+h2,l1+l2)

"""
plt.subplot(2,2,2) # (rows, columns, panel number)
plt.title("Daily new confirmed COVID-19 cases in the world(after 2021 Apr 1st)")
chart_data = world_df[world_df.date >= "2021-04-01"]
plt.bar(chart_data["date"],chart_data["new_cases"],label="New deaths")
plt.plot_date(chart_data["date"],chart_data["new_cases_smoothed"],label="rolling 7-day average", fmt="-", color="orange")
plt.xticks(rotation=70)
plt.grid(axis="y")
plt.legend()

plt.subplot(2,2,3) # (rows, columns, panel number)
plt.title("Daily new deaths in the world")
plt.bar(world_df.date,world_df.new_deaths,label="New cases")
plt.plot_date(world_df["date"],world_df["new_deaths_smoothed"],label="rolling 7-day average", fmt="-", color="orange")
plt.xticks(rotation=70)
plt.ylabel("people")
plt.grid(axis="y")
plt.legend()

plt.subplot(2,2,4) # (rows, columns, panel number)
plt.title("Daily new deaths in the world(after 2021 Apr 1st)")
chart_data = world_df[world_df.date >= "2021-04-01"]
plt.bar(chart_data["date"],chart_data["new_deaths"],label="New deaths")
plt.plot_date(chart_data["date"],chart_data["new_deaths_smoothed"],label="rolling 7-day average", fmt="-", color="orange")
plt.xticks(rotation=70)
plt.grid(axis="y")
plt.legend()
"""

fig.text(0,1,"Latest: {}".format(latest_date_str),fontsize=8,ha="left",va="top")
fig.text(0,0
         ,"*Data reference from:COVID-19 Dataset by Our World in Data",
        fontsize=7,ha="left",va="bottom")

fig.tight_layout()
# Out:
# <div id='21542f6b-8323-496f-8453-a2b538576f82'></div>

# %%
fig.savefig("out/covid-owid-global-vaccinations-daily.png")
