# %%
import pandas as pd

# %%
df = pd.read_csv("covid-19-data/public/data/vaccinations/vaccinations.csv")
df.head()
# Out:
#       location iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG  2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG  2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG  2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG  2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN              1367.0
# 2                      NaN                     NaN              1367.0
# 3                      NaN                     NaN              1367.0
# 4                      NaN                     NaN              1367.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                             0.0                            0.0
# 1                             NaN                            NaN
# 2                             NaN                            NaN
# 3                             NaN                            NaN
# 4                             NaN                            NaN
#
#    people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# 0                                  NaN                             NaN
# 1                                  NaN                            35.0
# 2                                  NaN                            35.0
# 3                                  NaN                            35.0
# 4                                  NaN                            35.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39647 entries, 0 to 39646
# Data columns (total 12 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   location                             39647 non-null  object
#  1   iso_code                             39647 non-null  object
#  2   date                                 39647 non-null  object
#  3   total_vaccinations                   23042 non-null  float64
#  4   people_vaccinated                    22123 non-null  float64
#  5   people_fully_vaccinated              19027 non-null  float64
#  6   daily_vaccinations_raw               19402 non-null  float64
#  7   daily_vaccinations                   39392 non-null  float64
#  8   total_vaccinations_per_hundred       23042 non-null  float64
#  9   people_vaccinated_per_hundred        22123 non-null  float64
#  10  people_fully_vaccinated_per_hundred  19027 non-null  float64
#  11  daily_vaccinations_per_million       39392 non-null  float64
# dtypes: float64(9), object(3)
# memory usage: 3.6+ MB

# %%
df.describe()
# Out:
#        total_vaccinations  people_vaccinated  people_fully_vaccinated  \
# count        2.304200e+04       2.212300e+04             1.902700e+04
# mean         5.728137e+07       3.129148e+07             1.759295e+07
# std          2.737119e+08       1.480513e+08             7.683358e+07
# min          0.000000e+00       0.000000e+00             1.000000e+00
# 25%          1.967330e+05       1.602905e+05             7.283500e+04
# 50%          1.534115e+06       1.038383e+06             6.225130e+05
# 75%          9.377128e+06       5.688524e+06             3.905858e+06
# max          4.541765e+09       2.373026e+09             1.234742e+09
#
#        daily_vaccinations_raw  daily_vaccinations  \
# count            1.940200e+04        3.939200e+04
# mean             9.403518e+05        4.647072e+05
# std              3.831040e+06        2.640198e+06
# min              0.000000e+00        0.000000e+00
# 25%              6.076000e+03        9.570000e+02
# 50%              3.255150e+04        8.473000e+03
# 75%              2.017972e+05        5.572675e+04
# max              5.645783e+07        4.341315e+07
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# count                    23042.000000                   22123.000000
# mean                        33.570329                      21.088371
# std                         38.388567                      21.960660
# min                          0.000000                       0.000000
# 25%                          3.370000                       2.695000
# 50%                         17.575000                      12.230000
# 75%                         53.165000                      35.490000
# max                        233.030000                     116.830000
#
#        people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# count                         19027.000000                    39392.000000
# mean                             14.346830                     3495.926279
# std                              17.798412                     4546.907340
# min                               0.000000                        0.000000
# 25%                               1.400000                      448.000000
# 50%                               6.560000                     2046.000000
# 75%                              21.475000                     5229.000000
# max                             116.200000                   118759.000000

# %%
df["date"] = pd.to_datetime(df["date"])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39647 entries, 0 to 39646
# Data columns (total 12 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   location                             39647 non-null  object
#  1   iso_code                             39647 non-null  object
#  2   date                                 39647 non-null  datetime64[ns]
#  3   total_vaccinations                   23042 non-null  float64
#  4   people_vaccinated                    22123 non-null  float64
#  5   people_fully_vaccinated              19027 non-null  float64
#  6   daily_vaccinations_raw               19402 non-null  float64
#  7   daily_vaccinations                   39392 non-null  float64
#  8   total_vaccinations_per_hundred       23042 non-null  float64
#  9   people_vaccinated_per_hundred        22123 non-null  float64
#  10  people_fully_vaccinated_per_hundred  19027 non-null  float64
#  11  daily_vaccinations_per_million       39392 non-null  float64
# dtypes: datetime64[ns](1), float64(9), object(2)
# memory usage: 3.6+ MB

# %%
import datetime
latest_date_str = (df.date.max() - datetime.timedelta(days=1)).strftime("%Y-%m-%d")
latest_date_str
# Out:
# '2021-08-09'

# %% [markdown]
# ## 全世界のデータ

# %%
world_df = df.copy().loc[df.location=="World"]
world_df.tail()
# Out:
#       location  iso_code       date  total_vaccinations  people_vaccinated  \
# 39270    World  OWID_WRL 2021-08-06        4.407418e+09       2.321031e+09
# 39271    World  OWID_WRL 2021-08-07        4.439574e+09       2.332186e+09
# 39272    World  OWID_WRL 2021-08-08        4.469439e+09       2.345486e+09
# 39273    World  OWID_WRL 2021-08-09        4.488941e+09       2.356547e+09
# 39274    World  OWID_WRL 2021-08-10        4.541765e+09       2.373026e+09
#
#        people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 39270             1.194238e+09              38715050.0          41158561.0
# 39271             1.203100e+09              32155789.0          41090430.0
# 39272             1.209841e+09              29865774.0          39728395.0
# 39273             1.223456e+09              19502064.0          37181819.0
# 39274             1.234742e+09              52823313.0          36662602.0
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 39270                           56.54                          29.78
# 39271                           56.96                          29.92
# 39272                           57.34                          30.09
# 39273                           57.59                          30.23
# 39274                           58.27                          30.44
#
#        people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# 39270                                15.32                          5280.0
# 39271                                15.43                          5272.0
# 39272                                15.52                          5097.0
# 39273                                15.70                          4770.0
# 39274                                15.84                          4703.0

# %% [markdown]
# ## 国別

# %%
country_df = df.loc[df.iso_code.str.len()==3]
country_df.head()
# Out:
#       location iso_code       date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG 2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG 2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG 2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG 2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG 2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN              1367.0
# 2                      NaN                     NaN              1367.0
# 3                      NaN                     NaN              1367.0
# 4                      NaN                     NaN              1367.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                             0.0                            0.0
# 1                             NaN                            NaN
# 2                             NaN                            NaN
# 3                             NaN                            NaN
# 4                             NaN                            NaN
#
#    people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# 0                                  NaN                             NaN
# 1                                  NaN                            35.0
# 2                                  NaN                            35.0
# 3                                  NaN                            35.0
# 4                                  NaN                            35.0

# %%
latest_df = country_df.loc[country_df.date==latest_date_str]
latest_df.head()
# Out:
#          location iso_code       date  total_vaccinations  people_vaccinated  \
# 168   Afghanistan      AFG 2021-08-09           1767239.0           769869.0
# 594       Albania      ALB 2021-08-09                 NaN                NaN
# 1115       Angola      AGO 2021-08-09           1695588.0           972978.0
# 1696    Argentina      ARG 2021-08-09          34902791.0         26179454.0
# 1962        Aruba      ABW 2021-08-09            139887.0            73125.0
#
#       people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 168                       NaN                     NaN             40624.0
# 594                       NaN                     NaN              8191.0
# 1115                 722610.0                     NaN              3052.0
# 1696                8723337.0                277865.0            366771.0
# 1962                  66762.0                     NaN               171.0
#
#       total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 168                             4.54                           1.98
# 594                              NaN                            NaN
# 1115                            5.16                           2.96
# 1696                           77.23                          57.92
# 1962                          131.02                          68.49
#
#       people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# 168                                   NaN                          1044.0
# 594                                   NaN                          2846.0
# 1115                                 2.20                            93.0
# 1696                                19.30                          8115.0
# 1962                                62.53                          1602.0

# %% [markdown]
# ### ワクチン接種完了率トップ20

# %%
latest_df.sort_values(by="people_fully_vaccinated_per_hundred",ascending=False).head(20)[["location","iso_code","date","people_fully_vaccinated_per_hundred"]]
# Out:
#                    location iso_code       date  \
# 22501                 Malta      MLT 2021-08-09
# 37277  United Arab Emirates      ARE 2021-08-09
# 32364             Singapore      SGP 2021-08-09
# 38155               Uruguay      URY 2021-08-09
# 12006        Faeroe Islands      FRO 2021-08-09
# 4006                Belgium      BEL 2021-08-09
# 29376                 Qatar      QAT 2021-08-09
# 3192                Bahrain      BHR 2021-08-09
# 1962                  Aruba      ABW 2021-08-09
# 17682                Israel      ISR 2021-08-09
# 6354                 Canada      CAN 2021-08-09
# 4597                 Bhutan      BTN 2021-08-09
# 34044                 Spain      ESP 2021-08-09
# 9412                Denmark      DNK 2021-08-09
# 29144              Portugal      PRT 2021-08-09
# 23614              Mongolia      MNG 2021-08-09
# 17245               Ireland      IRL 2021-08-09
# 37518        United Kingdom      GBR 2021-08-09
# 16048               Hungary      HUN 2021-08-09
# 17909                 Italy      ITA 2021-08-09
#
#        people_fully_vaccinated_per_hundred
# 22501                                90.17
# 37277                                72.20
# 32364                                66.62
# 38155                                66.52
# 12006                                65.98
# 4006                                 63.89
# 29376                                63.38
# 3192                                 62.60
# 1962                                 62.53
# 17682                                62.39
# 6354                                 62.21
# 4597                                 61.65
# 34044                                61.53
# 9412                                 61.11
# 29144                                61.09
# 23614                                61.03
# 17245                                59.58
# 37518                                58.46
# 16048                                56.87
# 17909                                55.75

# %% [markdown]
# ### ワクチン接種完了率ワースト20

# %%
latest_df.sort_values(by="people_fully_vaccinated_per_hundred",ascending=True).head(20)[["location","iso_code","date","people_fully_vaccinated_per_hundred"]]
# Out:
#                            location iso_code       date  \
# 9176   Democratic Republic of Congo      COD 2021-08-09
# 15246                         Haiti      HTI 2021-08-09
# 15040                 Guinea-Bissau      GNB 2021-08-09
# 25797                         Niger      NER 2021-08-09
# 6115                       Cameroon      CMR 2021-08-09
# 22296                          Mali      MLI 2021-08-09
# 22639                    Mauritania      MRT 2021-08-09
# 25956                       Nigeria      NGA 2021-08-09
# 38642                       Vietnam      VNM 2021-08-09
# 39472                        Zambia      ZMB 2021-08-09
# 24318                    Mozambique      MOZ 2021-08-09
# 33042               Solomon Islands      SLB 2021-08-09
# 31629                       Senegal      SEN 2021-08-09
# 12999                         Gabon      GAB 2021-08-09
# 14621                     Guatemala      GTM 2021-08-09
# 35292                        Taiwan      TWN 2021-08-09
# 1115                         Angola      AGO 2021-08-09
# 3389                     Bangladesh      BGD 2021-08-09
# 19469                    Kyrgyzstan      KGZ 2021-08-09
# 6500                     Cape Verde      CPV 2021-08-09
#
#        people_fully_vaccinated_per_hundred
# 9176                                  0.00
# 15246                                 0.00
# 15040                                 0.12
# 25797                                 0.13
# 6115                                  0.23
# 22296                                 0.43
# 22639                                 0.45
# 25956                                 0.69
# 38642                                 1.03
# 39472                                 1.05
# 24318                                 1.53
# 33042                                 1.92
# 31629                                 1.94
# 12999                                 2.06
# 14621                                 2.17
# 35292                                 2.18
# 1115                                  2.20
# 3389                                  2.80
# 19469                                 3.00
# 6500                                  4.64

# %% [markdown]
# ### 日本

# %%
jp = df.loc[df.location=="Japan"]
jp.tail()
# Out:
#       location iso_code       date  total_vaccinations  people_vaccinated  \
# 18232    Japan      JPN 2021-08-06                 NaN                NaN
# 18233    Japan      JPN 2021-08-07                 NaN                NaN
# 18234    Japan      JPN 2021-08-08                 NaN                NaN
# 18235    Japan      JPN 2021-08-09         102913015.0         59629433.0
# 18236    Japan      JPN 2021-08-10         105680550.0         60534603.0
#
#        people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 18232                      NaN                     NaN           1805041.0
# 18233                      NaN                     NaN           1742929.0
# 18234                      NaN                     NaN           1724842.0
# 18235               43283582.0                     NaN           1718949.0
# 18236               45145947.0               2767535.0           1997542.0
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 18232                             NaN                            NaN
# 18233                             NaN                            NaN
# 18234                             NaN                            NaN
# 18235                           81.37                          47.15
# 18236                           83.56                          47.86
#
#        people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# 18232                                  NaN                         14272.0
# 18233                                  NaN                         13781.0
# 18234                                  NaN                         13638.0
# 18235                                34.22                         13591.0
# 18236                                35.70                         15794.0

# %% [markdown]
# ### 英国

# %%
uk = df.loc[df.location=="United Kingdom"]
#uk.append(pd.Series([uk.location.unique()[0],1,latest_date_str]),ignore_index=True).tail()
#uk.append(pd.Series(["UK","GBR",latest_date_str],index=uk.columns),ignore_index=True).tail()
uk.tail()
# Out:
#              location iso_code       date  total_vaccinations  \
# 37514  United Kingdom      GBR 2021-08-05          86009359.0
# 37515  United Kingdom      GBR 2021-08-06          86214691.0
# 37516  United Kingdom      GBR 2021-08-07          86466264.0
# 37517  United Kingdom      GBR 2021-08-08          86611177.0
# 37518  United Kingdom      GBR 2021-08-09          86780455.0
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 37514         46961830.0               39047529.0                208192.0
# 37515         46998806.0               39215885.0                205332.0
# 37516         47036796.0               39429468.0                251573.0
# 37517         47059639.0               39551538.0                144913.0
# 37518         47091889.0               39688566.0                169278.0
#
#        daily_vaccinations  total_vaccinations_per_hundred  \
# 37514            189924.0                          126.70
# 37515            189568.0                          127.00
# 37516            189673.0                          127.37
# 37517            190478.0                          127.58
# 37518            192906.0                          127.83
#
#        people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 37514                          69.18                                57.52
# 37515                          69.23                                57.77
# 37516                          69.29                                58.08
# 37517                          69.32                                58.26
# 37518                          69.37                                58.46
#
#        daily_vaccinations_per_million
# 37514                          2798.0
# 37515                          2792.0
# 37516                          2794.0
# 37517                          2806.0
# 37518                          2842.0

# %% [markdown]
# ### イラン

# %%
iran = df.loc[df.location=="Iran"]
iran.tail()
# Out:
#       location iso_code       date  total_vaccinations  people_vaccinated  \
# 16860     Iran      IRN 2021-07-29                 NaN                NaN
# 16861     Iran      IRN 2021-07-30                 NaN                NaN
# 16862     Iran      IRN 2021-07-31                 NaN                NaN
# 16863     Iran      IRN 2021-08-01                 NaN                NaN
# 16864     Iran      IRN 2021-08-02          12388974.0          9615913.0
#
#        people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 16860                      NaN                     NaN            300285.0
# 16861                      NaN                     NaN            304510.0
# 16862                      NaN                     NaN            308735.0
# 16863                      NaN                     NaN            312960.0
# 16864                2773061.0                     NaN            317186.0
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 16860                             NaN                            NaN
# 16861                             NaN                            NaN
# 16862                             NaN                            NaN
# 16863                             NaN                            NaN
# 16864                           14.75                          11.45
#
#        people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# 16860                                  NaN                          3575.0
# 16861                                  NaN                          3625.0
# 16862                                  NaN                          3676.0
# 16863                                  NaN                          3726.0
# 16864                                  3.3                          3776.0

# %% [markdown]
# ## 可視化

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook
#%matplotlib inline

# %%
fig=plt.figure(figsize=(14,8))
ax1 = plt.subplot(1,2,1) # (rows, columns, panel number)
plt.title("Daily COVID-19 vacctinated in the world")
ax1.set_zorder(2)
ax1.patch.set_alpha(0)
plt.ylim(0,100)
plt.ylabel("vaccination %")
ax1.grid()
plt.xticks(rotation=70)
ax2 = plt.twinx()
ax2.set_zorder(1)
plt.ylabel("million people")
ax1.plot_date(world_df["date"],world_df["people_vaccinated_per_hundred"],label="Vaccinated at least once per population", fmt="-")
ax1.plot_date(world_df["date"],world_df["people_fully_vaccinated_per_hundred"],label="Fully vaccinated per population", fmt="-")
ax1.plot_date(jp["date"],jp["people_vaccinated_per_hundred"],label="Vaccinated at least once per population in Japan", fmt="-")
ax1.plot_date(jp["date"],jp["people_fully_vaccinated_per_hundred"],label="Fully vaccinated per population in Japan", fmt="-")
#ax1.plot_date(uk["date"],jp["people_vaccinated_per_hundred"],label="Vaccinated at least once per population in UK", fmt="-")
#ax1.plot_date(uk["date"],jp["people_fully_vaccinated_per_hundred"],label="Fully vaccinated per population in UK", fmt="-")
ax2.bar(world_df["date"],world_df["people_vaccinated"]/1000/1000,label="People vaccinated at least once", color="pink")
ax2.bar(world_df["date"],world_df["people_fully_vaccinated"]/1000/1000,label="People fully vaccinated", color="lightgray",zorder=1)
#plt.grid(axis="y")
h1,l1 = ax1.get_legend_handles_labels()
h2,l2 = ax2.get_legend_handles_labels()
plt.legend(h1+h2,l1+l2)

# fully vactinated
ax1 = plt.subplot(1,2,2) # (rows, columns, panel number)
plt.title("Daily COVID-19 fully vacctinated per population Top 50")
plt.ylabel("vaccination %")
plt.grid(axis="x")
plt.yticks(fontsize=9)
plt.xticks(rotation=70)
plt.xlim(0,100)
chart_data=latest_df.copy().sort_values(by="people_fully_vaccinated_per_hundred",ascending=False).head(50)
chart_data=chart_data.sort_values(by="people_fully_vaccinated_per_hundred",ascending=True)
plt.barh(chart_data["location"],chart_data["people_fully_vaccinated_per_hundred"],label="People fully vaccinated")
#plt.grid(axis="y")
#h1,l1 = ax1.get_legend_handles_labels()
#h2,l2 = ax2.get_legend_handles_labels()
#plt.legend(h1+h2,l1+l2)

"""
plt.subplot(2,2,2) # (rows, columns, panel number)
plt.title("Daily new confirmed COVID-19 cases in the world(after 2021 Apr 1st)")
chart_data = world_df[world_df.date >= "2021-04-01"]
plt.bar(chart_data["date"],chart_data["new_cases"],label="New deaths")
plt.plot_date(chart_data["date"],chart_data["new_cases_smoothed"],label="rolling 7-day average", fmt="-", color="orange")
plt.xticks(rotation=70)
plt.grid(axis="y")
plt.legend()

plt.subplot(2,2,3) # (rows, columns, panel number)
plt.title("Daily new deaths in the world")
plt.bar(world_df.date,world_df.new_deaths,label="New cases")
plt.plot_date(world_df["date"],world_df["new_deaths_smoothed"],label="rolling 7-day average", fmt="-", color="orange")
plt.xticks(rotation=70)
plt.ylabel("people")
plt.grid(axis="y")
plt.legend()

plt.subplot(2,2,4) # (rows, columns, panel number)
plt.title("Daily new deaths in the world(after 2021 Apr 1st)")
chart_data = world_df[world_df.date >= "2021-04-01"]
plt.bar(chart_data["date"],chart_data["new_deaths"],label="New deaths")
plt.plot_date(chart_data["date"],chart_data["new_deaths_smoothed"],label="rolling 7-day average", fmt="-", color="orange")
plt.xticks(rotation=70)
plt.grid(axis="y")
plt.legend()
"""

fig.text(0,1,"Latest: {}".format(latest_date_str),fontsize=8,ha="left",va="top")
fig.text(0,0
         ,"*Data reference from:COVID-19 Dataset by Our World in Data",
        fontsize=7,ha="left",va="bottom")

fig.tight_layout()
# Out:
# <div id='5e93390d-263f-4fe8-9607-eb0d1773e624'></div>

# %%
fig.savefig("out/covid-owid-global-vaccinations-daily.png")
