# %%
import pandas as pd

# %%
pref = pd.read_csv("COVID-19-jp/nhk_news_covid19_prefectures_daily_data.csv")
print(len(pref))
pref.head()
# Out:
# 22137
#           日付  都道府県コード 都道府県名  各地の感染者数_1日ごとの発表数  各地の感染者数_累計  各地の死者数_1日ごとの発表数  \
# 0  2020/1/16        1   北海道                 0           0                0
# 1  2020/1/17        1   北海道                 0           0                0
# 2  2020/1/18        1   北海道                 0           0                0
# 3  2020/1/19        1   北海道                 0           0                0
# 4  2020/1/20        1   北海道                 0           0                0
#
#    各地の死者数_累計
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0

# %%
pref["日付"] = pd.to_datetime(pref["日付"] )

# %%
all_jp = pref.groupby(["日付"], as_index=False).sum()
del all_jp["都道府県コード"]
del all_jp["各地の感染者数_累計"]
del all_jp["各地の死者数_累計"]
all_jp.tail()
# Out:
#             日付  各地の感染者数_1日ごとの発表数  各地の死者数_1日ごとの発表数
# 466 2021-04-26              3299               35
# 467 2021-04-27              4955               63
# 468 2021-04-28              5785               51
# 469 2021-04-29              5899               78
# 470 2021-04-30              4678               39

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook
#%matplotlib inline

# %%
all_jp
# Out:
#             日付  各地の感染者数_1日ごとの発表数  各地の死者数_1日ごとの発表数
# 0   2020-01-16                 1                0
# 1   2020-01-17                 0                0
# 2   2020-01-18                 0                0
# 3   2020-01-19                 0                0
# 4   2020-01-20                 0                0
# ..         ...               ...              ...
# 466 2021-04-26              3299               35
# 467 2021-04-27              4955               63
# 468 2021-04-28              5785               51
# 469 2021-04-29              5899               78
# 470 2021-04-30              4678               39
#
# [471 rows x 3 columns]

# %%
fig = plt.figure(figsize=(8,5))
ax1 = fig.add_subplot(111)
ax1.plot_date(all_jp["日付"],all_jp["各地の感染者数_1日ごとの発表数"],label="positive", linestyle="solid",marker="")
# ax2 = ax1.twinx()
ax1.plot_date(all_jp["日付"],all_jp["各地の死者数_1日ごとの発表数"],label="death", linestyle="solid",marker="")
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="800">
