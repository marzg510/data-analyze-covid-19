# %%
import pandas as pd

# %%
pop = pd.read_excel("world-data/WPP2019_POP_F01_1_TOTAL_POPULATION_BOTH_SEXES.xlsx",header=16)
pop.head()
# Out:
#    Index    Variant Region, subregion, country or area * Notes  Country code  \
# 0      1  Estimates                                WORLD   NaN           900
# 1      2  Estimates                UN development groups     a          1803
# 2      3  Estimates               More developed regions     b           901
# 3      4  Estimates               Less developed regions     c           902
# 4      5  Estimates            Least developed countries     d           941
#
#                 Type  Parent code         1950         1951         1952  ...  \
# 0              World            0  2536431.018  2584034.227   2630861.69  ...
# 1    Label/Separator          900          ...          ...          ...  ...
# 2  Development Group         1803   814818.913   824003.512   833720.173  ...
# 3  Development Group         1803  1721612.105  1760030.715  1797141.517  ...
# 4  Development Group          902   195427.785   199180.385   203015.198  ...
#
#           2011         2012         2013         2014         2015  \
# 0  7041194.168  7125827.957  7210582.041  7295290.759  7379796.967
# 1          ...          ...          ...          ...          ...
# 2  1239557.448  1244114.531   1248453.53  1252615.112  1256622.188
# 3   5801636.72  5881713.426  5962128.511  6042675.647  6123174.779
# 4   856471.437   876867.234   897793.439   919222.955   941131.317
#
#           2016        2017         2018         2019         2020
# 0  7464021.934   7547858.9  7631091.113  7713468.205  7794798.729
# 1          ...         ...          ...          ...          ...
# 2  1260478.667  1264146.38  1267558.904   1270630.32  1273304.261
# 3  6203543.267  6283712.52  6363532.209  6442837.885  6521494.468
# 4   963519.718  986385.402  1009691.252  1033388.868  1057438.163
#
# [5 rows x 78 columns]

# %%
world_pop = pop.loc[pop["Type"]=="World"]
world_pop.head()
# Out:
#    Index    Variant Region, subregion, country or area * Notes  Country code  \
# 0      1  Estimates                                WORLD   NaN           900
#
#     Type  Parent code         1950         1951        1952  ...         2011  \
# 0  World            0  2536431.018  2584034.227  2630861.69  ...  7041194.168
#
#           2012         2013         2014         2015         2016       2017  \
# 0  7125827.957  7210582.041  7295290.759  7379796.967  7464021.934  7547858.9
#
#           2018         2019         2020
# 0  7631091.113  7713468.205  7794798.729
#
# [1 rows x 78 columns]

# %%
#del world_pop[world_pop.columns[0:2]]
#del world_pop[0]
world_pop = world_pop.drop(world_pop.iloc[:,0:7],axis=1).stack().reset_index()
world_pop.columns = ["dummy","year","population"]
del world_pop["dummy"]
world_pop
# Out:
#     year   population
# 0   1950  2536431.018
# 1   1951  2584034.227
# 2   1952   2630861.69
# 3   1953  2677609.061
# 4   1954  2724846.754
# ..   ...          ...
# 66  2016  7464021.934
# 67  2017    7547858.9
# 68  2018  7631091.113
# 69  2019  7713468.205
# 70  2020  7794798.729
#
# [71 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook
#%matplotlib inline

# %%
plt.figure(figsize=(10,5))
plt.plot(world_pop["year"],world_pop["population"],label="population(1000)")
plt.xticks(rotation="90",fontsize=9)
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="1000">
